# %% [markdown]
# # Dependencies

# %%
import warnings
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

from sklearn.ensemble import RandomForestClassifier
from sklearn.feature_selection import VarianceThreshold
from sklearn.preprocessing import MinMaxScaler, StandardScaler
from sklearn.model_selection import train_test_split, StratifiedKFold
from sklearn.metrics import confusion_matrix, roc_auc_score, recall_score, precision_score

# Set seeds to make the experiment more reproducible.
from numpy.random import seed
seed(0)

# %matplotlib inline
sns.set_style("whitegrid")
warnings.filterwarnings("ignore")

# %% [markdown]
# # Load data

# %%
train = pd.read_csv('../input/train.csv')
test = pd.read_csv('../input/test.csv')
# submission = pd.read_csv('../input/sample_submission.csv')

# %%
print('Train set shape:', train.shape)
print('Test set shape:', test.shape)
print('Train set overview:')
display(train.head())
# Out:
# Train set shape: (262144, 258)
# Test set shape: (131073, 257)
# Train set overview:
#                                  id   ...    target
# 0  707b395ecdcbb4dc2eabea00e4d1b179   ...         0
# 1  5880c03c6582a7b42248668e56b4bdec   ...         0
# 2  4ccbcb3d13e5072ff1d9c61afe2c4f77   ...         1
# 3  e350f17a357f12a1941f0837afb7eb8d   ...         0
# 4  a8f910ea6075b6376af079055965ff68   ...         0
#
# [5 rows x 258 columns]

# %% [markdown]
# ## Preprocess

# %% [markdown]
# # Model
#
# ## Model parameters

# %%
N_FOLDS = 11

# %%
# INITIALIZE VARIABLES
cols = [c for c in train.columns if c not in ['id', 'target', 'wheezy-copper-turtle-magic', 'preds']]
test['target'] = 0
train['preds'] = 0

# BUILD 512 MODELS
for i in range(512):
    print('wheezy-copper-turtle-magic {}\n'.format(i))
    
    # EXTRACT SUBSET OF DATASET WHERE WHEEZY-MAGIC EQUALS I
    train2 = train[train['wheezy-copper-turtle-magic']==i]
    test2 = test[test['wheezy-copper-turtle-magic']==i]
    idx1 = train2.index
    idx2 = test2.index
    train2.reset_index(drop=True, inplace=True)
    
    # FEATURE SELECTION (USE APPROX 40 OF 255 FEATURES)
    sel = VarianceThreshold(threshold=1.5).fit(train2[cols])
    train3 = sel.transform(train2[cols])
    test3 = sel.transform(test2[cols])

    skf = StratifiedKFold(n_splits=N_FOLDS, random_state=0)
    counter = 0

    for train_index, val_index in skf.split(train3, train2['target']):
        counter += 1
        print('Fold {}\n'.format(counter))
        model = RandomForestClassifier()

        model.fit(train3[train_index,:], train2.loc[train_index]['target'])
        
        train_predictions = model.predict(train3[train_index,:])
        val_predictions = model.predict(train3[val_index,:])

        train_auc = roc_auc_score(train2.loc[train_index]['target'], train_predictions) * 100
        val_auc = roc_auc_score(train2.loc[val_index]['target'], val_predictions) * 100
        train_precision = precision_score(train2.loc[train_index]['target'], train_predictions) * 100
        val_precision = precision_score(train2.loc[val_index]['target'], val_predictions) * 100
        train_recall = recall_score(train2.loc[train_index]['target'], train_predictions) * 100
        val_recall = recall_score(train2.loc[val_index]['target'], val_predictions) * 100
        print('-----Train----------')
        print('AUC: %.2f Precision: %.2f Recall: %.2f \n' % (train_auc, train_precision, train_recall))
        print('-----Validation-----')
        print('AUC: %.2f Precision: %.2f Recall: %.2f \n' % (val_auc, val_precision, val_recall))

        # Make predictions
        train['preds'].loc[idx1] += model.predict_proba(train3)[:,1] / N_FOLDS
        test['target'].loc[idx2] += model.predict_proba(test3)[:,1] / N_FOLDS
# Out:
# wheezy-copper-turtle-magic 0
#
# Fold 1
#
# -----Train----------
# AUC: 99.59 Precision: 99.58 Recall: 99.58
#
# -----Validation-----
# AUC: 75.17 Precision: 87.50 Recall: 58.33
#
# Fold 2
#
# -----Train----------
# AUC: 98.74 Precision: 100.00 Recall: 97.49
#
# -----Validation-----
# AUC: 61.25 Precision: 60.00 Recall: 62.50
#
# Fold 3
#
# -----Train----------
# AUC: 99.16 Precision: 100.00 Recall: 98.33
#
# -----Validation-----
# AUC: 77.50 Precision: 78.26 Recall: 75.00
#
# Fold 4
#
# -----Train----------
# AUC: 99.37 Precision: 100.00 Recall: 98.74
#
# -----Validation-----
# AUC: 67.17 Precision: 70.00 Recall: 58.33
#
# Fold 5
#
# -----Train----------
# AUC: 99.38 Precision: 99.17 Recall: 99.58
#
# -----Validation-----
# AUC: 52.75 Precision: 52.94 Recall: 37.50
#
# Fold 6
#
# -----Train----------
# AUC: 98.33 Precision: 99.57 Recall: 97.07
#
# -----Validation-----
# AUC: 69.17 Precision: 73.68 Recall: 58.33
#
# Fold 7
#
# -----Train----------
# AUC: 98.75 Precision: 99.57 Recall: 97.91
#
# -----Validation-----
# AUC: 65.00 Precision: 70.59 Recall: 50.00
#
# Fold 8
#
# -----Train----------
# AUC: 99.16 Precision: 100.00 Recall: 98.33
#
# -----Validation-----
# AUC: 68.75 Precision: 69.57 Recall: 66.67
#
# Fold 9
#
# -----Train----------
# AUC: 98.54 Precision: 99.57 Recall: 97.49
#
# -----Validation-----
# AUC: 77.08 Precision: 76.00 Recall: 79.17
#
# Fold 10
#
# -----Train----------
# AUC: 98.74 Precision: 100.00 Recall: 97.49
#
# -----Validation-----
# AUC: 58.33 Precision: 64.29 Recall: 37.50
#
# Fold 11
#
# -----Train----------
# AUC: 98.55 Precision: 99.16 Recall: 97.92
#
# -----Validation-----
# AUC: 76.36 Precision: 83.33 Recall: 65.22
#
# wheezy-copper-turtle-magic 1
#
# Fold 1
#
# -----Train----------
# AUC: 98.91 Precision: 99.10 Recall: 98.65
#
# -----Validation-----
# AUC: 57.25 Precision: 57.89 Recall: 47.83
#
# Fold 2
#
# -----Train----------
# AUC: 99.10 Precision: 100.00 Recall: 98.21
#
# -----Validation-----
# AUC: 69.93 Precision: 76.47 Recall: 56.52
#
# Fold 3
#
# -----Train----------
# AUC: 99.10 Precision: 100.00 Recall: 98.21
#
# -----Validation-----
# AUC: 69.93 Precision: 76.47 Recall: 56.52
#
# Fold 4
#
# -----Train----------
# AUC: 99.34 Precision: 99.55 Recall: 99.10
#
# -----Validation-----
# AUC: 50.72 Precision: 50.00 Recall: 34.78
#
# Fold 5
#
# -----Train----------
# AUC: 98.88 Precision: 100.00 Recall: 97.77
#
# -----Validation-----
# AUC: 66.48 Precision: 76.92 Recall: 45.45
#
# Fold 6
#
# -----Train----------
# AUC: 99.35 Precision: 99.55 Recall: 99.11
#
# -----Validation-----
# AUC: 60.42 Precision: 61.11 Recall: 50.00
#
# Fold 7
#
# -----Train----------
# AUC: 98.88 Precision: 100.00 Recall: 97.77
#
# -----Validation-----
# AUC: 71.40 Precision: 73.68 Recall: 63.64
#
# Fold 8
#
# -----Train----------
# AUC: 98.45 Precision: 99.54 Recall: 97.32
#
# -----Validation-----
# AUC: 84.47 Precision: 89.47 Recall: 77.27
#
# Fold 9
#
# -----Train----------
# AUC: 98.66 Precision: 100.00 Recall: 97.32
#
# -----Validation-----
# AUC: 73.86 Precision: 72.73 Recall: 72.73
#
# Fold 10
#
# -----Train----------
# AUC: 99.78 Precision: 100.00 Recall: 99.55
#
# -----Validation-----
# AUC: 82.20 Precision: 88.89 Recall: 72.73
#
# Fold 11
#
# -----Train----------
# AUC: 99.78 Precision: 100.00 Recall: 99.55
#
# -----Validation-----
# AUC: 66.67 Precision: 73.33 Recall: 50.00
#
# wheezy-copper-turtle-magic 2
#
# Fold 1
#
# -----Train----------
# AUC: 98.86 Precision: 100.00 Recall: 97.73
#
# -----Validation-----
# AUC: 69.57 Precision: 73.68 Recall: 60.87
#
# Fold 2
#
# -----Train----------
# AUC: 99.10 Precision: 100.00 Recall: 98.19
#
# -----Validation-----
# AUC: 59.68 Precision: 62.50 Recall: 45.45
#
# Fold 3
#
# -----Train----------
# AUC: 98.65 Precision: 99.54 Recall: 97.74
#
# -----Validation-----
# AUC: 70.85 Precision: 76.47 Recall: 59.09
#
# Fold 4
#
# -----Train----------
# AUC: 99.32 Precision: 100.00 Recall: 98.64
#
# -----Validation-----
# AUC: 55.34 Precision: 55.56 Recall: 45.45
#
# Fold 5
#
# -----Train----------
# AUC: 99.55 Precision: 100.00 Recall: 99.10
#
# -----Validation-----
# AUC: 57.51 Precision: 58.82 Recall: 45.45
#
# Fold 6
#
# -----Train----------
# AUC: 98.87 Precision: 100.00 Recall: 97.74
#
# -----Validation-----
# AUC: 64.43 Precision: 63.64 Recall: 63.64
#
# Fold 7
#
# -----Train----------
# AUC: 99.10 Precision: 99.54 Recall: 98.64
#
# -----Validation-----
# AUC: 68.68 Precision: 72.22 Recall: 59.09
#
# Fold 8
#
# -----Train----------
# AUC: 99.33 Precision: 99.55 Recall: 99.10
#
# -----Validation-----
# AUC: 64.23 Precision: 66.67 Recall: 54.55
#
# Fold 9
#
# -----Train----------
# AUC: 98.64 Precision: 100.00 Recall: 97.29
#
# -----Validation-----
# AUC: 68.97 Precision: 66.67 Recall: 72.73
#
# Fold 10
#
# -----Train----------
# AUC: 99.10 Precision: 99.54 Recall: 98.64
#
# -----Validation-----
# AUC: 73.02 Precision: 81.25 Recall: 59.09
#
# Fold 11
#
# -----Train----------
# AUC: 99.10 Precision: 99.54 Recall: 98.64
#
# -----Validation-----
# AUC: 63.64 Precision: 66.67 Recall: 54.55
#
# wheezy-copper-turtle-magic 3
#
# Fold 1
#
# -----Train----------
# AUC: 99.39 Precision: 99.61 Recall: 99.22
#
# -----Validation-----
# AUC: 63.78 Precision: 64.29 Recall: 69.23
#
# Fold 2
#
# -----Train----------
# AUC: 99.18 Precision: 99.22 Recall: 99.22
#
# -----Validation-----
# AUC: 59.94 Precision: 61.54 Recall: 61.54
#
# Fold 3
#
# -----Train----------
# AUC: 99.20 Precision: 99.60 Recall: 98.82
#
# -----Validation-----
# AUC: 70.19 Precision: 73.91 Recall: 65.38
#
# Fold 4
#
# -----Train----------
# AUC: 98.63 Precision: 100.00 Recall: 97.25
#
# -----Validation-----
# AUC: 70.03 Precision: 72.00 Recall: 69.23
#
# Fold 5
#
# -----Train----------
# AUC: 99.22 Precision: 100.00 Recall: 98.43
#
# -----Validation-----
# AUC: 59.28 Precision: 62.50 Recall: 57.69
#
# Fold 6
#
# -----Train----------
# AUC: 99.80 Precision: 100.00 Recall: 99.61
#
# -----Validation-----
# AUC: 65.55 Precision: 69.57 Recall: 61.54
#
# Fold 7
#
# -----Train----------
# AUC: 98.99 Precision: 99.22 Recall: 98.83
#
# -----Validation-----
# AUC: 66.96 Precision: 71.43 Recall: 60.00
#
# Fold 8
#
# -----Train----------
# AUC: 99.22 Precision: 100.00 Recall: 98.44
#
# -----Validation-----
# AUC: 52.43 Precision: 55.00 Recall: 44.00
#
# Fold 9
#
# -----Train----------
# AUC: 99.61 Precision: 100.00 Recall: 99.22
#
# -----Validation-----
# AUC: 83.48 Precision: 86.96 Recall: 80.00
#
# Fold 10
#
# -----Train----------
# AUC: 98.44 Precision: 100.00 Recall: 96.88
#
# -----Validation-----
# AUC: 66.78 Precision: 69.57 Recall: 64.00
#
# Fold 11
#
# -----Train----------
# AUC: 98.83 Precision: 100.00 Recall: 97.66
#
# -----Validation-----
# AUC: 62.26 Precision: 62.96 Recall: 68.00
#
# wheezy-copper-turtle-magic 4
#
# Fold 1
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 64.58 Precision: 68.42 Recall: 54.17
#
# Fold 2
#
# -----Train----------
# AUC: 98.73 Precision: 99.57 Recall: 97.89
#
# -----Validation-----
# AUC: 79.17 Precision: 88.89 Recall: 66.67
#
# Fold 3
#
# -----Train----------
# AUC: 99.79 Precision: 100.00 Recall: 99.58
#
# -----Validation-----
# AUC: 62.05 Precision: 68.75 Recall: 45.83
#
# Fold 4
#
# -----Train----------
# AUC: 99.37 Precision: 100.00 Recall: 98.73
#
# -----Validation-----
# AUC: 83.24 Precision: 94.44 Recall: 70.83
#
# Fold 5
#
# -----Train----------
# AUC: 98.51 Precision: 99.15 Recall: 97.89
#
# -----Validation-----
# AUC: 68.30 Precision: 73.68 Recall: 58.33
#
# Fold 6
#
# -----Train----------
# AUC: 98.95 Precision: 100.00 Recall: 97.89
#
# -----Validation-----
# AUC: 68.39 Precision: 76.47 Recall: 54.17
#
# Fold 7
#
# -----Train----------
# AUC: 99.36 Precision: 99.16 Recall: 99.58
#
# -----Validation-----
# AUC: 61.96 Precision: 66.67 Recall: 50.00
#
# Fold 8
#
# -----Train----------
# AUC: 98.94 Precision: 99.15 Recall: 98.73
#
# -----Validation-----
# AUC: 76.72 Precision: 80.95 Recall: 70.83
#
# Fold 9
#
# -----Train----------
# AUC: 99.15 Precision: 99.58 Recall: 98.74
#
# -----Validation-----
# AUC: 73.91 Precision: 73.91 Recall: 73.91
#
# Fold 10
#
# -----Train----------
# AUC: 98.53 Precision: 100.00 Recall: 97.06
#
# -----Validation-----
# AUC: 71.74 Precision: 77.78 Recall: 60.87
#
# Fold 11
#
# -----Train----------
# AUC: 99.36 Precision: 99.58 Recall: 99.16
#
# -----Validation-----
# AUC: 63.04 Precision: 65.00 Recall: 56.52
#
# wheezy-copper-turtle-magic 5
#
# Fold 1
#
# -----Train----------
# AUC: 99.36 Precision: 100.00 Recall: 98.72
#
# -----Validation-----
# AUC: 66.67 Precision: 68.18 Recall: 62.50
#
# Fold 2
#
# -----Train----------
# AUC: 98.73 Precision: 99.57 Recall: 97.87
#
# -----Validation-----
# AUC: 56.25 Precision: 58.82 Recall: 41.67
#
# Fold 3
#
# -----Train----------
# AUC: 98.94 Precision: 99.15 Recall: 98.72
#
# -----Validation-----
# AUC: 60.42 Precision: 63.16 Recall: 50.00
#
# Fold 4
#
# -----Train----------
# AUC: 98.94 Precision: 99.15 Recall: 98.72
#
# -----Validation-----
# AUC: 66.67 Precision: 65.38 Recall: 70.83
#
# Fold 5
#
# -----Train----------
# AUC: 99.57 Precision: 100.00 Recall: 99.15
#
# -----Validation-----
# AUC: 81.25 Precision: 82.61 Recall: 79.17
#
# Fold 6
#
# -----Train----------
# AUC: 99.36 Precision: 99.57 Recall: 99.15
#
# -----Validation-----
# AUC: 68.75 Precision: 80.00 Recall: 50.00
#
# Fold 7
#
# -----Train----------
# AUC: 98.52 Precision: 100.00 Recall: 97.03
#
# -----Validation-----
# AUC: 50.91 Precision: 50.00 Recall: 43.48
#
# Fold 8
#
# -----Train----------
# AUC: 98.94 Precision: 99.15 Recall: 98.73
#
# -----Validation-----
# AUC: 74.28 Precision: 78.95 Recall: 65.22
#
# Fold 9
#
# -----Train----------
# AUC: 98.73 Precision: 99.57 Recall: 97.88
#
# -----Validation-----
# AUC: 74.46 Precision: 73.91 Recall: 73.91
#
# Fold 10
#
# -----Train----------
# AUC: 98.31 Precision: 100.00 Recall: 96.61
#
# -----Validation-----
# AUC: 67.39 Precision: 68.18 Recall: 65.22
#
# Fold 11
#
# -----Train----------
# AUC: 98.95 Precision: 99.15 Recall: 98.73
#
# -----Validation-----
# AUC: 65.22 Precision: 73.33 Recall: 47.83
#
# wheezy-copper-turtle-magic 6
#
# Fold 1
#
# -----Train----------
# AUC: 99.38 Precision: 100.00 Recall: 98.75
#
# -----Validation-----
# AUC: 70.78 Precision: 72.00 Recall: 72.00
#
# Fold 2
#
# -----Train----------
# AUC: 99.38 Precision: 100.00 Recall: 98.76
#
# -----Validation-----
# AUC: 70.38 Precision: 75.00 Recall: 62.50
#
# Fold 3
#
# -----Train----------
# AUC: 99.37 Precision: 99.58 Recall: 99.17
#
# -----Validation-----
# AUC: 64.04 Precision: 68.42 Recall: 54.17
#
# Fold 4
#
# -----Train----------
# AUC: 99.59 Precision: 100.00 Recall: 99.17
#
# -----Validation-----
# AUC: 85.42 Precision: 100.00 Recall: 70.83
#
# Fold 5
#
# -----Train----------
# AUC: 99.17 Precision: 100.00 Recall: 98.34
#
# -----Validation-----
# AUC: 66.30 Precision: 75.00 Recall: 50.00
#
# Fold 6
#
# -----Train----------
# AUC: 98.96 Precision: 100.00 Recall: 97.93
#
# -----Validation-----
# AUC: 66.12 Precision: 70.00 Recall: 58.33
#
# Fold 7
#
# -----Train----------
# AUC: 99.16 Precision: 99.58 Recall: 98.76
#
# -----Validation-----
# AUC: 72.28 Precision: 72.00 Recall: 75.00
#
# Fold 8
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 79.08 Precision: 93.75 Recall: 62.50
#
# Fold 9
#
# -----Train----------
# AUC: 99.16 Precision: 99.58 Recall: 98.76
#
# -----Validation-----
# AUC: 66.30 Precision: 75.00 Recall: 50.00
#
# Fold 10
#
# -----Train----------
# AUC: 98.74 Precision: 99.16 Recall: 98.34
#
# -----Validation-----
# AUC: 63.86 Precision: 65.22 Recall: 62.50
#
# Fold 11
#
# -----Train----------
# AUC: 99.78 Precision: 99.59 Recall: 100.00
#
# -----Validation-----
# AUC: 68.39 Precision: 76.47 Recall: 54.17
#
# wheezy-copper-turtle-magic 7
#
# Fold 1
#
# -----Train----------
# AUC: 99.13 Precision: 99.56 Recall: 98.70
#
# -----Validation-----
# AUC: 76.81 Precision: 84.21 Recall: 66.67
#
# Fold 2
#
# -----Train----------
# AUC: 98.26 Precision: 99.12 Recall: 97.40
#
# -----Validation-----
# AUC: 71.74 Precision: 85.71 Recall: 52.17
#
# Fold 3
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 58.70 Precision: 62.50 Recall: 43.48
#
# Fold 4
#
# -----Train----------
# AUC: 99.35 Precision: 100.00 Recall: 98.70
#
# -----Validation-----
# AUC: 69.57 Precision: 73.68 Recall: 60.87
#
# Fold 5
#
# -----Train----------
# AUC: 98.48 Precision: 99.56 Recall: 97.40
#
# -----Validation-----
# AUC: 56.52 Precision: 58.82 Recall: 43.48
#
# Fold 6
#
# -----Train----------
# AUC: 99.57 Precision: 100.00 Recall: 99.13
#
# -----Validation-----
# AUC: 65.22 Precision: 73.33 Recall: 47.83
#
# Fold 7
#
# -----Train----------
# AUC: 99.35 Precision: 99.57 Recall: 99.13
#
# -----Validation-----
# AUC: 65.22 Precision: 66.67 Recall: 60.87
#
# Fold 8
#
# -----Train----------
# AUC: 98.92 Precision: 100.00 Recall: 97.84
#
# -----Validation-----
# AUC: 65.22 Precision: 68.42 Recall: 56.52
#
# Fold 9
#
# -----Train----------
# AUC: 99.57 Precision: 99.57 Recall: 99.57
#
# -----Validation-----
# AUC: 63.04 Precision: 65.00 Recall: 56.52
#
# Fold 10
#
# -----Train----------
# AUC: 98.70 Precision: 100.00 Recall: 97.40
#
# -----Validation-----
# AUC: 69.57 Precision: 69.57 Recall: 69.57
#
# Fold 11
#
# -----Train----------
# AUC: 99.13 Precision: 100.00 Recall: 98.27
#
# -----Validation-----
# AUC: 71.34 Precision: 77.78 Recall: 60.87
#
# wheezy-copper-turtle-magic 8
#
# Fold 1
#
# -----Train----------
# AUC: 98.97 Precision: 100.00 Recall: 97.93
#
# -----Validation-----
# AUC: 55.33 Precision: 57.89 Recall: 44.00
#
# Fold 2
#
# -----Train----------
# AUC: 99.38 Precision: 100.00 Recall: 98.76
#
# -----Validation-----
# AUC: 61.42 Precision: 65.00 Recall: 52.00
#
# Fold 3
#
# -----Train----------
# AUC: 98.35 Precision: 100.00 Recall: 96.69
#
# -----Validation-----
# AUC: 58.96 Precision: 64.71 Recall: 44.00
#
# Fold 4
#
# -----Train----------
# AUC: 98.14 Precision: 99.58 Recall: 96.71
#
# -----Validation-----
# AUC: 68.21 Precision: 71.43 Recall: 62.50
#
# Fold 5
#
# -----Train----------
# AUC: 98.97 Precision: 100.00 Recall: 97.94
#
# -----Validation-----
# AUC: 55.43 Precision: 57.14 Recall: 50.00
#
# Fold 6
#
# -----Train----------
# AUC: 98.54 Precision: 99.17 Recall: 97.94
#
# -----Validation-----
# AUC: 47.19 Precision: 46.67 Recall: 29.17
#
# Fold 7
#
# -----Train----------
# AUC: 99.17 Precision: 99.59 Recall: 98.77
#
# -----Validation-----
# AUC: 55.53 Precision: 57.89 Recall: 45.83
#
# Fold 8
#
# -----Train----------
# AUC: 99.37 Precision: 99.59 Recall: 99.18
#
# -----Validation-----
# AUC: 70.38 Precision: 75.00 Recall: 62.50
#
# Fold 9
#
# -----Train----------
# AUC: 98.96 Precision: 99.58 Recall: 98.35
#
# -----Validation-----
# AUC: 64.22 Precision: 73.33 Recall: 45.83
#
# Fold 10
#
# -----Train----------
# AUC: 99.18 Precision: 100.00 Recall: 98.35
#
# -----Validation-----
# AUC: 61.68 Precision: 62.50 Recall: 62.50
#
# Fold 11
#
# -----Train----------
# AUC: 99.17 Precision: 99.59 Recall: 98.77
#
# -----Validation-----
# AUC: 59.69 Precision: 61.90 Recall: 54.17
#
# wheezy-copper-turtle-magic 9
#
# Fold 1
#
# -----Train----------
# AUC: 99.58 Precision: 100.00 Recall: 99.17
#
# -----Validation-----
# AUC: 60.42 Precision: 64.71 Recall: 45.83
#
# Fold 2
#
# -----Train----------
# AUC: 98.54 Precision: 99.57 Recall: 97.50
#
# -----Validation-----
# AUC: 58.33 Precision: 61.11 Recall: 45.83
#
# Fold 3
#
# -----Train----------
# AUC: 98.54 Precision: 99.57 Recall: 97.50
#
# -----Validation-----
# AUC: 56.25 Precision: 57.89 Recall: 45.83
#
# Fold 4
#
# -----Train----------
# AUC: 99.58 Precision: 100.00 Recall: 99.17
#
# -----Validation-----
# AUC: 60.42 Precision: 64.71 Recall: 45.83
#
# Fold 5
#
# -----Train----------
# AUC: 98.12 Precision: 99.57 Recall: 96.67
#
# -----Validation-----
# AUC: 66.67 Precision: 83.33 Recall: 41.67
#
# Fold 6
#
# -----Train----------
# AUC: 99.79 Precision: 100.00 Recall: 99.58
#
# -----Validation-----
# AUC: 64.58 Precision: 76.92 Recall: 41.67
#
# Fold 7
#
# -----Train----------
# AUC: 99.17 Precision: 99.58 Recall: 98.75
#
# -----Validation-----
# AUC: 50.00 Precision: 50.00 Recall: 50.00
#
# Fold 8
#
# -----Train----------
# AUC: 99.58 Precision: 100.00 Recall: 99.17
#
# -----Validation-----
# AUC: 64.58 Precision: 64.00 Recall: 66.67
#
# Fold 9
#
# -----Train----------
# AUC: 98.75 Precision: 100.00 Recall: 97.50
#
# -----Validation-----
# AUC: 60.42 Precision: 61.90 Recall: 54.17
#
# Fold 10
#
# -----Train----------
# AUC: 98.75 Precision: 100.00 Recall: 97.50
#
# -----Validation-----
# AUC: 68.75 Precision: 76.47 Recall: 54.17
#
# Fold 11
#
# -----Train----------
# AUC: 98.75 Precision: 100.00 Recall: 97.50
#
# -----Validation-----
# AUC: 72.92 Precision: 82.35 Recall: 58.33
#
# wheezy-copper-turtle-magic 10
#
# Fold 1
#
# -----Train----------
# AUC: 98.88 Precision: 100.00 Recall: 97.76
#
# -----Validation-----
# AUC: 73.91 Precision: 82.35 Recall: 60.87
#
# Fold 2
#
# -----Train----------
# AUC: 99.33 Precision: 100.00 Recall: 98.65
#
# -----Validation-----
# AUC: 65.22 Precision: 66.67 Recall: 60.87
#
# Fold 3
#
# -----Train----------
# AUC: 99.78 Precision: 100.00 Recall: 99.55
#
# -----Validation-----
# AUC: 82.61 Precision: 94.12 Recall: 69.57
#
# Fold 4
#
# -----Train----------
# AUC: 99.10 Precision: 100.00 Recall: 98.21
#
# -----Validation-----
# AUC: 54.35 Precision: 56.25 Recall: 39.13
#
# Fold 5
#
# -----Train----------
# AUC: 99.34 Precision: 99.55 Recall: 99.11
#
# -----Validation-----
# AUC: 68.77 Precision: 70.00 Recall: 63.64
#
# Fold 6
#
# -----Train----------
# AUC: 99.33 Precision: 100.00 Recall: 98.66
#
# -----Validation-----
# AUC: 73.22 Precision: 75.00 Recall: 68.18
#
# Fold 7
#
# -----Train----------
# AUC: 99.11 Precision: 100.00 Recall: 98.21
#
# -----Validation-----
# AUC: 59.88 Precision: 60.00 Recall: 54.55
#
# Fold 8
#
# -----Train----------
# AUC: 99.55 Precision: 100.00 Recall: 99.11
#
# -----Validation-----
# AUC: 77.67 Precision: 80.00 Recall: 72.73
#
# Fold 9
#
# -----Train----------
# AUC: 99.78 Precision: 100.00 Recall: 99.55
#
# -----Validation-----
# AUC: 77.57 Precision: 83.33 Recall: 68.18
#
# Fold 10
#
# -----Train----------
# AUC: 98.89 Precision: 99.55 Recall: 98.21
#
# -----Validation-----
# AUC: 77.47 Precision: 87.50 Recall: 63.64
#
# Fold 11
#
# -----Train----------
# AUC: 98.90 Precision: 99.10 Recall: 98.66
#
# -----Validation-----
# AUC: 52.27 Precision: 53.33 Recall: 36.36
#
# wheezy-copper-turtle-magic 11
#
# Fold 1
#
# -----Train----------
# AUC: 99.52 Precision: 100.00 Recall: 99.05
#
# -----Validation-----
# AUC: 77.77 Precision: 77.27 Recall: 77.27
#
# Fold 2
#
# -----Train----------
# AUC: 98.34 Precision: 100.00 Recall: 96.68
#
# -----Validation-----
# AUC: 65.73 Precision: 65.00 Recall: 61.90
#
# Fold 3
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 77.43 Precision: 73.91 Recall: 80.95
#
# Fold 4
#
# -----Train----------
# AUC: 98.83 Precision: 99.52 Recall: 98.10
#
# -----Validation-----
# AUC: 60.56 Precision: 64.29 Recall: 42.86
#
# Fold 5
#
# -----Train----------
# AUC: 99.54 Precision: 99.53 Recall: 99.53
#
# -----Validation-----
# AUC: 74.22 Precision: 85.71 Recall: 57.14
#
# Fold 6
#
# -----Train----------
# AUC: 98.82 Precision: 100.00 Recall: 97.63
#
# -----Validation-----
# AUC: 67.70 Precision: 70.59 Recall: 57.14
#
# Fold 7
#
# -----Train----------
# AUC: 98.82 Precision: 100.00 Recall: 97.63
#
# -----Validation-----
# AUC: 49.69 Precision: 47.37 Recall: 42.86
#
# Fold 8
#
# -----Train----------
# AUC: 99.29 Precision: 100.00 Recall: 98.58
#
# -----Validation-----
# AUC: 67.08 Precision: 81.82 Recall: 42.86
#
# Fold 9
#
# -----Train----------
# AUC: 97.88 Precision: 99.51 Recall: 96.21
#
# -----Validation-----
# AUC: 64.72 Precision: 71.43 Recall: 47.62
#
# Fold 10
#
# -----Train----------
# AUC: 99.05 Precision: 100.00 Recall: 98.10
#
# -----Validation-----
# AUC: 76.84 Precision: 73.91 Recall: 80.95
#
# Fold 11
#
# -----Train----------
# AUC: 98.61 Precision: 99.04 Recall: 98.10
#
# -----Validation-----
# AUC: 55.30 Precision: 58.33 Recall: 33.33
#
# wheezy-copper-turtle-magic 12
#
# Fold 1
#
# -----Train----------
# AUC: 99.12 Precision: 100.00 Recall: 98.25
#
# -----Validation-----
# AUC: 69.57 Precision: 76.47 Recall: 56.52
#
# Fold 2
#
# -----Train----------
# AUC: 99.34 Precision: 100.00 Recall: 98.68
#
# -----Validation-----
# AUC: 76.09 Precision: 83.33 Recall: 65.22
#
# Fold 3
#
# -----Train----------
# AUC: 99.78 Precision: 100.00 Recall: 99.56
#
# -----Validation-----
# AUC: 76.09 Precision: 87.50 Recall: 60.87
#
# Fold 4
#
# -----Train----------
# AUC: 99.33 Precision: 99.13 Recall: 99.56
#
# -----Validation-----
# AUC: 62.55 Precision: 68.75 Recall: 47.83
#
# Fold 5
#
# -----Train----------
# AUC: 99.78 Precision: 99.56 Recall: 100.00
#
# -----Validation-----
# AUC: 69.17 Precision: 76.47 Recall: 56.52
#
# Fold 6
#
# -----Train----------
# AUC: 99.12 Precision: 100.00 Recall: 98.25
#
# -----Validation-----
# AUC: 71.15 Precision: 72.73 Recall: 69.57
#
# Fold 7
#
# -----Train----------
# AUC: 99.34 Precision: 100.00 Recall: 98.68
#
# -----Validation-----
# AUC: 62.35 Precision: 65.00 Recall: 56.52
#
# Fold 8
#
# -----Train----------
# AUC: 98.68 Precision: 99.55 Recall: 97.81
#
# -----Validation-----
# AUC: 58.00 Precision: 61.11 Recall: 47.83
#
# Fold 9
#
# -----Train----------
# AUC: 99.56 Precision: 100.00 Recall: 99.12
#
# -----Validation-----
# AUC: 55.83 Precision: 58.82 Recall: 43.48
#
# Fold 10
#
# -----Train----------
# AUC: 99.34 Precision: 100.00 Recall: 98.69
#
# -----Validation-----
# AUC: 72.73 Precision: 75.00 Recall: 68.18
#
# Fold 11
#
# -----Train----------
# AUC: 98.91 Precision: 100.00 Recall: 97.82
#
# -----Validation-----
# AUC: 68.18 Precision: 68.18 Recall: 68.18
#
# wheezy-copper-turtle-magic 13
#
# Fold 1
#
# -----Train----------
# AUC: 99.53 Precision: 100.00 Recall: 99.06
#
# -----Validation-----
# AUC: 52.96 Precision: 53.33 Recall: 36.36
#
# Fold 2
#
# -----Train----------
# AUC: 97.92 Precision: 99.04 Recall: 96.71
#
# -----Validation-----
# AUC: 62.15 Precision: 61.90 Recall: 59.09
#
# Fold 3
#
# -----Train----------
# AUC: 99.06 Precision: 100.00 Recall: 98.12
#
# -----Validation-----
# AUC: 70.95 Precision: 73.68 Recall: 63.64
#
# Fold 4
#
# -----Train----------
# AUC: 99.08 Precision: 99.53 Recall: 98.59
#
# -----Validation-----
# AUC: 64.23 Precision: 66.67 Recall: 54.55
#
# Fold 5
#
# -----Train----------
# AUC: 98.60 Precision: 100.00 Recall: 97.20
#
# -----Validation-----
# AUC: 72.05 Precision: 80.00 Recall: 57.14
#
# Fold 6
#
# -----Train----------
# AUC: 98.85 Precision: 99.53 Recall: 98.13
#
# -----Validation-----
# AUC: 60.35 Precision: 66.67 Recall: 38.10
#
# Fold 7
#
# -----Train----------
# AUC: 99.55 Precision: 99.53 Recall: 99.53
#
# -----Validation-----
# AUC: 56.00 Precision: 57.14 Recall: 38.10
#
# Fold 8
#
# -----Train----------
# AUC: 99.07 Precision: 100.00 Recall: 98.13
#
# -----Validation-----
# AUC: 74.02 Precision: 91.67 Recall: 52.38
#
# Fold 9
#
# -----Train----------
# AUC: 99.33 Precision: 99.07 Recall: 99.53
#
# -----Validation-----
# AUC: 71.97 Precision: 73.68 Recall: 66.67
#
# Fold 10
#
# -----Train----------
# AUC: 97.91 Precision: 99.52 Recall: 96.26
#
# -----Validation-----
# AUC: 81.28 Precision: 84.21 Recall: 76.19
#
# Fold 11
#
# -----Train----------
# AUC: 98.85 Precision: 99.53 Recall: 98.13
#
# -----Validation-----
# AUC: 76.52 Precision: 82.35 Recall: 66.67
#
# wheezy-copper-turtle-magic 14
#
# Fold 1
#
# -----Train----------
# AUC: 99.30 Precision: 99.51 Recall: 99.03
#
# -----Validation-----
# AUC: 74.70 Precision: 81.25 Recall: 61.90
#
# Fold 2
#
# -----Train----------
# AUC: 99.03 Precision: 100.00 Recall: 98.07
#
# -----Validation-----
# AUC: 55.95 Precision: 60.00 Recall: 28.57
#
# Fold 3
#
# -----Train----------
# AUC: 99.06 Precision: 99.51 Recall: 98.55
#
# -----Validation-----
# AUC: 65.48 Precision: 71.43 Recall: 47.62
#
# Fold 4
#
# -----Train----------
# AUC: 98.55 Precision: 100.00 Recall: 97.10
#
# -----Validation-----
# AUC: 75.30 Precision: 75.00 Recall: 71.43
#
# Fold 5
#
# -----Train----------
# AUC: 99.28 Precision: 100.00 Recall: 98.55
#
# -----Validation-----
# AUC: 78.57 Precision: 100.00 Recall: 57.14
#
# Fold 6
#
# -----Train----------
# AUC: 98.58 Precision: 99.51 Recall: 97.58
#
# -----Validation-----
# AUC: 72.26 Precision: 76.47 Recall: 61.90
#
# Fold 7
#
# -----Train----------
# AUC: 99.03 Precision: 100.00 Recall: 98.07
#
# -----Validation-----
# AUC: 62.53 Precision: 72.73 Recall: 38.10
#
# Fold 8
#
# -----Train----------
# AUC: 98.34 Precision: 99.50 Recall: 97.10
#
# -----Validation-----
# AUC: 71.64 Precision: 90.91 Recall: 47.62
#
# Fold 9
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 72.28 Precision: 68.18 Recall: 75.00
#
# Fold 10
#
# -----Train----------
# AUC: 99.31 Precision: 99.52 Recall: 99.04
#
# -----Validation-----
# AUC: 59.78 Precision: 58.82 Recall: 50.00
#
# Fold 11
#
# -----Train----------
# AUC: 99.28 Precision: 100.00 Recall: 98.56
#
# -----Validation-----
# AUC: 61.96 Precision: 62.50 Recall: 50.00
#
# wheezy-copper-turtle-magic 15
#
# Fold 1
#
# -----Train----------
# AUC: 98.30 Precision: 99.14 Recall: 97.47
#
# -----Validation-----
# AUC: 75.00 Precision: 80.00 Recall: 66.67
#
# Fold 2
#
# -----Train----------
# AUC: 98.31 Precision: 100.00 Recall: 96.62
#
# -----Validation-----
# AUC: 54.17 Precision: 55.56 Recall: 41.67
#
# Fold 3
#
# -----Train----------
# AUC: 98.73 Precision: 100.00 Recall: 97.47
#
# -----Validation-----
# AUC: 76.63 Precision: 78.26 Recall: 75.00
#
# Fold 4
#
# -----Train----------
# AUC: 98.73 Precision: 99.57 Recall: 97.89
#
# -----Validation-----
# AUC: 66.21 Precision: 72.22 Recall: 54.17
#
# Fold 5
#
# -----Train----------
# AUC: 98.95 Precision: 100.00 Recall: 97.89
#
# -----Validation-----
# AUC: 70.29 Precision: 72.73 Recall: 66.67
#
# Fold 6
#
# -----Train----------
# AUC: 98.52 Precision: 100.00 Recall: 97.05
#
# -----Validation-----
# AUC: 61.68 Precision: 62.50 Recall: 62.50
#
# Fold 7
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 70.29 Precision: 72.73 Recall: 66.67
#
# Fold 8
#
# -----Train----------
# AUC: 99.16 Precision: 100.00 Recall: 98.31
#
# -----Validation-----
# AUC: 78.89 Precision: 85.00 Recall: 70.83
#
# Fold 9
#
# -----Train----------
# AUC: 99.15 Precision: 99.58 Recall: 98.74
#
# -----Validation-----
# AUC: 67.39 Precision: 68.18 Recall: 65.22
#
# Fold 10
#
# -----Train----------
# AUC: 99.57 Precision: 99.58 Recall: 99.58
#
# -----Validation-----
# AUC: 58.70 Precision: 61.11 Recall: 47.83
#
# Fold 11
#
# -----Train----------
# AUC: 99.57 Precision: 99.58 Recall: 99.58
#
# -----Validation-----
# AUC: 50.00 Precision: 50.00 Recall: 43.48
#
# wheezy-copper-turtle-magic 16
#
# Fold 1
#
# -----Train----------
# AUC: 99.78 Precision: 100.00 Recall: 99.56
#
# -----Validation-----
# AUC: 72.43 Precision: 77.78 Recall: 60.87
#
# Fold 2
#
# -----Train----------
# AUC: 99.35 Precision: 99.56 Recall: 99.12
#
# -----Validation-----
# AUC: 66.26 Precision: 68.42 Recall: 56.52
#
# Fold 3
#
# -----Train----------
# AUC: 99.78 Precision: 100.00 Recall: 99.56
#
# -----Validation-----
# AUC: 63.59 Precision: 66.67 Recall: 52.17
#
# Fold 4
#
# -----Train----------
# AUC: 98.90 Precision: 100.00 Recall: 97.81
#
# -----Validation-----
# AUC: 78.71 Precision: 78.26 Recall: 78.26
#
# Fold 5
#
# -----Train----------
# AUC: 99.14 Precision: 99.56 Recall: 98.68
#
# -----Validation-----
# AUC: 67.84 Precision: 72.22 Recall: 56.52
#
# Fold 6
#
# -----Train----------
# AUC: 99.14 Precision: 99.56 Recall: 98.68
#
# -----Validation-----
# AUC: 67.93 Precision: 70.00 Recall: 60.87
#
# Fold 7
#
# -----Train----------
# AUC: 99.12 Precision: 100.00 Recall: 98.25
#
# -----Validation-----
# AUC: 69.75 Precision: 84.62 Recall: 47.83
#
# Fold 8
#
# -----Train----------
# AUC: 98.72 Precision: 98.68 Recall: 98.68
#
# -----Validation-----
# AUC: 59.33 Precision: 61.11 Recall: 47.83
#
# Fold 9
#
# -----Train----------
# AUC: 98.48 Precision: 99.55 Recall: 97.37
#
# -----Validation-----
# AUC: 80.53 Precision: 93.75 Recall: 65.22
#
# Fold 10
#
# -----Train----------
# AUC: 99.36 Precision: 99.56 Recall: 99.13
#
# -----Validation-----
# AUC: 62.12 Precision: 69.23 Recall: 40.91
#
# Fold 11
#
# -----Train----------
# AUC: 99.34 Precision: 100.00 Recall: 98.69
#
# -----Validation-----
# AUC: 66.67 Precision: 73.33 Recall: 50.00
#
# wheezy-copper-turtle-magic 17
#
# Fold 1
#
# -----Train----------
# AUC: 99.16 Precision: 100.00 Recall: 98.32
#
# -----Validation-----
# AUC: 57.52 Precision: 59.09 Recall: 54.17
#
# Fold 2
#
# -----Train----------
# AUC: 99.14 Precision: 99.16 Recall: 99.16
#
# -----Validation-----
# AUC: 66.12 Precision: 70.00 Recall: 58.33
#
# Fold 3
#
# -----Train----------
# AUC: 98.93 Precision: 99.16 Recall: 98.74
#
# -----Validation-----
# AUC: 63.95 Precision: 66.67 Recall: 58.33
#
# Fold 4
#
# -----Train----------
# AUC: 98.31 Precision: 99.57 Recall: 97.06
#
# -----Validation-----
# AUC: 61.96 Precision: 66.67 Recall: 50.00
#
# Fold 5
#
# -----Train----------
# AUC: 98.74 Precision: 100.00 Recall: 97.48
#
# -----Validation-----
# AUC: 74.64 Precision: 80.00 Recall: 66.67
#
# Fold 6
#
# -----Train----------
# AUC: 99.15 Precision: 99.58 Recall: 98.74
#
# -----Validation-----
# AUC: 68.21 Precision: 71.43 Recall: 62.50
#
# Fold 7
#
# -----Train----------
# AUC: 98.95 Precision: 100.00 Recall: 97.90
#
# -----Validation-----
# AUC: 64.13 Precision: 70.59 Recall: 50.00
#
# Fold 8
#
# -----Train----------
# AUC: 99.37 Precision: 100.00 Recall: 98.74
#
# -----Validation-----
# AUC: 56.25 Precision: 57.69 Recall: 62.50
#
# Fold 9
#
# -----Train----------
# AUC: 98.73 Precision: 99.57 Recall: 97.90
#
# -----Validation-----
# AUC: 58.90 Precision: 61.90 Recall: 54.17
#
# Fold 10
#
# -----Train----------
# AUC: 99.78 Precision: 99.58 Recall: 100.00
#
# -----Validation-----
# AUC: 73.42 Precision: 76.19 Recall: 69.57
#
# Fold 11
#
# -----Train----------
# AUC: 99.58 Precision: 100.00 Recall: 99.16
#
# -----Validation-----
# AUC: 64.62 Precision: 68.42 Recall: 56.52
#
# wheezy-copper-turtle-magic 18
#
# Fold 1
#
# -----Train----------
# AUC: 98.93 Precision: 98.76 Recall: 99.17
#
# -----Validation-----
# AUC: 81.65 Precision: 90.00 Recall: 72.00
#
# Fold 2
#
# -----Train----------
# AUC: 98.94 Precision: 99.17 Recall: 98.76
#
# -----Validation-----
# AUC: 68.21 Precision: 71.43 Recall: 62.50
#
# Fold 3
#
# -----Train----------
# AUC: 99.38 Precision: 100.00 Recall: 98.76
#
# -----Validation-----
# AUC: 72.55 Precision: 78.95 Recall: 62.50
#
# Fold 4
#
# -----Train----------
# AUC: 99.38 Precision: 100.00 Recall: 98.76
#
# -----Validation-----
# AUC: 80.98 Precision: 85.71 Recall: 75.00
#
# Fold 5
#
# -----Train----------
# AUC: 99.79 Precision: 100.00 Recall: 99.59
#
# -----Validation-----
# AUC: 57.25 Precision: 57.14 Recall: 66.67
#
# Fold 6
#
# -----Train----------
# AUC: 99.17 Precision: 100.00 Recall: 98.34
#
# -----Validation-----
# AUC: 59.87 Precision: 64.71 Recall: 45.83
#
# Fold 7
#
# -----Train----------
# AUC: 99.38 Precision: 100.00 Recall: 98.76
#
# -----Validation-----
# AUC: 72.46 Precision: 76.19 Recall: 66.67
#
# Fold 8
#
# -----Train----------
# AUC: 98.95 Precision: 99.58 Recall: 98.34
#
# -----Validation-----
# AUC: 68.39 Precision: 76.47 Recall: 54.17
#
# Fold 9
#
# -----Train----------
# AUC: 99.58 Precision: 99.59 Recall: 99.59
#
# -----Validation-----
# AUC: 76.81 Precision: 84.21 Recall: 66.67
#
# Fold 10
#
# -----Train----------
# AUC: 99.38 Precision: 100.00 Recall: 98.76
#
# -----Validation-----
# AUC: 68.30 Precision: 73.68 Recall: 58.33
#
# Fold 11
#
# -----Train----------
# AUC: 98.13 Precision: 100.00 Recall: 96.27
#
# -----Validation-----
# AUC: 61.87 Precision: 65.00 Recall: 54.17
#
# wheezy-copper-turtle-magic 19
#
# Fold 1
#
# -----Train----------
# AUC: 98.33 Precision: 99.57 Recall: 97.08
#
# -----Validation-----
# AUC: 65.58 Precision: 72.22 Recall: 52.00
#
# Fold 2
#
# -----Train----------
# AUC: 99.59 Precision: 100.00 Recall: 99.17
#
# -----Validation-----
# AUC: 75.00 Precision: 83.33 Recall: 62.50
#
# Fold 3
#
# -----Train----------
# AUC: 99.17 Precision: 99.58 Recall: 98.76
#
# -----Validation-----
# AUC: 72.92 Precision: 78.95 Recall: 62.50
#
# Fold 4
#
# -----Train----------
# AUC: 99.58 Precision: 99.59 Recall: 99.59
#
# -----Validation-----
# AUC: 47.92 Precision: 48.15 Recall: 54.17
#
# Fold 5
#
# -----Train----------
# AUC: 98.34 Precision: 99.57 Recall: 97.10
#
# -----Validation-----
# AUC: 68.75 Precision: 69.57 Recall: 66.67
#
# Fold 6
#
# -----Train----------
# AUC: 99.59 Precision: 100.00 Recall: 99.17
#
# -----Validation-----
# AUC: 70.83 Precision: 75.00 Recall: 62.50
#
# Fold 7
#
# -----Train----------
# AUC: 99.59 Precision: 100.00 Recall: 99.17
#
# -----Validation-----
# AUC: 58.33 Precision: 62.50 Recall: 41.67
#
# Fold 8
#
# -----Train----------
# AUC: 99.59 Precision: 100.00 Recall: 99.17
#
# -----Validation-----
# AUC: 58.33 Precision: 59.09 Recall: 54.17
#
# Fold 9
#
# -----Train----------
# AUC: 99.38 Precision: 100.00 Recall: 98.76
#
# -----Validation-----
# AUC: 66.12 Precision: 70.00 Recall: 58.33
#
# Fold 10
#
# -----Train----------
# AUC: 99.59 Precision: 100.00 Recall: 99.17
#
# -----Validation-----
# AUC: 66.30 Precision: 75.00 Recall: 50.00
#
# Fold 11
#
# -----Train----------
# AUC: 98.34 Precision: 99.57 Recall: 97.10
#
# -----Validation-----
# AUC: 74.73 Precision: 83.33 Recall: 62.50
#
# wheezy-copper-turtle-magic 20
#
# Fold 1
#
# -----Train----------
# AUC: 99.34 Precision: 99.55 Recall: 99.10
#
# -----Validation-----
# AUC: 70.43 Precision: 73.68 Recall: 60.87
#
# Fold 2
#
# -----Train----------
# AUC: 99.55 Precision: 100.00 Recall: 99.10
#
# -----Validation-----
# AUC: 78.96 Precision: 80.95 Recall: 73.91
#
# Fold 3
#
# -----Train----------
# AUC: 98.69 Precision: 99.10 Recall: 98.21
#
# -----Validation-----
# AUC: 65.49 Precision: 76.92 Recall: 43.48
#
# Fold 4
#
# -----Train----------
# AUC: 98.88 Precision: 100.00 Recall: 97.76
#
# -----Validation-----
# AUC: 68.03 Precision: 68.18 Recall: 65.22
#
# Fold 5
#
# -----Train----------
# AUC: 98.88 Precision: 100.00 Recall: 97.77
#
# -----Validation-----
# AUC: 69.32 Precision: 70.00 Recall: 63.64
#
# Fold 6
#
# -----Train----------
# AUC: 99.11 Precision: 100.00 Recall: 98.21
#
# -----Validation-----
# AUC: 68.56 Precision: 83.33 Recall: 45.45
#
# Fold 7
#
# -----Train----------
# AUC: 99.11 Precision: 100.00 Recall: 98.21
#
# -----Validation-----
# AUC: 56.44 Precision: 54.55 Recall: 54.55
#
# Fold 8
#
# -----Train----------
# AUC: 99.14 Precision: 99.11 Recall: 99.11
#
# -----Validation-----
# AUC: 75.76 Precision: 78.95 Recall: 68.18
#
# Fold 9
#
# -----Train----------
# AUC: 99.11 Precision: 100.00 Recall: 98.21
#
# -----Validation-----
# AUC: 65.15 Precision: 63.64 Recall: 63.64
#
# Fold 10
#
# -----Train----------
# AUC: 99.59 Precision: 99.12 Recall: 100.00
#
# -----Validation-----
# AUC: 67.05 Precision: 68.42 Recall: 59.09
#
# Fold 11
#
# -----Train----------
# AUC: 99.55 Precision: 100.00 Recall: 99.11
#
# -----Validation-----
# AUC: 64.58 Precision: 68.75 Recall: 50.00
#
# wheezy-copper-turtle-magic 21
#
# Fold 1
#
# -----Train----------
# AUC: 98.77 Precision: 99.59 Recall: 97.96
#
# -----Validation-----
# AUC: 75.50 Precision: 76.00 Recall: 76.00
#
# Fold 2
#
# -----Train----------
# AUC: 99.18 Precision: 100.00 Recall: 98.37
#
# -----Validation-----
# AUC: 59.75 Precision: 72.73 Recall: 32.00
#
# Fold 3
#
# -----Train----------
# AUC: 98.16 Precision: 100.00 Recall: 96.33
#
# -----Validation-----
# AUC: 69.50 Precision: 72.73 Recall: 64.00
#
# Fold 4
#
# -----Train----------
# AUC: 98.98 Precision: 100.00 Recall: 97.96
#
# -----Validation-----
# AUC: 65.42 Precision: 68.18 Recall: 60.00
#
# Fold 5
#
# -----Train----------
# AUC: 98.97 Precision: 99.59 Recall: 98.37
#
# -----Validation-----
# AUC: 65.42 Precision: 68.18 Recall: 60.00
#
# Fold 6
#
# -----Train----------
# AUC: 99.39 Precision: 100.00 Recall: 98.78
#
# -----Validation-----
# AUC: 63.33 Precision: 65.22 Recall: 60.00
#
# Fold 7
#
# -----Train----------
# AUC: 99.59 Precision: 100.00 Recall: 99.19
#
# -----Validation-----
# AUC: 66.67 Precision: 66.67 Recall: 66.67
#
# Fold 8
#
# -----Train----------
# AUC: 98.97 Precision: 99.18 Recall: 98.78
#
# -----Validation-----
# AUC: 72.92 Precision: 76.19 Recall: 66.67
#
# Fold 9
#
# -----Train----------
# AUC: 99.59 Precision: 100.00 Recall: 99.19
#
# -----Validation-----
# AUC: 64.58 Precision: 66.67 Recall: 58.33
#
# Fold 10
#
# -----Train----------
# AUC: 98.98 Precision: 99.59 Recall: 98.37
#
# -----Validation-----
# AUC: 57.52 Precision: 59.09 Recall: 54.17
#
# Fold 11
#
# -----Train----------
# AUC: 99.19 Precision: 100.00 Recall: 98.37
#
# -----Validation-----
# AUC: 70.38 Precision: 75.00 Recall: 62.50
#
# wheezy-copper-turtle-magic 22
#
# Fold 1
#
# -----Train----------
# AUC: 99.19 Precision: 99.60 Recall: 98.80
#
# -----Validation-----
# AUC: 68.43 Precision: 75.00 Recall: 57.69
#
# Fold 2
#
# -----Train----------
# AUC: 99.60 Precision: 100.00 Recall: 99.20
#
# -----Validation-----
# AUC: 64.10 Precision: 66.67 Recall: 61.54
#
# Fold 3
#
# -----Train----------
# AUC: 99.21 Precision: 100.00 Recall: 98.41
#
# -----Validation-----
# AUC: 59.42 Precision: 63.16 Recall: 48.00
#
# Fold 4
#
# -----Train----------
# AUC: 98.78 Precision: 99.20 Recall: 98.41
#
# -----Validation-----
# AUC: 67.58 Precision: 73.68 Recall: 56.00
#
# Fold 5
#
# -----Train----------
# AUC: 98.80 Precision: 99.60 Recall: 98.02
#
# -----Validation-----
# AUC: 67.58 Precision: 73.68 Recall: 56.00
#
# Fold 6
#
# -----Train----------
# AUC: 98.80 Precision: 99.60 Recall: 98.02
#
# -----Validation-----
# AUC: 73.67 Precision: 80.00 Recall: 64.00
#
# Fold 7
#
# -----Train----------
# AUC: 98.81 Precision: 100.00 Recall: 97.62
#
# -----Validation-----
# AUC: 69.33 Precision: 69.23 Recall: 72.00
#
# Fold 8
#
# -----Train----------
# AUC: 98.80 Precision: 99.60 Recall: 98.02
#
# -----Validation-----
# AUC: 71.13 Precision: 76.19 Recall: 64.00
#
# Fold 9
#
# -----Train----------
# AUC: 98.60 Precision: 99.60 Recall: 97.62
#
# -----Validation-----
# AUC: 62.26 Precision: 62.96 Recall: 68.00
#
# Fold 10
#
# -----Train----------
# AUC: 99.39 Precision: 99.60 Recall: 99.21
#
# -----Validation-----
# AUC: 77.48 Precision: 85.00 Recall: 68.00
#
# Fold 11
#
# -----Train----------
# AUC: 98.60 Precision: 99.60 Recall: 97.62
#
# -----Validation-----
# AUC: 64.78 Precision: 68.18 Recall: 60.00
#
# wheezy-copper-turtle-magic 23
#
# Fold 1
#
# -----Train----------
# AUC: 99.15 Precision: 99.17 Recall: 99.17
#
# -----Validation-----
# AUC: 75.58 Precision: 78.26 Recall: 72.00
#
# Fold 2
#
# -----Train----------
# AUC: 98.96 Precision: 100.00 Recall: 97.93
#
# -----Validation-----
# AUC: 63.25 Precision: 64.00 Recall: 64.00
#
# Fold 3
#
# -----Train----------
# AUC: 98.95 Precision: 99.17 Recall: 98.76
#
# -----Validation-----
# AUC: 62.50 Precision: 62.50 Recall: 62.50
#
# Fold 4
#
# -----Train----------
# AUC: 98.74 Precision: 99.17 Recall: 98.35
#
# -----Validation-----
# AUC: 55.71 Precision: 60.00 Recall: 37.50
#
# Fold 5
#
# -----Train----------
# AUC: 99.58 Precision: 99.59 Recall: 99.59
#
# -----Validation-----
# AUC: 57.70 Precision: 61.11 Recall: 45.83
#
# Fold 6
#
# -----Train----------
# AUC: 98.54 Precision: 99.16 Recall: 97.93
#
# -----Validation-----
# AUC: 59.69 Precision: 61.90 Recall: 54.17
#
# Fold 7
#
# -----Train----------
# AUC: 99.79 Precision: 100.00 Recall: 99.59
#
# -----Validation-----
# AUC: 68.30 Precision: 73.68 Recall: 58.33
#
# Fold 8
#
# -----Train----------
# AUC: 98.55 Precision: 100.00 Recall: 97.11
#
# -----Validation-----
# AUC: 66.03 Precision: 68.18 Recall: 62.50
#
# Fold 9
#
# -----Train----------
# AUC: 98.33 Precision: 99.16 Recall: 97.52
#
# -----Validation-----
# AUC: 68.03 Precision: 68.00 Recall: 70.83
#
# Fold 10
#
# -----Train----------
# AUC: 99.16 Precision: 99.17 Recall: 99.17
#
# -----Validation-----
# AUC: 59.78 Precision: 63.16 Recall: 50.00
#
# Fold 11
#
# -----Train----------
# AUC: 99.38 Precision: 100.00 Recall: 98.76
#
# -----Validation-----
# AUC: 62.23 Precision: 75.00 Recall: 37.50
#
# wheezy-copper-turtle-magic 24
#
# Fold 1
#
# -----Train----------
# AUC: 99.05 Precision: 100.00 Recall: 98.10
#
# -----Validation-----
# AUC: 84.47 Precision: 89.47 Recall: 77.27
#
# Fold 2
#
# -----Train----------
# AUC: 98.84 Precision: 99.52 Recall: 98.10
#
# -----Validation-----
# AUC: 64.77 Precision: 66.67 Recall: 54.55
#
# Fold 3
#
# -----Train----------
# AUC: 98.58 Precision: 100.00 Recall: 97.17
#
# -----Validation-----
# AUC: 72.92 Precision: 73.68 Recall: 66.67
#
# Fold 4
#
# -----Train----------
# AUC: 98.85 Precision: 99.52 Recall: 98.11
#
# -----Validation-----
# AUC: 74.70 Precision: 81.25 Recall: 61.90
#
# Fold 5
#
# -----Train----------
# AUC: 98.82 Precision: 100.00 Recall: 97.64
#
# -----Validation-----
# AUC: 68.45 Precision: 68.42 Recall: 61.90
#
# Fold 6
#
# -----Train----------
# AUC: 98.58 Precision: 100.00 Recall: 97.17
#
# -----Validation-----
# AUC: 70.24 Precision: 75.00 Recall: 57.14
#
# Fold 7
#
# -----Train----------
# AUC: 99.29 Precision: 100.00 Recall: 98.58
#
# -----Validation-----
# AUC: 62.80 Precision: 72.73 Recall: 38.10
#
# Fold 8
#
# -----Train----------
# AUC: 99.79 Precision: 99.53 Recall: 100.00
#
# -----Validation-----
# AUC: 77.68 Precision: 76.19 Recall: 76.19
#
# Fold 9
#
# -----Train----------
# AUC: 99.53 Precision: 100.00 Recall: 99.06
#
# -----Validation-----
# AUC: 79.76 Precision: 80.00 Recall: 76.19
#
# Fold 10
#
# -----Train----------
# AUC: 99.06 Precision: 100.00 Recall: 98.11
#
# -----Validation-----
# AUC: 69.46 Precision: 83.33 Recall: 47.62
#
# Fold 11
#
# -----Train----------
# AUC: 99.29 Precision: 100.00 Recall: 98.58
#
# -----Validation-----
# AUC: 65.53 Precision: 66.67 Recall: 57.14
#
# wheezy-copper-turtle-magic 25
#
# Fold 1
#
# -----Train----------
# AUC: 98.84 Precision: 99.52 Recall: 98.10
#
# -----Validation-----
# AUC: 68.75 Precision: 78.57 Recall: 50.00
#
# Fold 2
#
# -----Train----------
# AUC: 98.58 Precision: 100.00 Recall: 97.16
#
# -----Validation-----
# AUC: 57.77 Precision: 61.54 Recall: 36.36
#
# Fold 3
#
# -----Train----------
# AUC: 99.06 Precision: 100.00 Recall: 98.11
#
# -----Validation-----
# AUC: 47.92 Precision: 43.75 Recall: 33.33
#
# Fold 4
#
# -----Train----------
# AUC: 99.06 Precision: 100.00 Recall: 98.11
#
# -----Validation-----
# AUC: 63.69 Precision: 64.71 Recall: 52.38
#
# Fold 5
#
# -----Train----------
# AUC: 98.87 Precision: 99.05 Recall: 98.58
#
# -----Validation-----
# AUC: 63.99 Precision: 63.16 Recall: 57.14
#
# Fold 6
#
# -----Train----------
# AUC: 98.58 Precision: 100.00 Recall: 97.17
#
# -----Validation-----
# AUC: 68.32 Precision: 65.22 Recall: 71.43
#
# Fold 7
#
# -----Train----------
# AUC: 98.61 Precision: 99.52 Recall: 97.64
#
# -----Validation-----
# AUC: 67.70 Precision: 70.59 Recall: 57.14
#
# Fold 8
#
# -----Train----------
# AUC: 98.82 Precision: 100.00 Recall: 97.64
#
# -----Validation-----
# AUC: 79.40 Precision: 80.00 Recall: 76.19
#
# Fold 9
#
# -----Train----------
# AUC: 98.63 Precision: 99.05 Recall: 98.11
#
# -----Validation-----
# AUC: 69.67 Precision: 78.57 Recall: 52.38
#
# Fold 10
#
# -----Train----------
# AUC: 98.61 Precision: 99.52 Recall: 97.64
#
# -----Validation-----
# AUC: 49.07 Precision: 46.15 Recall: 28.57
#
# Fold 11
#
# -----Train----------
# AUC: 99.29 Precision: 100.00 Recall: 98.58
#
# -----Validation-----
# AUC: 77.02 Precision: 78.95 Recall: 71.43
#
# wheezy-copper-turtle-magic 26
#
# Fold 1
#
# -----Train----------
# AUC: 98.38 Precision: 99.52 Recall: 97.20
#
# -----Validation-----
# AUC: 57.21 Precision: 63.64 Recall: 31.82
#
# Fold 2
#
# -----Train----------
# AUC: 98.38 Precision: 99.52 Recall: 97.20
#
# -----Validation-----
# AUC: 77.67 Precision: 80.00 Recall: 72.73
#
# Fold 3
#
# -----Train----------
# AUC: 98.13 Precision: 100.00 Recall: 96.26
#
# -----Validation-----
# AUC: 68.58 Precision: 75.00 Recall: 54.55
#
# Fold 4
#
# -----Train----------
# AUC: 97.91 Precision: 99.52 Recall: 96.26
#
# -----Validation-----
# AUC: 61.86 Precision: 66.67 Recall: 45.45
#
# Fold 5
#
# -----Train----------
# AUC: 98.61 Precision: 99.52 Recall: 97.66
#
# -----Validation-----
# AUC: 79.84 Precision: 84.21 Recall: 72.73
#
# Fold 6
#
# -----Train----------
# AUC: 98.84 Precision: 100.00 Recall: 97.67
#
# -----Validation-----
# AUC: 60.35 Precision: 66.67 Recall: 38.10
#
# Fold 7
#
# -----Train----------
# AUC: 99.30 Precision: 100.00 Recall: 98.60
#
# -----Validation-----
# AUC: 62.94 Precision: 66.67 Recall: 47.62
#
# Fold 8
#
# -----Train----------
# AUC: 98.84 Precision: 100.00 Recall: 97.67
#
# -----Validation-----
# AUC: 68.12 Precision: 66.67 Recall: 66.67
#
# Fold 9
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 64.91 Precision: 75.00 Recall: 42.86
#
# Fold 10
#
# -----Train----------
# AUC: 98.37 Precision: 100.00 Recall: 96.74
#
# -----Validation-----
# AUC: 67.70 Precision: 70.59 Recall: 57.14
#
# Fold 11
#
# -----Train----------
# AUC: 99.30 Precision: 100.00 Recall: 98.60
#
# -----Validation-----
# AUC: 51.86 Precision: 50.00 Recall: 42.86
#
# wheezy-copper-turtle-magic 27
#
# Fold 1
#
# -----Train----------
# AUC: 98.15 Precision: 100.00 Recall: 96.30
#
# -----Validation-----
# AUC: 73.27 Precision: 85.71 Recall: 54.55
#
# Fold 2
#
# -----Train----------
# AUC: 98.38 Precision: 100.00 Recall: 96.76
#
# -----Validation-----
# AUC: 58.73 Precision: 58.82 Recall: 45.45
#
# Fold 3
#
# -----Train----------
# AUC: 98.84 Precision: 100.00 Recall: 97.69
#
# -----Validation-----
# AUC: 69.13 Precision: 72.22 Recall: 59.09
#
# Fold 4
#
# -----Train----------
# AUC: 98.61 Precision: 100.00 Recall: 97.22
#
# -----Validation-----
# AUC: 75.95 Precision: 76.19 Recall: 72.73
#
# Fold 5
#
# -----Train----------
# AUC: 99.31 Precision: 100.00 Recall: 98.61
#
# -----Validation-----
# AUC: 73.30 Precision: 81.25 Recall: 59.09
#
# Fold 6
#
# -----Train----------
# AUC: 98.15 Precision: 100.00 Recall: 96.30
#
# -----Validation-----
# AUC: 56.06 Precision: 55.56 Recall: 45.45
#
# Fold 7
#
# -----Train----------
# AUC: 98.66 Precision: 99.07 Recall: 98.15
#
# -----Validation-----
# AUC: 73.48 Precision: 77.78 Recall: 63.64
#
# Fold 8
#
# -----Train----------
# AUC: 99.31 Precision: 100.00 Recall: 98.62
#
# -----Validation-----
# AUC: 70.83 Precision: 70.00 Recall: 66.67
#
# Fold 9
#
# -----Train----------
# AUC: 99.31 Precision: 100.00 Recall: 98.62
#
# -----Validation-----
# AUC: 65.77 Precision: 68.75 Recall: 52.38
#
# Fold 10
#
# -----Train----------
# AUC: 98.20 Precision: 99.06 Recall: 97.24
#
# -----Validation-----
# AUC: 72.92 Precision: 73.68 Recall: 66.67
#
# Fold 11
#
# -----Train----------
# AUC: 98.41 Precision: 99.53 Recall: 97.24
#
# -----Validation-----
# AUC: 72.92 Precision: 73.68 Recall: 66.67
#
# wheezy-copper-turtle-magic 28
#
# Fold 1
#
# -----Train----------
# AUC: 97.95 Precision: 98.35 Recall: 97.54
#
# -----Validation-----
# AUC: 60.00 Precision: 63.16 Recall: 48.00
#
# Fold 2
#
# -----Train----------
# AUC: 99.59 Precision: 99.59 Recall: 99.59
#
# -----Validation-----
# AUC: 58.00 Precision: 60.00 Recall: 48.00
#
# Fold 3
#
# -----Train----------
# AUC: 98.56 Precision: 99.17 Recall: 97.95
#
# -----Validation-----
# AUC: 58.00 Precision: 58.33 Recall: 56.00
#
# Fold 4
#
# -----Train----------
# AUC: 99.79 Precision: 99.59 Recall: 100.00
#
# -----Validation-----
# AUC: 58.00 Precision: 60.00 Recall: 48.00
#
# Fold 5
#
# -----Train----------
# AUC: 98.36 Precision: 98.36 Recall: 98.36
#
# -----Validation-----
# AUC: 73.58 Precision: 77.27 Recall: 68.00
#
# Fold 6
#
# -----Train----------
# AUC: 98.98 Precision: 100.00 Recall: 97.96
#
# -----Validation-----
# AUC: 62.50 Precision: 66.67 Recall: 50.00
#
# Fold 7
#
# -----Train----------
# AUC: 98.37 Precision: 99.17 Recall: 97.55
#
# -----Validation-----
# AUC: 56.25 Precision: 60.00 Recall: 37.50
#
# Fold 8
#
# -----Train----------
# AUC: 98.98 Precision: 100.00 Recall: 97.96
#
# -----Validation-----
# AUC: 56.25 Precision: 60.00 Recall: 37.50
#
# Fold 9
#
# -----Train----------
# AUC: 99.18 Precision: 100.00 Recall: 98.37
#
# -----Validation-----
# AUC: 66.67 Precision: 68.18 Recall: 62.50
#
# Fold 10
#
# -----Train----------
# AUC: 98.37 Precision: 99.58 Recall: 97.14
#
# -----Validation-----
# AUC: 66.67 Precision: 68.18 Recall: 62.50
#
# Fold 11
#
# -----Train----------
# AUC: 97.75 Precision: 99.16 Recall: 96.33
#
# -----Validation-----
# AUC: 54.17 Precision: 53.85 Recall: 58.33
#
# wheezy-copper-turtle-magic 29
#
# Fold 1
#
# -----Train----------
# AUC: 99.12 Precision: 99.56 Recall: 98.68
#
# -----Validation-----
# AUC: 67.39 Precision: 78.57 Recall: 47.83
#
# Fold 2
#
# -----Train----------
# AUC: 99.34 Precision: 100.00 Recall: 98.68
#
# -----Validation-----
# AUC: 76.09 Precision: 83.33 Recall: 65.22
#
# Fold 3
#
# -----Train----------
# AUC: 99.56 Precision: 99.56 Recall: 99.56
#
# -----Validation-----
# AUC: 67.39 Precision: 68.18 Recall: 65.22
#
# Fold 4
#
# -----Train----------
# AUC: 99.56 Precision: 100.00 Recall: 99.12
#
# -----Validation-----
# AUC: 58.70 Precision: 61.11 Recall: 47.83
#
# Fold 5
#
# -----Train----------
# AUC: 98.46 Precision: 100.00 Recall: 96.92
#
# -----Validation-----
# AUC: 63.04 Precision: 68.75 Recall: 47.83
#
# Fold 6
#
# -----Train----------
# AUC: 99.56 Precision: 100.00 Recall: 99.12
#
# -----Validation-----
# AUC: 76.09 Precision: 77.27 Recall: 73.91
#
# Fold 7
#
# -----Train----------
# AUC: 98.90 Precision: 99.55 Recall: 98.24
#
# -----Validation-----
# AUC: 64.53 Precision: 66.67 Recall: 60.87
#
# Fold 8
#
# -----Train----------
# AUC: 99.12 Precision: 100.00 Recall: 98.24
#
# -----Validation-----
# AUC: 64.72 Precision: 70.59 Recall: 52.17
#
# Fold 9
#
# -----Train----------
# AUC: 99.56 Precision: 100.00 Recall: 99.12
#
# -----Validation-----
# AUC: 59.09 Precision: 59.09 Recall: 59.09
#
# Fold 10
#
# -----Train----------
# AUC: 98.90 Precision: 99.12 Recall: 98.68
#
# -----Validation-----
# AUC: 63.64 Precision: 68.75 Recall: 50.00
#
# Fold 11
#
# -----Train----------
# AUC: 99.12 Precision: 99.56 Recall: 98.68
#
# -----Validation-----
# AUC: 77.27 Precision: 87.50 Recall: 63.64
#
# wheezy-copper-turtle-magic 30
#
# Fold 1
#
# -----Train----------
# AUC: 98.92 Precision: 98.78 Recall: 99.18
#
# -----Validation-----
# AUC: 68.96 Precision: 72.73 Recall: 64.00
#
# Fold 2
#
# -----Train----------
# AUC: 99.16 Precision: 99.59 Recall: 98.77
#
# -----Validation-----
# AUC: 60.43 Precision: 62.50 Recall: 60.00
#
# Fold 3
#
# -----Train----------
# AUC: 98.98 Precision: 100.00 Recall: 97.95
#
# -----Validation-----
# AUC: 70.96 Precision: 73.91 Recall: 68.00
#
# Fold 4
#
# -----Train----------
# AUC: 99.80 Precision: 100.00 Recall: 99.59
#
# -----Validation-----
# AUC: 60.61 Precision: 63.64 Recall: 56.00
#
# Fold 5
#
# -----Train----------
# AUC: 99.39 Precision: 100.00 Recall: 98.77
#
# -----Validation-----
# AUC: 55.82 Precision: 60.00 Recall: 48.00
#
# Fold 6
#
# -----Train----------
# AUC: 99.78 Precision: 99.59 Recall: 100.00
#
# -----Validation-----
# AUC: 69.89 Precision: 75.00 Recall: 62.50
#
# Fold 7
#
# -----Train----------
# AUC: 98.55 Precision: 99.58 Recall: 97.55
#
# -----Validation-----
# AUC: 61.93 Precision: 75.00 Recall: 37.50
#
# Fold 8
#
# -----Train----------
# AUC: 99.18 Precision: 100.00 Recall: 98.37
#
# -----Validation-----
# AUC: 74.05 Precision: 77.27 Recall: 70.83
#
# Fold 9
#
# -----Train----------
# AUC: 99.37 Precision: 99.59 Recall: 99.18
#
# -----Validation-----
# AUC: 82.77 Precision: 86.36 Recall: 79.17
#
# ...
#
# -----Train----------
# AUC: 99.33 Precision: 99.58 Recall: 99.16
#
# -----Validation-----
# AUC: 59.84 Precision: 65.00 Recall: 56.52
#
# Fold 10
#
# -----Train----------
# AUC: 98.86 Precision: 99.15 Recall: 98.73
#
# -----Validation-----
# AUC: 68.19 Precision: 80.00 Recall: 52.17
#
# Fold 11
#
# -----Train----------
# AUC: 98.65 Precision: 99.15 Recall: 98.31
#
# -----Validation-----
# AUC: 52.40 Precision: 57.14 Recall: 52.17
#
# wheezy-copper-turtle-magic 502
#
# Fold 1
#
# -----Train----------
# AUC: 99.15 Precision: 99.57 Recall: 98.72
#
# -----Validation-----
# AUC: 48.67 Precision: 47.06 Recall: 33.33
#
# Fold 2
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 69.42 Precision: 68.00 Recall: 70.83
#
# Fold 3
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 70.83 Precision: 77.78 Recall: 58.33
#
# Fold 4
#
# -----Train----------
# AUC: 99.15 Precision: 99.57 Recall: 98.72
#
# -----Validation-----
# AUC: 64.58 Precision: 70.59 Recall: 50.00
#
# Fold 5
#
# -----Train----------
# AUC: 98.94 Precision: 99.57 Recall: 98.29
#
# -----Validation-----
# AUC: 75.00 Precision: 87.50 Recall: 58.33
#
# Fold 6
#
# -----Train----------
# AUC: 99.15 Precision: 100.00 Recall: 98.30
#
# -----Validation-----
# AUC: 74.28 Precision: 78.95 Recall: 65.22
#
# Fold 7
#
# -----Train----------
# AUC: 98.72 Precision: 100.00 Recall: 97.45
#
# -----Validation-----
# AUC: 65.85 Precision: 66.67 Recall: 60.87
#
# Fold 8
#
# -----Train----------
# AUC: 98.94 Precision: 99.57 Recall: 98.30
#
# -----Validation-----
# AUC: 74.18 Precision: 82.35 Recall: 60.87
#
# Fold 9
#
# -----Train----------
# AUC: 99.57 Precision: 100.00 Recall: 99.15
#
# -----Validation-----
# AUC: 52.81 Precision: 53.33 Recall: 34.78
#
# Fold 10
#
# -----Train----------
# AUC: 99.57 Precision: 100.00 Recall: 99.15
#
# -----Validation-----
# AUC: 61.96 Precision: 58.62 Recall: 73.91
#
# Fold 11
#
# -----Train----------
# AUC: 98.30 Precision: 100.00 Recall: 96.60
#
# -----Validation-----
# AUC: 65.76 Precision: 68.42 Recall: 56.52
#
# wheezy-copper-turtle-magic 503
#
# Fold 1
#
# -----Train----------
# AUC: 99.07 Precision: 100.00 Recall: 98.13
#
# -----Validation-----
# AUC: 73.02 Precision: 81.25 Recall: 59.09
#
# Fold 2
#
# -----Train----------
# AUC: 99.32 Precision: 99.07 Recall: 99.53
#
# -----Validation-----
# AUC: 59.88 Precision: 60.00 Recall: 54.55
#
# Fold 3
#
# -----Train----------
# AUC: 99.30 Precision: 100.00 Recall: 98.60
#
# -----Validation-----
# AUC: 66.50 Precision: 68.42 Recall: 59.09
#
# Fold 4
#
# -----Train----------
# AUC: 99.07 Precision: 100.00 Recall: 98.13
#
# -----Validation-----
# AUC: 71.25 Precision: 68.00 Recall: 77.27
#
# Fold 5
#
# -----Train----------
# AUC: 98.61 Precision: 99.52 Recall: 97.66
#
# -----Validation-----
# AUC: 70.75 Precision: 80.00 Recall: 54.55
#
# Fold 6
#
# -----Train----------
# AUC: 99.31 Precision: 99.53 Recall: 99.07
#
# -----Validation-----
# AUC: 74.64 Precision: 77.78 Recall: 66.67
#
# Fold 7
#
# -----Train----------
# AUC: 99.30 Precision: 100.00 Recall: 98.60
#
# -----Validation-----
# AUC: 64.83 Precision: 68.75 Recall: 52.38
#
# Fold 8
#
# -----Train----------
# AUC: 98.84 Precision: 100.00 Recall: 97.67
#
# -----Validation-----
# AUC: 76.73 Precision: 76.19 Recall: 76.19
#
# Fold 9
#
# -----Train----------
# AUC: 99.30 Precision: 100.00 Recall: 98.60
#
# -----Validation-----
# AUC: 67.10 Precision: 73.33 Recall: 52.38
#
# Fold 10
#
# -----Train----------
# AUC: 99.09 Precision: 99.07 Recall: 99.07
#
# -----Validation-----
# AUC: 62.77 Precision: 61.90 Recall: 61.90
#
# Fold 11
#
# -----Train----------
# AUC: 99.08 Precision: 99.53 Recall: 98.60
#
# -----Validation-----
# AUC: 69.26 Precision: 83.33 Recall: 47.62
#
# wheezy-copper-turtle-magic 504
#
# Fold 1
#
# -----Train----------
# AUC: 99.36 Precision: 100.00 Recall: 98.73
#
# -----Validation-----
# AUC: 81.07 Precision: 89.47 Recall: 70.83
#
# Fold 2
#
# -----Train----------
# AUC: 98.72 Precision: 99.57 Recall: 97.88
#
# -----Validation-----
# AUC: 68.48 Precision: 80.00 Recall: 50.00
#
# Fold 3
#
# -----Train----------
# AUC: 99.15 Precision: 100.00 Recall: 98.31
#
# -----Validation-----
# AUC: 74.73 Precision: 83.33 Recall: 62.50
#
# Fold 4
#
# -----Train----------
# AUC: 99.13 Precision: 99.15 Recall: 99.15
#
# -----Validation-----
# AUC: 69.89 Precision: 75.00 Recall: 62.50
#
# Fold 5
#
# -----Train----------
# AUC: 99.79 Precision: 100.00 Recall: 99.58
#
# -----Validation-----
# AUC: 80.87 Precision: 89.47 Recall: 70.83
#
# Fold 6
#
# -----Train----------
# AUC: 99.58 Precision: 100.00 Recall: 99.15
#
# -----Validation-----
# AUC: 67.80 Precision: 73.68 Recall: 58.33
#
# Fold 7
#
# -----Train----------
# AUC: 98.72 Precision: 99.57 Recall: 97.88
#
# -----Validation-----
# AUC: 76.52 Precision: 84.21 Recall: 66.67
#
# Fold 8
#
# -----Train----------
# AUC: 99.37 Precision: 100.00 Recall: 98.73
#
# -----Validation-----
# AUC: 64.33 Precision: 64.00 Recall: 69.57
#
# Fold 9
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 68.97 Precision: 71.43 Recall: 65.22
#
# Fold 10
#
# -----Train----------
# AUC: 99.37 Precision: 100.00 Recall: 98.73
#
# -----Validation-----
# AUC: 77.67 Precision: 76.00 Recall: 82.61
#
# Fold 11
#
# -----Train----------
# AUC: 99.37 Precision: 100.00 Recall: 98.73
#
# -----Validation-----
# AUC: 66.80 Precision: 70.00 Recall: 60.87
#
# wheezy-copper-turtle-magic 505
#
# Fold 1
#
# -----Train----------
# AUC: 98.50 Precision: 98.69 Recall: 98.26
#
# -----Validation-----
# AUC: 72.92 Precision: 73.91 Recall: 70.83
#
# Fold 2
#
# -----Train----------
# AUC: 99.57 Precision: 99.57 Recall: 99.57
#
# -----Validation-----
# AUC: 61.32 Precision: 66.67 Recall: 43.48
#
# Fold 3
#
# -----Train----------
# AUC: 99.36 Precision: 99.57 Recall: 99.13
#
# -----Validation-----
# AUC: 74.37 Precision: 76.19 Recall: 69.57
#
# Fold 4
#
# -----Train----------
# AUC: 98.70 Precision: 100.00 Recall: 97.40
#
# -----Validation-----
# AUC: 72.01 Precision: 81.25 Recall: 56.52
#
# Fold 5
#
# -----Train----------
# AUC: 99.14 Precision: 99.56 Recall: 98.70
#
# -----Validation-----
# AUC: 61.50 Precision: 63.16 Recall: 52.17
#
# Fold 6
#
# -----Train----------
# AUC: 98.49 Precision: 99.56 Recall: 97.40
#
# -----Validation-----
# AUC: 72.19 Precision: 75.00 Recall: 65.22
#
# Fold 7
#
# -----Train----------
# AUC: 99.13 Precision: 100.00 Recall: 98.27
#
# -----Validation-----
# AUC: 76.36 Precision: 83.33 Recall: 65.22
#
# Fold 8
#
# -----Train----------
# AUC: 99.35 Precision: 100.00 Recall: 98.70
#
# -----Validation-----
# AUC: 69.93 Precision: 76.47 Recall: 56.52
#
# Fold 9
#
# -----Train----------
# AUC: 98.92 Precision: 100.00 Recall: 97.84
#
# -----Validation-----
# AUC: 69.57 Precision: 68.00 Recall: 73.91
#
# Fold 10
#
# -----Train----------
# AUC: 98.50 Precision: 99.12 Recall: 97.84
#
# -----Validation-----
# AUC: 63.04 Precision: 66.67 Recall: 52.17
#
# Fold 11
#
# -----Train----------
# AUC: 99.57 Precision: 100.00 Recall: 99.13
#
# -----Validation-----
# AUC: 47.83 Precision: 47.37 Recall: 39.13
#
# wheezy-copper-turtle-magic 506
#
# Fold 1
#
# -----Train----------
# AUC: 99.59 Precision: 100.00 Recall: 99.17
#
# -----Validation-----
# AUC: 58.00 Precision: 60.00 Recall: 48.00
#
# Fold 2
#
# -----Train----------
# AUC: 99.17 Precision: 99.58 Recall: 98.76
#
# -----Validation-----
# AUC: 64.00 Precision: 68.42 Recall: 52.00
#
# Fold 3
#
# -----Train----------
# AUC: 99.38 Precision: 100.00 Recall: 98.76
#
# -----Validation-----
# AUC: 71.33 Precision: 72.73 Recall: 66.67
#
# Fold 4
#
# -----Train----------
# AUC: 98.76 Precision: 99.58 Recall: 97.93
#
# -----Validation-----
# AUC: 64.58 Precision: 70.59 Recall: 50.00
#
# Fold 5
#
# -----Train----------
# AUC: 98.14 Precision: 98.74 Recall: 97.52
#
# -----Validation-----
# AUC: 68.75 Precision: 68.00 Recall: 70.83
#
# Fold 6
#
# -----Train----------
# AUC: 98.97 Precision: 99.58 Recall: 98.35
#
# -----Validation-----
# AUC: 70.83 Precision: 70.83 Recall: 70.83
#
# Fold 7
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 66.67 Precision: 68.18 Recall: 62.50
#
# Fold 8
#
# -----Train----------
# AUC: 98.55 Precision: 100.00 Recall: 97.11
#
# -----Validation-----
# AUC: 77.08 Precision: 88.24 Recall: 62.50
#
# Fold 9
#
# -----Train----------
# AUC: 98.14 Precision: 99.16 Recall: 97.11
#
# -----Validation-----
# AUC: 62.50 Precision: 71.43 Recall: 41.67
#
# Fold 10
#
# -----Train----------
# AUC: 98.97 Precision: 100.00 Recall: 97.93
#
# -----Validation-----
# AUC: 60.42 Precision: 69.23 Recall: 37.50
#
# Fold 11
#
# -----Train----------
# AUC: 98.97 Precision: 100.00 Recall: 97.93
#
# -----Validation-----
# AUC: 72.92 Precision: 86.67 Recall: 54.17
#
# wheezy-copper-turtle-magic 507
#
# Fold 1
#
# -----Train----------
# AUC: 99.11 Precision: 100.00 Recall: 98.22
#
# -----Validation-----
# AUC: 84.96 Precision: 94.44 Recall: 73.91
#
# Fold 2
#
# -----Train----------
# AUC: 98.89 Precision: 100.00 Recall: 97.78
#
# -----Validation-----
# AUC: 74.61 Precision: 78.95 Recall: 65.22
#
# Fold 3
#
# -----Train----------
# AUC: 98.67 Precision: 100.00 Recall: 97.33
#
# -----Validation-----
# AUC: 70.26 Precision: 76.47 Recall: 56.52
#
# Fold 4
#
# -----Train----------
# AUC: 99.33 Precision: 100.00 Recall: 98.67
#
# -----Validation-----
# AUC: 61.91 Precision: 64.71 Recall: 47.83
#
# Fold 5
#
# -----Train----------
# AUC: 99.11 Precision: 100.00 Recall: 98.22
#
# -----Validation-----
# AUC: 66.09 Precision: 70.59 Recall: 52.17
#
# Fold 6
#
# -----Train----------
# AUC: 98.70 Precision: 99.10 Recall: 98.22
#
# -----Validation-----
# AUC: 55.57 Precision: 56.25 Recall: 39.13
#
# Fold 7
#
# -----Train----------
# AUC: 98.93 Precision: 99.11 Recall: 98.67
#
# -----Validation-----
# AUC: 67.82 Precision: 66.67 Recall: 63.64
#
# Fold 8
#
# -----Train----------
# AUC: 98.47 Precision: 99.55 Recall: 97.35
#
# -----Validation-----
# AUC: 53.03 Precision: 55.56 Recall: 22.73
#
# Fold 9
#
# -----Train----------
# AUC: 98.69 Precision: 99.55 Recall: 97.79
#
# -----Validation-----
# AUC: 58.33 Precision: 57.89 Recall: 50.00
#
# Fold 10
#
# -----Train----------
# AUC: 98.67 Precision: 100.00 Recall: 97.35
#
# -----Validation-----
# AUC: 66.86 Precision: 70.59 Recall: 54.55
#
# Fold 11
#
# -----Train----------
# AUC: 98.89 Precision: 100.00 Recall: 97.79
#
# -----Validation-----
# AUC: 69.32 Precision: 70.00 Recall: 63.64
#
# wheezy-copper-turtle-magic 508
#
# Fold 1
#
# -----Train----------
# AUC: 98.73 Precision: 100.00 Recall: 97.47
#
# -----Validation-----
# AUC: 66.67 Precision: 66.67 Recall: 66.67
#
# Fold 2
#
# -----Train----------
# AUC: 99.16 Precision: 100.00 Recall: 98.31
#
# -----Validation-----
# AUC: 64.58 Precision: 68.42 Recall: 54.17
#
# Fold 3
#
# -----Train----------
# AUC: 98.10 Precision: 98.31 Recall: 97.89
#
# -----Validation-----
# AUC: 68.75 Precision: 80.00 Recall: 50.00
#
# Fold 4
#
# -----Train----------
# AUC: 99.79 Precision: 100.00 Recall: 99.58
#
# -----Validation-----
# AUC: 64.58 Precision: 64.00 Recall: 66.67
#
# Fold 5
#
# -----Train----------
# AUC: 98.95 Precision: 99.15 Recall: 98.73
#
# -----Validation-----
# AUC: 64.58 Precision: 68.42 Recall: 54.17
#
# Fold 6
#
# -----Train----------
# AUC: 98.73 Precision: 99.57 Recall: 97.89
#
# -----Validation-----
# AUC: 70.83 Precision: 72.73 Recall: 66.67
#
# Fold 7
#
# -----Train----------
# AUC: 99.16 Precision: 100.00 Recall: 98.31
#
# -----Validation-----
# AUC: 54.17 Precision: 54.55 Recall: 50.00
#
# Fold 8
#
# -----Train----------
# AUC: 98.95 Precision: 99.57 Recall: 98.31
#
# -----Validation-----
# AUC: 62.50 Precision: 65.00 Recall: 54.17
#
# Fold 9
#
# -----Train----------
# AUC: 98.95 Precision: 99.57 Recall: 98.32
#
# -----Validation-----
# AUC: 73.91 Precision: 73.91 Recall: 73.91
#
# Fold 10
#
# -----Train----------
# AUC: 98.74 Precision: 100.00 Recall: 97.48
#
# -----Validation-----
# AUC: 65.22 Precision: 73.33 Recall: 47.83
#
# Fold 11
#
# -----Train----------
# AUC: 98.53 Precision: 100.00 Recall: 97.06
#
# -----Validation-----
# AUC: 60.87 Precision: 63.16 Recall: 52.17
#
# wheezy-copper-turtle-magic 509
#
# Fold 1
#
# -----Train----------
# AUC: 99.34 Precision: 99.55 Recall: 99.10
#
# -----Validation-----
# AUC: 69.93 Precision: 76.47 Recall: 56.52
#
# Fold 2
#
# -----Train----------
# AUC: 98.21 Precision: 99.54 Recall: 96.86
#
# -----Validation-----
# AUC: 69.93 Precision: 76.47 Recall: 56.52
#
# Fold 3
#
# -----Train----------
# AUC: 98.89 Precision: 99.55 Recall: 98.21
#
# -----Validation-----
# AUC: 58.70 Precision: 66.67 Recall: 34.78
#
# Fold 4
#
# -----Train----------
# AUC: 99.33 Precision: 100.00 Recall: 98.65
#
# -----Validation-----
# AUC: 76.09 Precision: 77.27 Recall: 73.91
#
# Fold 5
#
# -----Train----------
# AUC: 99.33 Precision: 100.00 Recall: 98.66
#
# -----Validation-----
# AUC: 68.77 Precision: 70.00 Recall: 63.64
#
# Fold 6
#
# -----Train----------
# AUC: 99.33 Precision: 100.00 Recall: 98.66
#
# -----Validation-----
# AUC: 71.05 Precision: 71.43 Recall: 68.18
#
# Fold 7
#
# -----Train----------
# AUC: 98.44 Precision: 100.00 Recall: 96.88
#
# -----Validation-----
# AUC: 77.77 Precision: 77.27 Recall: 77.27
#
# Fold 8
#
# -----Train----------
# AUC: 98.22 Precision: 99.54 Recall: 96.88
#
# -----Validation-----
# AUC: 59.58 Precision: 64.29 Recall: 40.91
#
# Fold 9
#
# -----Train----------
# AUC: 97.77 Precision: 100.00 Recall: 95.54
#
# -----Validation-----
# AUC: 59.78 Precision: 61.11 Recall: 50.00
#
# Fold 10
#
# -----Train----------
# AUC: 99.55 Precision: 100.00 Recall: 99.11
#
# -----Validation-----
# AUC: 71.05 Precision: 71.43 Recall: 68.18
#
# Fold 11
#
# -----Train----------
# AUC: 98.67 Precision: 99.55 Recall: 97.77
#
# -----Validation-----
# AUC: 66.50 Precision: 68.42 Recall: 59.09
#
# wheezy-copper-turtle-magic 510
#
# Fold 1
#
# -----Train----------
# AUC: 98.69 Precision: 100.00 Recall: 97.38
#
# -----Validation-----
# AUC: 65.76 Precision: 68.42 Recall: 56.52
#
# Fold 2
#
# -----Train----------
# AUC: 98.71 Precision: 99.12 Recall: 98.25
#
# -----Validation-----
# AUC: 59.42 Precision: 60.00 Recall: 52.17
#
# Fold 3
#
# -----Train----------
# AUC: 99.14 Precision: 99.56 Recall: 98.69
#
# -----Validation-----
# AUC: 57.25 Precision: 57.89 Recall: 47.83
#
# Fold 4
#
# -----Train----------
# AUC: 99.14 Precision: 99.13 Recall: 99.13
#
# -----Validation-----
# AUC: 63.50 Precision: 68.75 Recall: 47.83
#
# Fold 5
#
# -----Train----------
# AUC: 99.13 Precision: 100.00 Recall: 98.25
#
# -----Validation-----
# AUC: 57.34 Precision: 57.14 Recall: 52.17
#
# Fold 6
#
# -----Train----------
# AUC: 99.34 Precision: 100.00 Recall: 98.69
#
# -----Validation-----
# AUC: 65.67 Precision: 70.59 Recall: 52.17
#
# Fold 7
#
# -----Train----------
# AUC: 99.34 Precision: 100.00 Recall: 98.69
#
# -----Validation-----
# AUC: 61.50 Precision: 63.16 Recall: 52.17
#
# Fold 8
#
# -----Train----------
# AUC: 99.34 Precision: 100.00 Recall: 98.69
#
# -----Validation-----
# AUC: 67.84 Precision: 72.22 Recall: 56.52
#
# Fold 9
#
# -----Train----------
# AUC: 98.91 Precision: 100.00 Recall: 97.82
#
# -----Validation-----
# AUC: 65.85 Precision: 66.67 Recall: 60.87
#
# Fold 10
#
# -----Train----------
# AUC: 99.13 Precision: 100.00 Recall: 98.25
#
# -----Validation-----
# AUC: 69.84 Precision: 80.00 Recall: 52.17
#
# Fold 11
#
# -----Train----------
# AUC: 98.70 Precision: 100.00 Recall: 97.39
#
# -----Validation-----
# AUC: 64.23 Precision: 66.67 Recall: 54.55
#
# wheezy-copper-turtle-magic 511
#
# Fold 1
#
# -----Train----------
# AUC: 99.13 Precision: 99.57 Recall: 98.72
#
# -----Validation-----
# AUC: 74.55 Precision: 77.27 Recall: 70.83
#
# Fold 2
#
# -----Train----------
# AUC: 99.36 Precision: 100.00 Recall: 98.72
#
# -----Validation-----
# AUC: 70.29 Precision: 72.73 Recall: 66.67
#
# Fold 3
#
# -----Train----------
# AUC: 98.71 Precision: 99.57 Recall: 97.86
#
# -----Validation-----
# AUC: 65.91 Precision: 75.00 Recall: 50.00
#
# Fold 4
#
# -----Train----------
# AUC: 98.49 Precision: 99.56 Recall: 97.44
#
# -----Validation-----
# AUC: 60.98 Precision: 63.64 Recall: 58.33
#
# Fold 5
#
# -----Train----------
# AUC: 99.79 Precision: 100.00 Recall: 99.57
#
# -----Validation-----
# AUC: 54.92 Precision: 58.82 Recall: 41.67
#
# Fold 6
#
# -----Train----------
# AUC: 99.57 Precision: 100.00 Recall: 99.15
#
# -----Validation-----
# AUC: 75.79 Precision: 83.33 Recall: 65.22
#
# Fold 7
#
# -----Train----------
# AUC: 98.71 Precision: 99.57 Recall: 97.87
#
# -----Validation-----
# AUC: 82.02 Precision: 77.78 Recall: 91.30
#
# Fold 8
#
# -----Train----------
# AUC: 98.94 Precision: 100.00 Recall: 97.87
#
# -----Validation-----
# AUC: 82.41 Precision: 89.47 Recall: 73.91
#
# Fold 9
#
# -----Train----------
# AUC: 99.15 Precision: 100.00 Recall: 98.30
#
# -----Validation-----
# AUC: 62.25 Precision: 63.64 Recall: 60.87
#
# Fold 10
#
# -----Train----------
# AUC: 99.79 Precision: 100.00 Recall: 99.57
#
# -----Validation-----
# AUC: 66.80 Precision: 70.00 Recall: 60.87
#
# Fold 11
#
# -----Train----------
# AUC: 98.70 Precision: 99.14 Recall: 98.30
#
# -----Validation-----
# AUC: 62.15 Precision: 62.50 Recall: 65.22

# %% [markdown]
# # Model evaluation
# ## Confusion matrix

# %%
f = plt.subplots(1, 1, figsize=(16, 5), sharex=True)
train_cnf_matrix = confusion_matrix(train['target'], [np.round(x) for x in train['preds']])
train_cnf_matrix_norm = train_cnf_matrix / train_cnf_matrix.sum(axis=1)[:, np.newaxis]
train_df_cm = pd.DataFrame(train_cnf_matrix_norm, index=[0, 1], columns=[0, 1])
sns.heatmap(train_df_cm, annot=True, fmt='.2f', cmap="Blues")
plt.show()

# %% [markdown]
# ## Metrics ROC AUC

# %%
print('AUC %.2f' % roc_auc_score(train['target'], train['preds']))
# Out:
# AUC 1.00

# %% [markdown]
# # Test predictions

# %%
submission = test[['id', 'target']]
submission.to_csv('submission.csv', index=False)
submission.head(10)
# Out:
#                                  id    target
# 0  1c13f2701648e0b0d46d8a2a5a131a53  0.536364
# 1  ba88c155ba898fc8b5099893036ef205  0.545455
# 2  7cbab5cea99169139e7e6d8ff74ebb77  0.545455
# 3  ca820ad57809f62eb7b4d13f5d4371a0  0.536364
# 4  7baaf361537fbd8a1aaa2c97a6d4ccc7  0.381818
# 5  8b3116e5e3e92e971dac305d1a093bf6  0.581818
# 6  35cfd7cab9bfa29bc963d1b8c94dd280  0.200000
# 7  83cf532df8ff4642a3e33a70fffdac37  0.636364
# 8  2e1350fe94ec9f2220bec5245e5e9265  0.581818
# 9  e62020afa72eb54a15725473e3a8475b  0.300000
