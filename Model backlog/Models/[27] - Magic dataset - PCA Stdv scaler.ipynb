# %% [markdown]
# # Dependencies

# %%
import warnings
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

from sklearn.svm import SVC, NuSVC
from sklearn.decomposition import PCA
from sklearn.neural_network import MLPClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.discriminant_analysis import QuadraticDiscriminantAnalysis
from sklearn.feature_selection import VarianceThreshold
from sklearn.preprocessing import MinMaxScaler, StandardScaler
from sklearn.model_selection import train_test_split, StratifiedKFold
from sklearn.metrics import confusion_matrix, roc_auc_score, recall_score, precision_score

# Set seeds to make the experiment more reproducible.
from numpy.random import seed
seed(0)

# %matplotlib inline
sns.set_style("whitegrid")
warnings.filterwarnings("ignore")

# %% [markdown]
# # Load data

# %%
train = pd.read_csv('../input/train.csv')
test = pd.read_csv('../input/test.csv')

print('Train set shape:', train.shape)
print('Test set shape:', test.shape)
print('Train set overview:')
display(train.head())
# Out:
# Train set shape: (262144, 258)
# Test set shape: (131073, 257)
# Train set overview:
#                                  id   ...    target
# 0  707b395ecdcbb4dc2eabea00e4d1b179   ...         0
# 1  5880c03c6582a7b42248668e56b4bdec   ...         0
# 2  4ccbcb3d13e5072ff1d9c61afe2c4f77   ...         1
# 3  e350f17a357f12a1941f0837afb7eb8d   ...         0
# 4  a8f910ea6075b6376af079055965ff68   ...         0
#
# [5 rows x 258 columns]

# %% [markdown]
# # Model
#
# ## Model parameters

# %%
N_FOLDS = 11

# %% [markdown]
# ### You can find evaluation metrics for each model on each fold below on this cell output log. (It's hidden to keep the code clean)

# %%
# INITIALIZE VARIABLES
cols = [c for c in train.columns if c not in ['id', 'target', 'wheezy-copper-turtle-magic', 'preds']]
test['target_qda'] = 0
train['preds_qda'] = 0
test['target_knn'] = 0
train['preds_knn'] = 0
test['target_mlp'] = 0
train['preds_mlp'] = 0
test['target_svc'] = 0
train['preds_svc'] = 0
test['target_nusvc'] = 0
train['preds_nusvc'] = 0

# BUILD 512 MODELS
for i in range(512):
    print('wheezy-copper-turtle-magic {}\n'.format(i))
    
    # EXTRACT SUBSET OF DATASET WHERE WHEEZY-MAGIC EQUALS I
    train2 = train[train['wheezy-copper-turtle-magic']==i]
    test2 = test[test['wheezy-copper-turtle-magic']==i]
    idx1 = train2.index
    idx2 = test2.index
    train2.reset_index(drop=True, inplace=True)
    
    data = pd.concat([pd.DataFrame(train2[cols]), pd.DataFrame(test2[cols])])
    data2 = StandardScaler().fit_transform(PCA(svd_solver='full',n_components='mle').fit_transform(data[cols]))
    train3 = data2[:train2.shape[0]]
    test3 = data2[train2.shape[0]:]

    skf = StratifiedKFold(n_splits=N_FOLDS, random_state=0)
    counter = 0

    for train_index, val_index in skf.split(train3, train2['target']):
        counter += 1
        print('Fold {}\n'.format(counter))
        model_names = ['qda', 'knn', 'mlp', 'svc', 'nusvc']
        models = [QuadraticDiscriminantAnalysis(), KNeighborsClassifier(n_neighbors=17, p=2.9), MLPClassifier(), 
                  SVC(probability=True, kernel='poly', degree=4, gamma='auto', random_state=4), 
                  NuSVC(probability=True, kernel='poly', degree=4, gamma='auto', random_state=4)]
        
        for i in range(len(model_names)):
            model = models[i]
            model_name = model_names[i]
            model.fit(train3[train_index,:], train2.loc[train_index]['target'])

            train_predictions = model.predict(train3[train_index,:])
            val_predictions = model.predict(train3[val_index,:])

            train_auc = roc_auc_score(train2.loc[train_index]['target'], train_predictions) * 100
            val_auc = roc_auc_score(train2.loc[val_index]['target'], val_predictions) * 100
            train_precision = precision_score(train2.loc[train_index]['target'], train_predictions) * 100
            val_precision = precision_score(train2.loc[val_index]['target'], val_predictions) * 100
            train_recall = recall_score(train2.loc[train_index]['target'], train_predictions) * 100
            val_recall = recall_score(train2.loc[val_index]['target'], val_predictions) * 100
            print('-----%s - Train----------' % model_name)
            print('AUC: %.2f Precision: %.2f Recall: %.2f \n' % (train_auc, train_precision, train_recall))
            print('-----%s - Validation-----' % model_name)
            print('AUC: %.2f Precision: %.2f Recall: %.2f \n' % (val_auc, val_precision, val_recall))

            # Make predictions
            train[('preds_%s' % model_name)].loc[idx1] += model.predict_proba(train3)[:,1] / N_FOLDS
            test[('target_%s' % model_name)].loc[idx2] += model.predict_proba(test3)[:,1] / N_FOLDS
# Out:
# wheezy-copper-turtle-magic 0
#
# Fold 1
#
# -----qda - Train----------
# AUC: 97.32 Precision: 97.48 Recall: 97.07
#
# -----qda - Validation-----
# AUC: 83.67 Precision: 83.33 Recall: 83.33
#
# -----knn - Train----------
# AUC: 87.38 Precision: 89.38 Recall: 84.52
#
# -----knn - Validation-----
# AUC: 83.42 Precision: 94.44 Recall: 70.83
#
# -----mlp - Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----mlp - Validation-----
# AUC: 77.42 Precision: 80.95 Recall: 70.83
#
# -----svc - Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----svc - Validation-----
# AUC: 85.58 Precision: 90.48 Recall: 79.17
#
# -----nusvc - Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----nusvc - Validation-----
# AUC: 83.42 Precision: 94.44 Recall: 70.83
#
# Fold 2
#
# -----qda - Train----------
# AUC: 96.49 Precision: 96.64 Recall: 96.23
#
# -----qda - Validation-----
# AUC: 87.75 Precision: 87.50 Recall: 87.50
#
# -----knn - Train----------
# AUC: 88.79 Precision: 93.02 Recall: 83.68
#
# -----knn - Validation-----
# AUC: 67.08 Precision: 72.22 Recall: 54.17
#
# -----mlp - Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----mlp - Validation-----
# AUC: 81.67 Precision: 80.00 Recall: 83.33
#
# -----svc - Train----------
# AUC: 98.95 Precision: 100.00 Recall: 97.91
#
# -----svc - Validation-----
# AUC: 73.08 Precision: 86.67 Recall: 54.17
#
# -----nusvc - Train----------
# AUC: 99.58 Precision: 100.00 Recall: 99.16
#
# -----nusvc - Validation-----
# AUC: 66.83 Precision: 83.33 Recall: 41.67
#
# Fold 3
#
# -----qda - Train----------
# AUC: 97.12 Precision: 96.68 Recall: 97.49
#
# -----qda - Validation-----
# AUC: 95.92 Precision: 95.83 Recall: 95.83
#
# -----knn - Train----------
# AUC: 87.58 Precision: 90.13 Recall: 84.10
#
# -----knn - Validation-----
# AUC: 83.50 Precision: 90.00 Recall: 75.00
#
# -----mlp - Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----mlp - Validation-----
# AUC: 92.00 Precision: 85.71 Recall: 100.00
#
# -----svc - Train----------
# AUC: 99.58 Precision: 100.00 Recall: 99.16
#
# -----svc - Validation-----
# AUC: 85.42 Precision: 100.00 Recall: 70.83
#
# -----nusvc - Train----------
# AUC: 99.79 Precision: 100.00 Recall: 99.58
#
# -----nusvc - Validation-----
# AUC: 79.17 Precision: 100.00 Recall: 58.33
#
# Fold 4
#
# -----qda - Train----------
# AUC: 96.91 Precision: 96.67 Recall: 97.07
#
# -----qda - Validation-----
# AUC: 95.92 Precision: 95.83 Recall: 95.83
#
# -----knn - Train----------
# AUC: 86.71 Precision: 91.87 Recall: 80.33
#
# -----knn - Validation-----
# AUC: 85.58 Precision: 90.48 Recall: 79.17
#
# -----mlp - Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----mlp - Validation-----
# AUC: 81.58 Precision: 82.61 Recall: 79.17
#
# -----svc - Train----------
# AUC: 99.58 Precision: 100.00 Recall: 99.16
#
# -----svc - Validation-----
# AUC: 77.17 Precision: 93.33 Recall: 58.33
#
# -----nusvc - Train----------
# AUC: 99.58 Precision: 100.00 Recall: 99.16
#
# -----nusvc - Validation-----
# AUC: 73.00 Precision: 92.31 Recall: 50.00
#
# Fold 5
#
# -----qda - Train----------
# AUC: 96.70 Precision: 96.65 Recall: 96.65
#
# -----qda - Validation-----
# AUC: 95.83 Precision: 100.00 Recall: 91.67
#
# -----knn - Train----------
# AUC: 87.16 Precision: 90.05 Recall: 83.26
#
# -----knn - Validation-----
# AUC: 87.75 Precision: 87.50 Recall: 87.50
#
# -----mlp - Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----mlp - Validation-----
# AUC: 79.58 Precision: 79.17 Recall: 79.17
#
# -----svc - Train----------
# AUC: 99.16 Precision: 100.00 Recall: 98.33
#
# -----svc - Validation-----
# AUC: 87.50 Precision: 100.00 Recall: 75.00
#
# -----nusvc - Train----------
# AUC: 99.79 Precision: 100.00 Recall: 99.58
#
# -----nusvc - Validation-----
# AUC: 79.17 Precision: 100.00 Recall: 58.33
#
# Fold 6
#
# -----qda - Train----------
# AUC: 96.70 Precision: 96.65 Recall: 96.65
#
# -----qda - Validation-----
# AUC: 97.92 Precision: 100.00 Recall: 95.83
#
# -----knn - Train----------
# AUC: 87.36 Precision: 90.45 Recall: 83.26
#
# -----knn - Validation-----
# AUC: 87.58 Precision: 95.00 Recall: 79.17
#
# -----mlp - Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----mlp - Validation-----
# AUC: 91.83 Precision: 91.67 Recall: 91.67
#
# -----svc - Train----------
# AUC: 98.95 Precision: 100.00 Recall: 97.91
#
# -----svc - Validation-----
# AUC: 87.50 Precision: 100.00 Recall: 75.00
#
# -----nusvc - Train----------
# AUC: 99.79 Precision: 100.00 Recall: 99.58
#
# -----nusvc - Validation-----
# AUC: 83.33 Precision: 100.00 Recall: 66.67
#
# Fold 7
#
# -----qda - Train----------
# AUC: 96.91 Precision: 96.67 Recall: 97.07
#
# -----qda - Validation-----
# AUC: 95.92 Precision: 95.83 Recall: 95.83
#
# -----knn - Train----------
# AUC: 86.74 Precision: 89.95 Recall: 82.43
#
# -----knn - Validation-----
# AUC: 83.67 Precision: 83.33 Recall: 83.33
#
# -----mlp - Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----mlp - Validation-----
# AUC: 81.67 Precision: 80.00 Recall: 83.33
#
# -----svc - Train----------
# AUC: 99.37 Precision: 100.00 Recall: 98.74
#
# -----svc - Validation-----
# AUC: 85.58 Precision: 90.48 Recall: 79.17
#
# -----nusvc - Train----------
# AUC: 99.79 Precision: 100.00 Recall: 99.58
#
# -----nusvc - Validation-----
# AUC: 83.50 Precision: 90.00 Recall: 75.00
#
# Fold 8
#
# -----qda - Train----------
# AUC: 96.91 Precision: 97.06 Recall: 96.65
#
# -----qda - Validation-----
# AUC: 89.58 Precision: 91.30 Recall: 87.50
#
# -----knn - Train----------
# AUC: 87.58 Precision: 91.24 Recall: 82.85
#
# -----knn - Validation-----
# AUC: 75.00 Precision: 80.00 Recall: 66.67
#
# -----mlp - Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----mlp - Validation-----
# AUC: 77.08 Precision: 78.26 Recall: 75.00
#
# -----svc - Train----------
# AUC: 99.79 Precision: 100.00 Recall: 99.58
#
# -----svc - Validation-----
# AUC: 83.33 Precision: 94.44 Recall: 70.83
#
# -----nusvc - Train----------
# AUC: 99.79 Precision: 100.00 Recall: 99.58
#
# -----nusvc - Validation-----
# AUC: 81.25 Precision: 94.12 Recall: 66.67
#
# Fold 9
#
# -----qda - Train----------
# AUC: 97.94 Precision: 97.91 Recall: 97.91
#
# -----qda - Validation-----
# AUC: 87.50 Precision: 90.91 Recall: 83.33
#
# -----knn - Train----------
# AUC: 88.43 Precision: 90.67 Recall: 85.36
#
# -----knn - Validation-----
# AUC: 87.50 Precision: 84.62 Recall: 91.67
#
# -----mlp - Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----mlp - Validation-----
# AUC: 89.58 Precision: 88.00 Recall: 91.67
#
# -----svc - Train----------
# AUC: 99.58 Precision: 100.00 Recall: 99.16
#
# -----svc - Validation-----
# AUC: 83.33 Precision: 94.44 Recall: 70.83
#
# -----nusvc - Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----nusvc - Validation-----
# AUC: 81.25 Precision: 94.12 Recall: 66.67
#
# Fold 10
#
# -----qda - Train----------
# AUC: 96.91 Precision: 97.06 Recall: 96.65
#
# -----qda - Validation-----
# AUC: 93.75 Precision: 95.65 Recall: 91.67
#
# -----knn - Train----------
# AUC: 87.17 Precision: 90.41 Recall: 82.85
#
# -----knn - Validation-----
# AUC: 83.33 Precision: 94.44 Recall: 70.83
#
# -----mlp - Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----mlp - Validation-----
# AUC: 87.50 Precision: 87.50 Recall: 87.50
#
# -----svc - Train----------
# AUC: 99.37 Precision: 100.00 Recall: 98.74
#
# -----svc - Validation-----
# AUC: 75.00 Precision: 92.86 Recall: 54.17
#
# -----nusvc - Train----------
# AUC: 99.79 Precision: 100.00 Recall: 99.58
#
# -----nusvc - Validation-----
# AUC: 75.00 Precision: 100.00 Recall: 50.00
#
# Fold 11
#
# -----qda - Train----------
# AUC: 96.92 Precision: 96.68 Recall: 97.08
#
# -----qda - Validation-----
# AUC: 97.83 Precision: 100.00 Recall: 95.65
#
# -----knn - Train----------
# AUC: 87.03 Precision: 88.65 Recall: 84.58
#
# -----knn - Validation-----
# AUC: 83.06 Precision: 80.00 Recall: 86.96
#
# -----mlp - Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----mlp - Validation-----
# AUC: 85.14 Precision: 83.33 Recall: 86.96
#
# -----svc - Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----svc - Validation-----
# AUC: 97.83 Precision: 100.00 Recall: 95.65
#
# -----nusvc - Train----------
# AUC: 99.79 Precision: 100.00 Recall: 99.58
#
# -----nusvc - Validation-----
# AUC: 89.13 Precision: 100.00 Recall: 78.26
#
# wheezy-copper-turtle-magic 1
#
# Fold 1
#
# -----qda - Train----------
# AUC: 96.60 Precision: 94.81 Recall: 98.21
#
# -----qda - Validation-----
# AUC: 91.58 Precision: 88.00 Recall: 95.65
#
# -----knn - Train----------
# AUC: 92.18 Precision: 87.80 Recall: 96.86
#
# -----knn - Validation-----
# AUC: 83.15 Precision: 77.78 Recall: 91.30
#
# -----mlp - Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----mlp - Validation-----
# AUC: 83.15 Precision: 77.78 Recall: 91.30
#
# -----svc - Train----------
# AUC: 98.65 Precision: 100.00 Recall: 97.31
#
# -----svc - Validation-----
# AUC: 78.53 Precision: 84.21 Recall: 69.57
#
# -----nusvc - Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----nusvc - Validation-----
# AUC: 81.25 Precision: 71.88 Recall: 100.00
#
# Fold 2
#
# -----qda - Train----------
# AUC: 96.17 Precision: 94.37 Recall: 97.76
#
# -----qda - Validation-----
# AUC: 97.83 Precision: 100.00 Recall: 95.65
#
# -----knn - Train----------
# AUC: 90.08 Precision: 84.65 Recall: 96.41
#
# -----knn - Validation-----
# AUC: 95.83 Precision: 92.00 Recall: 100.00
#
# -----mlp - Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----mlp - Validation-----
# AUC: 93.75 Precision: 88.46 Recall: 100.00
#
# -----svc - Train----------
# AUC: 97.98 Precision: 100.00 Recall: 95.96
#
# -----svc - Validation-----
# AUC: 80.53 Precision: 93.75 Recall: 65.22
#
# -----nusvc - Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----nusvc - Validation-----
# AUC: 89.22 Precision: 95.00 Recall: 82.61
#
# Fold 3
#
# -----qda - Train----------
# AUC: 96.60 Precision: 94.81 Recall: 98.21
#
# -----qda - Validation-----
# AUC: 93.57 Precision: 95.45 Recall: 91.30
#
# -----knn - Train----------
# AUC: 92.13 Precision: 88.75 Recall: 95.52
#
# -----knn - Validation-----
# AUC: 91.49 Precision: 91.30 Recall: 91.30
#
# -----mlp - Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----mlp - Validation-----
# AUC: 85.05 Precision: 86.36 Recall: 82.61
#
# -----svc - Train----------
# AUC: 98.21 Precision: 100.00 Recall: 96.41
#
# -----svc - Validation-----
# AUC: 76.09 Precision: 100.00 Recall: 52.17
#
# -----nusvc - Train----------
# AUC: 99.78 Precision: 100.00 Recall: 99.55
#
# -----nusvc - Validation-----
# AUC: 84.87 Precision: 94.44 Recall: 73.91
#
# Fold 4
#
# -----qda - Train----------
# AUC: 96.60 Precision: 94.81 Recall: 98.21
#
# -----qda - Validation-----
# AUC: 89.49 Precision: 84.62 Recall: 95.65
#
# -----knn - Train----------
# AUC: 91.25 Precision: 88.24 Recall: 94.17
#
# -----knn - Validation-----
# AUC: 89.58 Precision: 82.14 Recall: 100.00
#
# -----mlp - Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----mlp - Validation-----
# AUC: 85.24 Precision: 80.77 Recall: 91.30
#
# -----svc - Train----------
# AUC: 98.21 Precision: 100.00 Recall: 96.41
#
# -----svc - Validation-----
# AUC: 71.92 Precision: 85.71 Recall: 52.17
#
# -----nusvc - Train----------
# AUC: 99.78 Precision: 100.00 Recall: 99.55
#
# -----nusvc - Validation-----
# AUC: 78.62 Precision: 80.95 Recall: 73.91
#
# Fold 5
#
# -----qda - Train----------
# AUC: 96.61 Precision: 94.83 Recall: 98.21
#
# -----qda - Validation-----
# AUC: 89.20 Precision: 86.96 Recall: 90.91
#
# -----knn - Train----------
# AUC: 91.50 Precision: 88.02 Recall: 95.09
#
# -----knn - Validation-----
# AUC: 89.39 Precision: 84.00 Recall: 95.45
#
# -----mlp - Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----mlp - Validation-----
# AUC: 89.20 Precision: 86.96 Recall: 90.91
#
# -----svc - Train----------
# AUC: 96.88 Precision: 100.00 Recall: 93.75
#
# -----svc - Validation-----
# AUC: 77.65 Precision: 87.50 Recall: 63.64
#
# -----nusvc - Train----------
# AUC: 99.78 Precision: 100.00 Recall: 99.55
#
# -----nusvc - Validation-----
# AUC: 89.02 Precision: 90.48 Recall: 86.36
#
# Fold 6
#
# -----qda - Train----------
# AUC: 96.40 Precision: 94.42 Recall: 98.21
#
# -----qda - Validation-----
# AUC: 91.10 Precision: 95.00 Recall: 86.36
#
# -----knn - Train----------
# AUC: 91.55 Precision: 87.10 Recall: 96.43
#
# -----knn - Validation-----
# AUC: 85.04 Precision: 80.00 Recall: 90.91
#
# -----mlp - Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----mlp - Validation-----
# AUC: 78.03 Precision: 80.00 Recall: 72.73
#
# -----svc - Train----------
# AUC: 98.21 Precision: 100.00 Recall: 96.43
#
# -----svc - Validation-----
# AUC: 82.01 Precision: 93.75 Recall: 68.18
#
# -----nusvc - Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----nusvc - Validation-----
# AUC: 89.02 Precision: 90.48 Recall: 86.36
#
# Fold 7
#
# -----qda - Train----------
# AUC: 97.02 Precision: 95.65 Recall: 98.21
#
# -----qda - Validation-----
# AUC: 82.77 Precision: 79.17 Recall: 86.36
#
# -----knn - Train----------
# AUC: 91.28 Precision: 87.97 Recall: 94.64
#
# -----knn - Validation-----
# AUC: 87.12 Precision: 83.33 Recall: 90.91
#
# -----mlp - Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----mlp - Validation-----
# AUC: 85.04 Precision: 80.00 Recall: 90.91
#
# -----svc - Train----------
# AUC: 97.54 Precision: 100.00 Recall: 95.09
#
# -----svc - Validation-----
# AUC: 75.19 Precision: 92.31 Recall: 54.55
#
# -----nusvc - Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----nusvc - Validation-----
# AUC: 82.58 Precision: 81.82 Recall: 81.82
#
# Fold 8
#
# -----qda - Train----------
# AUC: 96.85 Precision: 94.47 Recall: 99.11
#
# -----qda - Validation-----
# AUC: 95.64 Precision: 95.45 Recall: 95.45
#
# -----knn - Train----------
# AUC: 91.93 Precision: 88.43 Recall: 95.54
#
# -----knn - Validation-----
# AUC: 89.39 Precision: 84.00 Recall: 95.45
#
# -----mlp - Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----mlp - Validation-----
# AUC: 91.29 Precision: 90.91 Recall: 90.91
#
# -----svc - Train----------
# AUC: 98.21 Precision: 100.00 Recall: 96.43
#
# -----svc - Validation-----
# AUC: 81.82 Precision: 100.00 Recall: 63.64
#
# -----nusvc - Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----nusvc - Validation-----
# AUC: 89.02 Precision: 90.48 Recall: 86.36
#
# Fold 9
#
# -----qda - Train----------
# AUC: 96.61 Precision: 94.83 Recall: 98.21
#
# -----qda - Validation-----
# AUC: 89.02 Precision: 90.48 Recall: 86.36
#
# -----knn - Train----------
# AUC: 93.21 Precision: 90.00 Recall: 96.43
#
# -----knn - Validation-----
# AUC: 93.56 Precision: 91.30 Recall: 95.45
#
# -----mlp - Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----mlp - Validation-----
# AUC: 71.97 Precision: 68.00 Recall: 77.27
#
# -----svc - Train----------
# AUC: 97.10 Precision: 100.00 Recall: 94.20
#
# -----svc - Validation-----
# AUC: 68.75 Precision: 78.57 Recall: 50.00
#
# -----nusvc - Train----------
# AUC: 99.78 Precision: 100.00 Recall: 99.55
#
# -----nusvc - Validation-----
# AUC: 73.30 Precision: 81.25 Recall: 59.09
#
# Fold 10
#
# -----qda - Train----------
# AUC: 97.05 Precision: 94.87 Recall: 99.11
#
# -----qda - Validation-----
# AUC: 95.83 Precision: 91.67 Recall: 100.00
#
# -----knn - Train----------
# AUC: 90.70 Precision: 86.00 Recall: 95.98
#
# -----knn - Validation-----
# AUC: 93.56 Precision: 91.30 Recall: 95.45
#
# -----mlp - Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----mlp - Validation-----
# AUC: 97.92 Precision: 95.65 Recall: 100.00
#
# -----svc - Train----------
# AUC: 98.21 Precision: 100.00 Recall: 96.43
#
# -----svc - Validation-----
# AUC: 84.47 Precision: 89.47 Recall: 77.27
#
# -----nusvc - Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----nusvc - Validation-----
# AUC: 93.56 Precision: 91.30 Recall: 95.45
#
# Fold 11
#
# -----qda - Train----------
# AUC: 96.61 Precision: 94.83 Recall: 98.21
#
# -----qda - Validation-----
# AUC: 93.37 Precision: 95.24 Recall: 90.91
#
# -----knn - Train----------
# AUC: 91.79 Precision: 86.85 Recall: 97.32
#
# -----knn - Validation-----
# AUC: 80.68 Precision: 76.00 Recall: 86.36
#
# -----mlp - Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----mlp - Validation-----
# AUC: 82.20 Precision: 88.89 Recall: 72.73
#
# -----svc - Train----------
# AUC: 98.66 Precision: 100.00 Recall: 97.32
#
# -----svc - Validation-----
# AUC: 86.55 Precision: 94.44 Recall: 77.27
#
# -----nusvc - Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----nusvc - Validation-----
# AUC: 82.77 Precision: 79.17 Recall: 86.36
#
# wheezy-copper-turtle-magic 2
#
# Fold 1
#
# -----qda - Train----------
# AUC: 97.55 Precision: 97.29 Recall: 97.73
#
# -----qda - Validation-----
# AUC: 95.65 Precision: 95.65 Recall: 95.65
#
# -----knn - Train----------
# AUC: 88.33 Precision: 91.58 Recall: 84.09
#
# -----knn - Validation-----
# AUC: 80.43 Precision: 88.89 Recall: 69.57
#
# -----mlp - Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----mlp - Validation-----
# AUC: 84.78 Precision: 83.33 Recall: 86.96
#
# -----svc - Train----------
# AUC: 99.09 Precision: 100.00 Recall: 98.18
#
# -----svc - Validation-----
# AUC: 78.26 Precision: 93.33 Recall: 60.87
#
# -----nusvc - Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----nusvc - Validation-----
# AUC: 89.13 Precision: 95.00 Recall: 82.61
#
# Fold 2
#
# -----qda - Train----------
# AUC: 97.34 Precision: 96.86 Recall: 97.74
#
# -----qda - Validation-----
# AUC: 95.55 Precision: 95.45 Recall: 95.45
#
# -----knn - Train----------
# AUC: 87.92 Precision: 91.54 Recall: 83.26
#
# -----knn - Validation-----
# AUC: 86.56 Precision: 90.00 Recall: 81.82
#
# -----mlp - Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----mlp - Validation-----
# AUC: 77.77 Precision: 77.27 Recall: 77.27
#
# -----svc - Train----------
# AUC: 97.96 Precision: 100.00 Recall: 95.93
#
# -----svc - Validation-----
# AUC: 75.10 Precision: 92.31 Recall: 54.55
#
# -----nusvc - Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----nusvc - Validation-----
# AUC: 88.74 Precision: 94.74 Recall: 81.82
#
# Fold 3
#
# -----qda - Train----------
# AUC: 98.23 Precision: 97.76 Recall: 98.64
#
# -----qda - Validation-----
# AUC: 88.83 Precision: 90.48 Recall: 86.36
#
# -----knn - Train----------
# AUC: 86.54 Precision: 92.59 Recall: 79.19
#
# -----knn - Validation-----
# AUC: 72.83 Precision: 91.67 Recall: 50.00
#
# -----mlp - Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----mlp - Validation-----
# AUC: 86.66 Precision: 86.36 Recall: 86.36
#
# -----svc - Train----------
# AUC: 98.19 Precision: 100.00 Recall: 96.38
#
# -----svc - Validation-----
# AUC: 70.55 Precision: 90.91 Recall: 45.45
#
# -----nusvc - Train----------
# AUC: 99.77 Precision: 100.00 Recall: 99.55
#
# -----nusvc - Validation-----
# AUC: 82.02 Precision: 88.89 Recall: 72.73
#
# Fold 4
#
# -----qda - Train----------
# AUC: 97.33 Precision: 97.29 Recall: 97.29
#
# -----qda - Validation-----
# AUC: 93.28 Precision: 95.24 Recall: 90.91
#
# -----knn - Train----------
# AUC: 87.91 Precision: 91.96 Recall: 82.81
#
# -----knn - Validation-----
# AUC: 93.38 Precision: 91.30 Recall: 95.45
#
# -----mlp - Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----mlp - Validation-----
# AUC: 88.93 Precision: 86.96 Recall: 90.91
#
# -----svc - Train----------
# AUC: 99.10 Precision: 100.00 Recall: 98.19
#
# -----svc - Validation-----
# AUC: 90.91 Precision: 100.00 Recall: 81.82
#
# -----nusvc - Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----nusvc - Validation-----
# AUC: 88.83 Precision: 90.48 Recall: 86.36
#
# Fold 5
#
# -----qda - Train----------
# AUC: 97.78 Precision: 97.74 Recall: 97.74
#
# -----qda - Validation-----
# AUC: 91.21 Precision: 87.50 Recall: 95.45
#
# -----knn - Train----------
# AUC: 88.14 Precision: 91.58 Recall: 83.71
#
# -----knn - Validation-----
# AUC: 82.11 Precision: 85.00 Recall: 77.27
#
# -----mlp - Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----mlp - Validation-----
# AUC: 82.21 Precision: 81.82 Recall: 81.82
#
# -----svc - Train----------
# AUC: 98.64 Precision: 100.00 Recall: 97.29
#
# -----svc - Validation-----
# AUC: 70.55 Precision: 90.91 Recall: 45.45
#
# -----nusvc - Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----nusvc - Validation-----
# AUC: 86.56 Precision: 90.00 Recall: 81.82
#
# Fold 6
#
# -----qda - Train----------
# AUC: 98.44 Precision: 98.64 Recall: 98.19
#
# -----qda - Validation-----
# AUC: 88.93 Precision: 86.96 Recall: 90.91
#
# -----knn - Train----------
# AUC: 89.91 Precision: 94.44 Recall: 84.62
#
# -----knn - Validation-----
# AUC: 80.04 Precision: 78.26 Recall: 81.82
#
# -----mlp - Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----mlp - Validation-----
# AUC: 73.52 Precision: 69.23 Recall: 81.82
#
# -----svc - Train----------
# AUC: 99.32 Precision: 100.00 Recall: 98.64
#
# -----svc - Validation-----
# AUC: 84.29 Precision: 89.47 Recall: 77.27
#
# -----nusvc - Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----nusvc - Validation-----
# AUC: 91.11 Precision: 90.91 Recall: 90.91
#
# Fold 7
#
# -----qda - Train----------
# AUC: 97.11 Precision: 96.85 Recall: 97.29
#
# -----qda - Validation-----
# AUC: 95.65 Precision: 91.67 Recall: 100.00
#
# -----knn - Train----------
# AUC: 87.90 Precision: 92.39 Recall: 82.35
#
# -----knn - Validation-----
# AUC: 75.20 Precision: 86.67 Recall: 59.09
#
# -----mlp - Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----mlp - Validation-----
# AUC: 79.94 Precision: 80.95 Recall: 77.27
#
# -----svc - Train----------
# AUC: 99.32 Precision: 100.00 Recall: 98.64
#
# -----svc - Validation-----
# AUC: 81.82 Precision: 100.00 Recall: 63.64
#
# -----nusvc - Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----nusvc - Validation-----
# AUC: 88.64 Precision: 100.00 Recall: 77.27
#
# Fold 8
#
# -----qda - Train----------
# AUC: 97.34 Precision: 96.86 Recall: 97.74
#
# -----qda - Validation-----
# AUC: 93.28 Precision: 95.24 Recall: 90.91
#
# -----knn - Train----------
# AUC: 86.75 Precision: 93.55 Recall: 78.73
#
# -----knn - Validation-----
# AUC: 93.28 Precision: 95.24 Recall: 90.91
#
# -----mlp - Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----mlp - Validation-----
# AUC: 97.73 Precision: 100.00 Recall: 95.45
#
# -----svc - Train----------
# AUC: 98.87 Precision: 100.00 Recall: 97.74
#
# -----svc - Validation-----
# AUC: 70.45 Precision: 100.00 Recall: 40.91
#
# -----nusvc - Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----nusvc - Validation-----
# AUC: 86.56 Precision: 90.00 Recall: 81.82
#
# Fold 9
#
# -----qda - Train----------
# AUC: 98.02 Precision: 96.90 Recall: 99.10
#
# -----qda - Validation-----
# AUC: 93.18 Precision: 100.00 Recall: 86.36
#
# -----knn - Train----------
# AUC: 87.65 Precision: 93.68 Recall: 80.54
#
# -----knn - Validation-----
# AUC: 82.02 Precision: 88.89 Recall: 72.73
#
# -----mlp - Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----mlp - Validation-----
# AUC: 80.04 Precision: 78.26 Recall: 81.82
#
# -----svc - Train----------
# AUC: 98.64 Precision: 100.00 Recall: 97.29
#
# -----svc - Validation-----
# AUC: 72.73 Precision: 100.00 Recall: 45.45
#
# -----nusvc - Train----------
# AUC: 99.77 Precision: 100.00 Recall: 99.55
#
# -----nusvc - Validation-----
# AUC: 81.82 Precision: 100.00 Recall: 63.64
#
# Fold 10
#
# -----qda - Train----------
# AUC: 97.55 Precision: 97.73 Recall: 97.29
#
# -----qda - Validation-----
# AUC: 97.83 Precision: 95.65 Recall: 100.00
#
# -----knn - Train----------
# AUC: 85.87 Precision: 92.02 Recall: 78.28
#
# -----knn - Validation-----
# AUC: 84.29 Precision: 89.47 Recall: 77.27
#
# -----mlp - Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----mlp - Validation-----
# AUC: 88.93 Precision: 86.96 Recall: 90.91
#
# -----svc - Train----------
# AUC: 98.64 Precision: 100.00 Recall: 97.29
#
# -----svc - Validation-----
# AUC: 70.45 Precision: 100.00 Recall: 40.91
#
# -----nusvc - Train----------
# AUC: 99.77 Precision: 100.00 Recall: 99.55
#
# -----nusvc - Validation-----
# AUC: 84.09 Precision: 100.00 Recall: 68.18
#
# Fold 11
#
# -----qda - Train----------
# AUC: 97.12 Precision: 96.85 Recall: 97.29
#
# -----qda - Validation-----
# AUC: 93.18 Precision: 91.30 Recall: 95.45
#
# -----knn - Train----------
# AUC: 88.59 Precision: 92.93 Recall: 83.26
#
# -----knn - Validation-----
# AUC: 77.27 Precision: 83.33 Recall: 68.18
#
# -----mlp - Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----mlp - Validation-----
# AUC: 90.91 Precision: 90.91 Recall: 90.91
#
# -----svc - Train----------
# AUC: 99.10 Precision: 100.00 Recall: 98.19
#
# -----svc - Validation-----
# AUC: 84.09 Precision: 100.00 Recall: 68.18
#
# -----nusvc - Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----nusvc - Validation-----
# AUC: 88.64 Precision: 90.48 Recall: 86.36
#
# wheezy-copper-turtle-magic 3
#
# Fold 1
#
# -----qda - Train----------
# AUC: 98.36 Precision: 98.43 Recall: 98.43
#
# -----qda - Validation-----
# AUC: 98.08 Precision: 100.00 Recall: 96.15
#
# -----knn - Train----------
# AUC: 85.11 Precision: 79.74 Recall: 97.25
#
# -----knn - Validation-----
# AUC: 81.25 Precision: 74.29 Recall: 100.00
#
# -----mlp - Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----mlp - Validation-----
# AUC: 90.22 Precision: 95.65 Recall: 84.62
#
# -----svc - Train----------
# AUC: 94.64 Precision: 91.07 Recall: 100.00
#
# -----svc - Validation-----
# AUC: 58.33 Precision: 56.52 Recall: 100.00
#
# -----nusvc - Train----------
# AUC: 98.28 Precision: 96.96 Recall: 100.00
#
# -----nusvc - Validation-----
# AUC: 68.75 Precision: 63.41 Recall: 100.00
#
# Fold 2
#
# -----qda - Train----------
# AUC: 98.77 Precision: 98.82 Recall: 98.82
#
# -----qda - Validation-----
# AUC: 93.91 Precision: 92.59 Recall: 96.15
#
# -----knn - Train----------
# AUC: 86.61 Precision: 81.58 Recall: 97.25
#
# -----knn - Validation-----
# AUC: 81.41 Precision: 75.76 Recall: 96.15
#
# -----mlp - Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----mlp - Validation-----
# AUC: 91.99 Precision: 92.31 Recall: 92.31
#
# -----svc - Train----------
# AUC: 95.06 Precision: 91.73 Recall: 100.00
#
# -----svc - Validation-----
# AUC: 64.74 Precision: 60.98 Recall: 96.15
#
# -----nusvc - Train----------
# AUC: 98.93 Precision: 98.08 Recall: 100.00
#
# -----nusvc - Validation-----
# AUC: 77.24 Precision: 71.43 Recall: 96.15
#
# Fold 3
#
# -----qda - Train----------
# AUC: 98.39 Precision: 99.20 Recall: 97.65
#
# -----qda - Validation-----
# AUC: 94.07 Precision: 96.00 Recall: 92.31
#
# -----knn - Train----------
# AUC: 86.02 Precision: 81.40 Recall: 96.08
#
# -----knn - Validation-----
# AUC: 83.49 Precision: 78.12 Recall: 96.15
#
# -----mlp - Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----mlp - Validation-----
# AUC: 83.97 Precision: 84.62 Recall: 84.62
#
# -----svc - Train----------
# AUC: 97.21 Precision: 95.15 Recall: 100.00
#
# -----svc - Validation-----
# AUC: 75.16 Precision: 69.44 Recall: 96.15
#
# -----nusvc - Train----------
# AUC: 99.14 Precision: 98.46 Recall: 100.00
#
# -----nusvc - Validation-----
# AUC: 77.24 Precision: 71.43 Recall: 96.15
#
# Fold 4
#
# -----qda - Train----------
# AUC: 98.18 Precision: 98.81 Recall: 97.65
#
# -----qda - Validation-----
# AUC: 93.75 Precision: 89.66 Recall: 100.00
#
# -----knn - Train----------
# AUC: 85.15 Precision: 80.13 Recall: 96.47
#
# -----knn - Validation-----
# AUC: 85.42 Precision: 78.79 Recall: 100.00
#
# -----mlp - Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----mlp - Validation-----
# AUC: 86.06 Precision: 88.00 Recall: 84.62
#
# -----svc - Train----------
# AUC: 95.49 Precision: 92.39 Recall: 100.00
#
# -----svc - Validation-----
# AUC: 62.50 Precision: 59.09 Recall: 100.00
#
# -----nusvc - Train----------
# AUC: 98.71 Precision: 97.70 Recall: 100.00
#
# -----nusvc - Validation-----
# AUC: 68.75 Precision: 63.41 Recall: 100.00
#
# Fold 5
#
# -----qda - Train----------
# AUC: 98.40 Precision: 99.20 Recall: 97.65
#
# -----qda - Validation-----
# AUC: 87.46 Precision: 85.71 Recall: 92.31
#
# -----knn - Train----------
# AUC: 85.65 Precision: 80.86 Recall: 96.08
#
# -----knn - Validation-----
# AUC: 80.69 Precision: 75.76 Recall: 96.15
#
# -----mlp - Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----mlp - Validation-----
# AUC: 81.44 Precision: 81.48 Recall: 84.62
#
# -----svc - Train----------
# AUC: 95.94 Precision: 93.07 Recall: 100.00
#
# -----svc - Validation-----
# AUC: 63.04 Precision: 60.47 Recall: 100.00
#
# -----nusvc - Train----------
# AUC: 99.15 Precision: 98.46 Recall: 100.00
#
# -----nusvc - Validation-----
# AUC: 71.74 Precision: 66.67 Recall: 100.00
#
# Fold 6
#
# -----qda - Train----------
# AUC: 98.18 Precision: 98.81 Recall: 97.65
#
# -----qda - Validation-----
# AUC: 95.90 Precision: 96.15 Recall: 96.15
#
# -----knn - Train----------
# AUC: 85.43 Precision: 80.59 Recall: 96.08
#
# -----knn - Validation-----
# AUC: 84.78 Precision: 78.79 Recall: 100.00
#
# -----mlp - Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----mlp - Validation-----
# AUC: 89.63 Precision: 88.89 Recall: 92.31
#
# -----svc - Train----------
# AUC: 97.22 Precision: 95.15 Recall: 100.00
#
# -----svc - Validation-----
# AUC: 73.91 Precision: 68.42 Recall: 100.00
#
# -----nusvc - Train----------
# AUC: 99.36 Precision: 98.84 Recall: 100.00
#
# -----nusvc - Validation-----
# AUC: 76.09 Precision: 70.27 Recall: 100.00
#
# Fold 7
#
# -----qda - Train----------
# AUC: 98.60 Precision: 99.21 Recall: 98.05
#
# -----qda - Validation-----
# AUC: 91.83 Precision: 95.65 Recall: 88.00
#
# -----knn - Train----------
# AUC: 86.10 Precision: 81.67 Recall: 95.70
#
# -----knn - Validation-----
# AUC: 80.61 Precision: 75.00 Recall: 96.00
#
# -----mlp - Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----mlp - Validation-----
# AUC: 83.13 Precision: 81.48 Recall: 88.00
#
# -----svc - Train----------
# AUC: 97.22 Precision: 95.17 Recall: 100.00
#
# -----svc - Validation-----
# AUC: 76.09 Precision: 69.44 Recall: 100.00
#
# -----nusvc - Train----------
# AUC: 99.57 Precision: 99.22 Recall: 100.00
#
# -----nusvc - Validation-----
# AUC: 89.13 Precision: 83.33 Recall: 100.00
#
# Fold 8
#
# -----qda - Train----------
# AUC: 98.15 Precision: 98.05 Recall: 98.44
#
# -----qda - Validation-----
# AUC: 93.83 Precision: 95.83 Recall: 92.00
#
# -----knn - Train----------
# AUC: 85.37 Precision: 79.87 Recall: 97.66
#
# -----knn - Validation-----
# AUC: 84.96 Precision: 80.00 Recall: 96.00
#
# -----mlp - Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----mlp - Validation-----
# AUC: 85.48 Precision: 87.50 Recall: 84.00
#
# -----svc - Train----------
# AUC: 96.15 Precision: 93.43 Recall: 100.00
#
# -----svc - Validation-----
# AUC: 71.74 Precision: 65.79 Recall: 100.00
#
# -----nusvc - Train----------
# AUC: 98.93 Precision: 98.08 Recall: 100.00
#
# -----nusvc - Validation-----
# AUC: 76.09 Precision: 69.44 Recall: 100.00
#
# Fold 9
#
# -----qda - Train----------
# AUC: 98.58 Precision: 98.82 Recall: 98.44
#
# -----qda - Validation-----
# AUC: 89.83 Precision: 95.45 Recall: 84.00
#
# -----knn - Train----------
# AUC: 86.69 Precision: 81.85 Recall: 96.88
#
# -----knn - Validation-----
# AUC: 80.43 Precision: 73.53 Recall: 100.00
#
# -----mlp - Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----mlp - Validation-----
# AUC: 93.65 Precision: 92.31 Recall: 96.00
#
# -----svc - Train----------
# AUC: 95.94 Precision: 93.09 Recall: 100.00
#
# -----svc - Validation-----
# AUC: 69.57 Precision: 64.10 Recall: 100.00
#
# -----nusvc - Train----------
# AUC: 99.36 Precision: 98.84 Recall: 100.00
#
# -----nusvc - Validation-----
# AUC: 82.61 Precision: 75.76 Recall: 100.00
#
# Fold 10
#
# -----qda - Train----------
# AUC: 98.61 Precision: 99.60 Recall: 97.66
#
# -----qda - Validation-----
# AUC: 91.83 Precision: 95.65 Recall: 88.00
#
# -----knn - Train----------
# AUC: 86.56 Precision: 82.65 Recall: 94.92
#
# -----knn - Validation-----
# AUC: 91.65 Precision: 92.00 Recall: 92.00
#
# -----mlp - Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----mlp - Validation-----
# AUC: 83.48 Precision: 86.96 Recall: 80.00
#
# -----svc - Train----------
# AUC: 97.01 Precision: 94.81 Recall: 100.00
#
# -----svc - Validation-----
# AUC: 69.57 Precision: 64.10 Recall: 100.00
#
# -----nusvc - Train----------
# AUC: 99.57 Precision: 99.22 Recall: 100.00
#
# -----nusvc - Validation-----
# AUC: 84.78 Precision: 78.12 Recall: 100.00
#
# Fold 11
#
# -----qda - Train----------
# AUC: 98.17 Precision: 98.43 Recall: 98.05
#
# -----qda - Validation-----
# AUC: 85.30 Precision: 84.62 Recall: 88.00
#
# -----knn - Train----------
# AUC: 85.81 Precision: 80.58 Recall: 97.27
#
# -----knn - Validation-----
# AUC: 72.26 Precision: 68.75 Recall: 88.00
#
# -----mlp - Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----mlp - Validation-----
# AUC: 83.13 Precision: 81.48 Recall: 88.00
#
# -----svc - Train----------
# AUC: 95.94 Precision: 93.09 Recall: 100.00
#
# -----svc - Validation-----
# AUC: 56.52 Precision: 55.56 Recall: 100.00
#
# -----nusvc - Train----------
# AUC: 98.93 Precision: 98.08 Recall: 100.00
#
# -----nusvc - Validation-----
# AUC: 61.04 Precision: 58.54 Recall: 96.00
#
# wheezy-copper-turtle-magic 4
#
# Fold 1
#
# -----qda - Train----------
# AUC: 97.45 Precision: 98.28 Recall: 96.62
#
# -----qda - Validation-----
# AUC: 87.50 Precision: 87.50 Recall: 87.50
#
# -----knn - Train----------
# AUC: 91.01 Precision: 90.12 Recall: 92.41
#
# -----knn - Validation-----
# AUC: 83.33 Precision: 83.33 Recall: 83.33
#
# -----mlp - Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----mlp - Validation-----
# AUC: 85.42 Precision: 90.48 Recall: 79.17
#
# -----svc - Train----------
# AUC: 99.13 Precision: 98.34 Recall: 100.00
#
# -----svc - Validation-----
# AUC: 81.25 Precision: 75.86 Recall: 91.67
#
# -----nusvc - Train----------
# AUC: 99.78 Precision: 99.58 Recall: 100.00
#
# -----nusvc - Validation-----
# AUC: 83.33 Precision: 80.77 Recall: 87.50
#
# Fold 2
#
# -----qda - Train----------
# AUC: 96.38 Precision: 97.01 Recall: 95.78
#
# -----qda - Validation-----
# AUC: 93.75 Precision: 88.89 Recall: 100.00
#
# -----knn - Train----------
# AUC: 89.96 Precision: 90.60 Recall: 89.45
#
# -----knn - Validation-----
# AUC: 85.42 Precision: 81.48 Recall: 91.67
#
# -----mlp - Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----mlp - Validation-----
# AUC: 79.17 Precision: 79.17 Recall: 79.17
#
# -----svc - Train----------
# AUC: 98.48 Precision: 97.13 Recall: 100.00
#
# -----svc - Validation-----
# AUC: 77.08 Precision: 68.57 Recall: 100.00
#
# -----nusvc - Train----------
# AUC: 99.57 Precision: 99.16 Recall: 100.00
#
# -----nusvc - Validation-----
# AUC: 81.25 Precision: 72.73 Recall: 100.00
#
# Fold 3
#
# -----qda - Train----------
# AUC: 96.38 Precision: 97.01 Recall: 95.78
#
# -----qda - Validation-----
# AUC: 89.40 Precision: 91.30 Recall: 87.50
#
# -----knn - Train----------
# AUC: 90.63 Precision: 91.42 Recall: 89.87
#
# -----knn - Validation-----
# AUC: 89.49 Precision: 95.24 Recall: 83.33
#
# -----mlp - Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----mlp - Validation-----
# AUC: 85.24 Precision: 90.48 Recall: 79.17
#
# -----svc - Train----------
# AUC: 99.57 Precision: 99.16 Recall: 100.00
#
# -----svc - Validation-----
# AUC: 87.05 Precision: 82.14 Recall: 95.83
#
# -----nusvc - Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----nusvc - Validation-----
# AUC: 87.05 Precision: 82.14 Recall: 95.83
#
# Fold 4
#
# -----qda - Train----------
# AUC: 96.60 Precision: 97.42 Recall: 95.78
#
# -----qda - Validation-----
# AUC: 95.83 Precision: 100.00 Recall: 91.67
#
# -----knn - Train----------
# AUC: 90.18 Precision: 89.63 Recall: 91.14
#
# -----knn - Validation-----
# AUC: 93.66 Precision: 95.65 Recall: 91.67
#
# -----mlp - Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----mlp - Validation-----
# AUC: 95.83 Precision: 100.00 Recall: 91.67
#
# -----svc - Train----------
# AUC: 98.92 Precision: 97.93 Recall: 100.00
#
# -----svc - Validation-----
# AUC: 93.57 Precision: 92.00 Recall: 95.83
#
# -----nusvc - Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----nusvc - Validation-----
# AUC: 95.83 Precision: 100.00 Recall: 91.67
#
# Fold 5
#
# -----qda - Train----------
# AUC: 97.02 Precision: 97.45 Recall: 96.62
#
# -----qda - Validation-----
# AUC: 91.58 Precision: 95.45 Recall: 87.50
#
# -----knn - Train----------
# AUC: 89.77 Precision: 90.56 Recall: 89.03
#
# -----knn - Validation-----
# AUC: 89.49 Precision: 95.24 Recall: 83.33
#
# -----mlp - Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----mlp - Validation-----
# AUC: 85.24 Precision: 90.48 Recall: 79.17
#
# -----svc - Train----------
# AUC: 99.14 Precision: 98.34 Recall: 100.00
#
# -----svc - Validation-----
# AUC: 84.96 Precision: 81.48 Recall: 91.67
#
# -----nusvc - Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----nusvc - Validation-----
# AUC: 89.40 Precision: 91.30 Recall: 87.50
#
# Fold 6
#
# -----qda - Train----------
# AUC: 97.66 Precision: 98.29 Recall: 97.05
#
# -----qda - Validation-----
# AUC: 84.96 Precision: 81.48 Recall: 91.67
#
# -----knn - Train----------
# AUC: 90.63 Precision: 91.42 Recall: 89.87
#
# -----knn - Validation-----
# AUC: 82.79 Precision: 78.57 Recall: 91.67
#
# -----mlp - Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----mlp - Validation-----
# AUC: 84.96 Precision: 81.48 Recall: 91.67
#
# -----svc - Train----------
# AUC: 99.35 Precision: 98.75 Recall: 100.00
#
# -----svc - Validation-----
# AUC: 78.35 Precision: 71.88 Recall: 95.83
#
# -----nusvc - Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----nusvc - Validation-----
# AUC: 80.71 Precision: 77.78 Recall: 87.50
#
# Fold 7
#
# -----qda - Train----------
# AUC: 97.45 Precision: 97.87 Recall: 97.05
#
# -----qda - Validation-----
# AUC: 87.14 Precision: 84.62 Recall: 91.67
#
# -----knn - Train----------
# AUC: 90.20 Precision: 90.99 Recall: 89.45
#
# -----knn - Validation-----
# AUC: 85.14 Precision: 86.96 Recall: 83.33
#
# -----mlp - Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----mlp - Validation-----
# AUC: 85.05 Precision: 84.00 Recall: 87.50
#
# -----svc - Train----------
# AUC: 98.92 Precision: 97.93 Recall: 100.00
#
# -----svc - Validation-----
# AUC: 91.30 Precision: 85.71 Recall: 100.00
#
# -----nusvc - Train----------
# AUC: 99.78 Precision: 99.58 Recall: 100.00
#
# -----nusvc - Validation-----
# AUC: 91.39 Precision: 88.46 Recall: 95.83
#
# Fold 8
#
# -----qda - Train----------
# AUC: 97.23 Precision: 97.86 Recall: 96.62
#
# -----qda - Validation-----
# AUC: 93.57 Precision: 92.00 Recall: 95.83
#
# -----knn - Train----------
# AUC: 89.77 Precision: 90.56 Recall: 89.03
#
# -----knn - Validation-----
# AUC: 91.39 Precision: 88.46 Recall: 95.83
#
# -----mlp - Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----mlp - Validation-----
# AUC: 84.96 Precision: 81.48 Recall: 91.67
#
# -----svc - Train----------
# AUC: 98.92 Precision: 97.93 Recall: 100.00
#
# -----svc - Validation-----
# AUC: 84.78 Precision: 77.42 Recall: 100.00
#
# -----nusvc - Train----------
# AUC: 99.78 Precision: 99.58 Recall: 100.00
#
# -----nusvc - Validation-----
# AUC: 89.22 Precision: 85.19 Recall: 95.83
#
# Fold 9
#
# -----qda - Train----------
# AUC: 97.45 Precision: 97.88 Recall: 97.06
#
# -----qda - Validation-----
# AUC: 97.83 Precision: 100.00 Recall: 95.65
#
# -----knn - Train----------
# AUC: 90.44 Precision: 91.42 Recall: 89.50
#
# -----knn - Validation-----
# AUC: 91.30 Precision: 95.24 Recall: 86.96
#
# -----mlp - Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----mlp - Validation-----
# AUC: 80.43 Precision: 75.00 Recall: 91.30
#
# -----svc - Train----------
# AUC: 99.35 Precision: 98.76 Recall: 100.00
#
# -----svc - Validation-----
# AUC: 93.48 Precision: 91.67 Recall: 95.65
#
# -----nusvc - Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----nusvc - Validation-----
# AUC: 93.48 Precision: 91.67 Recall: 95.65
#
# Fold 10
#
# -----qda - Train----------
# AUC: 97.03 Precision: 97.86 Recall: 96.22
#
# -----qda - Validation-----
# AUC: 91.30 Precision: 95.24 Recall: 86.96
#
# -----knn - Train----------
# AUC: 90.44 Precision: 91.42 Recall: 89.50
#
# -----knn - Validation-----
# AUC: 84.78 Precision: 90.00 Recall: 78.26
#
# -----mlp - Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----mlp - Validation-----
# AUC: 86.96 Precision: 94.74 Recall: 78.26
#
# -----svc - Train----------
# AUC: 98.92 Precision: 97.94 Recall: 100.00
#
# -----svc - Validation-----
# AUC: 86.96 Precision: 81.48 Recall: 95.65
#
# -----nusvc - Train----------
# AUC: 99.78 Precision: 99.58 Recall: 100.00
#
# -----nusvc - Validation-----
# AUC: 93.48 Precision: 100.00 Recall: 86.96
#
# Fold 11
#
# -----qda - Train----------
# AUC: 97.46 Precision: 98.29 Recall: 96.64
#
# -----qda - Validation-----
# AUC: 91.30 Precision: 88.00 Recall: 95.65
#
# -----knn - Train----------
# AUC: 90.65 Precision: 91.45 Recall: 89.92
#
# -----knn - Validation-----
# AUC: 82.61 Precision: 85.71 Recall: 78.26
#
# -----mlp - Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----mlp - Validation-----
# AUC: 80.43 Precision: 85.00 Recall: 73.91
#
# -----svc - Train----------
# AUC: 99.35 Precision: 98.76 Recall: 100.00
#
# -----svc - Validation-----
# AUC: 86.96 Precision: 81.48 Recall: 95.65
#
# -----nusvc - Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----nusvc - Validation-----
# AUC: 91.30 Precision: 88.00 Recall: 95.65
#
# wheezy-copper-turtle-magic 5
#
# Fold 1
#
# -----qda - Train----------
# AUC: 97.25 Precision: 97.84 Recall: 96.60
#
# -----qda - Validation-----
# AUC: 89.58 Precision: 95.24 Recall: 83.33
#
# -----knn - Train----------
# AUC: 88.32 Precision: 95.45 Recall: 80.43
#
# -----knn - Validation-----
# AUC: 77.08 Precision: 78.26 Recall: 75.00
#
# -----mlp - Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----mlp - Validation-----
# AUC: 83.33 Precision: 80.77 Recall: 87.50
#
# -----svc - Train----------
# AUC: 99.16 Precision: 98.33 Recall: 100.00
#
# -----svc - Validation-----
# AUC: 81.25 Precision: 75.86 Recall: 91.67
#
# -----nusvc - Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----nusvc - Validation-----
# AUC: 85.42 Precision: 86.96 Recall: 83.33
#
# Fold 2
#
# -----qda - Train----------
# AUC: 97.88 Precision: 98.70 Recall: 97.02
#
# -----qda - Validation-----
# AUC: 81.25 Precision: 77.78 Recall: 87.50
#
# -----knn - Train----------
# AUC: 86.84 Precision: 93.91 Recall: 78.72
#
# -----knn - Validation-----
# AUC: 75.00 Precision: 83.33 Recall: 62.50
#
# -----mlp - Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----mlp - Validation-----
# AUC: 85.42 Precision: 86.96 Recall: 83.33
#
# -----svc - Train----------
# AUC: 99.37 Precision: 98.74 Recall: 100.00
#
# -----svc - Validation-----
# AUC: 79.17 Precision: 71.88 Recall: 95.83
#
# -----nusvc - Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----nusvc - Validation-----
# AUC: 85.42 Precision: 84.00 Recall: 87.50
#
# Fold 3
#
# -----qda - Train----------
# AUC: 97.24 Precision: 98.26 Recall: 96.17
#
# -----qda - Validation-----
# AUC: 93.75 Precision: 95.65 Recall: 91.67
#
# -----knn - Train----------
# AUC: 86.64 Precision: 91.75 Recall: 80.43
#
# -----knn - Validation-----
# AUC: 85.42 Precision: 94.74 Recall: 75.00
#
# -----mlp - Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----mlp - Validation-----
# AUC: 85.42 Precision: 86.96 Recall: 83.33
#
# -----svc - Train----------
# AUC: 99.37 Precision: 98.74 Recall: 100.00
#
# -----svc - Validation-----
# AUC: 87.50 Precision: 80.00 Recall: 100.00
#
# -----nusvc - Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----nusvc - Validation-----
# AUC: 93.75 Precision: 88.89 Recall: 100.00
#
# Fold 4
#
# -----qda - Train----------
# AUC: 97.24 Precision: 98.68 Recall: 95.74
#
# -----qda - Validation-----
# AUC: 93.75 Precision: 100.00 Recall: 87.50
#
# -----knn - Train----------
# AUC: 87.71 Precision: 91.94 Recall: 82.55
#
# -----knn - Validation-----
# AUC: 87.50 Precision: 90.91 Recall: 83.33
#
# -----mlp - Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----mlp - Validation-----
# AUC: 83.33 Precision: 80.77 Recall: 87.50
#
# -----svc - Train----------
# AUC: 99.58 Precision: 99.16 Recall: 100.00
#
# -----svc - Validation-----
# AUC: 87.50 Precision: 80.00 Recall: 100.00
#
# -----nusvc - Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----nusvc - Validation-----
# AUC: 91.67 Precision: 95.45 Recall: 87.50
#
# Fold 5
#
# -----qda - Train----------
# AUC: 97.24 Precision: 98.26 Recall: 96.17
#
# -----qda - Validation-----
# AUC: 91.67 Precision: 91.67 Recall: 91.67
#
# -----knn - Train----------
# AUC: 85.58 Precision: 91.54 Recall: 78.30
#
# -----knn - Validation-----
# AUC: 83.33 Precision: 90.00 Recall: 75.00
#
# -----mlp - Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----mlp - Validation-----
# AUC: 91.67 Precision: 88.46 Recall: 95.83
#
# -----svc - Train----------
# AUC: 98.95 Precision: 97.92 Recall: 100.00
#
# -----svc - Validation-----
# AUC: 75.00 Precision: 66.67 Recall: 100.00
#
# -----nusvc - Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----nusvc - Validation-----
# AUC: 87.50 Precision: 82.14 Recall: 95.83
#
# Fold 6
#
# -----qda - Train----------
# AUC: 97.66 Precision: 99.12 Recall: 96.17
#
# -----qda - Validation-----
# AUC: 93.75 Precision: 95.65 Recall: 91.67
#
# -----knn - Train----------
# AUC: 85.78 Precision: 92.42 Recall: 77.87
#
# -----knn - Validation-----
# AUC: 85.42 Precision: 100.00 Recall: 70.83
#
# -----mlp - Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----mlp - Validation-----
# AUC: 85.42 Precision: 84.00 Recall: 87.50
#
# -----svc - Train----------
# AUC: 99.79 Precision: 99.58 Recall: 100.00
#
# -----svc - Validation-----
# AUC: 87.50 Precision: 80.00 Recall: 100.00
#
# -----nusvc - Train----------
# AUC: 99.79 Precision: 100.00 Recall: 99.57
#
# -----nusvc - Validation-----
# AUC: 93.75 Precision: 95.65 Recall: 91.67
#
# Fold 7
#
# -----qda - Train----------
# AUC: 97.25 Precision: 97.85 Recall: 96.61
#
# -----qda - Validation-----
# AUC: 95.65 Precision: 100.00 Recall: 91.30
#
# -----knn - Train----------
# AUC: 87.95 Precision: 94.09 Recall: 80.93
#
# -----knn - Validation-----
# AUC: 72.10 Precision: 77.78 Recall: 60.87
#
# -----mlp - Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----mlp - Validation-----
# AUC: 80.89 Precision: 79.17 Recall: 82.61
#
# -----svc - Train----------
# AUC: 99.37 Precision: 98.74 Recall: 100.00
#
# -----svc - Validation-----
# AUC: 79.17 Precision: 69.70 Recall: 100.00
#
# -----nusvc - Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----nusvc - Validation-----
# AUC: 87.32 Precision: 84.00 Recall: 91.30
#
# Fold 8
#
# -----qda - Train----------
# AUC: 97.25 Precision: 98.27 Recall: 96.19
#
# -----qda - Validation-----
# AUC: 93.48 Precision: 100.00 Recall: 86.96
#
# -----knn - Train----------
# AUC: 86.26 Precision: 92.54 Recall: 78.81
#
# -----knn - Validation-----
# AUC: 86.96 Precision: 100.00 Recall: 73.91
#
# -----mlp - Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----mlp - Validation-----
# AUC: 78.44 Precision: 88.24 Recall: 65.22
#
# -----svc - Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----svc - Validation-----
# AUC: 93.57 Precision: 95.45 Recall: 91.30
#
# -----nusvc - Train----------
# AUC: 99.79 Precision: 100.00 Recall: 99.58
#
# -----nusvc - Validation-----
# AUC: 93.48 Precision: 100.00 Recall: 86.96
#
# Fold 9
#
# -----qda - Train----------
# AUC: 97.46 Precision: 98.70 Recall: 96.19
#
# -----qda - Validation-----
# AUC: 95.83 Precision: 92.00 Recall: 100.00
#
# -----knn - Train----------
# AUC: 84.15 Precision: 90.05 Recall: 76.69
#
# -----knn - Validation-----
# AUC: 89.13 Precision: 100.00 Recall: 78.26
#
# -----mlp - Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----mlp - Validation-----
# AUC: 87.50 Precision: 79.31 Recall: 100.00
#
# -----svc - Train----------
# AUC: 99.16 Precision: 98.33 Recall: 100.00
#
# -----svc - Validation-----
# AUC: 87.50 Precision: 79.31 Recall: 100.00
#
# -----nusvc - Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----nusvc - Validation-----
# AUC: 89.58 Precision: 82.14 Recall: 100.00
#
# Fold 10
#
# -----qda - Train----------
# AUC: 97.89 Precision: 98.71 Recall: 97.03
#
# -----qda - Validation-----
# AUC: 82.61 Precision: 85.71 Recall: 78.26
#
# -----knn - Train----------
# AUC: 86.26 Precision: 94.76 Recall: 76.69
#
# -----knn - Validation-----
# AUC: 78.26 Precision: 84.21 Recall: 69.57
#
# -----mlp - Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----mlp - Validation-----
# AUC: 86.96 Precision: 86.96 Recall: 86.96
#
# -----svc - Train----------
# AUC: 99.79 Precision: 99.58 Recall: 100.00
#
# -----svc - Validation-----
# AUC: 86.96 Precision: 84.00 Recall: 91.30
#
# -----nusvc - Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----nusvc - Validation-----
# AUC: 80.43 Precision: 81.82 Recall: 78.26
#
# Fold 11
#
# -----qda - Train----------
# AUC: 97.47 Precision: 98.70 Recall: 96.19
#
# -----qda - Validation-----
# AUC: 93.48 Precision: 95.45 Recall: 91.30
#
# -----knn - Train----------
# AUC: 86.06 Precision: 92.08 Recall: 78.81
#
# -----knn - Validation-----
# AUC: 82.61 Precision: 94.12 Recall: 69.57
#
# -----mlp - Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----mlp - Validation-----
# ...
#
# -----mlp - Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----mlp - Validation-----
# AUC: 77.87 Precision: 80.95 Recall: 73.91
#
# -----svc - Train----------
# AUC: 98.20 Precision: 96.62 Recall: 100.00
#
# -----svc - Validation-----
# AUC: 72.92 Precision: 67.74 Recall: 91.30
#
# -----nusvc - Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----nusvc - Validation-----
# AUC: 77.47 Precision: 72.41 Recall: 91.30
#
# Fold 11
#
# -----qda - Train----------
# AUC: 98.45 Precision: 98.27 Recall: 98.70
#
# -----qda - Validation-----
# AUC: 97.73 Precision: 100.00 Recall: 95.45
#
# -----knn - Train----------
# AUC: 86.53 Precision: 87.89 Recall: 85.22
#
# -----knn - Validation-----
# AUC: 88.64 Precision: 90.48 Recall: 86.36
#
# -----mlp - Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----mlp - Validation-----
# AUC: 88.64 Precision: 90.48 Recall: 86.36
#
# -----svc - Train----------
# AUC: 99.10 Precision: 98.29 Recall: 100.00
#
# -----svc - Validation-----
# AUC: 75.00 Precision: 66.67 Recall: 100.00
#
# -----nusvc - Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----nusvc - Validation-----
# AUC: 86.36 Precision: 78.57 Recall: 100.00
#
# wheezy-copper-turtle-magic 114
#
# Fold 1
#
# -----qda - Train----------
# AUC: 97.38 Precision: 97.03 Recall: 97.86
#
# -----qda - Validation-----
# AUC: 93.75 Precision: 100.00 Recall: 87.50
#
# -----knn - Train----------
# AUC: 84.08 Precision: 78.12 Recall: 96.15
#
# -----knn - Validation-----
# AUC: 76.36 Precision: 72.41 Recall: 87.50
#
# -----mlp - Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----mlp - Validation-----
# AUC: 97.92 Precision: 100.00 Recall: 95.83
#
# -----svc - Train----------
# AUC: 96.22 Precision: 93.23 Recall: 100.00
#
# -----svc - Validation-----
# AUC: 60.87 Precision: 57.14 Recall: 100.00
#
# -----nusvc - Train----------
# AUC: 99.11 Precision: 98.32 Recall: 100.00
#
# -----nusvc - Validation-----
# AUC: 60.96 Precision: 57.50 Recall: 95.83
#
# Fold 2
#
# -----qda - Train----------
# AUC: 97.59 Precision: 97.05 Recall: 98.29
#
# -----qda - Validation-----
# AUC: 87.23 Precision: 87.50 Recall: 87.50
#
# -----knn - Train----------
# AUC: 85.43 Precision: 80.22 Recall: 95.30
#
# -----knn - Validation-----
# AUC: 80.62 Precision: 75.86 Recall: 91.67
#
# -----mlp - Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----mlp - Validation-----
# AUC: 74.55 Precision: 77.27 Recall: 70.83
#
# -----svc - Train----------
# AUC: 96.89 Precision: 94.35 Recall: 100.00
#
# -----svc - Validation-----
# AUC: 76.18 Precision: 69.70 Recall: 95.83
#
# -----nusvc - Train----------
# AUC: 99.33 Precision: 98.73 Recall: 100.00
#
# -----nusvc - Validation-----
# AUC: 82.70 Precision: 76.67 Recall: 95.83
#
# Fold 3
#
# -----qda - Train----------
# AUC: 97.58 Precision: 96.65 Recall: 98.72
#
# -----qda - Validation-----
# AUC: 85.24 Precision: 90.48 Recall: 79.17
#
# -----knn - Train----------
# AUC: 84.12 Precision: 79.14 Recall: 94.02
#
# -----knn - Validation-----
# AUC: 82.79 Precision: 78.57 Recall: 91.67
#
# -----mlp - Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----mlp - Validation-----
# AUC: 80.98 Precision: 85.71 Recall: 75.00
#
# -----svc - Train----------
# AUC: 96.89 Precision: 94.35 Recall: 100.00
#
# -----svc - Validation-----
# AUC: 67.57 Precision: 62.86 Recall: 91.67
#
# -----nusvc - Train----------
# AUC: 98.89 Precision: 97.91 Recall: 100.00
#
# -----nusvc - Validation-----
# AUC: 74.09 Precision: 68.75 Recall: 91.67
#
# Fold 4
#
# -----qda - Train----------
# AUC: 97.16 Precision: 97.02 Recall: 97.44
#
# -----qda - Validation-----
# AUC: 95.74 Precision: 95.83 Recall: 95.83
#
# -----knn - Train----------
# AUC: 84.37 Precision: 80.07 Recall: 92.74
#
# -----knn - Validation-----
# AUC: 86.96 Precision: 80.00 Recall: 100.00
#
# -----mlp - Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----mlp - Validation-----
# AUC: 89.22 Precision: 85.19 Recall: 95.83
#
# -----svc - Train----------
# AUC: 95.78 Precision: 92.49 Recall: 100.00
#
# -----svc - Validation-----
# AUC: 67.39 Precision: 61.54 Recall: 100.00
#
# -----nusvc - Train----------
# AUC: 99.33 Precision: 98.73 Recall: 100.00
#
# -----nusvc - Validation-----
# AUC: 71.74 Precision: 64.86 Recall: 100.00
#
# Fold 5
#
# -----qda - Train----------
# AUC: 96.94 Precision: 96.61 Recall: 97.44
#
# -----qda - Validation-----
# AUC: 93.57 Precision: 92.00 Recall: 95.83
#
# -----knn - Train----------
# AUC: 85.21 Precision: 80.14 Recall: 94.87
#
# -----knn - Validation-----
# AUC: 80.71 Precision: 77.78 Recall: 87.50
#
# -----mlp - Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----mlp - Validation-----
# AUC: 85.05 Precision: 84.00 Recall: 87.50
#
# -----svc - Train----------
# AUC: 95.56 Precision: 92.13 Recall: 100.00
#
# -----svc - Validation-----
# AUC: 69.57 Precision: 63.16 Recall: 100.00
#
# -----nusvc - Train----------
# AUC: 98.89 Precision: 97.91 Recall: 100.00
#
# -----nusvc - Validation-----
# AUC: 82.61 Precision: 75.00 Recall: 100.00
#
# Fold 6
#
# -----qda - Train----------
# AUC: 96.94 Precision: 96.23 Recall: 97.87
#
# -----qda - Validation-----
# AUC: 91.30 Precision: 95.24 Recall: 86.96
#
# -----knn - Train----------
# AUC: 86.38 Precision: 82.89 Recall: 92.77
#
# -----knn - Validation-----
# AUC: 82.61 Precision: 77.78 Recall: 91.30
#
# -----mlp - Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----mlp - Validation-----
# AUC: 84.78 Precision: 90.00 Recall: 78.26
#
# -----svc - Train----------
# AUC: 96.89 Precision: 94.38 Recall: 100.00
#
# -----svc - Validation-----
# AUC: 89.13 Precision: 82.14 Recall: 100.00
#
# -----nusvc - Train----------
# AUC: 99.56 Precision: 99.16 Recall: 100.00
#
# -----nusvc - Validation-----
# AUC: 91.30 Precision: 85.19 Recall: 100.00
#
# Fold 7
#
# -----qda - Train----------
# AUC: 97.17 Precision: 96.64 Recall: 97.87
#
# -----qda - Validation-----
# AUC: 97.83 Precision: 100.00 Recall: 95.65
#
# -----knn - Train----------
# AUC: 84.85 Precision: 80.07 Recall: 94.04
#
# -----knn - Validation-----
# AUC: 77.47 Precision: 72.41 Recall: 91.30
#
# -----mlp - Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----mlp - Validation-----
# AUC: 89.03 Precision: 95.00 Recall: 82.61
#
# -----svc - Train----------
# AUC: 96.68 Precision: 94.00 Recall: 100.00
#
# -----svc - Validation-----
# AUC: 81.82 Precision: 74.19 Recall: 100.00
#
# -----nusvc - Train----------
# AUC: 99.56 Precision: 99.16 Recall: 100.00
#
# -----nusvc - Validation-----
# AUC: 88.64 Precision: 82.14 Recall: 100.00
#
# Fold 8
#
# -----qda - Train----------
# AUC: 97.39 Precision: 97.05 Recall: 97.87
#
# -----qda - Validation-----
# AUC: 93.18 Precision: 88.46 Recall: 100.00
#
# -----knn - Train----------
# AUC: 85.99 Precision: 82.51 Recall: 92.34
#
# -----knn - Validation-----
# AUC: 79.74 Precision: 75.00 Recall: 91.30
#
# -----mlp - Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----mlp - Validation-----
# AUC: 84.39 Precision: 83.33 Recall: 86.96
#
# -----svc - Train----------
# AUC: 97.12 Precision: 94.76 Recall: 100.00
#
# -----svc - Validation-----
# AUC: 72.73 Precision: 65.71 Recall: 100.00
#
# -----nusvc - Train----------
# AUC: 99.34 Precision: 98.74 Recall: 100.00
#
# -----nusvc - Validation-----
# AUC: 81.92 Precision: 75.86 Recall: 95.65
#
# Fold 9
#
# -----qda - Train----------
# AUC: 96.73 Precision: 96.22 Recall: 97.45
#
# -----qda - Validation-----
# AUC: 95.45 Precision: 92.00 Recall: 100.00
#
# -----knn - Train----------
# AUC: 85.09 Precision: 80.81 Recall: 93.19
#
# -----knn - Validation-----
# AUC: 79.84 Precision: 76.92 Recall: 86.96
#
# -----mlp - Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----mlp - Validation-----
# AUC: 77.67 Precision: 76.00 Recall: 82.61
#
# -----svc - Train----------
# AUC: 98.01 Precision: 96.31 Recall: 100.00
#
# -----svc - Validation-----
# AUC: 77.27 Precision: 69.70 Recall: 100.00
#
# -----nusvc - Train----------
# AUC: 99.56 Precision: 99.16 Recall: 100.00
#
# -----nusvc - Validation-----
# AUC: 79.55 Precision: 71.88 Recall: 100.00
#
# Fold 10
#
# -----qda - Train----------
# AUC: 98.04 Precision: 97.88 Recall: 98.30
#
# -----qda - Validation-----
# AUC: 88.64 Precision: 82.14 Recall: 100.00
#
# -----knn - Train----------
# AUC: 84.41 Precision: 79.50 Recall: 94.04
#
# -----knn - Validation-----
# AUC: 70.75 Precision: 66.67 Recall: 86.96
#
# -----mlp - Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----mlp - Validation-----
# AUC: 84.58 Precision: 90.00 Recall: 78.26
#
# -----svc - Train----------
# AUC: 96.24 Precision: 93.25 Recall: 100.00
#
# -----svc - Validation-----
# AUC: 65.91 Precision: 60.53 Recall: 100.00
#
# -----nusvc - Train----------
# AUC: 98.67 Precision: 97.51 Recall: 100.00
#
# -----nusvc - Validation-----
# AUC: 79.55 Precision: 71.88 Recall: 100.00
#
# Fold 11
#
# -----qda - Train----------
# AUC: 96.30 Precision: 95.80 Recall: 97.02
#
# -----qda - Validation-----
# AUC: 93.28 Precision: 91.67 Recall: 95.65
#
# -----knn - Train----------
# AUC: 85.10 Precision: 81.04 Recall: 92.77
#
# -----knn - Validation-----
# AUC: 84.29 Precision: 80.77 Recall: 91.30
#
# -----mlp - Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----mlp - Validation-----
# AUC: 93.18 Precision: 88.46 Recall: 100.00
#
# -----svc - Train----------
# AUC: 96.68 Precision: 94.00 Recall: 100.00
#
# -----svc - Validation-----
# AUC: 75.00 Precision: 67.65 Recall: 100.00
#
# -----nusvc - Train----------
# AUC: 99.56 Precision: 99.16 Recall: 100.00
#
# -----nusvc - Validation-----
# AUC: 81.82 Precision: 74.19 Recall: 100.00
#
# wheezy-copper-turtle-magic 115
#
# Fold 1
#
# -----qda - Train----------
# AUC: 97.27 Precision: 96.85 Recall: 97.73
#
# -----qda - Validation-----
# AUC: 95.55 Precision: 95.45 Recall: 95.45
#
# -----knn - Train----------
# AUC: 86.36 Precision: 91.67 Recall: 80.00
#
# -----knn - Validation-----
# AUC: 82.02 Precision: 88.89 Recall: 72.73
#
# -----mlp - Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----mlp - Validation-----
# AUC: 84.49 Precision: 82.61 Recall: 86.36
#
# -----svc - Train----------
# AUC: 98.86 Precision: 100.00 Recall: 97.73
#
# -----svc - Validation-----
# AUC: 77.27 Precision: 100.00 Recall: 54.55
#
# -----nusvc - Train----------
# AUC: 99.77 Precision: 100.00 Recall: 99.55
#
# -----nusvc - Validation-----
# AUC: 84.19 Precision: 94.12 Recall: 72.73
#
# Fold 2
#
# -----qda - Train----------
# AUC: 97.96 Precision: 97.74 Recall: 98.18
#
# -----qda - Validation-----
# AUC: 90.91 Precision: 84.62 Recall: 100.00
#
# -----knn - Train----------
# AUC: 86.83 Precision: 92.19 Recall: 80.45
#
# -----knn - Validation-----
# AUC: 77.27 Precision: 83.33 Recall: 68.18
#
# -----mlp - Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----mlp - Validation-----
# AUC: 79.55 Precision: 84.21 Recall: 72.73
#
# -----svc - Train----------
# AUC: 98.64 Precision: 100.00 Recall: 97.27
#
# -----svc - Validation-----
# AUC: 81.82 Precision: 88.89 Recall: 72.73
#
# -----nusvc - Train----------
# AUC: 99.77 Precision: 100.00 Recall: 99.55
#
# -----nusvc - Validation-----
# AUC: 84.09 Precision: 89.47 Recall: 77.27
#
# Fold 3
#
# -----qda - Train----------
# AUC: 97.05 Precision: 96.41 Recall: 97.73
#
# -----qda - Validation-----
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----knn - Train----------
# AUC: 88.20 Precision: 92.00 Recall: 83.64
#
# -----knn - Validation-----
# AUC: 84.09 Precision: 89.47 Recall: 77.27
#
# -----mlp - Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----mlp - Validation-----
# AUC: 90.91 Precision: 90.91 Recall: 90.91
#
# -----svc - Train----------
# AUC: 99.09 Precision: 100.00 Recall: 98.18
#
# -----svc - Validation-----
# AUC: 88.64 Precision: 100.00 Recall: 77.27
#
# -----nusvc - Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----nusvc - Validation-----
# AUC: 88.64 Precision: 100.00 Recall: 77.27
#
# Fold 4
#
# -----qda - Train----------
# AUC: 97.05 Precision: 96.00 Recall: 98.18
#
# -----qda - Validation-----
# AUC: 97.73 Precision: 100.00 Recall: 95.45
#
# -----knn - Train----------
# AUC: 85.69 Precision: 93.37 Recall: 76.82
#
# -----knn - Validation-----
# AUC: 77.27 Precision: 87.50 Recall: 63.64
#
# -----mlp - Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----mlp - Validation-----
# AUC: 86.36 Precision: 86.36 Recall: 86.36
#
# -----svc - Train----------
# AUC: 97.05 Precision: 100.00 Recall: 94.09
#
# -----svc - Validation-----
# AUC: 70.45 Precision: 100.00 Recall: 40.91
#
# -----nusvc - Train----------
# AUC: 99.55 Precision: 100.00 Recall: 99.09
#
# -----nusvc - Validation-----
# AUC: 79.55 Precision: 100.00 Recall: 59.09
#
# Fold 5
#
# -----qda - Train----------
# AUC: 97.51 Precision: 96.86 Recall: 98.18
#
# -----qda - Validation-----
# AUC: 90.91 Precision: 90.91 Recall: 90.91
#
# -----knn - Train----------
# AUC: 87.29 Precision: 91.84 Recall: 81.82
#
# -----knn - Validation-----
# AUC: 84.09 Precision: 89.47 Recall: 77.27
#
# -----mlp - Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----mlp - Validation-----
# AUC: 86.36 Precision: 83.33 Recall: 90.91
#
# -----svc - Train----------
# AUC: 98.18 Precision: 100.00 Recall: 96.36
#
# -----svc - Validation-----
# AUC: 63.64 Precision: 87.50 Recall: 31.82
#
# -----nusvc - Train----------
# AUC: 99.55 Precision: 100.00 Recall: 99.09
#
# -----nusvc - Validation-----
# AUC: 72.73 Precision: 85.71 Recall: 54.55
#
# Fold 6
#
# -----qda - Train----------
# AUC: 97.73 Precision: 96.88 Recall: 98.64
#
# -----qda - Validation-----
# AUC: 93.18 Precision: 95.24 Recall: 90.91
#
# -----knn - Train----------
# AUC: 86.38 Precision: 92.55 Recall: 79.09
#
# -----knn - Validation-----
# AUC: 84.09 Precision: 94.12 Recall: 72.73
#
# -----mlp - Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----mlp - Validation-----
# AUC: 84.09 Precision: 85.71 Recall: 81.82
#
# -----svc - Train----------
# AUC: 98.86 Precision: 100.00 Recall: 97.73
#
# -----svc - Validation-----
# AUC: 79.55 Precision: 93.33 Recall: 63.64
#
# -----nusvc - Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----nusvc - Validation-----
# AUC: 79.55 Precision: 93.33 Recall: 63.64
#
# Fold 7
#
# -----qda - Train----------
# AUC: 97.28 Precision: 96.85 Recall: 97.73
#
# -----qda - Validation-----
# AUC: 93.18 Precision: 91.30 Recall: 95.45
#
# -----knn - Train----------
# AUC: 86.83 Precision: 92.19 Recall: 80.45
#
# -----knn - Validation-----
# AUC: 77.27 Precision: 87.50 Recall: 63.64
#
# -----mlp - Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----mlp - Validation-----
# AUC: 77.27 Precision: 77.27 Recall: 77.27
#
# -----svc - Train----------
# AUC: 98.86 Precision: 100.00 Recall: 97.73
#
# -----svc - Validation-----
# AUC: 81.82 Precision: 100.00 Recall: 63.64
#
# -----nusvc - Train----------
# AUC: 99.55 Precision: 100.00 Recall: 99.09
#
# -----nusvc - Validation-----
# AUC: 81.82 Precision: 93.75 Recall: 68.18
#
# Fold 8
#
# -----qda - Train----------
# AUC: 97.28 Precision: 96.02 Recall: 98.64
#
# -----qda - Validation-----
# AUC: 90.91 Precision: 95.00 Recall: 86.36
#
# -----knn - Train----------
# AUC: 86.15 Precision: 90.77 Recall: 80.45
#
# -----knn - Validation-----
# AUC: 88.64 Precision: 94.74 Recall: 81.82
#
# -----mlp - Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----mlp - Validation-----
# AUC: 88.64 Precision: 86.96 Recall: 90.91
#
# -----svc - Train----------
# AUC: 97.95 Precision: 100.00 Recall: 95.91
#
# -----svc - Validation-----
# AUC: 79.55 Precision: 100.00 Recall: 59.09
#
# -----nusvc - Train----------
# AUC: 99.55 Precision: 100.00 Recall: 99.09
#
# -----nusvc - Validation-----
# AUC: 79.55 Precision: 100.00 Recall: 59.09
#
# Fold 9
#
# -----qda - Train----------
# AUC: 97.51 Precision: 96.86 Recall: 98.18
#
# -----qda - Validation-----
# AUC: 93.18 Precision: 88.00 Recall: 100.00
#
# -----knn - Train----------
# AUC: 85.70 Precision: 92.90 Recall: 77.27
#
# -----knn - Validation-----
# AUC: 81.82 Precision: 81.82 Recall: 81.82
#
# -----mlp - Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----mlp - Validation-----
# AUC: 88.64 Precision: 84.00 Recall: 95.45
#
# -----svc - Train----------
# AUC: 98.64 Precision: 100.00 Recall: 97.27
#
# -----svc - Validation-----
# AUC: 81.82 Precision: 93.75 Recall: 68.18
#
# -----nusvc - Train----------
# AUC: 99.77 Precision: 100.00 Recall: 99.55
#
# -----nusvc - Validation-----
# AUC: 86.36 Precision: 94.44 Recall: 77.27
#
# Fold 10
#
# -----qda - Train----------
# AUC: 97.73 Precision: 96.88 Recall: 98.64
#
# -----qda - Validation-----
# AUC: 90.91 Precision: 95.00 Recall: 86.36

# %% [markdown]
# # Ensemble models
#
# Here you can ensemble any combination of models, and give the desired weight for each one.

# %%
train['preds_top2'] = (train['preds_qda'] * 0.5) + (train['preds_nusvc'] * 0.5)
test['target_top2'] = (test['target_qda'] * 0.5) + (test['target_nusvc'] * 0.5)

train['preds_top3'] = (train['preds_qda'] * 0.35) + (train['preds_mlp'] * 0.3) + (train['preds_nusvc'] * 0.35)
test['target_top3'] = (test['target_qda'] * 0.35) + (test['target_mlp'] * 0.3) + (test['target_nusvc'] * 0.35)

train['preds_top4'] = (train['preds_qda'] * 0.25) + (train['preds_mlp'] * 0.25) + (train['preds_svc'] * 0.25) + (train['preds_nusvc'] * 0.25)
test['target_top4'] = (test['target_qda'] * 0.25) + (test['target_mlp'] * 0.25) + (test['target_svc'] * 0.25) + (test['target_nusvc'] * 0.25)

train['preds_avg'] = (train['preds_qda'] * 0.2) + (train['preds_knn'] * 0.2) + (train['preds_mlp'] * 0.2) + (train['preds_svc'] * 0.2) + (train['preds_nusvc'] * 0.2)
test['target_avg'] = (test['target_qda'] * 0.2) + (test['target_knn'] * 0.2) + (test['target_mlp'] * 0.2) + (test['target_svc'] * 0.2) + (test['target_nusvc'] * 0.2)

# %% [markdown]
# # Model evaluation
# ## Confusion matrix (averaged model)

# %%
f = plt.subplots(1, 1, figsize=(16, 5), sharex=True)
train_cnf_matrix = confusion_matrix(train['target'], [np.round(x) for x in train['preds_avg']])
train_cnf_matrix_norm = train_cnf_matrix / train_cnf_matrix.sum(axis=1)[:, np.newaxis]
train_df_cm = pd.DataFrame(train_cnf_matrix_norm, index=[0, 1], columns=[0, 1])
sns.heatmap(train_df_cm, annot=True, fmt='.2f', cmap="Blues")
plt.show()

# %% [markdown]
# ## Confusion matrix (knn model)

# %% [markdown]
# ## Confusion matrix (SVC model)

# %%
f = plt.subplots(1, 1, figsize=(16, 5), sharex=True)
train_cnf_matrix = confusion_matrix(train['target'], [np.round(x) for x in train['preds_svc']])
train_cnf_matrix_norm = train_cnf_matrix / train_cnf_matrix.sum(axis=1)[:, np.newaxis]
train_df_cm = pd.DataFrame(train_cnf_matrix_norm, index=[0, 1], columns=[0, 1])
sns.heatmap(train_df_cm, annot=True, fmt='.2f', cmap="Blues")
plt.show()

# %% [markdown]
# ## Metrics ROC AUC

# %%
print('QDA AUC %.2f' % roc_auc_score(train['target'], train['preds_qda']))
print('KNN AUC %.2f' % roc_auc_score(train['target'], train['preds_knn']))
print('MLP AUC %.2f' % roc_auc_score(train['target'], train['preds_mlp']))
print('SVC AUC %.2f' % roc_auc_score(train['target'], train['preds_svc']))
print('NuSVC AUC %.2f' % roc_auc_score(train['target'], train['preds_nusvc']))
print('Top 2 AUC %.2f' % roc_auc_score(train['target'], train['preds_top2']))
print('Top 3 AUC %.2f' % roc_auc_score(train['target'], train['preds_top3']))
print('Top 4 AUC %.2f' % roc_auc_score(train['target'], train['preds_top4']))
print('Averaged AUC %.2f' % roc_auc_score(train['target'], train['preds_avg']))
# Out:
# QDA AUC 0.99
# KNN AUC 0.95
# MLP AUC 1.00
# SVC AUC 1.00
# NuSVC AUC 1.00
# Top 2 AUC 1.00
# Top 3 AUC 1.00
# Top 4 AUC 1.00
# Averaged AUC 1.00

# %% [markdown]
# ### Test set with all models predictions

# %%
test[['id', 'target_avg', 'target_qda', 'target_knn', 'target_mlp', 'target_svc', 'target_nusvc']].head()
# Out:
#                                  id      ...       target_nusvc
# 0  1c13f2701648e0b0d46d8a2a5a131a53      ...           0.936818
# 1  ba88c155ba898fc8b5099893036ef205      ...           0.505846
# 2  7cbab5cea99169139e7e6d8ff74ebb77      ...           0.115472
# 3  ca820ad57809f62eb7b4d13f5d4371a0      ...           0.717197
# 4  7baaf361537fbd8a1aaa2c97a6d4ccc7      ...           0.154924
#
# [5 rows x 7 columns]

# %% [markdown]
# # Test predictions
# Now you can output predictions for each individual model and the ensembled models as well.
#
# #### Averaged models submission

# %%
submission = test[['id', 'target_avg']]
submission.columns = ['id', 'target']
submission.to_csv('submission_avg.csv', index=False)
submission.head()
# Out:
#                                  id    target
# 0  1c13f2701648e0b0d46d8a2a5a131a53  0.747977
# 1  ba88c155ba898fc8b5099893036ef205  0.717784
# 2  7cbab5cea99169139e7e6d8ff74ebb77  0.161480
# 3  ca820ad57809f62eb7b4d13f5d4371a0  0.450142
# 4  7baaf361537fbd8a1aaa2c97a6d4ccc7  0.231074

# %%
submission = test[['id', 'target_top2']]
submission.columns = ['id', 'target']
submission.to_csv('submission_top2.csv', index=False)
submission.head()
# Out:
#                                  id    target
# 0  1c13f2701648e0b0d46d8a2a5a131a53  0.968387
# 1  ba88c155ba898fc8b5099893036ef205  0.746843
# 2  7cbab5cea99169139e7e6d8ff74ebb77  0.057736
# 3  ca820ad57809f62eb7b4d13f5d4371a0  0.408817
# 4  7baaf361537fbd8a1aaa2c97a6d4ccc7  0.258522

# %%
submission = test[['id', 'target_top3']]
submission.columns = ['id', 'target']
submission.to_csv('submission_top3.csv', index=False)
submission.head()
# Out:
#                                  id    target
# 0  1c13f2701648e0b0d46d8a2a5a131a53  0.807113
# 1  ba88c155ba898fc8b5099893036ef205  0.768963
# 2  7cbab5cea99169139e7e6d8ff74ebb77  0.101433
# 3  ca820ad57809f62eb7b4d13f5d4371a0  0.347698
# 4  7baaf361537fbd8a1aaa2c97a6d4ccc7  0.197675

# %%
submission = test[['id', 'target_top4']]
submission.columns = ['id', 'target']
submission.to_csv('submission_top4.csv', index=False)
submission.head()
# Out:
#                                  id    target
# 0  1c13f2701648e0b0d46d8a2a5a131a53  0.815987
# 1  ba88c155ba898fc8b5099893036ef205  0.719422
# 2  7cbab5cea99169139e7e6d8ff74ebb77  0.117625
# 3  ca820ad57809f62eb7b4d13f5d4371a0  0.431661
# 4  7baaf361537fbd8a1aaa2c97a6d4ccc7  0.191248

# %%
submission = test[['id', 'target_qda']]
submission.columns = ['id', 'target']
submission.to_csv('submission_qda.csv', index=False)
submission.head()
# Out:
#                                  id        target
# 0  1c13f2701648e0b0d46d8a2a5a131a53  9.999560e-01
# 1  ba88c155ba898fc8b5099893036ef205  9.878395e-01
# 2  7cbab5cea99169139e7e6d8ff74ebb77  1.287616e-07
# 3  ca820ad57809f62eb7b4d13f5d4371a0  1.004371e-01
# 4  7baaf361537fbd8a1aaa2c97a6d4ccc7  3.621191e-01

# %%
submission = test[['id', 'target_knn']]
submission.columns = ['id', 'target']
submission.to_csv('submission_knn.csv', index=False)
submission.head()
# Out:
#                                  id    target
# 0  1c13f2701648e0b0d46d8a2a5a131a53  0.475936
# 1  ba88c155ba898fc8b5099893036ef205  0.711230
# 2  7cbab5cea99169139e7e6d8ff74ebb77  0.336898
# 3  ca820ad57809f62eb7b4d13f5d4371a0  0.524064
# 4  7baaf361537fbd8a1aaa2c97a6d4ccc7  0.390374

# %%
submission = test[['id', 'target_mlp']]
submission.columns = ['id', 'target']
submission.to_csv('submission_mlp.csv', index=False)
submission.head()
# Out:
#                                  id    target
# 0  1c13f2701648e0b0d46d8a2a5a131a53  0.430807
# 1  ba88c155ba898fc8b5099893036ef205  0.820578
# 2  7cbab5cea99169139e7e6d8ff74ebb77  0.203393
# 3  ca820ad57809f62eb7b4d13f5d4371a0  0.205088
# 4  7baaf361537fbd8a1aaa2c97a6d4ccc7  0.055699

# %%
submission = test[['id', 'target_svc']]
submission.columns = ['id', 'target']
submission.to_csv('submission_svc.csv', index=False)
submission.head()
# Out:
#                                  id    target
# 0  1c13f2701648e0b0d46d8a2a5a131a53  0.896369
# 1  ba88c155ba898fc8b5099893036ef205  0.563425
# 2  7cbab5cea99169139e7e6d8ff74ebb77  0.151635
# 3  ca820ad57809f62eb7b4d13f5d4371a0  0.703922
# 4  7baaf361537fbd8a1aaa2c97a6d4ccc7  0.192252

# %%
submission = test[['id', 'target_nusvc']]
submission.columns = ['id', 'target']
submission.to_csv('submission_nusvc.csv', index=False)
submission.head()
# Out:
#                                  id    target
# 0  1c13f2701648e0b0d46d8a2a5a131a53  0.936818
# 1  ba88c155ba898fc8b5099893036ef205  0.505846
# 2  7cbab5cea99169139e7e6d8ff74ebb77  0.115472
# 3  ca820ad57809f62eb7b4d13f5d4371a0  0.717197
# 4  7baaf361537fbd8a1aaa2c97a6d4ccc7  0.154924
