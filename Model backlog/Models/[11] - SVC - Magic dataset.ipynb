# %% [markdown]
# # Dependencies

# %%
import warnings
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

from sklearn.svm import SVC
from sklearn.feature_selection import VarianceThreshold
from sklearn.preprocessing import MinMaxScaler, StandardScaler
from sklearn.model_selection import train_test_split, StratifiedKFold
from sklearn.metrics import confusion_matrix, roc_auc_score, recall_score, precision_score

# Set seeds to make the experiment more reproducible.
from numpy.random import seed
seed(0)

# %matplotlib inline
sns.set_style("whitegrid")
warnings.filterwarnings("ignore")

# %% [markdown]
# # Load data

# %%
train = pd.read_csv('../input/train.csv')
test = pd.read_csv('../input/test.csv')
# submission = pd.read_csv('../input/sample_submission.csv')

# %%
print('Train set shape:', train.shape)
print('Test set shape:', test.shape)
print('Train set overview:')
display(train.head())
# Out:
# Train set shape: (262144, 258)
# Test set shape: (131073, 257)
# Train set overview:
#                                  id   ...    target
# 0  707b395ecdcbb4dc2eabea00e4d1b179   ...         0
# 1  5880c03c6582a7b42248668e56b4bdec   ...         0
# 2  4ccbcb3d13e5072ff1d9c61afe2c4f77   ...         1
# 3  e350f17a357f12a1941f0837afb7eb8d   ...         0
# 4  a8f910ea6075b6376af079055965ff68   ...         0
#
# [5 rows x 258 columns]

# %% [markdown]
# ## Preprocess

# %% [markdown]
# # Model
#
# ## Model parameters

# %%
N_FOLDS = 11

# %%
# INITIALIZE VARIABLES
cols = [c for c in train.columns if c not in ['id', 'target', 'wheezy-copper-turtle-magic', 'preds']]
test['target'] = 0
train['preds'] = 0

# BUILD 512 MODELS
for i in range(512):
    print('wheezy-copper-turtle-magic {}\n'.format(i))
    
    # EXTRACT SUBSET OF DATASET WHERE WHEEZY-MAGIC EQUALS I
    train2 = train[train['wheezy-copper-turtle-magic']==i]
    test2 = test[test['wheezy-copper-turtle-magic']==i]
    idx1 = train2.index
    idx2 = test2.index
    train2.reset_index(drop=True, inplace=True)
    
    # FEATURE SELECTION (USE APPROX 40 OF 255 FEATURES)
    sel = VarianceThreshold(threshold=1.5).fit(train2[cols])
    train3 = sel.transform(train2[cols])
    test3 = sel.transform(test2[cols])

    skf = StratifiedKFold(n_splits=N_FOLDS, random_state=0)
    counter = 0

    for train_index, val_index in skf.split(train3, train2['target']):
        counter += 1
        print('Fold {}\n'.format(counter))
        model = SVC(probability=True,kernel='poly',degree=4,gamma='auto')

        model.fit(train3[train_index,:], train2.loc[train_index]['target'])
        
        train_predictions = model.predict(train3[train_index,:])
        val_predictions = model.predict(train3[val_index,:])

        train_auc = roc_auc_score(train2.loc[train_index]['target'], train_predictions) * 100
        val_auc = roc_auc_score(train2.loc[val_index]['target'], val_predictions) * 100
        train_precision = precision_score(train2.loc[train_index]['target'], train_predictions) * 100
        val_precision = precision_score(train2.loc[val_index]['target'], val_predictions) * 100
        train_recall = recall_score(train2.loc[train_index]['target'], train_predictions) * 100
        val_recall = recall_score(train2.loc[val_index]['target'], val_predictions) * 100
        print('-----Train----------')
        print('AUC: %.2f Precision: %.2f Recall: %.2f \n' % (train_auc, train_precision, train_recall))
        print('-----Validation-----')
        print('AUC: %.2f Precision: %.2f Recall: %.2f \n' % (val_auc, val_precision, val_recall))

        # Make predictions
        train['preds'].loc[idx1] += model.predict_proba(train3)[:,1] / N_FOLDS
        test['target'].loc[idx2] += model.predict_proba(test3)[:,1] / N_FOLDS
# Out:
# wheezy-copper-turtle-magic 0
#
# Fold 1
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 83.50 Precision: 90.00 Recall: 75.00
#
# Fold 2
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 71.25 Precision: 75.00 Recall: 62.50
#
# Fold 3
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 87.67 Precision: 90.91 Recall: 83.33
#
# Fold 4
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 79.42 Precision: 85.00 Recall: 70.83
#
# Fold 5
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 91.75 Precision: 95.45 Recall: 87.50
#
# Fold 6
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 93.75 Precision: 100.00 Recall: 87.50
#
# Fold 7
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 81.42 Precision: 89.47 Recall: 70.83
#
# Fold 8
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 91.67 Precision: 95.45 Recall: 87.50
#
# Fold 9
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 89.58 Precision: 95.24 Recall: 83.33
#
# Fold 10
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 79.17 Precision: 93.75 Recall: 62.50
#
# Fold 11
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 89.22 Precision: 95.00 Recall: 82.61
#
# wheezy-copper-turtle-magic 1
#
# Fold 1
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 77.08 Precision: 67.65 Recall: 100.00
#
# Fold 2
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 76.90 Precision: 70.00 Recall: 91.30
#
# Fold 3
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 85.24 Precision: 80.77 Recall: 91.30
#
# Fold 4
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 76.63 Precision: 75.00 Recall: 78.26
#
# Fold 5
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 85.42 Precision: 75.86 Recall: 100.00
#
# Fold 6
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 76.89 Precision: 67.74 Recall: 95.45
#
# Fold 7
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 83.14 Precision: 75.00 Recall: 95.45
#
# Fold 8
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 80.68 Precision: 76.00 Recall: 86.36
#
# Fold 9
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 87.12 Precision: 83.33 Recall: 90.91
#
# Fold 10
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 82.95 Precision: 76.92 Recall: 90.91
#
# Fold 11
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 68.56 Precision: 60.00 Recall: 95.45
#
# wheezy-copper-turtle-magic 2
#
# Fold 1
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 78.26 Precision: 100.00 Recall: 56.52
#
# Fold 2
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 77.47 Precision: 87.50 Recall: 63.64
#
# Fold 3
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 79.74 Precision: 88.24 Recall: 68.18
#
# Fold 4
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 91.01 Precision: 95.00 Recall: 86.36
#
# Fold 5
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 64.03 Precision: 71.43 Recall: 45.45
#
# Fold 6
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 82.02 Precision: 88.89 Recall: 72.73
#
# Fold 7
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 72.92 Precision: 85.71 Recall: 54.55
#
# Fold 8
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 77.37 Precision: 92.86 Recall: 59.09
#
# Fold 9
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 86.36 Precision: 100.00 Recall: 72.73
#
# Fold 10
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 68.28 Precision: 90.00 Recall: 40.91
#
# Fold 11
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 75.00 Precision: 92.31 Recall: 54.55
#
# wheezy-copper-turtle-magic 3
#
# Fold 1
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 77.08 Precision: 70.27 Recall: 100.00
#
# Fold 2
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 83.49 Precision: 78.12 Recall: 96.15
#
# Fold 3
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 83.65 Precision: 80.00 Recall: 92.31
#
# Fold 4
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 77.08 Precision: 70.27 Recall: 100.00
#
# Fold 5
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 76.09 Precision: 70.27 Recall: 100.00
#
# Fold 6
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 78.26 Precision: 72.22 Recall: 100.00
#
# Fold 7
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 84.96 Precision: 80.00 Recall: 96.00
#
# Fold 8
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 89.13 Precision: 83.33 Recall: 100.00
#
# Fold 9
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 76.43 Precision: 71.88 Recall: 92.00
#
# Fold 10
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 91.30 Precision: 86.21 Recall: 100.00
#
# Fold 11
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 65.74 Precision: 62.86 Recall: 88.00
#
# wheezy-copper-turtle-magic 4
#
# Fold 1
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 77.08 Precision: 78.26 Recall: 75.00
#
# Fold 2
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 83.33 Precision: 80.77 Recall: 87.50
#
# Fold 3
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 82.97 Precision: 83.33 Recall: 83.33
#
# Fold 4
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 93.66 Precision: 95.65 Recall: 91.67
#
# Fold 5
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 85.14 Precision: 86.96 Recall: 83.33
#
# Fold 6
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 76.54 Precision: 76.00 Recall: 79.17
#
# Fold 7
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 83.06 Precision: 86.36 Recall: 79.17
#
# Fold 8
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 87.23 Precision: 87.50 Recall: 87.50
#
# Fold 9
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 82.61 Precision: 74.19 Recall: 100.00
#
# Fold 10
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 89.13 Precision: 100.00 Recall: 78.26
#
# Fold 11
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 78.26 Precision: 80.95 Recall: 73.91
#
# wheezy-copper-turtle-magic 5
#
# Fold 1
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 83.33 Precision: 90.00 Recall: 75.00
#
# Fold 2
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 81.25 Precision: 94.12 Recall: 66.67
#
# Fold 3
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 85.42 Precision: 90.48 Recall: 79.17
#
# Fold 4
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 87.50 Precision: 95.00 Recall: 79.17
#
# Fold 5
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 72.92 Precision: 82.35 Recall: 58.33
#
# Fold 6
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 77.08 Precision: 80.95 Recall: 70.83
#
# Fold 7
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 76.27 Precision: 87.50 Recall: 60.87
#
# Fold 8
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 76.18 Precision: 92.86 Recall: 56.52
#
# Fold 9
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 87.14 Precision: 90.48 Recall: 82.61
#
# Fold 10
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 80.43 Precision: 85.00 Recall: 73.91
#
# Fold 11
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 84.78 Precision: 86.36 Recall: 82.61
#
# wheezy-copper-turtle-magic 6
#
# Fold 1
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 82.78 Precision: 77.42 Recall: 96.00
#
# Fold 2
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 87.05 Precision: 82.14 Recall: 95.83
#
# Fold 3
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 82.70 Precision: 76.67 Recall: 95.83
#
# Fold 4
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 78.62 Precision: 76.92 Recall: 83.33
#
# Fold 5
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 89.13 Precision: 82.76 Recall: 100.00
#
# Fold 6
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 80.43 Precision: 72.73 Recall: 100.00
#
# Fold 7
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 89.31 Precision: 88.00 Recall: 91.67
#
# Fold 8
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 76.36 Precision: 72.41 Recall: 87.50
#
# Fold 9
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 82.79 Precision: 78.57 Recall: 91.67
#
# Fold 10
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 82.79 Precision: 78.57 Recall: 91.67
#
# Fold 11
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 71.92 Precision: 66.67 Recall: 91.67
#
# wheezy-copper-turtle-magic 7
#
# Fold 1
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 87.41 Precision: 95.00 Recall: 79.17
#
# Fold 2
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 82.61 Precision: 85.71 Recall: 78.26
#
# Fold 3
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 89.13 Precision: 90.91 Recall: 86.96
#
# Fold 4
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 80.43 Precision: 79.17 Recall: 82.61
#
# Fold 5
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 89.13 Precision: 90.91 Recall: 86.96
#
# Fold 6
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 76.09 Precision: 83.33 Recall: 65.22
#
# Fold 7
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 80.43 Precision: 88.89 Recall: 69.57
#
# Fold 8
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 80.43 Precision: 85.00 Recall: 73.91
#
# Fold 9
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 89.13 Precision: 87.50 Recall: 91.30
#
# Fold 10
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 86.96 Precision: 84.00 Recall: 91.30
#
# Fold 11
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 82.11 Precision: 80.00 Recall: 86.96
#
# wheezy-copper-turtle-magic 8
#
# Fold 1
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 91.83 Precision: 92.00 Recall: 92.00
#
# Fold 2
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 87.67 Precision: 85.19 Recall: 92.00
#
# Fold 3
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 91.83 Precision: 95.65 Recall: 88.00
#
# Fold 4
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 93.57 Precision: 92.00 Recall: 95.83
#
# Fold 5
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 82.97 Precision: 83.33 Recall: 83.33
#
# Fold 6
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 82.88 Precision: 80.77 Recall: 87.50
#
# Fold 7
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 87.05 Precision: 82.14 Recall: 95.83
#
# Fold 8
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 82.88 Precision: 80.77 Recall: 87.50
#
# Fold 9
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 87.14 Precision: 84.62 Recall: 91.67
#
# Fold 10
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 85.14 Precision: 86.96 Recall: 83.33
#
# Fold 11
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 87.32 Precision: 90.91 Recall: 83.33
#
# wheezy-copper-turtle-magic 9
#
# Fold 1
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 81.25 Precision: 72.73 Recall: 100.00
#
# Fold 2
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 79.17 Precision: 71.88 Recall: 95.83
#
# Fold 3
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 75.00 Precision: 68.75 Recall: 91.67
#
# Fold 4
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 83.33 Precision: 76.67 Recall: 95.83
#
# Fold 5
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 89.58 Precision: 82.76 Recall: 100.00
#
# Fold 6
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 81.25 Precision: 72.73 Recall: 100.00
#
# Fold 7
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 72.92 Precision: 67.74 Recall: 87.50
#
# Fold 8
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 87.50 Precision: 84.62 Recall: 91.67
#
# Fold 9
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 85.42 Precision: 79.31 Recall: 95.83
#
# Fold 10
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 68.75 Precision: 62.86 Recall: 91.67
#
# Fold 11
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 89.58 Precision: 82.76 Recall: 100.00
#
# wheezy-copper-turtle-magic 10
#
# Fold 1
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 73.91 Precision: 86.67 Recall: 56.52
#
# Fold 2
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 78.26 Precision: 93.33 Recall: 60.87
#
# Fold 3
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 82.61 Precision: 100.00 Recall: 65.22
#
# Fold 4
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 71.74 Precision: 100.00 Recall: 43.48
#
# Fold 5
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 75.00 Precision: 100.00 Recall: 50.00
#
# Fold 6
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 72.73 Precision: 100.00 Recall: 45.45
#
# Fold 7
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 81.82 Precision: 100.00 Recall: 63.64
#
# Fold 8
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 68.28 Precision: 90.00 Recall: 40.91
#
# Fold 9
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 68.28 Precision: 90.00 Recall: 40.91
#
# Fold 10
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 86.46 Precision: 94.44 Recall: 77.27
#
# Fold 11
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 77.27 Precision: 92.86 Recall: 59.09
#
# wheezy-copper-turtle-magic 11
#
# Fold 1
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 80.14 Precision: 76.00 Recall: 86.36
#
# Fold 2
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 90.68 Precision: 94.74 Recall: 85.71
#
# Fold 3
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 91.10 Precision: 86.96 Recall: 95.24
#
# Fold 4
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 92.86 Precision: 100.00 Recall: 85.71
#
# Fold 5
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 77.02 Precision: 78.95 Recall: 71.43
#
# Fold 6
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 88.51 Precision: 90.00 Recall: 85.71
#
# Fold 7
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 86.13 Precision: 89.47 Recall: 80.95
#
# Fold 8
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 93.06 Precision: 95.00 Recall: 90.48
#
# Fold 9
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 86.15 Precision: 82.61 Recall: 90.48
#
# Fold 10
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 85.93 Precision: 89.47 Recall: 80.95
#
# Fold 11
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 93.07 Precision: 90.91 Recall: 95.24
#
# wheezy-copper-turtle-magic 12
#
# Fold 1
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 82.61 Precision: 77.78 Recall: 91.30
#
# Fold 2
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 84.78 Precision: 80.77 Recall: 91.30
#
# Fold 3
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 89.13 Precision: 84.62 Recall: 95.65
#
# Fold 4
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 86.46 Precision: 81.48 Recall: 95.65
#
# Fold 5
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 75.20 Precision: 70.00 Recall: 91.30
#
# Fold 6
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 70.45 Precision: 63.89 Recall: 100.00
#
# Fold 7
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 82.02 Precision: 77.78 Recall: 91.30
#
# Fold 8
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 75.10 Precision: 68.75 Recall: 95.65
#
# Fold 9
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 73.02 Precision: 68.97 Recall: 86.96
#
# Fold 10
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 84.09 Precision: 82.61 Recall: 86.36
#
# Fold 11
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 79.55 Precision: 72.41 Recall: 95.45
#
# wheezy-copper-turtle-magic 13
#
# Fold 1
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 82.11 Precision: 85.00 Recall: 77.27
#
# Fold 2
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 82.02 Precision: 88.89 Recall: 72.73
#
# Fold 3
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 97.73 Precision: 100.00 Recall: 95.45
#
# Fold 4
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 84.29 Precision: 89.47 Recall: 77.27
#
# Fold 5
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 88.51 Precision: 90.00 Recall: 85.71
#
# Fold 6
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 80.95 Precision: 100.00 Recall: 61.90
#
# Fold 7
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 93.27 Precision: 90.91 Recall: 95.24
#
# Fold 8
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 90.68 Precision: 94.74 Recall: 85.71
#
# Fold 9
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 85.71 Precision: 100.00 Recall: 71.43
#
# Fold 10
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 85.93 Precision: 89.47 Recall: 80.95
#
# Fold 11
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 90.69 Precision: 90.48 Recall: 90.48
#
# wheezy-copper-turtle-magic 14
#
# Fold 1
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 85.71 Precision: 100.00 Recall: 71.43
#
# Fold 2
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 88.39 Precision: 94.44 Recall: 80.95
#
# Fold 3
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 76.49 Precision: 92.31 Recall: 57.14
#
# Fold 4
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 74.40 Precision: 85.71 Recall: 57.14
#
# Fold 5
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 95.24 Precision: 100.00 Recall: 90.48
#
# Fold 6
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 90.89 Precision: 90.48 Recall: 90.48
#
# Fold 7
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 90.89 Precision: 90.48 Recall: 90.48
#
# Fold 8
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 85.92 Precision: 94.12 Recall: 76.19
#
# Fold 9
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 72.50 Precision: 100.00 Recall: 45.00
#
# Fold 10
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 75.98 Precision: 81.25 Recall: 65.00
#
# Fold 11
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 75.33 Precision: 91.67 Recall: 55.00
#
# wheezy-copper-turtle-magic 15
#
# Fold 1
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 89.58 Precision: 91.30 Recall: 87.50
#
# Fold 2
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 87.50 Precision: 95.00 Recall: 79.17
#
# Fold 3
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 87.14 Precision: 84.62 Recall: 91.67
#
# Fold 4
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 87.50 Precision: 100.00 Recall: 75.00
#
# Fold 5
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 83.06 Precision: 86.36 Recall: 79.17
#
# Fold 6
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 85.24 Precision: 90.48 Recall: 79.17
#
# Fold 7
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 87.14 Precision: 84.62 Recall: 91.67
#
# Fold 8
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 85.33 Precision: 94.74 Recall: 75.00
#
# Fold 9
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 84.78 Precision: 86.36 Recall: 82.61
#
# Fold 10
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 73.91 Precision: 78.95 Recall: 65.22
#
# Fold 11
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 86.96 Precision: 90.48 Recall: 82.61
#
# wheezy-copper-turtle-magic 16
#
# Fold 1
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 91.83 Precision: 88.00 Recall: 95.65
#
# Fold 2
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 81.65 Precision: 75.00 Recall: 91.30
#
# Fold 3
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 85.24 Precision: 80.77 Recall: 91.30
#
# Fold 4
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 85.42 Precision: 76.67 Recall: 100.00
#
# Fold 5
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 93.75 Precision: 88.46 Recall: 100.00
#
# Fold 6
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 70.83 Precision: 62.16 Recall: 100.00
#
# Fold 7
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 83.15 Precision: 77.78 Recall: 91.30
#
# Fold 8
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 89.31 Precision: 90.91 Recall: 86.96
#
# Fold 9
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 87.32 Precision: 84.00 Recall: 91.30
#
# Fold 10
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 85.23 Precision: 77.78 Recall: 95.45
#
# Fold 11
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 80.68 Precision: 76.00 Recall: 86.36
#
# wheezy-copper-turtle-magic 17
#
# Fold 1
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 95.65 Precision: 92.31 Recall: 100.00
#
# Fold 2
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 76.63 Precision: 78.26 Recall: 75.00
#
# Fold 3
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 84.87 Precision: 79.31 Recall: 95.83
#
# Fold 4
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 91.49 Precision: 91.67 Recall: 91.67
#
# Fold 5
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 87.41 Precision: 95.00 Recall: 79.17
#
# Fold 6
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 89.22 Precision: 85.19 Recall: 95.83
#
# Fold 7
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 89.40 Precision: 91.30 Recall: 87.50
#
# Fold 8
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 89.02 Precision: 88.00 Recall: 91.67
#
# Fold 9
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 86.93 Precision: 87.50 Recall: 87.50
#
# Fold 10
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 82.21 Precision: 82.61 Recall: 82.61
#
# Fold 11
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 82.51 Precision: 94.12 Recall: 69.57
#
# wheezy-copper-turtle-magic 18
#
# Fold 1
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 79.83 Precision: 94.12 Recall: 64.00
#
# Fold 2
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 83.15 Precision: 90.00 Recall: 75.00
#
# Fold 3
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 80.62 Precision: 75.86 Recall: 91.67
#
# Fold 4
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 91.49 Precision: 91.67 Recall: 91.67
#
# Fold 5
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 87.14 Precision: 84.62 Recall: 91.67
#
# Fold 6
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 95.74 Precision: 95.83 Recall: 95.83
#
# Fold 7
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 87.14 Precision: 84.62 Recall: 91.67
#
# Fold 8
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 85.05 Precision: 84.00 Recall: 87.50
#
# Fold 9
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 89.31 Precision: 88.00 Recall: 91.67
#
# Fold 10
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 91.49 Precision: 91.67 Recall: 91.67
#
# Fold 11
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 91.49 Precision: 91.67 Recall: 91.67
#
# wheezy-copper-turtle-magic 19
#
# Fold 1
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 89.75 Precision: 88.46 Recall: 92.00
#
# Fold 2
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 87.50 Precision: 82.14 Recall: 95.83
#
# Fold 3
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 85.42 Precision: 84.00 Recall: 87.50
#
# Fold 4
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 83.33 Precision: 78.57 Recall: 91.67
#
# Fold 5
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 83.33 Precision: 78.57 Recall: 91.67
#
# Fold 6
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 75.00 Precision: 66.67 Recall: 100.00
#
# Fold 7
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 95.83 Precision: 95.83 Recall: 95.83
#
# Fold 8
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 77.08 Precision: 68.57 Recall: 100.00
#
# Fold 9
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 89.31 Precision: 88.00 Recall: 91.67
#
# Fold 10
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 89.40 Precision: 91.30 Recall: 87.50
#
# Fold 11
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 85.14 Precision: 86.96 Recall: 83.33
#
# wheezy-copper-turtle-magic 20
#
# Fold 1
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 71.74 Precision: 100.00 Recall: 43.48
#
# Fold 2
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 89.30 Precision: 95.00 Recall: 82.61
#
# Fold 3
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 84.78 Precision: 100.00 Recall: 69.57
#
# Fold 4
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 82.70 Precision: 94.12 Recall: 69.57
#
# Fold 5
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 81.82 Precision: 100.00 Recall: 63.64
#
# Fold 6
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 81.82 Precision: 100.00 Recall: 63.64
#
# Fold 7
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 73.11 Precision: 85.71 Recall: 54.55
#
# Fold 8
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 77.46 Precision: 92.86 Recall: 59.09
#
# Fold 9
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 68.75 Precision: 78.57 Recall: 50.00
#
# Fold 10
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 84.09 Precision: 100.00 Recall: 68.18
#
# Fold 11
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 79.73 Precision: 93.33 Recall: 63.64
#
# wheezy-copper-turtle-magic 21
#
# Fold 1
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 79.42 Precision: 75.86 Recall: 88.00
#
# Fold 2
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 79.58 Precision: 80.00 Recall: 80.00
#
# Fold 3
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 81.75 Precision: 86.36 Recall: 76.00
#
# Fold 4
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 69.00 Precision: 64.71 Recall: 88.00
#
# Fold 5
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 79.25 Precision: 72.73 Recall: 96.00
#
# Fold 6
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 77.08 Precision: 69.44 Recall: 100.00
#
# Fold 7
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 68.75 Precision: 62.86 Recall: 91.67
#
# Fold 8
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 85.42 Precision: 81.48 Recall: 91.67
#
# Fold 9
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 79.17 Precision: 71.88 Recall: 95.83
#
# Fold 10
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 76.27 Precision: 70.97 Recall: 91.67
#
# Fold 11
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 78.53 Precision: 75.00 Recall: 87.50
#
# wheezy-copper-turtle-magic 22
#
# Fold 1
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 94.07 Precision: 96.00 Recall: 92.31
#
# Fold 2
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 87.50 Precision: 81.25 Recall: 100.00
#
# Fold 3
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 73.08 Precision: 67.65 Recall: 92.00
#
# Fold 4
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 75.08 Precision: 68.57 Recall: 96.00
#
# Fold 5
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 83.42 Precision: 77.42 Recall: 96.00
#
# Fold 6
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 87.58 Precision: 82.76 Recall: 96.00
#
# Fold 7
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 89.58 Precision: 83.33 Recall: 100.00
#
# Fold 8
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 80.61 Precision: 75.00 Recall: 96.00
#
# Fold 9
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 78.43 Precision: 72.73 Recall: 96.00
#
# Fold 10
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 89.48 Precision: 88.46 Recall: 92.00
#
# Fold 11
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 91.48 Precision: 88.89 Recall: 96.00
#
# wheezy-copper-turtle-magic 23
#
# Fold 1
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 91.92 Precision: 95.65 Recall: 88.00
#
# Fold 2
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 79.92 Precision: 94.12 Recall: 64.00
#
# Fold 3
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 93.75 Precision: 95.65 Recall: 91.67
#
# Fold 4
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 89.22 Precision: 85.19 Recall: 95.83
#
# Fold 5
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 81.07 Precision: 89.47 Recall: 70.83
#
# Fold 6
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 89.40 Precision: 91.30 Recall: 87.50
#
# Fold 7
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 79.08 Precision: 93.75 Recall: 62.50
#
# Fold 8
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 83.33 Precision: 100.00 Recall: 66.67
#
# Fold 9
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 89.49 Precision: 95.24 Recall: 83.33
#
# Fold 10
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 93.75 Precision: 100.00 Recall: 87.50
#
# Fold 11
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 91.58 Precision: 95.45 Recall: 87.50
#
# wheezy-copper-turtle-magic 24
#
# Fold 1
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 87.12 Precision: 83.33 Recall: 90.91
#
# Fold 2
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 76.52 Precision: 70.37 Recall: 86.36
#
# Fold 3
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 76.19 Precision: 69.23 Recall: 85.71
#
# Fold 4
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 80.06 Precision: 77.27 Recall: 80.95
#
# Fold 5
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 84.23 Precision: 85.00 Recall: 80.95
#
# Fold 6
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 84.23 Precision: 85.00 Recall: 80.95
#
# Fold 7
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 86.01 Precision: 94.12 Recall: 76.19
#
# Fold 8
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 86.61 Precision: 85.71 Recall: 85.71
#
# Fold 9
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 91.37 Precision: 86.96 Recall: 95.24
#
# Fold 10
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 88.72 Precision: 86.36 Recall: 90.48
#
# Fold 11
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 90.68 Precision: 94.74 Recall: 85.71
#
# wheezy-copper-turtle-magic 25
#
# Fold 1
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 84.47 Precision: 89.47 Recall: 77.27
#
# Fold 2
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 89.02 Precision: 90.48 Recall: 86.36
#
# Fold 3
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 80.06 Precision: 77.27 Recall: 80.95
#
# Fold 4
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 88.69 Precision: 90.00 Recall: 85.71
#
# Fold 5
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 91.37 Precision: 86.96 Recall: 95.24
#
# Fold 6
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 95.45 Precision: 95.24 Recall: 95.24
#
# Fold 7
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 95.24 Precision: 100.00 Recall: 90.48
#
# Fold 8
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 93.48 Precision: 87.50 Recall: 100.00
#
# Fold 9
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 83.95 Precision: 85.00 Recall: 80.95
#
# Fold 10
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 78.78 Precision: 92.86 Recall: 61.90
#
# Fold 11
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 88.72 Precision: 86.36 Recall: 90.48
#
# wheezy-copper-turtle-magic 26
#
# Fold 1
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 90.91 Precision: 100.00 Recall: 81.82
#
# Fold 2
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 77.47 Precision: 87.50 Recall: 63.64
#
# Fold 3
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 84.49 Precision: 82.61 Recall: 86.36
#
# Fold 4
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 75.40 Precision: 78.95 Recall: 68.18
#
# Fold 5
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 91.21 Precision: 87.50 Recall: 95.45
#
# Fold 6
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 77.23 Precision: 76.19 Recall: 76.19
#
# Fold 7
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 84.58 Precision: 76.92 Recall: 95.24
#
# Fold 8
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 77.02 Precision: 78.95 Recall: 71.43
#
# Fold 9
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 85.71 Precision: 100.00 Recall: 71.43
#
# Fold 10
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 88.51 Precision: 90.00 Recall: 85.71
#
# Fold 11
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 81.99 Precision: 78.26 Recall: 85.71
#
# wheezy-copper-turtle-magic 27
#
# Fold 1
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 88.91 Precision: 94.74 Recall: 81.82
#
# Fold 2
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 69.18 Precision: 61.29 Recall: 86.36
#
# Fold 3
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 76.70 Precision: 68.97 Recall: 90.91
#
# Fold 4
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 87.31 Precision: 80.77 Recall: 95.45
#
# Fold 5
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 80.49 Precision: 78.26 Recall: 81.82
#
# Fold 6
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 82.77 Precision: 79.17 Recall: 86.36
#
# Fold 7
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 95.83 Precision: 91.67 Recall: 100.00
#
# Fold 8
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 93.75 Precision: 87.50 Recall: 100.00
#
# Fold 9
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 80.65 Precision: 73.08 Recall: 90.48
#
# Fold 10
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 84.82 Precision: 79.17 Recall: 90.48
#
# Fold 11
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 84.23 Precision: 85.00 Recall: 80.95
#
# wheezy-copper-turtle-magic 28
#
# Fold 1
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 82.00 Precision: 83.33 Recall: 80.00
#
# Fold 2
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 88.00 Precision: 91.30 Recall: 84.00
#
# Fold 3
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 76.00 Precision: 76.00 Recall: 76.00
#
# Fold 4
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 92.00 Precision: 88.89 Recall: 96.00
#
# Fold 5
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 91.75 Precision: 88.89 Recall: 96.00
#
# Fold 6
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 91.67 Precision: 95.45 Recall: 87.50
#
# Fold 7
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 79.17 Precision: 79.17 Recall: 79.17
#
# Fold 8
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 89.58 Precision: 95.24 Recall: 83.33
#
# Fold 9
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 91.67 Precision: 95.45 Recall: 87.50
#
# Fold 10
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 91.67 Precision: 88.46 Recall: 95.83
#
# Fold 11
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 87.50 Precision: 95.00 Recall: 79.17
#
# wheezy-copper-turtle-magic 29
#
# Fold 1
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 89.13 Precision: 87.50 Recall: 91.30
#
# Fold 2
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 84.78 Precision: 76.67 Recall: 100.00
#
# Fold 3
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 84.78 Precision: 80.77 Recall: 91.30
#
# Fold 4
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 84.78 Precision: 76.67 Recall: 100.00
#
# Fold 5
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 71.74 Precision: 64.71 Recall: 95.65
#
# Fold 6
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 86.96 Precision: 79.31 Recall: 100.00
#
# Fold 7
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 79.64 Precision: 73.33 Recall: 95.65
#
# Fold 8
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 86.36 Precision: 79.31 Recall: 100.00
#
# Fold 9
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 90.91 Precision: 84.62 Recall: 100.00
#
# Fold 10
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 77.27 Precision: 68.75 Recall: 100.00
#
# Fold 11
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 84.09 Precision: 75.86 Recall: 100.00
#
# wheezy-copper-turtle-magic 30
#
# Fold 1
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 80.61 Precision: 75.00 Recall: 96.00
#
# Fold 2
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 87.48 Precision: 88.00 Recall: 88.00
#
# Fold 3
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# ...
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 74.60 Precision: 72.41 Recall: 91.30
#
# wheezy-copper-turtle-magic 502
#
# Fold 1
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 87.67 Precision: 90.91 Recall: 83.33
#
# Fold 2
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 78.00 Precision: 68.57 Recall: 100.00
#
# Fold 3
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 87.50 Precision: 90.91 Recall: 83.33
#
# Fold 4
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 87.50 Precision: 80.00 Recall: 100.00
#
# Fold 5
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 91.67 Precision: 88.46 Recall: 95.83
#
# Fold 6
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 83.06 Precision: 80.00 Recall: 86.96
#
# Fold 7
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 74.82 Precision: 67.74 Recall: 91.30
#
# Fold 8
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 85.24 Precision: 80.77 Recall: 91.30
#
# Fold 9
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 74.91 Precision: 66.67 Recall: 95.65
#
# Fold 10
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 80.98 Precision: 76.92 Recall: 86.96
#
# Fold 11
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 87.32 Precision: 84.00 Recall: 91.30
#
# wheezy-copper-turtle-magic 503
#
# Fold 1
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 82.02 Precision: 88.89 Recall: 72.73
#
# Fold 2
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 81.82 Precision: 100.00 Recall: 63.64
#
# Fold 3
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 90.91 Precision: 100.00 Recall: 81.82
#
# Fold 4
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 84.39 Precision: 85.71 Recall: 81.82
#
# Fold 5
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 77.57 Precision: 83.33 Recall: 68.18
#
# Fold 6
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 78.78 Precision: 92.86 Recall: 61.90
#
# Fold 7
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 83.55 Precision: 88.89 Recall: 76.19
#
# Fold 8
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 78.79 Precision: 87.50 Recall: 66.67
#
# Fold 9
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 78.79 Precision: 87.50 Recall: 66.67
#
# Fold 10
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 83.55 Precision: 88.89 Recall: 76.19
#
# Fold 11
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 90.58 Precision: 94.74 Recall: 85.71
#
# wheezy-copper-turtle-magic 504
#
# Fold 1
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 80.80 Precision: 80.00 Recall: 83.33
#
# Fold 2
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 72.01 Precision: 67.74 Recall: 87.50
#
# Fold 3
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 83.06 Precision: 86.36 Recall: 79.17
#
# Fold 4
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 88.83 Precision: 85.19 Recall: 95.83
#
# Fold 5
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 84.47 Precision: 81.48 Recall: 91.67
#
# Fold 6
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 80.30 Precision: 80.00 Recall: 83.33
#
# Fold 7
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 93.37 Precision: 92.00 Recall: 95.83
#
# Fold 8
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 82.41 Precision: 89.47 Recall: 73.91
#
# Fold 9
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 75.20 Precision: 70.00 Recall: 91.30
#
# Fold 10
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 86.86 Precision: 94.74 Recall: 78.26
#
# Fold 11
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 79.64 Precision: 73.33 Recall: 95.65
#
# wheezy-copper-turtle-magic 505
#
# Fold 1
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 97.92 Precision: 100.00 Recall: 95.83
#
# Fold 2
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 87.23 Precision: 86.96 Recall: 86.96
#
# Fold 3
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 72.01 Precision: 81.25 Recall: 56.52
#
# Fold 4
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 89.22 Precision: 95.00 Recall: 82.61
#
# Fold 5
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 89.31 Precision: 90.91 Recall: 86.96
#
# Fold 6
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 83.06 Precision: 80.00 Recall: 86.96
#
# Fold 7
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 80.71 Precision: 85.00 Recall: 73.91
#
# Fold 8
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 67.84 Precision: 72.22 Recall: 56.52
#
# Fold 9
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 84.78 Precision: 83.33 Recall: 86.96
#
# Fold 10
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 84.78 Precision: 90.00 Recall: 78.26
#
# Fold 11
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 89.13 Precision: 95.00 Recall: 82.61
#
# wheezy-copper-turtle-magic 506
#
# Fold 1
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 96.00 Precision: 92.59 Recall: 100.00
#
# Fold 2
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 80.00 Precision: 72.73 Recall: 96.00
#
# Fold 3
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 81.83 Precision: 75.86 Recall: 91.67
#
# Fold 4
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 81.25 Precision: 75.86 Recall: 91.67
#
# Fold 5
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 81.25 Precision: 77.78 Recall: 87.50
#
# Fold 6
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 83.33 Precision: 80.77 Recall: 87.50
#
# Fold 7
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 77.08 Precision: 72.41 Recall: 87.50
#
# Fold 8
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 95.83 Precision: 100.00 Recall: 91.67
#
# Fold 9
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 87.50 Precision: 82.14 Recall: 95.83
#
# Fold 10
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 89.58 Precision: 85.19 Recall: 95.83
#
# Fold 11
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 77.08 Precision: 72.41 Recall: 87.50
#
# wheezy-copper-turtle-magic 507
#
# Fold 1
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 89.30 Precision: 95.00 Recall: 82.61
#
# Fold 2
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 87.30 Precision: 90.48 Recall: 82.61
#
# Fold 3
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 82.78 Precision: 94.12 Recall: 69.57
#
# Fold 4
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 84.78 Precision: 100.00 Recall: 69.57
#
# Fold 5
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 89.30 Precision: 95.00 Recall: 82.61
#
# Fold 6
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 89.30 Precision: 95.00 Recall: 82.61
#
# Fold 7
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 84.36 Precision: 94.12 Recall: 72.73
#
# Fold 8
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 95.64 Precision: 95.45 Recall: 95.45
#
# Fold 9
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 86.74 Precision: 90.00 Recall: 81.82
#
# Fold 10
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 84.47 Precision: 89.47 Recall: 77.27
#
# Fold 11
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 82.77 Precision: 79.17 Recall: 86.36
#
# wheezy-copper-turtle-magic 508
#
# Fold 1
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 81.25 Precision: 94.12 Recall: 66.67
#
# Fold 2
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 77.08 Precision: 84.21 Recall: 66.67
#
# Fold 3
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 85.42 Precision: 90.48 Recall: 79.17
#
# Fold 4
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 83.33 Precision: 90.00 Recall: 75.00
#
# Fold 5
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 75.00 Precision: 83.33 Recall: 62.50
#
# Fold 6
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 83.33 Precision: 94.44 Recall: 70.83
#
# Fold 7
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 83.33 Precision: 90.00 Recall: 75.00
#
# Fold 8
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 85.42 Precision: 90.48 Recall: 79.17
#
# Fold 9
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 73.91 Precision: 92.31 Recall: 52.17
#
# Fold 10
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 78.26 Precision: 88.24 Recall: 65.22
#
# Fold 11
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 80.43 Precision: 85.00 Recall: 73.91
#
# wheezy-copper-turtle-magic 509
#
# Fold 1
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 74.09 Precision: 86.67 Recall: 56.52
#
# Fold 2
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 84.87 Precision: 94.44 Recall: 73.91
#
# Fold 3
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 71.74 Precision: 81.25 Recall: 56.52
#
# Fold 4
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 84.78 Precision: 100.00 Recall: 69.57
#
# Fold 5
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 84.19 Precision: 94.12 Recall: 72.73
#
# Fold 6
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 81.92 Precision: 93.75 Recall: 68.18
#
# Fold 7
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 75.00 Precision: 100.00 Recall: 50.00
#
# Fold 8
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 82.02 Precision: 88.89 Recall: 72.73
#
# Fold 9
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 72.83 Precision: 91.67 Recall: 50.00
#
# Fold 10
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 75.20 Precision: 86.67 Recall: 59.09
#
# Fold 11
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 73.12 Precision: 77.78 Recall: 63.64
#
# wheezy-copper-turtle-magic 510
#
# Fold 1
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 87.05 Precision: 94.74 Recall: 78.26
#
# Fold 2
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 86.96 Precision: 100.00 Recall: 73.91
#
# Fold 3
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 87.14 Precision: 90.48 Recall: 82.61
#
# Fold 4
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 80.53 Precision: 93.75 Recall: 65.22
#
# Fold 5
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 78.35 Precision: 93.33 Recall: 60.87
#
# Fold 6
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 93.57 Precision: 95.45 Recall: 91.30
#
# Fold 7
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 83.06 Precision: 80.00 Recall: 86.96
#
# Fold 8
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 74.00 Precision: 92.31 Recall: 52.17
#
# Fold 9
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 80.71 Precision: 85.00 Recall: 73.91
#
# Fold 10
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 84.96 Precision: 90.00 Recall: 78.26
#
# Fold 11
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 84.09 Precision: 100.00 Recall: 68.18
#
# wheezy-copper-turtle-magic 511
#
# Fold 1
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 83.06 Precision: 86.36 Recall: 79.17
#
# Fold 2
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 89.13 Precision: 82.76 Recall: 100.00
#
# Fold 3
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 89.20 Precision: 91.30 Recall: 87.50
#
# Fold 4
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 84.85 Precision: 86.96 Recall: 83.33
#
# Fold 5
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 82.20 Precision: 78.57 Recall: 91.67
#
# Fold 6
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 81.82 Precision: 74.19 Recall: 100.00
#
# Fold 7
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 82.02 Precision: 77.78 Recall: 91.30
#
# Fold 8
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 82.31 Precision: 85.71 Recall: 78.26
#
# Fold 9
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 70.85 Precision: 67.86 Recall: 82.61
#
# Fold 10
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 80.14 Precision: 85.00 Recall: 73.91
#
# Fold 11
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 88.74 Precision: 84.62 Recall: 95.65

# %% [markdown]
# # Model evaluation
# ## Confusion matrix

# %%
f = plt.subplots(1, 1, figsize=(16, 5), sharex=True)
train_cnf_matrix = confusion_matrix(train['target'], [np.round(x) for x in train['preds']])
train_cnf_matrix_norm = train_cnf_matrix / train_cnf_matrix.sum(axis=1)[:, np.newaxis]
train_df_cm = pd.DataFrame(train_cnf_matrix_norm, index=[0, 1], columns=[0, 1])
sns.heatmap(train_df_cm, annot=True, fmt='.2f', cmap="Blues")
plt.show()

# %% [markdown]
# ## Metrics ROC AUC

# %%
print('AUC %.2f' % roc_auc_score(train['target'], train['preds']))
# Out:
# AUC 1.00

# %% [markdown]
# # Test predictions

# %%
submission = test[['id', 'target']]
submission.to_csv('submission.csv', index=False)
submission.head(10)
# Out:
#                                  id    target
# 0  1c13f2701648e0b0d46d8a2a5a131a53  0.774347
# 1  ba88c155ba898fc8b5099893036ef205  0.623124
# 2  7cbab5cea99169139e7e6d8ff74ebb77  0.348646
# 3  ca820ad57809f62eb7b4d13f5d4371a0  0.611856
# 4  7baaf361537fbd8a1aaa2c97a6d4ccc7  0.311326
# 5  8b3116e5e3e92e971dac305d1a093bf6  0.002189
# 6  35cfd7cab9bfa29bc963d1b8c94dd280  0.065287
# 7  83cf532df8ff4642a3e33a70fffdac37  0.917606
# 8  2e1350fe94ec9f2220bec5245e5e9265  0.632835
# 9  e62020afa72eb54a15725473e3a8475b  0.183589
