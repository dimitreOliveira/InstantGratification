# %% [markdown]
# # Dependencies

# %%
import warnings
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

from sklearn.svm import SVC, NuSVC
from sklearn.neural_network import MLPClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.discriminant_analysis import QuadraticDiscriminantAnalysis
from sklearn.feature_selection import VarianceThreshold
from sklearn.preprocessing import MinMaxScaler, StandardScaler
from sklearn.model_selection import train_test_split, StratifiedKFold
from sklearn.metrics import confusion_matrix, roc_auc_score, recall_score, precision_score

# Set seeds to make the experiment more reproducible.
from numpy.random import seed
seed(0)

# %matplotlib inline
sns.set_style("whitegrid")
warnings.filterwarnings("ignore")

# %% [markdown]
# # Load data

# %%
train = pd.read_csv('../input/train.csv')
test = pd.read_csv('../input/test.csv')

print('Train set shape:', train.shape)
print('Test set shape:', test.shape)
print('Train set overview:')
display(train.head())
# Out:
# Train set shape: (262144, 258)
# Test set shape: (131073, 257)
# Train set overview:
#                                  id   ...    target
# 0  707b395ecdcbb4dc2eabea00e4d1b179   ...         0
# 1  5880c03c6582a7b42248668e56b4bdec   ...         0
# 2  4ccbcb3d13e5072ff1d9c61afe2c4f77   ...         1
# 3  e350f17a357f12a1941f0837afb7eb8d   ...         0
# 4  a8f910ea6075b6376af079055965ff68   ...         0
#
# [5 rows x 258 columns]

# %% [markdown]
# # Model
#
# ## Model parameters

# %%
N_FOLDS = 11

# %% [markdown]
# ### You can find evaluation metrics for each model on each fold below on this cell output log. (It's hidden to keep the code clean)

# %%
# INITIALIZE VARIABLES
cols = [c for c in train.columns if c not in ['id', 'target', 'wheezy-copper-turtle-magic', 'preds']]
test['target_qda'] = 0
train['preds_qda'] = 0
test['target_knn'] = 0
train['preds_knn'] = 0
test['target_mlp'] = 0
train['preds_mlp'] = 0
test['target_svc'] = 0
train['preds_svc'] = 0
test['target_nusvc'] = 0
train['preds_nusvc'] = 0

# BUILD 512 MODELS
for i in range(512):
    print('wheezy-copper-turtle-magic {}\n'.format(i))
    
    # EXTRACT SUBSET OF DATASET WHERE WHEEZY-MAGIC EQUALS I
    train2 = train[train['wheezy-copper-turtle-magic']==i]
    test2 = test[test['wheezy-copper-turtle-magic']==i]
    idx1 = train2.index
    idx2 = test2.index
    train2.reset_index(drop=True, inplace=True)
    
    # FEATURE SELECTION (USE APPROX 40 OF 255 FEATURES)
    sel = VarianceThreshold(threshold=1.5).fit(train2[cols])
    train3 = sel.transform(train2[cols])
    test3 = sel.transform(test2[cols])
    scaler = StandardScaler().fit(train3)
    train3 = scaler.transform(train3)
    test3 = scaler.transform(test3)

    skf = StratifiedKFold(n_splits=N_FOLDS, random_state=0)
    counter = 0

    for train_index, val_index in skf.split(train3, train2['target']):
        counter += 1
        print('Fold {}\n'.format(counter))
        model_names = ['qda', 'knn', 'mlp', 'svc', 'nusvc']
        models = [QuadraticDiscriminantAnalysis(), KNeighborsClassifier(n_neighbors=17, p=2.9), MLPClassifier(), 
                  SVC(probability=True, kernel='poly', degree=4, gamma='auto', random_state=4), 
                  NuSVC(probability=True, kernel='poly', degree=4, gamma='auto', random_state=4)]
        
        for i in range(len(model_names)):
            model = models[i]
            model_name = model_names[i]
            model.fit(train3[train_index,:], train2.loc[train_index]['target'])

            train_predictions = model.predict(train3[train_index,:])
            val_predictions = model.predict(train3[val_index,:])

            train_auc = roc_auc_score(train2.loc[train_index]['target'], train_predictions) * 100
            val_auc = roc_auc_score(train2.loc[val_index]['target'], val_predictions) * 100
            train_precision = precision_score(train2.loc[train_index]['target'], train_predictions) * 100
            val_precision = precision_score(train2.loc[val_index]['target'], val_predictions) * 100
            train_recall = recall_score(train2.loc[train_index]['target'], train_predictions) * 100
            val_recall = recall_score(train2.loc[val_index]['target'], val_predictions) * 100
            print('-----%s - Train----------' % model_name)
            print('AUC: %.2f Precision: %.2f Recall: %.2f \n' % (train_auc, train_precision, train_recall))
            print('-----%s - Validation-----' % model_name)
            print('AUC: %.2f Precision: %.2f Recall: %.2f \n' % (val_auc, val_precision, val_recall))

            # Make predictions
            train[('preds_%s' % model_name)].loc[idx1] += model.predict_proba(train3)[:,1] / N_FOLDS
            test[('target_%s' % model_name)].loc[idx2] += model.predict_proba(test3)[:,1] / N_FOLDS
# Out:
# wheezy-copper-turtle-magic 0
#
# Fold 1
#
# -----qda - Train----------
# AUC: 97.32 Precision: 97.48 Recall: 97.07
#
# -----qda - Validation-----
# AUC: 81.58 Precision: 82.61 Recall: 79.17
#
# -----knn - Train----------
# AUC: 89.44 Precision: 91.59 Recall: 86.61
#
# -----knn - Validation-----
# AUC: 79.50 Precision: 81.82 Recall: 75.00
#
# -----mlp - Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----mlp - Validation-----
# AUC: 81.58 Precision: 82.61 Recall: 79.17
#
# -----svc - Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----svc - Validation-----
# AUC: 85.83 Precision: 81.48 Recall: 91.67
#
# -----nusvc - Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----nusvc - Validation-----
# AUC: 87.83 Precision: 84.62 Recall: 91.67
#
# Fold 2
#
# -----qda - Train----------
# AUC: 96.90 Precision: 97.06 Recall: 96.65
#
# -----qda - Validation-----
# AUC: 87.75 Precision: 87.50 Recall: 87.50
#
# -----knn - Train----------
# AUC: 87.34 Precision: 91.98 Recall: 81.59
#
# -----knn - Validation-----
# AUC: 83.42 Precision: 94.44 Recall: 70.83
#
# -----mlp - Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----mlp - Validation-----
# AUC: 87.75 Precision: 87.50 Recall: 87.50
#
# -----svc - Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----svc - Validation-----
# AUC: 81.42 Precision: 89.47 Recall: 70.83
#
# -----nusvc - Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----nusvc - Validation-----
# AUC: 83.50 Precision: 90.00 Recall: 75.00
#
# Fold 3
#
# -----qda - Train----------
# AUC: 97.12 Precision: 96.68 Recall: 97.49
#
# -----qda - Validation-----
# AUC: 95.92 Precision: 95.83 Recall: 95.83
#
# -----knn - Train----------
# AUC: 88.61 Precision: 91.07 Recall: 85.36
#
# -----knn - Validation-----
# AUC: 85.58 Precision: 90.48 Recall: 79.17
#
# -----mlp - Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----mlp - Validation-----
# AUC: 85.92 Precision: 79.31 Recall: 95.83
#
# -----svc - Train----------
# AUC: 99.80 Precision: 99.58 Recall: 100.00
#
# -----svc - Validation-----
# AUC: 83.75 Precision: 80.77 Recall: 87.50
#
# -----nusvc - Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----nusvc - Validation-----
# AUC: 89.75 Precision: 91.30 Recall: 87.50
#
# Fold 4
#
# -----qda - Train----------
# AUC: 96.91 Precision: 96.67 Recall: 97.07
#
# -----qda - Validation-----
# AUC: 95.92 Precision: 95.83 Recall: 95.83
#
# -----knn - Train----------
# AUC: 86.50 Precision: 92.23 Recall: 79.50
#
# -----knn - Validation-----
# AUC: 77.42 Precision: 80.95 Recall: 70.83
#
# -----mlp - Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----mlp - Validation-----
# AUC: 81.67 Precision: 80.00 Recall: 83.33
#
# -----svc - Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----svc - Validation-----
# AUC: 87.67 Precision: 90.91 Recall: 83.33
#
# -----nusvc - Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----nusvc - Validation-----
# AUC: 83.50 Precision: 90.00 Recall: 75.00
#
# Fold 5
#
# -----qda - Train----------
# AUC: 96.90 Precision: 97.06 Recall: 96.65
#
# -----qda - Validation-----
# AUC: 95.83 Precision: 100.00 Recall: 91.67
#
# -----knn - Train----------
# AUC: 88.20 Precision: 90.62 Recall: 84.94
#
# -----knn - Validation-----
# AUC: 85.67 Precision: 86.96 Recall: 83.33
#
# -----mlp - Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----mlp - Validation-----
# AUC: 83.58 Precision: 86.36 Recall: 79.17
#
# -----svc - Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----svc - Validation-----
# AUC: 91.75 Precision: 95.45 Recall: 87.50
#
# -----nusvc - Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----nusvc - Validation-----
# AUC: 93.83 Precision: 95.65 Recall: 91.67
#
# Fold 6
#
# -----qda - Train----------
# AUC: 96.71 Precision: 96.27 Recall: 97.07
#
# -----qda - Validation-----
# AUC: 97.92 Precision: 100.00 Recall: 95.83
#
# -----knn - Train----------
# AUC: 87.78 Precision: 90.54 Recall: 84.10
#
# -----knn - Validation-----
# AUC: 93.75 Precision: 100.00 Recall: 87.50
#
# -----mlp - Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----mlp - Validation-----
# AUC: 89.67 Precision: 95.24 Recall: 83.33
#
# -----svc - Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----svc - Validation-----
# AUC: 91.67 Precision: 100.00 Recall: 83.33
#
# -----nusvc - Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----nusvc - Validation-----
# AUC: 93.75 Precision: 100.00 Recall: 87.50
#
# Fold 7
#
# -----qda - Train----------
# AUC: 97.12 Precision: 96.68 Recall: 97.49
#
# -----qda - Validation-----
# AUC: 95.92 Precision: 95.83 Recall: 95.83
#
# -----knn - Train----------
# AUC: 87.56 Precision: 91.24 Recall: 82.85
#
# -----knn - Validation-----
# AUC: 79.67 Precision: 76.92 Recall: 83.33
#
# -----mlp - Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----mlp - Validation-----
# AUC: 87.75 Precision: 87.50 Recall: 87.50
#
# -----svc - Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----svc - Validation-----
# AUC: 85.75 Precision: 84.00 Recall: 87.50
#
# -----nusvc - Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----nusvc - Validation-----
# AUC: 85.67 Precision: 86.96 Recall: 83.33
#
# Fold 8
#
# -----qda - Train----------
# AUC: 96.91 Precision: 97.06 Recall: 96.65
#
# -----qda - Validation-----
# AUC: 89.58 Precision: 91.30 Recall: 87.50
#
# -----knn - Train----------
# AUC: 87.19 Precision: 89.69 Recall: 83.68
#
# -----knn - Validation-----
# AUC: 85.42 Precision: 90.48 Recall: 79.17
#
# -----mlp - Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----mlp - Validation-----
# AUC: 87.50 Precision: 87.50 Recall: 87.50
#
# -----svc - Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----svc - Validation-----
# AUC: 95.83 Precision: 100.00 Recall: 91.67
#
# -----nusvc - Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----nusvc - Validation-----
# AUC: 95.83 Precision: 100.00 Recall: 91.67
#
# Fold 9
#
# -----qda - Train----------
# AUC: 97.74 Precision: 97.50 Recall: 97.91
#
# -----qda - Validation-----
# AUC: 87.50 Precision: 90.91 Recall: 83.33
#
# -----knn - Train----------
# AUC: 88.64 Precision: 90.71 Recall: 85.77
#
# -----knn - Validation-----
# AUC: 75.00 Precision: 75.00 Recall: 75.00
#
# -----mlp - Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----mlp - Validation-----
# AUC: 85.42 Precision: 86.96 Recall: 83.33
#
# -----svc - Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----svc - Validation-----
# AUC: 87.50 Precision: 87.50 Recall: 87.50
#
# -----nusvc - Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----nusvc - Validation-----
# AUC: 87.50 Precision: 87.50 Recall: 87.50
#
# Fold 10
#
# -----qda - Train----------
# AUC: 96.71 Precision: 96.65 Recall: 96.65
#
# -----qda - Validation-----
# AUC: 93.75 Precision: 95.65 Recall: 91.67
#
# -----knn - Train----------
# AUC: 86.95 Precision: 91.12 Recall: 81.59
#
# -----knn - Validation-----
# AUC: 81.25 Precision: 85.71 Recall: 75.00
#
# -----mlp - Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----mlp - Validation-----
# AUC: 91.67 Precision: 91.67 Recall: 91.67
#
# -----svc - Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----svc - Validation-----
# AUC: 89.58 Precision: 100.00 Recall: 79.17
#
# -----nusvc - Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----nusvc - Validation-----
# AUC: 85.42 Precision: 100.00 Recall: 70.83
#
# Fold 11
#
# -----qda - Train----------
# AUC: 96.71 Precision: 96.67 Recall: 96.67
#
# -----qda - Validation-----
# AUC: 97.83 Precision: 100.00 Recall: 95.65
#
# -----knn - Train----------
# AUC: 86.80 Precision: 89.64 Recall: 82.92
#
# -----knn - Validation-----
# AUC: 87.14 Precision: 90.48 Recall: 82.61
#
# -----mlp - Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----mlp - Validation-----
# AUC: 87.23 Precision: 86.96 Recall: 86.96
#
# -----svc - Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----svc - Validation-----
# AUC: 95.74 Precision: 95.65 Recall: 95.65
#
# -----nusvc - Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----nusvc - Validation-----
# AUC: 93.57 Precision: 95.45 Recall: 91.30
#
# wheezy-copper-turtle-magic 1
#
# Fold 1
#
# -----qda - Train----------
# AUC: 96.60 Precision: 94.81 Recall: 98.21
#
# -----qda - Validation-----
# AUC: 91.58 Precision: 88.00 Recall: 95.65
#
# -----knn - Train----------
# AUC: 93.21 Precision: 89.96 Recall: 96.41
#
# -----knn - Validation-----
# AUC: 83.15 Precision: 77.78 Recall: 91.30
#
# -----mlp - Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----mlp - Validation-----
# AUC: 83.15 Precision: 77.78 Recall: 91.30
#
# -----svc - Train----------
# AUC: 99.33 Precision: 100.00 Recall: 98.65
#
# -----svc - Validation-----
# AUC: 85.14 Precision: 83.33 Recall: 86.96
#
# -----nusvc - Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----nusvc - Validation-----
# AUC: 83.15 Precision: 77.78 Recall: 91.30
#
# Fold 2
#
# -----qda - Train----------
# AUC: 96.17 Precision: 94.37 Recall: 97.76
#
# -----qda - Validation-----
# AUC: 97.83 Precision: 100.00 Recall: 95.65
#
# -----knn - Train----------
# AUC: 91.56 Precision: 86.75 Recall: 96.86
#
# -----knn - Validation-----
# AUC: 93.66 Precision: 91.67 Recall: 95.65
#
# -----mlp - Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----mlp - Validation-----
# AUC: 89.31 Precision: 90.91 Recall: 86.96
#
# -----svc - Train----------
# AUC: 98.43 Precision: 100.00 Recall: 96.86
#
# -----svc - Validation-----
# AUC: 93.48 Precision: 100.00 Recall: 86.96
#
# -----nusvc - Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----nusvc - Validation-----
# AUC: 91.49 Precision: 91.30 Recall: 91.30
#
# Fold 3
#
# -----qda - Train----------
# AUC: 96.39 Precision: 94.40 Recall: 98.21
#
# -----qda - Validation-----
# AUC: 93.57 Precision: 95.45 Recall: 91.30
#
# -----knn - Train----------
# AUC: 92.81 Precision: 88.89 Recall: 96.86
#
# -----knn - Validation-----
# AUC: 91.67 Precision: 85.19 Recall: 100.00
#
# -----mlp - Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----mlp - Validation-----
# AUC: 89.40 Precision: 87.50 Recall: 91.30
#
# -----svc - Train----------
# AUC: 98.65 Precision: 100.00 Recall: 97.31
#
# -----svc - Validation-----
# AUC: 82.70 Precision: 94.12 Recall: 69.57
#
# -----nusvc - Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----nusvc - Validation-----
# AUC: 87.05 Precision: 94.74 Recall: 78.26
#
# Fold 4
#
# -----qda - Train----------
# AUC: 96.60 Precision: 94.81 Recall: 98.21
#
# -----qda - Validation-----
# AUC: 87.32 Precision: 84.00 Recall: 91.30
#
# -----knn - Train----------
# AUC: 92.31 Precision: 89.79 Recall: 94.62
#
# -----knn - Validation-----
# AUC: 85.24 Precision: 80.77 Recall: 91.30
#
# -----mlp - Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----mlp - Validation-----
# AUC: 87.23 Precision: 86.96 Recall: 86.96
#
# -----svc - Train----------
# AUC: 98.88 Precision: 100.00 Recall: 97.76
#
# -----svc - Validation-----
# AUC: 74.18 Precision: 82.35 Recall: 60.87
#
# -----nusvc - Train----------
# AUC: 99.78 Precision: 100.00 Recall: 99.55
#
# -----nusvc - Validation-----
# AUC: 78.62 Precision: 80.95 Recall: 73.91
#
# Fold 5
#
# -----qda - Train----------
# AUC: 96.59 Precision: 95.22 Recall: 97.77
#
# -----qda - Validation-----
# AUC: 87.12 Precision: 83.33 Recall: 90.91
#
# -----knn - Train----------
# AUC: 92.38 Precision: 88.52 Recall: 96.43
#
# -----knn - Validation-----
# AUC: 86.93 Precision: 86.36 Recall: 86.36
#
# -----mlp - Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----mlp - Validation-----
# AUC: 82.39 Precision: 85.00 Recall: 77.27
#
# -----svc - Train----------
# AUC: 97.77 Precision: 100.00 Recall: 95.54
#
# -----svc - Validation-----
# AUC: 84.28 Precision: 94.12 Recall: 72.73
#
# -----nusvc - Train----------
# AUC: 99.11 Precision: 100.00 Recall: 98.21
#
# -----nusvc - Validation-----
# AUC: 86.93 Precision: 86.36 Recall: 86.36
#
# Fold 6
#
# -----qda - Train----------
# AUC: 96.18 Precision: 94.40 Recall: 97.77
#
# -----qda - Validation-----
# AUC: 93.18 Precision: 100.00 Recall: 86.36
#
# -----knn - Train----------
# AUC: 91.73 Precision: 88.07 Recall: 95.54
#
# -----knn - Validation-----
# AUC: 82.95 Precision: 76.92 Recall: 90.91
#
# -----mlp - Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----mlp - Validation-----
# AUC: 80.49 Precision: 78.26 Recall: 81.82
#
# -----svc - Train----------
# AUC: 98.88 Precision: 100.00 Recall: 97.77
#
# -----svc - Validation-----
# AUC: 86.55 Precision: 94.44 Recall: 77.27
#
# -----nusvc - Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----nusvc - Validation-----
# AUC: 89.20 Precision: 86.96 Recall: 90.91
#
# Fold 7
#
# -----qda - Train----------
# AUC: 96.80 Precision: 95.63 Recall: 97.77
#
# -----qda - Validation-----
# AUC: 82.58 Precision: 81.82 Recall: 81.82
#
# -----knn - Train----------
# AUC: 91.28 Precision: 87.97 Recall: 94.64
#
# -----knn - Validation-----
# AUC: 89.20 Precision: 86.96 Recall: 90.91
#
# -----mlp - Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----mlp - Validation-----
# AUC: 84.85 Precision: 82.61 Recall: 86.36
#
# -----svc - Train----------
# AUC: 98.44 Precision: 100.00 Recall: 96.88
#
# -----svc - Validation-----
# AUC: 78.03 Precision: 80.00 Recall: 72.73
#
# -----nusvc - Train----------
# AUC: 99.78 Precision: 100.00 Recall: 99.55
#
# -----nusvc - Validation-----
# AUC: 82.58 Precision: 81.82 Recall: 81.82
#
# Fold 8
#
# -----qda - Train----------
# AUC: 96.62 Precision: 94.44 Recall: 98.66
#
# -----qda - Validation-----
# AUC: 93.37 Precision: 95.24 Recall: 90.91
#
# -----knn - Train----------
# AUC: 92.38 Precision: 88.52 Recall: 96.43
#
# -----knn - Validation-----
# AUC: 91.48 Precision: 87.50 Recall: 95.45
#
# -----mlp - Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----mlp - Validation-----
# AUC: 89.02 Precision: 90.48 Recall: 86.36
#
# -----svc - Train----------
# AUC: 98.88 Precision: 100.00 Recall: 97.77
#
# -----svc - Validation-----
# AUC: 84.47 Precision: 89.47 Recall: 77.27
#
# -----nusvc - Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----nusvc - Validation-----
# AUC: 86.93 Precision: 86.36 Recall: 86.36
#
# Fold 9
#
# -----qda - Train----------
# AUC: 96.61 Precision: 94.83 Recall: 98.21
#
# -----qda - Validation-----
# AUC: 91.29 Precision: 90.91 Recall: 90.91
#
# -----knn - Train----------
# AUC: 92.74 Precision: 90.60 Recall: 94.64
#
# -----knn - Validation-----
# AUC: 89.20 Precision: 86.96 Recall: 90.91
#
# -----mlp - Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----mlp - Validation-----
# AUC: 69.70 Precision: 66.67 Recall: 72.73
#
# -----svc - Train----------
# AUC: 97.54 Precision: 100.00 Recall: 95.09
#
# -----svc - Validation-----
# AUC: 66.48 Precision: 76.92 Recall: 45.45
#
# -----nusvc - Train----------
# AUC: 98.88 Precision: 100.00 Recall: 97.77
#
# -----nusvc - Validation-----
# AUC: 75.76 Precision: 78.95 Recall: 68.18
#
# Fold 10
#
# -----qda - Train----------
# AUC: 97.04 Precision: 95.26 Recall: 98.66
#
# -----qda - Validation-----
# AUC: 95.83 Precision: 91.67 Recall: 100.00
#
# -----knn - Train----------
# AUC: 91.70 Precision: 88.70 Recall: 94.64
#
# -----knn - Validation-----
# AUC: 91.48 Precision: 87.50 Recall: 95.45
#
# -----mlp - Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----mlp - Validation-----
# AUC: 95.83 Precision: 91.67 Recall: 100.00
#
# -----svc - Train----------
# AUC: 98.88 Precision: 100.00 Recall: 97.77
#
# -----svc - Validation-----
# AUC: 91.48 Precision: 87.50 Recall: 95.45
#
# -----nusvc - Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----nusvc - Validation-----
# AUC: 93.75 Precision: 88.00 Recall: 100.00
#
# Fold 11
#
# -----qda - Train----------
# AUC: 96.83 Precision: 94.85 Recall: 98.66
#
# -----qda - Validation-----
# AUC: 95.64 Precision: 95.45 Recall: 95.45
#
# -----knn - Train----------
# AUC: 93.02 Precision: 89.30 Recall: 96.88
#
# -----knn - Validation-----
# AUC: 80.49 Precision: 78.26 Recall: 81.82
#
# -----mlp - Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----mlp - Validation-----
# AUC: 82.01 Precision: 93.75 Recall: 68.18
#
# -----svc - Train----------
# AUC: 99.11 Precision: 100.00 Recall: 98.21
#
# -----svc - Validation-----
# AUC: 86.74 Precision: 90.00 Recall: 81.82
#
# -----nusvc - Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----nusvc - Validation-----
# AUC: 93.75 Precision: 88.00 Recall: 100.00
#
# wheezy-copper-turtle-magic 2
#
# Fold 1
#
# -----qda - Train----------
# AUC: 97.77 Precision: 97.73 Recall: 97.73
#
# -----qda - Validation-----
# AUC: 93.48 Precision: 95.45 Recall: 91.30
#
# -----knn - Train----------
# AUC: 87.01 Precision: 89.71 Recall: 83.18
#
# -----knn - Validation-----
# AUC: 73.91 Precision: 78.95 Recall: 65.22
#
# -----mlp - Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----mlp - Validation-----
# AUC: 80.43 Precision: 81.82 Recall: 78.26
#
# -----svc - Train----------
# AUC: 99.32 Precision: 100.00 Recall: 98.64
#
# -----svc - Validation-----
# AUC: 80.43 Precision: 100.00 Recall: 60.87
#
# -----nusvc - Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----nusvc - Validation-----
# AUC: 91.30 Precision: 100.00 Recall: 82.61
#
# Fold 2
#
# -----qda - Train----------
# AUC: 97.34 Precision: 96.86 Recall: 97.74
#
# -----qda - Validation-----
# AUC: 95.55 Precision: 95.45 Recall: 95.45
#
# -----knn - Train----------
# AUC: 88.84 Precision: 90.91 Recall: 85.97
#
# -----knn - Validation-----
# AUC: 79.74 Precision: 88.24 Recall: 68.18
#
# -----mlp - Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----mlp - Validation-----
# AUC: 75.49 Precision: 76.19 Recall: 72.73
#
# -----svc - Train----------
# AUC: 99.32 Precision: 100.00 Recall: 98.64
#
# -----svc - Validation-----
# AUC: 84.19 Precision: 94.12 Recall: 72.73
#
# -----nusvc - Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----nusvc - Validation-----
# AUC: 84.29 Precision: 89.47 Recall: 77.27
#
# Fold 3
#
# -----qda - Train----------
# AUC: 97.78 Precision: 97.31 Recall: 98.19
#
# -----qda - Validation-----
# AUC: 88.83 Precision: 90.48 Recall: 86.36
#
# -----knn - Train----------
# AUC: 86.32 Precision: 92.11 Recall: 79.19
#
# -----knn - Validation-----
# AUC: 79.84 Precision: 84.21 Recall: 72.73
#
# -----mlp - Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----mlp - Validation-----
# AUC: 86.66 Precision: 86.36 Recall: 86.36
#
# -----svc - Train----------
# AUC: 98.64 Precision: 100.00 Recall: 97.29
#
# -----svc - Validation-----
# AUC: 70.75 Precision: 80.00 Recall: 54.55
#
# -----nusvc - Train----------
# AUC: 99.77 Precision: 100.00 Recall: 99.55
#
# -----nusvc - Validation-----
# AUC: 79.84 Precision: 84.21 Recall: 72.73
#
# Fold 4
#
# -----qda - Train----------
# AUC: 97.55 Precision: 97.73 Recall: 97.29
#
# -----qda - Validation-----
# AUC: 91.11 Precision: 90.91 Recall: 90.91
#
# -----knn - Train----------
# AUC: 88.62 Precision: 90.48 Recall: 85.97
#
# -----knn - Validation-----
# AUC: 89.03 Precision: 84.00 Recall: 95.45
#
# -----mlp - Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----mlp - Validation-----
# AUC: 91.11 Precision: 90.91 Recall: 90.91
#
# -----svc - Train----------
# AUC: 99.77 Precision: 100.00 Recall: 99.55
#
# -----svc - Validation-----
# AUC: 93.38 Precision: 91.30 Recall: 95.45
#
# -----nusvc - Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----nusvc - Validation-----
# AUC: 91.21 Precision: 87.50 Recall: 95.45
#
# Fold 5
#
# -----qda - Train----------
# AUC: 97.78 Precision: 97.74 Recall: 97.74
#
# -----qda - Validation-----
# AUC: 93.38 Precision: 91.30 Recall: 95.45
#
# -----knn - Train----------
# AUC: 86.15 Precision: 89.16 Recall: 81.90
#
# -----knn - Validation-----
# AUC: 84.39 Precision: 85.71 Recall: 81.82
#
# -----mlp - Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----mlp - Validation-----
# AUC: 77.77 Precision: 77.27 Recall: 77.27
#
# -----svc - Train----------
# AUC: 99.32 Precision: 100.00 Recall: 98.64
#
# -----svc - Validation-----
# AUC: 91.01 Precision: 95.00 Recall: 86.36
#
# -----nusvc - Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----nusvc - Validation-----
# AUC: 95.55 Precision: 95.45 Recall: 95.45
#
# Fold 6
#
# -----qda - Train----------
# AUC: 98.44 Precision: 98.64 Recall: 98.19
#
# -----qda - Validation-----
# AUC: 88.93 Precision: 86.96 Recall: 90.91
#
# -----knn - Train----------
# AUC: 89.06 Precision: 90.95 Recall: 86.43
#
# -----knn - Validation-----
# AUC: 80.04 Precision: 78.26 Recall: 81.82
#
# -----mlp - Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----mlp - Validation-----
# AUC: 75.79 Precision: 70.37 Recall: 86.36
#
# -----svc - Train----------
# AUC: 99.77 Precision: 100.00 Recall: 99.55
#
# -----svc - Validation-----
# AUC: 88.93 Precision: 86.96 Recall: 90.91
#
# -----nusvc - Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----nusvc - Validation-----
# AUC: 88.93 Precision: 86.96 Recall: 90.91
#
# Fold 7
#
# -----qda - Train----------
# AUC: 97.55 Precision: 97.73 Recall: 97.29
#
# -----qda - Validation-----
# AUC: 93.48 Precision: 88.00 Recall: 100.00
#
# -----knn - Train----------
# AUC: 87.05 Precision: 89.37 Recall: 83.71
#
# -----knn - Validation-----
# AUC: 84.29 Precision: 89.47 Recall: 77.27
#
# -----mlp - Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----mlp - Validation-----
# AUC: 86.66 Precision: 86.36 Recall: 86.36
#
# -----svc - Train----------
# AUC: 99.77 Precision: 100.00 Recall: 99.55
#
# -----svc - Validation-----
# AUC: 79.74 Precision: 88.24 Recall: 68.18
#
# -----nusvc - Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----nusvc - Validation-----
# AUC: 79.84 Precision: 84.21 Recall: 72.73
#
# Fold 8
#
# -----qda - Train----------
# AUC: 97.56 Precision: 97.30 Recall: 97.74
#
# -----qda - Validation-----
# AUC: 93.28 Precision: 95.24 Recall: 90.91
#
# -----knn - Train----------
# AUC: 87.25 Precision: 91.00 Recall: 82.35
#
# -----knn - Validation-----
# AUC: 88.64 Precision: 100.00 Recall: 77.27
#
# -----mlp - Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----mlp - Validation-----
# AUC: 91.11 Precision: 90.91 Recall: 90.91
#
# -----svc - Train----------
# AUC: 99.32 Precision: 100.00 Recall: 98.64
#
# -----svc - Validation-----
# AUC: 84.09 Precision: 100.00 Recall: 68.18
#
# -----nusvc - Train----------
# AUC: 99.77 Precision: 100.00 Recall: 99.55
#
# -----nusvc - Validation-----
# AUC: 84.29 Precision: 89.47 Recall: 77.27
#
# Fold 9
#
# -----qda - Train----------
# AUC: 98.24 Precision: 97.33 Recall: 99.10
#
# -----qda - Validation-----
# AUC: 93.18 Precision: 100.00 Recall: 86.36
#
# -----knn - Train----------
# AUC: 86.79 Precision: 91.33 Recall: 81.00
#
# -----knn - Validation-----
# AUC: 90.91 Precision: 100.00 Recall: 81.82
#
# -----mlp - Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----mlp - Validation-----
# AUC: 77.87 Precision: 75.00 Recall: 81.82
#
# -----svc - Train----------
# AUC: 99.77 Precision: 100.00 Recall: 99.55
#
# -----svc - Validation-----
# AUC: 81.92 Precision: 93.75 Recall: 68.18
#
# -----nusvc - Train----------
# AUC: 99.77 Precision: 100.00 Recall: 99.55
#
# -----nusvc - Validation-----
# AUC: 81.92 Precision: 93.75 Recall: 68.18
#
# Fold 10
#
# -----qda - Train----------
# AUC: 97.55 Precision: 97.73 Recall: 97.29
#
# -----qda - Validation-----
# AUC: 97.83 Precision: 95.65 Recall: 100.00
#
# -----knn - Train----------
# AUC: 85.22 Precision: 90.16 Recall: 78.73
#
# -----knn - Validation-----
# AUC: 84.19 Precision: 94.12 Recall: 72.73
#
# -----mlp - Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----mlp - Validation-----
# AUC: 86.56 Precision: 90.00 Recall: 81.82
#
# -----svc - Train----------
# AUC: 99.55 Precision: 100.00 Recall: 99.10
#
# -----svc - Validation-----
# AUC: 81.82 Precision: 100.00 Recall: 63.64
#
# -----nusvc - Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----nusvc - Validation-----
# AUC: 86.36 Precision: 100.00 Recall: 72.73
#
# Fold 11
#
# -----qda - Train----------
# AUC: 97.12 Precision: 96.85 Recall: 97.29
#
# -----qda - Validation-----
# AUC: 97.73 Precision: 95.65 Recall: 100.00
#
# -----knn - Train----------
# AUC: 87.06 Precision: 89.76 Recall: 83.26
#
# -----knn - Validation-----
# AUC: 86.36 Precision: 94.44 Recall: 77.27
#
# -----mlp - Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----mlp - Validation-----
# AUC: 90.91 Precision: 90.91 Recall: 90.91
#
# -----svc - Train----------
# AUC: 99.77 Precision: 100.00 Recall: 99.55
#
# -----svc - Validation-----
# AUC: 88.64 Precision: 100.00 Recall: 77.27
#
# -----nusvc - Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----nusvc - Validation-----
# AUC: 88.64 Precision: 100.00 Recall: 77.27
#
# wheezy-copper-turtle-magic 3
#
# Fold 1
#
# -----qda - Train----------
# AUC: 98.79 Precision: 99.21 Recall: 98.43
#
# -----qda - Validation-----
# AUC: 98.08 Precision: 100.00 Recall: 96.15
#
# -----knn - Train----------
# AUC: 85.95 Precision: 80.58 Recall: 97.65
#
# -----knn - Validation-----
# AUC: 89.58 Precision: 83.87 Recall: 100.00
#
# -----mlp - Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----mlp - Validation-----
# AUC: 94.07 Precision: 96.00 Recall: 92.31
#
# -----svc - Train----------
# AUC: 92.49 Precision: 87.93 Recall: 100.00
#
# -----svc - Validation-----
# AUC: 62.50 Precision: 59.09 Recall: 100.00
#
# -----nusvc - Train----------
# AUC: 97.64 Precision: 95.86 Recall: 100.00
#
# -----nusvc - Validation-----
# AUC: 72.92 Precision: 66.67 Recall: 100.00
#
# Fold 2
#
# -----qda - Train----------
# AUC: 98.79 Precision: 99.21 Recall: 98.43
#
# -----qda - Validation-----
# AUC: 93.91 Precision: 92.59 Recall: 96.15
#
# -----knn - Train----------
# AUC: 87.49 Precision: 82.89 Recall: 96.86
#
# -----knn - Validation-----
# AUC: 77.24 Precision: 71.43 Recall: 96.15
#
# -----mlp - Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----mlp - Validation-----
# AUC: 89.74 Precision: 86.21 Recall: 96.15
#
# -----svc - Train----------
# AUC: 92.49 Precision: 87.93 Recall: 100.00
#
# -----svc - Validation-----
# AUC: 66.99 Precision: 63.16 Recall: 92.31
#
# -----nusvc - Train----------
# AUC: 98.07 Precision: 96.59 Recall: 100.00
#
# -----nusvc - Validation-----
# AUC: 77.40 Precision: 72.73 Recall: 92.31
#
# Fold 3
#
# -----qda - Train----------
# AUC: 98.39 Precision: 99.20 Recall: 97.65
#
# -----qda - Validation-----
# AUC: 93.91 Precision: 92.59 Recall: 96.15
#
# -----knn - Train----------
# AUC: 87.92 Precision: 83.45 Recall: 96.86
#
# -----knn - Validation-----
# AUC: 87.66 Precision: 83.33 Recall: 96.15
#
# -----mlp - Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----mlp - Validation-----
# AUC: 81.57 Precision: 77.42 Recall: 92.31
#
# -----svc - Train----------
# AUC: 94.85 Precision: 91.40 Recall: 100.00
#
# -----svc - Validation-----
# AUC: 70.99 Precision: 65.79 Recall: 96.15
#
# -----nusvc - Train----------
# AUC: 98.28 Precision: 96.96 Recall: 100.00
#
# -----nusvc - Validation-----
# AUC: 75.32 Precision: 70.59 Recall: 92.31
#
# Fold 4
#
# -----qda - Train----------
# AUC: 98.59 Precision: 99.21 Recall: 98.04
#
# -----qda - Validation-----
# AUC: 93.75 Precision: 89.66 Recall: 100.00
#
# -----knn - Train----------
# AUC: 85.99 Precision: 80.98 Recall: 96.86
#
# -----knn - Validation-----
# AUC: 85.42 Precision: 78.79 Recall: 100.00
#
# -----mlp - Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----mlp - Validation-----
# AUC: 89.90 Precision: 88.89 Recall: 92.31
#
# -----svc - Train----------
# AUC: 93.78 Precision: 89.79 Recall: 100.00
#
# -----svc - Validation-----
# AUC: 62.50 Precision: 59.09 Recall: 100.00
#
# -----nusvc - Train----------
# AUC: 98.28 Precision: 96.96 Recall: 100.00
#
# -----nusvc - Validation-----
# AUC: 70.83 Precision: 65.00 Recall: 100.00
#
# Fold 5
#
# -----qda - Train----------
# AUC: 98.82 Precision: 100.00 Recall: 97.65
#
# -----qda - Validation-----
# AUC: 89.38 Precision: 86.21 Recall: 96.15
#
# -----knn - Train----------
# AUC: 86.47 Precision: 81.52 Recall: 96.86
#
# -----knn - Validation-----
# AUC: 74.16 Precision: 69.44 Recall: 96.15
#
# -----mlp - Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----mlp - Validation-----
# AUC: 77.34 Precision: 77.78 Recall: 80.77
#
# -----svc - Train----------
# AUC: 94.02 Precision: 90.11 Recall: 100.00
#
# -----svc - Validation-----
# AUC: 58.70 Precision: 57.78 Recall: 100.00
#
# -----nusvc - Train----------
# AUC: 98.72 Precision: 97.70 Recall: 100.00
#
# -----nusvc - Validation-----
# AUC: 71.74 Precision: 66.67 Recall: 100.00
#
# Fold 6
#
# -----qda - Train----------
# AUC: 98.59 Precision: 99.21 Recall: 98.04
#
# -----qda - Validation-----
# AUC: 97.83 Precision: 96.30 Recall: 100.00
#
# -----knn - Train----------
# AUC: 88.00 Precision: 83.90 Recall: 96.08
#
# -----knn - Validation-----
# AUC: 84.78 Precision: 78.79 Recall: 100.00
#
# -----mlp - Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----mlp - Validation-----
# AUC: 92.06 Precision: 95.83 Recall: 88.46
#
# -----svc - Train----------
# AUC: 95.51 Precision: 92.39 Recall: 100.00
#
# -----svc - Validation-----
# AUC: 73.91 Precision: 68.42 Recall: 100.00
#
# -----nusvc - Train----------
# AUC: 98.50 Precision: 97.33 Recall: 100.00
#
# -----nusvc - Validation-----
# AUC: 78.26 Precision: 72.22 Recall: 100.00
#
# Fold 7
#
# -----qda - Train----------
# AUC: 98.60 Precision: 99.21 Recall: 98.05
#
# -----qda - Validation-----
# AUC: 93.83 Precision: 95.83 Recall: 92.00
#
# -----knn - Train----------
# AUC: 87.97 Precision: 83.50 Recall: 96.88
#
# -----knn - Validation-----
# AUC: 87.13 Precision: 82.76 Recall: 96.00
#
# -----mlp - Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----mlp - Validation-----
# AUC: 89.30 Precision: 85.71 Recall: 96.00
#
# -----svc - Train----------
# AUC: 96.15 Precision: 93.43 Recall: 100.00
#
# -----svc - Validation-----
# AUC: 82.61 Precision: 75.76 Recall: 100.00
#
# -----nusvc - Train----------
# AUC: 98.93 Precision: 98.08 Recall: 100.00
#
# -----nusvc - Validation-----
# AUC: 87.13 Precision: 82.76 Recall: 96.00
#
# Fold 8
#
# -----qda - Train----------
# AUC: 98.58 Precision: 98.82 Recall: 98.44
#
# -----qda - Validation-----
# AUC: 93.83 Precision: 95.83 Recall: 92.00
#
# -----knn - Train----------
# AUC: 85.64 Precision: 80.72 Recall: 96.48
#
# -----knn - Validation-----
# AUC: 87.30 Precision: 85.19 Recall: 92.00
#
# -----mlp - Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----mlp - Validation-----
# AUC: 89.65 Precision: 91.67 Recall: 88.00
#
# -----svc - Train----------
# AUC: 94.02 Precision: 90.14 Recall: 100.00
#
# -----svc - Validation-----
# AUC: 76.09 Precision: 69.44 Recall: 100.00
#
# -----nusvc - Train----------
# AUC: 98.50 Precision: 97.34 Recall: 100.00
#
# -----nusvc - Validation-----
# AUC: 80.43 Precision: 73.53 Recall: 100.00
#
# Fold 9
#
# -----qda - Train----------
# AUC: 99.01 Precision: 99.60 Recall: 98.44
#
# -----qda - Validation-----
# AUC: 91.83 Precision: 95.65 Recall: 88.00
#
# -----knn - Train----------
# AUC: 87.13 Precision: 82.61 Recall: 96.48
#
# -----knn - Validation-----
# AUC: 76.43 Precision: 71.88 Recall: 92.00
#
# -----mlp - Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----mlp - Validation-----
# AUC: 87.30 Precision: 85.19 Recall: 92.00
#
# -----svc - Train----------
# AUC: 94.02 Precision: 90.14 Recall: 100.00
#
# -----svc - Validation-----
# AUC: 73.91 Precision: 67.57 Recall: 100.00
#
# -----nusvc - Train----------
# AUC: 98.29 Precision: 96.97 Recall: 100.00
#
# -----nusvc - Validation-----
# AUC: 76.26 Precision: 70.59 Recall: 96.00
#
# Fold 10
#
# -----qda - Train----------
# AUC: 98.61 Precision: 99.60 Recall: 97.66
#
# -----qda - Validation-----
# AUC: 93.83 Precision: 95.83 Recall: 92.00
#
# -----knn - Train----------
# AUC: 88.45 Precision: 84.78 Recall: 95.70
#
# -----knn - Validation-----
# AUC: 87.13 Precision: 82.76 Recall: 96.00
#
# -----mlp - Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----mlp - Validation-----
# AUC: 89.48 Precision: 88.46 Recall: 92.00
#
# -----svc - Train----------
# AUC: 95.73 Precision: 92.75 Recall: 100.00
#
# -----svc - Validation-----
# AUC: 69.57 Precision: 64.10 Recall: 100.00
#
# -----nusvc - Train----------
# AUC: 98.72 Precision: 97.71 Recall: 100.00
#
# -----nusvc - Validation-----
# AUC: 86.96 Precision: 80.65 Recall: 100.00
#
# Fold 11
#
# -----qda - Train----------
# AUC: 98.60 Precision: 99.21 Recall: 98.05
#
# -----qda - Validation-----
# AUC: 85.30 Precision: 84.62 Recall: 88.00
#
# -----knn - Train----------
# AUC: 86.65 Precision: 81.43 Recall: 97.66
#
# -----knn - Validation-----
# AUC: 80.61 Precision: 75.00 Recall: 96.00
#
# -----mlp - Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----mlp - Validation-----
# AUC: 85.30 Precision: 84.62 Recall: 88.00
#
# -----svc - Train----------
# AUC: 93.80 Precision: 89.82 Recall: 100.00
#
# -----svc - Validation-----
# AUC: 54.52 Precision: 54.55 Recall: 96.00
#
# -----nusvc - Train----------
# AUC: 98.29 Precision: 96.97 Recall: 100.00
#
# -----nusvc - Validation-----
# AUC: 63.57 Precision: 61.11 Recall: 88.00
#
# wheezy-copper-turtle-magic 4
#
# Fold 1
#
# -----qda - Train----------
# AUC: 97.45 Precision: 98.28 Recall: 96.62
#
# -----qda - Validation-----
# AUC: 85.42 Precision: 86.96 Recall: 83.33
#
# -----knn - Train----------
# AUC: 89.10 Precision: 89.41 Recall: 89.03
#
# -----knn - Validation-----
# AUC: 83.33 Precision: 83.33 Recall: 83.33
#
# -----mlp - Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----mlp - Validation-----
# AUC: 87.50 Precision: 95.00 Recall: 79.17
#
# -----svc - Train----------
# AUC: 99.79 Precision: 100.00 Recall: 99.58
#
# -----svc - Validation-----
# AUC: 77.08 Precision: 84.21 Recall: 66.67
#
# -----nusvc - Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----nusvc - Validation-----
# AUC: 81.25 Precision: 85.71 Recall: 75.00
#
# Fold 2
#
# -----qda - Train----------
# AUC: 96.16 Precision: 96.60 Recall: 95.78
#
# -----qda - Validation-----
# AUC: 87.50 Precision: 82.14 Recall: 95.83
#
# -----knn - Train----------
# AUC: 87.84 Precision: 89.13 Recall: 86.50
#
# -----knn - Validation-----
# AUC: 83.33 Precision: 86.36 Recall: 79.17
#
# -----mlp - Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----mlp - Validation-----
# AUC: 83.33 Precision: 86.36 Recall: 79.17
#
# -----svc - Train----------
# AUC: 99.79 Precision: 100.00 Recall: 99.58
#
# -----svc - Validation-----
# AUC: 91.67 Precision: 91.67 Recall: 91.67
#
# -----nusvc - Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----nusvc - Validation-----
# AUC: 89.58 Precision: 91.30 Recall: 87.50
#
# Fold 3
#
# -----qda - Train----------
# AUC: 96.80 Precision: 97.03 Recall: 96.62
#
# -----qda - Validation-----
# AUC: 89.40 Precision: 91.30 Recall: 87.50
#
# -----knn - Train----------
# AUC: 88.93 Precision: 90.75 Recall: 86.92
#
# -----knn - Validation-----
# AUC: 89.58 Precision: 100.00 Recall: 79.17
#
# -----mlp - Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----mlp - Validation-----
# AUC: 87.41 Precision: 95.00 Recall: 79.17
#
# -----svc - Train----------
# AUC: 99.16 Precision: 100.00 Recall: 98.31
#
# -----svc - Validation-----
# AUC: 89.49 Precision: 95.24 Recall: 83.33
#
# -----nusvc - Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----nusvc - Validation-----
# AUC: 89.49 Precision: 95.24 Recall: 83.33
#
# Fold 4
#
# -----qda - Train----------
# AUC: 96.81 Precision: 97.44 Recall: 96.20
#
# -----qda - Validation-----
# AUC: 95.83 Precision: 100.00 Recall: 91.67
#
# -----knn - Train----------
# AUC: 88.30 Precision: 90.62 Recall: 85.65
#
# -----knn - Validation-----
# AUC: 89.31 Precision: 88.00 Recall: 91.67
#
# -----mlp - Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----mlp - Validation-----
# AUC: 89.49 Precision: 95.24 Recall: 83.33
#
# -----svc - Train----------
# AUC: 99.58 Precision: 100.00 Recall: 99.16
#
# -----svc - Validation-----
# AUC: 93.75 Precision: 100.00 Recall: 87.50
#
# -----nusvc - Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----nusvc - Validation-----
# AUC: 93.75 Precision: 100.00 Recall: 87.50
#
# Fold 5
#
# -----qda - Train----------
# AUC: 97.23 Precision: 97.86 Recall: 96.62
#
# -----qda - Validation-----
# AUC: 91.58 Precision: 95.45 Recall: 87.50
#
# -----knn - Train----------
# AUC: 88.07 Precision: 89.18 Recall: 86.92
#
# -----knn - Validation-----
# AUC: 83.24 Precision: 94.44 Recall: 70.83
#
# -----mlp - Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----mlp - Validation-----
# AUC: 87.23 Precision: 87.50 Recall: 87.50
#
# -----svc - Train----------
# AUC: 99.37 Precision: 100.00 Recall: 98.73
#
# -----svc - Validation-----
# AUC: 93.75 Precision: 100.00 Recall: 87.50
#
# -----nusvc - Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----nusvc - Validation-----
# AUC: 87.41 Precision: 95.00 Recall: 79.17
#
# Fold 6
#
# -----qda - Train----------
# AUC: 97.66 Precision: 98.29 Recall: 97.05
#
# -----qda - Validation-----
# AUC: 87.14 Precision: 84.62 Recall: 91.67
#
# -----knn - Train----------
# AUC: 89.16 Precision: 91.89 Recall: 86.08
#
# -----knn - Validation-----
# AUC: 89.31 Precision: 88.00 Recall: 91.67
#
# -----mlp - Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----mlp - Validation-----
# AUC: 80.80 Precision: 80.00 Recall: 83.33
#
# -----svc - Train----------
# AUC: 99.37 Precision: 100.00 Recall: 98.73
#
# -----svc - Validation-----
# AUC: 87.32 Precision: 90.91 Recall: 83.33
#
# -----nusvc - Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----nusvc - Validation-----
# AUC: 87.23 Precision: 87.50 Recall: 87.50
#
# Fold 7
#
# -----qda - Train----------
# AUC: 97.23 Precision: 97.86 Recall: 96.62
#
# -----qda - Validation-----
# AUC: 87.14 Precision: 84.62 Recall: 91.67
#
# -----knn - Train----------
# AUC: 88.72 Precision: 90.71 Recall: 86.50
#
# -----knn - Validation-----
# AUC: 82.97 Precision: 83.33 Recall: 83.33
#
# -----mlp - Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----mlp - Validation-----
# AUC: 89.31 Precision: 88.00 Recall: 91.67
#
# -----svc - Train----------
# AUC: 99.16 Precision: 100.00 Recall: 98.31
#
# -----svc - Validation-----
# AUC: 74.73 Precision: 83.33 Recall: 62.50
#
# -----nusvc - Train----------
# AUC: 99.58 Precision: 100.00 Recall: 99.16
#
# -----nusvc - Validation-----
# AUC: 83.06 Precision: 86.36 Recall: 79.17
#
# Fold 8
#
# -----qda - Train----------
# AUC: 97.66 Precision: 98.29 Recall: 97.05
#
# -----qda - Validation-----
# AUC: 93.57 Precision: 92.00 Recall: 95.83
#
# -----knn - Train----------
# AUC: 87.24 Precision: 89.69 Recall: 84.39
#
# -----knn - Validation-----
# AUC: 91.49 Precision: 91.67 Recall: 91.67
#
# -----mlp - Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----mlp - Validation-----
# AUC: 87.14 Precision: 84.62 Recall: 91.67
#
# -----svc - Train----------
# AUC: 99.58 Precision: 100.00 Recall: 99.16
#
# -----svc - Validation-----
# AUC: 91.49 Precision: 91.67 Recall: 91.67
#
# -----nusvc - Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----nusvc - Validation-----
# AUC: 91.39 Precision: 88.46 Recall: 95.83
#
# Fold 9
#
# -----qda - Train----------
# AUC: 97.03 Precision: 97.86 Recall: 96.22
#
# -----qda - Validation-----
# AUC: 97.83 Precision: 100.00 Recall: 95.65
#
# -----knn - Train----------
# AUC: 87.69 Precision: 89.82 Recall: 85.29
#
# -----knn - Validation-----
# AUC: 86.96 Precision: 84.00 Recall: 91.30
#
# -----mlp - Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----mlp - Validation-----
# AUC: 80.43 Precision: 75.00 Recall: 91.30
#
# -----svc - Train----------
# AUC: 98.53 Precision: 100.00 Recall: 97.06
#
# -----svc - Validation-----
# AUC: 86.96 Precision: 94.74 Recall: 78.26
#
# -----nusvc - Train----------
# AUC: 99.58 Precision: 100.00 Recall: 99.16
#
# -----nusvc - Validation-----
# AUC: 86.96 Precision: 94.74 Recall: 78.26
#
# Fold 10
#
# -----qda - Train----------
# AUC: 97.24 Precision: 97.87 Recall: 96.64
#
# -----qda - Validation-----
# AUC: 93.48 Precision: 95.45 Recall: 91.30
#
# -----knn - Train----------
# AUC: 88.53 Precision: 89.66 Recall: 87.39
#
# -----knn - Validation-----
# AUC: 84.78 Precision: 90.00 Recall: 78.26
#
# -----mlp - Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----mlp - Validation-----
# AUC: 84.78 Precision: 83.33 Recall: 86.96
#
# -----svc - Train----------
# AUC: 99.79 Precision: 100.00 Recall: 99.58
#
# -----svc - Validation-----
# AUC: 91.30 Precision: 100.00 Recall: 82.61
#
# -----nusvc - Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----nusvc - Validation-----
# AUC: 91.30 Precision: 100.00 Recall: 82.61
#
# Fold 11
#
# -----qda - Train----------
# AUC: 97.66 Precision: 97.89 Recall: 97.48
#
# -----qda - Validation-----
# AUC: 91.30 Precision: 88.00 Recall: 95.65
#
# -----knn - Train----------
# AUC: 87.71 Precision: 90.91 Recall: 84.03
#
# -----knn - Validation-----
# AUC: 84.78 Precision: 90.00 Recall: 78.26
#
# -----mlp - Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----mlp - Validation-----
# AUC: 78.26 Precision: 76.00 Recall: 82.61
#
# -----svc - Train----------
# AUC: 98.95 Precision: 100.00 Recall: 97.90
#
# -----svc - Validation-----
# AUC: 84.78 Precision: 94.44 Recall: 73.91
#
# -----nusvc - Train----------
# AUC: 99.79 Precision: 100.00 Recall: 99.58
#
# -----nusvc - Validation-----
# AUC: 82.61 Precision: 94.12 Recall: 69.57
#
# wheezy-copper-turtle-magic 5
#
# Fold 1
#
# -----qda - Train----------
# AUC: 97.46 Precision: 98.27 Recall: 96.60
#
# -----qda - Validation-----
# AUC: 89.58 Precision: 95.24 Recall: 83.33
#
# -----knn - Train----------
# AUC: 85.80 Precision: 90.38 Recall: 80.00
#
# -----knn - Validation-----
# AUC: 85.42 Precision: 86.96 Recall: 83.33
#
# -----mlp - Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----mlp - Validation-----
# AUC: 79.17 Precision: 76.92 Recall: 83.33
#
# -----svc - Train----------
# AUC: 98.11 Precision: 96.31 Recall: 100.00
#
# -----svc - Validation-----
# AUC: 77.08 Precision: 69.70 Recall: 95.83
#
# -----nusvc - Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----nusvc - Validation-----
# AUC: 83.33 Precision: 86.36 Recall: 79.17
#
# Fold 2
#
# -----qda - Train----------
# AUC: 97.45 Precision: 98.69 Recall: 96.17
#
# -----qda - Validation-----
# AUC: 81.25 Precision: 77.78 Recall: 87.50
#
# -----knn - Train----------
# AUC: 87.71 Precision: 91.55 Recall: 82.98
#
# -----knn - Validation-----
# AUC: 75.00 Precision: 80.00 Recall: 66.67
#
# -----mlp - Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----mlp - Validation-----
# AUC: 83.33 Precision: 86.36 Recall: 79.17
#
# -----svc - Train----------
# AUC: 98.11 Precision: 96.31 Recall: 100.00
#
# -----svc - Validation-----
# AUC: 75.00 Precision: 67.65 Recall: 95.83
#
# -----nusvc - Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----nusvc - Validation-----
# AUC: 83.33 Precision: 83.33 Recall: 83.33
#
# Fold 3
#
# -----qda - Train----------
# AUC: 97.24 Precision: 98.26 Recall: 96.17
#
# -----qda - Validation-----
# AUC: 93.75 Precision: 95.65 Recall: 91.67
#
# -----knn - Train----------
# AUC: 87.71 Precision: 90.78 Recall: 83.83
#
# -----knn - Validation-----
# AUC: 85.42 Precision: 90.48 Recall: 79.17
#
# -----mlp - Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----mlp - Validation-----
# AUC: 87.50 Precision: 87.50 Recall: 87.50
#
# -----svc - Train----------
# AUC: 98.32 Precision: 96.71 Recall: 100.00
#
# -----svc - Validation-----
# AUC: 85.42 Precision: 77.42 Recall: 100.00
#
# -----nusvc - Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----nusvc - Validation-----
# AUC: 91.67 Precision: 88.46 Recall: 95.83
#
# Fold 4
#
# -----qda - Train----------
# AUC: 96.82 Precision: 97.83 Recall: 95.74
#
# -----qda - Validation-----
# AUC: 95.83 Precision: 100.00 Recall: 91.67
#
# -----knn - Train----------
# AUC: 87.28 Precision: 91.47 Recall: 82.13
#
# -----knn - Validation-----
# AUC: 85.42 Precision: 90.48 Recall: 79.17
#
# -----mlp - Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----mlp - Validation-----
# AUC: 83.33 Precision: 80.77 Recall: 87.50
#
# -----svc - Train----------
# AUC: 98.74 Precision: 97.51 Recall: 100.00
#
# -----svc - Validation-----
# AUC: 79.17 Precision: 70.59 Recall: 100.00
#
# -----nusvc - Train----------
# AUC: 99.79 Precision: 100.00 Recall: 99.57
#
# -----nusvc - Validation-----
# AUC: 89.58 Precision: 95.24 Recall: 83.33
#
# Fold 5
#
# -----qda - Train----------
# AUC: 97.24 Precision: 98.26 Recall: 96.17
#
# -----qda - Validation-----
# AUC: 93.75 Precision: 92.00 Recall: 95.83
#
# -----knn - Train----------
# AUC: 87.28 Precision: 91.87 Recall: 81.70
#
# -----knn - Validation-----
# AUC: 83.33 Precision: 86.36 Recall: 79.17
#
# -----mlp - Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----mlp - Validation-----
# AUC: 91.67 Precision: 88.46 Recall: 95.83
#
# -----svc - Train----------
# AUC: 97.90 Precision: 95.92 Recall: 100.00
#
# -----svc - Validation-----
# AUC: 75.00 Precision: 66.67 Recall: 100.00
#
# -----nusvc - Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----nusvc - Validation-----
# AUC: 85.42 Precision: 84.00 Recall: 87.50
#
# Fold 6
#
# -----qda - Train----------
# AUC: 97.45 Precision: 98.69 Recall: 96.17
#
# -----qda - Validation-----
# AUC: 95.83 Precision: 95.83 Recall: 95.83
#
# -----knn - Train----------
# AUC: 86.85 Precision: 92.20 Recall: 80.43
#
# -----knn - Validation-----
# AUC: 81.25 Precision: 89.47 Recall: 70.83
#
# -----mlp - Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----mlp - Validation-----
# AUC: 85.42 Precision: 84.00 Recall: 87.50
#
# -----svc - Train----------
# AUC: 98.95 Precision: 97.92 Recall: 100.00
#
# -----svc - Validation-----
# AUC: 83.33 Precision: 76.67 Recall: 95.83
#
# -----nusvc - Train----------
# AUC: 99.79 Precision: 100.00 Recall: 99.57
#
# -----nusvc - Validation-----
# AUC: 85.42 Precision: 90.48 Recall: 79.17
#
# Fold 7
#
# -----qda - Train----------
# AUC: 97.47 Precision: 97.86 Recall: 97.03
#
# -----qda - Validation-----
# AUC: 95.65 Precision: 100.00 Recall: 91.30
#
# -----knn - Train----------
# AUC: 86.47 Precision: 90.95 Recall: 80.93
#
# -----knn - Validation-----
# AUC: 80.71 Precision: 85.00 Recall: 73.91
#
# -----mlp - Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----mlp - Validation-----
# AUC: 85.05 Precision: 86.36 Recall: 82.61
#
# -----svc - Train----------
# AUC: 97.69 Precision: 95.55 Recall: 100.00
#
# -----svc - Validation-----
# AUC: 72.74 Precision: 65.62 Recall: 91.30
#
# -----nusvc - Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----nusvc - Validation-----
# AUC: 84.96 Precision: 90.00 Recall: 78.26
#
# Fold 8
#
# -----qda - Train----------
# AUC: 97.25 Precision: 98.27 Recall: 96.19
#
# -----qda - Validation-----
# AUC: 93.48 Precision: 100.00 Recall: 86.96
#
# -----knn - Train----------
# AUC: 88.16 Precision: 93.27 Recall: 82.20
#
# -----knn - Validation-----
# AUC: 87.05 Precision: 94.74 Recall: 78.26
#
# -----mlp - Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----mlp - Validation-----
# AUC: 80.53 Precision: 93.75 Recall: 65.22
#
# -----svc - Train----------
# AUC: 98.95 Precision: 97.93 Recall: 100.00
#
# -----svc - Validation-----
# AUC: 97.92 Precision: 95.83 Recall: 100.00
#
# -----nusvc - Train----------
# AUC: 99.79 Precision: 100.00 Recall: 99.58
#
# -----nusvc - Validation-----
# AUC: 86.96 Precision: 100.00 Recall: 73.91
#
# Fold 9
#
# -----qda - Train----------
# AUC: 97.46 Precision: 98.70 Recall: 96.19
#
# -----qda - Validation-----
# AUC: 95.83 Precision: 92.00 Recall: 100.00
#
# -----knn - Train----------
# AUC: 87.31 Precision: 93.56 Recall: 80.08
#
# -----knn - Validation-----
# AUC: 85.05 Precision: 86.36 Recall: 82.61
#
# -----mlp - Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----mlp - Validation-----
# AUC: 87.50 Precision: 79.31 Recall: 100.00
#
# -----svc - Train----------
# AUC: 98.32 Precision: 96.72 Recall: 100.00
#
# -----svc - Validation-----
# AUC: 85.42 Precision: 76.67 Recall: 100.00
#
# -----nusvc - Train----------
# AUC: 99.79 Precision: 100.00 Recall: 99.58
#
# -----nusvc - Validation-----
# AUC: 93.75 Precision: 88.46 Recall: 100.00
#
# Fold 10
#
# -----qda - Train----------
# AUC: 97.89 Precision: 98.71 Recall: 97.03
#
# -----qda - Validation-----
# AUC: 82.61 Precision: 85.71 Recall: 78.26
#
# -----knn - Train----------
# AUC: 86.70 Precision: 91.00 Recall: 81.36
#
# -----knn - Validation-----
# AUC: 80.43 Precision: 88.89 Recall: 69.57
#
# -----mlp - Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----mlp - Validation-----
# AUC: 91.30 Precision: 91.30 Recall: 91.30
#
# -----svc - Train----------
# AUC: 98.74 Precision: 97.52 Recall: 100.00
#
# -----svc - Validation-----
# AUC: 86.96 Precision: 84.00 Recall: 91.30
#
# -----nusvc - Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----nusvc - Validation-----
# AUC: 82.61 Precision: 85.71 Recall: 78.26
#
# Fold 11
#
# -----qda - Train----------
# AUC: 97.04 Precision: 98.26 Recall: 95.76
#
# -----qda - Validation-----
# AUC: 93.48 Precision: 95.45 Recall: 91.30
#
# -----knn - Train----------
# AUC: 87.77 Precision: 90.83 Recall: 83.90
#
# -----knn - Validation-----
# AUC: 84.78 Precision: 100.00 Recall: 69.57
#
# -----mlp - Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# ...
#
# -----knn - Train----------
# AUC: 88.25 Precision: 84.80 Recall: 93.39
#
# -----knn - Validation-----
# AUC: 89.13 Precision: 84.62 Recall: 95.65
#
# -----mlp - Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----mlp - Validation-----
# AUC: 86.96 Precision: 90.48 Recall: 82.61
#
# -----svc - Train----------
# AUC: 99.56 Precision: 99.13 Recall: 100.00
#
# -----svc - Validation-----
# AUC: 86.96 Precision: 81.48 Recall: 95.65
#
# -----nusvc - Train----------
# AUC: 99.78 Precision: 99.56 Recall: 100.00
#
# -----nusvc - Validation-----
# AUC: 82.61 Precision: 77.78 Recall: 91.30
#
# Fold 6
#
# -----qda - Train----------
# AUC: 97.79 Precision: 98.65 Recall: 96.92
#
# -----qda - Validation-----
# AUC: 97.83 Precision: 95.83 Recall: 100.00
#
# -----knn - Train----------
# AUC: 88.93 Precision: 87.66 Recall: 90.75
#
# -----knn - Validation-----
# AUC: 93.48 Precision: 95.45 Recall: 91.30
#
# -----mlp - Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----mlp - Validation-----
# AUC: 89.13 Precision: 87.50 Recall: 91.30
#
# -----svc - Train----------
# AUC: 99.78 Precision: 99.56 Recall: 100.00
#
# -----svc - Validation-----
# AUC: 84.78 Precision: 76.67 Recall: 100.00
#
# -----nusvc - Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----nusvc - Validation-----
# AUC: 89.13 Precision: 82.14 Recall: 100.00
#
# Fold 7
#
# -----qda - Train----------
# AUC: 98.23 Precision: 98.67 Recall: 97.80
#
# -----qda - Validation-----
# AUC: 95.55 Precision: 95.65 Recall: 95.65
#
# -----knn - Train----------
# AUC: 87.63 Precision: 85.19 Recall: 91.19
#
# -----knn - Validation-----
# AUC: 93.18 Precision: 88.46 Recall: 100.00
#
# -----mlp - Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----mlp - Validation-----
# AUC: 84.19 Precision: 78.57 Recall: 95.65
#
# -----svc - Train----------
# AUC: 99.78 Precision: 99.56 Recall: 100.00
#
# -----svc - Validation-----
# AUC: 93.18 Precision: 88.46 Recall: 100.00
#
# -----nusvc - Train----------
# AUC: 99.78 Precision: 99.56 Recall: 100.00
#
# -----nusvc - Validation-----
# AUC: 90.91 Precision: 85.19 Recall: 100.00
#
# Fold 8
#
# -----qda - Train----------
# AUC: 97.35 Precision: 97.78 Recall: 96.92
#
# -----qda - Validation-----
# AUC: 95.65 Precision: 100.00 Recall: 91.30
#
# -----knn - Train----------
# AUC: 90.06 Precision: 88.89 Recall: 91.63
#
# -----knn - Validation-----
# AUC: 75.49 Precision: 75.00 Recall: 78.26
#
# -----mlp - Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----mlp - Validation-----
# AUC: 82.21 Precision: 82.61 Recall: 82.61
#
# -----svc - Train----------
# AUC: 99.78 Precision: 99.56 Recall: 100.00
#
# -----svc - Validation-----
# AUC: 86.76 Precision: 90.48 Recall: 82.61
#
# -----nusvc - Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----nusvc - Validation-----
# AUC: 84.49 Precision: 86.36 Recall: 82.61
#
# Fold 9
#
# -----qda - Train----------
# AUC: 98.24 Precision: 98.25 Recall: 98.25
#
# -----qda - Validation-----
# AUC: 88.64 Precision: 86.96 Recall: 90.91
#
# -----knn - Train----------
# AUC: 90.08 Precision: 87.97 Recall: 92.98
#
# -----knn - Validation-----
# AUC: 81.82 Precision: 81.82 Recall: 81.82
#
# -----mlp - Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----mlp - Validation-----
# AUC: 72.73 Precision: 75.00 Recall: 68.18
#
# -----svc - Train----------
# AUC: 99.78 Precision: 99.56 Recall: 100.00
#
# -----svc - Validation-----
# AUC: 84.09 Precision: 82.61 Recall: 86.36
#
# -----nusvc - Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----nusvc - Validation-----
# AUC: 88.64 Precision: 86.96 Recall: 90.91
#
# Fold 10
#
# -----qda - Train----------
# AUC: 97.36 Precision: 97.79 Recall: 96.93
#
# -----qda - Validation-----
# AUC: 88.64 Precision: 86.96 Recall: 90.91
#
# -----knn - Train----------
# AUC: 89.64 Precision: 89.18 Recall: 90.35
#
# -----knn - Validation-----
# AUC: 84.09 Precision: 82.61 Recall: 86.36
#
# -----mlp - Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----mlp - Validation-----
# AUC: 86.36 Precision: 90.00 Recall: 81.82
#
# -----svc - Train----------
# AUC: 99.78 Precision: 99.56 Recall: 100.00
#
# -----svc - Validation-----
# AUC: 88.64 Precision: 84.00 Recall: 95.45
#
# -----nusvc - Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----nusvc - Validation-----
# AUC: 93.18 Precision: 91.30 Recall: 95.45
#
# Fold 11
#
# -----qda - Train----------
# AUC: 97.58 Precision: 98.22 Recall: 96.93
#
# -----qda - Validation-----
# AUC: 95.45 Precision: 100.00 Recall: 90.91
#
# -----knn - Train----------
# AUC: 90.29 Precision: 87.70 Recall: 93.86
#
# -----knn - Validation-----
# AUC: 86.36 Precision: 90.00 Recall: 81.82
#
# -----mlp - Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----mlp - Validation-----
# AUC: 90.91 Precision: 95.00 Recall: 86.36
#
# -----svc - Train----------
# AUC: 99.78 Precision: 99.56 Recall: 100.00
#
# -----svc - Validation-----
# AUC: 77.27 Precision: 75.00 Recall: 81.82
#
# -----nusvc - Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----nusvc - Validation-----
# AUC: 84.09 Precision: 82.61 Recall: 86.36
#
# wheezy-copper-turtle-magic 120
#
# Fold 1
#
# -----qda - Train----------
# AUC: 95.62 Precision: 95.18 Recall: 96.34
#
# -----qda - Validation-----
# AUC: 89.75 Precision: 88.46 Recall: 92.00
#
# -----knn - Train----------
# AUC: 87.25 Precision: 85.71 Recall: 90.24
#
# -----knn - Validation-----
# AUC: 85.67 Precision: 84.62 Recall: 88.00
#
# -----mlp - Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----mlp - Validation-----
# AUC: 81.58 Precision: 80.77 Recall: 84.00
#
# -----svc - Train----------
# AUC: 99.39 Precision: 100.00 Recall: 98.78
#
# -----svc - Validation-----
# AUC: 79.75 Precision: 85.71 Recall: 72.00
#
# -----nusvc - Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----nusvc - Validation-----
# AUC: 85.83 Precision: 90.91 Recall: 80.00
#
# Fold 2
#
# -----qda - Train----------
# AUC: 95.61 Precision: 94.82 Recall: 96.75
#
# -----qda - Validation-----
# AUC: 81.58 Precision: 80.77 Recall: 84.00
#
# -----knn - Train----------
# AUC: 87.52 Precision: 87.80 Recall: 87.80
#
# -----knn - Validation-----
# AUC: 79.42 Precision: 75.86 Recall: 88.00
#
# -----mlp - Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----mlp - Validation-----
# AUC: 83.67 Precision: 84.00 Recall: 84.00
#
# -----svc - Train----------
# AUC: 98.37 Precision: 100.00 Recall: 96.75
#
# -----svc - Validation-----
# AUC: 81.92 Precision: 94.44 Recall: 68.00
#
# -----nusvc - Train----------
# AUC: 99.80 Precision: 100.00 Recall: 99.59
#
# -----nusvc - Validation-----
# AUC: 85.83 Precision: 90.91 Recall: 80.00
#
# Fold 3
#
# -----qda - Train----------
# AUC: 96.03 Precision: 95.58 Recall: 96.75
#
# -----qda - Validation-----
# AUC: 85.50 Precision: 80.00 Recall: 96.00
#
# -----knn - Train----------
# AUC: 89.53 Precision: 87.69 Recall: 92.68
#
# -----knn - Validation-----
# AUC: 77.33 Precision: 73.33 Recall: 88.00
#
# -----mlp - Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----mlp - Validation-----
# AUC: 77.42 Precision: 75.00 Recall: 84.00
#
# -----svc - Train----------
# AUC: 98.78 Precision: 100.00 Recall: 97.56
#
# -----svc - Validation-----
# AUC: 87.75 Precision: 88.00 Recall: 88.00
#
# -----nusvc - Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----nusvc - Validation-----
# AUC: 87.58 Precision: 82.76 Recall: 96.00
#
# Fold 4
#
# -----qda - Train----------
# AUC: 96.02 Precision: 95.22 Recall: 97.15
#
# -----qda - Validation-----
# AUC: 93.83 Precision: 92.31 Recall: 96.00
#
# -----knn - Train----------
# AUC: 87.45 Precision: 85.77 Recall: 90.65
#
# -----knn - Validation-----
# AUC: 87.58 Precision: 82.76 Recall: 96.00
#
# -----mlp - Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----mlp - Validation-----
# AUC: 93.83 Precision: 92.31 Recall: 96.00
#
# -----svc - Train----------
# AUC: 99.39 Precision: 100.00 Recall: 98.78
#
# -----svc - Validation-----
# AUC: 94.00 Precision: 100.00 Recall: 88.00
#
# -----nusvc - Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----nusvc - Validation-----
# AUC: 91.83 Precision: 92.00 Recall: 92.00
#
# Fold 5
#
# -----qda - Train----------
# AUC: 96.24 Precision: 95.60 Recall: 97.15
#
# -----qda - Validation-----
# AUC: 79.75 Precision: 85.71 Recall: 72.00
#
# -----knn - Train----------
# AUC: 88.33 Precision: 88.00 Recall: 89.43
#
# -----knn - Validation-----
# AUC: 77.67 Precision: 81.82 Recall: 72.00
#
# -----mlp - Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----mlp - Validation-----
# AUC: 77.75 Precision: 85.00 Recall: 68.00
#
# -----svc - Train----------
# AUC: 97.15 Precision: 100.00 Recall: 94.31
#
# -----svc - Validation-----
# AUC: 71.92 Precision: 92.31 Recall: 48.00
#
# -----nusvc - Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----nusvc - Validation-----
# AUC: 75.75 Precision: 84.21 Recall: 64.00
#
# Fold 6
#
# -----qda - Train----------
# AUC: 95.81 Precision: 94.84 Recall: 97.15
#
# -----qda - Validation-----
# AUC: 96.00 Precision: 100.00 Recall: 92.00
#
# -----knn - Train----------
# AUC: 88.15 Precision: 88.57 Recall: 88.21
#
# -----knn - Validation-----
# AUC: 83.67 Precision: 84.00 Recall: 84.00
#
# -----mlp - Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----mlp - Validation-----
# AUC: 89.83 Precision: 91.67 Recall: 88.00
#
# -----svc - Train----------
# AUC: 97.15 Precision: 100.00 Recall: 94.31
#
# -----svc - Validation-----
# AUC: 80.00 Precision: 100.00 Recall: 60.00
#
# -----nusvc - Train----------
# AUC: 99.80 Precision: 100.00 Recall: 99.59
#
# -----nusvc - Validation-----
# AUC: 88.00 Precision: 100.00 Recall: 76.00
#
# Fold 7
#
# -----qda - Train----------
# AUC: 95.42 Precision: 94.80 Recall: 96.34
#
# -----qda - Validation-----
# AUC: 87.13 Precision: 82.76 Recall: 96.00
#
# -----knn - Train----------
# AUC: 86.26 Precision: 85.16 Recall: 88.62
#
# -----knn - Validation-----
# AUC: 76.96 Precision: 76.92 Recall: 80.00
#
# -----mlp - Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----mlp - Validation-----
# AUC: 85.13 Precision: 82.14 Recall: 92.00
#
# -----svc - Train----------
# AUC: 98.58 Precision: 100.00 Recall: 97.15
#
# -----svc - Validation-----
# AUC: 85.65 Precision: 90.91 Recall: 80.00
#
# -----nusvc - Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----nusvc - Validation-----
# AUC: 85.13 Precision: 82.14 Recall: 92.00
#
# Fold 8
#
# -----qda - Train----------
# AUC: 96.24 Precision: 95.26 Recall: 97.57
#
# -----qda - Validation-----
# AUC: 85.14 Precision: 86.96 Recall: 83.33
#
# -----knn - Train----------
# AUC: 87.78 Precision: 88.21 Recall: 87.85
#
# -----knn - Validation-----
# AUC: 80.89 Precision: 82.61 Recall: 79.17
#
# -----mlp - Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----mlp - Validation-----
# AUC: 76.63 Precision: 78.26 Recall: 75.00
#
# -----svc - Train----------
# AUC: 96.56 Precision: 100.00 Recall: 93.12
#
# -----svc - Validation-----
# AUC: 72.83 Precision: 92.31 Recall: 50.00
#
# -----nusvc - Train----------
# AUC: 99.60 Precision: 100.00 Recall: 99.19
#
# -----nusvc - Validation-----
# AUC: 76.90 Precision: 88.24 Recall: 62.50
#
# Fold 9
#
# -----qda - Train----------
# AUC: 96.04 Precision: 95.24 Recall: 97.17
#
# -----qda - Validation-----
# AUC: 89.22 Precision: 85.19 Recall: 95.83
#
# -----knn - Train----------
# AUC: 86.31 Precision: 86.06 Recall: 87.45
#
# -----knn - Validation-----
# AUC: 87.23 Precision: 87.50 Recall: 87.50
#
# -----mlp - Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----mlp - Validation-----
# AUC: 89.22 Precision: 85.19 Recall: 95.83
#
# -----svc - Train----------
# AUC: 97.57 Precision: 100.00 Recall: 95.14
#
# -----svc - Validation-----
# AUC: 85.42 Precision: 100.00 Recall: 70.83
#
# -----nusvc - Train----------
# AUC: 99.80 Precision: 100.00 Recall: 99.60
#
# -----nusvc - Validation-----
# AUC: 91.67 Precision: 100.00 Recall: 83.33
#
# Fold 10
#
# -----qda - Train----------
# AUC: 96.04 Precision: 95.24 Recall: 97.17
#
# -----qda - Validation-----
# AUC: 82.88 Precision: 80.77 Recall: 87.50
#
# -----knn - Train----------
# AUC: 87.93 Precision: 86.49 Recall: 90.69
#
# -----knn - Validation-----
# AUC: 82.79 Precision: 78.57 Recall: 91.67
#
# -----mlp - Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----mlp - Validation-----
# AUC: 78.62 Precision: 76.92 Recall: 83.33
#
# -----svc - Train----------
# AUC: 97.77 Precision: 100.00 Recall: 95.55
#
# -----svc - Validation-----
# AUC: 76.99 Precision: 93.33 Recall: 58.33
#
# -----nusvc - Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----nusvc - Validation-----
# AUC: 85.24 Precision: 90.48 Recall: 79.17
#
# Fold 11
#
# -----qda - Train----------
# AUC: 95.64 Precision: 95.20 Recall: 96.36
#
# -----qda - Validation-----
# AUC: 95.65 Precision: 92.31 Recall: 100.00
#
# -----knn - Train----------
# AUC: 86.25 Precision: 84.41 Recall: 89.88
#
# -----knn - Validation-----
# AUC: 87.23 Precision: 87.50 Recall: 87.50
#
# -----mlp - Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----mlp - Validation-----
# AUC: 91.58 Precision: 95.45 Recall: 87.50
#
# -----svc - Train----------
# AUC: 98.38 Precision: 100.00 Recall: 96.76
#
# -----svc - Validation-----
# AUC: 85.42 Precision: 100.00 Recall: 70.83
#
# -----nusvc - Train----------
# AUC: 99.80 Precision: 100.00 Recall: 99.60
#
# -----nusvc - Validation-----
# AUC: 87.32 Precision: 90.91 Recall: 83.33
#
# wheezy-copper-turtle-magic 121
#
# Fold 1
#
# -----qda - Train----------
# AUC: 98.04 Precision: 98.22 Recall: 97.79
#
# -----qda - Validation-----
# AUC: 84.87 Precision: 94.44 Recall: 73.91
#
# -----knn - Train----------
# AUC: 89.99 Precision: 90.91 Recall: 88.50
#
# -----knn - Validation-----
# AUC: 76.36 Precision: 83.33 Recall: 65.22
#
# -----mlp - Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----mlp - Validation-----
# AUC: 76.36 Precision: 83.33 Recall: 65.22
#
# -----svc - Train----------
# AUC: 98.23 Precision: 100.00 Recall: 96.46
#
# -----svc - Validation-----
# AUC: 76.09 Precision: 100.00 Recall: 52.17
#
# -----nusvc - Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----nusvc - Validation-----
# AUC: 78.26 Precision: 100.00 Recall: 56.52
#
# Fold 2
#
# -----qda - Train----------
# AUC: 98.03 Precision: 99.10 Recall: 96.90
#
# -----qda - Validation-----
# AUC: 89.31 Precision: 90.91 Recall: 86.96
#
# -----knn - Train----------
# AUC: 88.17 Precision: 93.00 Recall: 82.30
#
# -----knn - Validation-----
# AUC: 78.53 Precision: 84.21 Recall: 69.57
#
# -----mlp - Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----mlp - Validation-----
# AUC: 72.28 Precision: 72.73 Recall: 69.57
#
# -----svc - Train----------
# AUC: 97.35 Precision: 100.00 Recall: 94.69
#
# -----svc - Validation-----
# AUC: 69.66 Precision: 90.91 Recall: 43.48
#
# -----nusvc - Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----nusvc - Validation-----
# AUC: 80.62 Precision: 88.89 Recall: 69.57
#
# Fold 3
#
# -----qda - Train----------
# AUC: 97.17 Precision: 97.76 Recall: 96.46
#
# -----qda - Validation-----
# AUC: 97.83 Precision: 100.00 Recall: 95.65
#
# -----knn - Train----------
# AUC: 86.44 Precision: 91.00 Recall: 80.53
#
# -----knn - Validation-----
# AUC: 91.58 Precision: 88.00 Recall: 95.65
#
# -----mlp - Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----mlp - Validation-----
# AUC: 89.31 Precision: 90.91 Recall: 86.96
#
# -----svc - Train----------
# AUC: 97.35 Precision: 100.00 Recall: 94.69
#
# -----svc - Validation-----
# AUC: 89.13 Precision: 100.00 Recall: 78.26
#
# -----nusvc - Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----nusvc - Validation-----
# AUC: 89.22 Precision: 95.00 Recall: 82.61
#
# Fold 4
#
# -----qda - Train----------
# AUC: 97.38 Precision: 98.20 Recall: 96.46
#
# -----qda - Validation-----
# AUC: 97.83 Precision: 100.00 Recall: 95.65
#
# -----knn - Train----------
# AUC: 87.09 Precision: 91.54 Recall: 81.42
#
# -----knn - Validation-----
# AUC: 87.05 Precision: 94.74 Recall: 78.26
#
# -----mlp - Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----mlp - Validation-----
# AUC: 82.88 Precision: 85.71 Recall: 78.26
#
# -----svc - Train----------
# AUC: 97.79 Precision: 100.00 Recall: 95.58
#
# -----svc - Validation-----
# AUC: 69.66 Precision: 90.91 Recall: 43.48
#
# -----nusvc - Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----nusvc - Validation-----
# AUC: 74.09 Precision: 86.67 Recall: 56.52
#
# Fold 5

# %% [markdown]
# # Ensemble models
#
# Here you can ensemble any combination of models, and give the desired weight for each one.

# %%
train['preds_top2'] = (train['preds_qda'] * 0.5) + (train['preds_nusvc'] * 0.5)
test['target_top2'] = (test['target_qda'] * 0.5) + (test['target_nusvc'] * 0.5)

train['preds_top3'] = (train['preds_qda'] * 0.35) + (train['preds_mlp'] * 0.3) + (train['preds_nusvc'] * 0.35)
test['target_top3'] = (test['target_qda'] * 0.35) + (test['target_mlp'] * 0.3) + (test['target_nusvc'] * 0.35)

train['preds_top4'] = (train['preds_qda'] * 0.25) + (train['preds_mlp'] * 0.25) + (train['preds_svc'] * 0.25) + (train['preds_nusvc'] * 0.25)
test['target_top4'] = (test['target_qda'] * 0.25) + (test['target_mlp'] * 0.25) + (test['target_svc'] * 0.25) + (test['target_nusvc'] * 0.25)

train['preds_avg'] = (train['preds_qda'] * 0.2) + (train['preds_knn'] * 0.2) + (train['preds_mlp'] * 0.2) + (train['preds_svc'] * 0.2) + (train['preds_nusvc'] * 0.2)
test['target_avg'] = (test['target_qda'] * 0.2) + (test['target_knn'] * 0.2) + (test['target_mlp'] * 0.2) + (test['target_svc'] * 0.2) + (test['target_nusvc'] * 0.2)

# %% [markdown]
# # Model evaluation
# ## Confusion matrix (averaged model)

# %%
f = plt.subplots(1, 1, figsize=(16, 5), sharex=True)
train_cnf_matrix = confusion_matrix(train['target'], [np.round(x) for x in train['preds_avg']])
train_cnf_matrix_norm = train_cnf_matrix / train_cnf_matrix.sum(axis=1)[:, np.newaxis]
train_df_cm = pd.DataFrame(train_cnf_matrix_norm, index=[0, 1], columns=[0, 1])
sns.heatmap(train_df_cm, annot=True, fmt='.2f', cmap="Blues")
plt.show()

# %% [markdown]
# ## Confusion matrix (knn model)

# %% [markdown]
# ## Confusion matrix (SVC model)

# %%
f = plt.subplots(1, 1, figsize=(16, 5), sharex=True)
train_cnf_matrix = confusion_matrix(train['target'], [np.round(x) for x in train['preds_svc']])
train_cnf_matrix_norm = train_cnf_matrix / train_cnf_matrix.sum(axis=1)[:, np.newaxis]
train_df_cm = pd.DataFrame(train_cnf_matrix_norm, index=[0, 1], columns=[0, 1])
sns.heatmap(train_df_cm, annot=True, fmt='.2f', cmap="Blues")
plt.show()

# %% [markdown]
# ## Metrics ROC AUC

# %%
print('QDA AUC %.2f' % roc_auc_score(train['target'], train['preds_qda']))
print('KNN AUC %.2f' % roc_auc_score(train['target'], train['preds_knn']))
print('MLP AUC %.2f' % roc_auc_score(train['target'], train['preds_mlp']))
print('SVC AUC %.2f' % roc_auc_score(train['target'], train['preds_svc']))
print('NuSVC AUC %.2f' % roc_auc_score(train['target'], train['preds_nusvc']))
print('Top 2 AUC %.2f' % roc_auc_score(train['target'], train['preds_top2']))
print('Top 3 AUC %.2f' % roc_auc_score(train['target'], train['preds_top3']))
print('Top 4 AUC %.2f' % roc_auc_score(train['target'], train['preds_top4']))
print('Averaged AUC %.2f' % roc_auc_score(train['target'], train['preds_avg']))
# Out:
# QDA AUC 0.99
# KNN AUC 0.95
# MLP AUC 1.00
# SVC AUC 1.00
# NuSVC AUC 1.00
# Top 2 AUC 1.00
# Top 3 AUC 1.00
# Top 4 AUC 1.00
# Averaged AUC 1.00

# %% [markdown]
# ### Test set with all models predictions

# %%
test[['id', 'target_avg', 'target_qda', 'target_knn', 'target_mlp', 'target_svc', 'target_nusvc']].head()
# Out:
#                                  id      ...       target_nusvc
# 0  1c13f2701648e0b0d46d8a2a5a131a53      ...           0.782619
# 1  ba88c155ba898fc8b5099893036ef205      ...           0.559281
# 2  7cbab5cea99169139e7e6d8ff74ebb77      ...           0.382656
# 3  ca820ad57809f62eb7b4d13f5d4371a0      ...           0.625869
# 4  7baaf361537fbd8a1aaa2c97a6d4ccc7      ...           0.451573
#
# [5 rows x 7 columns]

# %% [markdown]
# # Test predictions
# Now you can output predictions for each individual model and the ensembled models as well.
#
# #### Averaged models submission

# %%
submission = test[['id', 'target_avg']]
submission.columns = ['id', 'target']
submission.to_csv('submission_avg.csv', index=False)
submission.head()
# Out:
#                                  id    target
# 0  1c13f2701648e0b0d46d8a2a5a131a53  0.728040
# 1  ba88c155ba898fc8b5099893036ef205  0.672158
# 2  7cbab5cea99169139e7e6d8ff74ebb77  0.331248
# 3  ca820ad57809f62eb7b4d13f5d4371a0  0.339477
# 4  7baaf361537fbd8a1aaa2c97a6d4ccc7  0.359828

# %%
submission = test[['id', 'target_top2']]
submission.columns = ['id', 'target']
submission.to_csv('submission_top2.csv', index=False)
submission.head()
# Out:
#                                  id    target
# 0  1c13f2701648e0b0d46d8a2a5a131a53  0.891295
# 1  ba88c155ba898fc8b5099893036ef205  0.773628
# 2  7cbab5cea99169139e7e6d8ff74ebb77  0.191328
# 3  ca820ad57809f62eb7b4d13f5d4371a0  0.350569
# 4  7baaf361537fbd8a1aaa2c97a6d4ccc7  0.444835

# %%
submission = test[['id', 'target_top3']]
submission.columns = ['id', 'target']
submission.to_csv('submission_top3.csv', index=False)
submission.head()
# Out:
#                                  id    target
# 0  1c13f2701648e0b0d46d8a2a5a131a53  0.808650
# 1  ba88c155ba898fc8b5099893036ef205  0.790270
# 2  7cbab5cea99169139e7e6d8ff74ebb77  0.230442
# 3  ca820ad57809f62eb7b4d13f5d4371a0  0.290419
# 4  7baaf361537fbd8a1aaa2c97a6d4ccc7  0.347680

# %%
submission = test[['id', 'target_top4']]
submission.columns = ['id', 'target']
submission.to_csv('submission_top4.csv', index=False)
submission.head()
# Out:
#                                  id    target
# 0  1c13f2701648e0b0d46d8a2a5a131a53  0.784381
# 1  ba88c155ba898fc8b5099893036ef205  0.743941
# 2  7cbab5cea99169139e7e6d8ff74ebb77  0.272349
# 3  ca820ad57809f62eb7b4d13f5d4371a0  0.330764
# 4  7baaf361537fbd8a1aaa2c97a6d4ccc7  0.353529

# %%
submission = test[['id', 'target_qda']]
submission.columns = ['id', 'target']
submission.to_csv('submission_qda.csv', index=False)
submission.head()
# Out:
#                                  id        target
# 0  1c13f2701648e0b0d46d8a2a5a131a53  9.999712e-01
# 1  ba88c155ba898fc8b5099893036ef205  9.879759e-01
# 2  7cbab5cea99169139e7e6d8ff74ebb77  2.529365e-07
# 3  ca820ad57809f62eb7b4d13f5d4371a0  7.526842e-02
# 4  7baaf361537fbd8a1aaa2c97a6d4ccc7  4.380961e-01

# %%
submission = test[['id', 'target_knn']]
submission.columns = ['id', 'target']
submission.to_csv('submission_knn.csv', index=False)
submission.head()
# Out:
#                                  id    target
# 0  1c13f2701648e0b0d46d8a2a5a131a53  0.502674
# 1  ba88c155ba898fc8b5099893036ef205  0.385027
# 2  7cbab5cea99169139e7e6d8ff74ebb77  0.566845
# 3  ca820ad57809f62eb7b4d13f5d4371a0  0.374332
# 4  7baaf361537fbd8a1aaa2c97a6d4ccc7  0.385027

# %%
submission = test[['id', 'target_mlp']]
submission.columns = ['id', 'target']
submission.to_csv('submission_mlp.csv', index=False)
submission.head()
# Out:
#                                  id    target
# 0  1c13f2701648e0b0d46d8a2a5a131a53  0.615811
# 1  ba88c155ba898fc8b5099893036ef205  0.829102
# 2  7cbab5cea99169139e7e6d8ff74ebb77  0.321707
# 3  ca820ad57809f62eb7b4d13f5d4371a0  0.150071
# 4  7baaf361537fbd8a1aaa2c97a6d4ccc7  0.120986

# %%
submission = test[['id', 'target_svc']]
submission.columns = ['id', 'target']
submission.to_csv('submission_svc.csv', index=False)
submission.head()
# Out:
#                                  id    target
# 0  1c13f2701648e0b0d46d8a2a5a131a53  0.739123
# 1  ba88c155ba898fc8b5099893036ef205  0.599403
# 2  7cbab5cea99169139e7e6d8ff74ebb77  0.385033
# 3  ca820ad57809f62eb7b4d13f5d4371a0  0.471846
# 4  7baaf361537fbd8a1aaa2c97a6d4ccc7  0.403460

# %%
submission = test[['id', 'target_nusvc']]
submission.columns = ['id', 'target']
submission.to_csv('submission_nusvc.csv', index=False)
submission.head()
# Out:
#                                  id    target
# 0  1c13f2701648e0b0d46d8a2a5a131a53  0.782619
# 1  ba88c155ba898fc8b5099893036ef205  0.559281
# 2  7cbab5cea99169139e7e6d8ff74ebb77  0.382656
# 3  ca820ad57809f62eb7b4d13f5d4371a0  0.625869
# 4  7baaf361537fbd8a1aaa2c97a6d4ccc7  0.451573
