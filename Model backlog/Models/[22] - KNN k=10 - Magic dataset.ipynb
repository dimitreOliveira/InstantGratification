# %% [markdown]
# # Dependencies

# %%
import warnings
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

from sklearn.neighbors import KNeighborsClassifier
from sklearn.feature_selection import VarianceThreshold
from sklearn.preprocessing import MinMaxScaler, StandardScaler
from sklearn.model_selection import train_test_split, StratifiedKFold
from sklearn.metrics import confusion_matrix, roc_auc_score, recall_score, precision_score

# Set seeds to make the experiment more reproducible.
from numpy.random import seed
seed(0)

# %matplotlib inline
sns.set_style("whitegrid")
warnings.filterwarnings("ignore")

# %% [markdown]
# # Load data

# %%
train = pd.read_csv('../input/train.csv')
test = pd.read_csv('../input/test.csv')

# %%
print('Train set shape:', train.shape)
print('Test set shape:', test.shape)
print('Train set overview:')
display(train.head())
# Out:
# Train set shape: (262144, 258)
# Test set shape: (131073, 257)
# Train set overview:
#                                  id   ...    target
# 0  707b395ecdcbb4dc2eabea00e4d1b179   ...         0
# 1  5880c03c6582a7b42248668e56b4bdec   ...         0
# 2  4ccbcb3d13e5072ff1d9c61afe2c4f77   ...         1
# 3  e350f17a357f12a1941f0837afb7eb8d   ...         0
# 4  a8f910ea6075b6376af079055965ff68   ...         0
#
# [5 rows x 258 columns]

# %% [markdown]
# ## Preprocess

# %% [markdown]
# # Model
#
# ## Model parameters

# %%
N_FOLDS = 11

# %%
# INITIALIZE VARIABLES
cols = [c for c in train.columns if c not in ['id', 'target', 'wheezy-copper-turtle-magic', 'preds']]
test['target'] = 0
train['preds'] = 0

# BUILD 512 MODELS
for i in range(512):
    print('wheezy-copper-turtle-magic {}\n'.format(i))
    
    # EXTRACT SUBSET OF DATASET WHERE WHEEZY-MAGIC EQUALS I
    train2 = train[train['wheezy-copper-turtle-magic']==i]
    test2 = test[test['wheezy-copper-turtle-magic']==i]
    idx1 = train2.index
    idx2 = test2.index
    train2.reset_index(drop=True, inplace=True)
    
    # FEATURE SELECTION (USE APPROX 40 OF 255 FEATURES)
    sel = VarianceThreshold(threshold=1.5).fit(train2[cols])
    train3 = sel.transform(train2[cols])
    test3 = sel.transform(test2[cols])

    skf = StratifiedKFold(n_splits=N_FOLDS, random_state=0)
    counter = 0

    for train_index, val_index in skf.split(train3, train2['target']):
        counter += 1
        print('Fold {}\n'.format(counter))
        model = KNeighborsClassifier(n_neighbors=10, n_jobs=-1)
        model.fit(train3[train_index,:], train2.loc[train_index]['target'])
        
        train_predictions = model.predict(train3[train_index,:])
        val_predictions = model.predict(train3[val_index,:])

        train_auc = roc_auc_score(train2.loc[train_index]['target'], train_predictions) * 100
        val_auc = roc_auc_score(train2.loc[val_index]['target'], val_predictions) * 100
        train_precision = precision_score(train2.loc[train_index]['target'], train_predictions) * 100
        val_precision = precision_score(train2.loc[val_index]['target'], val_predictions) * 100
        train_recall = recall_score(train2.loc[train_index]['target'], train_predictions) * 100
        val_recall = recall_score(train2.loc[val_index]['target'], val_predictions) * 100
        print('-----Train----------')
        print('AUC: %.2f Precision: %.2f Recall: %.2f \n' % (train_auc, train_precision, train_recall))
        print('-----Validation-----')
        print('AUC: %.2f Precision: %.2f Recall: %.2f \n' % (val_auc, val_precision, val_recall))

        # Make predictions
        train['preds'].loc[idx1] += model.predict_proba(train3)[:,1] / N_FOLDS
        test['target'].loc[idx2] += model.predict_proba(test3)[:,1] / N_FOLDS
# Out:
# wheezy-copper-turtle-magic 0
#
# Fold 1
#
# -----Train----------
# AUC: 89.62 Precision: 93.95 Recall: 84.52
#
# -----Validation-----
# AUC: 87.58 Precision: 95.00 Recall: 79.17
#
# Fold 2
#
# -----Train----------
# AUC: 88.15 Precision: 93.75 Recall: 81.59
#
# -----Validation-----
# AUC: 85.50 Precision: 94.74 Recall: 75.00
#
# Fold 3
#
# -----Train----------
# AUC: 87.74 Precision: 93.27 Recall: 81.17
#
# -----Validation-----
# AUC: 83.58 Precision: 86.36 Recall: 79.17
#
# Fold 4
#
# -----Train----------
# AUC: 87.92 Precision: 95.48 Recall: 79.50
#
# -----Validation-----
# AUC: 79.42 Precision: 85.00 Recall: 70.83
#
# Fold 5
#
# -----Train----------
# AUC: 89.00 Precision: 93.46 Recall: 83.68
#
# -----Validation-----
# AUC: 91.67 Precision: 100.00 Recall: 83.33
#
# Fold 6
#
# -----Train----------
# AUC: 87.53 Precision: 93.24 Recall: 80.75
#
# -----Validation-----
# AUC: 85.42 Precision: 100.00 Recall: 70.83
#
# Fold 7
#
# -----Train----------
# AUC: 88.76 Precision: 95.57 Recall: 81.17
#
# -----Validation-----
# AUC: 77.33 Precision: 84.21 Recall: 66.67
#
# Fold 8
#
# -----Train----------
# AUC: 87.74 Precision: 93.69 Recall: 80.75
#
# -----Validation-----
# AUC: 87.50 Precision: 95.00 Recall: 79.17
#
# Fold 9
#
# -----Train----------
# AUC: 89.82 Precision: 94.81 Recall: 84.10
#
# -----Validation-----
# AUC: 72.92 Precision: 82.35 Recall: 58.33
#
# Fold 10
#
# -----Train----------
# AUC: 87.33 Precision: 93.20 Recall: 80.33
#
# -----Validation-----
# AUC: 83.33 Precision: 94.44 Recall: 70.83
#
# Fold 11
#
# -----Train----------
# AUC: 87.17 Precision: 92.79 Recall: 80.42
#
# -----Validation-----
# AUC: 89.22 Precision: 95.00 Recall: 82.61
#
# wheezy-copper-turtle-magic 1
#
# Fold 1
#
# -----Train----------
# AUC: 93.51 Precision: 93.27 Recall: 93.27
#
# -----Validation-----
# AUC: 87.41 Precision: 81.48 Recall: 95.65
#
# Fold 2
#
# -----Train----------
# AUC: 91.86 Precision: 89.70 Recall: 93.72
#
# -----Validation-----
# AUC: 95.83 Precision: 92.00 Recall: 100.00
#
# Fold 3
#
# -----Train----------
# AUC: 92.92 Precision: 91.30 Recall: 94.17
#
# -----Validation-----
# AUC: 85.05 Precision: 86.36 Recall: 82.61
#
# Fold 4
#
# -----Train----------
# AUC: 92.44 Precision: 91.96 Recall: 92.38
#
# -----Validation-----
# AUC: 83.06 Precision: 80.00 Recall: 86.96
#
# Fold 5
#
# -----Train----------
# AUC: 92.26 Precision: 91.23 Recall: 92.86
#
# -----Validation-----
# AUC: 93.37 Precision: 95.24 Recall: 90.91
#
# Fold 6
#
# -----Train----------
# AUC: 93.35 Precision: 92.14 Recall: 94.20
#
# -----Validation-----
# AUC: 78.41 Precision: 75.00 Recall: 81.82
#
# Fold 7
#
# -----Train----------
# AUC: 91.40 Precision: 90.35 Recall: 91.96
#
# -----Validation-----
# AUC: 86.93 Precision: 86.36 Recall: 86.36
#
# Fold 8
#
# -----Train----------
# AUC: 92.89 Precision: 92.44 Recall: 92.86
#
# -----Validation-----
# AUC: 93.37 Precision: 95.24 Recall: 90.91
#
# Fold 9
#
# -----Train----------
# AUC: 92.20 Precision: 92.73 Recall: 91.07
#
# -----Validation-----
# AUC: 86.74 Precision: 90.00 Recall: 81.82
#
# Fold 10
#
# -----Train----------
# AUC: 92.95 Precision: 90.99 Recall: 94.64
#
# -----Validation-----
# AUC: 91.48 Precision: 87.50 Recall: 95.45
#
# Fold 11
#
# -----Train----------
# AUC: 92.71 Precision: 91.30 Recall: 93.75
#
# -----Validation-----
# AUC: 84.66 Precision: 85.71 Recall: 81.82
#
# wheezy-copper-turtle-magic 2
#
# Fold 1
#
# -----Train----------
# AUC: 87.18 Precision: 92.23 Recall: 80.91
#
# -----Validation-----
# AUC: 78.26 Precision: 88.24 Recall: 65.22
#
# Fold 2
#
# -----Train----------
# AUC: 86.54 Precision: 92.15 Recall: 79.64
#
# -----Validation-----
# AUC: 79.74 Precision: 88.24 Recall: 68.18
#
# Fold 3
#
# -----Train----------
# AUC: 85.60 Precision: 94.35 Recall: 75.57
#
# -----Validation-----
# AUC: 81.92 Precision: 93.75 Recall: 68.18
#
# Fold 4
#
# -----Train----------
# AUC: 87.65 Precision: 93.68 Recall: 80.54
#
# -----Validation-----
# AUC: 82.02 Precision: 88.89 Recall: 72.73
#
# Fold 5
#
# -----Train----------
# AUC: 86.52 Precision: 93.51 Recall: 78.28
#
# -----Validation-----
# AUC: 73.22 Precision: 75.00 Recall: 68.18
#
# Fold 6
#
# -----Train----------
# AUC: 89.23 Precision: 94.36 Recall: 83.26
#
# -----Validation-----
# AUC: 84.39 Precision: 85.71 Recall: 81.82
#
# Fold 7
#
# -----Train----------
# AUC: 86.53 Precision: 93.05 Recall: 78.73
#
# -----Validation-----
# AUC: 75.20 Precision: 86.67 Recall: 59.09
#
# Fold 8
#
# -----Train----------
# AUC: 84.48 Precision: 93.68 Recall: 73.76
#
# -----Validation-----
# AUC: 86.46 Precision: 94.44 Recall: 77.27
#
# Fold 9
#
# -----Train----------
# AUC: 86.99 Precision: 92.67 Recall: 80.09
#
# -----Validation-----
# AUC: 84.19 Precision: 94.12 Recall: 72.73
#
# Fold 10
#
# -----Train----------
# AUC: 85.63 Precision: 92.43 Recall: 77.38
#
# -----Validation-----
# AUC: 79.64 Precision: 93.33 Recall: 63.64
#
# Fold 11
#
# -----Train----------
# AUC: 87.23 Precision: 92.71 Recall: 80.54
#
# -----Validation-----
# AUC: 81.82 Precision: 100.00 Recall: 63.64
#
# wheezy-copper-turtle-magic 3
#
# Fold 1
#
# -----Train----------
# AUC: 89.71 Precision: 86.79 Recall: 95.29
#
# -----Validation-----
# AUC: 87.50 Precision: 81.25 Recall: 100.00
#
# Fold 2
#
# -----Train----------
# AUC: 91.39 Precision: 88.77 Recall: 96.08
#
# -----Validation-----
# AUC: 85.58 Precision: 80.65 Recall: 96.15
#
# Fold 3
#
# -----Train----------
# AUC: 90.60 Precision: 88.60 Recall: 94.51
#
# -----Validation-----
# AUC: 85.74 Precision: 82.76 Recall: 92.31
#
# Fold 4
#
# -----Train----------
# AUC: 90.72 Precision: 87.54 Recall: 96.47
#
# -----Validation-----
# AUC: 91.83 Precision: 89.29 Recall: 96.15
#
# Fold 5
#
# -----Train----------
# AUC: 92.25 Precision: 89.78 Recall: 96.47
#
# -----Validation-----
# AUC: 74.67 Precision: 71.88 Recall: 88.46
#
# Fold 6
#
# -----Train----------
# AUC: 90.45 Precision: 88.85 Recall: 93.73
#
# -----Validation-----
# AUC: 91.30 Precision: 86.67 Recall: 100.00
#
# Fold 7
#
# -----Train----------
# AUC: 91.65 Precision: 89.42 Recall: 95.70
#
# -----Validation-----
# AUC: 89.48 Precision: 88.46 Recall: 92.00
#
# Fold 8
#
# -----Train----------
# AUC: 89.13 Precision: 86.17 Recall: 94.92
#
# -----Validation-----
# AUC: 91.83 Precision: 95.65 Recall: 88.00
#
# Fold 9
#
# -----Train----------
# AUC: 91.40 Precision: 88.53 Recall: 96.48
#
# -----Validation-----
# AUC: 81.13 Precision: 80.77 Recall: 84.00
#
# Fold 10
#
# -----Train----------
# AUC: 92.16 Precision: 91.29 Recall: 94.14
#
# -----Validation-----
# AUC: 91.48 Precision: 88.89 Recall: 96.00
#
# Fold 11
#
# -----Train----------
# AUC: 91.25 Precision: 89.05 Recall: 95.31
#
# -----Validation-----
# AUC: 80.78 Precision: 76.67 Recall: 92.00
#
# wheezy-copper-turtle-magic 4
#
# Fold 1
#
# -----Train----------
# AUC: 87.65 Precision: 90.87 Recall: 83.97
#
# -----Validation-----
# AUC: 81.25 Precision: 80.00 Recall: 83.33
#
# Fold 2
#
# -----Train----------
# AUC: 87.90 Precision: 93.69 Recall: 81.43
#
# -----Validation-----
# AUC: 79.17 Precision: 85.00 Recall: 70.83
#
# Fold 3
#
# -----Train----------
# AUC: 88.14 Precision: 95.02 Recall: 80.59
#
# -----Validation-----
# AUC: 91.58 Precision: 95.45 Recall: 87.50
#
# Fold 4
#
# -----Train----------
# AUC: 87.91 Precision: 93.27 Recall: 81.86
#
# -----Validation-----
# AUC: 91.67 Precision: 100.00 Recall: 83.33
#
# Fold 5
#
# -----Train----------
# AUC: 87.71 Precision: 94.53 Recall: 80.17
#
# -----Validation-----
# AUC: 87.50 Precision: 100.00 Recall: 75.00
#
# Fold 6
#
# -----Train----------
# AUC: 89.20 Precision: 95.15 Recall: 82.70
#
# -----Validation-----
# AUC: 87.32 Precision: 90.91 Recall: 83.33
#
# Fold 7
#
# -----Train----------
# AUC: 87.49 Precision: 93.20 Recall: 81.01
#
# -----Validation-----
# AUC: 87.32 Precision: 90.91 Recall: 83.33
#
# Fold 8
#
# -----Train----------
# AUC: 88.13 Precision: 93.72 Recall: 81.86
#
# -----Validation-----
# AUC: 83.06 Precision: 86.36 Recall: 79.17
#
# Fold 9
#
# -----Train----------
# AUC: 87.74 Precision: 93.69 Recall: 81.09
#
# -----Validation-----
# AUC: 89.13 Precision: 95.00 Recall: 82.61
#
# Fold 10
#
# -----Train----------
# AUC: 88.80 Precision: 94.26 Recall: 82.77
#
# -----Validation-----
# AUC: 82.61 Precision: 94.12 Recall: 69.57
#
# Fold 11
#
# -----Train----------
# AUC: 87.94 Precision: 92.49 Recall: 82.77
#
# -----Validation-----
# AUC: 76.09 Precision: 92.86 Recall: 56.52
#
# wheezy-copper-turtle-magic 5
#
# Fold 1
#
# -----Train----------
# AUC: 84.93 Precision: 92.71 Recall: 75.74
#
# -----Validation-----
# AUC: 81.25 Precision: 82.61 Recall: 79.17
#
# Fold 2
#
# -----Train----------
# AUC: 85.56 Precision: 94.18 Recall: 75.74
#
# -----Validation-----
# AUC: 72.92 Precision: 82.35 Recall: 58.33
#
# Fold 3
#
# -----Train----------
# AUC: 86.42 Precision: 93.40 Recall: 78.30
#
# -----Validation-----
# AUC: 79.17 Precision: 100.00 Recall: 58.33
#
# Fold 4
#
# -----Train----------
# AUC: 88.54 Precision: 94.15 Recall: 82.13
#
# -----Validation-----
# AUC: 91.67 Precision: 100.00 Recall: 83.33
#
# Fold 5
#
# -----Train----------
# AUC: 86.84 Precision: 93.47 Recall: 79.15
#
# -----Validation-----
# AUC: 83.33 Precision: 94.44 Recall: 70.83
#
# Fold 6
#
# -----Train----------
# AUC: 85.56 Precision: 94.18 Recall: 75.74
#
# -----Validation-----
# AUC: 83.33 Precision: 90.00 Recall: 75.00
#
# Fold 7
#
# -----Train----------
# AUC: 86.88 Precision: 94.85 Recall: 77.97
#
# -----Validation-----
# AUC: 74.18 Precision: 82.35 Recall: 60.87
#
# Fold 8
#
# -----Train----------
# AUC: 86.04 Precision: 93.81 Recall: 77.12
#
# -----Validation-----
# AUC: 84.78 Precision: 100.00 Recall: 69.57
#
# Fold 9
#
# -----Train----------
# AUC: 85.19 Precision: 94.15 Recall: 75.00
#
# -----Validation-----
# AUC: 89.31 Precision: 90.91 Recall: 86.96
#
# Fold 10
#
# -----Train----------
# AUC: 85.41 Precision: 95.14 Recall: 74.58
#
# -----Validation-----
# AUC: 80.43 Precision: 88.89 Recall: 69.57
#
# Fold 11
#
# -----Train----------
# AUC: 86.69 Precision: 92.61 Recall: 79.66
#
# -----Validation-----
# AUC: 82.61 Precision: 100.00 Recall: 65.22
#
# wheezy-copper-turtle-magic 6
#
# Fold 1
#
# -----Train----------
# AUC: 91.68 Precision: 91.02 Recall: 92.92
#
# -----Validation-----
# AUC: 91.65 Precision: 92.00 Recall: 92.00
#
# Fold 2
#
# -----Train----------
# AUC: 91.93 Precision: 92.12 Recall: 92.12
#
# -----Validation-----
# AUC: 83.06 Precision: 86.36 Recall: 79.17
#
# Fold 3
#
# -----Train----------
# AUC: 91.89 Precision: 90.76 Recall: 93.78
#
# -----Validation-----
# AUC: 85.14 Precision: 86.96 Recall: 83.33
#
# Fold 4
#
# -----Train----------
# AUC: 91.32 Precision: 92.37 Recall: 90.46
#
# -----Validation-----
# AUC: 85.05 Precision: 84.00 Recall: 87.50
#
# Fold 5
#
# -----Train----------
# AUC: 91.12 Precision: 92.70 Recall: 89.63
#
# -----Validation-----
# AUC: 87.14 Precision: 84.62 Recall: 91.67
#
# Fold 6
#
# -----Train----------
# AUC: 91.47 Precision: 90.69 Recall: 92.95
#
# -----Validation-----
# AUC: 91.30 Precision: 85.71 Recall: 100.00
#
# Fold 7
#
# -----Train----------
# AUC: 91.27 Precision: 90.65 Recall: 92.53
#
# -----Validation-----
# AUC: 89.49 Precision: 95.24 Recall: 83.33
#
# Fold 8
#
# -----Train----------
# AUC: 91.92 Precision: 91.77 Recall: 92.53
#
# -----Validation-----
# AUC: 87.23 Precision: 87.50 Recall: 87.50
#
# Fold 9
#
# -----Train----------
# AUC: 91.92 Precision: 91.77 Recall: 92.53
#
# -----Validation-----
# AUC: 91.58 Precision: 95.45 Recall: 87.50
#
# Fold 10
#
# -----Train----------
# AUC: 93.59 Precision: 92.37 Recall: 95.44
#
# -----Validation-----
# AUC: 85.14 Precision: 86.96 Recall: 83.33
#
# Fold 11
#
# -----Train----------
# AUC: 92.35 Precision: 92.53 Recall: 92.53
#
# -----Validation-----
# AUC: 86.96 Precision: 80.00 Recall: 100.00
#
# wheezy-copper-turtle-magic 7
#
# Fold 1
#
# -----Train----------
# AUC: 86.29 Precision: 93.72 Recall: 77.83
#
# -----Validation-----
# AUC: 80.98 Precision: 85.71 Recall: 75.00
#
# Fold 2
#
# -----Train----------
# AUC: 84.83 Precision: 93.51 Recall: 74.89
#
# -----Validation-----
# AUC: 82.61 Precision: 100.00 Recall: 65.22
#
# Fold 3
#
# -----Train----------
# AUC: 86.34 Precision: 93.30 Recall: 78.35
#
# -----Validation-----
# AUC: 82.61 Precision: 94.12 Recall: 69.57
#
# Fold 4
#
# -----Train----------
# AUC: 87.21 Precision: 95.26 Recall: 78.35
#
# -----Validation-----
# AUC: 76.09 Precision: 80.00 Recall: 69.57
#
# Fold 5
#
# -----Train----------
# AUC: 86.78 Precision: 95.21 Recall: 77.49
#
# -----Validation-----
# AUC: 69.57 Precision: 80.00 Recall: 52.17
#
# Fold 6
#
# -----Train----------
# AUC: 85.48 Precision: 94.57 Recall: 75.32
#
# -----Validation-----
# AUC: 84.78 Precision: 94.44 Recall: 73.91
#
# Fold 7
#
# -----Train----------
# AUC: 85.69 Precision: 94.12 Recall: 76.19
#
# -----Validation-----
# AUC: 80.43 Precision: 93.75 Recall: 65.22
#
# Fold 8
#
# -----Train----------
# AUC: 84.40 Precision: 95.43 Recall: 72.29
#
# -----Validation-----
# AUC: 82.61 Precision: 89.47 Recall: 73.91
#
# Fold 9
#
# -----Train----------
# AUC: 86.57 Precision: 97.21 Recall: 75.32
#
# -----Validation-----
# AUC: 84.78 Precision: 86.36 Recall: 82.61
#
# Fold 10
#
# -----Train----------
# AUC: 85.92 Precision: 95.60 Recall: 75.32
#
# -----Validation-----
# AUC: 76.09 Precision: 87.50 Recall: 60.87
#
# Fold 11
#
# -----Train----------
# AUC: 86.79 Precision: 95.70 Recall: 77.06
#
# -----Validation-----
# AUC: 82.51 Precision: 94.12 Recall: 69.57
#
# wheezy-copper-turtle-magic 8
#
# Fold 1
#
# -----Train----------
# AUC: 88.49 Precision: 93.09 Recall: 83.47
#
# -----Validation-----
# AUC: 83.75 Precision: 86.96 Recall: 80.00
#
# Fold 2
#
# -----Train----------
# AUC: 88.70 Precision: 93.12 Recall: 83.88
#
# -----Validation-----
# AUC: 89.92 Precision: 95.45 Recall: 84.00
#
# Fold 3
#
# -----Train----------
# AUC: 88.13 Precision: 94.69 Recall: 80.99
#
# -----Validation-----
# AUC: 89.83 Precision: 95.45 Recall: 84.00
#
# Fold 4
#
# -----Train----------
# AUC: 89.37 Precision: 93.64 Recall: 84.77
#
# -----Validation-----
# AUC: 89.49 Precision: 95.24 Recall: 83.33
#
# Fold 5
#
# -----Train----------
# AUC: 90.02 Precision: 94.93 Recall: 84.77
#
# -----Validation-----
# AUC: 83.06 Precision: 86.36 Recall: 79.17
#
# Fold 6
#
# -----Train----------
# AUC: 90.19 Precision: 93.75 Recall: 86.42
#
# -----Validation-----
# AUC: 78.89 Precision: 85.00 Recall: 70.83
#
# Fold 7
#
# -----Train----------
# AUC: 89.57 Precision: 93.27 Recall: 85.60
#
# -----Validation-----
# AUC: 81.16 Precision: 94.12 Recall: 66.67
#
# Fold 8
#
# -----Train----------
# AUC: 89.78 Precision: 93.69 Recall: 85.60
#
# -----Validation-----
# AUC: 81.07 Precision: 89.47 Recall: 70.83
#
# Fold 9
#
# -----Train----------
# AUC: 89.57 Precision: 93.27 Recall: 85.60
#
# -----Validation-----
# AUC: 83.06 Precision: 86.36 Recall: 79.17
#
# Fold 10
#
# -----Train----------
# AUC: 88.59 Precision: 95.19 Recall: 81.48
#
# -----Validation-----
# AUC: 78.80 Precision: 81.82 Recall: 75.00
#
# Fold 11
#
# -----Train----------
# AUC: 86.49 Precision: 93.20 Recall: 79.01
#
# -----Validation-----
# AUC: 93.75 Precision: 100.00 Recall: 87.50
#
# wheezy-copper-turtle-magic 9
#
# Fold 1
#
# -----Train----------
# AUC: 91.25 Precision: 90.24 Recall: 92.50
#
# -----Validation-----
# AUC: 77.08 Precision: 74.07 Recall: 83.33
#
# Fold 2
#
# -----Train----------
# AUC: 91.67 Precision: 90.32 Recall: 93.33
#
# -----Validation-----
# AUC: 77.08 Precision: 74.07 Recall: 83.33
#
# Fold 3
#
# -----Train----------
# AUC: 91.67 Precision: 90.32 Recall: 93.33
#
# -----Validation-----
# AUC: 85.42 Precision: 84.00 Recall: 87.50
#
# Fold 4
#
# -----Train----------
# AUC: 90.62 Precision: 87.94 Recall: 94.17
#
# -----Validation-----
# AUC: 81.25 Precision: 80.00 Recall: 83.33
#
# Fold 5
#
# -----Train----------
# AUC: 91.04 Precision: 89.88 Recall: 92.50
#
# -----Validation-----
# AUC: 93.75 Precision: 95.65 Recall: 91.67
#
# Fold 6
#
# -----Train----------
# AUC: 89.79 Precision: 88.66 Recall: 91.25
#
# -----Validation-----
# AUC: 89.58 Precision: 82.76 Recall: 100.00
#
# Fold 7
#
# -----Train----------
# AUC: 93.12 Precision: 93.31 Recall: 92.92
#
# -----Validation-----
# AUC: 79.17 Precision: 75.00 Recall: 87.50
#
# Fold 8
#
# -----Train----------
# AUC: 91.46 Precision: 90.28 Recall: 92.92
#
# -----Validation-----
# AUC: 93.75 Precision: 95.65 Recall: 91.67
#
# Fold 9
#
# -----Train----------
# AUC: 89.17 Precision: 87.30 Recall: 91.67
#
# -----Validation-----
# AUC: 85.42 Precision: 81.48 Recall: 91.67
#
# Fold 10
#
# -----Train----------
# AUC: 91.88 Precision: 90.04 Recall: 94.17
#
# -----Validation-----
# AUC: 81.25 Precision: 77.78 Recall: 87.50
#
# Fold 11
#
# -----Train----------
# AUC: 88.33 Precision: 88.33 Recall: 88.33
#
# -----Validation-----
# AUC: 85.42 Precision: 84.00 Recall: 87.50
#
# wheezy-copper-turtle-magic 10
#
# Fold 1
#
# -----Train----------
# AUC: 87.73 Precision: 94.21 Recall: 80.27
#
# -----Validation-----
# AUC: 82.61 Precision: 89.47 Recall: 73.91
#
# Fold 2
#
# -----Train----------
# AUC: 87.04 Precision: 95.58 Recall: 77.58
#
# -----Validation-----
# AUC: 84.78 Precision: 90.00 Recall: 78.26
#
# Fold 3
#
# -----Train----------
# AUC: 88.64 Precision: 93.43 Recall: 82.96
#
# -----Validation-----
# AUC: 86.96 Precision: 94.74 Recall: 78.26
#
# Fold 4
#
# -----Train----------
# AUC: 87.07 Precision: 93.65 Recall: 79.37
#
# -----Validation-----
# AUC: 84.78 Precision: 90.00 Recall: 78.26
#
# Fold 5
#
# -----Train----------
# AUC: 88.44 Precision: 94.79 Recall: 81.25
#
# -----Validation-----
# AUC: 79.74 Precision: 88.24 Recall: 68.18
#
# Fold 6
#
# -----Train----------
# AUC: 87.11 Precision: 94.15 Recall: 79.02
#
# -----Validation-----
# AUC: 81.92 Precision: 93.75 Recall: 68.18
#
# Fold 7
#
# -----Train----------
# AUC: 87.77 Precision: 94.71 Recall: 79.91
#
# -----Validation-----
# AUC: 84.39 Precision: 85.71 Recall: 81.82
#
# Fold 8
#
# -----Train----------
# AUC: 89.78 Precision: 95.41 Recall: 83.48
#
# -----Validation-----
# AUC: 79.94 Precision: 80.95 Recall: 77.27
#
# Fold 9
#
# -----Train----------
# AUC: 86.45 Precision: 93.12 Recall: 78.57
#
# -----Validation-----
# AUC: 79.74 Precision: 88.24 Recall: 68.18
#
# Fold 10
#
# -----Train----------
# AUC: 89.78 Precision: 95.41 Recall: 83.48
#
# -----Validation-----
# AUC: 84.39 Precision: 85.71 Recall: 81.82
#
# Fold 11
#
# -----Train----------
# AUC: 88.70 Precision: 93.03 Recall: 83.48
#
# -----Validation-----
# AUC: 72.73 Precision: 75.00 Recall: 68.18
#
# wheezy-copper-turtle-magic 11
#
# Fold 1
#
# -----Train----------
# AUC: 91.95 Precision: 92.27 Recall: 90.95
#
# -----Validation-----
# AUC: 93.38 Precision: 91.30 Recall: 95.45
#
# Fold 2
#
# -----Train----------
# AUC: 91.23 Precision: 93.03 Recall: 88.63
#
# -----Validation-----
# AUC: 90.68 Precision: 94.74 Recall: 85.71
#
# Fold 3
#
# -----Train----------
# AUC: 91.45 Precision: 93.50 Recall: 88.63
#
# -----Validation-----
# AUC: 88.72 Precision: 86.36 Recall: 90.48
#
# Fold 4
#
# -----Train----------
# AUC: 90.72 Precision: 93.85 Recall: 86.73
#
# -----Validation-----
# AUC: 88.72 Precision: 86.36 Recall: 90.48
#
# Fold 5
#
# -----Train----------
# AUC: 91.43 Precision: 93.94 Recall: 88.15
#
# -----Validation-----
# AUC: 83.75 Precision: 88.89 Recall: 76.19
#
# Fold 6
#
# -----Train----------
# AUC: 91.40 Precision: 94.85 Recall: 87.20
#
# -----Validation-----
# AUC: 93.06 Precision: 95.00 Recall: 90.48
#
# Fold 7
#
# -----Train----------
# AUC: 90.43 Precision: 95.21 Recall: 84.83
#
# -----Validation-----
# AUC: 86.34 Precision: 85.71 Recall: 85.71
#
# Fold 8
#
# -----Train----------
# AUC: 90.31 Precision: 92.04 Recall: 87.68
#
# -----Validation-----
# AUC: 88.30 Precision: 94.44 Recall: 80.95
#
# Fold 9
#
# -----Train----------
# AUC: 91.46 Precision: 93.50 Recall: 88.63
#
# -----Validation-----
# AUC: 83.66 Precision: 85.00 Recall: 80.95
#
# Fold 10
#
# -----Train----------
# AUC: 91.94 Precision: 93.56 Recall: 89.57
#
# -----Validation-----
# AUC: 88.31 Precision: 90.00 Recall: 85.71
#
# Fold 11
#
# -----Train----------
# AUC: 91.26 Precision: 92.61 Recall: 89.10
#
# -----Validation-----
# AUC: 83.55 Precision: 88.89 Recall: 76.19
#
# wheezy-copper-turtle-magic 12
#
# Fold 1
#
# -----Train----------
# AUC: 90.65 Precision: 89.74 Recall: 92.11
#
# -----Validation-----
# AUC: 84.78 Precision: 90.00 Recall: 78.26
#
# Fold 2
#
# -----Train----------
# AUC: 91.10 Precision: 90.87 Recall: 91.67
#
# -----Validation-----
# AUC: 86.96 Precision: 86.96 Recall: 86.96
#
# Fold 3
#
# -----Train----------
# AUC: 90.86 Precision: 89.45 Recall: 92.98
#
# -----Validation-----
# AUC: 89.13 Precision: 87.50 Recall: 91.30
#
# Fold 4
#
# -----Train----------
# AUC: 90.66 Precision: 89.08 Recall: 92.98
#
# -----Validation-----
# AUC: 91.01 Precision: 88.00 Recall: 95.65
#
# Fold 5
#
# -----Train----------
# AUC: 90.66 Precision: 88.75 Recall: 93.42
#
# -----Validation-----
# AUC: 82.11 Precision: 80.00 Recall: 86.96
#
# Fold 6
#
# -----Train----------
# AUC: 91.33 Precision: 90.21 Recall: 92.98
#
# -----Validation-----
# AUC: 77.67 Precision: 76.00 Recall: 82.61
#
# Fold 7
#
# -----Train----------
# AUC: 90.66 Precision: 89.08 Recall: 92.98
#
# -----Validation-----
# AUC: 86.76 Precision: 90.48 Recall: 82.61
#
# Fold 8
#
# -----Train----------
# AUC: 91.33 Precision: 90.21 Recall: 92.98
#
# -----Validation-----
# AUC: 88.74 Precision: 84.62 Recall: 95.65
#
# Fold 9
#
# -----Train----------
# AUC: 90.87 Precision: 88.16 Recall: 94.74
#
# -----Validation-----
# AUC: 82.02 Precision: 77.78 Recall: 91.30
#
# Fold 10
#
# -----Train----------
# AUC: 91.13 Precision: 90.21 Recall: 92.58
#
# -----Validation-----
# AUC: 86.36 Precision: 83.33 Recall: 90.91
#
# Fold 11
#
# -----Train----------
# AUC: 89.79 Precision: 87.97 Recall: 92.58
#
# -----Validation-----
# AUC: 86.36 Precision: 83.33 Recall: 90.91
#
# wheezy-copper-turtle-magic 13
#
# Fold 1
#
# -----Train----------
# AUC: 89.14 Precision: 93.68 Recall: 83.57
#
# -----Validation-----
# AUC: 82.02 Precision: 88.89 Recall: 72.73
#
# Fold 2
#
# -----Train----------
# AUC: 87.47 Precision: 94.41 Recall: 79.34
#
# -----Validation-----
# AUC: 84.29 Precision: 89.47 Recall: 77.27
#
# Fold 3
#
# -----Train----------
# AUC: 89.35 Precision: 94.65 Recall: 83.10
#
# -----Validation-----
# AUC: 91.01 Precision: 95.00 Recall: 86.36
#
# Fold 4
#
# -----Train----------
# AUC: 90.34 Precision: 92.96 Recall: 86.85
#
# -----Validation-----
# AUC: 82.11 Precision: 85.00 Recall: 77.27
#
# Fold 5
#
# -----Train----------
# AUC: 89.65 Precision: 93.78 Recall: 84.58
#
# -----Validation-----
# AUC: 88.51 Precision: 90.00 Recall: 85.71
#
# Fold 6
#
# -----Train----------
# AUC: 87.53 Precision: 93.96 Recall: 79.91
#
# -----Validation-----
# AUC: 76.40 Precision: 92.31 Recall: 57.14
#
# Fold 7
#
# -----Train----------
# AUC: 88.96 Precision: 93.23 Recall: 83.64
#
# -----Validation-----
# AUC: 90.68 Precision: 94.74 Recall: 85.71
#
# Fold 8
#
# -----Train----------
# AUC: 87.57 Precision: 92.55 Recall: 81.31
#
# -----Validation-----
# AUC: 83.54 Precision: 93.75 Recall: 71.43
#
# Fold 9
#
# -----Train----------
# AUC: 87.61 Precision: 91.67 Recall: 82.24
#
# -----Validation-----
# AUC: 88.20 Precision: 94.44 Recall: 80.95
#
# Fold 10
#
# -----Train----------
# AUC: 90.80 Precision: 94.85 Recall: 85.98
#
# -----Validation-----
# AUC: 81.17 Precision: 88.24 Recall: 71.43
#
# Fold 11
#
# -----Train----------
# AUC: 89.45 Precision: 92.86 Recall: 85.05
#
# -----Validation-----
# AUC: 85.93 Precision: 89.47 Recall: 80.95
#
# wheezy-copper-turtle-magic 14
#
# Fold 1
#
# -----Train----------
# AUC: 89.92 Precision: 94.09 Recall: 84.54
#
# -----Validation-----
# AUC: 92.86 Precision: 100.00 Recall: 85.71
#
# Fold 2
#
# -----Train----------
# AUC: 90.67 Precision: 93.72 Recall: 86.47
#
# -----Validation-----
# AUC: 88.39 Precision: 94.44 Recall: 80.95
#
# Fold 3
#
# -----Train----------
# AUC: 91.26 Precision: 96.20 Recall: 85.51
#
# -----Validation-----
# AUC: 90.48 Precision: 100.00 Recall: 80.95
#
# Fold 4
#
# -----Train----------
# AUC: 90.29 Precision: 96.11 Recall: 83.57
#
# -----Validation-----
# AUC: 86.31 Precision: 89.47 Recall: 80.95
#
# Fold 5
#
# -----Train----------
# AUC: 91.04 Precision: 95.68 Recall: 85.51
#
# -----Validation-----
# AUC: 91.07 Precision: 90.48 Recall: 90.48
#
# Fold 6
#
# -----Train----------
# AUC: 91.08 Precision: 95.19 Recall: 85.99
#
# -----Validation-----
# AUC: 90.68 Precision: 94.74 Recall: 85.71
#
# Fold 7
#
# -----Train----------
# AUC: 93.23 Precision: 95.88 Recall: 89.86
#
# -----Validation-----
# AUC: 92.86 Precision: 100.00 Recall: 85.71
#
# Fold 8
#
# -----Train----------
# AUC: 90.78 Precision: 96.15 Recall: 84.54
#
# -----Validation-----
# AUC: 79.40 Precision: 80.00 Recall: 76.19
#
# Fold 9
#
# -----Train----------
# AUC: 90.58 Precision: 96.15 Recall: 84.13
#
# -----Validation-----
# AUC: 85.00 Precision: 100.00 Recall: 70.00
#
# Fold 10
#
# -----Train----------
# AUC: 91.75 Precision: 96.76 Recall: 86.06
#
# -----Validation-----
# AUC: 83.80 Precision: 80.95 Recall: 85.00
#
# Fold 11
#
# -----Train----------
# AUC: 91.14 Precision: 94.74 Recall: 86.54
#
# -----Validation-----
# AUC: 85.00 Precision: 100.00 Recall: 70.00
#
# wheezy-copper-turtle-magic 15
#
# Fold 1
#
# -----Train----------
# AUC: 90.41 Precision: 92.11 Recall: 88.61
#
# -----Validation-----
# AUC: 91.67 Precision: 95.45 Recall: 87.50
#
# Fold 2
#
# -----Train----------
# AUC: 90.87 Precision: 94.91 Recall: 86.50
#
# -----Validation-----
# AUC: 87.50 Precision: 95.00 Recall: 79.17
#
# Fold 3
#
# -----Train----------
# AUC: 90.23 Precision: 93.61 Recall: 86.50
#
# -----Validation-----
# AUC: 89.31 Precision: 88.00 Recall: 91.67
#
# Fold 4
#
# -----Train----------
# AUC: 91.29 Precision: 94.14 Recall: 88.19
#
# -----Validation-----
# AUC: 87.41 Precision: 95.00 Recall: 79.17
#
# Fold 5
#
# -----Train----------
# AUC: 91.50 Precision: 93.78 Recall: 89.03
#
# -----Validation-----
# AUC: 85.14 Precision: 86.96 Recall: 83.33
#
# Fold 6
#
# -----Train----------
# AUC: 91.70 Precision: 93.04 Recall: 90.30
#
# -----Validation-----
# AUC: 89.22 Precision: 85.19 Recall: 95.83
#
# Fold 7
#
# -----Train----------
# AUC: 91.07 Precision: 93.33 Recall: 88.61
#
# -----Validation-----
# AUC: 93.57 Precision: 92.00 Recall: 95.83
#
# Fold 8
#
# -----Train----------
# AUC: 91.27 Precision: 92.61 Recall: 89.87
#
# -----Validation-----
# AUC: 87.50 Precision: 100.00 Recall: 75.00
#
# Fold 9
#
# -----Train----------
# AUC: 91.53 Precision: 94.20 Recall: 88.66
#
# -----Validation-----
# AUC: 82.61 Precision: 85.71 Recall: 78.26
#
# Fold 10
#
# -----Train----------
# AUC: 92.15 Precision: 93.89 Recall: 90.34
#
# -----Validation-----
# AUC: 80.43 Precision: 85.00 Recall: 73.91
#
# Fold 11
#
# -----Train----------
# AUC: 91.95 Precision: 94.25 Recall: 89.50
#
# -----Validation-----
# AUC: 86.96 Precision: 90.48 Recall: 82.61
#
# wheezy-copper-turtle-magic 16
#
# Fold 1
#
# -----Train----------
# AUC: 90.16 Precision: 90.62 Recall: 89.04
#
# -----Validation-----
# AUC: 83.13 Precision: 85.71 Recall: 78.26
#
# Fold 2
#
# -----Train----------
# AUC: 90.89 Precision: 88.70 Recall: 92.98
#
# -----Validation-----
# AUC: 87.30 Precision: 90.48 Recall: 82.61
#
# Fold 3
#
# -----Train----------
# AUC: 91.33 Precision: 89.45 Recall: 92.98
#
# -----Validation-----
# AUC: 89.40 Precision: 87.50 Recall: 91.30
#
# Fold 4
#
# -----Train----------
# AUC: 90.01 Precision: 89.18 Recall: 90.35
#
# -----Validation-----
# AUC: 85.24 Precision: 80.77 Recall: 91.30
#
# Fold 5
#
# -----Train----------
# AUC: 90.01 Precision: 89.18 Recall: 90.35
#
# -----Validation-----
# AUC: 93.57 Precision: 95.45 Recall: 91.30
#
# Fold 6
#
# -----Train----------
# AUC: 91.11 Precision: 89.41 Recall: 92.54
#
# -----Validation-----
# AUC: 80.98 Precision: 76.92 Recall: 86.96
#
# Fold 7
#
# -----Train----------
# AUC: 91.51 Precision: 90.52 Recall: 92.11
#
# -----Validation-----
# AUC: 85.14 Precision: 83.33 Recall: 86.96
#
# Fold 8
#
# -----Train----------
# AUC: 89.96 Precision: 90.58 Recall: 88.60
#
# -----Validation-----
# AUC: 93.57 Precision: 95.45 Recall: 91.30
#
# Fold 9
#
# -----Train----------
# AUC: 89.82 Precision: 88.46 Recall: 90.79
#
# -----Validation-----
# AUC: 78.62 Precision: 80.95 Recall: 73.91
#
# Fold 10
#
# -----Train----------
# AUC: 91.56 Precision: 89.54 Recall: 93.45
#
# -----Validation-----
# AUC: 75.95 Precision: 76.19 Recall: 72.73
#
# Fold 11
#
# -----Train----------
# AUC: 91.95 Precision: 90.99 Recall: 92.58
#
# -----Validation-----
# AUC: 82.58 Precision: 81.82 Recall: 81.82
#
# wheezy-copper-turtle-magic 17
#
# Fold 1
#
# -----Train----------
# AUC: 90.05 Precision: 96.59 Recall: 83.19
#
# -----Validation-----
# AUC: 82.97 Precision: 83.33 Recall: 83.33
#
# Fold 2
#
# -----Train----------
# AUC: 91.06 Precision: 95.37 Recall: 86.55
#
# -----Validation-----
# AUC: 78.80 Precision: 81.82 Recall: 75.00
#
# Fold 3
#
# -----Train----------
# AUC: 89.82 Precision: 95.67 Recall: 83.61
#
# -----Validation-----
# AUC: 91.67 Precision: 100.00 Recall: 83.33
#
# Fold 4
#
# -----Train----------
# AUC: 90.88 Precision: 96.21 Recall: 85.29
#
# -----Validation-----
# AUC: 87.50 Precision: 100.00 Recall: 75.00
#
# Fold 5
#
# -----Train----------
# AUC: 89.78 Precision: 94.39 Recall: 84.87
#
# -----Validation-----
# AUC: 81.07 Precision: 89.47 Recall: 70.83
#
# Fold 6
#
# -----Train----------
# AUC: 89.40 Precision: 95.63 Recall: 82.77
#
# -----Validation-----
# AUC: 87.23 Precision: 87.50 Recall: 87.50
#
# Fold 7
#
# -----Train----------
# AUC: 90.22 Precision: 95.28 Recall: 84.87
#
# -----Validation-----
# AUC: 81.07 Precision: 89.47 Recall: 70.83
#
# Fold 8
#
# -----Train----------
# AUC: 90.67 Precision: 96.19 Recall: 84.87
#
# -----Validation-----
# AUC: 91.67 Precision: 100.00 Recall: 83.33
#
# Fold 9
#
# -----Train----------
# AUC: 90.24 Precision: 95.71 Recall: 84.45
#
# -----Validation-----
# AUC: 83.14 Precision: 94.44 Recall: 70.83
#
# Fold 10
#
# -----Train----------
# AUC: 90.72 Precision: 96.65 Recall: 84.52
#
# -----Validation-----
# AUC: 84.58 Precision: 90.00 Recall: 78.26
#
# Fold 11
#
# -----Train----------
# AUC: 90.94 Precision: 97.12 Recall: 84.52
#
# -----Validation-----
# AUC: 80.24 Precision: 88.89 Recall: 69.57
#
# wheezy-copper-turtle-magic 18
#
# Fold 1
#
# -----Train----------
# AUC: 93.03 Precision: 95.59 Recall: 90.42
#
# -----Validation-----
# AUC: 83.65 Precision: 90.48 Recall: 76.00
#
# Fold 2
#
# -----Train----------
# AUC: 93.22 Precision: 94.09 Recall: 92.53
#
# -----Validation-----
# AUC: 87.32 Precision: 90.91 Recall: 83.33
#
# Fold 3
#
# -----Train----------
# AUC: 92.39 Precision: 93.99 Recall: 90.87
#
# -----Validation-----
# AUC: 80.80 Precision: 80.00 Recall: 83.33
#
# Fold 4
#
# -----Train----------
# AUC: 91.53 Precision: 92.77 Recall: 90.46
#
# -----Validation-----
# AUC: 97.92 Precision: 100.00 Recall: 95.83
#
# Fold 5
#
# -----Train----------
# AUC: 91.28 Precision: 90.98 Recall: 92.12
#
# -----Validation-----
# AUC: 87.05 Precision: 82.14 Recall: 95.83
#
# Fold 6
#
# -----Train----------
# AUC: 91.56 Precision: 93.89 Recall: 89.21
#
# -----Validation-----
# AUC: 83.06 Precision: 86.36 Recall: 79.17
#
# Fold 7
#
# -----Train----------
# AUC: 91.76 Precision: 93.53 Recall: 90.04
#
# -----Validation-----
# AUC: 91.58 Precision: 95.45 Recall: 87.50
#
# Fold 8
#
# -----Train----------
# AUC: 91.95 Precision: 92.83 Recall: 91.29
#
# -----Validation-----
# AUC: 89.31 Precision: 88.00 Recall: 91.67
#
# Fold 9
#
# -----Train----------
# AUC: 92.57 Precision: 92.92 Recall: 92.53
#
# -----Validation-----
# AUC: 89.40 Precision: 91.30 Recall: 87.50
#
# Fold 10
#
# -----Train----------
# AUC: 92.38 Precision: 93.62 Recall: 91.29
#
# -----Validation-----
# AUC: 85.24 Precision: 90.48 Recall: 79.17
#
# Fold 11
#
# -----Train----------
# AUC: 92.80 Precision: 93.67 Recall: 92.12
#
# -----Validation-----
# AUC: 87.23 Precision: 87.50 Recall: 87.50
#
# wheezy-copper-turtle-magic 19
#
# Fold 1
#
# -----Train----------
# AUC: 92.90 Precision: 96.40 Recall: 89.17
#
# -----Validation-----
# AUC: 91.92 Precision: 95.65 Recall: 88.00
#
# Fold 2
#
# -----Train----------
# AUC: 90.81 Precision: 92.64 Recall: 88.80
#
# -----Validation-----
# AUC: 81.25 Precision: 82.61 Recall: 79.17
#
# Fold 3
#
# -----Train----------
# AUC: 93.53 Precision: 95.65 Recall: 91.29
#
# -----Validation-----
# AUC: 85.42 Precision: 86.96 Recall: 83.33
#
# Fold 4
#
# -----Train----------
# AUC: 92.49 Precision: 94.76 Recall: 90.04
#
# -----Validation-----
# AUC: 89.58 Precision: 95.24 Recall: 83.33
#
# Fold 5
#
# -----Train----------
# AUC: 91.23 Precision: 93.07 Recall: 89.21
#
# -----Validation-----
# AUC: 85.42 Precision: 86.96 Recall: 83.33
#
# Fold 6
#
# -----Train----------
# AUC: 91.64 Precision: 92.77 Recall: 90.46
#
# -----Validation-----
# AUC: 87.50 Precision: 87.50 Recall: 87.50
#
# Fold 7
#
# -----Train----------
# AUC: 92.69 Precision: 94.40 Recall: 90.87
#
# -----Validation-----
# AUC: 89.58 Precision: 100.00 Recall: 79.17
#
# Fold 8
#
# -----Train----------
# AUC: 92.07 Precision: 93.94 Recall: 90.04
#
# -----Validation-----
# AUC: 91.67 Precision: 91.67 Recall: 91.67
#
# Fold 9
#
# -----Train----------
# AUC: 91.25 Precision: 93.45 Recall: 88.80
#
# -----Validation-----
# AUC: 89.58 Precision: 100.00 Recall: 79.17
#
# Fold 10
#
# -----Train----------
# AUC: 90.41 Precision: 92.95 Recall: 87.55
#
# -----Validation-----
# AUC: 85.24 Precision: 90.48 Recall: 79.17
#
# Fold 11
#
# -----Train----------
# AUC: 92.29 Precision: 95.13 Recall: 89.21
#
# -----Validation-----
# AUC: 87.23 Precision: 87.50 Recall: 87.50
#
# wheezy-copper-turtle-magic 20
#
# Fold 1
#
# -----Train----------
# AUC: 88.42 Precision: 97.24 Recall: 78.92
#
# -----Validation-----
# AUC: 70.09 Precision: 80.00 Recall: 52.17
#
# Fold 2
#
# -----Train----------
# AUC: 86.76 Precision: 93.12 Recall: 78.92
#
# -----Validation-----
# AUC: 93.83 Precision: 91.67 Recall: 95.65
#
# Fold 3
#
# -----Train----------
# AUC: 88.31 Precision: 94.27 Recall: 81.17
#
# -----Validation-----
# AUC: 76.18 Precision: 92.86 Recall: 56.52
#
# Fold 4
#
# -----Train----------
# AUC: 85.86 Precision: 93.44 Recall: 76.68
#
# -----Validation-----
# AUC: 74.28 Precision: 78.95 Recall: 65.22
#
# Fold 5
#
# -----Train----------
# AUC: 87.92 Precision: 93.78 Recall: 80.80
#
# -----Validation-----
# AUC: 86.74 Precision: 90.00 Recall: 81.82
#
# Fold 6
#
# -----Train----------
# AUC: 87.84 Precision: 96.17 Recall: 78.57
#
# -----Validation-----
# AUC: 68.75 Precision: 78.57 Recall: 50.00
#
# Fold 7
#
# -----Train----------
# AUC: 86.15 Precision: 93.05 Recall: 77.68
#
# -----Validation-----
# AUC: 70.83 Precision: 84.62 Recall: 50.00
#
# Fold 8
#
# -----Train----------
# AUC: 87.01 Precision: 94.12 Recall: 78.57
#
# -----Validation-----
# AUC: 84.47 Precision: 89.47 Recall: 77.27
#
# Fold 9
#
# -----Train----------
# AUC: 88.11 Precision: 94.74 Recall: 80.36
#
# -----Validation-----
# AUC: 90.91 Precision: 100.00 Recall: 81.82
#
# Fold 10
#
# -----Train----------
# AUC: 88.82 Precision: 93.91 Recall: 82.59
#
# -----Validation-----
# AUC: 77.65 Precision: 87.50 Recall: 63.64
#
# Fold 11
#
# -----Train----------
# AUC: 86.98 Precision: 95.08 Recall: 77.68
#
# -----Validation-----
# AUC: 91.10 Precision: 95.00 Recall: 86.36
#
# wheezy-copper-turtle-magic 21
#
# Fold 1
#
# -----Train----------
# AUC: 91.73 Precision: 92.53 Recall: 91.02
#
# -----Validation-----
# AUC: 85.75 Precision: 87.50 Recall: 84.00
#
# Fold 2
#
# -----Train----------
# AUC: 92.58 Precision: 94.85 Recall: 90.20
#
# -----Validation-----
# AUC: 87.92 Precision: 95.24 Recall: 80.00
#
# Fold 3
#
# -----Train----------
# AUC: 91.34 Precision: 93.56 Recall: 88.98
#
# -----Validation-----
# AUC: 94.00 Precision: 100.00 Recall: 88.00
#
# Fold 4
#
# -----Train----------
# AUC: 91.73 Precision: 92.53 Recall: 91.02
#
# -----Validation-----
# AUC: 75.50 Precision: 76.00 Recall: 76.00
#
# Fold 5
#
# -----Train----------
# AUC: 91.73 Precision: 92.53 Recall: 91.02
#
# -----Validation-----
# AUC: 93.83 Precision: 92.31 Recall: 96.00
#
# Fold 6
#
# -----Train----------
# AUC: 91.13 Precision: 93.16 Recall: 88.98
#
# -----Validation-----
# AUC: 93.75 Precision: 89.29 Recall: 100.00
#
# Fold 7
#
# -----Train----------
# AUC: 92.80 Precision: 94.51 Recall: 91.06
#
# -----Validation-----
# AUC: 87.50 Precision: 95.00 Recall: 79.17
#
# Fold 8
#
# -----Train----------
# AUC: 93.01 Precision: 95.30 Recall: 90.65
#
# -----Validation-----
# AUC: 97.92 Precision: 100.00 Recall: 95.83
#
# Fold 9
#
# -----Train----------
# AUC: 93.23 Precision: 96.10 Recall: 90.24
#
# -----Validation-----
# AUC: 91.67 Precision: 88.46 Recall: 95.83
#
# Fold 10
#
# -----Train----------
# AUC: 92.39 Precision: 93.72 Recall: 91.06
#
# -----Validation-----
# AUC: 83.06 Precision: 86.36 Recall: 79.17
#
# Fold 11
#
# -----Train----------
# AUC: 91.97 Precision: 92.95 Recall: 91.06
#
# -----Validation-----
# AUC: 82.97 Precision: 83.33 Recall: 83.33
#
# wheezy-copper-turtle-magic 22
#
# Fold 1
#
# -----Train----------
# AUC: 91.43 Precision: 93.36 Recall: 89.64
#
# -----Validation-----
# AUC: 96.15 Precision: 100.00 Recall: 92.31
#
# Fold 2
#
# -----Train----------
# AUC: 92.84 Precision: 93.90 Recall: 92.03
#
# -----Validation-----
# AUC: 89.90 Precision: 88.89 Recall: 92.31
#
# Fold 3
#
# -----Train----------
# AUC: 92.05 Precision: 93.47 Recall: 90.87
#
# -----Validation-----
# AUC: 93.83 Precision: 92.31 Recall: 96.00
#
# Fold 4
#
# -----Train----------
# AUC: 92.23 Precision: 93.15 Recall: 91.67
#
# -----Validation-----
# AUC: 85.67 Precision: 84.62 Recall: 88.00
#
# Fold 5
#
# -----Train----------
# AUC: 92.46 Precision: 93.88 Recall: 91.27
#
# -----Validation-----
# AUC: 83.83 Precision: 90.48 Recall: 76.00
#
# Fold 6
#
# -----Train----------
# AUC: 92.43 Precision: 93.17 Recall: 92.06
#
# -----Validation-----
# AUC: 94.00 Precision: 100.00 Recall: 88.00
#
# Fold 7
#
# -----Train----------
# AUC: 91.79 Precision: 92.06 Recall: 92.06
#
# -----Validation-----
# AUC: 91.92 Precision: 95.65 Recall: 88.00
#
# Fold 8
#
# -----Train----------
# AUC: 93.10 Precision: 95.04 Recall: 91.27
#
# -----Validation-----
# AUC: 80.96 Precision: 78.57 Recall: 88.00
#
# Fold 9
#
# -----Train----------
# AUC: 92.67 Precision: 93.90 Recall: 91.67
#
# -----Validation-----
# AUC: 79.13 Precision: 80.00 Recall: 80.00
#
# Fold 10
#
# -----Train----------
# AUC: 93.13 Precision: 95.80 Recall: 90.48
#
# -----Validation-----
# AUC: 87.48 Precision: 88.00 Recall: 88.00
#
# Fold 11
#
# -----Train----------
# AUC: 92.68 Precision: 94.26 Recall: 91.27
#
# -----Validation-----
# AUC: 93.83 Precision: 95.83 Recall: 92.00
#
# wheezy-copper-turtle-magic 23
#
# Fold 1
#
# -----Train----------
# AUC: 87.89 Precision: 95.07 Recall: 80.08
#
# -----Validation-----
# AUC: 87.92 Precision: 95.24 Recall: 80.00
#
# Fold 2
#
# -----Train----------
# AUC: 88.54 Precision: 96.97 Recall: 79.67
#
# -----Validation-----
# AUC: 82.00 Precision: 100.00 Recall: 64.00
#
# Fold 3
#
# -----Train----------
# AUC: 87.53 Precision: 95.96 Recall: 78.51
#
# -----Validation-----
# AUC: 85.42 Precision: 94.74 Recall: 75.00
#
# Fold 4
#
# -----Train----------
# AUC: 87.35 Precision: 96.89 Recall: 77.27
#
# -----Validation-----
# AUC: 76.72 Precision: 80.95 Recall: 70.83
#
# Fold 5
#
# -----Train----------
# AUC: 88.56 Precision: 95.61 Recall: 80.99
#
# -----Validation-----
# AUC: 76.99 Precision: 93.33 Recall: 58.33
#
# Fold 6
#
# -----Train----------
# AUC: 88.17 Precision: 96.48 Recall: 79.34
#
# -----Validation-----
# AUC: 79.08 Precision: 93.75 Recall: 62.50
#
# Fold 7
#
# -----Train----------
# AUC: 87.55 Precision: 96.43 Recall: 78.10
#
# -----Validation-----
# AUC: 83.24 Precision: 94.44 Recall: 70.83
#
# Fold 8
#
# -----Train----------
# AUC: 88.36 Precision: 95.59 Recall: 80.58
#
# -----Validation-----
# AUC: 81.16 Precision: 94.12 Recall: 66.67
#
# Fold 9
#
# -----Train----------
# AUC: 86.54 Precision: 97.84 Recall: 74.79
#
# -----Validation-----
# AUC: 80.98 Precision: 85.71 Recall: 75.00
#
# Fold 10
#
# -----Train----------
# AUC: 88.37 Precision: 96.50 Recall: 79.75
#
# -----Validation-----
# AUC: 85.42 Precision: 100.00 Recall: 70.83
#
# Fold 11
#
# -----Train----------
# AUC: 88.35 Precision: 95.15 Recall: 80.99
#
# -----Validation-----
# AUC: 83.24 Precision: 94.44 Recall: 70.83
#
# wheezy-copper-turtle-magic 24
#
# Fold 1
#
# -----Train----------
# AUC: 90.66 Precision: 92.93 Recall: 87.20
#
# -----Validation-----
# AUC: 89.02 Precision: 90.48 Recall: 86.36
#
# Fold 2
#
# -----Train----------
# AUC: 91.90 Precision: 92.27 Recall: 90.52
#
# -----Validation-----
# AUC: 91.29 Precision: 90.91 Recall: 90.91
#
# Fold 3
#
# -----Train----------
# AUC: 91.87 Precision: 93.14 Recall: 89.62
#
# -----Validation-----
# AUC: 91.07 Precision: 90.48 Recall: 90.48
#
# Fold 4
#
# -----Train----------
# AUC: 90.74 Precision: 92.12 Recall: 88.21
#
# -----Validation-----
# AUC: 88.69 Precision: 90.00 Recall: 85.71
#
# Fold 5
#
# -----Train----------
# AUC: 89.96 Precision: 93.30 Recall: 85.38
#
# -----Validation-----
# AUC: 93.15 Precision: 95.00 Recall: 90.48
#
# Fold 6
#
# -----Train----------
# AUC: 90.64 Precision: 93.85 Recall: 86.32
#
# -----Validation-----
# AUC: 88.39 Precision: 94.44 Recall: 80.95
#
# Fold 7
#
# -----Train----------
# AUC: 89.93 Precision: 93.75 Recall: 84.91
#
# -----Validation-----
# AUC: 95.54 Precision: 95.24 Recall: 95.24
#
# Fold 8
#
# -----Train----------
# AUC: 90.93 Precision: 93.00 Recall: 87.74
#
# -----Validation-----
# AUC: 77.68 Precision: 76.19 Recall: 76.19
#
# Fold 9
#
# -----Train----------
# AUC: 90.69 Precision: 92.96 Recall: 87.26
#
# -----Validation-----
# AUC: 93.15 Precision: 95.00 Recall: 90.48
#
# Fold 10
#
# -----Train----------
# AUC: 90.94 Precision: 93.00 Recall: 87.74
#
# -----Validation-----
# AUC: 83.54 Precision: 93.75 Recall: 71.43
#
# Fold 11
#
# -----Train----------
# AUC: 90.91 Precision: 93.43 Recall: 87.26
#
# -----Validation-----
# AUC: 81.57 Precision: 84.21 Recall: 76.19
#
# wheezy-copper-turtle-magic 25
#
# Fold 1
#
# -----Train----------
# AUC: 89.52 Precision: 95.60 Recall: 82.46
#
# -----Validation-----
# AUC: 88.64 Precision: 100.00 Recall: 77.27
#
# Fold 2
#
# -----Train----------
# AUC: 88.29 Precision: 96.53 Recall: 79.15
#
# -----Validation-----
# AUC: 84.28 Precision: 94.12 Recall: 72.73
#
# Fold 3
#
# -----Train----------
# AUC: 90.44 Precision: 97.24 Recall: 83.02
#
# -----Validation-----
# AUC: 84.23 Precision: 85.00 Recall: 80.95
#
# Fold 4
#
# -----Train----------
# AUC: 91.15 Precision: 97.28 Recall: 84.43
#
# -----Validation-----
# AUC: 83.33 Precision: 100.00 Recall: 66.67
#
# Fold 5
#
# -----Train----------
# AUC: 89.73 Precision: 97.19 Recall: 81.60
#
# -----Validation-----
# AUC: 81.25 Precision: 93.33 Recall: 66.67
#
# Fold 6
#
# -----Train----------
# AUC: 90.26 Precision: 96.20 Recall: 83.49
#
# -----Validation-----
# AUC: 88.10 Precision: 100.00 Recall: 76.19
#
# Fold 7
#
# -----Train----------
# AUC: 90.47 Precision: 96.72 Recall: 83.49
#
# -----Validation-----
# AUC: 90.48 Precision: 100.00 Recall: 80.95
#
# Fold 8
#
# -----Train----------
# AUC: 89.08 Precision: 96.09 Recall: 81.13
#
# -----Validation-----
# AUC: 86.13 Precision: 89.47 Recall: 80.95
#
# Fold 9
#
# -----Train----------
# AUC: 89.81 Precision: 95.65 Recall: 83.02
#
# -----Validation-----
# AUC: 83.54 Precision: 93.75 Recall: 71.43
#
# Fold 10
#
# -----Train----------
# AUC: 90.00 Precision: 96.69 Recall: 82.55
#
# -----Validation-----
# AUC: 83.54 Precision: 93.75 Recall: 71.43
#
# Fold 11
#
# -----Train----------
# AUC: 88.60 Precision: 96.05 Recall: 80.19
#
# -----Validation-----
# AUC: 86.13 Precision: 89.47 Recall: 80.95
#
# wheezy-copper-turtle-magic 26
#
# Fold 1
#
# -----Train----------
# AUC: 88.09 Precision: 92.19 Recall: 82.71
#
# -----Validation-----
# AUC: 88.74 Precision: 94.74 Recall: 81.82
#
# Fold 2
#
# -----Train----------
# AUC: 88.05 Precision: 93.55 Recall: 81.31
#
# -----Validation-----
# AUC: 77.57 Precision: 83.33 Recall: 68.18
#
# Fold 3
#
# -----Train----------
# AUC: 88.11 Precision: 91.75 Recall: 83.18
#
# -----Validation-----
# AUC: 84.29 Precision: 89.47 Recall: 77.27
#
# Fold 4
#
# -----Train----------
# AUC: 88.78 Precision: 92.75 Recall: 83.64
#
# -----Validation-----
# AUC: 73.02 Precision: 81.25 Recall: 59.09
#
# Fold 5
#
# -----Train----------
# AUC: 88.13 Precision: 91.33 Recall: 83.64
#
# -----Validation-----
# AUC: 90.91 Precision: 100.00 Recall: 81.82
#
# Fold 6
#
# -----Train----------
# AUC: 90.41 Precision: 93.91 Recall: 86.05
#
# -----Validation-----
# AUC: 81.78 Precision: 80.95 Recall: 80.95
#
# Fold 7
#
# -----Train----------
# AUC: 89.03 Precision: 93.26 Recall: 83.72
#
# -----Validation-----
# AUC: 77.02 Precision: 78.95 Recall: 71.43
#
# Fold 8
#
# -----Train----------
# AUC: 87.86 Precision: 93.55 Recall: 80.93
#
# -----Validation-----
# AUC: 83.75 Precision: 88.89 Recall: 76.19
#
# Fold 9
#
# -----Train----------
# AUC: 89.96 Precision: 93.40 Recall: 85.58
#
# -----Validation-----
# AUC: 85.71 Precision: 100.00 Recall: 71.43
#
# Fold 10
#
# -----Train----------
# AUC: 88.65 Precision: 91.04 Recall: 85.12
#
# -----Validation-----
# AUC: 81.37 Precision: 88.24 Recall: 71.43
#
# Fold 11
#
# -----Train----------
# AUC: 88.35 Precision: 92.71 Recall: 82.79
#
# -----Validation-----
# AUC: 83.95 Precision: 85.00 Recall: 80.95
#
# wheezy-copper-turtle-magic 27
#
# Fold 1
#
# -----Train----------
# AUC: 89.23 Precision: 92.86 Recall: 84.26
#
# -----Validation-----
# AUC: 80.09 Precision: 88.24 Recall: 68.18
#
# Fold 2
#
# -----Train----------
# AUC: 90.25 Precision: 91.35 Recall: 87.96
#
# -----Validation-----
# AUC: 76.36 Precision: 76.19 Recall: 72.73
#
# Fold 3
#
# -----Train----------
# AUC: 89.20 Precision: 89.57 Recall: 87.50
#
# -----Validation-----
# AUC: 86.93 Precision: 86.36 Recall: 86.36
#
# Fold 4
#
# -----Train----------
# AUC: 88.41 Precision: 91.00 Recall: 84.26
#
# -----Validation-----
# AUC: 82.95 Precision: 76.92 Recall: 90.91
#
# Fold 5
#
# -----Train----------
# AUC: 90.19 Precision: 92.57 Recall: 86.57
#
# -----Validation-----
# AUC: 84.47 Precision: 89.47 Recall: 77.27
#
# Fold 6
#
# -----Train----------
# AUC: 88.72 Precision: 89.86 Recall: 86.11
#
# -----Validation-----
# AUC: 80.11 Precision: 84.21 Recall: 72.73
#
# Fold 7
#
# -----Train----------
# AUC: 89.93 Precision: 92.96 Recall: 85.65
#
# -----Validation-----
# AUC: 86.74 Precision: 90.00 Recall: 81.82
#
# Fold 8
#
# -----Train----------
# AUC: 87.16 Precision: 89.16 Recall: 83.41
#
# -----Validation-----
# AUC: 84.52 Precision: 81.82 Recall: 85.71
#
# Fold 9
#
# -----Train----------
# AUC: 90.12 Precision: 94.36 Recall: 84.79
#
# -----Validation-----
# AUC: 82.14 Precision: 80.95 Recall: 80.95
#
# Fold 10
#
# -----Train----------
# AUC: 89.34 Precision: 91.63 Recall: 85.71
#
# -----Validation-----
# AUC: 88.39 Precision: 94.44 Recall: 80.95
#
# Fold 11
#
# -----Train----------
# AUC: 88.40 Precision: 91.88 Recall: 83.41
#
# -----Validation-----
# AUC: 86.01 Precision: 94.12 Recall: 76.19
#
# wheezy-copper-turtle-magic 28
#
# Fold 1
#
# -----Train----------
# AUC: 89.74 Precision: 93.69 Recall: 85.25
#
# -----Validation-----
# AUC: 86.00 Precision: 87.50 Recall: 84.00
#
# Fold 2
#
# -----Train----------
# AUC: 89.94 Precision: 92.58 Recall: 86.89
#
# -----Validation-----
# AUC: 82.00 Precision: 83.33 Recall: 80.00
#
# Fold 3
#
# -----Train----------
# AUC: 88.92 Precision: 92.41 Recall: 84.84
#
# -----Validation-----
# AUC: 82.00 Precision: 80.77 Recall: 84.00
#
# Fold 4
#
# -----Train----------
# AUC: 90.56 Precision: 92.67 Recall: 88.11
#
# -----Validation-----
# AUC: 84.00 Precision: 84.00 Recall: 84.00
#
# Fold 5
#
# -----Train----------
# AUC: 90.57 Precision: 93.04 Recall: 87.70
#
# -----Validation-----
# AUC: 83.75 Precision: 86.96 Recall: 80.00
#
# Fold 6
#
# -----Train----------
# AUC: 88.76 Precision: 90.25 Recall: 86.94
#
# -----Validation-----
# AUC: 91.67 Precision: 95.45 Recall: 87.50
#
# Fold 7
#
# -----Train----------
# AUC: 89.98 Precision: 92.24 Recall: 87.35
#
# -----Validation-----
# AUC: 85.42 Precision: 90.48 Recall: 79.17
#
# Fold 8
#
# -----Train----------
# AUC: 89.58 Precision: 92.92 Recall: 85.71
#
# -----Validation-----
# AUC: 91.67 Precision: 100.00 Recall: 83.33
#
# Fold 9
#
# -----Train----------
# AUC: 89.98 Precision: 91.88 Recall: 87.76
#
# -----Validation-----
# AUC: 87.50 Precision: 90.91 Recall: 83.33
#
# Fold 10
#
# -----Train----------
# AUC: 89.98 Precision: 92.24 Recall: 87.35
#
# -----Validation-----
# AUC: 89.58 Precision: 91.30 Recall: 87.50
#
# Fold 11
#
# -----Train----------
# AUC: 90.80 Precision: 93.10 Recall: 88.16
#
# -----Validation-----
# AUC: 81.25 Precision: 85.71 Recall: 75.00
#
# wheezy-copper-turtle-magic 29
#
# Fold 1
#
# -----Train----------
# AUC: 91.14 Precision: 89.79 Recall: 92.95
#
# -----Validation-----
# AUC: 91.30 Precision: 95.24 Recall: 86.96
#
# Fold 2
#
# -----Train----------
# AUC: 92.03 Precision: 90.64 Recall: 93.83
#
# -----Validation-----
# AUC: 89.13 Precision: 87.50 Recall: 91.30
#
# Fold 3
#
# -----Train----------
# AUC: 92.47 Precision: 90.72 Recall: 94.71
#
# -----Validation-----
# AUC: 84.78 Precision: 83.33 Recall: 86.96
#
# Fold 4
#
# -----Train----------
# AUC: 92.69 Precision: 91.81 Recall: 93.83
#
# -----Validation-----
# AUC: 82.61 Precision: 75.86 Recall: 95.65
#
# Fold 5
#
# -----Train----------
# AUC: 91.58 Precision: 89.87 Recall: 93.83
#
# -----Validation-----
# AUC: 93.48 Precision: 88.46 Recall: 100.00
#
# Fold 6
#
# -----Train----------
# AUC: 91.36 Precision: 89.83 Recall: 93.39
#
# -----Validation-----
# AUC: 91.30 Precision: 91.30 Recall: 91.30
#
# Fold 7
#
# -----Train----------
# AUC: 91.16 Precision: 88.80 Recall: 94.27
#
# -----Validation-----
# AUC: 82.21 Precision: 82.61 Recall: 82.61
#
# Fold 8
#
# -----Train----------
# AUC: 91.38 Precision: 88.84 Recall: 94.71
#
# -----Validation-----
# AUC: 84.29 Precision: 80.77 Recall: 91.30
#
# Fold 9
#
# -----Train----------
# AUC: 92.06 Precision: 91.03 Recall: 93.42
#
# -----Validation-----
# AUC: 86.36 Precision: 90.00 Recall: 81.82
#
# Fold 10
#
# -----Train----------
# AUC: 92.28 Precision: 90.72 Recall: 94.30
#
# -----Validation-----
# AUC: 79.55 Precision: 78.26 Recall: 81.82
#
# Fold 11
#
# -----Train----------
# AUC: 91.84 Precision: 89.96 Recall: 94.30
#
# -----Validation-----
# AUC: 79.55 Precision: 74.07 Recall: 90.91
#
# wheezy-copper-turtle-magic 30
#
# Fold 1
#
# -----Train----------
# AUC: 88.85 Precision: 93.21 Recall: 84.43
#
# -----Validation-----
# AUC: 83.65 Precision: 90.48 Recall: 76.00
#
# Fold 2
#
# -----Train----------
# AUC: 89.80 Precision: 96.21 Recall: 83.20
#
# -----Validation-----
# AUC: 81.83 Precision: 94.44 Recall: 68.00
#
# Fold 3
#
# -----Train----------
# AUC: 88.89 Precision: 94.01 Recall: 83.61
#
# -----Validation-----
# AUC: 79.48 Precision: 85.71 Recall: 72.00
#
# Fold 4
#
# -----Train----------
# AUC: 88.95 Precision: 95.26 Recall: 82.38
#
# -----Validation-----
# AUC: 83.48 Precision: 86.96 Recall: 80.00
#
# Fold 5
#
# -----Train----------
# AUC: 90.60 Precision: 95.43 Recall: 85.66
#
# -----Validation-----
# AUC: 85.45 Precision: 90.91 Recall: 80.00
#
# Fold 6
#
# -----Train----------
# AUC: 91.01 Precision: 95.09 Recall: 86.94
#
# -----Validation-----
# AUC: 80.49 Precision: 82.61 Recall: 79.17
#
# Fold 7
#
# -----Train----------
# AUC: 88.93 Precision: 94.04 Recall: 83.67
#
# -----Validation-----
# AUC: 87.50 Precision: 100.00 Recall: 75.00
#
# Fold 8
#
# -----Train----------
# AUC: 89.73 Precision: 93.75 Recall: 85.71
#
# -----Validation-----
# AUC: 84.85 Precision: 86.96 Recall: 83.33
#
# Fold 9
#
# -----Train----------
# AUC: 91.44 Precision: 95.54 Recall: 87.35
#
# -----Validation-----
# AUC: 82.95 Precision: 90.00 Recall: 75.00
#
# Fold 10
#
# -----Train----------
# AUC: 90.36 Precision: 94.22 Recall: 86.53
#
# -----Validation-----
# AUC: 93.75 Precision: 100.00 Recall: 87.50
#
# Fold 11
#
# ...
#
# wheezy-copper-turtle-magic 307
#
# Fold 1
#
# -----Train----------
# AUC: 90.00 Precision: 95.22 Recall: 84.32
#
# -----Validation-----
# AUC: 79.17 Precision: 85.00 Recall: 70.83
#
# Fold 2
#
# -----Train----------
# AUC: 89.58 Precision: 96.06 Recall: 82.63
#
# -----Validation-----
# AUC: 85.42 Precision: 94.74 Recall: 75.00
#
# Fold 3
#
# -----Train----------
# AUC: 90.21 Precision: 93.98 Recall: 86.02
#
# -----Validation-----
# AUC: 83.24 Precision: 94.44 Recall: 70.83
#
# Fold 4
#
# -----Train----------
# AUC: 89.57 Precision: 93.49 Recall: 85.17
#
# -----Validation-----
# AUC: 87.32 Precision: 90.91 Recall: 83.33
#
# Fold 5
#
# -----Train----------
# AUC: 89.36 Precision: 93.46 Recall: 84.75
#
# -----Validation-----
# AUC: 85.42 Precision: 100.00 Recall: 70.83
#
# Fold 6
#
# -----Train----------
# AUC: 89.14 Precision: 92.63 Recall: 85.17
#
# -----Validation-----
# AUC: 80.98 Precision: 85.71 Recall: 75.00
#
# Fold 7
#
# -----Train----------
# AUC: 89.56 Precision: 92.69 Recall: 86.02
#
# -----Validation-----
# AUC: 95.74 Precision: 95.83 Recall: 95.83
#
# Fold 8
#
# -----Train----------
# AUC: 90.89 Precision: 95.75 Recall: 85.65
#
# -----Validation-----
# AUC: 76.09 Precision: 80.00 Recall: 69.57
#
# Fold 9
#
# -----Train----------
# AUC: 88.76 Precision: 93.81 Recall: 83.12
#
# -----Validation-----
# AUC: 86.96 Precision: 90.48 Recall: 82.61
#
# Fold 10
#
# -----Train----------
# AUC: 89.80 Precision: 92.38 Recall: 86.92
#
# -----Validation-----
# AUC: 84.78 Precision: 86.36 Recall: 82.61
#
# Fold 11
#
# -----Train----------
# AUC: 90.24 Precision: 94.01 Recall: 86.08
#
# -----Validation-----
# AUC: 82.61 Precision: 89.47 Recall: 73.91
#
# wheezy-copper-turtle-magic 308
#
# Fold 1
#
# -----Train----------
# AUC: 88.77 Precision: 95.41 Recall: 81.30
#
# -----Validation-----
# AUC: 77.08 Precision: 93.33 Recall: 58.33
#
# Fold 2
#
# -----Train----------
# AUC: 85.36 Precision: 94.05 Recall: 75.32
#
# -----Validation-----
# AUC: 91.39 Precision: 95.24 Recall: 86.96
#
# Fold 3
#
# -----Train----------
# AUC: 86.22 Precision: 94.65 Recall: 76.62
#
# -----Validation-----
# AUC: 89.22 Precision: 95.00 Recall: 82.61
#
# Fold 4
#
# -----Train----------
# AUC: 87.51 Precision: 95.29 Recall: 78.79
#
# -----Validation-----
# AUC: 78.53 Precision: 84.21 Recall: 69.57
#
# Fold 5
#
# -----Train----------
# AUC: 88.61 Precision: 94.50 Recall: 81.82
#
# -----Validation-----
# AUC: 78.44 Precision: 88.24 Recall: 65.22
#
# Fold 6
#
# -----Train----------
# AUC: 85.61 Precision: 92.27 Recall: 77.49
#
# -----Validation-----
# AUC: 84.78 Precision: 100.00 Recall: 69.57
#
# Fold 7
#
# -----Train----------
# AUC: 86.41 Precision: 96.67 Recall: 75.32
#
# -----Validation-----
# AUC: 76.18 Precision: 92.86 Recall: 56.52
#
# Fold 8
#
# -----Train----------
# AUC: 86.64 Precision: 95.68 Recall: 76.62
#
# -----Validation-----
# AUC: 74.09 Precision: 86.67 Recall: 56.52
#
# Fold 9
#
# -----Train----------
# AUC: 86.21 Precision: 95.14 Recall: 76.19
#
# -----Validation-----
# AUC: 78.53 Precision: 84.21 Recall: 69.57
#
# Fold 10
#
# -----Train----------
# AUC: 86.00 Precision: 94.62 Recall: 76.19
#
# -----Validation-----
# AUC: 76.27 Precision: 87.50 Recall: 60.87
#
# Fold 11
#
# -----Train----------
# AUC: 85.33 Precision: 96.57 Recall: 73.16
#
# -----Validation-----
# AUC: 76.09 Precision: 87.50 Recall: 60.87
#
# wheezy-copper-turtle-magic 309
#
# Fold 1
#
# -----Train----------
# AUC: 86.98 Precision: 94.30 Recall: 78.79
#
# -----Validation-----
# AUC: 83.06 Precision: 86.36 Recall: 79.17
#
# Fold 2
#
# -----Train----------
# AUC: 86.77 Precision: 95.70 Recall: 77.06
#
# -----Validation-----
# AUC: 78.99 Precision: 88.89 Recall: 66.67
#
# Fold 3
#
# -----Train----------
# AUC: 85.74 Precision: 94.62 Recall: 75.86
#
# -----Validation-----
# AUC: 84.78 Precision: 94.44 Recall: 73.91
#
# Fold 4
#
# -----Train----------
# AUC: 85.53 Precision: 95.08 Recall: 75.00
#
# -----Validation-----
# AUC: 82.61 Precision: 85.71 Recall: 78.26
#
# Fold 5
#
# -----Train----------
# AUC: 87.68 Precision: 94.87 Recall: 79.74
#
# -----Validation-----
# AUC: 84.78 Precision: 94.44 Recall: 73.91
#
# Fold 6
#
# -----Train----------
# AUC: 86.36 Precision: 92.04 Recall: 79.74
#
# -----Validation-----
# AUC: 82.61 Precision: 100.00 Recall: 65.22
#
# Fold 7
#
# -----Train----------
# AUC: 85.50 Precision: 92.31 Recall: 77.59
#
# -----Validation-----
# AUC: 80.43 Precision: 93.75 Recall: 65.22
#
# Fold 8
#
# -----Train----------
# AUC: 85.09 Precision: 94.54 Recall: 74.57
#
# -----Validation-----
# AUC: 80.43 Precision: 93.75 Recall: 65.22
#
# Fold 9
#
# -----Train----------
# AUC: 87.67 Precision: 93.53 Recall: 81.03
#
# -----Validation-----
# AUC: 82.61 Precision: 94.12 Recall: 69.57
#
# Fold 10
#
# -----Train----------
# AUC: 84.66 Precision: 93.51 Recall: 74.57
#
# -----Validation-----
# AUC: 78.16 Precision: 93.33 Recall: 60.87
#
# Fold 11
#
# -----Train----------
# AUC: 87.47 Precision: 95.31 Recall: 78.88
#
# -----Validation-----
# AUC: 73.52 Precision: 78.95 Recall: 65.22
#
# wheezy-copper-turtle-magic 310
#
# Fold 1
#
# -----Train----------
# AUC: 89.40 Precision: 92.42 Recall: 85.53
#
# -----Validation-----
# AUC: 87.23 Precision: 86.96 Recall: 86.96
#
# Fold 2
#
# -----Train----------
# AUC: 90.04 Precision: 93.33 Recall: 85.96
#
# -----Validation-----
# AUC: 82.79 Precision: 89.47 Recall: 73.91
#
# Fold 3
#
# -----Train----------
# AUC: 89.18 Precision: 92.38 Recall: 85.09
#
# -----Validation-----
# AUC: 76.18 Precision: 92.86 Recall: 56.52
#
# Fold 4
#
# -----Train----------
# AUC: 89.15 Precision: 93.63 Recall: 83.77
#
# -----Validation-----
# AUC: 87.05 Precision: 94.74 Recall: 78.26
#
# Fold 5
#
# -----Train----------
# AUC: 88.52 Precision: 92.68 Recall: 83.33
#
# -----Validation-----
# AUC: 78.44 Precision: 88.24 Recall: 65.22
#
# Fold 6
#
# -----Train----------
# AUC: 88.93 Precision: 94.03 Recall: 82.89
#
# -----Validation-----
# AUC: 82.79 Precision: 89.47 Recall: 73.91
#
# Fold 7
#
# -----Train----------
# AUC: 87.82 Precision: 94.33 Recall: 80.26
#
# -----Validation-----
# AUC: 87.23 Precision: 86.96 Recall: 86.96
#
# Fold 8
#
# -----Train----------
# AUC: 89.60 Precision: 93.27 Recall: 85.09
#
# -----Validation-----
# AUC: 80.80 Precision: 81.82 Recall: 78.26
#
# Fold 9
#
# -----Train----------
# AUC: 88.67 Precision: 95.83 Recall: 80.70
#
# -----Validation-----
# AUC: 82.88 Precision: 85.71 Recall: 78.26
#
# Fold 10
#
# -----Train----------
# AUC: 87.48 Precision: 92.12 Recall: 81.66
#
# -----Validation-----
# AUC: 79.84 Precision: 84.21 Recall: 72.73
#
# Fold 11
#
# -----Train----------
# AUC: 88.77 Precision: 93.17 Recall: 83.41
#
# -----Validation-----
# AUC: 86.56 Precision: 90.00 Recall: 81.82
#
# wheezy-copper-turtle-magic 311
#
# Fold 1
#
# -----Train----------
# AUC: 87.87 Precision: 93.72 Recall: 81.64
#
# -----Validation-----
# AUC: 80.45 Precision: 90.00 Recall: 69.23
#
# Fold 2
#
# -----Train----------
# AUC: 89.37 Precision: 92.47 Recall: 86.33
#
# -----Validation-----
# AUC: 86.38 Precision: 95.24 Recall: 76.92
#
# Fold 3
#
# -----Train----------
# AUC: 89.87 Precision: 95.15 Recall: 84.38
#
# -----Validation-----
# AUC: 85.90 Precision: 85.19 Recall: 88.46
#
# Fold 4
#
# -----Train----------
# AUC: 89.79 Precision: 93.25 Recall: 86.33
#
# -----Validation-----
# AUC: 87.82 Precision: 85.71 Recall: 92.31
#
# Fold 5
#
# -----Train----------
# AUC: 89.77 Precision: 92.89 Recall: 86.72
#
# -----Validation-----
# AUC: 86.22 Precision: 91.30 Recall: 80.77
#
# Fold 6
#
# -----Train----------
# AUC: 89.53 Precision: 91.80 Recall: 87.50
#
# -----Validation-----
# AUC: 88.14 Precision: 91.67 Recall: 84.62
#
# Fold 7
#
# -----Train----------
# AUC: 88.60 Precision: 92.70 Recall: 84.38
#
# -----Validation-----
# AUC: 88.30 Precision: 95.45 Recall: 80.77
#
# Fold 8
#
# -----Train----------
# AUC: 87.17 Precision: 94.86 Recall: 78.99
#
# -----Validation-----
# AUC: 79.83 Precision: 89.47 Recall: 68.00
#
# Fold 9
#
# -----Train----------
# AUC: 89.26 Precision: 93.56 Recall: 84.82
#
# -----Validation-----
# AUC: 89.30 Precision: 85.71 Recall: 96.00
#
# Fold 10
#
# -----Train----------
# AUC: 88.06 Precision: 92.64 Recall: 83.27
#
# -----Validation-----
# AUC: 82.00 Precision: 100.00 Recall: 64.00
#
# Fold 11
#
# -----Train----------
# AUC: 89.77 Precision: 91.87 Recall: 87.94
#
# -----Validation-----
# AUC: 81.30 Precision: 83.33 Recall: 80.00
#
# wheezy-copper-turtle-magic 312
#
# Fold 1
#
# -----Train----------
# AUC: 88.88 Precision: 92.68 Recall: 84.07
#
# -----Validation-----
# AUC: 89.22 Precision: 95.00 Recall: 82.61
#
# Fold 2
#
# -----Train----------
# AUC: 87.41 Precision: 89.62 Recall: 84.07
#
# -----Validation-----
# AUC: 89.31 Precision: 90.91 Recall: 86.96
#
# Fold 3
#
# -----Train----------
# AUC: 90.23 Precision: 92.09 Recall: 87.61
#
# -----Validation-----
# AUC: 74.28 Precision: 78.95 Recall: 65.22
#
# Fold 4
#
# -----Train----------
# AUC: 87.15 Precision: 91.13 Recall: 81.86
#
# -----Validation-----
# AUC: 87.32 Precision: 84.00 Recall: 91.30
#
# Fold 5
#
# -----Train----------
# AUC: 89.59 Precision: 91.20 Recall: 87.17
#
# -----Validation-----
# AUC: 85.05 Precision: 86.36 Recall: 82.61
#
# Fold 6
#
# -----Train----------
# AUC: 89.13 Precision: 91.90 Recall: 85.40
#
# -----Validation-----
# AUC: 80.53 Precision: 93.75 Recall: 65.22
#
# Fold 7
#
# -----Train----------
# AUC: 87.80 Precision: 91.67 Recall: 82.74
#
# -----Validation-----
# AUC: 82.79 Precision: 89.47 Recall: 73.91
#
# Fold 8
#
# -----Train----------
# AUC: 89.16 Precision: 91.94 Recall: 85.46
#
# -----Validation-----
# AUC: 79.92 Precision: 88.24 Recall: 68.18
#
# Fold 9
#
# -----Train----------
# AUC: 89.17 Precision: 91.55 Recall: 85.90
#
# -----Validation-----
# AUC: 91.29 Precision: 90.91 Recall: 90.91
#
# Fold 10
#
# -----Train----------
# AUC: 89.09 Precision: 95.38 Recall: 81.94
#
# -----Validation-----
# AUC: 68.87 Precision: 68.18 Recall: 68.18
#
# Fold 11
#
# -----Train----------
# AUC: 89.59 Precision: 92.82 Recall: 85.46
#
# -----Validation-----
# AUC: 86.66 Precision: 86.36 Recall: 86.36
#
# wheezy-copper-turtle-magic 313
#
# Fold 1
#
# -----Train----------
# AUC: 87.19 Precision: 93.07 Recall: 80.69
#
# -----Validation-----
# AUC: 76.90 Precision: 88.24 Recall: 62.50
#
# Fold 2
#
# -----Train----------
# AUC: 86.15 Precision: 94.24 Recall: 77.25
#
# -----Validation-----
# AUC: 87.32 Precision: 90.91 Recall: 83.33
#
# Fold 3
#
# -----Train----------
# AUC: 87.37 Precision: 91.87 Recall: 82.40
#
# -----Validation-----
# AUC: 87.32 Precision: 90.91 Recall: 83.33
#
# Fold 4
#
# -----Train----------
# AUC: 85.73 Precision: 94.18 Recall: 76.39
#
# -----Validation-----
# AUC: 81.06 Precision: 94.12 Recall: 66.67
#
# Fold 5
#
# -----Train----------
# AUC: 87.92 Precision: 94.50 Recall: 80.77
#
# -----Validation-----
# AUC: 69.27 Precision: 80.00 Recall: 52.17
#
# Fold 6
#
# -----Train----------
# AUC: 87.91 Precision: 94.06 Recall: 81.20
#
# -----Validation-----
# AUC: 82.41 Precision: 89.47 Recall: 73.91
#
# Fold 7
#
# -----Train----------
# AUC: 88.97 Precision: 93.78 Recall: 83.76
#
# -----Validation-----
# AUC: 75.69 Precision: 80.00 Recall: 69.57
#
# Fold 8
#
# -----Train----------
# AUC: 86.43 Precision: 94.76 Recall: 77.35
#
# -----Validation-----
# AUC: 84.49 Precision: 86.36 Recall: 82.61
#
# Fold 9
#
# -----Train----------
# AUC: 86.66 Precision: 95.26 Recall: 77.35
#
# -----Validation-----
# AUC: 84.68 Precision: 94.44 Recall: 73.91
#
# Fold 10
#
# -----Train----------
# AUC: 88.35 Precision: 94.55 Recall: 81.62
#
# -----Validation-----
# AUC: 78.06 Precision: 88.24 Recall: 65.22
#
# Fold 11
#
# -----Train----------
# AUC: 86.43 Precision: 94.76 Recall: 77.35
#
# -----Validation-----
# AUC: 86.86 Precision: 94.74 Recall: 78.26
#
# wheezy-copper-turtle-magic 314
#
# Fold 1
#
# -----Train----------
# AUC: 90.32 Precision: 90.91 Recall: 91.60
#
# -----Validation-----
# AUC: 92.17 Precision: 96.00 Recall: 88.89
#
# Fold 2
#
# -----Train----------
# AUC: 90.63 Precision: 90.37 Recall: 93.13
#
# -----Validation-----
# AUC: 81.65 Precision: 84.62 Recall: 81.48
#
# Fold 3
#
# -----Train----------
# AUC: 89.64 Precision: 89.89 Recall: 91.60
#
# -----Validation-----
# AUC: 91.75 Precision: 92.59 Recall: 92.59
#
# Fold 4
#
# -----Train----------
# AUC: 90.00 Precision: 91.19 Recall: 90.49
#
# -----Validation-----
# AUC: 90.91 Precision: 86.67 Recall: 100.00
#
# Fold 5
#
# -----Train----------
# AUC: 89.58 Precision: 90.80 Recall: 90.11
#
# -----Validation-----
# AUC: 83.22 Precision: 84.62 Recall: 84.62
#
# Fold 6
#
# -----Train----------
# AUC: 89.50 Precision: 90.19 Recall: 90.87
#
# -----Validation-----
# AUC: 85.84 Precision: 91.30 Recall: 80.77
#
# Fold 7
#
# -----Train----------
# AUC: 90.41 Precision: 90.07 Recall: 93.16
#
# -----Validation-----
# AUC: 75.52 Precision: 81.82 Recall: 69.23
#
# Fold 8
#
# -----Train----------
# AUC: 88.89 Precision: 89.77 Recall: 90.11
#
# -----Validation-----
# AUC: 95.80 Precision: 96.15 Recall: 96.15
#
# Fold 9
#
# -----Train----------
# AUC: 91.29 Precision: 92.66 Recall: 91.25
#
# -----Validation-----
# AUC: 82.87 Precision: 82.14 Recall: 88.46
#
# Fold 10
#
# -----Train----------
# AUC: 89.04 Precision: 89.51 Recall: 90.87
#
# -----Validation-----
# AUC: 98.08 Precision: 100.00 Recall: 96.15
#
# Fold 11
#
# -----Train----------
# AUC: 90.06 Precision: 90.00 Recall: 92.40
#
# -----Validation-----
# AUC: 80.40 Precision: 81.48 Recall: 84.62
#
# wheezy-copper-turtle-magic 315
#
# Fold 1
#
# -----Train----------
# AUC: 92.10 Precision: 94.95 Recall: 89.22
#
# -----Validation-----
# AUC: 82.77 Precision: 86.36 Recall: 79.17
#
# Fold 2
#
# -----Train----------
# AUC: 92.75 Precision: 95.02 Recall: 90.52
#
# -----Validation-----
# AUC: 95.64 Precision: 95.83 Recall: 95.83
#
# Fold 3
#
# -----Train----------
# AUC: 91.68 Precision: 95.33 Recall: 87.93
#
# -----Validation-----
# AUC: 95.83 Precision: 100.00 Recall: 91.67
#
# Fold 4
#
# -----Train----------
# AUC: 92.57 Precision: 95.43 Recall: 89.70
#
# -----Validation-----
# AUC: 84.58 Precision: 90.00 Recall: 78.26
#
# Fold 5
#
# -----Train----------
# AUC: 90.84 Precision: 94.84 Recall: 86.70
#
# -----Validation-----
# AUC: 89.03 Precision: 95.00 Recall: 82.61
#
# Fold 6
#
# -----Train----------
# AUC: 92.95 Precision: 94.27 Recall: 91.85
#
# -----Validation-----
# AUC: 89.13 Precision: 100.00 Recall: 78.26
#
# Fold 7
#
# -----Train----------
# AUC: 91.47 Precision: 94.50 Recall: 88.41
#
# -----Validation-----
# AUC: 95.65 Precision: 100.00 Recall: 91.30
#
# Fold 8
#
# -----Train----------
# AUC: 91.08 Precision: 95.71 Recall: 86.27
#
# -----Validation-----
# AUC: 91.21 Precision: 95.24 Recall: 86.96
#
# Fold 9
#
# -----Train----------
# AUC: 92.38 Precision: 96.26 Recall: 88.41
#
# -----Validation-----
# AUC: 88.93 Precision: 90.91 Recall: 86.96
#
# Fold 10
#
# -----Train----------
# AUC: 91.49 Precision: 95.33 Recall: 87.55
#
# -----Validation-----
# AUC: 91.21 Precision: 95.24 Recall: 86.96
#
# Fold 11
#
# -----Train----------
# AUC: 93.44 Precision: 95.52 Recall: 91.42
#
# -----Validation-----
# AUC: 73.08 Precision: 78.95 Recall: 65.22
#
# wheezy-copper-turtle-magic 316
#
# Fold 1
#
# -----Train----------
# AUC: 88.54 Precision: 90.79 Recall: 87.50
#
# -----Validation-----
# AUC: 92.00 Precision: 100.00 Recall: 84.00
#
# Fold 2
#
# -----Train----------
# AUC: 90.76 Precision: 93.25 Recall: 89.11
#
# -----Validation-----
# AUC: 76.91 Precision: 81.82 Recall: 72.00
#
# Fold 3
#
# -----Train----------
# AUC: 88.70 Precision: 92.21 Recall: 85.89
#
# -----Validation-----
# AUC: 74.48 Precision: 80.95 Recall: 68.00
#
# Fold 4
#
# -----Train----------
# AUC: 89.67 Precision: 92.02 Recall: 88.31
#
# -----Validation-----
# AUC: 85.62 Precision: 95.00 Recall: 76.00
#
# Fold 5
#
# -----Train----------
# AUC: 88.63 Precision: 93.69 Recall: 83.87
#
# -----Validation-----
# AUC: 77.24 Precision: 88.89 Recall: 64.00
#
# Fold 6
#
# -----Train----------
# AUC: 88.90 Precision: 92.24 Recall: 86.29
#
# -----Validation-----
# AUC: 89.24 Precision: 91.67 Recall: 88.00
#
# Fold 7
#
# -----Train----------
# AUC: 90.38 Precision: 93.19 Recall: 88.31
#
# -----Validation-----
# AUC: 86.86 Precision: 88.00 Recall: 88.00
#
# Fold 8
#
# -----Train----------
# AUC: 89.23 Precision: 91.60 Recall: 87.90
#
# -----Validation-----
# AUC: 89.24 Precision: 91.67 Recall: 88.00
#
# Fold 9
#
# -----Train----------
# AUC: 88.60 Precision: 93.30 Recall: 84.27
#
# -----Validation-----
# AUC: 86.48 Precision: 85.19 Recall: 92.00
#
# Fold 10
#
# -----Train----------
# AUC: 89.49 Precision: 92.02 Recall: 87.95
#
# -----Validation-----
# AUC: 86.61 Precision: 87.50 Recall: 87.50
#
# Fold 11
#
# -----Train----------
# AUC: 88.25 Precision: 91.45 Recall: 85.94
#
# -----Validation-----
# AUC: 91.37 Precision: 95.45 Recall: 87.50
#
# wheezy-copper-turtle-magic 317
#
# Fold 1
#
# -----Train----------
# AUC: 88.23 Precision: 95.45 Recall: 80.08
#
# -----Validation-----
# AUC: 77.25 Precision: 88.24 Recall: 62.50
#
# Fold 2
#
# -----Train----------
# AUC: 88.23 Precision: 95.45 Recall: 80.08
#
# -----Validation-----
# AUC: 85.58 Precision: 90.48 Recall: 79.17
#
# Fold 3
#
# -----Train----------
# AUC: 87.83 Precision: 94.06 Recall: 80.51
#
# -----Validation-----
# AUC: 83.58 Precision: 86.36 Recall: 79.17

# %% [markdown]
# # Model evaluation
# ## Confusion matrix

# %%
f = plt.subplots(1, 1, figsize=(16, 5), sharex=True)
train_cnf_matrix = confusion_matrix(train['target'], [np.round(x) for x in train['preds']])
train_cnf_matrix_norm = train_cnf_matrix / train_cnf_matrix.sum(axis=1)[:, np.newaxis]
train_df_cm = pd.DataFrame(train_cnf_matrix_norm, index=[0, 1], columns=[0, 1])
sns.heatmap(train_df_cm, annot=True, fmt='.2f', cmap="Blues")
plt.show()

# %% [markdown]
# ## Metrics ROC AUC

# %%
print('AUC %.2f' % roc_auc_score(train['target'], train['preds']))
# Out:
# AUC 0.96

# %% [markdown]
# # Test predictions

# %%
submission = test[['id', 'target']]
submission.to_csv('submission.csv', index=False)
submission.head(10)
# Out:
#                                  id    target
# 0  1c13f2701648e0b0d46d8a2a5a131a53  0.309091
# 1  ba88c155ba898fc8b5099893036ef205  0.609091
# 2  7cbab5cea99169139e7e6d8ff74ebb77  0.545455
# 3  ca820ad57809f62eb7b4d13f5d4371a0  0.300000
# 4  7baaf361537fbd8a1aaa2c97a6d4ccc7  0.318182
# 5  8b3116e5e3e92e971dac305d1a093bf6  0.327273
# 6  35cfd7cab9bfa29bc963d1b8c94dd280  0.090909
# 7  83cf532df8ff4642a3e33a70fffdac37  0.790909
# 8  2e1350fe94ec9f2220bec5245e5e9265  0.563636
# 9  e62020afa72eb54a15725473e3a8475b  0.463636
