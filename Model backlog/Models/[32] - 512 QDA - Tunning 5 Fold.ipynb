# %% [markdown]
# # Dependencies

# %%
import warnings
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

from sklearn.svm import SVC, NuSVC
from sklearn.decomposition import PCA
from sklearn.neural_network import MLPClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.discriminant_analysis import QuadraticDiscriminantAnalysis
from sklearn.feature_selection import VarianceThreshold
from sklearn.preprocessing import MinMaxScaler, StandardScaler
from sklearn.model_selection import train_test_split, StratifiedKFold, RandomizedSearchCV
from sklearn.metrics import confusion_matrix, roc_auc_score, recall_score, precision_score
from bayes_opt import BayesianOptimization

# Set seeds to make the experiment more reproducible.
from numpy.random import seed
seed(0)

# %matplotlib inline
sns.set_style("whitegrid")
warnings.filterwarnings("ignore")

# %% [markdown]
# # Load data

# %%
train = pd.read_csv('../input/train.csv')
test = pd.read_csv('../input/test.csv')

print('Train set shape:', train.shape)
print('Test set shape:', test.shape)
print('Train set overview:')
display(train.head())
# Out:
# Train set shape: (262144, 258)
# Test set shape: (131073, 257)
# Train set overview:
#                                  id   ...    target
# 0  707b395ecdcbb4dc2eabea00e4d1b179   ...         0
# 1  5880c03c6582a7b42248668e56b4bdec   ...         0
# 2  4ccbcb3d13e5072ff1d9c61afe2c4f77   ...         1
# 3  e350f17a357f12a1941f0837afb7eb8d   ...         0
# 4  a8f910ea6075b6376af079055965ff68   ...         0
#
# [5 rows x 258 columns]

# %% [markdown]
# # Model
#
# ## Model parameters

# %%
N_FOLDS = 5

# %% [markdown]
# ### You can find evaluation metrics for each model on each fold below on this cell output log. (It's hidden to keep the code clean)

# %%
# INITIALIZE VARIABLES
cols = [c for c in train.columns if c not in ['id', 'target', 'wheezy-copper-turtle-magic', 'preds']]
reg_param = np.random.uniform(0.001, 1, 200)
test['target'] = 0
train['preds'] = 0


# BUILD 512 MODELS
for i in range(512):
    print('wheezy-copper-turtle-magic {}\n'.format(i))

    # EXTRACT SUBSET OF DATASET WHERE WHEEZY-MAGIC EQUALS I
    train2 = train[train['wheezy-copper-turtle-magic']==i]
    test2 = test[test['wheezy-copper-turtle-magic']==i]
    idx1 = train2.index
    idx2 = test2.index
    train2.reset_index(drop=True, inplace=True)

#     data = pd.concat([pd.DataFrame(train2[cols]), pd.DataFrame(test2[cols])])
#     data2 = StandardScaler().fit_transform(PCA(svd_solver='full', n_components='mle').fit_transform(data[cols]))
#     train3 = data2[:train2.shape[0]]
#     test3 = data2[train2.shape[0]:]
    sel = VarianceThreshold(threshold=2).fit(train2[cols])
    train3 = sel.transform(train2[cols])
    test3 = sel.transform(test2[cols])
#     scaler = StandardScaler().fit(train3)
#     train3 = scaler.transform(train3)
#     test3 = scaler.transform(test3)

    skf = StratifiedKFold(n_splits=N_FOLDS, random_state=0)
    counter = 0

    for train_index, val_index in skf.split(train3, train2['target']):
        counter += 1
        print('Fold {}\n'.format(counter))
        
        # Random search        
        param_grid = dict(reg_param=reg_param)
        model = QuadraticDiscriminantAnalysis()
        grid_search = RandomizedSearchCV(param_distributions=param_grid, estimator=model, scoring="roc_auc", cv=skf, n_jobs=-1, n_iter=100, verbose=0)
        result = grid_search.fit(train3, train2['target'])
        print("Best: %f using %s" % (result.best_score_, result.best_params_))
            
        model = QuadraticDiscriminantAnalysis(reg_param=result.best_params_['reg_param'])
        model.fit(train3[train_index,:], train2.loc[train_index]['target'])

        train_predictions = model.predict(train3[train_index,:])
        val_predictions = model.predict(train3[val_index,:])

        train_auc = roc_auc_score(train2.loc[train_index]['target'], train_predictions) * 100
        val_auc = roc_auc_score(train2.loc[val_index]['target'], val_predictions) * 100
        train_precision = precision_score(train2.loc[train_index]['target'], train_predictions) * 100
        val_precision = precision_score(train2.loc[val_index]['target'], val_predictions) * 100
        train_recall = recall_score(train2.loc[train_index]['target'], train_predictions) * 100
        val_recall = recall_score(train2.loc[val_index]['target'], val_predictions) * 100
        print('-----Train----------')
        print('AUC: %.2f Precision: %.2f Recall: %.2f \n' % (train_auc, train_precision, train_recall))
        print('-----Validation-----')
        print('AUC: %.2f Precision: %.2f Recall: %.2f \n' % (val_auc, val_precision, val_recall))

        # Make predictions
        train['preds'].loc[idx1] += model.predict_proba(train3)[:,1] / N_FOLDS
        test['target'].loc[idx2] += model.predict_proba(test3)[:,1] / N_FOLDS
# Out:
# wheezy-copper-turtle-magic 0
#
# Fold 1
#
# Best: 0.961316 using {'reg_param': 0.934279783926869}
# -----Train----------
# AUC: 97.17 Precision: 98.06 Recall: 96.19
#
# -----Validation-----
# AUC: 87.00 Precision: 88.24 Recall: 84.91
#
# Fold 2
#
# Best: 0.961316 using {'reg_param': 0.934279783926869}
# -----Train----------
# AUC: 96.50 Precision: 95.77 Recall: 97.14
#
# -----Validation-----
# AUC: 94.39 Precision: 94.34 Recall: 94.34
#
# Fold 3
#
# Best: 0.961316 using {'reg_param': 0.934279783926869}
# -----Train----------
# AUC: 96.72 Precision: 96.67 Recall: 96.67
#
# -----Validation-----
# AUC: 95.32 Precision: 96.15 Recall: 94.34
#
# Fold 4
#
# Best: 0.961316 using {'reg_param': 0.934279783926869}
# -----Train----------
# AUC: 97.43 Precision: 97.17 Recall: 97.63
#
# -----Validation-----
# AUC: 91.49 Precision: 92.16 Recall: 90.38
#
# Fold 5
#
# Best: 0.961178 using {'reg_param': 0.9195631311309289}
# -----Train----------
# AUC: 97.67 Precision: 97.18 Recall: 98.10
#
# -----Validation-----
# AUC: 92.41 Precision: 94.00 Recall: 90.38
#
# wheezy-copper-turtle-magic 1
#
# Fold 1
#
# Best: 0.960040 using {'reg_param': 0.6052406742253009}
# -----Train----------
# AUC: 96.35 Precision: 95.02 Recall: 97.45
#
# -----Validation-----
# AUC: 96.17 Precision: 94.23 Recall: 98.00
#
# Fold 2
#
# Best: 0.960040 using {'reg_param': 0.6052406742253009}
# -----Train----------
# AUC: 97.11 Precision: 95.57 Recall: 98.48
#
# -----Validation-----
# AUC: 88.29 Precision: 86.27 Recall: 89.80
#
# Fold 3
#
# Best: 0.960040 using {'reg_param': 0.6143519900099301}
# -----Train----------
# AUC: 96.62 Precision: 95.07 Recall: 97.97
#
# -----Validation-----
# AUC: 92.07 Precision: 93.62 Recall: 89.80
#
# Fold 4
#
# Best: 0.960040 using {'reg_param': 0.6052406742253009}
# -----Train----------
# AUC: 97.36 Precision: 95.59 Recall: 98.98
#
# -----Validation-----
# AUC: 91.12 Precision: 91.67 Recall: 89.80
#
# Fold 5
#
# Best: 0.960040 using {'reg_param': 0.6031606126955722}
# -----Train----------
# AUC: 97.13 Precision: 95.12 Recall: 98.98
#
# -----Validation-----
# AUC: 94.05 Precision: 93.88 Recall: 93.88
#
# wheezy-copper-turtle-magic 2
#
# Fold 1
#
# Best: 0.966252 using {'reg_param': 0.7354588281004723}
# -----Train----------
# AUC: 97.48 Precision: 96.94 Recall: 97.94
#
# -----Validation-----
# AUC: 92.98 Precision: 93.75 Recall: 91.84
#
# Fold 2
#
# Best: 0.966333 using {'reg_param': 0.7398112442542383}
# -----Train----------
# AUC: 98.23 Precision: 97.95 Recall: 98.45
#
# -----Validation-----
# AUC: 90.12 Precision: 85.45 Recall: 95.92
#
# Fold 3
#
# Best: 0.966334 using {'reg_param': 0.7303919074872529}
# -----Train----------
# AUC: 98.72 Precision: 99.48 Recall: 97.94
#
# -----Validation-----
# AUC: 90.94 Precision: 88.46 Recall: 93.88
#
# Fold 4
#
# Best: 0.966170 using {'reg_param': 0.7255290255398209}
# -----Train----------
# AUC: 97.51 Precision: 96.02 Recall: 98.97
#
# -----Validation-----
# AUC: 93.79 Precision: 97.73 Recall: 89.58
#
# Fold 5
#
# Best: 0.966334 using {'reg_param': 0.730260571861634}
# -----Train----------
# AUC: 96.48 Precision: 95.94 Recall: 96.92
#
# -----Validation-----
# AUC: 93.96 Precision: 90.38 Recall: 97.92
#
# wheezy-copper-turtle-magic 3
#
# Fold 1
#
# Best: 0.974950 using {'reg_param': 0.780748647110169}
# -----Train----------
# AUC: 98.40 Precision: 99.10 Recall: 97.77
#
# -----Validation-----
# AUC: 92.73 Precision: 94.55 Recall: 91.23
#
# Fold 2
#
# Best: 0.974950 using {'reg_param': 0.7939040056540632}
# -----Train----------
# AUC: 98.67 Precision: 100.00 Recall: 97.33
#
# -----Validation-----
# AUC: 95.40 Precision: 96.36 Recall: 94.64
#
# Fold 3
#
# Best: 0.974950 using {'reg_param': 0.7939040056540632}
# -----Train----------
# AUC: 98.67 Precision: 100.00 Recall: 97.33
#
# -----Validation-----
# AUC: 94.38 Precision: 94.64 Recall: 94.64
#
# Fold 4
#
# Best: 0.974949 using {'reg_param': 0.8063877950570396}
# -----Train----------
# AUC: 97.94 Precision: 98.65 Recall: 97.33
#
# -----Validation-----
# AUC: 87.24 Precision: 93.75 Recall: 80.36
#
# Fold 5
#
# Best: 0.974949 using {'reg_param': 0.8063877950570396}
# -----Train----------
# AUC: 98.42 Precision: 99.55 Recall: 97.33
#
# -----Validation-----
# AUC: 91.70 Precision: 94.34 Recall: 89.29
#
# wheezy-copper-turtle-magic 4
#
# Fold 1
#
# Best: 0.964935 using {'reg_param': 0.934279783926869}
# -----Train----------
# AUC: 97.09 Precision: 97.12 Recall: 97.12
#
# -----Validation-----
# AUC: 91.44 Precision: 95.83 Recall: 86.79
#
# Fold 2
#
# Best: 0.964710 using {'reg_param': 0.9281532121721253}
# -----Train----------
# AUC: 96.37 Precision: 96.63 Recall: 96.17
#
# -----Validation-----
# AUC: 93.25 Precision: 97.87 Recall: 88.46
#
# Fold 3
#
# Best: 0.965087 using {'reg_param': 0.9195631311309289}
# -----Train----------
# AUC: 96.62 Precision: 97.10 Recall: 96.17
#
# -----Validation-----
# AUC: 89.31 Precision: 88.68 Recall: 90.38
#
# Fold 4
#
# Best: 0.965087 using {'reg_param': 0.9195631311309289}
# -----Train----------
# AUC: 97.34 Precision: 97.60 Recall: 97.13
#
# -----Validation-----
# AUC: 89.25 Precision: 84.75 Recall: 96.15
#
# Fold 5
#
# Best: 0.965087 using {'reg_param': 0.9195631311309289}
# -----Train----------
# AUC: 97.09 Precision: 97.13 Recall: 97.13
#
# -----Validation-----
# AUC: 93.21 Precision: 94.12 Recall: 92.31
#
# wheezy-copper-turtle-magic 5
#
# Fold 1
#
# Best: 0.955233 using {'reg_param': 0.6781387202594339}
# -----Train----------
# AUC: 97.83 Precision: 98.53 Recall: 97.10
#
# -----Validation-----
# AUC: 87.61 Precision: 88.24 Recall: 86.54
#
# Fold 2
#
# Best: 0.955233 using {'reg_param': 0.6781387202594339}
# -----Train----------
# AUC: 97.59 Precision: 99.00 Recall: 96.14
#
# -----Validation-----
# AUC: 94.27 Precision: 96.00 Recall: 92.31
#
# Fold 3
#
# Best: 0.955160 using {'reg_param': 0.6462482189535894}
# -----Train----------
# AUC: 97.60 Precision: 98.05 Recall: 97.10
#
# -----Validation-----
# AUC: 86.54 Precision: 86.54 Recall: 86.54
#
# Fold 4
#
# Best: 0.955233 using {'reg_param': 0.6781387202594339}
# -----Train----------
# AUC: 97.83 Precision: 99.01 Recall: 96.62
#
# -----Validation-----
# AUC: 91.35 Precision: 93.88 Recall: 88.46
#
# Fold 5
#
# Best: 0.955233 using {'reg_param': 0.6781387202594339}
# -----Train----------
# AUC: 98.32 Precision: 99.02 Recall: 97.60
#
# -----Validation-----
# AUC: 90.25 Precision: 93.62 Recall: 86.27
#
# wheezy-copper-turtle-magic 6
#
# Fold 1
#
# Best: 0.981212 using {'reg_param': 0.6927796472506498}
# -----Train----------
# AUC: 98.29 Precision: 97.67 Recall: 99.06
#
# -----Validation-----
# AUC: 93.32 Precision: 96.00 Recall: 90.57
#
# Fold 2
#
# Best: 0.981212 using {'reg_param': 0.697731344371419}
# -----Train----------
# AUC: 98.56 Precision: 99.05 Recall: 98.11
#
# -----Validation-----
# AUC: 96.15 Precision: 96.23 Recall: 96.23
#
# Fold 3
#
# Best: 0.981212 using {'reg_param': 0.6979335647313376}
# -----Train----------
# AUC: 98.08 Precision: 98.57 Recall: 97.64
#
# -----Validation-----
# AUC: 95.14 Precision: 92.86 Recall: 98.11
#
# Fold 4
#
# Best: 0.981212 using {'reg_param': 0.6928390584876881}
# -----Train----------
# AUC: 97.34 Precision: 97.18 Recall: 97.64
#
# -----Validation-----
# AUC: 96.11 Precision: 96.23 Recall: 96.23
#
# Fold 5
#
# Best: 0.981212 using {'reg_param': 0.6997797960421868}
# -----Train----------
# AUC: 99.04 Precision: 99.06 Recall: 99.06
#
# -----Validation-----
# AUC: 93.23 Precision: 94.23 Recall: 92.45
#
# wheezy-copper-turtle-magic 7
#
# Fold 1
#
# Best: 0.948665 using {'reg_param': 0.8665159436027006}
# -----Train----------
# AUC: 97.77 Precision: 97.55 Recall: 98.03
#
# -----Validation-----
# AUC: 88.24 Precision: 88.24 Recall: 88.24
#
# Fold 2
#
# Best: 0.948899 using {'reg_param': 0.8559475390502184}
# -----Train----------
# AUC: 97.53 Precision: 98.01 Recall: 97.04
#
# -----Validation-----
# AUC: 89.22 Precision: 88.46 Recall: 90.20
#
# Fold 3
#
# Best: 0.948669 using {'reg_param': 0.8481602210929122}
# -----Train----------
# AUC: 97.78 Precision: 97.09 Recall: 98.52
#
# -----Validation-----
# AUC: 87.08 Precision: 83.93 Recall: 92.16
#
# Fold 4
#
# Best: 0.948899 using {'reg_param': 0.8559475390502184}
# -----Train----------
# AUC: 97.28 Precision: 97.06 Recall: 97.54
#
# -----Validation-----
# AUC: 94.08 Precision: 95.92 Recall: 92.16
#
# Fold 5
#
# Best: 0.948899 using {'reg_param': 0.8559475390502184}
# -----Train----------
# AUC: 97.78 Precision: 98.03 Recall: 97.55
#
# -----Validation-----
# AUC: 89.00 Precision: 86.79 Recall: 92.00
#
# wheezy-copper-turtle-magic 8
#
# Fold 1
#
# Best: 0.966806 using {'reg_param': 0.4691825504460539}
# -----Train----------
# AUC: 98.07 Precision: 97.67 Recall: 98.59
#
# -----Validation-----
# AUC: 92.43 Precision: 94.23 Recall: 90.74
#
# Fold 2
#
# Best: 0.966805 using {'reg_param': 0.4909683498089495}
# -----Train----------
# AUC: 97.61 Precision: 98.10 Recall: 97.18
#
# -----Validation-----
# AUC: 97.17 Precision: 98.11 Recall: 96.30
#
# Fold 3
#
# Best: 0.966806 using {'reg_param': 0.4691825504460539}
# -----Train----------
# AUC: 98.10 Precision: 98.58 Recall: 97.66
#
# -----Validation-----
# AUC: 89.47 Precision: 92.00 Recall: 86.79
#
# Fold 4
#
# Best: 0.966806 using {'reg_param': 0.4691825504460539}
# -----Train----------
# AUC: 98.56 Precision: 98.60 Recall: 98.60
#
# -----Validation-----
# AUC: 90.42 Precision: 92.16 Recall: 88.68
#
# Fold 5
#
# Best: 0.966805 using {'reg_param': 0.4909683498089495}
# -----Train----------
# AUC: 98.56 Precision: 98.60 Recall: 98.60
#
# -----Validation-----
# AUC: 95.14 Precision: 92.86 Recall: 98.11
#
# wheezy-copper-turtle-magic 9
#
# Fold 1
#
# Best: 0.964745 using {'reg_param': 0.7744594557447825}
# -----Train----------
# AUC: 97.39 Precision: 99.02 Recall: 95.73
#
# -----Validation-----
# AUC: 93.40 Precision: 96.00 Recall: 90.57
#
# Fold 2
#
# Best: 0.964745 using {'reg_param': 0.7744594557447825}
# -----Train----------
# AUC: 97.87 Precision: 99.03 Recall: 96.68
#
# -----Validation-----
# AUC: 90.57 Precision: 92.16 Recall: 88.68
#
# Fold 3
#
# Best: 0.964744 using {'reg_param': 0.7919333130445819}
# -----Train----------
# AUC: 96.92 Precision: 98.53 Recall: 95.26
#
# -----Validation-----
# AUC: 94.34 Precision: 92.73 Recall: 96.23
#
# Fold 4
#
# Best: 0.964744 using {'reg_param': 0.8291110891881457}
# -----Train----------
# AUC: 97.39 Precision: 99.02 Recall: 95.73
#
# -----Validation-----
# AUC: 88.68 Precision: 91.84 Recall: 84.91
#
# Fold 5
#
# Best: 0.964673 using {'reg_param': 0.8063877950570396}
# -----Train----------
# AUC: 97.17 Precision: 98.08 Recall: 96.23
#
# -----Validation-----
# AUC: 96.15 Precision: 98.00 Recall: 94.23
#
# wheezy-copper-turtle-magic 10
#
# Fold 1
#
# Best: 0.971856 using {'reg_param': 0.8920314316606565}
# -----Train----------
# AUC: 99.00 Precision: 98.48 Recall: 99.49
#
# -----Validation-----
# AUC: 95.06 Precision: 94.12 Recall: 96.00
#
# Fold 2
#
# Best: 0.971856 using {'reg_param': 0.8920314316606565}
# -----Train----------
# AUC: 97.75 Precision: 97.00 Recall: 98.48
#
# -----Validation-----
# AUC: 91.92 Precision: 95.56 Recall: 87.76
#
# Fold 3
#
# Best: 0.971856 using {'reg_param': 0.8920314316606565}
# -----Train----------
# AUC: 98.25 Precision: 97.50 Recall: 98.98
#
# -----Validation-----
# AUC: 89.88 Precision: 91.49 Recall: 87.76
#
# Fold 4
#
# Best: 0.971856 using {'reg_param': 0.8918812277812977}
# -----Train----------
# AUC: 97.76 Precision: 96.53 Recall: 98.98
#
# -----Validation-----
# AUC: 91.92 Precision: 91.84 Recall: 91.84
#
# Fold 5
#
# Best: 0.971856 using {'reg_param': 0.8920314316606565}
# -----Train----------
# AUC: 98.51 Precision: 97.51 Recall: 99.49
#
# -----Validation-----
# AUC: 91.90 Precision: 93.62 Recall: 89.80
#
# wheezy-copper-turtle-magic 11
#
# Fold 1
#
# Best: 0.973042 using {'reg_param': 0.11915615144306428}
# -----Train----------
# AUC: 98.73 Precision: 97.87 Recall: 99.46
#
# -----Validation-----
# AUC: 91.74 Precision: 91.49 Recall: 91.49
#
# Fold 2
#
# Best: 0.973042 using {'reg_param': 0.11126476602314084}
# -----Train----------
# AUC: 98.21 Precision: 97.34 Recall: 98.92
#
# -----Validation-----
# AUC: 93.74 Precision: 95.56 Recall: 91.49
#
# Fold 3
#
# Best: 0.973042 using {'reg_param': 0.09800417451726821}
# -----Train----------
# AUC: 98.44 Precision: 98.39 Recall: 98.39
#
# -----Validation-----
# AUC: 91.83 Precision: 88.00 Recall: 95.65
#
# Fold 4
#
# Best: 0.973042 using {'reg_param': 0.09484657024768324}
# -----Train----------
# AUC: 98.17 Precision: 98.38 Recall: 97.85
#
# -----Validation-----
# AUC: 92.74 Precision: 91.49 Recall: 93.48
#
# Fold 5
#
# Best: 0.973042 using {'reg_param': 0.09800417451726821}
# -----Train----------
# AUC: 97.41 Precision: 97.31 Recall: 97.31
#
# -----Validation-----
# AUC: 93.65 Precision: 95.45 Recall: 91.30
#
# wheezy-copper-turtle-magic 12
#
# Fold 1
#
# Best: 0.967099 using {'reg_param': 0.716610876914447}
# -----Train----------
# AUC: 97.22 Precision: 97.49 Recall: 97.00
#
# -----Validation-----
# AUC: 94.04 Precision: 95.92 Recall: 92.16
#
# Fold 2
#
# Best: 0.967099 using {'reg_param': 0.716610876914447}
# -----Train----------
# AUC: 98.00 Precision: 99.49 Recall: 96.52
#
# -----Validation-----
# AUC: 96.98 Precision: 97.96 Recall: 96.00
#
# Fold 3
#
# Best: 0.967099 using {'reg_param': 0.7145270582495623}
# -----Train----------
# AUC: 98.51 Precision: 100.00 Recall: 97.01
#
# -----Validation-----
# AUC: 89.88 Precision: 88.46 Recall: 92.00
#
# Fold 4
#
# Best: 0.967262 using {'reg_param': 0.7398112442542383}
# -----Train----------
# AUC: 97.75 Precision: 99.48 Recall: 96.02
#
# -----Validation-----
# AUC: 91.98 Precision: 97.73 Recall: 86.00
#
# Fold 5
#
# Best: 0.967262 using {'reg_param': 0.7398112442542383}
# -----Train----------
# AUC: 97.75 Precision: 98.98 Recall: 96.52
#
# -----Validation-----
# AUC: 93.98 Precision: 97.83 Recall: 90.00
#
# wheezy-copper-turtle-magic 13
#
# Fold 1
#
# Best: 0.971745 using {'reg_param': 0.7354588281004723}
# -----Train----------
# AUC: 97.95 Precision: 97.37 Recall: 98.40
#
# -----Validation-----
# AUC: 93.87 Precision: 91.84 Recall: 95.74
#
# Fold 2
#
# Best: 0.971745 using {'reg_param': 0.7395243158189033}
# -----Train----------
# AUC: 97.94 Precision: 97.87 Recall: 97.87
#
# -----Validation-----
# AUC: 95.87 Precision: 95.74 Recall: 95.74
#
# Fold 3
#
# Best: 0.971745 using {'reg_param': 0.7354588281004723}
# -----Train----------
# AUC: 97.92 Precision: 98.39 Recall: 97.34
#
# -----Validation-----
# AUC: 94.87 Precision: 93.75 Recall: 95.74
#
# Fold 4
#
# Best: 0.971745 using {'reg_param': 0.7395243158189033}
# -----Train----------
# AUC: 98.20 Precision: 97.88 Recall: 98.40
#
# -----Validation-----
# AUC: 93.87 Precision: 91.84 Recall: 95.74
#
# Fold 5
#
# Best: 0.971745 using {'reg_param': 0.7398112442542383}
# -----Train----------
# AUC: 98.22 Precision: 97.38 Recall: 98.94
#
# -----Validation-----
# AUC: 90.74 Precision: 89.58 Recall: 91.49
#
# wheezy-copper-turtle-magic 14
#
# Fold 1
#
# Best: 0.977781 using {'reg_param': 0.7744594557447825}
# -----Train----------
# AUC: 98.69 Precision: 98.90 Recall: 98.35
#
# -----Validation-----
# AUC: 93.60 Precision: 97.62 Recall: 89.13
#
# Fold 2
#
# Best: 0.977781 using {'reg_param': 0.7744594557447825}
# -----Train----------
# AUC: 99.24 Precision: 98.91 Recall: 99.45
#
# -----Validation-----
# AUC: 93.85 Precision: 93.48 Recall: 93.48
#
# Fold 3
#
# Best: 0.977781 using {'reg_param': 0.7744594557447825}
# -----Train----------
# AUC: 99.24 Precision: 98.91 Recall: 99.45
#
# -----Validation-----
# AUC: 95.78 Precision: 97.73 Recall: 93.48
#
# Fold 4
#
# Best: 0.977781 using {'reg_param': 0.7744594557447825}
# -----Train----------
# AUC: 98.97 Precision: 98.91 Recall: 98.91
#
# -----Validation-----
# AUC: 95.82 Precision: 95.56 Recall: 95.56
#
# Fold 5
#
# Best: 0.977779 using {'reg_param': 0.780748647110169}
# -----Train----------
# AUC: 99.49 Precision: 99.45 Recall: 99.45
#
# -----Validation-----
# AUC: 93.59 Precision: 95.35 Recall: 91.11
#
# wheezy-copper-turtle-magic 15
#
# Fold 1
#
# Best: 0.975707 using {'reg_param': 0.20079652837150366}
# -----Train----------
# AUC: 97.57 Precision: 97.60 Recall: 97.60
#
# -----Validation-----
# AUC: 93.29 Precision: 94.23 Recall: 92.45
#
# Fold 2
#
# Best: 0.975782 using {'reg_param': 0.09484657024768324}
# -----Train----------
# AUC: 97.58 Precision: 98.07 Recall: 97.13
#
# -----Validation-----
# AUC: 95.14 Precision: 94.34 Recall: 96.15
#
# Fold 3
#
# Best: 0.975782 using {'reg_param': 0.09484657024768324}
# -----Train----------
# AUC: 98.56 Precision: 99.51 Recall: 97.61
#
# -----Validation-----
# AUC: 90.27 Precision: 88.89 Recall: 92.31
#
# Fold 4
#
# Best: 0.975782 using {'reg_param': 0.09484657024768324}
# -----Train----------
# AUC: 98.55 Precision: 98.56 Recall: 98.56
#
# -----Validation-----
# AUC: 94.19 Precision: 96.00 Recall: 92.31
#
# Fold 5
#
# Best: 0.975707 using {'reg_param': 0.12469616286659208}
# -----Train----------
# AUC: 98.31 Precision: 99.03 Recall: 97.61
#
# -----Validation-----
# AUC: 88.31 Precision: 85.71 Recall: 92.31
#
# wheezy-copper-turtle-magic 16
#
# Fold 1
#
# Best: 0.972391 using {'reg_param': 0.456694181884332}
# -----Train----------
# AUC: 97.31 Precision: 97.97 Recall: 96.50
#
# -----Validation-----
# AUC: 92.54 Precision: 87.72 Recall: 98.04
#
# Fold 2
#
# Best: 0.972391 using {'reg_param': 0.456694181884332}
# -----Train----------
# AUC: 98.31 Precision: 98.02 Recall: 98.51
#
# -----Validation-----
# AUC: 92.34 Precision: 88.89 Recall: 96.00
#
# Fold 3
#
# Best: 0.972391 using {'reg_param': 0.456694181884332}
# -----Train----------
# AUC: 97.35 Precision: 97.03 Recall: 97.51
#
# -----Validation-----
# AUC: 96.06 Precision: 97.92 Recall: 94.00
#
# Fold 4
#
# Best: 0.972243 using {'reg_param': 0.46684446208345}
# -----Train----------
# AUC: 97.58 Precision: 97.51 Recall: 97.51
#
# -----Validation-----
# AUC: 94.11 Precision: 95.83 Recall: 92.00
#
# Fold 5
#
# Best: 0.972240 using {'reg_param': 0.4540891399953908}
# -----Train----------
# AUC: 97.85 Precision: 97.06 Recall: 98.51
#
# -----Validation-----
# AUC: 93.17 Precision: 93.88 Recall: 92.00
#
# wheezy-copper-turtle-magic 17
#
# Fold 1
#
# Best: 0.973944 using {'reg_param': 0.5018230575447755}
# -----Train----------
# AUC: 98.04 Precision: 98.09 Recall: 98.09
#
# -----Validation-----
# AUC: 94.23 Precision: 96.08 Recall: 92.45
#
# Fold 2
#
# Best: 0.973944 using {'reg_param': 0.5018230575447755}
# -----Train----------
# AUC: 98.04 Precision: 98.09 Recall: 98.09
#
# -----Validation-----
# AUC: 95.17 Precision: 96.15 Recall: 94.34
#
# Fold 3
#
# Best: 0.973943 using {'reg_param': 0.43916291194885804}
# -----Train----------
# AUC: 98.52 Precision: 98.11 Recall: 99.05
#
# -----Validation-----
# AUC: 93.15 Precision: 94.12 Recall: 92.31
#
# Fold 4
#
# Best: 0.973943 using {'reg_param': 0.4476782532390097}
# -----Train----------
# AUC: 98.04 Precision: 98.10 Recall: 98.10
#
# -----Validation-----
# AUC: 93.12 Precision: 92.45 Recall: 94.23
#
# Fold 5
#
# Best: 0.973944 using {'reg_param': 0.5018230575447755}
# -----Train----------
# AUC: 98.54 Precision: 98.57 Recall: 98.57
#
# -----Validation-----
# AUC: 94.00 Precision: 92.59 Recall: 96.15
#
# wheezy-copper-turtle-magic 18
#
# Fold 1
#
# Best: 0.973678 using {'reg_param': 0.7993594056525068}
# -----Train----------
# AUC: 99.03 Precision: 99.06 Recall: 99.06
#
# -----Validation-----
# AUC: 93.25 Precision: 92.59 Recall: 94.34
#
# Fold 2
#
# Best: 0.973679 using {'reg_param': 0.7939040056540632}
# -----Train----------
# AUC: 99.04 Precision: 99.52 Recall: 98.58
#
# -----Validation-----
# AUC: 95.17 Precision: 94.44 Recall: 96.23
#
# Fold 3
#
# Best: 0.973677 using {'reg_param': 0.8063877950570396}
# -----Train----------
# AUC: 98.55 Precision: 98.58 Recall: 98.58
#
# -----Validation-----
# AUC: 91.29 Precision: 89.29 Recall: 94.34
#
# Fold 4
#
# Best: 0.973679 using {'reg_param': 0.7919333130445819}
# -----Train----------
# AUC: 98.31 Precision: 98.12 Recall: 98.58
#
# -----Validation-----
# AUC: 95.17 Precision: 96.15 Recall: 94.34
#
# Fold 5
#
# Best: 0.973679 using {'reg_param': 0.7939040056540632}
# -----Train----------
# AUC: 98.81 Precision: 99.52 Recall: 98.11
#
# -----Validation-----
# AUC: 97.06 Precision: 96.30 Recall: 98.11
#
# wheezy-copper-turtle-magic 19
#
# Fold 1
#
# Best: 0.975494 using {'reg_param': 0.36819430817784865}
# -----Train----------
# AUC: 98.57 Precision: 98.13 Recall: 99.06
#
# -----Validation-----
# AUC: 90.57 Precision: 90.57 Recall: 90.57
#
# Fold 2
#
# Best: 0.975494 using {'reg_param': 0.36434706017168}
# -----Train----------
# AUC: 98.57 Precision: 98.58 Recall: 98.58
#
# -----Validation-----
# AUC: 90.46 Precision: 89.09 Recall: 92.45
#
# Fold 3
#
# Best: 0.975639 using {'reg_param': 0.3840580773069519}
# -----Train----------
# AUC: 97.62 Precision: 97.64 Recall: 97.64
#
# -----Validation-----
# AUC: 93.32 Precision: 92.59 Recall: 94.34
#
# Fold 4
#
# Best: 0.975639 using {'reg_param': 0.3840580773069519}
# -----Train----------
# AUC: 98.34 Precision: 99.04 Recall: 97.64
#
# -----Validation-----
# AUC: 90.42 Precision: 86.44 Recall: 96.23
#
# Fold 5
#
# Best: 0.975639 using {'reg_param': 0.3840580773069519}
# -----Train----------
# AUC: 98.81 Precision: 99.05 Recall: 98.58
#
# -----Validation-----
# AUC: 91.46 Precision: 94.00 Recall: 88.68
#
# wheezy-copper-turtle-magic 20
#
# Fold 1
#
# Best: 0.966171 using {'reg_param': 0.9281532121721253}
# -----Train----------
# AUC: 98.57 Precision: 97.50 Recall: 99.49
#
# -----Validation-----
# AUC: 91.37 Precision: 90.20 Recall: 92.00
#
# Fold 2
#
# Best: 0.966096 using {'reg_param': 0.9293669013786379}
# -----Train----------
# AUC: 98.08 Precision: 97.01 Recall: 98.98
#
# -----Validation-----
# AUC: 86.56 Precision: 80.70 Recall: 93.88
#
# Fold 3
#
# Best: 0.966097 using {'reg_param': 0.9256710416543684}
# -----Train----------
# AUC: 97.07 Precision: 96.95 Recall: 96.95
#
# -----Validation-----
# AUC: 97.09 Precision: 96.00 Recall: 97.96
#
# Fold 4
#
# Best: 0.966171 using {'reg_param': 0.9281532121721253}
# -----Train----------
# AUC: 98.03 Precision: 98.46 Recall: 97.46
#
# -----Validation-----
# AUC: 94.26 Precision: 90.57 Recall: 97.96
#
# Fold 5
#
# Best: 0.966025 using {'reg_param': 0.9195631311309289}
# -----Train----------
# AUC: 97.32 Precision: 96.97 Recall: 97.46
#
# -----Validation-----
# AUC: 93.95 Precision: 97.78 Recall: 89.80
#
# wheezy-copper-turtle-magic 21
#
# Fold 1
#
# Best: 0.965295 using {'reg_param': 0.06116524615764057}
# -----Train----------
# AUC: 97.89 Precision: 98.14 Recall: 97.69
#
# -----Validation-----
# AUC: 94.39 Precision: 94.44 Recall: 94.44
#
# Fold 2
#
# Best: 0.965295 using {'reg_param': 0.06116524615764057}
# -----Train----------
# AUC: 97.41 Precision: 97.67 Recall: 97.22
#
# -----Validation-----
# AUC: 91.60 Precision: 92.45 Recall: 90.74
#
# Fold 3
#
# Best: 0.965295 using {'reg_param': 0.058971131163551745}
# -----Train----------
# AUC: 97.66 Precision: 98.13 Recall: 97.22
#
# -----Validation-----
# AUC: 94.30 Precision: 92.86 Recall: 96.30
#
# Fold 4
#
# Best: 0.965295 using {'reg_param': 0.040148604462066355}
# -----Train----------
# AUC: 97.65 Precision: 97.69 Recall: 97.69
#
# -----Validation-----
# AUC: 95.30 Precision: 96.23 Recall: 94.44
#
# Fold 5
#
# Best: 0.965295 using {'reg_param': 0.07196502213968906}
# -----Train----------
# AUC: 98.12 Precision: 97.71 Recall: 98.61
#
# -----Validation-----
# AUC: 91.56 Precision: 94.12 Recall: 88.89
#
# wheezy-copper-turtle-magic 22
#
# Fold 1
#
# Best: 0.981992 using {'reg_param': 0.6462482189535894}
# -----Train----------
# AUC: 98.60 Precision: 98.64 Recall: 98.64
#
# -----Validation-----
# AUC: 94.30 Precision: 91.67 Recall: 98.21
#
# Fold 2
#
# Best: 0.982061 using {'reg_param': 0.667742969583718}
# -----Train----------
# AUC: 98.61 Precision: 99.09 Recall: 98.19
#
# -----Validation-----
# AUC: 96.29 Precision: 96.43 Recall: 96.43
#
# Fold 3
#
# Best: 0.981992 using {'reg_param': 0.6443462090304077}
# -----Train----------
# AUC: 98.14 Precision: 98.20 Recall: 98.20
#
# -----Validation-----
# AUC: 96.31 Precision: 98.11 Recall: 94.55
#
# Fold 4
#
# Best: 0.981992 using {'reg_param': 0.6535476190372765}
# -----Train----------
# AUC: 98.36 Precision: 98.21 Recall: 98.65
#
# -----Validation-----
# AUC: 96.26 Precision: 96.36 Recall: 96.36
#
# Fold 5
#
# Best: 0.981992 using {'reg_param': 0.6462482189535894}
# -----Train----------
# AUC: 98.84 Precision: 99.10 Recall: 98.65
#
# -----Validation-----
# AUC: 94.34 Precision: 92.98 Recall: 96.36
#
# wheezy-copper-turtle-magic 23
#
# Fold 1
#
# Best: 0.969874 using {'reg_param': 0.8920314316606565}
# -----Train----------
# AUC: 97.60 Precision: 98.10 Recall: 97.17
#
# -----Validation-----
# AUC: 95.26 Precision: 94.55 Recall: 96.30
#
# Fold 2
#
# Best: 0.969806 using {'reg_param': 0.780748647110169}
# -----Train----------
# AUC: 98.09 Precision: 98.12 Recall: 98.12
#
# -----Validation-----
# AUC: 88.31 Precision: 83.61 Recall: 96.23
#
# Fold 3
#
# Best: 0.969874 using {'reg_param': 0.8918812277812977}
# -----Train----------
# AUC: 98.32 Precision: 98.13 Recall: 98.59
#
# -----Validation-----
# AUC: 94.23 Precision: 94.34 Recall: 94.34
#
# Fold 4
#
# Best: 0.969874 using {'reg_param': 0.8920314316606565}
# -----Train----------
# AUC: 97.60 Precision: 97.21 Recall: 98.12
#
# -----Validation-----
# AUC: 90.31 Precision: 87.72 Recall: 94.34
#
# Fold 5
#
# Best: 0.969874 using {'reg_param': 0.8918812277812977}
# -----Train----------
# AUC: 97.85 Precision: 98.11 Recall: 97.65
#
# -----Validation-----
# AUC: 95.17 Precision: 94.44 Recall: 96.23
#
# wheezy-copper-turtle-magic 24
#
# Fold 1
#
# Best: 0.966412 using {'reg_param': 0.934279783926869}
# -----Train----------
# AUC: 97.94 Precision: 98.37 Recall: 97.31
#
# -----Validation-----
# AUC: 96.93 Precision: 97.83 Recall: 95.74
#
# Fold 2
#
# Best: 0.966246 using {'reg_param': 0.9281532121721253}
# -----Train----------
# AUC: 98.00 Precision: 97.34 Recall: 98.39
#
# -----Validation-----
# AUC: 88.20 Precision: 84.31 Recall: 91.49
#
# Fold 3
#
# Best: 0.966412 using {'reg_param': 0.934279783926869}
# -----Train----------
# AUC: 97.20 Precision: 97.30 Recall: 96.77
#
# -----Validation-----
# AUC: 89.87 Precision: 89.36 Recall: 89.36
#
# Fold 4
#
# Best: 0.966412 using {'reg_param': 0.934279783926869}
# -----Train----------
# AUC: 97.77 Precision: 96.84 Recall: 98.40
#
# -----Validation-----
# AUC: 94.69 Precision: 97.67 Recall: 91.30
#
# Fold 5
#
# Best: 0.966412 using {'reg_param': 0.934279783926869}
# -----Train----------
# AUC: 98.51 Precision: 97.88 Recall: 98.93
#
# -----Validation-----
# AUC: 90.47 Precision: 95.12 Recall: 84.78
#
# wheezy-copper-turtle-magic 25
#
# Fold 1
#
# Best: 0.964272 using {'reg_param': 0.7398112442542383}
# -----Train----------
# AUC: 98.20 Precision: 98.38 Recall: 97.85
#
# -----Validation-----
# AUC: 90.83 Precision: 91.30 Recall: 89.36
#
# Fold 2
#
# Best: 0.964272 using {'reg_param': 0.7303919074872529}
# -----Train----------
# AUC: 97.69 Precision: 97.84 Recall: 97.31
#
# -----Validation-----
# AUC: 95.85 Precision: 97.78 Recall: 93.62
#
# Fold 3
#
# Best: 0.964272 using {'reg_param': 0.7398112442542383}
# -----Train----------
# AUC: 97.93 Precision: 98.37 Recall: 97.31
#
# -----Validation-----
# AUC: 90.63 Precision: 95.24 Recall: 85.11
#
# Fold 4
#
# Best: 0.964272 using {'reg_param': 0.7398112442542383}
# -----Train----------
# AUC: 97.14 Precision: 98.35 Recall: 95.72
#
# -----Validation-----
# AUC: 95.87 Precision: 95.65 Recall: 95.65
#
# Fold 5
#
# Best: 0.964272 using {'reg_param': 0.730260571861634}
# -----Train----------
# AUC: 97.89 Precision: 99.45 Recall: 96.26
#
# -----Validation-----
# AUC: 92.71 Precision: 93.33 Recall: 91.30
#
# wheezy-copper-turtle-magic 26
#
# Fold 1
#
# Best: 0.964821 using {'reg_param': 0.3840580773069519}
# -----Train----------
# AUC: 98.50 Precision: 97.40 Recall: 99.47
#
# -----Validation-----
# AUC: 86.83 Precision: 87.23 Recall: 85.42
#
# Fold 2
#
# Best: 0.964821 using {'reg_param': 0.36935644549030316}
# -----Train----------
# AUC: 98.46 Precision: 98.41 Recall: 98.41
#
# -----Validation-----
# AUC: 90.84 Precision: 89.58 Recall: 91.49
#
# Fold 3
#
# Best: 0.964821 using {'reg_param': 0.36935644549030316}
# -----Train----------
# AUC: 97.69 Precision: 97.87 Recall: 97.35
#
# -----Validation-----
# AUC: 91.91 Precision: 89.80 Recall: 93.62
#
# Fold 4
#
# Best: 0.964821 using {'reg_param': 0.36434706017168}
# -----Train----------
# AUC: 97.69 Precision: 97.87 Recall: 97.35
#
# -----Validation-----
# AUC: 95.94 Precision: 93.88 Recall: 97.87
#
# Fold 5
#
# Best: 0.964821 using {'reg_param': 0.36819430817784865}
# -----Train----------
# AUC: 97.20 Precision: 96.84 Recall: 97.35
#
# -----Validation-----
# AUC: 94.81 Precision: 95.65 Recall: 93.62
#
# wheezy-copper-turtle-magic 27
#
# Fold 1
#
# Best: 0.950159 using {'reg_param': 0.8920314316606565}
# -----Train----------
# AUC: 96.82 Precision: 95.38 Recall: 97.89
#
# -----Validation-----
# AUC: 89.93 Precision: 93.18 Recall: 85.42
#
# Fold 2
#
# Best: 0.950072 using {'reg_param': 0.8701421360985724}
# -----Train----------
# AUC: 96.57 Precision: 95.36 Recall: 97.37
#
# -----Validation-----
# AUC: 93.85 Precision: 97.73 Recall: 89.58
#
# Fold 3
#
# Best: 0.950159 using {'reg_param': 0.8918812277812977}
# -----Train----------
# AUC: 95.55 Precision: 94.79 Recall: 95.79
#
# -----Validation-----
# AUC: 93.95 Precision: 95.65 Recall: 91.67
#
# Fold 4
#
# Best: 0.950159 using {'reg_param': 0.8920314316606565}
# -----Train----------
# AUC: 95.77 Precision: 95.79 Recall: 95.29
#
# -----Validation-----
# AUC: 91.97 Precision: 91.49 Recall: 91.49
#
# Fold 5
#
# Best: 0.950159 using {'reg_param': 0.8920314316606565}
# -----Train----------
# AUC: 96.79 Precision: 96.35 Recall: 96.86
#
# -----Validation-----
# AUC: 90.20 Precision: 86.27 Recall: 93.62
#
# wheezy-copper-turtle-magic 28
#
# Fold 1
#
# Best: 0.962817 using {'reg_param': 0.6031606126955722}
# -----Train----------
# AUC: 97.67 Precision: 98.12 Recall: 97.21
#
# -----Validation-----
# AUC: 91.67 Precision: 92.45 Recall: 90.74
#
# Fold 2
#
# Best: 0.962816 using {'reg_param': 0.6173170628778821}
# -----Train----------
# AUC: 97.67 Precision: 97.67 Recall: 97.67
#
# -----Validation-----
# AUC: 92.59 Precision: 92.59 Recall: 92.59
#
# Fold 3
#
# Best: 0.962816 using {'reg_param': 0.6173170628778821}
# -----Train----------
# AUC: 98.37 Precision: 99.06 Recall: 97.67
#
# -----Validation-----
# AUC: 93.52 Precision: 96.08 Recall: 90.74
#
# Fold 4
#
# Best: 0.962816 using {'reg_param': 0.6218569230982638}
# -----Train----------
# AUC: 97.21 Precision: 98.56 Recall: 95.81
#
# -----Validation-----
# AUC: 98.15 Precision: 100.00 Recall: 96.30
#
# Fold 5
#
# Best: 0.962816 using {'reg_param': 0.6180178615788012}
# -----Train----------
# AUC: 97.91 Precision: 98.59 Recall: 97.22
#
# -----Validation-----
# AUC: 91.51 Precision: 92.31 Recall: 90.57
#
# wheezy-copper-turtle-magic 29
#
# Fold 1
#
# Best: 0.967518 using {'reg_param': 0.05528365035091438}
# -----Train----------
# AUC: 98.74 Precision: 98.51 Recall: 99.00
#
# -----Validation-----
# AUC: 92.00 Precision: 90.38 Recall: 94.00
#
# Fold 2
#
# Best: 0.967518 using {'reg_param': 0.021198179042885394}
# -----Train----------
# AUC: 98.49 Precision: 98.02 Recall: 99.00
#
# -----Validation-----
# AUC: 88.00 Precision: 89.58 Recall: 86.00
#
# Fold 3
#
# Best: 0.967518 using {'reg_param': 0.0056907807163545186}
# -----Train----------
# AUC: 97.49 Precision: 97.50 Recall: 97.50
#
# -----Validation-----
# AUC: 94.00 Precision: 95.83 Recall: 92.00
#
# Fold 4
#
# Best: 0.967518 using {'reg_param': 0.01977101063591879}
# -----Train----------
# AUC: 98.75 Precision: 98.99 Recall: 98.50
#
# -----Validation-----
# AUC: 92.92 Precision: 92.16 Recall: 94.00
#
# Fold 5
#
# Best: 0.967518 using {'reg_param': 0.03280709060177654}
# -----Train----------
# AUC: 97.99 Precision: 98.00 Recall: 98.00
#
# -----Validation-----
# AUC: 95.94 Precision: 94.23 Recall: 98.00
#
# wheezy-copper-turtle-magic 30
#
# Fold 1
#
# Best: 0.975753 using {'reg_param': 0.8465622637986567}
# -----Train----------
# AUC: 97.82 Precision: 98.13 Recall: 97.67
#
# -----Validation-----
# AUC: 95.30 Precision: 98.04 Recall: 92.59
#
# Fold 2
#
# Best: 0.975603 using {'reg_param': 0.8139840218827747}
# -----Train----------
# AUC: 98.08 Precision: 98.59 Recall: 97.67
#
# -----Validation-----
# AUC: 93.14 Precision: 92.73 Recall: 94.44
#
# Fold 3
#
# Best: 0.975678 using {'reg_param': 0.8481602210929122}
# -----Train----------
# AUC: 98.52 Precision: 98.16 Recall: 99.07
#
# -----Validation-----
# AUC: 93.24 Precision: 94.34 Recall: 92.59
#
# Fold 4
#
# Best: 0.975678 using {'reg_param': 0.8381069625913051}
# -----Train----------
# AUC: 98.35 Precision: 99.52 Recall: 97.21
#
# -----Validation-----
# AUC: 93.24 Precision: 94.34 Recall: 92.59
#
# Fold 5
#
# Best: 0.975752 using {'reg_param': 0.8559475390502184}
# -----Train----------
# AUC: 97.85 Precision: 98.59 Recall: 97.22
#
# -----Validation-----
# AUC: 94.97 Precision: 92.86 Recall: 98.11
#
# wheezy-copper-turtle-magic 31
#
# Fold 1
#
# Best: 0.960729 using {'reg_param': 0.0056907807163545186}
# -----Train----------
# AUC: 97.79 Precision: 97.51 Recall: 98.00
#
# -----Validation-----
# AUC: 89.37 Precision: 85.71 Recall: 94.12
#
# Fold 2
#
# Best: 0.960729 using {'reg_param': 0.01950327266615336}
# -----Train----------
# AUC: 97.55 Precision: 97.04 Recall: 98.01
#
# -----Validation-----
# AUC: 90.19 Precision: 90.00 Recall: 90.00
#
# Fold 3
#
# Best: 0.960729 using {'reg_param': 0.07196502213968906}
# -----Train----------
# AUC: 97.31 Precision: 96.57 Recall: 98.01
#
# -----Validation-----
# AUC: 91.15 Precision: 91.84 Recall: 90.00
#
# Fold 4
#
# Best: 0.960729 using {'reg_param': 0.0700978284596829}
# -----Train----------
# AUC: 97.56 Precision: 97.04 Recall: 98.01
#
# -----Validation-----
# AUC: 91.14 Precision: 87.27 Recall: 96.00
#
# Fold 5
#
# Best: 0.960729 using {'reg_param': 0.058971131163551745}
# -----Train----------
# AUC: 96.34 Precision: 95.15 Recall: 97.51
#
# -----Validation-----
# AUC: 92.08 Precision: 92.00 Recall: 92.00
#
# wheezy-copper-turtle-magic 32
#
# Fold 1
#
# Best: 0.975953 using {'reg_param': 0.6781387202594339}
# -----Train----------
# AUC: 98.98 Precision: 98.41 Recall: 99.47
#
# -----Validation-----
# AUC: 89.68 Precision: 89.36 Recall: 89.36
#
# Fold 2
#
# Best: 0.975951 using {'reg_param': 0.716610876914447}
# -----Train----------
# AUC: 98.96 Precision: 98.93 Recall: 98.93
#
# -----Validation-----
# AUC: 87.55 Precision: 88.89 Recall: 85.11
#
# Fold 3
#
# Best: 0.975953 using {'reg_param': 0.6781387202594339}
# -----Train----------
# AUC: 99.25 Precision: 98.42 Recall: 100.00
#
# -----Validation-----
# AUC: 93.68 Precision: 97.67 Recall: 89.36
#
# Fold 4
#
# Best: 0.975951 using {'reg_param': 0.716610876914447}
# -----Train----------
# AUC: 98.48 Precision: 97.38 Recall: 99.47
#
# -----Validation-----
# AUC: 93.94 Precision: 90.20 Recall: 97.87
#
# Fold 5
#
# Best: 0.975951 using {'reg_param': 0.716610876914447}
# -----Train----------
# AUC: 98.47 Precision: 97.89 Recall: 98.94
#
# -----Validation-----
# AUC: 90.48 Precision: 91.11 Recall: 89.13
#
# wheezy-copper-turtle-magic 33
#
# Fold 1
#
# Best: 0.961317 using {'reg_param': 0.5776513600155634}
# -----Train----------
# AUC: 96.93 Precision: 97.63 Recall: 96.26
#
# -----Validation-----
# AUC: 88.64 Precision: 87.50 Recall: 90.74
#
# Fold 2
#
# Best: 0.961246 using {'reg_param': 0.5492646904233974}
# -----Train----------
# AUC: 96.94 Precision: 98.09 Recall: 95.79
#
# -----Validation-----
# AUC: 91.56 Precision: 94.12 Recall: 88.89
#
# Fold 3
#
# Best: 0.961247 using {'reg_param': 0.5293660248331515}
# -----Train----------
# AUC: 96.93 Precision: 97.63 Recall: 96.26
#
# -----Validation-----
# AUC: 95.37 Precision: 100.00 Recall: 90.74
#
# Fold 4
#
# Best: 0.961317 using {'reg_param': 0.5776513600155634}
# -----Train----------
# AUC: 97.18 Precision: 98.10 Recall: 96.28
#
# -----Validation-----
# AUC: 95.25 Precision: 96.15 Recall: 94.34
#
# Fold 5
#
# Best: 0.961317 using {'reg_param': 0.5776513600155634}
# -----Train----------
# AUC: 97.39 Precision: 97.22 Recall: 97.67
#
# -----Validation-----
# AUC: 93.36 Precision: 96.00 Recall: 90.57
#
# wheezy-copper-turtle-magic 34
#
# Fold 1
#
# Best: 0.977791 using {'reg_param': 0.868257931310846}
# -----Train----------
# AUC: 98.59 Precision: 99.09 Recall: 98.19
#
# -----Validation-----
# AUC: 89.64 Precision: 90.91 Recall: 89.29
#
# Fold 2
#
# Best: 0.977864 using {'reg_param': 0.8701421360985724}
# -----Train----------
# AUC: 97.17 Precision: 98.16 Recall: 96.38
#
# -----Validation-----
# AUC: 93.75 Precision: 100.00 Recall: 87.50
#
# Fold 3
#
# Best: 0.977864 using {'reg_param': 0.8701421360985724}
# -----Train----------
# AUC: 98.87 Precision: 100.00 Recall: 97.75
#
# -----Validation-----
# AUC: 95.12 Precision: 94.64 Recall: 96.36
#
# Fold 4
#
# Best: 0.977864 using {'reg_param': 0.8701421360985724}
# -----Train----------
# AUC: 97.67 Precision: 98.62 Recall: 96.85
#
# -----Validation-----
# AUC: 95.23 Precision: 96.30 Recall: 94.55
#
# Fold 5
#
# Best: 0.977646 using {'reg_param': 0.8812220939140504}
# -----Train----------
# AUC: 97.67 Precision: 98.62 Recall: 96.85
#
# -----Validation-----
# AUC: 96.14 Precision: 96.36 Recall: 96.36
#
# wheezy-copper-turtle-magic 35
#
# Fold 1
#
# Best: 0.963135 using {'reg_param': 0.22470076337231976}
# -----Train----------
# AUC: 97.28 Precision: 97.10 Recall: 97.57
#
# -----Validation-----
# AUC: 96.12 Precision: 98.00 Recall: 94.23
#
# Fold 2
#
# Best: 0.963135 using {'reg_param': 0.22470076337231976}
# -----Train----------
# AUC: 97.76 Precision: 97.13 Recall: 98.54
#
# -----Validation-----
# AUC: 93.12 Precision: 92.45 Recall: 94.23
#
# Fold 3
#
# Best: 0.963135 using {'reg_param': 0.22470076337231976}
# -----Train----------
# AUC: 97.78 Precision: 98.05 Recall: 97.57
#
# -----Validation-----
# AUC: 87.23 Precision: 86.79 Recall: 88.46
#
# Fold 4
#
# Best: 0.963134 using {'reg_param': 0.2907875296032336}
# -----Train----------
# AUC: 98.02 Precision: 97.61 Recall: 98.55
#
# -----Validation-----
# AUC: 93.10 Precision: 95.83 Recall: 90.20
#
# Fold 5
#
# Best: 0.963135 using {'reg_param': 0.2238585510079777}
# -----Train----------
# AUC: 98.04 Precision: 98.54 Recall: 97.58
#
# -----Validation-----
# AUC: 90.00 Precision: 90.20 Recall: 90.20
#
# wheezy-copper-turtle-magic 36
#
# Fold 1
#
# Best: 0.965140 using {'reg_param': 0.01950327266615336}
# -----Train----------
# AUC: 98.18 Precision: 98.33 Recall: 97.79
#
# -----Validation-----
# AUC: 90.79 Precision: 91.11 Recall: 89.13
#
# Fold 2
#
# Best: 0.965140 using {'reg_param': 0.01950327266615336}
# -----Train----------
# AUC: 98.42 Precision: 98.88 Recall: 97.79
#
# -----Validation-----
# AUC: 94.05 Precision: 91.67 Recall: 95.65
#
# Fold 3
#
# Best: 0.965306 using {'reg_param': 0.0056907807163545186}
# -----Train----------
# AUC: 97.72 Precision: 97.27 Recall: 97.80
#
# -----Validation-----
# AUC: 94.95 Precision: 93.48 Recall: 95.56
#
# Fold 4
#
# Best: 0.965140 using {'reg_param': 0.01950327266615336}
# -----Train----------
# AUC: 98.70 Precision: 98.90 Recall: 98.35
#
# -----Validation-----
# AUC: 85.79 Precision: 82.98 Recall: 86.67
#
# Fold 5
#
# Best: 0.965306 using {'reg_param': 0.0056907807163545186}
# -----Train----------
# AUC: 98.15 Precision: 98.88 Recall: 97.25
#
# -----Validation-----
# AUC: 94.59 Precision: 97.62 Recall: 91.11
#
# wheezy-copper-turtle-magic 37
#
# Fold 1
#
# Best: 0.969509 using {'reg_param': 0.8465622637986567}
# -----Train----------
# AUC: 98.57 Precision: 99.05 Recall: 98.11
#
# -----Validation-----
# AUC: 90.56 Precision: 90.74 Recall: 90.74
#
# Fold 2
#
# Best: 0.969509 using {'reg_param': 0.8481602210929122}
# -----Train----------
# AUC: 97.60 Precision: 97.21 Recall: 98.12
#
# -----Validation-----
# AUC: 97.13 Precision: 98.08 Recall: 96.23
#
# Fold 3
#
# Best: 0.969290 using {'reg_param': 0.8559475390502184}
# -----Train----------
# AUC: 98.09 Precision: 98.58 Recall: 97.65
#
# -----Validation-----
# AUC: 90.46 Precision: 93.88 Recall: 86.79
#
# Fold 4
#
# Best: 0.969509 using {'reg_param': 0.8465622637986567}
# -----Train----------
# AUC: 97.15 Precision: 98.09 Recall: 96.24
#
# -----Validation-----
# AUC: 93.29 Precision: 94.23 Recall: 92.45
#
# Fold 5
#
# Best: 0.969509 using {'reg_param': 0.8465622637986567}
# -----Train----------
# AUC: 97.14 Precision: 97.63 Recall: 96.71
#
# -----Validation-----
# AUC: 94.19 Precision: 92.73 Recall: 96.23
#
# wheezy-copper-turtle-magic 38
#
# Fold 1
#
# Best: 0.974004 using {'reg_param': 0.12469616286659208}
# -----Train----------
# AUC: 98.29 Precision: 98.98 Recall: 97.49
#
# -----Validation-----
# AUC: 95.32 Precision: 94.12 Recall: 96.00
#
# Fold 2
#
# Best: 0.974004 using {'reg_param': 0.1326660645419878}
# -----Train----------
# AUC: 99.75 Precision: 100.00 Recall: 99.50
#
# -----Validation-----
# AUC: 92.32 Precision: 93.75 Recall: 90.00
#
# Fold 3
#
# Best: 0.974004 using {'reg_param': 0.12979737135719846}
# -----Train----------
# AUC: 98.77 Precision: 99.49 Recall: 97.99
#
# -----Validation-----
# AUC: 95.32 Precision: 94.12 Recall: 96.00
#
# Fold 4
#
# Best: 0.974004 using {'reg_param': 0.10294276593728004}
# -----Train----------
# AUC: 98.80 Precision: 98.99 Recall: 98.49
#
# -----Validation-----
# AUC: 94.27 Precision: 94.00 Recall: 94.00
#
# Fold 5
#
# Best: 0.974004 using {'reg_param': 0.21117217851276707}
# -----Train----------
# AUC: 98.30 Precision: 98.98 Recall: 97.50
#
# -----Validation-----
# AUC: 95.12 Precision: 95.83 Recall: 93.88
#
# wheezy-copper-turtle-magic 39
#
# Fold 1
#
# Best: 0.964971 using {'reg_param': 0.5816915997632228}
# -----Train----------
# AUC: 98.76 Precision: 98.99 Recall: 98.49
#
# -----Validation-----
# AUC: 90.15 Precision: 91.67 Recall: 88.00
#
# Fold 2
#
# Best: 0.964971 using {'reg_param': 0.5776513600155634}
# -----Train----------
# AUC: 97.77 Precision: 97.98 Recall: 97.49
#
# -----Validation-----
# AUC: 92.12 Precision: 93.75 Recall: 90.00
#
# Fold 3
#
# Best: 0.964971 using {'reg_param': 0.5776513600155634}
# -----Train----------
# AUC: 98.02 Precision: 97.99 Recall: 97.99
#
# -----Validation-----
# AUC: 94.12 Precision: 94.00 Recall: 94.00
#
# Fold 4
#
# Best: 0.964971 using {'reg_param': 0.5816915997632228}
# -----Train----------
# AUC: 98.02 Precision: 98.48 Recall: 97.49
#
# -----Validation-----
# AUC: 91.08 Precision: 91.84 Recall: 90.00
#
# Fold 5
#
# Best: 0.964971 using {'reg_param': 0.5816915997632228}
# -----Train----------
# AUC: 98.03 Precision: 98.00 Recall: 98.00
#
# -----Validation-----
# AUC: 88.98 Precision: 89.58 Recall: 87.76
#
# wheezy-copper-turtle-magic 40
#
# Fold 1
#
# Best: 0.963387 using {'reg_param': 0.8920314316606565}
# -----Train----------
# AUC: 97.21 Precision: 97.44 Recall: 96.94
#
# -----Validation-----
# AUC: 91.00 Precision: 90.20 Recall: 92.00
#
# Fold 2
#
# Best: 0.963307 using {'reg_param': 0.8818536264929979}
# -----Train----------
# AUC: 97.22 Precision: 97.94 Recall: 96.45
#
# -----Validation-----
# AUC: 90.88 Precision: 93.48 Recall: 87.76
#
# Fold 3
#
# Best: 0.963387 using {'reg_param': 0.8920314316606565}
# -----Train----------
# AUC: 97.22 Precision: 97.45 Recall: 96.95
#
# -----Validation-----
# AUC: 91.88 Precision: 95.56 Recall: 87.76
#
# Fold 4
#
# Best: 0.963387 using {'reg_param': 0.8701421360985724}
# -----Train----------
# AUC: 96.46 Precision: 97.91 Recall: 94.92
#
# -----Validation-----
# AUC: 90.88 Precision: 93.48 Recall: 87.76
#
# Fold 5
#
# Best: 0.963387 using {'reg_param': 0.8918812277812977}
# -----Train----------
# AUC: 96.72 Precision: 97.92 Recall: 95.43
#
# -----Validation-----
# AUC: 93.88 Precision: 97.78 Recall: 89.80
#
# wheezy-copper-turtle-magic 41
#
# Fold 1
#
# Best: 0.965789 using {'reg_param': 0.6928390584876881}
# -----Train----------
# AUC: 97.22 Precision: 98.11 Recall: 96.30
#
# -----Validation-----
# AUC: 90.74 Precision: 92.31 Recall: 88.89
#
# Fold 2
#
# Best: 0.965858 using {'reg_param': 0.697731344371419}
# -----Train----------
# AUC: 97.68 Precision: 98.58 Recall: 96.76
#
# -----Validation-----
# AUC: 96.30 Precision: 94.64 Recall: 98.15
#
# Fold 3
#
# Best: 0.965858 using {'reg_param': 0.697731344371419}
# -----Train----------
# AUC: 97.68 Precision: 98.58 Recall: 96.76
#
# -----Validation-----
# AUC: 90.74 Precision: 87.93 Recall: 94.44
#
# Fold 4
#
# Best: 0.965789 using {'reg_param': 0.6927796472506498}
# -----Train----------
# AUC: 98.14 Precision: 98.15 Recall: 98.15
#
# -----Validation-----
# AUC: 94.44 Precision: 98.00 Recall: 90.74
#
# Fold 5
#
# Best: 0.965858 using {'reg_param': 0.697731344371419}
# -----Train----------
# AUC: 96.76 Precision: 97.20 Recall: 96.30
#
# -----Validation-----
# AUC: 91.65 Precision: 97.87 Recall: 85.19
#
# wheezy-copper-turtle-magic 42
#
# Fold 1
#
# Best: 0.970776 using {'reg_param': 0.896650049255212}
# -----Train----------
# AUC: 96.81 Precision: 96.34 Recall: 97.35
#
# -----Validation-----
# AUC: 95.81 Precision: 97.83 Recall: 93.75
#
# Fold 2
#
# Best: 0.970687 using {'reg_param': 0.8918812277812977}
# -----Train----------
# AUC: 96.81 Precision: 96.34 Recall: 97.35
#
# -----Validation-----
# AUC: 94.73 Precision: 93.88 Recall: 95.83
#
# Fold 3
#
# Best: 0.970322 using {'reg_param': 0.8812220939140504}
# -----Train----------
# AUC: 97.88 Precision: 98.40 Recall: 97.37
#
# -----Validation-----
# AUC: 89.36 Precision: 89.36 Recall: 89.36
#
# Fold 4
#
# Best: 0.970776 using {'reg_param': 0.896650049255212}
# -----Train----------
# AUC: 97.62 Precision: 98.40 Recall: 96.84
#
# -----Validation-----
# AUC: 92.55 Precision: 90.00 Recall: 95.74
#
# Fold 5
#
# Best: 0.970776 using {'reg_param': 0.896650049255212}
# -----Train----------
# AUC: 97.62 Precision: 97.38 Recall: 97.89
#
# -----Validation-----
# AUC: 92.48 Precision: 93.48 Recall: 91.49
#
# wheezy-copper-turtle-magic 43
#
# Fold 1
#
# Best: 0.951020 using {'reg_param': 0.83278722570239}
# -----Train----------
# AUC: 96.60 Precision: 97.47 Recall: 95.54
#
# -----Validation-----
# AUC: 85.89 Precision: 81.03 Recall: 92.16
#
# Fold 2
#
# Best: 0.950945 using {'reg_param': 0.8481602210929122}
# -----Train----------
# AUC: 95.91 Precision: 95.57 Recall: 96.04
#
# -----Validation-----
# AUC: 88.56 Precision: 88.24 Recall: 88.24
#
# Fold 3
#
# Best: 0.951020 using {'reg_param': 0.83278722570239}
# -----Train----------
# AUC: 95.93 Precision: 95.12 Recall: 96.53
#
# -----Validation-----
# AUC: 90.27 Precision: 95.56 Recall: 84.31
#
# Fold 4
#
# Best: 0.951093 using {'reg_param': 0.8291110891881457}
# -----Train----------
# AUC: 95.93 Precision: 95.59 Recall: 96.06
#
# -----Validation-----
# AUC: 92.17 Precision: 93.75 Recall: 90.00
#
# Fold 5
#
# Best: 0.951020 using {'reg_param': 0.83278722570239}
# -----Train----------
# AUC: 95.00 Precision: 93.33 Recall: 96.55
#
# -----Validation-----
# AUC: 89.40 Precision: 86.79 Recall: 92.00
#
# wheezy-copper-turtle-magic 44
#
# Fold 1
#
# Best: 0.970632 using {'reg_param': 0.7154741770060471}
# -----Train----------
# AUC: 98.23 Precision: 98.11 Recall: 98.58
#
# -----Validation-----
# AUC: 92.81 Precision: 89.66 Recall: 98.11
#
# Fold 2
#
# Best: 0.970553 using {'reg_param': 0.7354588281004723}
# -----Train----------
# AUC: 98.23 Precision: 98.11 Recall: 98.58
#
# -----Validation-----
# AUC: 96.13 Precision: 98.04 Recall: 94.34
#
# Fold 3
#
# Best: 0.970632 using {'reg_param': 0.716610876914447}
# -----Train----------
# AUC: 97.97 Precision: 97.65 Recall: 98.58
#
# -----Validation-----
# AUC: 98.11 Precision: 100.00 Recall: 96.23
#
# Fold 4
#
# Best: 0.970632 using {'reg_param': 0.7154741770060471}
# -----Train----------
# AUC: 98.24 Precision: 98.11 Recall: 98.58
#
# -----Validation-----
# AUC: 97.99 Precision: 98.11 Recall: 98.11
#
# Fold 5
#
# Best: 0.970632 using {'reg_param': 0.7145270582495623}
# -----Train----------
# AUC: 98.97 Precision: 98.60 Recall: 99.53
#
# -----Validation-----
# AUC: 90.94 Precision: 92.16 Recall: 90.38
#
# wheezy-copper-turtle-magic 45
#
# Fold 1
#
# Best: 0.964336 using {'reg_param': 0.6124836269996989}
# -----Train----------
# AUC: 96.88 Precision: 96.59 Recall: 97.06
#
# -----Validation-----
# AUC: 94.19 Precision: 95.92 Recall: 92.16
#
# Fold 2
#
# Best: 0.964336 using {'reg_param': 0.730260571861634}
# -----Train----------
# AUC: 96.40 Precision: 96.10 Recall: 96.57
#
# -----Validation-----
# AUC: 93.21 Precision: 95.83 Recall: 90.20
#
# Fold 3
#
# Best: 0.964336 using {'reg_param': 0.7255290255398209}
# -----Train----------
# AUC: 95.91 Precision: 96.06 Recall: 95.59
#
# -----Validation-----
# AUC: 94.15 Precision: 97.87 Recall: 90.20
#
# Fold 4
#
# Best: 0.964336 using {'reg_param': 0.6124836269996989}
# -----Train----------
# AUC: 97.82 Precision: 98.51 Recall: 97.06
#
# -----Validation-----
# AUC: 90.46 Precision: 87.27 Recall: 94.12
#
# Fold 5
#
# Best: 0.964336 using {'reg_param': 0.6124836269996989}
# -----Train----------
# AUC: 97.36 Precision: 97.07 Recall: 97.55
#
# -----Validation-----
# AUC: 86.46 Precision: 89.36 Recall: 82.35
#
# wheezy-copper-turtle-magic 46
#
# Fold 1
#
# Best: 0.963395 using {'reg_param': 0.7939040056540632}
# -----Train----------
# AUC: 96.74 Precision: 96.50 Recall: 96.98
#
# -----Validation-----
# AUC: 95.02 Precision: 97.87 Recall: 92.00
#
# Fold 2
#
# Best: 0.963395 using {'reg_param': 0.7939040056540632}
# -----Train----------
# AUC: 97.49 Precision: 98.46 Recall: 96.48
#
# -----Validation-----
# AUC: 90.00 Precision: 88.46 Recall: 92.00
#
# Fold 3
#
# Best: 0.963319 using {'reg_param': 0.5492646904233974}
# -----Train----------
# AUC: 96.25 Precision: 96.00 Recall: 96.48
#
# -----Validation-----
# AUC: 94.00 Precision: 95.83 Recall: 92.00
#
# Fold 4
#
# Best: 0.963316 using {'reg_param': 0.7919333130445819}
# -----Train----------
# AUC: 97.25 Precision: 97.00 Recall: 97.49
#
# -----Validation-----
# AUC: 93.00 Precision: 92.16 Recall: 94.00
#
# Fold 5
#
# Best: 0.963474 using {'reg_param': 0.8291110891881457}
# -----Train----------
# AUC: 96.76 Precision: 96.98 Recall: 96.50
#
# -----Validation-----
# AUC: 92.96 Precision: 90.38 Recall: 95.92
#
# wheezy-copper-turtle-magic 47
#
# Fold 1
#
# Best: 0.967131 using {'reg_param': 0.36819430817784865}
# -----Train----------
# AUC: 98.80 Precision: 99.07 Recall: 98.61
#
# -----Validation-----
# AUC: 89.45 Precision: 89.29 Recall: 90.91
#
# Fold 2
#
# Best: 0.967131 using {'reg_param': 0.3840580773069519}
# -----Train----------
# AUC: 98.11 Precision: 99.06 Recall: 97.24
#
# -----Validation-----
# AUC: 94.15 Precision: 92.86 Recall: 96.30
#
# Fold 3
#
# Best: 0.967131 using {'reg_param': 0.36819430817784865}
# -----Train----------
# AUC: 97.63 Precision: 98.59 Recall: 96.77
#
# -----Validation-----
# AUC: 96.22 Precision: 98.08 Recall: 94.44
#
# Fold 4
#
# Best: 0.967131 using {'reg_param': 0.36935644549030316}
# -----Train----------
# AUC: 97.88 Precision: 99.06 Recall: 96.77
#
# -----Validation-----
# AUC: 93.30 Precision: 94.34 Recall: 92.59
#
# Fold 5
#
# Best: 0.967058 using {'reg_param': 0.40777611392877366}
# -----Train----------
# AUC: 97.64 Precision: 98.59 Recall: 96.77
#
# -----Validation-----
# AUC: 93.24 Precision: 94.34 Recall: 92.59
#
# wheezy-copper-turtle-magic 48
#
# Fold 1
#
# Best: 0.964126 using {'reg_param': 0.31925038349887236}
# -----Train----------
# AUC: 97.15 Precision: 96.80 Recall: 97.70
#
# ...
#
# wheezy-copper-turtle-magic 496
#
# Fold 1
#
# Best: 0.973428 using {'reg_param': 0.7993594056525068}
# -----Train----------
# AUC: 98.51 Precision: 98.99 Recall: 98.00
#
# -----Validation-----
# AUC: 92.23 Precision: 92.16 Recall: 92.16
#
# Fold 2
#
# Best: 0.973428 using {'reg_param': 0.7993594056525068}
# -----Train----------
# AUC: 98.03 Precision: 98.01 Recall: 98.01
#
# -----Validation-----
# AUC: 95.12 Precision: 94.12 Recall: 96.00
#
# Fold 3
#
# Best: 0.973427 using {'reg_param': 0.780748647110169}
# -----Train----------
# AUC: 98.77 Precision: 99.00 Recall: 98.51
#
# -----Validation-----
# AUC: 94.06 Precision: 94.00 Recall: 94.00
#
# Fold 4
#
# Best: 0.973353 using {'reg_param': 0.8063877950570396}
# -----Train----------
# AUC: 98.77 Precision: 98.51 Recall: 99.00
#
# -----Validation-----
# AUC: 90.06 Precision: 93.48 Recall: 86.00
#
# Fold 5
#
# Best: 0.973428 using {'reg_param': 0.7993594056525068}
# -----Train----------
# AUC: 98.53 Precision: 98.51 Recall: 98.51
#
# -----Validation-----
# AUC: 97.00 Precision: 100.00 Recall: 94.00
#
# wheezy-copper-turtle-magic 497
#
# Fold 1
#
# Best: 0.950858 using {'reg_param': 0.7744594557447825}
# -----Train----------
# AUC: 96.90 Precision: 96.26 Recall: 97.63
#
# -----Validation-----
# AUC: 88.68 Precision: 90.20 Recall: 86.79
#
# Fold 2
#
# Best: 0.950858 using {'reg_param': 0.7744594557447825}
# -----Train----------
# AUC: 97.14 Precision: 97.16 Recall: 97.16
#
# -----Validation-----
# AUC: 84.91 Precision: 86.27 Recall: 83.02
#
# Fold 3
#
# Best: 0.950858 using {'reg_param': 0.7744594557447825}
# -----Train----------
# AUC: 96.44 Precision: 95.79 Recall: 97.16
#
# -----Validation-----
# AUC: 96.17 Precision: 94.55 Recall: 98.11
#
# Fold 4
#
# Best: 0.950858 using {'reg_param': 0.7744594557447825}
# -----Train----------
# AUC: 97.15 Precision: 97.61 Recall: 96.68
#
# -----Validation-----
# AUC: 89.42 Precision: 82.81 Recall: 100.00
#
# Fold 5
#
# Best: 0.950858 using {'reg_param': 0.7744594557447825}
# -----Train----------
# AUC: 96.20 Precision: 94.14 Recall: 98.58
#
# -----Validation-----
# AUC: 85.58 Precision: 84.91 Recall: 86.54
#
# wheezy-copper-turtle-magic 498
#
# Fold 1
#
# Best: 0.963409 using {'reg_param': 0.6462482189535894}
# -----Train----------
# AUC: 97.12 Precision: 95.75 Recall: 98.54
#
# -----Validation-----
# AUC: 94.29 Precision: 94.23 Recall: 94.23
#
# Fold 2
#
# Best: 0.963407 using {'reg_param': 0.7145270582495623}
# -----Train----------
# AUC: 97.36 Precision: 96.21 Recall: 98.54
#
# -----Validation-----
# AUC: 93.32 Precision: 94.12 Recall: 92.31
#
# Fold 3
#
# Best: 0.963481 using {'reg_param': 0.7223335438708776}
# -----Train----------
# AUC: 96.64 Precision: 95.71 Recall: 97.57
#
# -----Validation-----
# AUC: 95.19 Precision: 96.08 Recall: 94.23
#
# Fold 4
#
# Best: 0.963409 using {'reg_param': 0.6031606126955722}
# -----Train----------
# AUC: 97.13 Precision: 96.65 Recall: 97.58
#
# -----Validation-----
# AUC: 95.17 Precision: 92.59 Recall: 98.04
#
# Fold 5
#
# Best: 0.963409 using {'reg_param': 0.6462482189535894}
# -----Train----------
# AUC: 96.88 Precision: 97.09 Recall: 96.62
#
# -----Validation-----
# AUC: 92.27 Precision: 89.09 Recall: 96.08
#
# wheezy-copper-turtle-magic 499
#
# Fold 1
#
# Best: 0.952461 using {'reg_param': 0.5215155695979251}
# -----Train----------
# AUC: 96.48 Precision: 97.40 Recall: 95.41
#
# -----Validation-----
# AUC: 92.90 Precision: 97.73 Recall: 87.76
#
# Fold 2
#
# Best: 0.952381 using {'reg_param': 0.5360971702219334}
# -----Train----------
# AUC: 96.96 Precision: 98.94 Recall: 94.90
#
# -----Validation-----
# AUC: 89.96 Precision: 91.49 Recall: 87.76
#
# Fold 3
#
# Best: 0.952461 using {'reg_param': 0.5215155695979251}
# -----Train----------
# AUC: 97.24 Precision: 97.44 Recall: 96.94
#
# -----Validation-----
# AUC: 86.85 Precision: 92.86 Recall: 79.59
#
# Fold 4
#
# Best: 0.952461 using {'reg_param': 0.5215155695979251}
# -----Train----------
# AUC: 96.71 Precision: 98.41 Recall: 94.90
#
# -----Validation-----
# AUC: 93.92 Precision: 97.78 Recall: 89.80
#
# Fold 5
#
# Best: 0.952461 using {'reg_param': 0.523724805413233}
# -----Train----------
# AUC: 96.72 Precision: 97.91 Recall: 95.41
#
# -----Validation-----
# AUC: 89.06 Precision: 86.54 Recall: 91.84
#
# wheezy-copper-turtle-magic 500
#
# Fold 1
#
# Best: 0.953340 using {'reg_param': 0.2907875296032336}
# -----Train----------
# AUC: 97.50 Precision: 98.00 Recall: 97.03
#
# -----Validation-----
# AUC: 91.08 Precision: 90.38 Recall: 92.16
#
# Fold 2
#
# Best: 0.953340 using {'reg_param': 0.2901166868542539}
# -----Train----------
# AUC: 96.50 Precision: 96.53 Recall: 96.53
#
# -----Validation-----
# AUC: 93.04 Precision: 90.74 Recall: 96.08
#
# Fold 3
#
# Best: 0.953340 using {'reg_param': 0.2901166868542539}
# -----Train----------
# AUC: 96.99 Precision: 96.57 Recall: 97.52
#
# -----Validation-----
# AUC: 94.04 Precision: 92.45 Recall: 96.08
#
# Fold 4
#
# Best: 0.953419 using {'reg_param': 0.2707379652189727}
# -----Train----------
# AUC: 98.00 Precision: 97.56 Recall: 98.52
#
# -----Validation-----
# AUC: 85.82 Precision: 83.33 Recall: 90.00
#
# Fold 5
#
# Best: 0.953340 using {'reg_param': 0.2901166868542539}
# -----Train----------
# AUC: 97.75 Precision: 97.09 Recall: 98.52
#
# -----Validation-----
# AUC: 87.90 Precision: 89.58 Recall: 86.00
#
# wheezy-copper-turtle-magic 501
#
# Fold 1
#
# Best: 0.960506 using {'reg_param': 0.03280709060177654}
# -----Train----------
# AUC: 96.87 Precision: 97.57 Recall: 96.63
#
# -----Validation-----
# AUC: 89.16 Precision: 87.50 Recall: 94.23
#
# Fold 2
#
# Best: 0.960506 using {'reg_param': 0.03280709060177654}
# -----Train----------
# AUC: 96.82 Precision: 97.12 Recall: 97.12
#
# -----Validation-----
# AUC: 91.96 Precision: 95.83 Recall: 88.46
#
# Fold 3
#
# Best: 0.960506 using {'reg_param': 0.03280709060177654}
# -----Train----------
# AUC: 96.59 Precision: 97.10 Recall: 96.63
#
# -----Validation-----
# AUC: 94.99 Precision: 97.96 Recall: 92.31
#
# Fold 4
#
# Best: 0.960504 using {'reg_param': 0.09700230948606911}
# -----Train----------
# AUC: 96.35 Precision: 97.09 Recall: 96.15
#
# -----Validation-----
# AUC: 90.14 Precision: 89.09 Recall: 94.23
#
# Fold 5
#
# Best: 0.960506 using {'reg_param': 0.03280709060177654}
# -----Train----------
# AUC: 96.11 Precision: 97.07 Recall: 95.67
#
# -----Validation-----
# AUC: 91.30 Precision: 90.74 Recall: 94.23
#
# wheezy-copper-turtle-magic 502
#
# Fold 1
#
# Best: 0.961184 using {'reg_param': 0.8665159436027006}
# -----Train----------
# AUC: 96.66 Precision: 95.71 Recall: 97.57
#
# -----Validation-----
# AUC: 91.56 Precision: 89.09 Recall: 94.23
#
# Fold 2
#
# Best: 0.961312 using {'reg_param': 0.8139840218827747}
# -----Train----------
# AUC: 97.85 Precision: 98.05 Recall: 97.57
#
# -----Validation-----
# AUC: 92.40 Precision: 90.74 Recall: 94.23
#
# Fold 3
#
# Best: 0.961184 using {'reg_param': 0.8665159436027006}
# -----Train----------
# AUC: 95.95 Precision: 95.22 Recall: 96.60
#
# -----Validation-----
# AUC: 93.31 Precision: 95.92 Recall: 90.38
#
# Fold 4
#
# Best: 0.961095 using {'reg_param': 0.8211722366180871}
# -----Train----------
# AUC: 96.65 Precision: 97.54 Recall: 95.65
#
# -----Validation-----
# AUC: 91.40 Precision: 88.89 Recall: 94.12
#
# Fold 5
#
# Best: 0.961312 using {'reg_param': 0.8139840218827747}
# -----Train----------
# AUC: 96.90 Precision: 97.09 Recall: 96.62
#
# -----Validation-----
# AUC: 91.29 Precision: 93.75 Recall: 88.24
#
# wheezy-copper-turtle-magic 503
#
# Fold 1
#
# Best: 0.968264 using {'reg_param': 0.6997797960421868}
# -----Train----------
# AUC: 97.16 Precision: 96.83 Recall: 97.34
#
# -----Validation-----
# AUC: 93.83 Precision: 95.65 Recall: 91.67
#
# Fold 2
#
# Best: 0.968264 using {'reg_param': 0.704184694956826}
# -----Train----------
# AUC: 97.93 Precision: 97.88 Recall: 97.88
#
# -----Validation-----
# AUC: 91.74 Precision: 91.49 Recall: 91.49
#
# Fold 3
#
# Best: 0.968264 using {'reg_param': 0.7047099875216093}
# -----Train----------
# AUC: 97.92 Precision: 98.40 Recall: 97.35
#
# -----Validation-----
# AUC: 92.68 Precision: 95.45 Recall: 89.36
#
# Fold 4
#
# Best: 0.968264 using {'reg_param': 0.7047099875216093}
# -----Train----------
# AUC: 96.89 Precision: 97.33 Recall: 96.30
#
# -----Validation-----
# AUC: 95.83 Precision: 95.74 Recall: 95.74
#
# Fold 5
#
# Best: 0.968264 using {'reg_param': 0.7047099875216093}
# -----Train----------
# AUC: 97.67 Precision: 97.87 Recall: 97.35
#
# -----Validation-----
# AUC: 93.75 Precision: 93.62 Recall: 93.62
#
# wheezy-copper-turtle-magic 504
#
# Fold 1
#
# Best: 0.963736 using {'reg_param': 0.19738577931837345}
# -----Train----------
# AUC: 97.01 Precision: 96.67 Recall: 97.60
#
# -----Validation-----
# AUC: 92.97 Precision: 90.91 Recall: 96.15
#
# Fold 2
#
# Best: 0.963815 using {'reg_param': 0.20079652837150366}
# -----Train----------
# AUC: 97.04 Precision: 97.57 Recall: 96.63
#
# -----Validation-----
# AUC: 89.01 Precision: 87.27 Recall: 92.31
#
# Fold 3
#
# Best: 0.963815 using {'reg_param': 0.20079652837150366}
# -----Train----------
# AUC: 96.28 Precision: 96.17 Recall: 96.63
#
# -----Validation-----
# AUC: 95.02 Precision: 94.34 Recall: 96.15
#
# Fold 4
#
# Best: 0.963815 using {'reg_param': 0.20079652837150366}
# -----Train----------
# AUC: 98.00 Precision: 97.62 Recall: 98.56
#
# -----Validation-----
# AUC: 88.11 Precision: 88.46 Recall: 88.46
#
# Fold 5
#
# Best: 0.963658 using {'reg_param': 0.2707379652189727}
# -----Train----------
# AUC: 96.28 Precision: 96.17 Recall: 96.63
#
# -----Validation-----
# AUC: 92.19 Precision: 95.83 Recall: 88.46
#
# wheezy-copper-turtle-magic 505
#
# Fold 1
#
# Best: 0.962951 using {'reg_param': 0.31866519621458206}
# -----Train----------
# AUC: 97.10 Precision: 95.69 Recall: 98.52
#
# -----Validation-----
# AUC: 95.21 Precision: 94.23 Recall: 96.08
#
# Fold 2
#
# Best: 0.962941 using {'reg_param': 0.5453382998138999}
# -----Train----------
# AUC: 98.32 Precision: 97.12 Recall: 99.51
#
# -----Validation-----
# AUC: 89.39 Precision: 84.48 Recall: 96.08
#
# Fold 3
#
# Best: 0.962951 using {'reg_param': 0.31866519621458206}
# -----Train----------
# AUC: 98.06 Precision: 97.56 Recall: 98.52
#
# -----Validation-----
# AUC: 92.19 Precision: 95.74 Recall: 88.24
#
# Fold 4
#
# Best: 0.962951 using {'reg_param': 0.31866519621458206}
# -----Train----------
# AUC: 97.83 Precision: 96.63 Recall: 99.01
#
# -----Validation-----
# AUC: 85.50 Precision: 81.03 Recall: 92.16
#
# Fold 5
#
# Best: 0.962951 using {'reg_param': 0.31866519621458206}
# -----Train----------
# AUC: 97.11 Precision: 95.71 Recall: 98.53
#
# -----Validation-----
# AUC: 91.19 Precision: 90.20 Recall: 92.00
#
# wheezy-copper-turtle-magic 506
#
# Fold 1
#
# Best: 0.961679 using {'reg_param': 0.3840580773069519}
# -----Train----------
# AUC: 97.41 Precision: 97.63 Recall: 97.17
#
# -----Validation-----
# AUC: 91.67 Precision: 94.12 Recall: 88.89
#
# Fold 2
#
# Best: 0.961609 using {'reg_param': 0.36935644549030316}
# -----Train----------
# AUC: 97.65 Precision: 98.56 Recall: 96.71
#
# -----Validation-----
# AUC: 86.95 Precision: 84.21 Recall: 90.57
#
# Fold 3
#
# Best: 0.961608 using {'reg_param': 0.39710923510613766}
# -----Train----------
# AUC: 98.13 Precision: 98.58 Recall: 97.65
#
# -----Validation-----
# AUC: 92.45 Precision: 89.47 Recall: 96.23
#
# Fold 4
#
# Best: 0.961609 using {'reg_param': 0.36935644549030316}
# -----Train----------
# AUC: 97.19 Precision: 96.74 Recall: 97.65
#
# -----Validation-----
# AUC: 97.17 Precision: 98.08 Recall: 96.23
#
# Fold 5
#
# Best: 0.961538 using {'reg_param': 0.36819430817784865}
# -----Train----------
# AUC: 97.89 Precision: 98.11 Recall: 97.65
#
# -----Validation-----
# AUC: 90.57 Precision: 92.16 Recall: 88.68
#
# wheezy-copper-turtle-magic 507
#
# Fold 1
#
# Best: 0.971025 using {'reg_param': 0.6462482189535894}
# -----Train----------
# AUC: 98.53 Precision: 98.98 Recall: 97.98
#
# -----Validation-----
# AUC: 91.45 Precision: 90.20 Recall: 92.00
#
# Fold 2
#
# Best: 0.971025 using {'reg_param': 0.6402811003061963}
# -----Train----------
# AUC: 98.57 Precision: 98.00 Recall: 98.99
#
# -----Validation-----
# AUC: 90.37 Precision: 90.00 Recall: 90.00
#
# Fold 3
#
# Best: 0.971025 using {'reg_param': 0.5215155695979251}
# -----Train----------
# AUC: 98.80 Precision: 98.49 Recall: 98.99
#
# -----Validation-----
# AUC: 91.30 Precision: 91.84 Recall: 90.00
#
# Fold 4
#
# Best: 0.971025 using {'reg_param': 0.6462482189535894}
# -----Train----------
# AUC: 98.51 Precision: 99.49 Recall: 97.49
#
# -----Validation-----
# AUC: 94.26 Precision: 92.16 Recall: 95.92
#
# Fold 5
#
# Best: 0.971025 using {'reg_param': 0.6402811003061963}
# -----Train----------
# AUC: 98.09 Precision: 97.51 Recall: 98.49
#
# -----Validation-----
# AUC: 94.26 Precision: 92.16 Recall: 95.92
#
# wheezy-copper-turtle-magic 508
#
# Fold 1
#
# Best: 0.934192 using {'reg_param': 0.17245804758417907}
# -----Train----------
# AUC: 96.15 Precision: 95.28 Recall: 97.12
#
# -----Validation-----
# AUC: 90.57 Precision: 92.16 Recall: 88.68
#
# Fold 2
#
# Best: 0.934192 using {'reg_param': 0.18400817064510971}
# -----Train----------
# AUC: 95.69 Precision: 95.26 Recall: 96.17
#
# -----Validation-----
# AUC: 92.31 Precision: 90.74 Recall: 94.23
#
# Fold 3
#
# Best: 0.934192 using {'reg_param': 0.17245804758417907}
# -----Train----------
# AUC: 96.17 Precision: 95.31 Recall: 97.13
#
# -----Validation-----
# AUC: 91.35 Precision: 92.16 Recall: 90.38
#
# Fold 4
#
# Best: 0.934192 using {'reg_param': 0.18400817064510971}
# -----Train----------
# AUC: 95.93 Precision: 95.28 Recall: 96.65
#
# -----Validation-----
# AUC: 91.35 Precision: 89.09 Recall: 94.23
#
# Fold 5
#
# Best: 0.934192 using {'reg_param': 0.17245804758417907}
# -----Train----------
# AUC: 96.65 Precision: 97.10 Recall: 96.17
#
# -----Validation-----
# AUC: 84.62 Precision: 82.14 Recall: 88.46
#
# wheezy-copper-turtle-magic 509
#
# Fold 1
#
# Best: 0.961760 using {'reg_param': 0.5924498893405672}
# -----Train----------
# AUC: 97.73 Precision: 98.45 Recall: 96.94
#
# -----Validation-----
# AUC: 92.08 Precision: 92.00 Recall: 92.00
#
# Fold 2
#
# Best: 0.961760 using {'reg_param': 0.5924498893405672}
# -----Train----------
# AUC: 97.02 Precision: 96.48 Recall: 97.46
#
# -----Validation-----
# AUC: 96.00 Precision: 95.92 Recall: 95.92
#
# Fold 3
#
# Best: 0.961760 using {'reg_param': 0.5924498893405672}
# -----Train----------
# AUC: 98.00 Precision: 97.97 Recall: 97.97
#
# -----Validation-----
# AUC: 92.98 Precision: 93.75 Recall: 91.84
#
# Fold 4
#
# Best: 0.961681 using {'reg_param': 0.5869264218752731}
# -----Train----------
# AUC: 98.01 Precision: 97.49 Recall: 98.48
#
# -----Validation-----
# AUC: 90.90 Precision: 95.45 Recall: 85.71
#
# Fold 5
#
# Best: 0.961681 using {'reg_param': 0.6031606126955722}
# -----Train----------
# AUC: 97.26 Precision: 96.97 Recall: 97.46
#
# -----Validation-----
# AUC: 93.06 Precision: 90.38 Recall: 95.92
#
# wheezy-copper-turtle-magic 510
#
# Fold 1
#
# Best: 0.942670 using {'reg_param': 0.5695316378759787}
# -----Train----------
# AUC: 96.82 Precision: 97.47 Recall: 96.02
#
# -----Validation-----
# AUC: 94.23 Precision: 94.12 Recall: 94.12
#
# Fold 2
#
# Best: 0.942670 using {'reg_param': 0.5816915997632228}
# -----Train----------
# AUC: 96.83 Precision: 97.00 Recall: 96.52
#
# -----Validation-----
# AUC: 89.44 Precision: 88.46 Recall: 90.20
#
# Fold 3
#
# Best: 0.942672 using {'reg_param': 0.5924498893405672}
# -----Train----------
# AUC: 97.31 Precision: 97.99 Recall: 96.53
#
# -----Validation-----
# AUC: 87.40 Precision: 86.27 Recall: 88.00
#
# Fold 4
#
# Best: 0.942672 using {'reg_param': 0.5924498893405672}
# -----Train----------
# AUC: 97.58 Precision: 97.52 Recall: 97.52
#
# -----Validation-----
# AUC: 86.27 Precision: 86.00 Recall: 86.00
#
# Fold 5
#
# Best: 0.942670 using {'reg_param': 0.576581177083419}
# -----Train----------
# AUC: 97.80 Precision: 98.49 Recall: 97.03
#
# -----Validation-----
# AUC: 87.15 Precision: 91.11 Recall: 82.00
#
# wheezy-copper-turtle-magic 511
#
# Fold 1
#
# Best: 0.955166 using {'reg_param': 0.7993594056525068}
# -----Train----------
# AUC: 96.26 Precision: 96.59 Recall: 96.12
#
# -----Validation-----
# AUC: 93.94 Precision: 91.07 Recall: 98.08
#
# Fold 2
#
# Best: 0.955179 using {'reg_param': 0.7255290255398209}
# -----Train----------
# AUC: 96.76 Precision: 97.07 Recall: 96.60
#
# -----Validation-----
# AUC: 93.03 Precision: 92.45 Recall: 94.23
#
# Fold 3
#
# Best: 0.955179 using {'reg_param': 0.7354588281004723}
# -----Train----------
# AUC: 96.76 Precision: 97.07 Recall: 96.60
#
# -----Validation-----
# AUC: 94.05 Precision: 94.23 Recall: 94.23
#
# Fold 4
#
# Best: 0.955166 using {'reg_param': 0.7993594056525068}
# -----Train----------
# AUC: 96.26 Precision: 96.15 Recall: 96.62
#
# -----Validation-----
# AUC: 92.04 Precision: 93.88 Recall: 90.20
#
# Fold 5
#
# Best: 0.955179 using {'reg_param': 0.7354588281004723}
# -----Train----------
# AUC: 97.50 Precision: 97.13 Recall: 98.07
#
# -----Validation-----
# AUC: 87.93 Precision: 89.80 Recall: 86.27

# %% [markdown]
# # Ensemble models
#
# Here you can ensemble any combination of models, and give the desired weight for each one.

# %%
# train['preds_avg'] = (train['preds_pca_stdv'] * 0.5) + (train['preds_pca'] * 0.5)
# test['target_avg'] = (test['target_pca_stdv'] * 0.5) + (test['target_pca'] * 0.5)

# %% [markdown]
# # Model evaluation
# ## Confusion matrix (averaged model)

# %%
f = plt.subplots(1, 1, figsize=(16, 5), sharex=True)
train_cnf_matrix = confusion_matrix(train['target'], [np.round(x) for x in train['preds']])
train_cnf_matrix_norm = train_cnf_matrix / train_cnf_matrix.sum(axis=1)[:, np.newaxis]
train_df_cm = pd.DataFrame(train_cnf_matrix_norm, index=[0, 1], columns=[0, 1])
sns.heatmap(train_df_cm, annot=True, fmt='.2f', cmap="Blues")
plt.show()

# %% [markdown]
# ## Metrics ROC AUC

# %%
print('AUC %.5f' % roc_auc_score(train['target'], train['preds']))
# print('Averaged AUC        %.5f' % roc_auc_score(train['target'], train['preds_avg']))
# Out:
# AUC 0.99241

# %% [markdown]
# ### Test set with all models predictions

# %%
test[['id', 'target']].head()
# Out:
#                                  id        target
# 0  1c13f2701648e0b0d46d8a2a5a131a53  1.000000e+00
# 1  ba88c155ba898fc8b5099893036ef205  9.997138e-01
# 2  7cbab5cea99169139e7e6d8ff74ebb77  5.413640e-08
# 3  ca820ad57809f62eb7b4d13f5d4371a0  3.461147e-06
# 4  7baaf361537fbd8a1aaa2c97a6d4ccc7  2.124227e-01

# %% [markdown]
# # Test predictions
# Now you can output predictions for each individual model and the ensembled models as well.
#
# #### Averaged models submission

# %%
submission = test[['id', 'target']]
submission.columns = ['id', 'target']
submission.to_csv('submission.csv', index=False)
submission.head()
# Out:
#                                  id        target
# 0  1c13f2701648e0b0d46d8a2a5a131a53  1.000000e+00
# 1  ba88c155ba898fc8b5099893036ef205  9.997138e-01
# 2  7cbab5cea99169139e7e6d8ff74ebb77  5.413640e-08
# 3  ca820ad57809f62eb7b4d13f5d4371a0  3.461147e-06
# 4  7baaf361537fbd8a1aaa2c97a6d4ccc7  2.124227e-01
