# %% [markdown]
# # Dependencies

# %%
import warnings
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

from sklearn.svm import SVC, NuSVC
from sklearn.decomposition import PCA
from sklearn.neural_network import MLPClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.feature_selection import VarianceThreshold
from sklearn.discriminant_analysis import QuadraticDiscriminantAnalysis
from sklearn.preprocessing import MinMaxScaler, StandardScaler
from sklearn.model_selection import train_test_split, StratifiedKFold
from sklearn.metrics import confusion_matrix, roc_auc_score, recall_score, precision_score

# Set seeds to make the experiment more reproducible.
from numpy.random import seed
seed(0)

# %matplotlib inline
sns.set_style("whitegrid")
warnings.filterwarnings("ignore")

# %% [markdown]
# # Load data

# %%
train = pd.read_csv('../input/train.csv')
test = pd.read_csv('../input/test.csv')

print('Train set shape:', train.shape)
print('Test set shape:', test.shape)
print('Train set overview:')
display(train.head())
# Out:
# Train set shape: (262144, 258)
# Test set shape: (131073, 257)
# Train set overview:
#                                  id   ...    target
# 0  707b395ecdcbb4dc2eabea00e4d1b179   ...         0
# 1  5880c03c6582a7b42248668e56b4bdec   ...         0
# 2  4ccbcb3d13e5072ff1d9c61afe2c4f77   ...         1
# 3  e350f17a357f12a1941f0837afb7eb8d   ...         0
# 4  a8f910ea6075b6376af079055965ff68   ...         0
#
# [5 rows x 258 columns]

# %% [markdown]
# # Model
#
# ## Model parameters

# %%
N_FOLDS = 11

# %% [markdown]
# ### You can find evaluation metrics for each model on each fold below on this cell output log. (It's hidden to keep the code clean)

# %%
# INITIALIZE VARIABLES
cols = [c for c in train.columns if c not in ['id', 'target', 'wheezy-copper-turtle-magic', 'preds']]
test['target_qda'] = 0
train['preds_qda'] = 0
test['target_knn'] = 0
train['preds_knn'] = 0
test['target_mlp'] = 0
train['preds_mlp'] = 0
test['target_lr'] = 0
train['preds_lr'] = 0
test['target_nusvc'] = 0
train['preds_nusvc'] = 0

# BUILD 512 MODELS
for i in range(512):
    print('wheezy-copper-turtle-magic {}\n'.format(i))
    
    # EXTRACT SUBSET OF DATASET WHERE WHEEZY-MAGIC EQUALS I
    train2 = train[train['wheezy-copper-turtle-magic']==i]
    test2 = test[test['wheezy-copper-turtle-magic']==i]
    idx1 = train2.index
    idx2 = test2.index
    train2.reset_index(drop=True, inplace=True)
    
    data = pd.concat([pd.DataFrame(train2[cols]), pd.DataFrame(test2[cols])])
    data2 = MinMaxScaler().fit_transform(PCA(svd_solver='full',n_components='mle').fit_transform(data[cols]))
    train3 = data2[:train2.shape[0]]
    test3 = data2[train2.shape[0]:]

    skf = StratifiedKFold(n_splits=N_FOLDS, random_state=0)
    counter = 0

    for train_index, val_index in skf.split(train3, train2['target']):
        counter += 1
        print('Fold {}\n'.format(counter))
        model_names = ['qda', 'knn', 'mlp', 'lr', 'nusvc']
        models = [QuadraticDiscriminantAnalysis(), KNeighborsClassifier(n_neighbors=17, p=2.9), MLPClassifier(), 
#                   LogisticRegression(solver='liblinear',penalty='l1',C=0.1), 
                  LogisticRegression(solver='liblinear', penalty='l1'), 
                  NuSVC(probability=True, kernel='poly', degree=4, gamma='auto', random_state=4)]
        
        for i in range(len(model_names)):
            model = models[i]
            model_name = model_names[i]
            model.fit(train3[train_index,:], train2.loc[train_index]['target'])

            train_predictions = model.predict(train3[train_index,:])
            val_predictions = model.predict(train3[val_index,:])

            train_auc = roc_auc_score(train2.loc[train_index]['target'], train_predictions) * 100
            val_auc = roc_auc_score(train2.loc[val_index]['target'], val_predictions) * 100
            train_precision = precision_score(train2.loc[train_index]['target'], train_predictions) * 100
            val_precision = precision_score(train2.loc[val_index]['target'], val_predictions) * 100
            train_recall = recall_score(train2.loc[train_index]['target'], train_predictions) * 100
            val_recall = recall_score(train2.loc[val_index]['target'], val_predictions) * 100
            print('-----%s - Train----------' % model_name)
            print('AUC: %.2f Precision: %.2f Recall: %.2f \n' % (train_auc, train_precision, train_recall))
            print('-----%s - Validation-----' % model_name)
            print('AUC: %.2f Precision: %.2f Recall: %.2f \n' % (val_auc, val_precision, val_recall))

            # Make predictions
            train[('preds_%s' % model_name)].loc[idx1] += model.predict_proba(train3)[:,1] / N_FOLDS
            test[('target_%s' % model_name)].loc[idx2] += model.predict_proba(test3)[:,1] / N_FOLDS
# Out:
# wheezy-copper-turtle-magic 0
#
# Fold 1
#
# -----qda - Train----------
# AUC: 97.32 Precision: 97.48 Recall: 97.07
#
# -----qda - Validation-----
# AUC: 83.67 Precision: 83.33 Recall: 83.33
#
# -----knn - Train----------
# AUC: 88.40 Precision: 91.03 Recall: 84.94
#
# -----knn - Validation-----
# AUC: 77.33 Precision: 84.21 Recall: 66.67
#
# -----mlp - Train----------
# AUC: 85.76 Precision: 86.32 Recall: 84.52
#
# -----mlp - Validation-----
# AUC: 83.33 Precision: 100.00 Recall: 66.67
#
# -----lr - Train----------
# AUC: 78.35 Precision: 77.92 Recall: 78.24
#
# -----lr - Validation-----
# AUC: 81.33 Precision: 94.12 Recall: 66.67
#
# -----nusvc - Train----------
# AUC: 90.91 Precision: 91.85 Recall: 89.54
#
# -----nusvc - Validation-----
# AUC: 81.50 Precision: 85.71 Recall: 75.00
#
# Fold 2
#
# -----qda - Train----------
# AUC: 96.49 Precision: 96.64 Recall: 96.23
#
# -----qda - Validation-----
# AUC: 87.75 Precision: 87.50 Recall: 87.50
#
# -----knn - Train----------
# AUC: 86.54 Precision: 89.55 Recall: 82.43
#
# -----knn - Validation-----
# AUC: 77.33 Precision: 84.21 Recall: 66.67
#
# -----mlp - Train----------
# AUC: 83.73 Precision: 82.26 Recall: 85.36
#
# -----mlp - Validation-----
# AUC: 75.58 Precision: 73.08 Recall: 79.17
#
# -----lr - Train----------
# AUC: 81.43 Precision: 81.43 Recall: 80.75
#
# -----lr - Validation-----
# AUC: 67.42 Precision: 65.38 Recall: 70.83
#
# -----nusvc - Train----------
# AUC: 90.30 Precision: 90.34 Recall: 89.96
#
# -----nusvc - Validation-----
# AUC: 81.67 Precision: 80.00 Recall: 83.33
#
# Fold 3
#
# -----qda - Train----------
# AUC: 97.12 Precision: 96.68 Recall: 97.49
#
# -----qda - Validation-----
# AUC: 95.92 Precision: 95.83 Recall: 95.83
#
# -----knn - Train----------
# AUC: 86.75 Precision: 89.24 Recall: 83.26
#
# -----knn - Validation-----
# AUC: 85.58 Precision: 90.48 Recall: 79.17
#
# -----mlp - Train----------
# AUC: 84.49 Precision: 86.28 Recall: 81.59
#
# -----mlp - Validation-----
# AUC: 79.67 Precision: 76.92 Recall: 83.33
#
# -----lr - Train----------
# AUC: 78.55 Precision: 78.24 Recall: 78.24
#
# -----lr - Validation-----
# AUC: 79.50 Precision: 81.82 Recall: 75.00
#
# -----nusvc - Train----------
# AUC: 89.91 Precision: 88.93 Recall: 90.79
#
# -----nusvc - Validation-----
# AUC: 84.00 Precision: 75.00 Recall: 100.00
#
# Fold 4
#
# -----qda - Train----------
# AUC: 96.91 Precision: 96.67 Recall: 97.07
#
# -----qda - Validation-----
# AUC: 95.92 Precision: 95.83 Recall: 95.83
#
# -----knn - Train----------
# AUC: 86.50 Precision: 91.83 Recall: 79.92
#
# -----knn - Validation-----
# AUC: 81.50 Precision: 85.71 Recall: 75.00
#
# -----mlp - Train----------
# AUC: 85.37 Precision: 84.71 Recall: 85.77
#
# -----mlp - Validation-----
# AUC: 75.42 Precision: 77.27 Recall: 70.83
#
# -----lr - Train----------
# AUC: 76.90 Precision: 76.57 Recall: 76.57
#
# -----lr - Validation-----
# AUC: 73.33 Precision: 76.19 Recall: 66.67
#
# -----nusvc - Train----------
# AUC: 90.12 Precision: 88.98 Recall: 91.21
#
# -----nusvc - Validation-----
# AUC: 79.67 Precision: 76.92 Recall: 83.33
#
# Fold 5
#
# -----qda - Train----------
# AUC: 96.70 Precision: 96.65 Recall: 96.65
#
# -----qda - Validation-----
# AUC: 95.83 Precision: 100.00 Recall: 91.67
#
# -----knn - Train----------
# AUC: 87.17 Precision: 89.69 Recall: 83.68
#
# -----knn - Validation-----
# AUC: 87.67 Precision: 90.91 Recall: 83.33
#
# -----mlp - Train----------
# AUC: 86.58 Precision: 87.18 Recall: 85.36
#
# -----mlp - Validation-----
# AUC: 73.67 Precision: 68.97 Recall: 83.33
#
# -----lr - Train----------
# AUC: 79.78 Precision: 79.75 Recall: 79.08
#
# -----lr - Validation-----
# AUC: 69.50 Precision: 66.67 Recall: 75.00
#
# -----nusvc - Train----------
# AUC: 88.85 Precision: 89.70 Recall: 87.45
#
# -----nusvc - Validation-----
# AUC: 75.75 Precision: 70.00 Recall: 87.50
#
# Fold 6
#
# -----qda - Train----------
# AUC: 96.70 Precision: 96.65 Recall: 96.65
#
# -----qda - Validation-----
# AUC: 97.92 Precision: 100.00 Recall: 95.83
#
# -----knn - Train----------
# AUC: 86.96 Precision: 89.64 Recall: 83.26
#
# -----knn - Validation-----
# AUC: 91.67 Precision: 100.00 Recall: 83.33
#
# -----mlp - Train----------
# AUC: 84.28 Precision: 86.55 Recall: 80.75
#
# -----mlp - Validation-----
# AUC: 81.42 Precision: 89.47 Recall: 70.83
#
# -----lr - Train----------
# AUC: 80.00 Precision: 79.34 Recall: 80.33
#
# -----lr - Validation-----
# AUC: 73.25 Precision: 78.95 Recall: 62.50
#
# -----nusvc - Train----------
# AUC: 90.11 Precision: 89.63 Recall: 90.38
#
# -----nusvc - Validation-----
# AUC: 81.58 Precision: 82.61 Recall: 79.17
#
# Fold 7
#
# -----qda - Train----------
# AUC: 96.91 Precision: 96.67 Recall: 97.07
#
# -----qda - Validation-----
# AUC: 95.92 Precision: 95.83 Recall: 95.83
#
# -----knn - Train----------
# AUC: 86.35 Precision: 88.11 Recall: 83.68
#
# -----knn - Validation-----
# AUC: 81.58 Precision: 82.61 Recall: 79.17
#
# -----mlp - Train----------
# AUC: 85.13 Precision: 85.84 Recall: 83.68
#
# -----mlp - Validation-----
# AUC: 65.17 Precision: 66.67 Recall: 58.33
#
# -----lr - Train----------
# AUC: 79.17 Precision: 78.99 Recall: 78.66
#
# -----lr - Validation-----
# AUC: 65.25 Precision: 65.22 Recall: 62.50
#
# -----nusvc - Train----------
# AUC: 89.72 Precision: 87.65 Recall: 92.05
#
# -----nusvc - Validation-----
# AUC: 73.50 Precision: 72.00 Recall: 75.00
#
# Fold 8
#
# -----qda - Train----------
# AUC: 96.91 Precision: 97.06 Recall: 96.65
#
# -----qda - Validation-----
# AUC: 89.58 Precision: 91.30 Recall: 87.50
#
# -----knn - Train----------
# AUC: 86.96 Precision: 90.74 Recall: 82.01
#
# -----knn - Validation-----
# AUC: 79.17 Precision: 85.00 Recall: 70.83
#
# -----mlp - Train----------
# AUC: 86.57 Precision: 88.84 Recall: 83.26
#
# -----mlp - Validation-----
# AUC: 77.08 Precision: 78.26 Recall: 75.00
#
# -----lr - Train----------
# AUC: 79.19 Precision: 79.74 Recall: 77.41
#
# -----lr - Validation-----
# AUC: 70.83 Precision: 72.73 Recall: 66.67
#
# -----nusvc - Train----------
# AUC: 90.95 Precision: 90.46 Recall: 91.21
#
# -----nusvc - Validation-----
# AUC: 68.75 Precision: 68.00 Recall: 70.83
#
# Fold 9
#
# -----qda - Train----------
# AUC: 97.94 Precision: 97.91 Recall: 97.91
#
# -----qda - Validation-----
# AUC: 87.50 Precision: 90.91 Recall: 83.33
#
# -----knn - Train----------
# AUC: 88.43 Precision: 90.67 Recall: 85.36
#
# -----knn - Validation-----
# AUC: 81.25 Precision: 80.00 Recall: 83.33
#
# -----mlp - Train----------
# AUC: 86.41 Precision: 86.50 Recall: 85.77
#
# -----mlp - Validation-----
# AUC: 85.42 Precision: 84.00 Recall: 87.50
#
# -----lr - Train----------
# AUC: 80.03 Precision: 79.83 Recall: 79.50
#
# -----lr - Validation-----
# AUC: 81.25 Precision: 82.61 Recall: 79.17
#
# -----nusvc - Train----------
# AUC: 89.54 Precision: 87.60 Recall: 91.63
#
# -----nusvc - Validation-----
# AUC: 87.50 Precision: 84.62 Recall: 91.67
#
# Fold 10
#
# -----qda - Train----------
# AUC: 96.91 Precision: 97.06 Recall: 96.65
#
# -----qda - Validation-----
# AUC: 93.75 Precision: 95.65 Recall: 91.67
#
# -----knn - Train----------
# AUC: 86.33 Precision: 90.23 Recall: 81.17
#
# -----knn - Validation-----
# AUC: 87.50 Precision: 90.91 Recall: 83.33
#
# -----mlp - Train----------
# AUC: 84.98 Precision: 84.58 Recall: 84.94
#
# -----mlp - Validation-----
# AUC: 89.58 Precision: 88.00 Recall: 91.67
#
# -----lr - Train----------
# AUC: 78.18 Precision: 78.06 Recall: 77.41
#
# -----lr - Validation-----
# AUC: 72.92 Precision: 76.19 Recall: 66.67
#
# -----nusvc - Train----------
# AUC: 89.75 Precision: 87.65 Recall: 92.05
#
# -----nusvc - Validation-----
# AUC: 77.08 Precision: 76.00 Recall: 79.17
#
# Fold 11
#
# -----qda - Train----------
# AUC: 96.92 Precision: 96.68 Recall: 97.08
#
# -----qda - Validation-----
# AUC: 97.83 Precision: 100.00 Recall: 95.65
#
# -----knn - Train----------
# AUC: 86.19 Precision: 88.79 Recall: 82.50
#
# -----knn - Validation-----
# AUC: 89.40 Precision: 87.50 Recall: 91.30
#
# -----mlp - Train----------
# AUC: 85.90 Precision: 82.51 Recall: 90.42
#
# -----mlp - Validation-----
# AUC: 76.99 Precision: 68.75 Recall: 95.65
#
# -----lr - Train----------
# AUC: 80.68 Precision: 80.93 Recall: 79.58
#
# -----lr - Validation-----
# AUC: 66.12 Precision: 62.96 Recall: 73.91
#
# -----nusvc - Train----------
# AUC: 90.36 Precision: 89.71 Recall: 90.83
#
# -----nusvc - Validation-----
# AUC: 80.98 Precision: 76.92 Recall: 86.96
#
# wheezy-copper-turtle-magic 1
#
# Fold 1
#
# -----qda - Train----------
# AUC: 96.60 Precision: 94.81 Recall: 98.21
#
# -----qda - Validation-----
# AUC: 91.58 Precision: 88.00 Recall: 95.65
#
# -----knn - Train----------
# AUC: 90.85 Precision: 87.19 Recall: 94.62
#
# -----knn - Validation-----
# AUC: 85.33 Precision: 78.57 Recall: 95.65
#
# -----mlp - Train----------
# AUC: 86.08 Precision: 87.32 Recall: 83.41
#
# -----mlp - Validation-----
# AUC: 74.28 Precision: 78.95 Recall: 65.22
#
# -----lr - Train----------
# AUC: 83.55 Precision: 83.26 Recall: 82.51
#
# -----lr - Validation-----
# AUC: 74.46 Precision: 73.91 Recall: 73.91
#
# -----nusvc - Train----------
# AUC: 89.63 Precision: 88.89 Recall: 89.69
#
# -----nusvc - Validation-----
# AUC: 78.71 Precision: 78.26 Recall: 78.26
#
# Fold 2
#
# -----qda - Train----------
# AUC: 96.17 Precision: 94.37 Recall: 97.76
#
# -----qda - Validation-----
# AUC: 97.83 Precision: 100.00 Recall: 95.65
#
# -----knn - Train----------
# AUC: 89.81 Precision: 85.43 Recall: 94.62
#
# -----knn - Validation-----
# AUC: 93.66 Precision: 91.67 Recall: 95.65
#
# -----mlp - Train----------
# AUC: 85.21 Precision: 86.38 Recall: 82.51
#
# -----mlp - Validation-----
# AUC: 85.14 Precision: 83.33 Recall: 86.96
#
# -----lr - Train----------
# AUC: 83.76 Precision: 83.64 Recall: 82.51
#
# -----lr - Validation-----
# AUC: 80.89 Precision: 79.17 Recall: 82.61
#
# -----nusvc - Train----------
# AUC: 90.48 Precision: 90.13 Recall: 90.13
#
# -----nusvc - Validation-----
# AUC: 89.31 Precision: 90.91 Recall: 86.96
#
# Fold 3
#
# -----qda - Train----------
# AUC: 96.60 Precision: 94.81 Recall: 98.21
#
# -----qda - Validation-----
# AUC: 93.57 Precision: 95.45 Recall: 91.30
#
# -----knn - Train----------
# AUC: 90.43 Precision: 86.48 Recall: 94.62
#
# -----knn - Validation-----
# AUC: 91.58 Precision: 88.00 Recall: 95.65
#
# -----mlp - Train----------
# AUC: 82.52 Precision: 85.57 Recall: 77.13
#
# -----mlp - Validation-----
# AUC: 89.31 Precision: 90.91 Recall: 86.96
#
# -----lr - Train----------
# AUC: 83.05 Precision: 84.04 Recall: 80.27
#
# -----lr - Validation-----
# AUC: 87.23 Precision: 86.96 Recall: 86.96
#
# -----nusvc - Train----------
# AUC: 88.93 Precision: 89.45 Recall: 87.44
#
# -----nusvc - Validation-----
# AUC: 91.49 Precision: 91.30 Recall: 91.30
#
# Fold 4
#
# -----qda - Train----------
# AUC: 96.60 Precision: 94.81 Recall: 98.21
#
# -----qda - Validation-----
# AUC: 89.49 Precision: 84.62 Recall: 95.65
#
# -----knn - Train----------
# AUC: 91.00 Precision: 88.84 Recall: 92.83
#
# -----knn - Validation-----
# AUC: 87.41 Precision: 81.48 Recall: 95.65
#
# -----mlp - Train----------
# AUC: 85.65 Precision: 86.85 Recall: 82.96
#
# -----mlp - Validation-----
# AUC: 81.16 Precision: 73.33 Recall: 95.65
#
# -----lr - Train----------
# AUC: 84.17 Precision: 84.40 Recall: 82.51
#
# -----lr - Validation-----
# AUC: 78.89 Precision: 74.07 Recall: 86.96
#
# -----nusvc - Train----------
# AUC: 90.92 Precision: 90.58 Recall: 90.58
#
# -----nusvc - Validation-----
# AUC: 83.15 Precision: 77.78 Recall: 91.30
#
# Fold 5
#
# -----qda - Train----------
# AUC: 96.61 Precision: 94.83 Recall: 98.21
#
# -----qda - Validation-----
# AUC: 89.20 Precision: 86.96 Recall: 90.91
#
# -----knn - Train----------
# AUC: 90.65 Precision: 86.89 Recall: 94.64
#
# -----knn - Validation-----
# AUC: 91.48 Precision: 87.50 Recall: 95.45
#
# -----mlp - Train----------
# AUC: 86.59 Precision: 86.82 Recall: 85.27
#
# -----mlp - Validation-----
# AUC: 82.01 Precision: 93.75 Recall: 68.18
#
# -----lr - Train----------
# AUC: 84.05 Precision: 83.19 Recall: 83.93
#
# -----lr - Validation-----
# AUC: 77.84 Precision: 83.33 Recall: 68.18
#
# -----nusvc - Train----------
# AUC: 89.30 Precision: 86.86 Recall: 91.52
#
# -----nusvc - Validation-----
# AUC: 78.03 Precision: 80.00 Recall: 72.73
#
# Fold 6
#
# -----qda - Train----------
# AUC: 96.40 Precision: 94.42 Recall: 98.21
#
# -----qda - Validation-----
# AUC: 91.10 Precision: 95.00 Recall: 86.36
#
# -----knn - Train----------
# AUC: 91.09 Precision: 87.30 Recall: 95.09
#
# -----knn - Validation-----
# AUC: 86.93 Precision: 86.36 Recall: 86.36
#
# -----mlp - Train----------
# AUC: 86.32 Precision: 87.79 Recall: 83.48
#
# -----mlp - Validation-----
# AUC: 75.76 Precision: 78.95 Recall: 68.18
#
# -----lr - Train----------
# AUC: 83.14 Precision: 83.18 Recall: 81.70
#
# -----lr - Validation-----
# AUC: 73.86 Precision: 72.73 Recall: 72.73
#
# -----nusvc - Train----------
# AUC: 91.16 Precision: 90.67 Recall: 91.07
#
# -----nusvc - Validation-----
# AUC: 80.30 Precision: 80.95 Recall: 77.27
#
# Fold 7
#
# -----qda - Train----------
# AUC: 97.02 Precision: 95.65 Recall: 98.21
#
# -----qda - Validation-----
# AUC: 82.77 Precision: 79.17 Recall: 86.36
#
# -----knn - Train----------
# AUC: 90.39 Precision: 87.76 Recall: 92.86
#
# -----knn - Validation-----
# AUC: 91.48 Precision: 87.50 Recall: 95.45
#
# -----mlp - Train----------
# AUC: 83.93 Precision: 85.71 Recall: 80.36
#
# -----mlp - Validation-----
# AUC: 88.83 Precision: 94.74 Recall: 81.82
#
# -----lr - Train----------
# AUC: 82.07 Precision: 81.90 Recall: 80.80
#
# -----lr - Validation-----
# AUC: 91.48 Precision: 87.50 Recall: 95.45
#
# -----nusvc - Train----------
# AUC: 90.39 Precision: 87.76 Recall: 92.86
#
# -----nusvc - Validation-----
# AUC: 84.85 Precision: 82.61 Recall: 86.36
#
# Fold 8
#
# -----qda - Train----------
# AUC: 96.85 Precision: 94.47 Recall: 99.11
#
# -----qda - Validation-----
# AUC: 95.64 Precision: 95.45 Recall: 95.45
#
# -----knn - Train----------
# AUC: 90.83 Precision: 87.87 Recall: 93.75
#
# -----knn - Validation-----
# AUC: 87.31 Precision: 80.77 Recall: 95.45
#
# -----mlp - Train----------
# AUC: 84.85 Precision: 80.97 Recall: 89.29
#
# -----mlp - Validation-----
# AUC: 84.66 Precision: 85.71 Recall: 81.82
#
# -----lr - Train----------
# AUC: 82.02 Precision: 82.79 Recall: 79.46
#
# -----lr - Validation-----
# AUC: 82.39 Precision: 85.00 Recall: 77.27
#
# -----nusvc - Train----------
# AUC: 90.25 Precision: 90.87 Recall: 88.84
#
# -----nusvc - Validation-----
# AUC: 86.74 Precision: 90.00 Recall: 81.82
#
# Fold 9
#
# -----qda - Train----------
# AUC: 96.61 Precision: 94.83 Recall: 98.21
#
# -----qda - Validation-----
# AUC: 89.02 Precision: 90.48 Recall: 86.36
#
# -----knn - Train----------
# AUC: 92.53 Precision: 90.21 Recall: 94.64
#
# -----knn - Validation-----
# AUC: 80.68 Precision: 76.00 Recall: 86.36
#
# -----mlp - Train----------
# AUC: 87.57 Precision: 85.17 Recall: 89.73
#
# -----mlp - Validation-----
# AUC: 67.61 Precision: 64.00 Recall: 72.73
#
# -----lr - Train----------
# AUC: 84.42 Precision: 84.86 Recall: 82.59
#
# -----lr - Validation-----
# AUC: 60.98 Precision: 58.33 Recall: 63.64
#
# -----nusvc - Train----------
# AUC: 89.57 Precision: 91.12 Recall: 87.05
#
# -----nusvc - Validation-----
# AUC: 69.89 Precision: 65.38 Recall: 77.27
#
# Fold 10
#
# -----qda - Train----------
# AUC: 97.05 Precision: 94.87 Recall: 99.11
#
# -----qda - Validation-----
# AUC: 95.83 Precision: 91.67 Recall: 100.00
#
# -----knn - Train----------
# AUC: 90.65 Precision: 86.89 Recall: 94.64
#
# -----knn - Validation-----
# AUC: 93.56 Precision: 91.30 Recall: 95.45
#
# -----mlp - Train----------
# AUC: 85.71 Precision: 86.24 Recall: 83.93
#
# -----mlp - Validation-----
# AUC: 89.02 Precision: 90.48 Recall: 86.36
#
# -----lr - Train----------
# AUC: 83.12 Precision: 83.49 Recall: 81.25
#
# -----lr - Validation-----
# AUC: 89.02 Precision: 90.48 Recall: 86.36
#
# -----nusvc - Train----------
# AUC: 90.55 Precision: 89.13 Recall: 91.52
#
# -----nusvc - Validation-----
# AUC: 91.29 Precision: 90.91 Recall: 90.91
#
# Fold 11
#
# -----qda - Train----------
# AUC: 96.61 Precision: 94.83 Recall: 98.21
#
# -----qda - Validation-----
# AUC: 93.37 Precision: 95.24 Recall: 90.91
#
# -----knn - Train----------
# AUC: 90.43 Precision: 86.83 Recall: 94.20
#
# -----knn - Validation-----
# AUC: 82.77 Precision: 79.17 Recall: 86.36
#
# -----mlp - Train----------
# AUC: 84.85 Precision: 85.32 Recall: 83.04
#
# -----mlp - Validation-----
# AUC: 82.01 Precision: 93.75 Recall: 68.18
#
# -----lr - Train----------
# AUC: 82.69 Precision: 83.03 Recall: 80.80
#
# -----lr - Validation-----
# AUC: 79.92 Precision: 88.24 Recall: 68.18
#
# -----nusvc - Train----------
# AUC: 89.09 Precision: 86.50 Recall: 91.52
#
# -----nusvc - Validation-----
# AUC: 84.28 Precision: 94.12 Recall: 72.73
#
# wheezy-copper-turtle-magic 2
#
# Fold 1
#
# -----qda - Train----------
# AUC: 97.55 Precision: 97.29 Recall: 97.73
#
# -----qda - Validation-----
# AUC: 95.65 Precision: 95.65 Recall: 95.65
#
# -----knn - Train----------
# AUC: 88.12 Precision: 91.13 Recall: 84.09
#
# -----knn - Validation-----
# AUC: 86.96 Precision: 94.74 Recall: 78.26
#
# -----mlp - Train----------
# AUC: 82.43 Precision: 81.06 Recall: 83.64
#
# -----mlp - Validation-----
# AUC: 71.74 Precision: 77.78 Recall: 60.87
#
# -----lr - Train----------
# AUC: 76.88 Precision: 75.00 Recall: 79.09
#
# -----lr - Validation-----
# AUC: 71.74 Precision: 77.78 Recall: 60.87
#
# -----nusvc - Train----------
# AUC: 89.40 Precision: 85.54 Recall: 94.09
#
# -----nusvc - Validation-----
# AUC: 82.61 Precision: 80.00 Recall: 86.96
#
# Fold 2
#
# -----qda - Train----------
# AUC: 97.34 Precision: 96.86 Recall: 97.74
#
# -----qda - Validation-----
# AUC: 95.55 Precision: 95.45 Recall: 95.45
#
# -----knn - Train----------
# AUC: 87.90 Precision: 92.39 Recall: 82.35
#
# -----knn - Validation-----
# AUC: 84.19 Precision: 94.12 Recall: 72.73
#
# -----mlp - Train----------
# AUC: 82.72 Precision: 80.17 Recall: 85.97
#
# -----mlp - Validation-----
# AUC: 75.40 Precision: 78.95 Recall: 68.18
#
# -----lr - Train----------
# AUC: 76.92 Precision: 75.32 Recall: 78.73
#
# -----lr - Validation-----
# AUC: 73.22 Precision: 75.00 Recall: 68.18
#
# -----nusvc - Train----------
# AUC: 89.79 Precision: 88.89 Recall: 90.50
#
# -----nusvc - Validation-----
# AUC: 77.57 Precision: 83.33 Recall: 68.18
#
# Fold 3
#
# -----qda - Train----------
# AUC: 98.23 Precision: 97.76 Recall: 98.64
#
# -----qda - Validation-----
# AUC: 88.83 Precision: 90.48 Recall: 86.36
#
# -----knn - Train----------
# AUC: 87.20 Precision: 93.62 Recall: 79.64
#
# -----knn - Validation-----
# AUC: 75.20 Precision: 86.67 Recall: 59.09
#
# -----mlp - Train----------
# AUC: 82.82 Precision: 84.95 Recall: 79.19
#
# -----mlp - Validation-----
# AUC: 75.49 Precision: 76.19 Recall: 72.73
#
# -----lr - Train----------
# AUC: 76.23 Precision: 75.22 Recall: 76.92
#
# -----lr - Validation-----
# AUC: 71.15 Precision: 69.57 Recall: 72.73
#
# -----nusvc - Train----------
# AUC: 89.32 Precision: 89.50 Recall: 88.69
#
# -----nusvc - Validation-----
# AUC: 84.39 Precision: 85.71 Recall: 81.82
#
# Fold 4
#
# -----qda - Train----------
# AUC: 97.33 Precision: 97.29 Recall: 97.29
#
# -----qda - Validation-----
# AUC: 93.28 Precision: 95.24 Recall: 90.91
#
# -----knn - Train----------
# AUC: 87.66 Precision: 93.23 Recall: 81.00
#
# -----knn - Validation-----
# AUC: 95.55 Precision: 95.45 Recall: 95.45
#
# -----mlp - Train----------
# AUC: 84.03 Precision: 82.25 Recall: 85.97
#
# -----mlp - Validation-----
# AUC: 71.15 Precision: 69.57 Recall: 72.73
#
# -----lr - Train----------
# AUC: 76.48 Precision: 74.89 Recall: 78.28
#
# -----lr - Validation-----
# AUC: 71.25 Precision: 68.00 Recall: 77.27
#
# -----nusvc - Train----------
# AUC: 90.90 Precision: 90.18 Recall: 91.40
#
# -----nusvc - Validation-----
# AUC: 71.15 Precision: 69.57 Recall: 72.73
#
# Fold 5
#
# -----qda - Train----------
# AUC: 97.78 Precision: 97.74 Recall: 97.74
#
# -----qda - Validation-----
# AUC: 91.21 Precision: 87.50 Recall: 95.45
#
# -----knn - Train----------
# AUC: 88.81 Precision: 92.12 Recall: 84.62
#
# -----knn - Validation-----
# AUC: 77.57 Precision: 83.33 Recall: 68.18
#
# -----mlp - Train----------
# AUC: 82.88 Precision: 82.73 Recall: 82.35
#
# -----mlp - Validation-----
# AUC: 68.77 Precision: 70.00 Recall: 63.64
#
# -----lr - Train----------
# AUC: 76.47 Precision: 75.11 Recall: 77.83
#
# -----lr - Validation-----
# AUC: 68.97 Precision: 66.67 Recall: 72.73
#
# -----nusvc - Train----------
# AUC: 90.67 Precision: 90.13 Recall: 90.95
#
# -----nusvc - Validation-----
# AUC: 75.59 Precision: 73.91 Recall: 77.27
#
# Fold 6
#
# -----qda - Train----------
# AUC: 98.44 Precision: 98.64 Recall: 98.19
#
# -----qda - Validation-----
# AUC: 88.93 Precision: 86.96 Recall: 90.91
#
# -----knn - Train----------
# AUC: 89.70 Precision: 93.53 Recall: 85.07
#
# -----knn - Validation-----
# AUC: 73.42 Precision: 70.83 Recall: 77.27
#
# -----mlp - Train----------
# AUC: 80.81 Precision: 83.25 Recall: 76.47
#
# -----mlp - Validation-----
# AUC: 73.42 Precision: 70.83 Recall: 77.27
#
# -----lr - Train----------
# AUC: 76.00 Precision: 75.34 Recall: 76.02
#
# -----lr - Validation-----
# AUC: 64.62 Precision: 61.54 Recall: 72.73
#
# -----nusvc - Train----------
# AUC: 91.54 Precision: 92.17 Recall: 90.50
#
# -----nusvc - Validation-----
# AUC: 75.79 Precision: 70.37 Recall: 86.36
#
# Fold 7
#
# -----qda - Train----------
# AUC: 97.11 Precision: 96.85 Recall: 97.29
#
# -----qda - Validation-----
# AUC: 95.65 Precision: 91.67 Recall: 100.00
#
# -----knn - Train----------
# AUC: 87.21 Precision: 92.71 Recall: 80.54
#
# -----knn - Validation-----
# AUC: 79.84 Precision: 84.21 Recall: 72.73
#
# -----mlp - Train----------
# AUC: 83.75 Precision: 84.26 Recall: 82.35
#
# -----mlp - Validation-----
# AUC: 75.59 Precision: 73.91 Recall: 77.27
#
# -----lr - Train----------
# AUC: 76.91 Precision: 75.77 Recall: 77.83
#
# -----lr - Validation-----
# AUC: 66.60 Precision: 66.67 Recall: 63.64
#
# -----nusvc - Train----------
# AUC: 90.26 Precision: 88.31 Recall: 92.31
#
# -----nusvc - Validation-----
# AUC: 75.59 Precision: 73.91 Recall: 77.27
#
# Fold 8
#
# -----qda - Train----------
# AUC: 97.34 Precision: 96.86 Recall: 97.74
#
# -----qda - Validation-----
# AUC: 93.28 Precision: 95.24 Recall: 90.91
#
# -----knn - Train----------
# AUC: 86.08 Precision: 92.51 Recall: 78.28
#
# -----knn - Validation-----
# AUC: 88.64 Precision: 100.00 Recall: 77.27
#
# -----mlp - Train----------
# AUC: 82.94 Precision: 80.51 Recall: 85.97
#
# -----mlp - Validation-----
# AUC: 84.39 Precision: 85.71 Recall: 81.82
#
# -----lr - Train----------
# AUC: 74.90 Precision: 73.89 Recall: 75.57
#
# -----lr - Validation-----
# AUC: 84.39 Precision: 85.71 Recall: 81.82
#
# -----nusvc - Train----------
# AUC: 89.73 Precision: 91.87 Recall: 86.88
#
# -----nusvc - Validation-----
# AUC: 88.74 Precision: 94.74 Recall: 81.82
#
# Fold 9
#
# -----qda - Train----------
# AUC: 98.02 Precision: 96.90 Recall: 99.10
#
# -----qda - Validation-----
# AUC: 93.18 Precision: 100.00 Recall: 86.36
#
# -----knn - Train----------
# AUC: 85.64 Precision: 91.98 Recall: 77.83
#
# -----knn - Validation-----
# AUC: 84.29 Precision: 89.47 Recall: 77.27
#
# -----mlp - Train----------
# AUC: 80.84 Precision: 81.99 Recall: 78.28
#
# -----mlp - Validation-----
# AUC: 73.32 Precision: 72.73 Recall: 72.73
#
# -----lr - Train----------
# AUC: 75.98 Precision: 75.80 Recall: 75.11
#
# -----lr - Validation-----
# AUC: 71.34 Precision: 66.67 Recall: 81.82
#
# -----nusvc - Train----------
# AUC: 89.54 Precision: 89.91 Recall: 88.69
#
# -----nusvc - Validation-----
# AUC: 77.87 Precision: 75.00 Recall: 81.82
#
# Fold 10
#
# -----qda - Train----------
# AUC: 97.55 Precision: 97.73 Recall: 97.29
#
# -----qda - Validation-----
# AUC: 97.83 Precision: 95.65 Recall: 100.00
#
# -----knn - Train----------
# AUC: 85.62 Precision: 92.90 Recall: 76.92
#
# -----knn - Validation-----
# AUC: 75.30 Precision: 82.35 Recall: 63.64
#
# -----mlp - Train----------
# AUC: 83.77 Precision: 83.64 Recall: 83.26
#
# -----mlp - Validation-----
# AUC: 75.59 Precision: 73.91 Recall: 77.27
#
# -----lr - Train----------
# AUC: 77.58 Precision: 76.09 Recall: 79.19
#
# -----lr - Validation-----
# AUC: 71.05 Precision: 71.43 Recall: 68.18
#
# -----nusvc - Train----------
# AUC: 90.43 Precision: 90.83 Recall: 89.59
#
# -----nusvc - Validation-----
# AUC: 75.69 Precision: 72.00 Recall: 81.82
#
# Fold 11
#
# -----qda - Train----------
# AUC: 97.12 Precision: 96.85 Recall: 97.29
#
# -----qda - Validation-----
# AUC: 93.18 Precision: 91.30 Recall: 95.45
#
# -----knn - Train----------
# AUC: 87.26 Precision: 91.00 Recall: 82.35
#
# -----knn - Validation-----
# AUC: 81.82 Precision: 85.00 Recall: 77.27
#
# -----mlp - Train----------
# AUC: 82.58 Precision: 79.10 Recall: 87.33
#
# -----mlp - Validation-----
# AUC: 79.55 Precision: 76.00 Recall: 86.36
#
# -----lr - Train----------
# AUC: 75.63 Precision: 74.45 Recall: 76.47
#
# -----lr - Validation-----
# AUC: 72.73 Precision: 70.83 Recall: 77.27
#
# -----nusvc - Train----------
# AUC: 90.31 Precision: 87.34 Recall: 93.67
#
# -----nusvc - Validation-----
# AUC: 81.82 Precision: 76.92 Recall: 90.91
#
# wheezy-copper-turtle-magic 3
#
# Fold 1
#
# -----qda - Train----------
# AUC: 98.36 Precision: 98.43 Recall: 98.43
#
# -----qda - Validation-----
# AUC: 98.08 Precision: 100.00 Recall: 96.15
#
# -----knn - Train----------
# AUC: 83.23 Precision: 78.03 Recall: 96.08
#
# -----knn - Validation-----
# AUC: 79.17 Precision: 72.22 Recall: 100.00
#
# -----mlp - Train----------
# AUC: 83.05 Precision: 82.40 Recall: 86.27
#
# -----mlp - Validation-----
# AUC: 74.04 Precision: 76.00 Recall: 73.08
#
# -----lr - Train----------
# AUC: 74.82 Precision: 74.72 Recall: 78.82
#
# -----lr - Validation-----
# AUC: 68.27 Precision: 72.73 Recall: 61.54
#
# -----nusvc - Train----------
# AUC: 90.13 Precision: 90.27 Recall: 90.98
#
# -----nusvc - Validation-----
# AUC: 86.06 Precision: 88.00 Recall: 84.62
#
# Fold 2
#
# -----qda - Train----------
# AUC: 98.77 Precision: 98.82 Recall: 98.82
#
# -----qda - Validation-----
# AUC: 93.91 Precision: 92.59 Recall: 96.15
#
# -----knn - Train----------
# AUC: 84.46 Precision: 78.98 Recall: 97.25
#
# -----knn - Validation-----
# AUC: 83.49 Precision: 78.12 Recall: 96.15
#
# -----mlp - Train----------
# AUC: 80.89 Precision: 81.64 Recall: 81.96
#
# -----mlp - Validation-----
# AUC: 67.63 Precision: 66.67 Recall: 76.92
#
# -----lr - Train----------
# AUC: 75.87 Precision: 75.94 Recall: 79.22
#
# -----lr - Validation-----
# AUC: 65.54 Precision: 64.52 Recall: 76.92
#
# -----nusvc - Train----------
# AUC: 91.53 Precision: 91.15 Recall: 92.94
#
# -----nusvc - Validation-----
# AUC: 75.48 Precision: 71.88 Recall: 88.46
#
# Fold 3
#
# -----qda - Train----------
# AUC: 98.39 Precision: 99.20 Recall: 97.65
#
# -----qda - Validation-----
# AUC: 94.07 Precision: 96.00 Recall: 92.31
#
# -----knn - Train----------
# AUC: 85.81 Precision: 81.13 Recall: 96.08
#
# -----knn - Validation-----
# AUC: 79.33 Precision: 73.53 Recall: 96.15
#
# -----mlp - Train----------
# AUC: 80.57 Precision: 79.93 Recall: 84.31
#
# -----mlp - Validation-----
# AUC: 65.54 Precision: 64.52 Recall: 76.92
#
# -----lr - Train----------
# AUC: 75.70 Precision: 76.05 Recall: 78.43
#
# -----lr - Validation-----
# AUC: 63.62 Precision: 63.33 Recall: 73.08
#
# -----nusvc - Train----------
# AUC: 90.41 Precision: 88.56 Recall: 94.12
#
# -----nusvc - Validation-----
# AUC: 75.64 Precision: 73.33 Recall: 84.62
#
# Fold 4
#
# -----qda - Train----------
# AUC: 98.18 Precision: 98.81 Recall: 97.65
#
# -----qda - Validation-----
# AUC: 93.75 Precision: 89.66 Recall: 100.00
#
# -----knn - Train----------
# AUC: 83.23 Precision: 78.03 Recall: 96.08
#
# -----knn - Validation-----
# AUC: 85.42 Precision: 78.79 Recall: 100.00
#
# -----mlp - Train----------
# AUC: 82.34 Precision: 83.14 Recall: 83.14
#
# -----mlp - Validation-----
# AUC: 80.45 Precision: 90.00 Recall: 69.23
#
# -----lr - Train----------
# AUC: 75.03 Precision: 75.00 Recall: 78.82
#
# -----lr - Validation-----
# AUC: 72.28 Precision: 77.27 Recall: 65.38
#
# -----nusvc - Train----------
# AUC: 90.79 Precision: 91.67 Recall: 90.59
#
# -----nusvc - Validation-----
# AUC: 82.21 Precision: 86.96 Recall: 76.92
#
# Fold 5
#
# -----qda - Train----------
# AUC: 98.40 Precision: 99.20 Recall: 97.65
#
# -----qda - Validation-----
# AUC: 87.46 Precision: 85.71 Recall: 92.31
#
# -----knn - Train----------
# AUC: 85.41 Precision: 80.39 Recall: 96.47
#
# -----knn - Validation-----
# AUC: 78.26 Precision: 72.22 Recall: 100.00
#
# -----mlp - Train----------
# AUC: 82.37 Precision: 80.36 Recall: 88.24
#
# -----mlp - Validation-----
# AUC: 66.72 Precision: 66.67 Recall: 76.92
#
# -----lr - Train----------
# AUC: 75.31 Precision: 75.28 Recall: 78.82
#
# -----lr - Validation-----
# AUC: 66.97 Precision: 67.86 Recall: 73.08
#
# -----nusvc - Train----------
# AUC: 91.01 Precision: 88.41 Recall: 95.69
#
# -----nusvc - Validation-----
# AUC: 72.24 Precision: 68.57 Recall: 92.31
#
# Fold 6
#
# -----qda - Train----------
# AUC: 98.18 Precision: 98.81 Recall: 97.65
#
# -----qda - Validation-----
# AUC: 95.90 Precision: 96.15 Recall: 96.15
#
# -----knn - Train----------
# AUC: 84.15 Precision: 79.03 Recall: 96.08
#
# -----knn - Validation-----
# AUC: 86.96 Precision: 81.25 Recall: 100.00
#
# -----mlp - Train----------
# AUC: 81.67 Precision: 83.95 Recall: 80.00
#
# -----mlp - Validation-----
# AUC: 83.61 Precision: 84.62 Recall: 84.62
#
# -----lr - Train----------
# AUC: 75.06 Precision: 74.63 Recall: 79.61
#
# -----lr - Validation-----
# AUC: 77.09 Precision: 75.86 Recall: 84.62
#
# -----nusvc - Train----------
# AUC: 90.03 Precision: 88.19 Recall: 93.73
#
# -----nusvc - Validation-----
# AUC: 87.71 Precision: 88.46 Recall: 88.46
#
# Fold 7
#
# -----qda - Train----------
# AUC: 98.60 Precision: 99.21 Recall: 98.05
#
# -----qda - Validation-----
# AUC: 91.83 Precision: 95.65 Recall: 88.00
#
# -----knn - Train----------
# AUC: 84.80 Precision: 79.87 Recall: 96.09
#
# -----knn - Validation-----
# AUC: 80.61 Precision: 75.00 Recall: 96.00
#
# -----mlp - Train----------
# AUC: 81.60 Precision: 82.42 Recall: 82.42
#
# -----mlp - Validation-----
# AUC: 68.96 Precision: 72.73 Recall: 64.00
#
# -----lr - Train----------
# AUC: 74.69 Precision: 74.36 Recall: 79.30
#
# -----lr - Validation-----
# AUC: 66.78 Precision: 69.57 Recall: 64.00
#
# -----nusvc - Train----------
# AUC: 90.52 Precision: 89.77 Recall: 92.58
#
# -----nusvc - Validation-----
# AUC: 75.13 Precision: 78.26 Recall: 72.00
#
# Fold 8
#
# -----qda - Train----------
# AUC: 98.15 Precision: 98.05 Recall: 98.44
#
# -----qda - Validation-----
# AUC: 93.83 Precision: 95.83 Recall: 92.00
#
# -----knn - Train----------
# AUC: 84.53 Precision: 79.05 Recall: 97.27
#
# -----knn - Validation-----
# AUC: 85.13 Precision: 82.14 Recall: 92.00
#
# -----mlp - Train----------
# AUC: 82.96 Precision: 82.89 Recall: 85.16
#
# -----mlp - Validation-----
# AUC: 79.13 Precision: 80.00 Recall: 80.00
#
# -----lr - Train----------
# AUC: 75.14 Precision: 75.09 Recall: 78.91
#
# -----lr - Validation-----
# AUC: 72.78 Precision: 73.08 Recall: 76.00
#
# -----nusvc - Train----------
# AUC: 89.24 Precision: 87.78 Recall: 92.58
#
# -----nusvc - Validation-----
# AUC: 83.48 Precision: 86.96 Recall: 80.00
#
# Fold 9
#
# -----qda - Train----------
# AUC: 98.58 Precision: 98.82 Recall: 98.44
#
# -----qda - Validation-----
# AUC: 89.83 Precision: 95.45 Recall: 84.00
#
# -----knn - Train----------
# AUC: 84.82 Precision: 80.07 Recall: 95.70
#
# -----knn - Validation-----
# AUC: 74.26 Precision: 69.70 Recall: 92.00
#
# -----mlp - Train----------
# AUC: 83.30 Precision: 85.08 Recall: 82.42
#
# -----mlp - Validation-----
# AUC: 72.78 Precision: 73.08 Recall: 76.00
#
# -----lr - Train----------
# AUC: 75.17 Precision: 75.47 Recall: 78.12
#
# -----lr - Validation-----
# AUC: 68.61 Precision: 69.23 Recall: 72.00
#
# -----nusvc - Train----------
# AUC: 91.31 Precision: 93.47 Recall: 89.45
#
# -----nusvc - Validation-----
# AUC: 72.96 Precision: 75.00 Recall: 72.00
#
# Fold 10
#
# -----qda - Train----------
# AUC: 98.61 Precision: 99.60 Recall: 97.66
#
# -----qda - Validation-----
# AUC: 91.83 Precision: 95.65 Recall: 88.00
#
# -----knn - Train----------
# AUC: 85.69 Precision: 81.33 Recall: 95.31
#
# -----knn - Validation-----
# AUC: 87.30 Precision: 85.19 Recall: 92.00
#
# -----mlp - Train----------
# AUC: 78.46 Precision: 78.71 Recall: 80.86
#
# -----mlp - Validation-----
# AUC: 76.96 Precision: 76.92 Recall: 80.00
#
# -----lr - Train----------
# AUC: 74.20 Precision: 75.00 Recall: 76.17
#
# -----lr - Validation-----
# AUC: 78.78 Precision: 75.86 Recall: 88.00
#
# -----nusvc - Train----------
# AUC: 88.85 Precision: 87.69 Recall: 91.80
#
# -----nusvc - Validation-----
# AUC: 83.13 Precision: 81.48 Recall: 88.00
#
# Fold 11
#
# -----qda - Train----------
# AUC: 98.17 Precision: 98.43 Recall: 98.05
#
# -----qda - Validation-----
# AUC: 85.30 Precision: 84.62 Recall: 88.00
#
# -----knn - Train----------
# AUC: 85.38 Precision: 80.06 Recall: 97.27
#
# -----knn - Validation-----
# AUC: 65.91 Precision: 63.64 Recall: 84.00
#
# -----mlp - Train----------
# AUC: 81.79 Precision: 82.49 Recall: 82.81
#
# -----mlp - Validation-----
# AUC: 66.61 Precision: 68.00 Recall: 68.00
#
# -----lr - Train----------
# AUC: 75.16 Precision: 75.28 Recall: 78.52
#
# -----lr - Validation-----
# AUC: 62.43 Precision: 64.00 Recall: 64.00
#
# -----nusvc - Train----------
# AUC: 89.72 Precision: 89.31 Recall: 91.41
#
# -----nusvc - Validation-----
# AUC: 76.78 Precision: 75.00 Recall: 84.00
#
# wheezy-copper-turtle-magic 4
#
# Fold 1
#
# -----qda - Train----------
# AUC: 97.45 Precision: 98.28 Recall: 96.62
#
# -----qda - Validation-----
# AUC: 87.50 Precision: 87.50 Recall: 87.50
#
# -----knn - Train----------
# AUC: 89.49 Precision: 87.30 Recall: 92.83
#
# -----knn - Validation-----
# AUC: 83.33 Precision: 80.77 Recall: 87.50
#
# -----mlp - Train----------
# AUC: 84.37 Precision: 83.06 Recall: 86.92
#
# -----mlp - Validation-----
# AUC: 85.42 Precision: 86.96 Recall: 83.33
#
# -----lr - Train----------
# AUC: 77.81 Precision: 79.56 Recall: 75.53
#
# -----lr - Validation-----
# AUC: 79.17 Precision: 81.82 Recall: 75.00
#
# -----nusvc - Train----------
# AUC: 91.02 Precision: 90.79 Recall: 91.56
#
# -----nusvc - Validation-----
# AUC: 89.58 Precision: 95.24 Recall: 83.33
#
# Fold 2
#
# -----qda - Train----------
# AUC: 96.38 Precision: 97.01 Recall: 95.78
#
# -----qda - Validation-----
# AUC: 93.75 Precision: 88.89 Recall: 100.00
#
# -----knn - Train----------
# AUC: 89.96 Precision: 90.25 Recall: 89.87
#
# -----knn - Validation-----
# AUC: 79.17 Precision: 71.88 Recall: 95.83
#
# -----mlp - Train----------
# AUC: 85.25 Precision: 85.29 Recall: 85.65
#
# -----mlp - Validation-----
# AUC: 70.83 Precision: 72.73 Recall: 66.67
#
# -----lr - Train----------
# AUC: 80.56 Precision: 81.20 Recall: 80.17
#
# -----lr - Validation-----
# AUC: 70.83 Precision: 70.83 Recall: 70.83
#
# -----nusvc - Train----------
# AUC: 90.18 Precision: 90.99 Recall: 89.45
#
# -----nusvc - Validation-----
# AUC: 75.00 Precision: 73.08 Recall: 79.17
#
# Fold 3
#
# -----qda - Train----------
# AUC: 96.38 Precision: 97.01 Recall: 95.78
#
# -----qda - Validation-----
# AUC: 89.40 Precision: 91.30 Recall: 87.50
#
# -----knn - Train----------
# AUC: 89.76 Precision: 89.21 Recall: 90.72
#
# -----knn - Validation-----
# AUC: 87.23 Precision: 87.50 Recall: 87.50
#
# -----mlp - Train----------
# AUC: 83.38 Precision: 84.12 Recall: 82.70
#
# -----mlp - Validation-----
# AUC: 78.71 Precision: 79.17 Recall: 79.17
#
# -----lr - Train----------
# AUC: 79.75 Precision: 80.34 Recall: 79.32
#
# -----lr - Validation-----
# AUC: 78.71 Precision: 79.17 Recall: 79.17
#
# -----nusvc - Train----------
# AUC: 90.19 Precision: 90.30 Recall: 90.30
#
# -----nusvc - Validation-----
# AUC: 83.15 Precision: 90.00 Recall: 75.00
#
# Fold 4
#
# -----qda - Train----------
# AUC: 96.60 Precision: 97.42 Recall: 95.78
#
# -----qda - Validation-----
# AUC: 95.83 Precision: 100.00 Recall: 91.67
#
# -----knn - Train----------
# AUC: 89.76 Precision: 89.87 Recall: 89.87
#
# -----knn - Validation-----
# AUC: 89.31 Precision: 88.00 Recall: 91.67
#
# -----mlp - Train----------
# AUC: 84.63 Precision: 83.95 Recall: 86.08
#
# -----mlp - Validation-----
# AUC: 84.96 Precision: 81.48 Recall: 91.67
#
# -----lr - Train----------
# AUC: 79.11 Precision: 79.57 Recall: 78.90
#
# -----lr - Validation-----
# AUC: 80.80 Precision: 80.00 Recall: 83.33
#
# -----nusvc - Train----------
# AUC: 90.63 Precision: 91.42 Recall: 89.87
#
# -----nusvc - Validation-----
# AUC: 80.80 Precision: 80.00 Recall: 83.33
#
# Fold 5
#
# -----qda - Train----------
# AUC: 97.02 Precision: 97.45 Recall: 96.62
#
# -----qda - Validation-----
# AUC: 91.58 Precision: 95.45 Recall: 87.50
#
# -----knn - Train----------
# AUC: 90.81 Precision: 89.75 Recall: 92.41
#
# -----knn - Validation-----
# AUC: 87.32 Precision: 90.91 Recall: 83.33
#
# -----mlp - Train----------
# AUC: 84.43 Precision: 84.17 Recall: 85.23
#
# -----mlp - Validation-----
# AUC: 76.72 Precision: 80.95 Recall: 70.83
#
# -----lr - Train----------
# AUC: 78.68 Precision: 78.90 Recall: 78.90
#
# -----lr - Validation-----
# AUC: 74.46 Precision: 75.00 Recall: 75.00
#
# -----nusvc - Train----------
# AUC: 88.88 Precision: 87.15 Recall: 91.56
#
# -----nusvc - Validation-----
# AUC: 80.89 Precision: 82.61 Recall: 79.17
#
# Fold 6
#
# -----qda - Train----------
# AUC: 97.66 Precision: 98.29 Recall: 97.05
#
# -----qda - Validation-----
# AUC: 84.96 Precision: 81.48 Recall: 91.67
#
# -----knn - Train----------
# AUC: 89.54 Precision: 88.84 Recall: 90.72
#
# -----knn - Validation-----
# AUC: 84.87 Precision: 79.31 Recall: 95.83
#
# -----mlp - Train----------
# AUC: 82.30 Precision: 82.35 Recall: 82.70
#
# -----mlp - Validation-----
# AUC: 70.20 Precision: 70.83 Recall: 70.83
#
# -----lr - Train----------
# AUC: 80.38 Precision: 80.33 Recall: 81.01
#
# -----lr - Validation-----
# AUC: 70.11 Precision: 69.23 Recall: 75.00
#
# -----nusvc - Train----------
# AUC: 89.32 Precision: 88.16 Recall: 91.14
#
# -----nusvc - Validation-----
# AUC: 84.96 Precision: 81.48 Recall: 91.67
#
# Fold 7
#
# -----qda - Train----------
# AUC: 97.45 Precision: 97.87 Recall: 97.05
#
# -----qda - Validation-----
# AUC: 87.14 Precision: 84.62 Recall: 91.67
#
# -----knn - Train----------
# AUC: 88.91 Precision: 88.70 Recall: 89.45
#
# -----knn - Validation-----
# AUC: 82.97 Precision: 83.33 Recall: 83.33
#
# -----mlp - Train----------
# AUC: 85.93 Precision: 86.38 Recall: 85.65
#
# -----mlp - Validation-----
# AUC: 78.62 Precision: 76.92 Recall: 83.33
#
# -----lr - Train----------
# AUC: 79.09 Precision: 78.84 Recall: 80.17
#
# -----lr - Validation-----
# AUC: 78.62 Precision: 76.92 Recall: 83.33
#
# -----nusvc - Train----------
# AUC: 89.99 Precision: 90.95 Recall: 89.03
#
# -----nusvc - Validation-----
# AUC: 85.05 Precision: 84.00 Recall: 87.50
#
# Fold 8
#
# -----qda - Train----------
# AUC: 97.23 Precision: 97.86 Recall: 96.62
#
# -----qda - Validation-----
# AUC: 93.57 Precision: 92.00 Recall: 95.83
#
# -----knn - Train----------
# AUC: 88.91 Precision: 89.03 Recall: 89.03
#
# -----knn - Validation-----
# AUC: 89.31 Precision: 88.00 Recall: 91.67
#
# -----mlp - Train----------
# AUC: 83.34 Precision: 81.67 Recall: 86.50
#
# -----mlp - Validation-----
# AUC: 84.87 Precision: 79.31 Recall: 95.83
#
# -----lr - Train----------
# AUC: 79.54 Precision: 80.52 Recall: 78.48
#
# -----lr - Validation-----
# AUC: 78.62 Precision: 76.92 Recall: 83.33
#
# -----nusvc - Train----------
# AUC: 89.76 Precision: 89.54 Recall: 90.30
#
# -----nusvc - Validation-----
# AUC: 82.70 Precision: 76.67 Recall: 95.83
#
# Fold 9
#
# -----qda - Train----------
# AUC: 97.45 Precision: 97.88 Recall: 97.06
#
# -----qda - Validation-----
# AUC: 97.83 Precision: 100.00 Recall: 95.65
#
# -----knn - Train----------
# AUC: 89.14 Precision: 88.80 Recall: 89.92
#
# -----knn - Validation-----
# AUC: 86.96 Precision: 84.00 Recall: 91.30
#
# -----mlp - Train----------
# AUC: 86.18 Precision: 86.81 Recall: 85.71
#
# -----mlp - Validation-----
# AUC: 78.26 Precision: 76.00 Recall: 82.61
#
# -----lr - Train----------
# AUC: 80.00 Precision: 80.51 Recall: 79.83
#
# -----lr - Validation-----
# AUC: 71.74 Precision: 72.73 Recall: 69.57
#
# -----nusvc - Train----------
# AUC: 90.24 Precision: 92.11 Recall: 88.24
#
# -----nusvc - Validation-----
# AUC: 80.43 Precision: 79.17 Recall: 82.61
#
# Fold 10
#
# -----qda - Train----------
# AUC: 97.03 Precision: 97.86 Recall: 96.22
#
# -----qda - Validation-----
# AUC: 91.30 Precision: 95.24 Recall: 86.96
#
# -----knn - Train----------
# AUC: 89.34 Precision: 88.52 Recall: 90.76
#
# -----knn - Validation-----
# AUC: 86.96 Precision: 90.48 Recall: 82.61
#
# -----mlp - Train----------
# AUC: 84.44 Precision: 83.13 Recall: 86.97
#
# -----mlp - Validation-----
# AUC: 69.57 Precision: 66.67 Recall: 78.26
#
# -----lr - Train----------
# AUC: 79.58 Precision: 80.08 Recall: 79.41
#
# -----lr - Validation-----
# AUC: 71.74 Precision: 70.83 Recall: 73.91
#
# -----nusvc - Train----------
# AUC: 90.42 Precision: 90.04 Recall: 91.18
#
# -----nusvc - Validation-----
# AUC: 80.43 Precision: 79.17 Recall: 82.61
#
# Fold 11
#
# -----qda - Train----------
# AUC: 97.46 Precision: 98.29 Recall: 96.64
#
# -----qda - Validation-----
# AUC: 91.30 Precision: 88.00 Recall: 95.65
#
# -----knn - Train----------
# AUC: 90.42 Precision: 90.38 Recall: 90.76
#
# -----knn - Validation-----
# AUC: 80.43 Precision: 79.17 Recall: 82.61
#
# -----mlp - Train----------
# AUC: 85.07 Precision: 83.60 Recall: 87.82
#
# -----mlp - Validation-----
# AUC: 67.39 Precision: 68.18 Recall: 65.22
#
# -----lr - Train----------
# AUC: 80.86 Precision: 81.62 Recall: 80.25
#
# -----lr - Validation-----
# AUC: 65.22 Precision: 66.67 Recall: 60.87
#
# -----nusvc - Train----------
# AUC: 91.70 Precision: 91.98 Recall: 91.60
#
# -----nusvc - Validation-----
# AUC: 71.74 Precision: 75.00 Recall: 65.22
#
# wheezy-copper-turtle-magic 5
#
# Fold 1
#
# -----qda - Train----------
# AUC: 97.25 Precision: 97.84 Recall: 96.60
#
# -----qda - Validation-----
# AUC: 89.58 Precision: 95.24 Recall: 83.33
#
# -----knn - Train----------
# AUC: 87.26 Precision: 94.42 Recall: 79.15
#
# -----knn - Validation-----
# AUC: 79.17 Precision: 79.17 Recall: 79.17
#
# -----mlp - Train----------
# AUC: 83.08 Precision: 83.26 Recall: 82.55
#
# -----mlp - Validation-----
# AUC: 66.67 Precision: 66.67 Recall: 66.67
#
# -----lr - Train----------
# AUC: 78.00 Precision: 78.60 Recall: 76.60
#
# -----lr - Validation-----
# AUC: 60.42 Precision: 60.00 Recall: 62.50
#
# -----nusvc - Train----------
# AUC: 89.23 Precision: 87.40 Recall: 91.49
#
# -----nusvc - Validation-----
# AUC: 72.92 Precision: 70.37 Recall: 79.17
#
# Fold 2
#
# -----qda - Train----------
# AUC: 97.88 Precision: 98.70 Recall: 97.02
#
# -----qda - Validation-----
# AUC: 81.25 Precision: 77.78 Recall: 87.50
#
# -----knn - Train----------
# AUC: 86.42 Precision: 92.96 Recall: 78.72
#
# -----knn - Validation-----
# AUC: 79.17 Precision: 85.00 Recall: 70.83
#
# -----mlp - Train----------
# AUC: 84.15 Precision: 83.33 Recall: 85.11
#
# -----mlp - Validation-----
# AUC: 81.25 Precision: 82.61 Recall: 79.17
#
# -----lr - Train----------
# AUC: 76.53 Precision: 76.72 Recall: 75.74
#
# -----lr - Validation-----
# AUC: 79.17 Precision: 81.82 Recall: 75.00
#
# -----nusvc - Train----------
# AUC: 89.01 Precision: 88.94 Recall: 88.94
#
# -----nusvc - Validation-----
# AUC: 83.33 Precision: 86.36 Recall: 79.17
#
# Fold 3
#
# -----qda - Train----------
# AUC: 97.24 Precision: 98.26 Recall: 96.17
#
# -----qda - Validation-----
# AUC: 93.75 Precision: 95.65 Recall: 91.67
#
# -----knn - Train----------
# AUC: 86.85 Precision: 92.61 Recall: 80.00
#
# -----knn - Validation-----
# AUC: 87.50 Precision: 100.00 Recall: 75.00
#
# -----mlp - Train----------
# AUC: 83.73 Precision: 82.64 Recall: 85.11
#
# -----mlp - Validation-----
# AUC: 77.08 Precision: 78.26 Recall: 75.00
#
# -----lr - Train----------
# AUC: 77.58 Precision: 77.92 Recall: 76.60
#
# -----lr - Validation-----
# AUC: 79.17 Precision: 81.82 Recall: 75.00
#
# -----nusvc - Train----------
# AUC: 87.98 Precision: 84.23 Recall: 93.19
#
# -----nusvc - Validation-----
# AUC: 79.17 Precision: 75.00 Recall: 87.50
#
# Fold 4
#
# -----qda - Train----------
# AUC: 97.24 Precision: 98.68 Recall: 95.74
#
# -----qda - Validation-----
# AUC: 93.75 Precision: 100.00 Recall: 87.50
#
# -----knn - Train----------
# AUC: 87.70 Precision: 92.34 Recall: 82.13
#
# -----knn - Validation-----
# AUC: 85.42 Precision: 90.48 Recall: 79.17
#
# -----mlp - Train----------
# AUC: 84.15 Precision: 83.33 Recall: 85.11
#
# -----mlp - Validation-----
# AUC: 75.00 Precision: 71.43 Recall: 83.33
#
# -----lr - Train----------
# AUC: 77.16 Precision: 77.97 Recall: 75.32
#
# -----lr - Validation-----
# AUC: 70.83 Precision: 69.23 Recall: 75.00
#
# -----nusvc - Train----------
# AUC: 90.05 Precision: 91.23 Recall: 88.51
#
# -----nusvc - Validation-----
# AUC: 79.17 Precision: 73.33 Recall: 91.67
#
# Fold 5
#
# -----qda - Train----------
# AUC: 97.24 Precision: 98.26 Recall: 96.17
#
# -----qda - Validation-----
# AUC: 91.67 Precision: 91.67 Recall: 91.67
#
# -----knn - Train----------
# AUC: 87.28 Precision: 92.27 Recall: 81.28
#
# -----knn - Validation-----
# AUC: 87.50 Precision: 100.00 Recall: 75.00
#
# -----mlp - Train----------
# AUC: 83.96 Precision: 80.69 Recall: 88.94
#
# -----mlp - Validation-----
# AUC: 87.50 Precision: 82.14 Recall: 95.83
#
# -----lr - Train----------
# AUC: 74.63 Precision: 74.68 Recall: 74.04
#
# -----lr - Validation-----
# AUC: 83.33 Precision: 80.77 Recall: 87.50
#
# -----nusvc - Train----------
# AUC: 87.31 Precision: 87.88 Recall: 86.38
#
# -----nusvc - Validation-----
# AUC: 89.58 Precision: 88.00 Recall: 91.67
#
# Fold 6
#
# -----qda - Train----------
# AUC: 97.66 Precision: 99.12 Recall: 96.17
#
# -----qda - Validation-----
# AUC: 93.75 Precision: 95.65 Recall: 91.67
#
# -----knn - Train----------
# AUC: 87.70 Precision: 93.17 Recall: 81.28
#
# -----knn - Validation-----
# AUC: 87.50 Precision: 100.00 Recall: 75.00
#
# -----mlp - Train----------
# AUC: 82.65 Precision: 84.00 Recall: 80.43
#
# -----mlp - Validation-----
# AUC: 72.92 Precision: 73.91 Recall: 70.83
#
# -----lr - Train----------
# AUC: 77.58 Precision: 77.92 Recall: 76.60
#
# -----lr - Validation-----
# AUC: 64.58 Precision: 65.22 Recall: 62.50
#
# -----nusvc - Train----------
# AUC: 89.85 Precision: 89.45 Recall: 90.21
#
# -----nusvc - Validation-----
# AUC: 70.83 Precision: 69.23 Recall: 75.00
#
# Fold 7
#
# -----qda - Train----------
# AUC: 97.25 Precision: 97.85 Recall: 96.61
#
# -----qda - Validation-----
# AUC: 95.65 Precision: 100.00 Recall: 91.30
#
# -----knn - Train----------
# AUC: 88.15 Precision: 95.45 Recall: 80.08
#
# -----knn - Validation-----
# AUC: 72.19 Precision: 75.00 Recall: 65.22
#
# -----mlp - Train----------
# AUC: 84.17 Precision: 85.15 Recall: 82.63
#
# -----mlp - Validation-----
# AUC: 65.85 Precision: 66.67 Recall: 60.87
#
# -----lr - Train----------
# AUC: 78.90 Precision: 79.57 Recall: 77.54
#
# -----lr - Validation-----
# AUC: 61.50 Precision: 63.16 Recall: 52.17
#
# -----nusvc - Train----------
# AUC: 88.61 Precision: 88.24 Recall: 88.98
#
# -----nusvc - Validation-----
# AUC: 76.54 Precision: 77.27 Recall: 73.91
#
# Fold 8
#
# -----qda - Train----------
# AUC: 97.25 Precision: 98.27 Recall: 96.19
#
# -----qda - Validation-----
# AUC: 93.48 Precision: 100.00 Recall: 86.96
#
# -----knn - Train----------
# AUC: 86.89 Precision: 93.50 Recall: 79.24
#
# -----knn - Validation-----
# AUC: 84.87 Precision: 94.44 Recall: 73.91
#
# -----mlp - Train----------
# AUC: 82.28 Precision: 81.67 Recall: 83.05
#
# -----mlp - Validation-----
# AUC: 72.19 Precision: 75.00 Recall: 65.22
#
# -----lr - Train----------
# AUC: 77.42 Precision: 77.45 Recall: 77.12
#
# -----lr - Validation-----
# AUC: 72.10 Precision: 77.78 Recall: 60.87
#
# -----nusvc - Train----------
# AUC: 90.30 Precision: 88.62 Recall: 92.37
#
# -----nusvc - Validation-----
# AUC: 76.45 Precision: 80.00 Recall: 69.57
#
# Fold 9
#
# -----qda - Train----------
# AUC: 97.46 Precision: 98.70 Recall: 96.19
#
# -----qda - Validation-----
# AUC: 95.83 Precision: 92.00 Recall: 100.00
#
# -----knn - Train----------
# AUC: 86.05 Precision: 91.67 Recall: 79.24
#
# -----knn - Validation-----
# AUC: 89.22 Precision: 95.00 Recall: 82.61
#
# -----mlp - Train----------
# AUC: 81.23 Precision: 80.75 Recall: 81.78
#
# -----mlp - Validation-----
# AUC: 78.80 Precision: 76.00 Recall: 82.61
#
# -----lr - Train----------
# AUC: 77.63 Precision: 78.51 Recall: 75.85
#
# -----lr - Validation-----
# AUC: 78.71 Precision: 78.26 Recall: 78.26
#
# -----nusvc - Train----------
# AUC: 89.45 Precision: 89.74 Recall: 88.98
#
# -----nusvc - Validation-----
# AUC: 81.07 Precision: 75.00 Recall: 91.30
#
# Fold 10
#
# -----qda - Train----------
# AUC: 97.89 Precision: 98.71 Recall: 97.03
#
# -----qda - Validation-----
# AUC: 82.61 Precision: 85.71 Recall: 78.26
#
# -----knn - Train----------
# AUC: 87.32 Precision: 94.00 Recall: 79.66
#
# -----knn - Validation-----
# AUC: 76.09 Precision: 83.33 Recall: 65.22
#
# -----mlp - Train----------
# AUC: 83.15 Precision: 83.62 Recall: 82.20
#
# -----mlp - Validation-----
# AUC: 84.78 Precision: 80.77 Recall: 91.30
#
# -----lr - Train----------
# AUC: 75.15 Precision: 75.88 Recall: 73.31
#
# -----lr - Validation-----
# AUC: 86.96 Precision: 84.00 Recall: 91.30
#
# -----nusvc - Train----------
# AUC: 89.89 Precision: 90.17 Recall: 89.41
#
# -----nusvc - Validation-----
# AUC: 84.78 Precision: 83.33 Recall: 86.96
#
# Fold 11
#
# -----qda - Train----------
# AUC: 97.47 Precision: 98.70 Recall: 96.19
#
# -----qda - Validation-----
# AUC: 93.48 Precision: 95.45 Recall: 91.30
#
# -----knn - Train----------
# AUC: 88.39 Precision: 92.09 Recall: 83.90
#
# -----knn - Validation-----
# AUC: 82.61 Precision: 94.12 Recall: 69.57
#
# -----mlp - Train----------
# AUC: 84.01 Precision: 82.79 Recall: 85.59
#
# -----mlp - Validation-----
# AUC: 71.74 Precision: 77.78 Recall: 60.87
#
# -----lr - Train----------
# AUC: 77.90 Precision: 77.41 Recall: 78.39
#
# -----lr - Validation-----
# AUC: 73.91 Precision: 78.95 Recall: 65.22
#
# -----nusvc - Train----------
# AUC: 88.01 Precision: 87.14 Recall: 88.98
#
# -----nusvc - Validation-----
# AUC: 69.57 Precision: 73.68 Recall: 60.87
#
# wheezy-copper-turtle-magic 6
#
# Fold 1
#
# -----qda - Train----------
# AUC: 98.30 Precision: 98.33 Recall: 98.33
#
# -----qda - Validation-----
# AUC: 93.65 Precision: 92.31 Recall: 96.00
#
# -----knn - Train----------
# AUC: 88.14 Precision: 83.88 Recall: 95.42
#
# ...
#
# -----lr - Validation-----
# AUC: 72.73 Precision: 81.25 Recall: 59.09
#
# -----nusvc - Train----------
# AUC: 90.25 Precision: 91.16 Recall: 89.09
#
# -----nusvc - Validation-----
# AUC: 81.82 Precision: 85.00 Recall: 77.27
#
# Fold 11
#
# -----qda - Train----------
# AUC: 97.51 Precision: 96.04 Recall: 99.09
#
# -----qda - Validation-----
# AUC: 95.45 Precision: 100.00 Recall: 90.91
#
# -----knn - Train----------
# AUC: 84.11 Precision: 90.76 Recall: 75.91
#
# -----knn - Validation-----
# AUC: 86.36 Precision: 94.44 Recall: 77.27
#
# -----mlp - Train----------
# AUC: 81.41 Precision: 80.80 Recall: 82.27
#
# -----mlp - Validation-----
# AUC: 68.18 Precision: 70.00 Recall: 63.64
#
# -----lr - Train----------
# AUC: 76.19 Precision: 75.11 Recall: 78.18
#
# -----lr - Validation-----
# AUC: 75.00 Precision: 76.19 Recall: 72.73
#
# -----nusvc - Train----------
# AUC: 92.29 Precision: 91.52 Recall: 93.18
#
# -----nusvc - Validation-----
# AUC: 75.00 Precision: 76.19 Recall: 72.73
#
# wheezy-copper-turtle-magic 116
#
# Fold 1
#
# -----qda - Train----------
# AUC: 98.48 Precision: 98.29 Recall: 98.71
#
# -----qda - Validation-----
# AUC: 93.57 Precision: 92.00 Recall: 95.83
#
# -----knn - Train----------
# AUC: 88.06 Precision: 87.71 Recall: 88.84
#
# -----knn - Validation-----
# AUC: 76.27 Precision: 70.97 Recall: 91.67
#
# -----mlp - Train----------
# AUC: 85.00 Precision: 83.06 Recall: 88.41
#
# -----mlp - Validation-----
# AUC: 74.18 Precision: 70.00 Recall: 87.50
#
# -----lr - Train----------
# AUC: 80.90 Precision: 80.85 Recall: 81.55
#
# -----lr - Validation-----
# AUC: 70.02 Precision: 67.86 Recall: 79.17
#
# -----nusvc - Train----------
# AUC: 89.81 Precision: 90.43 Recall: 89.27
#
# -----nusvc - Validation-----
# AUC: 76.27 Precision: 70.97 Recall: 91.67
#
# Fold 2
#
# -----qda - Train----------
# AUC: 98.47 Precision: 97.88 Recall: 99.14
#
# -----qda - Validation-----
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----knn - Train----------
# AUC: 88.50 Precision: 88.79 Recall: 88.41
#
# -----knn - Validation-----
# AUC: 85.05 Precision: 84.00 Recall: 87.50
#
# -----mlp - Train----------
# AUC: 84.82 Precision: 85.28 Recall: 84.55
#
# -----mlp - Validation-----
# AUC: 72.64 Precision: 82.35 Recall: 58.33
#
# -----lr - Train----------
# AUC: 78.94 Precision: 78.57 Recall: 80.26
#
# -----lr - Validation-----
# AUC: 70.47 Precision: 77.78 Recall: 58.33
#
# -----nusvc - Train----------
# AUC: 90.87 Precision: 89.63 Recall: 92.70
#
# -----nusvc - Validation-----
# AUC: 76.90 Precision: 88.24 Recall: 62.50
#
# Fold 3
#
# -----qda - Train----------
# AUC: 98.48 Precision: 98.29 Recall: 98.71
#
# -----qda - Validation-----
# AUC: 97.83 Precision: 96.00 Recall: 100.00
#
# -----knn - Train----------
# AUC: 86.73 Precision: 84.40 Recall: 90.56
#
# -----knn - Validation-----
# AUC: 80.80 Precision: 80.00 Recall: 83.33
#
# -----mlp - Train----------
# AUC: 85.00 Precision: 83.33 Recall: 87.98
#
# -----mlp - Validation-----
# AUC: 72.37 Precision: 73.91 Recall: 70.83
#
# -----lr - Train----------
# AUC: 80.47 Precision: 80.69 Recall: 80.69
#
# -----lr - Validation-----
# AUC: 65.94 Precision: 66.67 Recall: 66.67
#
# -----nusvc - Train----------
# AUC: 90.86 Precision: 88.98 Recall: 93.56
#
# -----nusvc - Validation-----
# AUC: 72.28 Precision: 72.00 Recall: 75.00
#
# Fold 4
#
# -----qda - Train----------
# AUC: 98.91 Precision: 98.31 Recall: 99.57
#
# -----qda - Validation-----
# AUC: 97.92 Precision: 100.00 Recall: 95.83
#
# -----knn - Train----------
# AUC: 87.86 Precision: 88.31 Recall: 87.55
#
# -----knn - Validation-----
# AUC: 87.05 Precision: 82.14 Recall: 95.83
#
# -----mlp - Train----------
# AUC: 86.96 Precision: 85.60 Recall: 89.27
#
# -----mlp - Validation-----
# AUC: 70.38 Precision: 75.00 Recall: 62.50
#
# -----lr - Train----------
# AUC: 81.78 Precision: 82.25 Recall: 81.55
#
# -----lr - Validation-----
# AUC: 70.29 Precision: 72.73 Recall: 66.67
#
# -----nusvc - Train----------
# AUC: 90.02 Precision: 90.13 Recall: 90.13
#
# -----nusvc - Validation-----
# AUC: 76.72 Precision: 80.95 Recall: 70.83
#
# Fold 5
#
# -----qda - Train----------
# AUC: 98.91 Precision: 98.31 Recall: 99.57
#
# -----qda - Validation-----
# AUC: 91.30 Precision: 95.24 Recall: 86.96
#
# -----knn - Train----------
# AUC: 87.45 Precision: 87.93 Recall: 87.18
#
# -----knn - Validation-----
# AUC: 86.96 Precision: 86.96 Recall: 86.96
#
# -----mlp - Train----------
# AUC: 84.62 Precision: 84.39 Recall: 85.47
#
# -----mlp - Validation-----
# AUC: 78.26 Precision: 76.00 Recall: 82.61
#
# -----lr - Train----------
# AUC: 81.17 Precision: 81.55 Recall: 81.20
#
# -----lr - Validation-----
# AUC: 76.09 Precision: 75.00 Recall: 78.26
#
# -----nusvc - Train----------
# AUC: 89.37 Precision: 88.38 Recall: 91.03
#
# -----nusvc - Validation-----
# AUC: 73.91 Precision: 73.91 Recall: 73.91
#
# Fold 6
#
# -----qda - Train----------
# AUC: 98.70 Precision: 98.31 Recall: 99.15
#
# -----qda - Validation-----
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----knn - Train----------
# AUC: 85.67 Precision: 83.60 Recall: 89.32
#
# -----knn - Validation-----
# AUC: 86.96 Precision: 84.00 Recall: 91.30
#
# -----mlp - Train----------
# AUC: 85.24 Precision: 83.47 Recall: 88.46
#
# -----mlp - Validation-----
# AUC: 78.26 Precision: 76.00 Recall: 82.61
#
# -----lr - Train----------
# AUC: 79.43 Precision: 79.57 Recall: 79.91
#
# -----lr - Validation-----
# AUC: 78.26 Precision: 76.00 Recall: 82.61
#
# -----nusvc - Train----------
# AUC: 88.77 Precision: 90.27 Recall: 87.18
#
# -----nusvc - Validation-----
# AUC: 80.43 Precision: 79.17 Recall: 82.61
#
# Fold 7
#
# -----qda - Train----------
# AUC: 98.70 Precision: 98.31 Recall: 99.15
#
# -----qda - Validation-----
# AUC: 89.13 Precision: 87.50 Recall: 91.30
#
# -----knn - Train----------
# AUC: 88.91 Precision: 86.17 Recall: 93.16
#
# -----knn - Validation-----
# AUC: 86.96 Precision: 90.48 Recall: 82.61
#
# -----mlp - Train----------
# AUC: 84.85 Precision: 85.34 Recall: 84.62
#
# -----mlp - Validation-----
# AUC: 73.91 Precision: 73.91 Recall: 73.91
#
# -----lr - Train----------
# AUC: 80.73 Precision: 80.85 Recall: 81.20
#
# -----lr - Validation-----
# AUC: 69.57 Precision: 66.67 Recall: 78.26
#
# -----nusvc - Train----------
# AUC: 90.46 Precision: 89.58 Recall: 91.88
#
# -----nusvc - Validation-----
# AUC: 76.09 Precision: 77.27 Recall: 73.91
#
# Fold 8
#
# -----qda - Train----------
# AUC: 98.48 Precision: 98.30 Recall: 98.72
#
# -----qda - Validation-----
# AUC: 91.30 Precision: 95.24 Recall: 86.96
#
# -----knn - Train----------
# AUC: 87.86 Precision: 87.08 Recall: 89.32
#
# -----knn - Validation-----
# AUC: 82.61 Precision: 85.71 Recall: 78.26
#
# -----mlp - Train----------
# AUC: 83.58 Precision: 85.59 Recall: 81.20
#
# -----mlp - Validation-----
# AUC: 71.74 Precision: 75.00 Recall: 65.22
#
# -----lr - Train----------
# AUC: 80.30 Precision: 80.43 Recall: 80.77
#
# -----lr - Validation-----
# AUC: 69.57 Precision: 73.68 Recall: 60.87
#
# -----nusvc - Train----------
# AUC: 89.57 Precision: 87.80 Recall: 92.31
#
# -----nusvc - Validation-----
# AUC: 71.74 Precision: 72.73 Recall: 69.57
#
# Fold 9
#
# -----qda - Train----------
# AUC: 98.70 Precision: 98.72 Recall: 98.72
#
# -----qda - Validation-----
# AUC: 93.48 Precision: 91.67 Recall: 95.65
#
# -----knn - Train----------
# AUC: 87.62 Precision: 85.83 Recall: 90.60
#
# -----knn - Validation-----
# AUC: 80.43 Precision: 81.82 Recall: 78.26
#
# -----mlp - Train----------
# AUC: 85.91 Precision: 85.06 Recall: 87.61
#
# -----mlp - Validation-----
# AUC: 80.43 Precision: 81.82 Recall: 78.26
#
# -----lr - Train----------
# AUC: 79.86 Precision: 80.00 Recall: 80.34
#
# -----lr - Validation-----
# AUC: 73.91 Precision: 73.91 Recall: 73.91
#
# -----nusvc - Train----------
# AUC: 91.11 Precision: 90.38 Recall: 92.31
#
# -----nusvc - Validation-----
# AUC: 82.61 Precision: 82.61 Recall: 82.61
#
# Fold 10
#
# -----qda - Train----------
# AUC: 98.91 Precision: 98.31 Recall: 99.57
#
# -----qda - Validation-----
# AUC: 95.45 Precision: 92.00 Recall: 100.00
#
# -----knn - Train----------
# AUC: 88.10 Precision: 87.14 Recall: 89.74
#
# -----knn - Validation-----
# AUC: 86.66 Precision: 86.96 Recall: 86.96
#
# -----mlp - Train----------
# AUC: 85.30 Precision: 84.87 Recall: 86.32
#
# -----mlp - Validation-----
# AUC: 77.67 Precision: 76.00 Recall: 82.61
#
# -----lr - Train----------
# AUC: 80.12 Precision: 79.83 Recall: 81.20
#
# -----lr - Validation-----
# AUC: 71.05 Precision: 70.83 Recall: 73.91
#
# -----nusvc - Train----------
# AUC: 89.21 Precision: 90.00 Recall: 88.46
#
# -----nusvc - Validation-----
# AUC: 84.49 Precision: 86.36 Recall: 82.61
#
# Fold 11
#
# -----qda - Train----------
# AUC: 98.70 Precision: 98.31 Recall: 99.15
#
# -----qda - Validation-----
# AUC: 93.38 Precision: 95.45 Recall: 91.30
#
# -----knn - Train----------
# AUC: 87.43 Precision: 84.92 Recall: 91.45
#
# -----knn - Validation-----
# AUC: 82.31 Precision: 85.71 Recall: 78.26
#
# -----mlp - Train----------
# AUC: 84.19 Precision: 81.82 Recall: 88.46
#
# -----mlp - Validation-----
# AUC: 70.95 Precision: 69.23 Recall: 78.26
#
# -----lr - Train----------
# AUC: 80.98 Precision: 80.67 Recall: 82.05
#
# -----lr - Validation-----
# AUC: 71.05 Precision: 70.83 Recall: 73.91
#
# -----nusvc - Train----------
# AUC: 90.06 Precision: 89.83 Recall: 90.60
#
# -----nusvc - Validation-----
# AUC: 73.22 Precision: 72.00 Recall: 78.26
#
# wheezy-copper-turtle-magic 117
#
# Fold 1
#
# -----qda - Train----------
# AUC: 97.80 Precision: 98.67 Recall: 96.96
#
# -----qda - Validation-----
# AUC: 95.83 Precision: 100.00 Recall: 91.67
#
# -----knn - Train----------
# AUC: 90.17 Precision: 88.75 Recall: 92.61
#
# -----knn - Validation-----
# AUC: 91.49 Precision: 91.67 Recall: 91.67
#
# -----mlp - Train----------
# AUC: 82.14 Precision: 80.74 Recall: 85.65
#
# -----mlp - Validation-----
# AUC: 78.62 Precision: 76.92 Recall: 83.33
#
# -----lr - Train----------
# AUC: 77.77 Precision: 78.26 Recall: 78.26
#
# -----lr - Validation-----
# AUC: 65.94 Precision: 66.67 Recall: 66.67
#
# -----nusvc - Train----------
# AUC: 92.04 Precision: 93.69 Recall: 90.43
#
# -----nusvc - Validation-----
# AUC: 85.24 Precision: 90.48 Recall: 79.17
#
# Fold 2
#
# -----qda - Train----------
# AUC: 97.82 Precision: 99.11 Recall: 96.54
#
# -----qda - Validation-----
# AUC: 91.01 Precision: 88.00 Recall: 95.65
#
# -----knn - Train----------
# AUC: 90.73 Precision: 92.00 Recall: 89.61
#
# -----knn - Validation-----
# AUC: 88.83 Precision: 87.50 Recall: 91.30
#
# -----mlp - Train----------
# AUC: 85.16 Precision: 85.04 Recall: 86.15
#
# -----mlp - Validation-----
# AUC: 79.84 Precision: 76.92 Recall: 86.96
#
# -----lr - Train----------
# AUC: 76.98 Precision: 77.49 Recall: 77.49
#
# -----lr - Validation-----
# AUC: 75.49 Precision: 75.00 Recall: 78.26
#
# -----nusvc - Train----------
# AUC: 91.57 Precision: 91.06 Recall: 92.64
#
# -----nusvc - Validation-----
# AUC: 82.11 Precision: 80.00 Recall: 86.96
#
# Fold 3
#
# -----qda - Train----------
# AUC: 98.24 Precision: 98.69 Recall: 97.84
#
# -----qda - Validation-----
# AUC: 86.76 Precision: 90.48 Recall: 82.61
#
# -----knn - Train----------
# AUC: 90.32 Precision: 92.69 Recall: 87.88
#
# -----knn - Validation-----
# AUC: 77.96 Precision: 84.21 Recall: 69.57
#
# -----mlp - Train----------
# AUC: 86.01 Precision: 85.00 Recall: 88.31
#
# -----mlp - Validation-----
# AUC: 66.80 Precision: 70.00 Recall: 60.87
#
# -----lr - Train----------
# AUC: 78.50 Precision: 78.39 Recall: 80.09
#
# -----lr - Validation-----
# AUC: 66.80 Precision: 70.00 Recall: 60.87
#
# -----nusvc - Train----------
# AUC: 91.63 Precision: 93.27 Recall: 90.04
#
# -----nusvc - Validation-----
# AUC: 69.07 Precision: 73.68 Recall: 60.87
#
# Fold 4
#
# -----qda - Train----------
# AUC: 97.37 Precision: 98.67 Recall: 96.10
#
# -----qda - Validation-----
# AUC: 97.73 Precision: 95.83 Recall: 100.00
#
# -----knn - Train----------
# AUC: 90.26 Precision: 90.48 Recall: 90.48
#
# -----knn - Validation-----
# AUC: 84.29 Precision: 80.77 Recall: 91.30
#
# -----mlp - Train----------
# AUC: 84.77 Precision: 86.49 Recall: 83.12
#
# -----mlp - Validation-----
# AUC: 73.22 Precision: 72.00 Recall: 78.26
#
# -----lr - Train----------
# AUC: 78.08 Precision: 78.45 Recall: 78.79
#
# -----lr - Validation-----
# AUC: 73.22 Precision: 72.00 Recall: 78.26
#
# -----nusvc - Train----------
# AUC: 89.81 Precision: 89.70 Recall: 90.48
#
# -----nusvc - Validation-----
# AUC: 77.47 Precision: 72.41 Recall: 91.30
#
# Fold 5
#
# -----qda - Train----------
# AUC: 97.15 Precision: 98.23 Recall: 96.10
#
# -----qda - Validation-----
# AUC: 97.83 Precision: 100.00 Recall: 95.65
#
# -----knn - Train----------
# AUC: 90.95 Precision: 92.04 Recall: 90.04
#
# -----knn - Validation-----
# AUC: 84.39 Precision: 83.33 Recall: 86.96
#
# -----mlp - Train----------
# AUC: 84.87 Precision: 83.00 Recall: 88.74
#
# -----mlp - Validation-----
# AUC: 68.58 Precision: 65.52 Recall: 82.61
#
# -----lr - Train----------
# AUC: 77.19 Precision: 77.35 Recall: 78.35
#
# -----lr - Validation-----
# AUC: 64.13 Precision: 62.07 Recall: 78.26
#
# -----nusvc - Train----------
# AUC: 92.72 Precision: 93.81 Recall: 91.77
#
# -----nusvc - Validation-----
# AUC: 73.22 Precision: 72.00 Recall: 78.26
#
# Fold 6
#
# -----qda - Train----------
# AUC: 97.81 Precision: 98.68 Recall: 96.97
#
# -----qda - Validation-----
# AUC: 93.28 Precision: 91.67 Recall: 95.65
#
# -----knn - Train----------
# AUC: 90.01 Precision: 89.41 Recall: 91.34
#
# -----knn - Validation-----
# AUC: 88.83 Precision: 87.50 Recall: 91.30
#
# -----mlp - Train----------
# AUC: 84.54 Precision: 85.78 Recall: 83.55
#
# -----mlp - Validation-----
# AUC: 82.31 Precision: 85.71 Recall: 78.26
#
# -----lr - Train----------
# AUC: 77.88 Precision: 78.85 Recall: 77.49
#
# -----lr - Validation-----
# AUC: 75.49 Precision: 75.00 Recall: 78.26
#
# -----nusvc - Train----------
# AUC: 91.83 Precision: 92.92 Recall: 90.91
#
# -----nusvc - Validation-----
# AUC: 84.39 Precision: 83.33 Recall: 86.96
#
# Fold 7
#
# -----qda - Train----------
# AUC: 98.02 Precision: 98.68 Recall: 97.40
#
# -----qda - Validation-----
# AUC: 97.73 Precision: 95.83 Recall: 100.00
#
# -----knn - Train----------
# AUC: 88.27 Precision: 88.70 Recall: 88.31
#
# -----knn - Validation-----
# AUC: 84.49 Precision: 86.36 Recall: 82.61
#
# -----mlp - Train----------
# AUC: 84.27 Precision: 84.19 Recall: 85.28
#
# -----mlp - Validation-----
# AUC: 75.69 Precision: 80.00 Recall: 69.57
#
# -----lr - Train----------
# AUC: 77.62 Precision: 77.54 Recall: 79.22
#
# -----lr - Validation-----
# AUC: 73.52 Precision: 78.95 Recall: 65.22
#
# -----nusvc - Train----------
# AUC: 91.83 Precision: 92.92 Recall: 90.91
#
# -----nusvc - Validation-----
# AUC: 86.76 Precision: 90.48 Recall: 82.61
#
# Fold 8
#
# -----qda - Train----------
# AUC: 97.59 Precision: 98.67 Recall: 96.54
#
# -----qda - Validation-----
# AUC: 93.38 Precision: 95.45 Recall: 91.30
#
# -----knn - Train----------
# AUC: 90.47 Precision: 90.17 Recall: 91.34
#
# -----knn - Validation-----
# AUC: 84.58 Precision: 90.00 Recall: 78.26
#
# -----mlp - Train----------
# AUC: 85.18 Precision: 85.96 Recall: 84.85
#
# -----mlp - Validation-----
# AUC: 71.34 Precision: 77.78 Recall: 60.87
#
# -----lr - Train----------
# AUC: 78.97 Precision: 79.31 Recall: 79.65
#
# -----lr - Validation-----
# AUC: 69.07 Precision: 73.68 Recall: 60.87
#
# -----nusvc - Train----------
# AUC: 91.16 Precision: 91.70 Recall: 90.91
#
# -----nusvc - Validation-----
# AUC: 80.24 Precision: 88.89 Recall: 69.57
#
# Fold 9
#
# -----qda - Train----------
# AUC: 98.03 Precision: 99.12 Recall: 96.97
#
# -----qda - Validation-----
# AUC: 93.48 Precision: 100.00 Recall: 86.96
#
# -----knn - Train----------
# AUC: 88.05 Precision: 88.31 Recall: 88.31
#
# -----knn - Validation-----
# AUC: 91.21 Precision: 95.24 Recall: 86.96
#
# -----mlp - Train----------
# AUC: 82.43 Precision: 80.65 Recall: 86.58
#
# -----mlp - Validation-----
# AUC: 75.20 Precision: 70.00 Recall: 91.30
#
# -----lr - Train----------
# AUC: 78.97 Precision: 79.31 Recall: 79.65
#
# -----lr - Validation-----
# AUC: 79.74 Precision: 75.00 Recall: 91.30
#
# -----nusvc - Train----------
# AUC: 91.41 Precision: 93.24 Recall: 89.61
#
# -----nusvc - Validation-----
# AUC: 82.11 Precision: 80.00 Recall: 86.96
#
# Fold 10
#
# -----qda - Train----------
# AUC: 98.25 Precision: 99.12 Recall: 97.40
#
# -----qda - Validation-----
# AUC: 91.11 Precision: 91.30 Recall: 91.30
#
# -----knn - Train----------
# AUC: 90.29 Precision: 91.56 Recall: 89.18
#
# -----knn - Validation-----
# AUC: 80.24 Precision: 88.89 Recall: 69.57
#
# -----mlp - Train----------
# AUC: 83.61 Precision: 83.69 Recall: 84.42
#
# -----mlp - Validation-----
# AUC: 70.95 Precision: 69.23 Recall: 78.26
#
# -----lr - Train----------
# AUC: 78.51 Precision: 78.63 Recall: 79.65
#
# -----lr - Validation-----
# AUC: 66.50 Precision: 65.38 Recall: 73.91

# %% [markdown]
# # Ensemble models
#
# Here you can ensemble any combination of models, and give the desired weight for each one.

# %%
train['preds_top2'] = (train['preds_qda'] * 0.5) + (train['preds_nusvc'] * 0.5)
test['target_top2'] = (test['target_qda'] * 0.5) + (test['target_nusvc'] * 0.5)

train['preds_top3'] = (train['preds_qda'] * 0.35) + (train['preds_mlp'] * 0.3) + (train['preds_nusvc'] * 0.35)
test['target_top3'] = (test['target_qda'] * 0.35) + (test['target_mlp'] * 0.3) + (test['target_nusvc'] * 0.35)

train['preds_top4'] = (train['preds_qda'] * 0.25) + (train['preds_mlp'] * 0.25) + (train['preds_lr'] * 0.25) + (train['preds_nusvc'] * 0.25)
test['target_top4'] = (test['target_qda'] * 0.25) + (test['target_mlp'] * 0.25) + (test['target_lr'] * 0.25) + (test['target_nusvc'] * 0.25)

train['preds_avg'] = (train['preds_qda'] * 0.2) + (train['preds_knn'] * 0.2) + (train['preds_mlp'] * 0.2) + (train['preds_lr'] * 0.2) + (train['preds_nusvc'] * 0.2)
test['target_avg'] = (test['target_qda'] * 0.2) + (test['target_knn'] * 0.2) + (test['target_mlp'] * 0.2) + (test['target_lr'] * 0.2) + (test['target_nusvc'] * 0.2)

# %% [markdown]
# # Model evaluation
# ## Confusion matrix (averaged model)

# %%
f = plt.subplots(1, 1, figsize=(16, 5), sharex=True)
train_cnf_matrix = confusion_matrix(train['target'], [np.round(x) for x in train['preds_avg']])
train_cnf_matrix_norm = train_cnf_matrix / train_cnf_matrix.sum(axis=1)[:, np.newaxis]
train_df_cm = pd.DataFrame(train_cnf_matrix_norm, index=[0, 1], columns=[0, 1])
sns.heatmap(train_df_cm, annot=True, fmt='.2f', cmap="Blues")
plt.show()

# %% [markdown]
# ## Metrics ROC AUC

# %%
print('QDA AUC %.2f' % roc_auc_score(train['target'], train['preds_qda']))
print('KNN AUC %.2f' % roc_auc_score(train['target'], train['preds_knn']))
print('MLP AUC %.2f' % roc_auc_score(train['target'], train['preds_mlp']))
print('LR AUC %.2f' % roc_auc_score(train['target'], train['preds_lr']))
print('NuSVC AUC %.2f' % roc_auc_score(train['target'], train['preds_nusvc']))
print('Top 2 AUC %.2f' % roc_auc_score(train['target'], train['preds_top2']))
print('Top 3 AUC %.2f' % roc_auc_score(train['target'], train['preds_top3']))
print('Top 4 AUC %.2f' % roc_auc_score(train['target'], train['preds_top4']))
print('Averaged AUC %.2f' % roc_auc_score(train['target'], train['preds_avg']))
# Out:
# QDA AUC 0.99
# KNN AUC 0.95
# MLP AUC 0.91
# LR AUC 0.86
# NuSVC AUC 0.96
# Top 2 AUC 0.99
# Top 3 AUC 0.99
# Top 4 AUC 0.98
# Averaged AUC 0.98

# %% [markdown]
# ### Test set with all models predictions

# %%
test[['id', 'target_avg', 'target_qda', 'target_knn', 'target_mlp', 'target_lr', 'target_nusvc']].head()
# Out:
#                                  id      ...       target_nusvc
# 0  1c13f2701648e0b0d46d8a2a5a131a53      ...           0.432462
# 1  ba88c155ba898fc8b5099893036ef205      ...           0.765646
# 2  7cbab5cea99169139e7e6d8ff74ebb77      ...           0.331577
# 3  ca820ad57809f62eb7b4d13f5d4371a0      ...           0.175616
# 4  7baaf361537fbd8a1aaa2c97a6d4ccc7      ...           0.179216
#
# [5 rows x 7 columns]

# %% [markdown]
# # Test predictions
# Now you can output predictions for each individual model and the ensembled models as well.
#
# #### Averaged models submission

# %%
submission = test[['id', 'target_avg']]
submission.columns = ['id', 'target']
submission.to_csv('submission_avg.csv', index=False)
submission.head()
# Out:
#                                  id    target
# 0  1c13f2701648e0b0d46d8a2a5a131a53  0.564252
# 1  ba88c155ba898fc8b5099893036ef205  0.735170
# 2  7cbab5cea99169139e7e6d8ff74ebb77  0.311726
# 3  ca820ad57809f62eb7b4d13f5d4371a0  0.234042
# 4  7baaf361537fbd8a1aaa2c97a6d4ccc7  0.221059

# %%
submission = test[['id', 'target_top2']]
submission.columns = ['id', 'target']
submission.to_csv('submission_top2.csv', index=False)
submission.head()
# Out:
#                                  id    target
# 0  1c13f2701648e0b0d46d8a2a5a131a53  0.716209
# 1  ba88c155ba898fc8b5099893036ef205  0.876743
# 2  7cbab5cea99169139e7e6d8ff74ebb77  0.165789
# 3  ca820ad57809f62eb7b4d13f5d4371a0  0.138027
# 4  7baaf361537fbd8a1aaa2c97a6d4ccc7  0.270667

# %%
submission = test[['id', 'target_top3']]
submission.columns = ['id', 'target']
submission.to_csv('submission_top3.csv', index=False)
submission.head()
# Out:
#                                  id    target
# 0  1c13f2701648e0b0d46d8a2a5a131a53  0.626378
# 1  ba88c155ba898fc8b5099893036ef205  0.813072
# 2  7cbab5cea99169139e7e6d8ff74ebb77  0.223929
# 3  ca820ad57809f62eb7b4d13f5d4371a0  0.140107
# 4  7baaf361537fbd8a1aaa2c97a6d4ccc7  0.221077

# %%
submission = test[['id', 'target_top4']]
submission.columns = ['id', 'target']
submission.to_csv('submission_top4.csv', index=False)
submission.head()
# Out:
#                                  id    target
# 0  1c13f2701648e0b0d46d8a2a5a131a53  0.579647
# 1  ba88c155ba898fc8b5099893036ef205  0.745165
# 2  7cbab5cea99169139e7e6d8ff74ebb77  0.280032
# 3  ca820ad57809f62eb7b4d13f5d4371a0  0.158863
# 4  7baaf361537fbd8a1aaa2c97a6d4ccc7  0.193436

# %%
submission = test[['id', 'target_qda']]
submission.columns = ['id', 'target']
submission.to_csv('submission_qda.csv', index=False)
submission.head()
# Out:
#                                  id        target
# 0  1c13f2701648e0b0d46d8a2a5a131a53  9.999560e-01
# 1  ba88c155ba898fc8b5099893036ef205  9.878395e-01
# 2  7cbab5cea99169139e7e6d8ff74ebb77  1.287616e-07
# 3  ca820ad57809f62eb7b4d13f5d4371a0  1.004371e-01
# 4  7baaf361537fbd8a1aaa2c97a6d4ccc7  3.621191e-01

# %%
submission = test[['id', 'target_knn']]
submission.columns = ['id', 'target']
submission.to_csv('submission_knn.csv', index=False)
submission.head()
# Out:
#                                  id    target
# 0  1c13f2701648e0b0d46d8a2a5a131a53  0.502674
# 1  ba88c155ba898fc8b5099893036ef205  0.695187
# 2  7cbab5cea99169139e7e6d8ff74ebb77  0.438503
# 3  ca820ad57809f62eb7b4d13f5d4371a0  0.534759
# 4  7baaf361537fbd8a1aaa2c97a6d4ccc7  0.331551

# %%
submission = test[['id', 'target_mlp']]
submission.columns = ['id', 'target']
submission.to_csv('submission_mlp.csv', index=False)
submission.head()
# Out:
#                                  id    target
# 0  1c13f2701648e0b0d46d8a2a5a131a53  0.416771
# 1  ba88c155ba898fc8b5099893036ef205  0.664506
# 2  7cbab5cea99169139e7e6d8ff74ebb77  0.359591
# 3  ca820ad57809f62eb7b4d13f5d4371a0  0.144963
# 4  7baaf361537fbd8a1aaa2c97a6d4ccc7  0.105367

# %%
submission = test[['id', 'target_lr']]
submission.columns = ['id', 'target']
submission.to_csv('submission_lr.csv', index=False)
submission.head()
# Out:
#                                  id    target
# 0  1c13f2701648e0b0d46d8a2a5a131a53  0.469397
# 1  ba88c155ba898fc8b5099893036ef205  0.562671
# 2  7cbab5cea99169139e7e6d8ff74ebb77  0.428960
# 3  ca820ad57809f62eb7b4d13f5d4371a0  0.214435
# 4  7baaf361537fbd8a1aaa2c97a6d4ccc7  0.127042

# %%
submission = test[['id', 'target_nusvc']]
submission.columns = ['id', 'target']
submission.to_csv('submission_nusvc.csv', index=False)
submission.head()
# Out:
#                                  id    target
# 0  1c13f2701648e0b0d46d8a2a5a131a53  0.432462
# 1  ba88c155ba898fc8b5099893036ef205  0.765646
# 2  7cbab5cea99169139e7e6d8ff74ebb77  0.331577
# 3  ca820ad57809f62eb7b4d13f5d4371a0  0.175616
# 4  7baaf361537fbd8a1aaa2c97a6d4ccc7  0.179216
