# %% [markdown]
# # Dependencies

# %%
import warnings
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

from sklearn.svm import SVC, NuSVC
from sklearn.decomposition import PCA
from sklearn.neural_network import MLPClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.discriminant_analysis import QuadraticDiscriminantAnalysis
from sklearn.feature_selection import VarianceThreshold
from sklearn.preprocessing import MinMaxScaler, StandardScaler
from sklearn.model_selection import train_test_split, StratifiedKFold
from sklearn.metrics import confusion_matrix, roc_auc_score, recall_score, precision_score

# Set seeds to make the experiment more reproducible.
from numpy.random import seed
seed(0)

# %matplotlib inline
sns.set_style("whitegrid")
warnings.filterwarnings("ignore")

# %% [markdown]
# # Load data

# %%
train = pd.read_csv('../input/train.csv')
test = pd.read_csv('../input/test.csv')

print('Train set shape:', train.shape)
print('Test set shape:', test.shape)
print('Train set overview:')
display(train.head())
# Out:
# Train set shape: (262144, 258)
# Test set shape: (131073, 257)
# Train set overview:
#                                  id   ...    target
# 0  707b395ecdcbb4dc2eabea00e4d1b179   ...         0
# 1  5880c03c6582a7b42248668e56b4bdec   ...         0
# 2  4ccbcb3d13e5072ff1d9c61afe2c4f77   ...         1
# 3  e350f17a357f12a1941f0837afb7eb8d   ...         0
# 4  a8f910ea6075b6376af079055965ff68   ...         0
#
# [5 rows x 258 columns]

# %% [markdown]
# # Model
#
# ## Model parameters

# %%
N_FOLDS = 11

# %% [markdown]
# ### You can find evaluation metrics for each model on each fold below on this cell output log. (It's hidden to keep the code clean)

# %%
# INITIALIZE VARIABLES
cols = [c for c in train.columns if c not in ['id', 'target', 'wheezy-copper-turtle-magic', 'preds']]
test['target_05'] = 0
train['preds_05'] = 0
test['target_1'] = 0
train['preds_1'] = 0
test['target_15'] = 0
train['preds_15'] = 0
test['target_2'] = 0
train['preds_2'] = 0
test['target_25'] = 0
train['preds_25'] = 0
test['target_3'] = 0
train['preds_3'] = 0

thresholds = [0.5, 1, 1.5, 2, 2.5, 3]
threshold_names = ['05', '1', '15', '2', '25', '3']

for t in range(len(thresholds)):
    threshold = thresholds[t]
    threshold_name = threshold_names[t]
    print('Threshold ', threshold_name)
    # BUILD 512 MODELS
    for i in range(512):
        print('wheezy-copper-turtle-magic {}\n'.format(i))

        # EXTRACT SUBSET OF DATASET WHERE WHEEZY-MAGIC EQUALS I
        train2 = train[train['wheezy-copper-turtle-magic']==i]
        test2 = test[test['wheezy-copper-turtle-magic']==i]
        idx1 = train2.index
        idx2 = test2.index
        train2.reset_index(drop=True, inplace=True)

        sel = VarianceThreshold(threshold=threshold).fit(train2[cols])
        train3 = sel.transform(train2[cols])
        test3 = sel.transform(test2[cols])

    #     data = pd.concat([pd.DataFrame(train2[cols]), pd.DataFrame(test2[cols])])
    #     data2 = StandardScaler().fit_transform(PCA(svd_solver='full',n_components='mle').fit_transform(data[cols]))
    #     train3 = data2[:train2.shape[0]]
    #     test3 = data2[train2.shape[0]:]

        skf = StratifiedKFold(n_splits=N_FOLDS, random_state=0)
        counter = 0

        for train_index, val_index in skf.split(train3, train2['target']):
            counter += 1
            print('Fold {}\n'.format(counter))

            model = QuadraticDiscriminantAnalysis()
            model.fit(train3[train_index,:], train2.loc[train_index]['target'])

            train_predictions = model.predict(train3[train_index,:])
            val_predictions = model.predict(train3[val_index,:])

            train_auc = roc_auc_score(train2.loc[train_index]['target'], train_predictions) * 100
            val_auc = roc_auc_score(train2.loc[val_index]['target'], val_predictions) * 100
            train_precision = precision_score(train2.loc[train_index]['target'], train_predictions) * 100
            val_precision = precision_score(train2.loc[val_index]['target'], val_predictions) * 100
            train_recall = recall_score(train2.loc[train_index]['target'], train_predictions) * 100
            val_recall = recall_score(train2.loc[val_index]['target'], val_predictions) * 100
            print('-----Train----------')
            print('AUC: %.2f Precision: %.2f Recall: %.2f \n' % (train_auc, train_precision, train_recall))
            print('-----Validation-----')
            print('AUC: %.2f Precision: %.2f Recall: %.2f \n' % (val_auc, val_precision, val_recall))

            # Make predictions
            train['preds_%s' % threshold_name].loc[idx1] += model.predict_proba(train3)[:,1] / N_FOLDS
            test['target_%s' % threshold_name].loc[idx2] += model.predict_proba(test3)[:,1] / N_FOLDS
# Out:
# Threshold  05
# wheezy-copper-turtle-magic 0
#
# Fold 1
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 47.58 Precision: 47.50 Recall: 79.17
#
# Fold 2
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 53.83 Precision: 51.16 Recall: 91.67
#
# Fold 3
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 38.75 Precision: 37.50 Recall: 37.50
#
# Fold 4
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 47.67 Precision: 47.62 Recall: 83.33
#
# Fold 5
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 51.67 Precision: 50.00 Recall: 83.33
#
# Fold 6
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 49.92 Precision: 48.94 Recall: 95.83
#
# Fold 7
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 52.92 Precision: 52.38 Recall: 45.83
#
# Fold 8
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 50.00 Precision: 50.00 Recall: 45.83
#
# Fold 9
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 50.00 Precision: 50.00 Recall: 87.50
#
# Fold 10
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 54.17 Precision: 52.27 Recall: 95.83
#
# Fold 11
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 47.64 Precision: 47.62 Recall: 86.96
#
# wheezy-copper-turtle-magic 1
#
# Fold 1
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 61.87 Precision: 59.26 Recall: 69.57
#
# Fold 2
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 50.72 Precision: 50.00 Recall: 34.78
#
# Fold 3
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 53.08 Precision: 52.38 Recall: 47.83
#
# Fold 4
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 53.53 Precision: 51.61 Recall: 69.57
#
# Fold 5
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 41.67 Precision: 40.74 Recall: 50.00
#
# Fold 6
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 47.73 Precision: 45.45 Recall: 45.45
#
# Fold 7
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 52.08 Precision: 50.00 Recall: 50.00
#
# Fold 8
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 65.53 Precision: 61.54 Recall: 72.73
#
# Fold 9
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 52.27 Precision: 50.00 Recall: 54.55
#
# Fold 10
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 54.17 Precision: 52.38 Recall: 50.00
#
# Fold 11
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 63.07 Precision: 60.87 Recall: 63.64
#
# wheezy-copper-turtle-magic 2
#
# Fold 1
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 45.65 Precision: 46.43 Recall: 56.52
#
# Fold 2
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 62.06 Precision: 63.16 Recall: 54.55
#
# Fold 3
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 48.91 Precision: 47.83 Recall: 50.00
#
# Fold 4
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 51.19 Precision: 50.00 Recall: 54.55
#
# Fold 5
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 64.62 Precision: 61.54 Recall: 72.73
#
# Fold 6
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 55.53 Precision: 54.55 Recall: 54.55
#
# Fold 7
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 51.38 Precision: 50.00 Recall: 63.64
#
# Fold 8
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 52.96 Precision: 53.33 Recall: 36.36
#
# Fold 9
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 49.01 Precision: 48.00 Recall: 54.55
#
# Fold 10
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 50.89 Precision: 50.00 Recall: 40.91
#
# Fold 11
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 52.27 Precision: 52.38 Recall: 50.00
#
# wheezy-copper-turtle-magic 3
#
# Fold 1
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 43.91 Precision: 46.15 Recall: 46.15
#
# Fold 2
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 48.72 Precision: 50.00 Recall: 30.77
#
# Fold 3
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 40.38 Precision: 40.00 Recall: 30.77
#
# Fold 4
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 41.67 Precision: 44.83 Recall: 50.00
#
# Fold 5
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 54.93 Precision: 57.69 Recall: 57.69
#
# Fold 6
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 36.20 Precision: 25.00 Recall: 11.54
#
# Fold 7
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 50.00 Precision: 52.08 Recall: 100.00
#
# Fold 8
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 50.00 Precision: 52.08 Recall: 100.00
#
# Fold 9
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 50.00 Precision: 52.08 Recall: 100.00
#
# Fold 10
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 50.00 Precision: 52.08 Recall: 100.00
#
# Fold 11
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 50.00 Precision: 52.08 Recall: 100.00
#
# wheezy-copper-turtle-magic 4
#
# Fold 1
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 47.92 Precision: 47.83 Recall: 45.83
#
# Fold 2
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 35.42 Precision: 34.78 Recall: 33.33
#
# Fold 3
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 46.92 Precision: 47.62 Recall: 41.67
#
# Fold 4
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 54.89 Precision: 54.55 Recall: 75.00
#
# Fold 5
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 44.47 Precision: 46.43 Recall: 54.17
#
# Fold 6
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 49.00 Precision: 50.00 Recall: 45.83
#
# Fold 7
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 48.82 Precision: 50.00 Recall: 54.17
#
# Fold 8
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 50.91 Precision: 51.85 Recall: 58.33
#
# Fold 9
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 60.87 Precision: 63.16 Recall: 52.17
#
# Fold 10
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 50.00 Precision: 50.00 Recall: 69.57
#
# Fold 11
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 50.00 Precision: 50.00 Recall: 60.87
#
# wheezy-copper-turtle-magic 5
#
# Fold 1
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 56.25 Precision: 57.14 Recall: 50.00
#
# Fold 2
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 37.50 Precision: 37.50 Recall: 37.50
#
# Fold 3
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 56.25 Precision: 57.14 Recall: 50.00
#
# Fold 4
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 58.33 Precision: 61.11 Recall: 45.83
#
# Fold 5
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 52.08 Precision: 52.17 Recall: 50.00
#
# Fold 6
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 58.33 Precision: 54.76 Recall: 95.83
#
# Fold 7
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 40.40 Precision: 39.13 Recall: 39.13
#
# Fold 8
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 62.05 Precision: 58.06 Recall: 78.26
#
# Fold 9
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 61.59 Precision: 61.90 Recall: 56.52
#
# Fold 10
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 52.17 Precision: 52.17 Recall: 52.17
#
# Fold 11
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 58.70 Precision: 60.00 Recall: 52.17
#
# wheezy-copper-turtle-magic 6
#
# Fold 1
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 57.91 Precision: 58.62 Recall: 68.00
#
# Fold 2
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 42.57 Precision: 43.48 Recall: 41.67
#
# Fold 3
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 63.86 Precision: 65.22 Recall: 62.50
#
# Fold 4
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 55.80 Precision: 61.54 Recall: 33.33
#
# Fold 5
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 49.64 Precision: 50.00 Recall: 16.67
#
# Fold 6
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 53.26 Precision: 54.55 Recall: 50.00
#
# Fold 7
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 49.18 Precision: 50.00 Recall: 37.50
#
# Fold 8
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 49.00 Precision: 50.00 Recall: 45.83
#
# Fold 9
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 46.74 Precision: 48.00 Recall: 50.00
#
# Fold 10
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 59.69 Precision: 61.90 Recall: 54.17
#
# Fold 11
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 59.51 Precision: 60.00 Recall: 62.50
#
# wheezy-copper-turtle-magic 7
#
# Fold 1
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 50.91 Precision: 51.85 Recall: 58.33
#
# Fold 2
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 52.17 Precision: 52.38 Recall: 47.83
#
# Fold 3
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 60.87 Precision: 60.00 Recall: 65.22
#
# Fold 4
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 54.35 Precision: 55.56 Recall: 43.48
#
# Fold 5
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 58.70 Precision: 58.33 Recall: 60.87
#
# Fold 6
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 56.52 Precision: 56.52 Recall: 56.52
#
# Fold 7
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 43.48 Precision: 44.00 Recall: 47.83
#
# Fold 8
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 56.52 Precision: 55.56 Recall: 65.22
#
# Fold 9
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 60.87 Precision: 61.90 Recall: 56.52
#
# Fold 10
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 54.35 Precision: 55.00 Recall: 47.83
#
# Fold 11
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 55.63 Precision: 57.14 Recall: 52.17
#
# wheezy-copper-turtle-magic 8
#
# Fold 1
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 38.83 Precision: 39.13 Recall: 36.00
#
# Fold 2
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 52.83 Precision: 53.33 Recall: 64.00
#
# Fold 3
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 48.43 Precision: 50.00 Recall: 36.00
#
# Fold 4
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 45.47 Precision: 33.33 Recall: 8.33
#
# Fold 5
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 51.09 Precision: 52.17 Recall: 50.00
#
# Fold 6
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 49.64 Precision: 50.00 Recall: 16.67
#
# Fold 7
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 53.99 Precision: 66.67 Recall: 16.67
#
# Fold 8
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 49.73 Precision: 50.00 Recall: 12.50
#
# Fold 9
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 53.17 Precision: 54.17 Recall: 54.17
#
# Fold 10
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 59.78 Precision: 63.16 Recall: 50.00
#
# Fold 11
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 53.26 Precision: 54.55 Recall: 50.00
#
# wheezy-copper-turtle-magic 9
#
# Fold 1
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 66.67 Precision: 63.33 Recall: 79.17
#
# Fold 2
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 45.83 Precision: 45.83 Recall: 45.83
#
# Fold 3
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 50.00 Precision: 50.00 Recall: 8.33
#
# Fold 4
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 60.42 Precision: 60.87 Recall: 58.33
#
# Fold 5
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 58.33 Precision: 61.11 Recall: 45.83
#
# Fold 6
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 58.33 Precision: 59.09 Recall: 54.17
#
# Fold 7
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 41.67 Precision: 30.00 Recall: 12.50
#
# Fold 8
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 62.50 Precision: 62.50 Recall: 62.50
#
# Fold 9
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 45.83 Precision: 45.45 Recall: 41.67
#
# Fold 10
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 54.17 Precision: 53.33 Recall: 66.67
#
# Fold 11
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 64.58 Precision: 62.07 Recall: 75.00
#
# wheezy-copper-turtle-magic 10
#
# Fold 1
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 47.83 Precision: 47.83 Recall: 47.83
#
# Fold 2
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 54.35 Precision: 55.56 Recall: 43.48
#
# Fold 3
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 63.04 Precision: 62.50 Recall: 65.22
#
# Fold 4
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 47.83 Precision: 47.37 Recall: 39.13
#
# Fold 5
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 37.85 Precision: 37.50 Recall: 40.91
#
# Fold 6
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 57.81 Precision: 56.52 Recall: 59.09
#
# Fold 7
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 51.09 Precision: 50.00 Recall: 50.00
#
# Fold 8
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 58.00 Precision: 55.56 Recall: 68.18
#
# Fold 9
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 40.12 Precision: 40.00 Recall: 45.45
#
# Fold 10
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 53.36 Precision: 52.17 Recall: 54.55
#
# Fold 11
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 52.27 Precision: 52.38 Recall: 50.00
#
# wheezy-copper-turtle-magic 11
#
# Fold 1
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 41.90 Precision: 37.50 Recall: 27.27
#
# Fold 2
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 53.52 Precision: 50.00 Recall: 80.95
#
# Fold 3
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 40.99 Precision: 39.13 Recall: 42.86
#
# Fold 4
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 57.04 Precision: 54.17 Recall: 61.90
#
# Fold 5
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 47.93 Precision: 45.83 Recall: 52.38
#
# Fold 6
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 63.56 Precision: 61.90 Recall: 61.90
#
# Fold 7
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 43.17 Precision: 40.91 Recall: 42.86
#
# Fold 8
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 61.39 Precision: 59.09 Recall: 61.90
#
# Fold 9
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 51.30 Precision: 50.00 Recall: 57.14
#
# Fold 10
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 60.50 Precision: 59.09 Recall: 61.90
#
# Fold 11
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 44.26 Precision: 43.48 Recall: 47.62
#
# wheezy-copper-turtle-magic 12
#
# Fold 1
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 43.48 Precision: 44.44 Recall: 52.17
#
# Fold 2
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 47.83 Precision: 47.62 Recall: 43.48
#
# Fold 3
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 65.22 Precision: 68.42 Recall: 56.52
#
# Fold 4
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 48.91 Precision: 50.00 Recall: 47.83
#
# Fold 5
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 40.02 Precision: 40.91 Recall: 39.13
#
# Fold 6
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 68.77 Precision: 68.00 Recall: 73.91
#
# Fold 7
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 37.65 Precision: 40.00 Recall: 43.48
#
# Fold 8
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 46.54 Precision: 48.00 Recall: 52.17
#
# Fold 9
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 48.91 Precision: 50.00 Recall: 47.83
#
# Fold 10
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 50.00 Precision: 50.00 Recall: 50.00
#
# Fold 11
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 43.18 Precision: 42.86 Recall: 40.91
#
# wheezy-copper-turtle-magic 13
#
# Fold 1
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 49.11 Precision: 48.15 Recall: 59.09
#
# Fold 2
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 44.47 Precision: 43.48 Recall: 45.45
#
# Fold 3
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 55.63 Precision: 54.17 Recall: 59.09
#
# Fold 4
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 46.64 Precision: 45.45 Recall: 45.45
#
# Fold 5
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 54.66 Precision: 52.17 Recall: 57.14
#
# Fold 6
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 59.21 Precision: 56.52 Recall: 61.90
#
# Fold 7
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 36.02 Precision: 31.58 Recall: 28.57
#
# Fold 8
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 60.97 Precision: 61.11 Recall: 52.38
#
# Fold 9
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 39.50 Precision: 38.10 Recall: 38.10
#
# Fold 10
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 60.61 Precision: 58.33 Recall: 66.67
#
# Fold 11
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 60.50 Precision: 59.09 Recall: 61.90
#
# wheezy-copper-turtle-magic 14
#
# Fold 1
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 61.90 Precision: 60.00 Recall: 57.14
#
# Fold 2
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 46.73 Precision: 43.48 Recall: 47.62
#
# Fold 3
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 64.29 Precision: 61.90 Recall: 61.90
#
# Fold 4
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 55.65 Precision: 52.17 Recall: 57.14
#
# Fold 5
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 48.21 Precision: 44.44 Recall: 38.10
#
# Fold 6
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 49.48 Precision: 47.06 Recall: 38.10
#
# Fold 7
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 47.72 Precision: 45.45 Recall: 47.62
#
# Fold 8
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 58.39 Precision: 60.00 Recall: 42.86
#
# Fold 9
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 57.61 Precision: 55.56 Recall: 50.00
#
# Fold 10
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 53.59 Precision: 50.00 Recall: 55.00
#
# Fold 11
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 52.61 Precision: 50.00 Recall: 40.00
#
# wheezy-copper-turtle-magic 15
#
# Fold 1
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 56.25 Precision: 55.56 Recall: 62.50
#
# Fold 2
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 64.58 Precision: 66.67 Recall: 58.33
#
# Fold 3
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 53.35 Precision: 55.00 Recall: 45.83
#
# Fold 4
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 42.57 Precision: 43.48 Recall: 41.67
#
# Fold 5
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 53.26 Precision: 54.55 Recall: 50.00
#
# Fold 6
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 44.84 Precision: 45.00 Recall: 37.50
#
# Fold 7
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 38.32 Precision: 39.13 Recall: 37.50
#
# Fold 8
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 49.09 Precision: 50.00 Recall: 41.67
#
# Fold 9
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 43.48 Precision: 44.44 Recall: 52.17
#
# Fold 10
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 58.70 Precision: 59.09 Recall: 56.52
#
# Fold 11
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 56.52 Precision: 56.00 Recall: 60.87
#
# wheezy-copper-turtle-magic 16
#
# Fold 1
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 60.78 Precision: 57.14 Recall: 69.57
#
# Fold 2
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 60.26 Precision: 59.09 Recall: 56.52
#
# Fold 3
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 51.00 Precision: 50.00 Recall: 47.83
#
# Fold 4
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 70.02 Precision: 73.68 Recall: 60.87
#
# Fold 5
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 51.90 Precision: 50.00 Recall: 91.30
#
# Fold 6
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 51.00 Precision: 50.00 Recall: 47.83
#
# Fold 7
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 59.33 Precision: 61.11 Recall: 47.83
#
# Fold 8
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 55.53 Precision: 53.57 Recall: 65.22
#
# Fold 9
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 46.83 Precision: 45.83 Recall: 47.83
#
# Fold 10
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 57.20 Precision: 53.33 Recall: 72.73
#
# Fold 11
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 56.25 Precision: 55.00 Recall: 50.00
#
# wheezy-copper-turtle-magic 17
#
# Fold 1
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 48.91 Precision: 50.00 Recall: 50.00
#
# Fold 2
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 46.83 Precision: 47.83 Recall: 45.83
#
# Fold 3
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 55.43 Precision: 57.14 Recall: 50.00
#
# Fold 4
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 38.41 Precision: 38.10 Recall: 33.33
#
# Fold 5
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 53.53 Precision: 56.25 Recall: 37.50
#
# Fold 6
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 51.27 Precision: 52.63 Recall: 41.67
#
# Fold 7
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 49.18 Precision: 50.00 Recall: 37.50
#
# Fold 8
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 54.55 Precision: 57.14 Recall: 50.00
#
# Fold 9
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 43.75 Precision: 45.00 Recall: 37.50
#
# Fold 10
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 57.71 Precision: 58.33 Recall: 60.87
#
# Fold 11
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 46.64 Precision: 47.83 Recall: 47.83
#
# wheezy-copper-turtle-magic 18
#
# Fold 1
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 57.48 Precision: 70.00 Recall: 28.00
#
# Fold 2
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 44.84 Precision: 45.00 Recall: 37.50
#
# Fold 3
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 47.46 Precision: 44.44 Recall: 16.67
#
# Fold 4
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 53.17 Precision: 54.17 Recall: 54.17
#
# Fold 5
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 38.13 Precision: 40.74 Recall: 45.83
#
# Fold 6
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 57.52 Precision: 59.09 Recall: 54.17
#
# Fold 7
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 51.18 Precision: 52.38 Recall: 45.83
#
# Fold 8
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 51.00 Precision: 52.00 Recall: 54.17
#
# Fold 9
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 55.34 Precision: 56.52 Recall: 54.17
#
# Fold 10
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 49.00 Precision: 50.00 Recall: 45.83
#
# Fold 11
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 49.09 Precision: 50.00 Recall: 41.67
#
# wheezy-copper-turtle-magic 19
#
# Fold 1
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 51.00 Precision: 52.00 Recall: 52.00
#
# Fold 2
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 66.67 Precision: 62.50 Recall: 83.33
#
# Fold 3
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 56.25 Precision: 56.52 Recall: 54.17
#
# Fold 4
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 56.25 Precision: 57.89 Recall: 45.83
#
# Fold 5
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 54.17 Precision: 54.17 Recall: 54.17
#
# Fold 6
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 52.08 Precision: 51.85 Recall: 58.33
#
# Fold 7
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 43.75 Precision: 43.48 Recall: 41.67
#
# Fold 8
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 58.33 Precision: 60.00 Recall: 50.00
#
# Fold 9
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 51.18 Precision: 52.38 Recall: 45.83
#
# Fold 10
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 51.36 Precision: 52.94 Recall: 37.50
#
# Fold 11
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 59.69 Precision: 61.90 Recall: 54.17
#
# wheezy-copper-turtle-magic 20
#
# Fold 1
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 60.43 Precision: 58.33 Recall: 60.87
#
# Fold 2
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 54.43 Precision: 51.85 Recall: 60.87
#
# Fold 3
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 44.84 Precision: 44.44 Recall: 52.17
#
# Fold 4
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 59.15 Precision: 64.29 Recall: 39.13
#
# Fold 5
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 47.73 Precision: 45.45 Recall: 45.45
#
# Fold 6
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 45.27 Precision: 42.11 Recall: 36.36
#
# Fold 7
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 60.80 Precision: 59.09 Recall: 59.09
#
# Fold 8
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 37.12 Precision: 36.00 Recall: 40.91
#
# Fold 9
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 50.19 Precision: 48.00 Recall: 54.55
#
# Fold 10
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 43.37 Precision: 40.91 Recall: 40.91
#
# Fold 11
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 53.98 Precision: 50.00 Recall: 95.45
#
# wheezy-copper-turtle-magic 21
#
# Fold 1
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 55.08 Precision: 56.00 Recall: 56.00
#
# Fold 2
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 49.17 Precision: 50.00 Recall: 40.00
#
# Fold 3
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 61.08 Precision: 60.71 Recall: 68.00
#
# Fold 4
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 57.25 Precision: 59.09 Recall: 52.00
#
# Fold 5
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 47.67 Precision: 42.86 Recall: 12.00
#
# Fold 6
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 51.83 Precision: 60.00 Recall: 12.00
#
# Fold 7
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 43.75 Precision: 28.57 Recall: 8.33
#
# Fold 8
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 45.83 Precision: 25.00 Recall: 4.17
#
# Fold 9
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 58.33 Precision: 56.67 Recall: 70.83
#
# Fold 10
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 35.78 Precision: 40.62 Recall: 54.17
#
# Fold 11
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 49.55 Precision: 50.00 Recall: 20.83
#
# wheezy-copper-turtle-magic 22
#
# Fold 1
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 51.12 Precision: 54.55 Recall: 23.08
#
# Fold 2
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 57.37 Precision: 75.00 Recall: 23.08
#
# Fold 3
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 49.83 Precision: 50.00 Recall: 8.00
#
# Fold 4
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 47.67 Precision: 42.86 Recall: 12.00
#
# Fold 5
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 47.75 Precision: 40.00 Recall: 8.00
#
# Fold 6
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 39.42 Precision: 22.22 Recall: 8.00
#
# Fold 7
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 55.75 Precision: 66.67 Recall: 24.00
#
# Fold 8
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 53.65 Precision: 66.67 Recall: 16.00
#
# Fold 9
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 45.13 Precision: 37.50 Recall: 12.00
#
# Fold 10
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 47.30 Precision: 42.86 Recall: 12.00
#
# Fold 11
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 53.65 Precision: 66.67 Recall: 16.00
#
# wheezy-copper-turtle-magic 23
#
# Fold 1
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 53.17 Precision: 54.55 Recall: 48.00
#
# Fold 2
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 61.17 Precision: 61.54 Recall: 64.00
#
# Fold 3
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 58.33 Precision: 57.69 Recall: 62.50
#
# Fold 4
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 53.17 Precision: 54.17 Recall: 54.17
#
# Fold 5
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 65.76 Precision: 64.29 Recall: 75.00
#
# Fold 6
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 53.44 Precision: 55.56 Recall: 41.67
#
# Fold 7
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 56.07 Precision: 71.43 Recall: 20.83
#
# Fold 8
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 53.17 Precision: 54.17 Recall: 54.17
#
# Fold 9
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 51.81 Precision: 57.14 Recall: 16.67
#
# Fold 10
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 56.16 Precision: 80.00 Recall: 16.67
#
# Fold 11
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 42.57 Precision: 43.48 Recall: 41.67
#
# wheezy-copper-turtle-magic 24
#
# Fold 1
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 67.42 Precision: 65.22 Recall: 68.18
#
# Fold 2
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 60.42 Precision: 61.11 Recall: 50.00
#
# Fold 3
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 50.89 Precision: 47.62 Recall: 47.62
#
# Fold 4
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 42.26 Precision: 39.13 Recall: 42.86
#
# Fold 5
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 46.43 Precision: 42.86 Recall: 42.86
#
# Fold 6
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 61.31 Precision: 62.50 Recall: 47.62
#
# Fold 7
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 64.29 Precision: 61.90 Recall: 61.90
#
# Fold 8
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 59.82 Precision: 57.14 Recall: 57.14
#
# Fold 9
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 53.57 Precision: 50.00 Recall: 57.14
#
# Fold 10
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 58.80 Precision: 57.89 Recall: 52.38
#
# Fold 11
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 63.98 Precision: 60.00 Recall: 71.43
#
# wheezy-copper-turtle-magic 25
#
# Fold 1
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 49.24 Precision: 46.67 Recall: 31.82
#
# Fold 2
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 47.92 Precision: 45.83 Recall: 50.00
#
# Fold 3
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 55.95 Precision: 52.00 Recall: 61.90
#
# Fold 4
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 50.89 Precision: 47.62 Recall: 47.62
#
# Fold 5
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 53.57 Precision: 50.00 Recall: 57.14
#
# Fold 6
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 49.69 Precision: 47.37 Recall: 42.86
#
# Fold 7
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 43.17 Precision: 40.91 Recall: 42.86
#
# Fold 8
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 43.37 Precision: 41.67 Recall: 47.62
#
# Fold 9
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 44.93 Precision: 41.18 Recall: 33.33
#
# Fold 10
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 66.77 Precision: 60.00 Recall: 85.71
#
# Fold 11
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 63.56 Precision: 61.90 Recall: 61.90
#
# wheezy-copper-turtle-magic 26
#
# Fold 1
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 55.63 Precision: 54.17 Recall: 59.09
#
# Fold 2
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 46.44 Precision: 44.44 Recall: 36.36
#
# Fold 3
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 46.54 Precision: 45.00 Recall: 40.91
#
# Fold 4
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 60.18 Precision: 57.69 Recall: 68.18
#
# Fold 5
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 53.06 Precision: 52.94 Recall: 40.91
#
# Fold 6
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 50.52 Precision: 48.15 Recall: 61.90
#
# Fold 7
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 52.48 Precision: 50.00 Recall: 57.14
#
# Fold 8
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 52.48 Precision: 50.00 Recall: 57.14
#
# Fold 9
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 39.03 Precision: 38.46 Recall: 47.62
#
# Fold 10
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 50.10 Precision: 47.83 Recall: 52.38
#
# Fold 11
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 34.06 Precision: 31.82 Recall: 33.33
#
# wheezy-copper-turtle-magic 27
#
# Fold 1
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 54.73 Precision: 52.63 Recall: 45.45
#
# Fold 2
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 53.18 Precision: 48.72 Recall: 86.36
#
# Fold 3
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 52.46 Precision: 50.00 Recall: 59.09
#
# Fold 4
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 49.43 Precision: 47.50 Recall: 86.36
#
# Fold 5
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 57.95 Precision: 60.00 Recall: 40.91
#
# Fold 6
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 41.67 Precision: 40.74 Recall: 50.00
#
# Fold 7
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 64.39 Precision: 56.76 Recall: 95.45
#
# Fold 8
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 61.90 Precision: 60.00 Recall: 57.14
#
# Fold 9
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 48.21 Precision: 44.44 Recall: 38.10
#
# Fold 10
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 42.86 Precision: 40.74 Recall: 52.38
#
# Fold 11
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 48.21 Precision: 44.44 Recall: 38.10
#
# wheezy-copper-turtle-magic 28
#
# Fold 1
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 58.00 Precision: 66.67 Recall: 32.00
#
# Fold 2
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 48.00 Precision: 48.15 Recall: 52.00
#
# Fold 3
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 50.00 Precision: 50.00 Recall: 8.00
#
# Fold 4
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 62.00 Precision: 62.50 Recall: 60.00
#
# Fold 5
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 38.58 Precision: 41.38 Recall: 48.00
#
# Fold 6
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 45.83 Precision: 40.00 Recall: 16.67
#
# Fold 7
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 60.42 Precision: 58.62 Recall: 70.83
#
# Fold 8
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 52.08 Precision: 52.94 Recall: 37.50
#
# Fold 9
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 43.75 Precision: 46.34 Recall: 79.17
#
# Fold 10
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 50.00 Precision: 50.00 Recall: 8.33
#
# Fold 11
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 47.92 Precision: 48.00 Recall: 50.00
#
# wheezy-copper-turtle-magic 29
#
# Fold 1
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 50.00 Precision: 50.00 Recall: 65.22
#
# Fold 2
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 45.65 Precision: 45.45 Recall: 43.48
#
# Fold 3
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 63.04 Precision: 66.67 Recall: 52.17
#
# Fold 4
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 39.13 Precision: 40.74 Recall: 47.83
#
# Fold 5
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 47.83 Precision: 47.62 Recall: 43.48
#
# Fold 6
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 41.30 Precision: 42.31 Recall: 47.83
#
# Fold 7
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 62.15 Precision: 62.50 Recall: 65.22
#
# Fold 8
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 53.46 Precision: 55.00 Recall: 47.83
#
# Fold 9
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 45.45 Precision: 45.83 Recall: 50.00
#
# Fold 10
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 56.82 Precision: 58.82 Recall: 45.45
#
# Fold 11
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 47.73 Precision: 47.06 Recall: 36.36
#
# wheezy-copper-turtle-magic 30
#
# Fold 1
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 44.96 Precision: 40.00 Recall: 16.00
#
# Fold 2
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 45.13 Precision: 37.50 Recall: 12.00
#
# Fold 3
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 47.65 Precision: 33.33 Recall: 4.00
#
# Fold 4
#
# ...
#
# Fold 11
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 77.87 Precision: 75.00 Recall: 81.82
#
# wheezy-copper-turtle-magic 67
#
# Fold 1
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 59.91 Precision: 60.00 Recall: 72.00
#
# Fold 2
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 65.74 Precision: 62.86 Recall: 88.00
#
# Fold 3
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 69.91 Precision: 65.71 Recall: 92.00
#
# Fold 4
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 71.83 Precision: 65.71 Recall: 95.83
#
# Fold 5
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 71.02 Precision: 67.74 Recall: 87.50
#
# Fold 6
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 60.23 Precision: 60.00 Recall: 75.00
#
# Fold 7
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 77.65 Precision: 73.33 Recall: 91.67
#
# Fold 8
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 68.94 Precision: 66.67 Recall: 83.33
#
# Fold 9
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 71.21 Precision: 68.97 Recall: 83.33
#
# Fold 10
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 62.31 Precision: 61.29 Recall: 79.17
#
# Fold 11
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 75.38 Precision: 70.97 Recall: 91.67
#
# wheezy-copper-turtle-magic 68
#
# Fold 1
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 71.21 Precision: 68.97 Recall: 83.33
#
# Fold 2
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 72.92 Precision: 67.65 Recall: 95.83
#
# Fold 3
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 71.21 Precision: 68.97 Recall: 83.33
#
# Fold 4
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 75.40 Precision: 73.08 Recall: 82.61
#
# Fold 5
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 61.76 Precision: 59.38 Recall: 82.61
#
# Fold 6
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 84.29 Precision: 80.77 Recall: 91.30
#
# Fold 7
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 77.57 Precision: 74.07 Recall: 86.96
#
# Fold 8
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 84.19 Precision: 78.57 Recall: 95.65
#
# Fold 9
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 61.86 Precision: 60.00 Recall: 78.26
#
# Fold 10
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 73.32 Precision: 73.91 Recall: 73.91
#
# Fold 11
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 63.93 Precision: 60.61 Recall: 86.96
#
# wheezy-copper-turtle-magic 69
#
# Fold 1
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 73.17 Precision: 68.75 Recall: 88.00
#
# Fold 2
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 61.00 Precision: 60.00 Recall: 72.00
#
# Fold 3
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 66.75 Precision: 61.54 Recall: 96.00
#
# Fold 4
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 71.08 Precision: 66.67 Recall: 88.00
#
# Fold 5
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 65.08 Precision: 63.33 Recall: 76.00
#
# Fold 6
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 68.78 Precision: 70.83 Recall: 68.00
#
# Fold 7
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 70.09 Precision: 66.67 Recall: 88.00
#
# Fold 8
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 78.43 Precision: 72.73 Recall: 96.00
#
# Fold 9
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 68.09 Precision: 65.62 Recall: 84.00
#
# Fold 10
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 85.48 Precision: 87.50 Recall: 84.00
#
# Fold 11
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 78.35 Precision: 71.88 Recall: 95.83
#
# wheezy-copper-turtle-magic 70
#
# Fold 1
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 68.09 Precision: 65.62 Recall: 84.00
#
# Fold 2
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 74.09 Precision: 68.57 Recall: 96.00
#
# Fold 3
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 74.09 Precision: 68.57 Recall: 96.00
#
# Fold 4
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 78.09 Precision: 75.86 Recall: 88.00
#
# Fold 5
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 51.36 Precision: 54.05 Recall: 80.00
#
# Fold 6
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 76.09 Precision: 75.00 Recall: 84.00
#
# Fold 7
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 66.73 Precision: 64.71 Recall: 88.00
#
# Fold 8
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 77.55 Precision: 72.73 Recall: 96.00
#
# Fold 9
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 71.00 Precision: 67.65 Recall: 92.00
#
# Fold 10
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 75.76 Precision: 74.07 Recall: 83.33
#
# Fold 11
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 71.02 Precision: 67.74 Recall: 87.50
#
# wheezy-copper-turtle-magic 71
#
# Fold 1
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 75.33 Precision: 72.41 Recall: 84.00
#
# Fold 2
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 81.25 Precision: 75.86 Recall: 91.67
#
# Fold 3
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 84.87 Precision: 79.31 Recall: 95.83
#
# Fold 4
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 72.10 Precision: 68.97 Recall: 83.33
#
# Fold 5
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 80.71 Precision: 77.78 Recall: 87.50
#
# Fold 6
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 76.27 Precision: 70.97 Recall: 91.67
#
# Fold 7
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 74.18 Precision: 70.00 Recall: 87.50
#
# Fold 8
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 74.46 Precision: 75.00 Recall: 75.00
#
# Fold 9
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 72.19 Precision: 70.37 Recall: 79.17
#
# Fold 10
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 70.20 Precision: 70.83 Recall: 70.83
#
# Fold 11
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 76.18 Precision: 69.70 Recall: 95.83
#
# wheezy-copper-turtle-magic 72
#
# Fold 1
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 59.82 Precision: 58.97 Recall: 95.83
#
# Fold 2
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 50.30 Precision: 53.49 Recall: 95.83
#
# Fold 3
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 54.76 Precision: 55.81 Recall: 100.00
#
# Fold 4
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 64.88 Precision: 62.86 Recall: 91.67
#
# Fold 5
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 60.42 Precision: 60.00 Recall: 87.50
#
# Fold 6
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 60.12 Precision: 59.46 Recall: 91.67
#
# Fold 7
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 59.82 Precision: 58.97 Recall: 95.83
#
# Fold 8
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 59.82 Precision: 58.97 Recall: 95.83
#
# Fold 9
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 67.26 Precision: 64.71 Recall: 91.67
#
# Fold 10
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 60.12 Precision: 59.46 Recall: 91.67
#
# Fold 11
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 50.41 Precision: 52.50 Recall: 91.30
#
# wheezy-copper-turtle-magic 73
#
# Fold 1
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 85.42 Precision: 81.48 Recall: 91.67
#
# Fold 2
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 72.92 Precision: 76.19 Recall: 66.67
#
# Fold 3
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 77.08 Precision: 74.07 Recall: 83.33
#
# Fold 4
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 79.17 Precision: 81.82 Recall: 75.00
#
# Fold 5
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 56.25 Precision: 55.17 Recall: 66.67
#
# Fold 6
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 68.75 Precision: 64.52 Recall: 83.33
#
# Fold 7
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 68.75 Precision: 66.67 Recall: 75.00
#
# Fold 8
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 72.92 Precision: 73.91 Recall: 70.83
#
# Fold 9
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 69.57 Precision: 73.68 Recall: 60.87
#
# Fold 10
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 82.61 Precision: 77.78 Recall: 91.30
#
# Fold 11
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 84.78 Precision: 86.36 Recall: 82.61
#
# wheezy-copper-turtle-magic 74
#
# Fold 1
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 64.43 Precision: 65.22 Recall: 65.22
#
# Fold 2
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 62.15 Precision: 62.50 Recall: 65.22
#
# Fold 3
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 59.09 Precision: 56.67 Recall: 77.27
#
# Fold 4
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 63.64 Precision: 58.33 Recall: 95.45
#
# Fold 5
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 63.64 Precision: 61.54 Recall: 72.73
#
# Fold 6
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 52.27 Precision: 51.85 Recall: 63.64
#
# Fold 7
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 72.73 Precision: 72.73 Recall: 72.73
#
# Fold 8
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 76.52 Precision: 73.08 Recall: 86.36
#
# Fold 9
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 67.42 Precision: 68.18 Recall: 68.18
#
# Fold 10
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 46.21 Precision: 48.15 Recall: 59.09
#
# Fold 11
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 64.94 Precision: 64.00 Recall: 72.73
#
# wheezy-copper-turtle-magic 75
#
# Fold 1
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 70.83 Precision: 67.86 Recall: 79.17
#
# Fold 2
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 72.46 Precision: 69.23 Recall: 78.26
#
# Fold 3
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 78.99 Precision: 72.41 Recall: 91.30
#
# Fold 4
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 68.03 Precision: 68.18 Recall: 65.22
#
# Fold 5
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 65.22 Precision: 65.22 Recall: 65.22
#
# Fold 6
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 73.91 Precision: 78.95 Recall: 65.22
#
# Fold 7
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 78.26 Precision: 74.07 Recall: 86.96
#
# Fold 8
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 80.43 Precision: 79.17 Recall: 82.61
#
# Fold 9
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 71.74 Precision: 77.78 Recall: 60.87
#
# Fold 10
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 60.87 Precision: 64.71 Recall: 47.83
#
# Fold 11
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 65.22 Precision: 68.42 Recall: 56.52
#
# wheezy-copper-turtle-magic 76
#
# Fold 1
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 68.00 Precision: 66.67 Recall: 72.00
#
# Fold 2
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 68.00 Precision: 65.52 Recall: 76.00
#
# Fold 3
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 68.00 Precision: 80.00 Recall: 48.00
#
# Fold 4
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 72.00 Precision: 68.97 Recall: 80.00
#
# Fold 5
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 78.00 Precision: 85.00 Recall: 68.00
#
# Fold 6
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 80.00 Precision: 77.78 Recall: 84.00
#
# Fold 7
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 81.58 Precision: 80.77 Recall: 84.00
#
# Fold 8
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 73.33 Precision: 71.43 Recall: 80.00
#
# Fold 9
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 81.25 Precision: 82.61 Recall: 79.17
#
# Fold 10
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 79.17 Precision: 79.17 Recall: 79.17
#
# Fold 11
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 68.75 Precision: 65.52 Recall: 79.17

# %% [markdown]
# # Ensemble models
#
# Here you can ensemble any combination of models, and give the desired weight for each one.

# %%
train['preds_avg'] = (train['preds_05'] * 0.15) + (train['preds_1'] * 0.2) + (train['preds_15'] * 0.2) + (train['preds_2'] * 0.15) + (train['preds_25'] * 0.15) + (train['preds_3'] * 0.15)
test['target_avg'] = (test['target_05'] * 0.15) + (test['target_1'] * 0.2) + (test['target_15'] * 0.2) + (test['target_2'] * 0.15) + (test['target_25'] * 0.15) + (test['target_3'] * 0.15)

# %% [markdown]
# # Model evaluation
# ## Confusion matrix (averaged model)

# %%
f = plt.subplots(1, 1, figsize=(16, 5), sharex=True)
train_cnf_matrix = confusion_matrix(train['target'], [np.round(x) for x in train['preds_avg']])
train_cnf_matrix_norm = train_cnf_matrix / train_cnf_matrix.sum(axis=1)[:, np.newaxis]
train_df_cm = pd.DataFrame(train_cnf_matrix_norm, index=[0, 1], columns=[0, 1])
sns.heatmap(train_df_cm, annot=True, fmt='.2f', cmap="Blues")
plt.show()

# %% [markdown]
# ## Metrics ROC AUC

# %%
print('QDA Var 0.5 %.2f' % roc_auc_score(train['target'], train['preds_05']))
print('QDA Var 1   %.2f' % roc_auc_score(train['target'], train['preds_1']))
print('QDA Var 1.5 %.2f' % roc_auc_score(train['target'], train['preds_15']))
print('QDA Var 2   %.2f' % roc_auc_score(train['target'], train['preds_2']))
print('QDA Var 2.5 %.2f' % roc_auc_score(train['target'], train['preds_25']))
print('QDA Var 3   %.2f' % roc_auc_score(train['target'], train['preds_3']))
print('Averaged AUC %.2f' % roc_auc_score(train['target'], train['preds_avg']))
# Out:
# QDA Var 0.5 1.00
# QDA Var 1   1.00
# QDA Var 1.5 0.99
# QDA Var 2   0.99
# QDA Var 2.5 0.99
# QDA Var 3   0.99
# Averaged AUC 1.00

# %% [markdown]
# ### Test set with all models predictions

# %%
test[['id', 'target_avg', 'target_05', 'target_1', 'target_15', 'target_2', 'target_25', 'target_3']].head()
# Out:
#                                  id      ...           target_3
# 0  1c13f2701648e0b0d46d8a2a5a131a53      ...       9.999712e-01
# 1  ba88c155ba898fc8b5099893036ef205      ...       9.879759e-01
# 2  7cbab5cea99169139e7e6d8ff74ebb77      ...       2.529365e-07
# 3  ca820ad57809f62eb7b4d13f5d4371a0      ...       7.526842e-02
# 4  7baaf361537fbd8a1aaa2c97a6d4ccc7      ...       4.380961e-01
#
# [5 rows x 8 columns]

# %% [markdown]
# # Test predictions
# Now you can output predictions for each individual model and the ensembled models as well.
#
# #### Averaged models submission

# %%
submission = test[['id', 'target_avg']]
submission.columns = ['id', 'target']
submission.to_csv('submission_avg.csv', index=False)
submission.head()
# Out:
#                                  id    target
# 0  1c13f2701648e0b0d46d8a2a5a131a53  0.931799
# 1  ba88c155ba898fc8b5099893036ef205  0.724002
# 2  7cbab5cea99169139e7e6d8ff74ebb77  0.164744
# 3  ca820ad57809f62eb7b4d13f5d4371a0  0.144379
# 4  7baaf361537fbd8a1aaa2c97a6d4ccc7  0.352994

# %%
submission = test[['id', 'target_05']]
submission.columns = ['id', 'target']
submission.to_csv('submission_thr05.csv', index=False)
submission.head()
# Out:
#                                  id    target
# 0  1c13f2701648e0b0d46d8a2a5a131a53  0.545455
# 1  ba88c155ba898fc8b5099893036ef205  0.545455
# 2  7cbab5cea99169139e7e6d8ff74ebb77  0.545455
# 3  ca820ad57809f62eb7b4d13f5d4371a0  0.636364
# 4  7baaf361537fbd8a1aaa2c97a6d4ccc7  0.454545

# %%
submission = test[['id', 'target_1']]
submission.columns = ['id', 'target']
submission.to_csv('submission_thr1.csv', index=False)
submission.head()
# Out:
#                                  id        target
# 0  1c13f2701648e0b0d46d8a2a5a131a53  1.000000e+00
# 1  ba88c155ba898fc8b5099893036ef205  1.124096e-11
# 2  7cbab5cea99169139e7e6d8ff74ebb77  4.146297e-01
# 3  ca820ad57809f62eb7b4d13f5d4371a0  1.381775e-07
# 4  7baaf361537fbd8a1aaa2c97a6d4ccc7  2.475349e-04

# %%
submission = test[['id', 'target_15']]
submission.columns = ['id', 'target']
submission.to_csv('submission_thr15.csv', index=False)
submission.head()
# Out:
#                                  id        target
# 0  1c13f2701648e0b0d46d8a2a5a131a53  9.999712e-01
# 1  ba88c155ba898fc8b5099893036ef205  9.879759e-01
# 2  7cbab5cea99169139e7e6d8ff74ebb77  2.529365e-07
# 3  ca820ad57809f62eb7b4d13f5d4371a0  7.526842e-02
# 4  7baaf361537fbd8a1aaa2c97a6d4ccc7  4.380961e-01

# %%
submission = test[['id', 'target_2']]
submission.columns = ['id', 'target']
submission.to_csv('submission_thr2.csv', index=False)
submission.head()
# Out:
#                                  id        target
# 0  1c13f2701648e0b0d46d8a2a5a131a53  9.999712e-01
# 1  ba88c155ba898fc8b5099893036ef205  9.879759e-01
# 2  7cbab5cea99169139e7e6d8ff74ebb77  2.529365e-07
# 3  ca820ad57809f62eb7b4d13f5d4371a0  7.526842e-02
# 4  7baaf361537fbd8a1aaa2c97a6d4ccc7  4.380961e-01

# %%
submission = test[['id', 'target_25']]
submission.columns = ['id', 'target']
submission.to_csv('submission_thr25.csv', index=False)
submission.head()
# Out:
#                                  id        target
# 0  1c13f2701648e0b0d46d8a2a5a131a53  9.999712e-01
# 1  ba88c155ba898fc8b5099893036ef205  9.879759e-01
# 2  7cbab5cea99169139e7e6d8ff74ebb77  2.529365e-07
# 3  ca820ad57809f62eb7b4d13f5d4371a0  7.526842e-02
# 4  7baaf361537fbd8a1aaa2c97a6d4ccc7  4.380961e-01

# %%
submission = test[['id', 'target_3']]
submission.columns = ['id', 'target']
submission.to_csv('submission_thr3.csv', index=False)
submission.head()
# Out:
#                                  id        target
# 0  1c13f2701648e0b0d46d8a2a5a131a53  9.999712e-01
# 1  ba88c155ba898fc8b5099893036ef205  9.879759e-01
# 2  7cbab5cea99169139e7e6d8ff74ebb77  2.529365e-07
# 3  ca820ad57809f62eb7b4d13f5d4371a0  7.526842e-02
# 4  7baaf361537fbd8a1aaa2c97a6d4ccc7  4.380961e-01
