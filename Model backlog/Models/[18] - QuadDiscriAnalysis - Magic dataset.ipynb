# %% [markdown]
# # Dependencies

# %%
import warnings
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

from sklearn.discriminant_analysis import QuadraticDiscriminantAnalysis
from sklearn.feature_selection import VarianceThreshold
from sklearn.preprocessing import MinMaxScaler, StandardScaler
from sklearn.model_selection import train_test_split, StratifiedKFold
from sklearn.metrics import confusion_matrix, roc_auc_score, recall_score, precision_score

# Set seeds to make the experiment more reproducible.
from numpy.random import seed
seed(0)

# %matplotlib inline
sns.set_style("whitegrid")
warnings.filterwarnings("ignore")

# %% [markdown]
# # Load data

# %%
train = pd.read_csv('../input/train.csv')
test = pd.read_csv('../input/test.csv')

# %%
print('Train set shape:', train.shape)
print('Test set shape:', test.shape)
print('Train set overview:')
display(train.head())
# Out:
# Train set shape: (262144, 258)
# Test set shape: (131073, 257)
# Train set overview:
#                                  id   ...    target
# 0  707b395ecdcbb4dc2eabea00e4d1b179   ...         0
# 1  5880c03c6582a7b42248668e56b4bdec   ...         0
# 2  4ccbcb3d13e5072ff1d9c61afe2c4f77   ...         1
# 3  e350f17a357f12a1941f0837afb7eb8d   ...         0
# 4  a8f910ea6075b6376af079055965ff68   ...         0
#
# [5 rows x 258 columns]

# %% [markdown]
# ## Preprocess

# %% [markdown]
# # Model
#
# ## Model parameters

# %%
N_FOLDS = 11

# %%
# INITIALIZE VARIABLES
cols = [c for c in train.columns if c not in ['id', 'target', 'wheezy-copper-turtle-magic', 'preds']]
test['target'] = 0
train['preds'] = 0

# BUILD 512 MODELS
for i in range(512):
    print('wheezy-copper-turtle-magic {}\n'.format(i))
    
    # EXTRACT SUBSET OF DATASET WHERE WHEEZY-MAGIC EQUALS I
    train2 = train[train['wheezy-copper-turtle-magic']==i]
    test2 = test[test['wheezy-copper-turtle-magic']==i]
    idx1 = train2.index
    idx2 = test2.index
    train2.reset_index(drop=True, inplace=True)
    
    # FEATURE SELECTION (USE APPROX 40 OF 255 FEATURES)
    sel = VarianceThreshold(threshold=1.5).fit(train2[cols])
    train3 = sel.transform(train2[cols])
    test3 = sel.transform(test2[cols])

    skf = StratifiedKFold(n_splits=N_FOLDS, random_state=0)
    counter = 0

    for train_index, val_index in skf.split(train3, train2['target']):
        counter += 1
        print('Fold {}\n'.format(counter))
        model = QuadraticDiscriminantAnalysis()
        model.fit(train3[train_index,:], train2.loc[train_index]['target'])
        
        train_predictions = model.predict(train3[train_index,:])
        val_predictions = model.predict(train3[val_index,:])

        train_auc = roc_auc_score(train2.loc[train_index]['target'], train_predictions) * 100
        val_auc = roc_auc_score(train2.loc[val_index]['target'], val_predictions) * 100
        train_precision = precision_score(train2.loc[train_index]['target'], train_predictions) * 100
        val_precision = precision_score(train2.loc[val_index]['target'], val_predictions) * 100
        train_recall = recall_score(train2.loc[train_index]['target'], train_predictions) * 100
        val_recall = recall_score(train2.loc[val_index]['target'], val_predictions) * 100
        print('-----Train----------')
        print('AUC: %.2f Precision: %.2f Recall: %.2f \n' % (train_auc, train_precision, train_recall))
        print('-----Validation-----')
        print('AUC: %.2f Precision: %.2f Recall: %.2f \n' % (val_auc, val_precision, val_recall))

        # Make predictions
        train['preds'].loc[idx1] += model.predict_proba(train3)[:,1] / N_FOLDS
        test['target'].loc[idx2] += model.predict_proba(test3)[:,1] / N_FOLDS
# Out:
# wheezy-copper-turtle-magic 0
#
# Fold 1
#
# -----Train----------
# AUC: 97.32 Precision: 97.48 Recall: 97.07
#
# -----Validation-----
# AUC: 81.58 Precision: 82.61 Recall: 79.17
#
# Fold 2
#
# -----Train----------
# AUC: 96.90 Precision: 97.06 Recall: 96.65
#
# -----Validation-----
# AUC: 87.75 Precision: 87.50 Recall: 87.50
#
# Fold 3
#
# -----Train----------
# AUC: 97.12 Precision: 96.68 Recall: 97.49
#
# -----Validation-----
# AUC: 95.92 Precision: 95.83 Recall: 95.83
#
# Fold 4
#
# -----Train----------
# AUC: 96.91 Precision: 96.67 Recall: 97.07
#
# -----Validation-----
# AUC: 95.92 Precision: 95.83 Recall: 95.83
#
# Fold 5
#
# -----Train----------
# AUC: 96.90 Precision: 97.06 Recall: 96.65
#
# -----Validation-----
# AUC: 95.83 Precision: 100.00 Recall: 91.67
#
# Fold 6
#
# -----Train----------
# AUC: 96.71 Precision: 96.27 Recall: 97.07
#
# -----Validation-----
# AUC: 97.92 Precision: 100.00 Recall: 95.83
#
# Fold 7
#
# -----Train----------
# AUC: 97.12 Precision: 96.68 Recall: 97.49
#
# -----Validation-----
# AUC: 95.92 Precision: 95.83 Recall: 95.83
#
# Fold 8
#
# -----Train----------
# AUC: 96.91 Precision: 97.06 Recall: 96.65
#
# -----Validation-----
# AUC: 89.58 Precision: 91.30 Recall: 87.50
#
# Fold 9
#
# -----Train----------
# AUC: 97.74 Precision: 97.50 Recall: 97.91
#
# -----Validation-----
# AUC: 87.50 Precision: 90.91 Recall: 83.33
#
# Fold 10
#
# -----Train----------
# AUC: 96.71 Precision: 96.65 Recall: 96.65
#
# -----Validation-----
# AUC: 93.75 Precision: 95.65 Recall: 91.67
#
# Fold 11
#
# -----Train----------
# AUC: 96.71 Precision: 96.67 Recall: 96.67
#
# -----Validation-----
# AUC: 97.83 Precision: 100.00 Recall: 95.65
#
# wheezy-copper-turtle-magic 1
#
# Fold 1
#
# -----Train----------
# AUC: 96.60 Precision: 94.81 Recall: 98.21
#
# -----Validation-----
# AUC: 91.58 Precision: 88.00 Recall: 95.65
#
# Fold 2
#
# -----Train----------
# AUC: 96.17 Precision: 94.37 Recall: 97.76
#
# -----Validation-----
# AUC: 97.83 Precision: 100.00 Recall: 95.65
#
# Fold 3
#
# -----Train----------
# AUC: 96.39 Precision: 94.40 Recall: 98.21
#
# -----Validation-----
# AUC: 93.57 Precision: 95.45 Recall: 91.30
#
# Fold 4
#
# -----Train----------
# AUC: 96.60 Precision: 94.81 Recall: 98.21
#
# -----Validation-----
# AUC: 87.32 Precision: 84.00 Recall: 91.30
#
# Fold 5
#
# -----Train----------
# AUC: 96.59 Precision: 95.22 Recall: 97.77
#
# -----Validation-----
# AUC: 87.12 Precision: 83.33 Recall: 90.91
#
# Fold 6
#
# -----Train----------
# AUC: 96.18 Precision: 94.40 Recall: 97.77
#
# -----Validation-----
# AUC: 93.18 Precision: 100.00 Recall: 86.36
#
# Fold 7
#
# -----Train----------
# AUC: 96.80 Precision: 95.63 Recall: 97.77
#
# -----Validation-----
# AUC: 82.58 Precision: 81.82 Recall: 81.82
#
# Fold 8
#
# -----Train----------
# AUC: 96.62 Precision: 94.44 Recall: 98.66
#
# -----Validation-----
# AUC: 93.37 Precision: 95.24 Recall: 90.91
#
# Fold 9
#
# -----Train----------
# AUC: 96.61 Precision: 94.83 Recall: 98.21
#
# -----Validation-----
# AUC: 91.29 Precision: 90.91 Recall: 90.91
#
# Fold 10
#
# -----Train----------
# AUC: 97.04 Precision: 95.26 Recall: 98.66
#
# -----Validation-----
# AUC: 95.83 Precision: 91.67 Recall: 100.00
#
# Fold 11
#
# -----Train----------
# AUC: 96.83 Precision: 94.85 Recall: 98.66
#
# -----Validation-----
# AUC: 95.64 Precision: 95.45 Recall: 95.45
#
# wheezy-copper-turtle-magic 2
#
# Fold 1
#
# -----Train----------
# AUC: 97.77 Precision: 97.73 Recall: 97.73
#
# -----Validation-----
# AUC: 93.48 Precision: 95.45 Recall: 91.30
#
# Fold 2
#
# -----Train----------
# AUC: 97.34 Precision: 96.86 Recall: 97.74
#
# -----Validation-----
# AUC: 95.55 Precision: 95.45 Recall: 95.45
#
# Fold 3
#
# -----Train----------
# AUC: 97.78 Precision: 97.31 Recall: 98.19
#
# -----Validation-----
# AUC: 88.83 Precision: 90.48 Recall: 86.36
#
# Fold 4
#
# -----Train----------
# AUC: 97.55 Precision: 97.73 Recall: 97.29
#
# -----Validation-----
# AUC: 91.11 Precision: 90.91 Recall: 90.91
#
# Fold 5
#
# -----Train----------
# AUC: 97.78 Precision: 97.74 Recall: 97.74
#
# -----Validation-----
# AUC: 93.38 Precision: 91.30 Recall: 95.45
#
# Fold 6
#
# -----Train----------
# AUC: 98.44 Precision: 98.64 Recall: 98.19
#
# -----Validation-----
# AUC: 88.93 Precision: 86.96 Recall: 90.91
#
# Fold 7
#
# -----Train----------
# AUC: 97.55 Precision: 97.73 Recall: 97.29
#
# -----Validation-----
# AUC: 93.48 Precision: 88.00 Recall: 100.00
#
# Fold 8
#
# -----Train----------
# AUC: 97.56 Precision: 97.30 Recall: 97.74
#
# -----Validation-----
# AUC: 93.28 Precision: 95.24 Recall: 90.91
#
# Fold 9
#
# -----Train----------
# AUC: 98.24 Precision: 97.33 Recall: 99.10
#
# -----Validation-----
# AUC: 93.18 Precision: 100.00 Recall: 86.36
#
# Fold 10
#
# -----Train----------
# AUC: 97.55 Precision: 97.73 Recall: 97.29
#
# -----Validation-----
# AUC: 97.83 Precision: 95.65 Recall: 100.00
#
# Fold 11
#
# -----Train----------
# AUC: 97.12 Precision: 96.85 Recall: 97.29
#
# -----Validation-----
# AUC: 97.73 Precision: 95.65 Recall: 100.00
#
# wheezy-copper-turtle-magic 3
#
# Fold 1
#
# -----Train----------
# AUC: 98.79 Precision: 99.21 Recall: 98.43
#
# -----Validation-----
# AUC: 98.08 Precision: 100.00 Recall: 96.15
#
# Fold 2
#
# -----Train----------
# AUC: 98.79 Precision: 99.21 Recall: 98.43
#
# -----Validation-----
# AUC: 93.91 Precision: 92.59 Recall: 96.15
#
# Fold 3
#
# -----Train----------
# AUC: 98.39 Precision: 99.20 Recall: 97.65
#
# -----Validation-----
# AUC: 93.91 Precision: 92.59 Recall: 96.15
#
# Fold 4
#
# -----Train----------
# AUC: 98.59 Precision: 99.21 Recall: 98.04
#
# -----Validation-----
# AUC: 93.75 Precision: 89.66 Recall: 100.00
#
# Fold 5
#
# -----Train----------
# AUC: 98.82 Precision: 100.00 Recall: 97.65
#
# -----Validation-----
# AUC: 89.38 Precision: 86.21 Recall: 96.15
#
# Fold 6
#
# -----Train----------
# AUC: 98.59 Precision: 99.21 Recall: 98.04
#
# -----Validation-----
# AUC: 97.83 Precision: 96.30 Recall: 100.00
#
# Fold 7
#
# -----Train----------
# AUC: 98.60 Precision: 99.21 Recall: 98.05
#
# -----Validation-----
# AUC: 93.83 Precision: 95.83 Recall: 92.00
#
# Fold 8
#
# -----Train----------
# AUC: 98.58 Precision: 98.82 Recall: 98.44
#
# -----Validation-----
# AUC: 93.83 Precision: 95.83 Recall: 92.00
#
# Fold 9
#
# -----Train----------
# AUC: 99.01 Precision: 99.60 Recall: 98.44
#
# -----Validation-----
# AUC: 91.83 Precision: 95.65 Recall: 88.00
#
# Fold 10
#
# -----Train----------
# AUC: 98.61 Precision: 99.60 Recall: 97.66
#
# -----Validation-----
# AUC: 93.83 Precision: 95.83 Recall: 92.00
#
# Fold 11
#
# -----Train----------
# AUC: 98.60 Precision: 99.21 Recall: 98.05
#
# -----Validation-----
# AUC: 85.30 Precision: 84.62 Recall: 88.00
#
# wheezy-copper-turtle-magic 4
#
# Fold 1
#
# -----Train----------
# AUC: 97.45 Precision: 98.28 Recall: 96.62
#
# -----Validation-----
# AUC: 85.42 Precision: 86.96 Recall: 83.33
#
# Fold 2
#
# -----Train----------
# AUC: 96.16 Precision: 96.60 Recall: 95.78
#
# -----Validation-----
# AUC: 87.50 Precision: 82.14 Recall: 95.83
#
# Fold 3
#
# -----Train----------
# AUC: 96.80 Precision: 97.03 Recall: 96.62
#
# -----Validation-----
# AUC: 89.40 Precision: 91.30 Recall: 87.50
#
# Fold 4
#
# -----Train----------
# AUC: 96.81 Precision: 97.44 Recall: 96.20
#
# -----Validation-----
# AUC: 95.83 Precision: 100.00 Recall: 91.67
#
# Fold 5
#
# -----Train----------
# AUC: 97.23 Precision: 97.86 Recall: 96.62
#
# -----Validation-----
# AUC: 91.58 Precision: 95.45 Recall: 87.50
#
# Fold 6
#
# -----Train----------
# AUC: 97.66 Precision: 98.29 Recall: 97.05
#
# -----Validation-----
# AUC: 87.14 Precision: 84.62 Recall: 91.67
#
# Fold 7
#
# -----Train----------
# AUC: 97.23 Precision: 97.86 Recall: 96.62
#
# -----Validation-----
# AUC: 87.14 Precision: 84.62 Recall: 91.67
#
# Fold 8
#
# -----Train----------
# AUC: 97.66 Precision: 98.29 Recall: 97.05
#
# -----Validation-----
# AUC: 93.57 Precision: 92.00 Recall: 95.83
#
# Fold 9
#
# -----Train----------
# AUC: 97.03 Precision: 97.86 Recall: 96.22
#
# -----Validation-----
# AUC: 97.83 Precision: 100.00 Recall: 95.65
#
# Fold 10
#
# -----Train----------
# AUC: 97.24 Precision: 97.87 Recall: 96.64
#
# -----Validation-----
# AUC: 93.48 Precision: 95.45 Recall: 91.30
#
# Fold 11
#
# -----Train----------
# AUC: 97.66 Precision: 97.89 Recall: 97.48
#
# -----Validation-----
# AUC: 91.30 Precision: 88.00 Recall: 95.65
#
# wheezy-copper-turtle-magic 5
#
# Fold 1
#
# -----Train----------
# AUC: 97.46 Precision: 98.27 Recall: 96.60
#
# -----Validation-----
# AUC: 89.58 Precision: 95.24 Recall: 83.33
#
# Fold 2
#
# -----Train----------
# AUC: 97.45 Precision: 98.69 Recall: 96.17
#
# -----Validation-----
# AUC: 81.25 Precision: 77.78 Recall: 87.50
#
# Fold 3
#
# -----Train----------
# AUC: 97.24 Precision: 98.26 Recall: 96.17
#
# -----Validation-----
# AUC: 93.75 Precision: 95.65 Recall: 91.67
#
# Fold 4
#
# -----Train----------
# AUC: 96.82 Precision: 97.83 Recall: 95.74
#
# -----Validation-----
# AUC: 95.83 Precision: 100.00 Recall: 91.67
#
# Fold 5
#
# -----Train----------
# AUC: 97.24 Precision: 98.26 Recall: 96.17
#
# -----Validation-----
# AUC: 93.75 Precision: 92.00 Recall: 95.83
#
# Fold 6
#
# -----Train----------
# AUC: 97.45 Precision: 98.69 Recall: 96.17
#
# -----Validation-----
# AUC: 95.83 Precision: 95.83 Recall: 95.83
#
# Fold 7
#
# -----Train----------
# AUC: 97.47 Precision: 97.86 Recall: 97.03
#
# -----Validation-----
# AUC: 95.65 Precision: 100.00 Recall: 91.30
#
# Fold 8
#
# -----Train----------
# AUC: 97.25 Precision: 98.27 Recall: 96.19
#
# -----Validation-----
# AUC: 93.48 Precision: 100.00 Recall: 86.96
#
# Fold 9
#
# -----Train----------
# AUC: 97.46 Precision: 98.70 Recall: 96.19
#
# -----Validation-----
# AUC: 95.83 Precision: 92.00 Recall: 100.00
#
# Fold 10
#
# -----Train----------
# AUC: 97.89 Precision: 98.71 Recall: 97.03
#
# -----Validation-----
# AUC: 82.61 Precision: 85.71 Recall: 78.26
#
# Fold 11
#
# -----Train----------
# AUC: 97.04 Precision: 98.26 Recall: 95.76
#
# -----Validation-----
# AUC: 93.48 Precision: 95.45 Recall: 91.30
#
# wheezy-copper-turtle-magic 6
#
# Fold 1
#
# -----Train----------
# AUC: 98.30 Precision: 98.33 Recall: 98.33
#
# -----Validation-----
# AUC: 93.65 Precision: 92.31 Recall: 96.00
#
# Fold 2
#
# -----Train----------
# AUC: 98.29 Precision: 97.94 Recall: 98.76
#
# -----Validation-----
# AUC: 93.75 Precision: 100.00 Recall: 87.50
#
# Fold 3
#
# -----Train----------
# AUC: 98.10 Precision: 98.74 Recall: 97.51
#
# -----Validation-----
# AUC: 97.83 Precision: 96.00 Recall: 100.00
#
# Fold 4
#
# -----Train----------
# AUC: 97.89 Precision: 98.33 Recall: 97.51
#
# -----Validation-----
# AUC: 93.57 Precision: 92.00 Recall: 95.83
#
# Fold 5
#
# -----Train----------
# AUC: 98.30 Precision: 98.34 Recall: 98.34
#
# -----Validation-----
# AUC: 93.66 Precision: 95.65 Recall: 91.67
#
# Fold 6
#
# -----Train----------
# AUC: 98.52 Precision: 98.75 Recall: 98.34
#
# -----Validation-----
# AUC: 93.48 Precision: 88.89 Recall: 100.00
#
# Fold 7
#
# -----Train----------
# AUC: 97.67 Precision: 97.92 Recall: 97.51
#
# -----Validation-----
# AUC: 95.74 Precision: 95.83 Recall: 95.83
#
# Fold 8
#
# -----Train----------
# AUC: 98.09 Precision: 98.33 Recall: 97.93
#
# -----Validation-----
# AUC: 97.83 Precision: 96.00 Recall: 100.00
#
# Fold 9
#
# -----Train----------
# AUC: 98.30 Precision: 98.34 Recall: 98.34
#
# -----Validation-----
# AUC: 97.92 Precision: 100.00 Recall: 95.83
#
# Fold 10
#
# -----Train----------
# AUC: 98.30 Precision: 98.34 Recall: 98.34
#
# -----Validation-----
# AUC: 95.83 Precision: 100.00 Recall: 91.67
#
# Fold 11
#
# -----Train----------
# AUC: 98.31 Precision: 98.74 Recall: 97.93
#
# -----Validation-----
# AUC: 93.57 Precision: 92.00 Recall: 95.83
#
# wheezy-copper-turtle-magic 7
#
# Fold 1
#
# -----Train----------
# AUC: 98.04 Precision: 97.42 Recall: 98.70
#
# -----Validation-----
# AUC: 91.58 Precision: 95.45 Recall: 87.50
#
# Fold 2
#
# -----Train----------
# AUC: 97.39 Precision: 97.82 Recall: 96.97
#
# -----Validation-----
# AUC: 86.96 Precision: 90.48 Recall: 82.61
#
# Fold 3
#
# -----Train----------
# AUC: 97.39 Precision: 97.82 Recall: 96.97
#
# -----Validation-----
# AUC: 89.13 Precision: 87.50 Recall: 91.30
#
# Fold 4
#
# -----Train----------
# AUC: 97.83 Precision: 98.68 Recall: 96.97
#
# -----Validation-----
# AUC: 84.78 Precision: 83.33 Recall: 86.96
#
# Fold 5
#
# -----Train----------
# AUC: 97.39 Precision: 97.00 Recall: 97.84
#
# -----Validation-----
# AUC: 91.30 Precision: 91.30 Recall: 91.30
#
# Fold 6
#
# -----Train----------
# AUC: 98.26 Precision: 98.27 Recall: 98.27
#
# -----Validation-----
# AUC: 91.30 Precision: 91.30 Recall: 91.30
#
# Fold 7
#
# -----Train----------
# AUC: 97.61 Precision: 97.41 Recall: 97.84
#
# -----Validation-----
# AUC: 89.13 Precision: 90.91 Recall: 86.96
#
# Fold 8
#
# -----Train----------
# AUC: 97.83 Precision: 97.84 Recall: 97.84
#
# -----Validation-----
# AUC: 91.30 Precision: 95.24 Recall: 86.96
#
# Fold 9
#
# -----Train----------
# AUC: 97.83 Precision: 98.68 Recall: 96.97
#
# -----Validation-----
# AUC: 93.48 Precision: 91.67 Recall: 95.65
#
# Fold 10
#
# -----Train----------
# AUC: 98.04 Precision: 97.84 Recall: 98.27
#
# -----Validation-----
# AUC: 82.61 Precision: 80.00 Recall: 86.96
#
# Fold 11
#
# -----Train----------
# AUC: 98.05 Precision: 98.26 Recall: 97.84
#
# -----Validation-----
# AUC: 88.93 Precision: 90.91 Recall: 86.96
#
# wheezy-copper-turtle-magic 8
#
# Fold 1
#
# -----Train----------
# AUC: 97.66 Precision: 97.14 Recall: 98.35
#
# -----Validation-----
# AUC: 96.00 Precision: 100.00 Recall: 92.00
#
# Fold 2
#
# -----Train----------
# AUC: 98.09 Precision: 97.94 Recall: 98.35
#
# -----Validation-----
# AUC: 97.92 Precision: 96.15 Recall: 100.00
#
# Fold 3
#
# -----Train----------
# AUC: 97.89 Precision: 97.93 Recall: 97.93
#
# -----Validation-----
# AUC: 89.83 Precision: 95.45 Recall: 84.00
#
# Fold 4
#
# -----Train----------
# AUC: 98.11 Precision: 98.35 Recall: 97.94
#
# -----Validation-----
# AUC: 93.66 Precision: 95.65 Recall: 91.67
#
# Fold 5
#
# -----Train----------
# AUC: 98.31 Precision: 98.35 Recall: 98.35
#
# -----Validation-----
# AUC: 93.57 Precision: 92.00 Recall: 95.83
#
# Fold 6
#
# -----Train----------
# AUC: 97.68 Precision: 97.54 Recall: 97.94
#
# -----Validation-----
# AUC: 91.58 Precision: 95.45 Recall: 87.50
#
# Fold 7
#
# -----Train----------
# AUC: 97.89 Precision: 97.94 Recall: 97.94
#
# -----Validation-----
# AUC: 97.92 Precision: 100.00 Recall: 95.83
#
# Fold 8
#
# -----Train----------
# AUC: 97.90 Precision: 98.34 Recall: 97.53
#
# -----Validation-----
# AUC: 89.40 Precision: 91.30 Recall: 87.50
#
# Fold 9
#
# -----Train----------
# AUC: 98.31 Precision: 98.35 Recall: 98.35
#
# -----Validation-----
# AUC: 85.24 Precision: 90.48 Recall: 79.17
#
# Fold 10
#
# -----Train----------
# AUC: 98.31 Precision: 98.35 Recall: 98.35
#
# -----Validation-----
# AUC: 89.40 Precision: 91.30 Recall: 87.50
#
# Fold 11
#
# -----Train----------
# AUC: 97.88 Precision: 97.55 Recall: 98.35
#
# -----Validation-----
# AUC: 97.92 Precision: 100.00 Recall: 95.83
#
# wheezy-copper-turtle-magic 9
#
# Fold 1
#
# -----Train----------
# AUC: 97.50 Precision: 98.31 Recall: 96.67
#
# -----Validation-----
# AUC: 91.67 Precision: 91.67 Recall: 91.67
#
# Fold 2
#
# -----Train----------
# AUC: 97.29 Precision: 97.49 Recall: 97.08
#
# -----Validation-----
# AUC: 97.92 Precision: 100.00 Recall: 95.83
#
# Fold 3
#
# -----Train----------
# AUC: 96.88 Precision: 97.87 Recall: 95.83
#
# -----Validation-----
# AUC: 93.75 Precision: 95.65 Recall: 91.67
#
# Fold 4
#
# -----Train----------
# AUC: 97.08 Precision: 97.88 Recall: 96.25
#
# -----Validation-----
# AUC: 95.83 Precision: 95.83 Recall: 95.83
#
# Fold 5
#
# -----Train----------
# AUC: 96.88 Precision: 97.87 Recall: 95.83
#
# -----Validation-----
# AUC: 95.83 Precision: 100.00 Recall: 91.67
#
# Fold 6
#
# -----Train----------
# AUC: 97.50 Precision: 98.31 Recall: 96.67
#
# -----Validation-----
# AUC: 95.83 Precision: 95.83 Recall: 95.83
#
# Fold 7
#
# -----Train----------
# AUC: 97.08 Precision: 98.29 Recall: 95.83
#
# -----Validation-----
# AUC: 85.42 Precision: 81.48 Recall: 91.67
#
# Fold 8
#
# -----Train----------
# AUC: 98.12 Precision: 99.15 Recall: 97.08
#
# -----Validation-----
# AUC: 85.42 Precision: 94.74 Recall: 75.00
#
# Fold 9
#
# -----Train----------
# AUC: 96.67 Precision: 97.86 Recall: 95.42
#
# -----Validation-----
# AUC: 91.67 Precision: 91.67 Recall: 91.67
#
# Fold 10
#
# -----Train----------
# AUC: 97.08 Precision: 98.29 Recall: 95.83
#
# -----Validation-----
# AUC: 93.75 Precision: 95.65 Recall: 91.67
#
# Fold 11
#
# -----Train----------
# AUC: 96.67 Precision: 97.86 Recall: 95.42
#
# -----Validation-----
# AUC: 97.92 Precision: 100.00 Recall: 95.83
#
# wheezy-copper-turtle-magic 10
#
# Fold 1
#
# -----Train----------
# AUC: 98.46 Precision: 97.79 Recall: 99.10
#
# -----Validation-----
# AUC: 95.65 Precision: 95.65 Recall: 95.65
#
# Fold 2
#
# -----Train----------
# AUC: 98.68 Precision: 98.22 Recall: 99.10
#
# -----Validation-----
# AUC: 95.65 Precision: 92.00 Recall: 100.00
#
# Fold 3
#
# -----Train----------
# AUC: 98.24 Precision: 97.36 Recall: 99.10
#
# -----Validation-----
# AUC: 93.48 Precision: 95.45 Recall: 91.30
#
# Fold 4
#
# -----Train----------
# AUC: 98.02 Precision: 96.93 Recall: 99.10
#
# -----Validation-----
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# Fold 5
#
# -----Train----------
# AUC: 98.46 Precision: 97.80 Recall: 99.11
#
# -----Validation-----
# AUC: 88.93 Precision: 86.96 Recall: 90.91
#
# Fold 6
#
# -----Train----------
# AUC: 98.24 Precision: 97.79 Recall: 98.66
#
# -----Validation-----
# AUC: 88.83 Precision: 90.48 Recall: 86.36
#
# Fold 7
#
# -----Train----------
# AUC: 98.24 Precision: 97.37 Recall: 99.11
#
# -----Validation-----
# AUC: 91.11 Precision: 90.91 Recall: 90.91
#
# Fold 8
#
# -----Train----------
# AUC: 98.03 Precision: 96.94 Recall: 99.11
#
# -----Validation-----
# AUC: 93.28 Precision: 95.24 Recall: 90.91
#
# Fold 9
#
# -----Train----------
# AUC: 98.03 Precision: 96.94 Recall: 99.11
#
# -----Validation-----
# AUC: 95.45 Precision: 100.00 Recall: 90.91
#
# Fold 10
#
# -----Train----------
# AUC: 97.81 Precision: 96.52 Recall: 99.11
#
# -----Validation-----
# AUC: 95.65 Precision: 91.67 Recall: 100.00
#
# Fold 11
#
# -----Train----------
# AUC: 98.69 Precision: 97.81 Recall: 99.55
#
# -----Validation-----
# AUC: 88.64 Precision: 94.74 Recall: 81.82
#
# wheezy-copper-turtle-magic 11
#
# Fold 1
#
# -----Train----------
# AUC: 97.73 Precision: 97.17 Recall: 98.10
#
# -----Validation-----
# AUC: 91.11 Precision: 90.91 Recall: 90.91
#
# Fold 2
#
# -----Train----------
# AUC: 97.95 Precision: 97.64 Recall: 98.10
#
# -----Validation-----
# AUC: 95.45 Precision: 95.24 Recall: 95.24
#
# Fold 3
#
# -----Train----------
# AUC: 98.19 Precision: 97.65 Recall: 98.58
#
# -----Validation-----
# AUC: 97.62 Precision: 100.00 Recall: 95.24
#
# Fold 4
#
# -----Train----------
# AUC: 97.95 Precision: 97.64 Recall: 98.10
#
# -----Validation-----
# AUC: 93.06 Precision: 95.00 Recall: 90.48
#
# Fold 5
#
# -----Train----------
# AUC: 98.17 Precision: 98.10 Recall: 98.10
#
# -----Validation-----
# AUC: 88.51 Precision: 90.00 Recall: 85.71
#
# Fold 6
#
# -----Train----------
# AUC: 97.71 Precision: 97.63 Recall: 97.63
#
# -----Validation-----
# AUC: 97.83 Precision: 95.45 Recall: 100.00
#
# Fold 7
#
# -----Train----------
# AUC: 97.71 Precision: 97.63 Recall: 97.63
#
# -----Validation-----
# AUC: 95.45 Precision: 95.24 Recall: 95.24
#
# Fold 8
#
# -----Train----------
# AUC: 97.26 Precision: 97.16 Recall: 97.16
#
# -----Validation-----
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# Fold 9
#
# -----Train----------
# AUC: 98.16 Precision: 98.56 Recall: 97.63
#
# -----Validation-----
# AUC: 90.91 Precision: 84.00 Recall: 100.00
#
# Fold 10
#
# -----Train----------
# AUC: 97.26 Precision: 97.16 Recall: 97.16
#
# -----Validation-----
# AUC: 95.24 Precision: 100.00 Recall: 90.48
#
# Fold 11
#
# -----Train----------
# AUC: 97.48 Precision: 97.62 Recall: 97.16
#
# -----Validation-----
# AUC: 95.35 Precision: 95.24 Recall: 95.24
#
# wheezy-copper-turtle-magic 12
#
# Fold 1
#
# -----Train----------
# AUC: 97.78 Precision: 98.23 Recall: 97.37
#
# -----Validation-----
# AUC: 95.65 Precision: 100.00 Recall: 91.30
#
# Fold 2
#
# -----Train----------
# AUC: 96.01 Precision: 96.88 Recall: 95.18
#
# -----Validation-----
# AUC: 95.65 Precision: 95.65 Recall: 95.65
#
# Fold 3
#
# -----Train----------
# AUC: 97.79 Precision: 98.66 Recall: 96.93
#
# -----Validation-----
# AUC: 95.65 Precision: 95.65 Recall: 95.65
#
# Fold 4
#
# -----Train----------
# AUC: 97.79 Precision: 98.66 Recall: 96.93
#
# -----Validation-----
# AUC: 97.73 Precision: 95.83 Recall: 100.00
#
# Fold 5
#
# -----Train----------
# AUC: 97.35 Precision: 98.65 Recall: 96.05
#
# -----Validation-----
# AUC: 93.28 Precision: 91.67 Recall: 95.65
#
# Fold 6
#
# -----Train----------
# AUC: 97.79 Precision: 98.66 Recall: 96.93
#
# -----Validation-----
# AUC: 93.18 Precision: 88.46 Recall: 100.00
#
# Fold 7
#
# -----Train----------
# AUC: 97.79 Precision: 98.23 Recall: 97.37
#
# -----Validation-----
# AUC: 82.51 Precision: 94.12 Recall: 69.57
#
# Fold 8
#
# -----Train----------
# AUC: 97.35 Precision: 98.21 Recall: 96.49
#
# -----Validation-----
# AUC: 95.45 Precision: 92.00 Recall: 100.00
#
# Fold 9
#
# -----Train----------
# AUC: 98.68 Precision: 99.55 Recall: 97.81
#
# -----Validation-----
# AUC: 93.48 Precision: 100.00 Recall: 86.96
#
# Fold 10
#
# -----Train----------
# AUC: 97.14 Precision: 98.21 Recall: 96.07
#
# -----Validation-----
# AUC: 97.73 Precision: 95.65 Recall: 100.00
#
# Fold 11
#
# -----Train----------
# AUC: 98.02 Precision: 98.67 Recall: 97.38
#
# -----Validation-----
# AUC: 86.36 Precision: 90.00 Recall: 81.82
#
# wheezy-copper-turtle-magic 13
#
# Fold 1
#
# -----Train----------
# AUC: 97.72 Precision: 97.65 Recall: 97.65
#
# -----Validation-----
# AUC: 97.83 Precision: 95.65 Recall: 100.00
#
# Fold 2
#
# -----Train----------
# AUC: 98.19 Precision: 97.67 Recall: 98.59
#
# -----Validation-----
# AUC: 91.11 Precision: 90.91 Recall: 90.91
#
# Fold 3
#
# -----Train----------
# AUC: 97.74 Precision: 97.21 Recall: 98.12
#
# -----Validation-----
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# Fold 4
#
# -----Train----------
# AUC: 97.50 Precision: 97.20 Recall: 97.65
#
# -----Validation-----
# AUC: 91.11 Precision: 90.91 Recall: 90.91
#
# Fold 5
#
# -----Train----------
# AUC: 97.95 Precision: 98.12 Recall: 97.66
#
# -----Validation-----
# AUC: 90.68 Precision: 94.74 Recall: 85.71
#
# Fold 6
#
# -----Train----------
# AUC: 97.28 Precision: 97.20 Recall: 97.20
#
# -----Validation-----
# AUC: 93.27 Precision: 90.91 Recall: 95.24
#
# Fold 7
#
# -----Train----------
# AUC: 97.95 Precision: 98.12 Recall: 97.66
#
# -----Validation-----
# AUC: 93.27 Precision: 90.91 Recall: 95.24
#
# Fold 8
#
# -----Train----------
# AUC: 97.73 Precision: 97.66 Recall: 97.66
#
# -----Validation-----
# AUC: 97.83 Precision: 95.45 Recall: 100.00
#
# Fold 9
#
# -----Train----------
# AUC: 97.76 Precision: 96.79 Recall: 98.60
#
# -----Validation-----
# AUC: 92.97 Precision: 95.00 Recall: 90.48
#
# Fold 10
#
# -----Train----------
# AUC: 98.22 Precision: 97.25 Recall: 99.07
#
# -----Validation-----
# AUC: 88.31 Precision: 90.00 Recall: 85.71
#
# Fold 11
#
# -----Train----------
# AUC: 97.52 Precision: 97.21 Recall: 97.66
#
# -----Validation-----
# AUC: 92.97 Precision: 95.00 Recall: 90.48
#
# wheezy-copper-turtle-magic 14
#
# Fold 1
#
# -----Train----------
# AUC: 98.85 Precision: 99.03 Recall: 98.55
#
# -----Validation-----
# AUC: 88.39 Precision: 94.44 Recall: 80.95
#
# Fold 2
#
# -----Train----------
# AUC: 98.39 Precision: 98.54 Recall: 98.07
#
# -----Validation-----
# AUC: 95.24 Precision: 100.00 Recall: 90.48
#
# Fold 3
#
# -----Train----------
# AUC: 98.85 Precision: 99.03 Recall: 98.55
#
# -----Validation-----
# AUC: 95.54 Precision: 95.24 Recall: 95.24
#
# Fold 4
#
# -----Train----------
# AUC: 98.88 Precision: 98.56 Recall: 99.03
#
# -----Validation-----
# AUC: 95.54 Precision: 95.24 Recall: 95.24
#
# Fold 5
#
# -----Train----------
# AUC: 98.39 Precision: 98.54 Recall: 98.07
#
# -----Validation-----
# AUC: 93.15 Precision: 95.00 Recall: 90.48
#
# Fold 6
#
# -----Train----------
# AUC: 99.09 Precision: 99.03 Recall: 99.03
#
# -----Validation-----
# AUC: 97.83 Precision: 95.45 Recall: 100.00
#
# Fold 7
#
# -----Train----------
# AUC: 98.40 Precision: 98.54 Recall: 98.07
#
# -----Validation-----
# AUC: 92.86 Precision: 100.00 Recall: 85.71
#
# Fold 8
#
# -----Train----------
# AUC: 99.09 Precision: 99.03 Recall: 99.03
#
# -----Validation-----
# AUC: 93.06 Precision: 95.00 Recall: 90.48
#
# Fold 9
#
# -----Train----------
# AUC: 98.85 Precision: 99.03 Recall: 98.56
#
# -----Validation-----
# AUC: 92.83 Precision: 94.74 Recall: 90.00
#
# Fold 10
#
# -----Train----------
# AUC: 99.09 Precision: 99.04 Recall: 99.04
#
# -----Validation-----
# AUC: 93.15 Precision: 90.48 Recall: 95.00
#
# Fold 11
#
# -----Train----------
# AUC: 98.85 Precision: 99.03 Recall: 98.56
#
# -----Validation-----
# AUC: 92.50 Precision: 100.00 Recall: 85.00
#
# wheezy-copper-turtle-magic 15
#
# Fold 1
#
# -----Train----------
# AUC: 97.44 Precision: 97.87 Recall: 97.05
#
# -----Validation-----
# AUC: 91.67 Precision: 91.67 Recall: 91.67
#
# Fold 2
#
# -----Train----------
# AUC: 98.07 Precision: 97.90 Recall: 98.31
#
# -----Validation-----
# AUC: 95.83 Precision: 100.00 Recall: 91.67
#
# Fold 3
#
# -----Train----------
# AUC: 98.08 Precision: 98.31 Recall: 97.89
#
# -----Validation-----
# AUC: 95.65 Precision: 92.31 Recall: 100.00
#
# Fold 4
#
# -----Train----------
# AUC: 97.45 Precision: 97.87 Recall: 97.05
#
# -----Validation-----
# AUC: 97.92 Precision: 100.00 Recall: 95.83
#
# Fold 5
#
# -----Train----------
# AUC: 98.08 Precision: 98.31 Recall: 97.89
#
# -----Validation-----
# AUC: 87.14 Precision: 84.62 Recall: 91.67
#
# Fold 6
#
# -----Train----------
# AUC: 97.66 Precision: 97.88 Recall: 97.47
#
# -----Validation-----
# AUC: 91.49 Precision: 91.67 Recall: 91.67
#
# Fold 7
#
# -----Train----------
# AUC: 97.88 Precision: 98.71 Recall: 97.05
#
# -----Validation-----
# AUC: 93.48 Precision: 88.89 Recall: 100.00
#
# Fold 8
#
# -----Train----------
# AUC: 98.08 Precision: 97.90 Recall: 98.31
#
# -----Validation-----
# AUC: 91.58 Precision: 95.45 Recall: 87.50
#
# Fold 9
#
# -----Train----------
# AUC: 98.30 Precision: 98.73 Recall: 97.90
#
# -----Validation-----
# AUC: 95.65 Precision: 92.00 Recall: 100.00
#
# Fold 10
#
# -----Train----------
# AUC: 98.30 Precision: 98.73 Recall: 97.90
#
# -----Validation-----
# AUC: 86.96 Precision: 86.96 Recall: 86.96
#
# Fold 11
#
# -----Train----------
# AUC: 97.88 Precision: 98.31 Recall: 97.48
#
# -----Validation-----
# AUC: 93.48 Precision: 91.67 Recall: 95.65
#
# wheezy-copper-turtle-magic 16
#
# Fold 1
#
# -----Train----------
# AUC: 97.02 Precision: 96.52 Recall: 97.37
#
# -----Validation-----
# AUC: 95.83 Precision: 95.65 Recall: 95.65
#
# Fold 2
#
# -----Train----------
# AUC: 97.43 Precision: 97.79 Recall: 96.93
#
# -----Validation-----
# AUC: 94.00 Precision: 88.46 Recall: 100.00
#
# Fold 3
#
# -----Train----------
# AUC: 97.65 Precision: 97.80 Recall: 97.37
#
# -----Validation-----
# AUC: 93.66 Precision: 91.67 Recall: 95.65
#
# Fold 4
#
# -----Train----------
# AUC: 97.44 Precision: 97.37 Recall: 97.37
#
# -----Validation-----
# AUC: 93.66 Precision: 91.67 Recall: 95.65
#
# Fold 5
#
# -----Train----------
# AUC: 97.46 Precision: 96.96 Recall: 97.81
#
# -----Validation-----
# AUC: 93.66 Precision: 91.67 Recall: 95.65
#
# Fold 6
#
# -----Train----------
# AUC: 97.02 Precision: 96.93 Recall: 96.93
#
# -----Validation-----
# AUC: 95.74 Precision: 95.65 Recall: 95.65
#
# Fold 7
#
# -----Train----------
# AUC: 97.24 Precision: 96.94 Recall: 97.37
#
# -----Validation-----
# AUC: 91.30 Precision: 100.00 Recall: 82.61
#
# Fold 8
#
# -----Train----------
# AUC: 97.66 Precision: 97.38 Recall: 97.81
#
# -----Validation-----
# AUC: 93.57 Precision: 95.45 Recall: 91.30
#
# Fold 9
#
# -----Train----------
# AUC: 97.66 Precision: 97.38 Recall: 97.81
#
# -----Validation-----
# AUC: 93.57 Precision: 95.45 Recall: 91.30
#
# Fold 10
#
# -----Train----------
# AUC: 97.45 Precision: 97.38 Recall: 97.38
#
# -----Validation-----
# AUC: 93.56 Precision: 91.30 Recall: 95.45
#
# Fold 11
#
# -----Train----------
# AUC: 97.24 Precision: 96.96 Recall: 97.38
#
# -----Validation-----
# AUC: 95.64 Precision: 95.45 Recall: 95.45
#
# wheezy-copper-turtle-magic 17
#
# Fold 1
#
# -----Train----------
# AUC: 97.84 Precision: 97.90 Recall: 97.90
#
# -----Validation-----
# AUC: 95.74 Precision: 95.83 Recall: 95.83
#
# Fold 2
#
# -----Train----------
# AUC: 97.64 Precision: 98.30 Recall: 97.06
#
# -----Validation-----
# AUC: 93.66 Precision: 95.65 Recall: 91.67
#
# Fold 3
#
# -----Train----------
# AUC: 97.84 Precision: 97.90 Recall: 97.90
#
# -----Validation-----
# AUC: 89.22 Precision: 85.19 Recall: 95.83
#
# Fold 4
#
# -----Train----------
# AUC: 97.84 Precision: 97.90 Recall: 97.90
#
# -----Validation-----
# AUC: 97.92 Precision: 100.00 Recall: 95.83
#
# Fold 5
#
# -----Train----------
# AUC: 98.26 Precision: 97.92 Recall: 98.74
#
# -----Validation-----
# AUC: 93.66 Precision: 95.65 Recall: 91.67
#
# Fold 6
#
# -----Train----------
# AUC: 98.27 Precision: 98.32 Recall: 98.32
#
# -----Validation-----
# AUC: 93.48 Precision: 88.89 Recall: 100.00
#
# Fold 7
#
# -----Train----------
# AUC: 97.63 Precision: 97.89 Recall: 97.48
#
# -----Validation-----
# AUC: 97.92 Precision: 100.00 Recall: 95.83
#
# Fold 8
#
# -----Train----------
# AUC: 97.86 Precision: 98.31 Recall: 97.48
#
# -----Validation-----
# AUC: 93.37 Precision: 92.00 Recall: 95.83
#
# Fold 9
#
# -----Train----------
# AUC: 97.85 Precision: 97.90 Recall: 97.90
#
# -----Validation-----
# AUC: 91.29 Precision: 91.67 Recall: 91.67
#
# Fold 10
#
# -----Train----------
# AUC: 97.86 Precision: 98.31 Recall: 97.49
#
# -----Validation-----
# AUC: 91.11 Precision: 91.30 Recall: 91.30
#
# Fold 11
#
# -----Train----------
# AUC: 97.85 Precision: 97.91 Recall: 97.91
#
# -----Validation-----
# AUC: 91.11 Precision: 91.30 Recall: 91.30
#
# wheezy-copper-turtle-magic 18
#
# Fold 1
#
# -----Train----------
# AUC: 98.94 Precision: 99.16 Recall: 98.75
#
# -----Validation-----
# AUC: 98.00 Precision: 100.00 Recall: 96.00
#
# Fold 2
#
# -----Train----------
# AUC: 98.74 Precision: 99.16 Recall: 98.34
#
# -----Validation-----
# AUC: 95.74 Precision: 95.83 Recall: 95.83
#
# Fold 3
#
# -----Train----------
# AUC: 98.53 Precision: 99.16 Recall: 97.93
#
# -----Validation-----
# AUC: 93.57 Precision: 92.00 Recall: 95.83
#
# Fold 4
#
# -----Train----------
# AUC: 98.52 Precision: 98.75 Recall: 98.34
#
# -----Validation-----
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# Fold 5
#
# -----Train----------
# AUC: 99.16 Precision: 99.58 Recall: 98.76
#
# -----Validation-----
# AUC: 87.14 Precision: 84.62 Recall: 91.67
#
# Fold 6
#
# -----Train----------
# AUC: 97.89 Precision: 98.33 Recall: 97.51
#
# -----Validation-----
# AUC: 97.92 Precision: 100.00 Recall: 95.83
#
# Fold 7
#
# -----Train----------
# AUC: 98.74 Precision: 99.16 Recall: 98.34
#
# -----Validation-----
# AUC: 93.66 Precision: 95.65 Recall: 91.67
#
# Fold 8
#
# -----Train----------
# AUC: 98.52 Precision: 98.75 Recall: 98.34
#
# -----Validation-----
# AUC: 97.92 Precision: 100.00 Recall: 95.83
#
# Fold 9
#
# -----Train----------
# AUC: 98.31 Precision: 98.74 Recall: 97.93
#
# -----Validation-----
# AUC: 95.65 Precision: 92.31 Recall: 100.00
#
# Fold 10
#
# -----Train----------
# AUC: 98.53 Precision: 99.16 Recall: 97.93
#
# -----Validation-----
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# Fold 11
#
# -----Train----------
# AUC: 99.16 Precision: 99.58 Recall: 98.76
#
# -----Validation-----
# AUC: 93.57 Precision: 92.00 Recall: 95.83
#
# wheezy-copper-turtle-magic 19
#
# Fold 1
#
# -----Train----------
# AUC: 98.32 Precision: 98.33 Recall: 98.33
#
# -----Validation-----
# AUC: 91.75 Precision: 88.89 Recall: 96.00
#
# Fold 2
#
# -----Train----------
# AUC: 98.12 Precision: 97.93 Recall: 98.34
#
# -----Validation-----
# AUC: 95.83 Precision: 100.00 Recall: 91.67
#
# Fold 3
#
# -----Train----------
# AUC: 98.96 Precision: 99.17 Recall: 98.76
#
# -----Validation-----
# AUC: 85.42 Precision: 90.48 Recall: 79.17
#
# Fold 4
#
# -----Train----------
# AUC: 98.12 Precision: 98.33 Recall: 97.93
#
# -----Validation-----
# AUC: 93.75 Precision: 92.00 Recall: 95.83
#
# Fold 5
#
# -----Train----------
# AUC: 97.49 Precision: 97.51 Recall: 97.51
#
# -----Validation-----
# AUC: 91.67 Precision: 88.46 Recall: 95.83
#
# Fold 6
#
# -----Train----------
# AUC: 98.12 Precision: 97.93 Recall: 98.34
#
# -----Validation-----
# AUC: 95.83 Precision: 95.83 Recall: 95.83
#
# Fold 7
#
# -----Train----------
# AUC: 97.91 Precision: 98.33 Recall: 97.51
#
# -----Validation-----
# AUC: 93.75 Precision: 92.00 Recall: 95.83
#
# Fold 8
#
# -----Train----------
# AUC: 98.12 Precision: 98.74 Recall: 97.51
#
# -----Validation-----
# AUC: 91.67 Precision: 85.71 Recall: 100.00
#
# Fold 9
#
# -----Train----------
# AUC: 98.33 Precision: 98.34 Recall: 98.34
#
# -----Validation-----
# AUC: 91.30 Precision: 85.71 Recall: 100.00
#
# Fold 10
#
# -----Train----------
# AUC: 98.12 Precision: 97.93 Recall: 98.34
#
# -----Validation-----
# AUC: 93.66 Precision: 95.65 Recall: 91.67
#
# Fold 11
#
# -----Train----------
# AUC: 98.33 Precision: 97.94 Recall: 98.76
#
# -----Validation-----
# AUC: 91.58 Precision: 95.45 Recall: 87.50
#
# wheezy-copper-turtle-magic 20
#
# Fold 1
#
# -----Train----------
# AUC: 97.63 Precision: 97.32 Recall: 97.76
#
# -----Validation-----
# AUC: 85.13 Precision: 90.00 Recall: 78.26
#
# Fold 2
#
# -----Train----------
# AUC: 97.22 Precision: 96.46 Recall: 97.76
#
# -----Validation-----
# AUC: 91.48 Precision: 95.24 Recall: 86.96
#
# Fold 3
#
# -----Train----------
# AUC: 98.09 Precision: 97.35 Recall: 98.65
#
# -----Validation-----
# AUC: 87.14 Precision: 90.48 Recall: 82.61
#
# Fold 4
#
# -----Train----------
# AUC: 97.62 Precision: 97.75 Recall: 97.31
#
# -----Validation-----
# AUC: 91.67 Precision: 85.19 Recall: 100.00
#
# Fold 5
#
# -----Train----------
# AUC: 97.21 Precision: 96.89 Recall: 97.32
#
# -----Validation-----
# AUC: 87.12 Precision: 83.33 Recall: 90.91
#
# Fold 6
#
# -----Train----------
# AUC: 96.82 Precision: 95.63 Recall: 97.77
#
# -----Validation-----
# AUC: 95.64 Precision: 95.45 Recall: 95.45
#
# Fold 7
#
# -----Train----------
# AUC: 97.63 Precision: 97.76 Recall: 97.32
#
# -----Validation-----
# AUC: 93.56 Precision: 91.30 Recall: 95.45
#
# Fold 8
#
# -----Train----------
# AUC: 97.44 Precision: 96.90 Recall: 97.77
#
# -----Validation-----
# AUC: 97.92 Precision: 95.65 Recall: 100.00
#
# Fold 9
#
# -----Train----------
# AUC: 97.66 Precision: 96.92 Recall: 98.21
#
# -----Validation-----
# AUC: 93.56 Precision: 91.30 Recall: 95.45
#
# Fold 10
#
# -----Train----------
# AUC: 97.66 Precision: 96.92 Recall: 98.21
#
# -----Validation-----
# AUC: 91.10 Precision: 95.00 Recall: 86.36
#
# Fold 11
#
# -----Train----------
# AUC: 97.66 Precision: 96.92 Recall: 98.21
#
# -----Validation-----
# AUC: 91.10 Precision: 95.00 Recall: 86.36
#
# wheezy-copper-turtle-magic 21
#
# Fold 1
#
# -----Train----------
# AUC: 97.52 Precision: 97.55 Recall: 97.55
#
# -----Validation-----
# AUC: 97.92 Precision: 96.15 Recall: 100.00
#
# Fold 2
#
# -----Train----------
# AUC: 97.72 Precision: 97.56 Recall: 97.96
#
# -----Validation-----
# AUC: 91.83 Precision: 92.00 Recall: 92.00
#
# Fold 3
#
# -----Train----------
# AUC: 97.31 Precision: 97.54 Recall: 97.14
#
# -----Validation-----
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# Fold 4
#
# -----Train----------
# AUC: 97.31 Precision: 97.54 Recall: 97.14
#
# -----Validation-----
# AUC: 83.67 Precision: 84.00 Recall: 84.00
#
# Fold 5
#
# -----Train----------
# AUC: 97.53 Precision: 98.34 Recall: 96.73
#
# -----Validation-----
# AUC: 97.92 Precision: 96.15 Recall: 100.00
#
# Fold 6
#
# -----Train----------
# AUC: 97.52 Precision: 97.55 Recall: 97.55
#
# -----Validation-----
# AUC: 95.92 Precision: 96.00 Recall: 96.00
#
# Fold 7
#
# -----Train----------
# AUC: 97.31 Precision: 97.17 Recall: 97.56
#
# -----Validation-----
# AUC: 91.67 Precision: 95.45 Recall: 87.50
#
# Fold 8
#
# -----Train----------
# AUC: 97.53 Precision: 98.35 Recall: 96.75
#
# -----Validation-----
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# Fold 9
#
# -----Train----------
# AUC: 97.73 Precision: 97.96 Recall: 97.56
#
# -----Validation-----
# AUC: 91.67 Precision: 91.67 Recall: 91.67
#
# Fold 10
#
# -----Train----------
# AUC: 97.94 Precision: 97.97 Recall: 97.97
#
# -----Validation-----
# AUC: 95.83 Precision: 100.00 Recall: 91.67
#
# Fold 11
#
# -----Train----------
# AUC: 97.73 Precision: 97.57 Recall: 97.97
#
# -----Validation-----
# AUC: 89.40 Precision: 91.30 Recall: 87.50
#
# wheezy-copper-turtle-magic 22
#
# Fold 1
#
# -----Train----------
# AUC: 98.14 Precision: 98.02 Recall: 98.41
#
# -----Validation-----
# AUC: 89.90 Precision: 88.89 Recall: 92.31
#
# Fold 2
#
# -----Train----------
# AUC: 98.57 Precision: 98.80 Recall: 98.41
#
# -----Validation-----
# AUC: 93.91 Precision: 92.59 Recall: 96.15
#
# Fold 3
#
# -----Train----------
# AUC: 98.13 Precision: 97.65 Recall: 98.81
#
# -----Validation-----
# AUC: 95.83 Precision: 92.59 Recall: 100.00
#
# Fold 4
#
# -----Train----------
# AUC: 97.94 Precision: 97.64 Recall: 98.41
#
# -----Validation-----
# AUC: 98.00 Precision: 100.00 Recall: 96.00
#
# Fold 5
#
# -----Train----------
# AUC: 97.95 Precision: 98.02 Recall: 98.02
#
# -----Validation-----
# AUC: 95.92 Precision: 96.00 Recall: 96.00
#
# Fold 6
#
# -----Train----------
# AUC: 97.74 Precision: 97.63 Recall: 98.02
#
# -----Validation-----
# AUC: 98.00 Precision: 100.00 Recall: 96.00
#
# Fold 7
#
# -----Train----------
# AUC: 97.94 Precision: 97.64 Recall: 98.41
#
# -----Validation-----
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# Fold 8
#
# -----Train----------
# AUC: 97.94 Precision: 97.64 Recall: 98.41
#
# -----Validation-----
# AUC: 94.00 Precision: 100.00 Recall: 88.00
#
# Fold 9
#
# -----Train----------
# AUC: 98.77 Precision: 98.81 Recall: 98.81
#
# -----Validation-----
# AUC: 93.65 Precision: 92.31 Recall: 96.00
#
# Fold 10
#
# -----Train----------
# AUC: 98.15 Precision: 98.02 Recall: 98.41
#
# -----Validation-----
# AUC: 91.48 Precision: 88.89 Recall: 96.00
#
# Fold 11
#
# -----Train----------
# AUC: 97.94 Precision: 97.64 Recall: 98.41
#
# -----Validation-----
# AUC: 98.00 Precision: 100.00 Recall: 96.00
#
# wheezy-copper-turtle-magic 23
#
# Fold 1
#
# -----Train----------
# AUC: 98.32 Precision: 99.16 Recall: 97.51
#
# -----Validation-----
# AUC: 95.83 Precision: 92.59 Recall: 100.00
#
# Fold 2
#
# -----Train----------
# AUC: 98.12 Precision: 99.15 Recall: 97.10
#
# -----Validation-----
# AUC: 94.00 Precision: 100.00 Recall: 88.00
#
# Fold 3
#
# -----Train----------
# AUC: 98.11 Precision: 98.74 Recall: 97.52
#
# -----Validation-----
# AUC: 89.58 Precision: 88.00 Recall: 91.67
#
# Fold 4
#
# -----Train----------
# AUC: 98.34 Precision: 99.58 Recall: 97.11
#
# -----Validation-----
# AUC: 87.05 Precision: 82.14 Recall: 95.83
#
# Fold 5
#
# -----Train----------
# AUC: 98.12 Precision: 99.16 Recall: 97.11
#
# -----Validation-----
# AUC: 97.92 Precision: 100.00 Recall: 95.83
#
# Fold 6
#
# -----Train----------
# AUC: 98.54 Precision: 99.16 Recall: 97.93
#
# -----Validation-----
# AUC: 93.57 Precision: 92.00 Recall: 95.83
#
# Fold 7
#
# -----Train----------
# AUC: 98.75 Precision: 99.58 Recall: 97.93
#
# -----Validation-----
# AUC: 89.31 Precision: 88.00 Recall: 91.67
#
# Fold 8
#
# -----Train----------
# AUC: 98.33 Precision: 99.16 Recall: 97.52
#
# -----Validation-----
# AUC: 91.67 Precision: 100.00 Recall: 83.33
#
# Fold 9
#
# -----Train----------
# AUC: 98.33 Precision: 99.16 Recall: 97.52
#
# -----Validation-----
# AUC: 89.31 Precision: 88.00 Recall: 91.67
#
# Fold 10
#
# -----Train----------
# AUC: 98.12 Precision: 99.16 Recall: 97.11
#
# -----Validation-----
# AUC: 95.74 Precision: 95.83 Recall: 95.83
#
# Fold 11
#
# -----Train----------
# AUC: 98.54 Precision: 99.16 Recall: 97.93
#
# -----Validation-----
# AUC: 91.49 Precision: 91.67 Recall: 91.67
#
# wheezy-copper-turtle-magic 24
#
# Fold 1
#
# -----Train----------
# AUC: 97.97 Precision: 98.10 Recall: 97.63
#
# -----Validation-----
# AUC: 97.73 Precision: 100.00 Recall: 95.45
#
# Fold 2
#
# -----Train----------
# AUC: 98.42 Precision: 98.57 Recall: 98.10
#
# -----Validation-----
# AUC: 95.64 Precision: 95.45 Recall: 95.45
#
# Fold 3
#
# -----Train----------
# AUC: 97.77 Precision: 97.64 Recall: 97.64
#
# -----Validation-----
# AUC: 91.37 Precision: 86.96 Recall: 95.24
#
# Fold 4
#
# -----Train----------
# AUC: 98.45 Precision: 98.12 Recall: 98.58
#
# -----Validation-----
# AUC: 91.07 Precision: 90.48 Recall: 90.48
#
# Fold 5
#
# -----Train----------
# AUC: 97.98 Precision: 98.10 Recall: 97.64
#
# -----Validation-----
# AUC: 92.86 Precision: 100.00 Recall: 85.71
#
# Fold 6
#
# -----Train----------
# AUC: 98.43 Precision: 98.58 Recall: 98.11
#
# -----Validation-----
# AUC: 88.99 Precision: 86.36 Recall: 90.48
#
# Fold 7
#
# -----Train----------
# AUC: 98.22 Precision: 98.11 Recall: 98.11
#
# -----Validation-----
# AUC: 91.07 Precision: 90.48 Recall: 90.48
#
# Fold 8
#
# -----Train----------
# AUC: 97.80 Precision: 97.20 Recall: 98.11
#
# -----Validation-----
# AUC: 95.24 Precision: 100.00 Recall: 90.48
#
# Fold 9
#
# -----Train----------
# AUC: 97.77 Precision: 97.64 Recall: 97.64
#
# -----Validation-----
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# Fold 10
#
# -----Train----------
# AUC: 98.69 Precision: 98.13 Recall: 99.06
#
# -----Validation-----
# AUC: 90.68 Precision: 94.74 Recall: 85.71
#
# Fold 11
#
# -----Train----------
# AUC: 97.98 Precision: 98.10 Recall: 97.64
#
# -----Validation-----
# AUC: 85.92 Precision: 94.12 Recall: 76.19
#
# wheezy-copper-turtle-magic 25
#
# Fold 1
#
# -----Train----------
# AUC: 97.96 Precision: 98.10 Recall: 97.63
#
# -----Validation-----
# AUC: 93.37 Precision: 95.24 Recall: 90.91
#
# Fold 2
#
# -----Train----------
# AUC: 97.96 Precision: 98.10 Recall: 97.63
#
# -----Validation-----
# AUC: 89.02 Precision: 90.48 Recall: 86.36
#
# Fold 3
#
# -----Train----------
# AUC: 97.73 Precision: 98.10 Recall: 97.17
#
# -----Validation-----
# AUC: 97.62 Precision: 100.00 Recall: 95.24
#
# Fold 4
#
# -----Train----------
# AUC: 97.73 Precision: 98.10 Recall: 97.17
#
# -----Validation-----
# AUC: 93.75 Precision: 87.50 Recall: 100.00
#
# Fold 5
#
# -----Train----------
# AUC: 97.71 Precision: 98.56 Recall: 96.70
#
# -----Validation-----
# AUC: 95.54 Precision: 95.24 Recall: 95.24
#
# Fold 6
#
# -----Train----------
# AUC: 97.52 Precision: 97.63 Recall: 97.17
#
# -----Validation-----
# AUC: 85.92 Precision: 94.12 Recall: 76.19
#
# Fold 7
#
# -----Train----------
# AUC: 97.73 Precision: 98.10 Recall: 97.17
#
# -----Validation-----
# AUC: 95.24 Precision: 100.00 Recall: 90.48
#
# Fold 8
#
# -----Train----------
# AUC: 97.47 Precision: 98.55 Recall: 96.23
#
# -----Validation-----
# AUC: 97.83 Precision: 95.45 Recall: 100.00
#
# Fold 9
#
# -----Train----------
# AUC: 97.71 Precision: 98.56 Recall: 96.70
#
# -----Validation-----
# AUC: 88.92 Precision: 83.33 Recall: 95.24
#
# Fold 10
#
# -----Train----------
# AUC: 97.92 Precision: 99.03 Recall: 96.70
#
# -----Validation-----
# AUC: 90.89 Precision: 90.48 Recall: 90.48
#
# Fold 11
#
# -----Train----------
# AUC: 97.50 Precision: 98.09 Recall: 96.70
#
# -----Validation-----
# AUC: 95.45 Precision: 95.24 Recall: 95.24
#
# wheezy-copper-turtle-magic 26
#
# Fold 1
#
# -----Train----------
# AUC: 97.76 Precision: 97.22 Recall: 98.13
#
# -----Validation-----
# AUC: 79.94 Precision: 80.95 Recall: 77.27
#
# Fold 2
#
# -----Train----------
# AUC: 97.76 Precision: 97.22 Recall: 98.13
#
# -----Validation-----
# AUC: 91.01 Precision: 95.00 Recall: 86.36
#
# Fold 3
#
# -----Train----------
# AUC: 97.98 Precision: 97.67 Recall: 98.13
#
# -----Validation-----
# AUC: 89.03 Precision: 84.00 Recall: 95.45
#
# Fold 4
#
# -----Train----------
# AUC: 98.43 Precision: 98.14 Recall: 98.60
#
# -----Validation-----
# AUC: 88.83 Precision: 90.48 Recall: 86.36
#
# Fold 5
#
# -----Train----------
# AUC: 97.08 Precision: 96.74 Recall: 97.20
#
# -----Validation-----
# AUC: 97.83 Precision: 95.65 Recall: 100.00
#
# Fold 6
#
# -----Train----------
# AUC: 97.75 Precision: 97.67 Recall: 97.67
#
# -----Validation-----
# AUC: 88.92 Precision: 83.33 Recall: 95.24
#
# Fold 7
#
# -----Train----------
# AUC: 97.97 Precision: 98.13 Recall: 97.67
#
# -----Validation-----
# AUC: 95.45 Precision: 95.24 Recall: 95.24
#
# Fold 8
#
# -----Train----------
# AUC: 97.75 Precision: 97.67 Recall: 97.67
#
# -----Validation-----
# AUC: 93.48 Precision: 87.50 Recall: 100.00
#
# Fold 9
#
# -----Train----------
# AUC: 97.32 Precision: 96.77 Recall: 97.67
#
# -----Validation-----
# AUC: 97.83 Precision: 95.45 Recall: 100.00
#
# Fold 10
#
# -----Train----------
# AUC: 97.77 Precision: 97.24 Recall: 98.14
#
# -----Validation-----
# AUC: 88.30 Precision: 94.44 Recall: 80.95
#
# Fold 11
#
# -----Train----------
# AUC: 97.75 Precision: 97.67 Recall: 97.67
#
# -----Validation-----
# AUC: 93.27 Precision: 90.91 Recall: 95.24
#
# wheezy-copper-turtle-magic 27
#
# Fold 1
#
# -----Train----------
# AUC: 96.77 Precision: 95.48 Recall: 97.69
#
# -----Validation-----
# AUC: 95.45 Precision: 100.00 Recall: 90.91
#
# Fold 2
#
# -----Train----------
# AUC: 97.65 Precision: 96.38 Recall: 98.61
#
# -----Validation-----
# AUC: 88.91 Precision: 94.74 Recall: 81.82
#
# Fold 3
#
# -----Train----------
# AUC: 96.08 Precision: 95.41 Recall: 96.30
#
# -----Validation-----
# AUC: 91.10 Precision: 95.00 Recall: 86.36
#
# Fold 4
#
# -----Train----------
# AUC: 97.01 Precision: 95.50 Recall: 98.15
#
# -----Validation-----
# AUC: 93.37 Precision: 95.24 Recall: 90.91
#
# Fold 5
#
# -----Train----------
# AUC: 97.21 Precision: 95.93 Recall: 98.15
#
# -----Validation-----
# AUC: 91.10 Precision: 95.00 Recall: 86.36
#
# Fold 6
#
# -----Train----------
# AUC: 96.52 Precision: 95.87 Recall: 96.76
#
# -----Validation-----
# AUC: 86.74 Precision: 90.00 Recall: 81.82
#
# Fold 7
#
# -----Train----------
# AUC: 96.78 Precision: 95.48 Recall: 97.69
#
# -----Validation-----
# AUC: 97.92 Precision: 95.65 Recall: 100.00
#
# Fold 8
#
# -----Train----------
# AUC: 97.22 Precision: 95.95 Recall: 98.16
#
# -----Validation-----
# AUC: 95.83 Precision: 91.30 Recall: 100.00
#
# Fold 9
#
# -----Train----------
# AUC: 95.84 Precision: 95.83 Recall: 95.39
#
# -----Validation-----
# AUC: 86.90 Precision: 82.61 Recall: 90.48
#
# Fold 10
#
# -----Train----------
# AUC: 96.78 Precision: 95.50 Recall: 97.70
#
# -----Validation-----
# AUC: 86.61 Precision: 85.71 Recall: 85.71
#
# Fold 11
#
# -----Train----------
# AUC: 96.55 Precision: 95.48 Recall: 97.24
#
# -----Validation-----
# AUC: 90.77 Precision: 94.74 Recall: 85.71
#
# wheezy-copper-turtle-magic 28
#
# Fold 1
#
# -----Train----------
# AUC: 97.13 Precision: 97.92 Recall: 96.31
#
# -----Validation-----
# AUC: 96.00 Precision: 100.00 Recall: 92.00
#
# Fold 2
#
# -----Train----------
# AUC: 97.95 Precision: 98.75 Recall: 97.13
#
# -----Validation-----
# AUC: 86.00 Precision: 84.62 Recall: 88.00
#
# Fold 3
#
# -----Train----------
# AUC: 96.92 Precision: 97.51 Recall: 96.31
#
# -----Validation-----
# AUC: 92.00 Precision: 95.65 Recall: 88.00
#
# Fold 4
#
# -----Train----------
# AUC: 97.13 Precision: 97.52 Recall: 96.72
#
# -----Validation-----
# AUC: 94.00 Precision: 92.31 Recall: 96.00
#
# Fold 5
#
# -----Train----------
# AUC: 97.75 Precision: 98.74 Recall: 96.72
#
# -----Validation-----
# AUC: 95.83 Precision: 92.59 Recall: 100.00
#
# Fold 6
#
# -----Train----------
# AUC: 97.14 Precision: 97.93 Recall: 96.33
#
# -----Validation-----
# AUC: 95.83 Precision: 100.00 Recall: 91.67
#
# Fold 7
#
# -----Train----------
# AUC: 97.34 Precision: 97.93 Recall: 96.73
#
# -----Validation-----
# AUC: 93.75 Precision: 95.65 Recall: 91.67
#
# Fold 8
#
# -----Train----------
# AUC: 96.73 Precision: 97.91 Recall: 95.51
#
# -----Validation-----
# AUC: 97.92 Precision: 100.00 Recall: 95.83
#
# Fold 9
#
# -----Train----------
# AUC: 96.93 Precision: 97.92 Recall: 95.92
#
# -----Validation-----
# AUC: 97.92 Precision: 100.00 Recall: 95.83
#
# Fold 10
#
# -----Train----------
# AUC: 97.75 Precision: 98.35 Recall: 97.14
#
# -----Validation-----
# AUC: 89.58 Precision: 88.00 Recall: 91.67
#
# Fold 11
#
# -----Train----------
# AUC: 97.14 Precision: 97.93 Recall: 96.33
#
# -----Validation-----
# AUC: 93.75 Precision: 100.00 Recall: 87.50
#
# wheezy-copper-turtle-magic 29
#
# Fold 1
#
# -----Train----------
# AUC: 98.23 Precision: 97.82 Recall: 98.68
#
# -----Validation-----
# AUC: 95.65 Precision: 100.00 Recall: 91.30
#
# Fold 2
#
# -----Train----------
# AUC: 98.23 Precision: 98.24 Recall: 98.24
#
# -----Validation-----
# AUC: 89.13 Precision: 84.62 Recall: 95.65
#
# Fold 3
#
# -----Train----------
# AUC: 98.23 Precision: 97.82 Recall: 98.68
#
# -----Validation-----
# AUC: 93.48 Precision: 95.45 Recall: 91.30
#
# Fold 4
#
# -----Train----------
# AUC: 98.23 Precision: 98.24 Recall: 98.24
#
# -----Validation-----
# AUC: 86.96 Precision: 86.96 Recall: 86.96
#
# Fold 5
#
# -----Train----------
# AUC: 98.01 Precision: 97.81 Recall: 98.24
#
# -----Validation-----
# AUC: 91.30 Precision: 88.00 Recall: 95.65
#
# Fold 6
#
# -----Train----------
# AUC: 98.01 Precision: 97.81 Recall: 98.24
#
# -----Validation-----
# AUC: 97.83 Precision: 100.00 Recall: 95.65
#
# Fold 7
#
# -----Train----------
# AUC: 97.57 Precision: 97.79 Recall: 97.36
#
# -----Validation-----
# AUC: 95.65 Precision: 100.00 Recall: 91.30
#
# Fold 8
#
# -----Train----------
# AUC: 98.46 Precision: 98.67 Recall: 98.24
#
# -----Validation-----
# AUC: 91.11 Precision: 91.30 Recall: 91.30
#
# Fold 9
#
# -----Train----------
# AUC: 97.80 Precision: 97.81 Recall: 97.81
#
# -----Validation-----
# AUC: 93.18 Precision: 91.30 Recall: 95.45
#
# Fold 10
#
# -----Train----------
# AUC: 98.02 Precision: 98.24 Recall: 97.81
#
# -----Validation-----
# AUC: 93.18 Precision: 88.00 Recall: 100.00
#
# Fold 11
#
# -----Train----------
# AUC: 97.14 Precision: 97.36 Recall: 96.93
#
# -----Validation-----
# AUC: 97.73 Precision: 100.00 Recall: 95.45
#
# wheezy-copper-turtle-magic 30
#
# Fold 1
#
# -----Train----------
# AUC: 98.51 Precision: 98.77 Recall: 98.36
#
# -----Validation-----
# AUC: 93.83 Precision: 95.83 Recall: 92.00
#
# Fold 2
#
# -----Train----------
# AUC: 98.10 Precision: 98.76 Recall: 97.54
#
# -----Validation-----
# AUC: 93.83 Precision: 95.83 Recall: 92.00
#
# Fold 3
#
# -----Train----------
# AUC: 97.89 Precision: 98.75 Recall: 97.13
#
# -----Validation-----
# AUC: 93.48 Precision: 89.29 Recall: 100.00
#
# Fold 4
#
# -----Train----------
# AUC: 97.65 Precision: 97.94 Recall: 97.54
#
# -----Validation-----
# AUC: 95.83 Precision: 96.00 Recall: 96.00
#
# Fold 5
#
# -----Train----------
# AUC: 98.51 Precision: 98.77 Recall: 98.36
#
# -----Validation-----
# AUC: 87.18 Precision: 88.00 Recall: 88.00
#
# Fold 6
#
# -----Train----------
# AUC: 98.49 Precision: 98.37 Recall: 98.78
#
# -----Validation-----
# AUC: 91.10 Precision: 88.46 Recall: 95.83
#
# Fold 7
#
# -----Train----------
# AUC: 97.86 Precision: 97.96 Recall: 97.96
#
# -----Validation-----
# AUC: 95.83 Precision: 100.00 Recall: 91.67
#
# Fold 8
#
# -----Train----------
# AUC: 98.78 Precision: 100.00 Recall: 97.55
#
# -----Validation-----
# AUC: 91.10 Precision: 88.46 Recall: 95.83
#
# Fold 9
#
# -----Train----------
# AUC: 97.88 Precision: 98.35 Recall: 97.55
#
# -----Validation-----
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# Fold 10
#
# -----Train----------
# ...
#
# Fold 9
#
# -----Train----------
# AUC: 96.59 Precision: 97.44 Recall: 96.20
#
# -----Validation-----
# AUC: 92.11 Precision: 88.46 Recall: 100.00
#
# Fold 10
#
# -----Train----------
# AUC: 96.08 Precision: 96.61 Recall: 96.20
#
# -----Validation-----
# AUC: 87.76 Precision: 87.50 Recall: 91.30
#
# Fold 11
#
# -----Train----------
# AUC: 96.29 Precision: 96.62 Recall: 96.62
#
# -----Validation-----
# AUC: 92.56 Precision: 91.67 Recall: 95.65
#
# wheezy-copper-turtle-magic 502
#
# Fold 1
#
# -----Train----------
# AUC: 97.06 Precision: 96.61 Recall: 97.44
#
# -----Validation-----
# AUC: 91.83 Precision: 91.67 Recall: 91.67
#
# Fold 2
#
# -----Train----------
# AUC: 96.20 Precision: 96.96 Recall: 95.30
#
# -----Validation-----
# AUC: 95.92 Precision: 95.83 Recall: 95.83
#
# Fold 3
#
# -----Train----------
# AUC: 96.84 Precision: 97.00 Recall: 96.58
#
# -----Validation-----
# AUC: 87.50 Precision: 84.62 Recall: 91.67
#
# Fold 4
#
# -----Train----------
# AUC: 97.88 Precision: 98.70 Recall: 97.01
#
# -----Validation-----
# AUC: 91.67 Precision: 88.46 Recall: 95.83
#
# Fold 5
#
# -----Train----------
# AUC: 96.84 Precision: 97.40 Recall: 96.15
#
# -----Validation-----
# AUC: 95.83 Precision: 95.83 Recall: 95.83
#
# Fold 6
#
# -----Train----------
# AUC: 96.85 Precision: 97.41 Recall: 96.17
#
# -----Validation-----
# AUC: 87.23 Precision: 86.96 Recall: 86.96
#
# Fold 7
#
# -----Train----------
# AUC: 96.85 Precision: 97.41 Recall: 96.17
#
# -----Validation-----
# AUC: 97.83 Precision: 100.00 Recall: 95.65
#
# Fold 8
#
# -----Train----------
# AUC: 96.43 Precision: 96.98 Recall: 95.74
#
# -----Validation-----
# AUC: 95.83 Precision: 92.00 Recall: 100.00
#
# Fold 9
#
# -----Train----------
# AUC: 96.63 Precision: 97.82 Recall: 95.32
#
# -----Validation-----
# AUC: 82.97 Precision: 82.61 Recall: 82.61
#
# Fold 10
#
# -----Train----------
# AUC: 97.06 Precision: 97.42 Recall: 96.60
#
# -----Validation-----
# AUC: 93.48 Precision: 100.00 Recall: 86.96
#
# Fold 11
#
# -----Train----------
# AUC: 97.27 Precision: 97.44 Recall: 97.02
#
# -----Validation-----
# AUC: 87.05 Precision: 94.74 Recall: 78.26
#
# wheezy-copper-turtle-magic 503
#
# Fold 1
#
# -----Train----------
# AUC: 97.72 Precision: 97.66 Recall: 97.66
#
# -----Validation-----
# AUC: 93.38 Precision: 91.30 Recall: 95.45
#
# Fold 2
#
# -----Train----------
# AUC: 97.49 Precision: 97.65 Recall: 97.20
#
# -----Validation-----
# AUC: 90.91 Precision: 100.00 Recall: 81.82
#
# Fold 3
#
# -----Train----------
# AUC: 97.72 Precision: 97.66 Recall: 97.66
#
# -----Validation-----
# AUC: 95.45 Precision: 100.00 Recall: 90.91
#
# Fold 4
#
# -----Train----------
# AUC: 97.01 Precision: 98.09 Recall: 95.79
#
# -----Validation-----
# AUC: 93.48 Precision: 88.00 Recall: 100.00
#
# Fold 5
#
# -----Train----------
# AUC: 97.95 Precision: 97.67 Recall: 98.13
#
# -----Validation-----
# AUC: 91.11 Precision: 90.91 Recall: 90.91
#
# Fold 6
#
# -----Train----------
# AUC: 97.25 Precision: 98.10 Recall: 96.28
#
# -----Validation-----
# AUC: 93.06 Precision: 95.00 Recall: 90.48
#
# Fold 7
#
# -----Train----------
# AUC: 97.28 Precision: 97.21 Recall: 97.21
#
# -----Validation-----
# AUC: 95.24 Precision: 100.00 Recall: 90.48
#
# Fold 8
#
# -----Train----------
# AUC: 97.50 Precision: 97.66 Recall: 97.21
#
# -----Validation-----
# AUC: 95.45 Precision: 91.30 Recall: 100.00
#
# Fold 9
#
# -----Train----------
# AUC: 97.27 Precision: 97.65 Recall: 96.74
#
# -----Validation-----
# AUC: 97.73 Precision: 95.45 Recall: 100.00
#
# Fold 10
#
# -----Train----------
# AUC: 97.25 Precision: 98.10 Recall: 96.28
#
# -----Validation-----
# AUC: 93.07 Precision: 90.91 Recall: 95.24
#
# Fold 11
#
# -----Train----------
# AUC: 98.18 Precision: 98.14 Recall: 98.14
#
# -----Validation-----
# AUC: 97.62 Precision: 100.00 Recall: 95.24
#
# wheezy-copper-turtle-magic 504
#
# Fold 1
#
# -----Train----------
# AUC: 96.29 Precision: 96.60 Recall: 96.19
#
# -----Validation-----
# AUC: 93.57 Precision: 92.00 Recall: 95.83
#
# Fold 2
#
# -----Train----------
# AUC: 96.50 Precision: 96.61 Recall: 96.61
#
# -----Validation-----
# AUC: 93.57 Precision: 92.00 Recall: 95.83
#
# Fold 3
#
# -----Train----------
# AUC: 96.49 Precision: 96.22 Recall: 97.03
#
# -----Validation-----
# AUC: 91.39 Precision: 88.46 Recall: 95.83
#
# Fold 4
#
# -----Train----------
# AUC: 97.17 Precision: 97.45 Recall: 97.03
#
# -----Validation-----
# AUC: 87.12 Precision: 90.91 Recall: 83.33
#
# Fold 5
#
# -----Train----------
# AUC: 96.51 Precision: 96.61 Recall: 96.61
#
# -----Validation-----
# AUC: 97.73 Precision: 96.00 Recall: 100.00
#
# Fold 6
#
# -----Train----------
# AUC: 96.52 Precision: 97.01 Recall: 96.19
#
# -----Validation-----
# AUC: 91.10 Precision: 88.46 Recall: 95.83
#
# Fold 7
#
# -----Train----------
# AUC: 96.96 Precision: 97.44 Recall: 96.61
#
# -----Validation-----
# AUC: 95.64 Precision: 95.83 Recall: 95.83
#
# Fold 8
#
# -----Train----------
# AUC: 97.38 Precision: 97.07 Recall: 97.89
#
# -----Validation-----
# AUC: 91.11 Precision: 91.30 Recall: 91.30
#
# Fold 9
#
# -----Train----------
# AUC: 97.15 Precision: 96.67 Recall: 97.89
#
# -----Validation-----
# AUC: 91.11 Precision: 91.30 Recall: 91.30
#
# Fold 10
#
# -----Train----------
# AUC: 96.31 Precision: 96.61 Recall: 96.20
#
# -----Validation-----
# AUC: 91.30 Precision: 100.00 Recall: 82.61
#
# Fold 11
#
# -----Train----------
# AUC: 96.74 Precision: 97.03 Recall: 96.62
#
# -----Validation-----
# AUC: 95.55 Precision: 95.65 Recall: 95.65
#
# wheezy-copper-turtle-magic 505
#
# Fold 1
#
# -----Train----------
# AUC: 97.02 Precision: 95.76 Recall: 98.26
#
# -----Validation-----
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# Fold 2
#
# -----Train----------
# AUC: 97.03 Precision: 95.40 Recall: 98.70
#
# -----Validation-----
# AUC: 93.66 Precision: 91.67 Recall: 95.65
#
# Fold 3
#
# -----Train----------
# AUC: 97.45 Precision: 96.20 Recall: 98.70
#
# -----Validation-----
# AUC: 87.32 Precision: 84.00 Recall: 91.30
#
# Fold 4
#
# -----Train----------
# AUC: 97.88 Precision: 96.62 Recall: 99.13
#
# -----Validation-----
# AUC: 87.32 Precision: 84.00 Recall: 91.30
#
# Fold 5
#
# -----Train----------
# AUC: 97.01 Precision: 96.57 Recall: 97.40
#
# -----Validation-----
# AUC: 95.83 Precision: 92.00 Recall: 100.00
#
# Fold 6
#
# -----Train----------
# AUC: 97.24 Precision: 96.19 Recall: 98.27
#
# -----Validation-----
# AUC: 91.39 Precision: 95.24 Recall: 86.96
#
# Fold 7
#
# -----Train----------
# AUC: 96.60 Precision: 95.36 Recall: 97.84
#
# -----Validation-----
# AUC: 89.49 Precision: 84.62 Recall: 95.65
#
# Fold 8
#
# -----Train----------
# AUC: 98.09 Precision: 97.03 Recall: 99.13
#
# -----Validation-----
# AUC: 85.14 Precision: 83.33 Recall: 86.96
#
# Fold 9
#
# -----Train----------
# AUC: 97.24 Precision: 96.19 Recall: 98.27
#
# -----Validation-----
# AUC: 93.48 Precision: 91.67 Recall: 95.65
#
# Fold 10
#
# -----Train----------
# AUC: 97.25 Precision: 95.80 Recall: 98.70
#
# -----Validation-----
# AUC: 91.30 Precision: 88.00 Recall: 95.65
#
# Fold 11
#
# -----Train----------
# AUC: 96.60 Precision: 95.74 Recall: 97.40
#
# -----Validation-----
# AUC: 86.96 Precision: 90.48 Recall: 82.61
#
# wheezy-copper-turtle-magic 506
#
# Fold 1
#
# -----Train----------
# AUC: 97.31 Precision: 97.90 Recall: 96.68
#
# -----Validation-----
# AUC: 98.00 Precision: 96.15 Recall: 100.00
#
# Fold 2
#
# -----Train----------
# AUC: 97.31 Precision: 97.50 Recall: 97.10
#
# -----Validation-----
# AUC: 94.00 Precision: 92.31 Recall: 96.00
#
# Fold 3
#
# -----Train----------
# AUC: 97.73 Precision: 98.33 Recall: 97.11
#
# -----Validation-----
# AUC: 87.75 Precision: 87.50 Recall: 87.50
#
# Fold 4
#
# -----Train----------
# AUC: 96.91 Precision: 97.49 Recall: 96.28
#
# -----Validation-----
# AUC: 87.50 Precision: 82.14 Recall: 95.83
#
# Fold 5
#
# -----Train----------
# AUC: 97.53 Precision: 97.52 Recall: 97.52
#
# -----Validation-----
# AUC: 93.75 Precision: 100.00 Recall: 87.50
#
# Fold 6
#
# -----Train----------
# AUC: 98.14 Precision: 98.34 Recall: 97.93
#
# -----Validation-----
# AUC: 89.58 Precision: 85.19 Recall: 95.83
#
# Fold 7
#
# -----Train----------
# AUC: 97.73 Precision: 97.93 Recall: 97.52
#
# -----Validation-----
# AUC: 93.75 Precision: 92.00 Recall: 95.83
#
# Fold 8
#
# -----Train----------
# AUC: 97.32 Precision: 97.51 Recall: 97.11
#
# -----Validation-----
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# Fold 9
#
# -----Train----------
# AUC: 97.11 Precision: 97.50 Recall: 96.69
#
# -----Validation-----
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# Fold 10
#
# -----Train----------
# AUC: 97.32 Precision: 97.91 Recall: 96.69
#
# -----Validation-----
# AUC: 95.83 Precision: 100.00 Recall: 91.67
#
# Fold 11
#
# -----Train----------
# AUC: 97.53 Precision: 97.52 Recall: 97.52
#
# -----Validation-----
# AUC: 89.58 Precision: 88.00 Recall: 91.67
#
# wheezy-copper-turtle-magic 507
#
# Fold 1
#
# -----Train----------
# AUC: 97.63 Precision: 98.20 Recall: 96.89
#
# -----Validation-----
# AUC: 91.65 Precision: 91.30 Recall: 91.30
#
# Fold 2
#
# -----Train----------
# AUC: 97.85 Precision: 98.21 Recall: 97.33
#
# -----Validation-----
# AUC: 91.65 Precision: 91.30 Recall: 91.30
#
# Fold 3
#
# -----Train----------
# AUC: 98.30 Precision: 98.22 Recall: 98.22
#
# -----Validation-----
# AUC: 85.65 Precision: 80.77 Recall: 91.30
#
# Fold 4
#
# -----Train----------
# AUC: 98.28 Precision: 98.65 Recall: 97.78
#
# -----Validation-----
# AUC: 89.48 Precision: 90.91 Recall: 86.96
#
# Fold 5
#
# -----Train----------
# AUC: 98.52 Precision: 98.23 Recall: 98.67
#
# -----Validation-----
# AUC: 91.30 Precision: 100.00 Recall: 82.61
#
# Fold 6
#
# -----Train----------
# AUC: 98.06 Precision: 98.65 Recall: 97.33
#
# -----Validation-----
# AUC: 93.65 Precision: 95.45 Recall: 91.30
#
# Fold 7
#
# -----Train----------
# AUC: 98.10 Precision: 97.80 Recall: 98.23
#
# -----Validation-----
# AUC: 96.00 Precision: 91.67 Recall: 100.00
#
# Fold 8
#
# -----Train----------
# AUC: 98.05 Precision: 99.10 Recall: 96.90
#
# -----Validation-----
# AUC: 95.64 Precision: 95.45 Recall: 95.45
#
# Fold 9
#
# -----Train----------
# AUC: 97.64 Precision: 98.21 Recall: 96.90
#
# -----Validation-----
# AUC: 95.83 Precision: 91.67 Recall: 100.00
#
# Fold 10
#
# -----Train----------
# AUC: 98.08 Precision: 98.22 Recall: 97.79
#
# -----Validation-----
# AUC: 93.37 Precision: 95.24 Recall: 90.91
#
# Fold 11
#
# -----Train----------
# AUC: 97.66 Precision: 97.78 Recall: 97.35
#
# -----Validation-----
# AUC: 95.64 Precision: 95.45 Recall: 95.45
#
# wheezy-copper-turtle-magic 508
#
# Fold 1
#
# -----Train----------
# AUC: 96.20 Precision: 95.44 Recall: 97.05
#
# -----Validation-----
# AUC: 89.58 Precision: 95.24 Recall: 83.33
#
# Fold 2
#
# -----Train----------
# AUC: 95.78 Precision: 95.02 Recall: 96.62
#
# -----Validation-----
# AUC: 89.58 Precision: 91.30 Recall: 87.50
#
# Fold 3
#
# -----Train----------
# AUC: 95.15 Precision: 94.21 Recall: 96.20
#
# -----Validation-----
# AUC: 91.67 Precision: 91.67 Recall: 91.67
#
# Fold 4
#
# -----Train----------
# AUC: 95.99 Precision: 95.42 Recall: 96.62
#
# -----Validation-----
# AUC: 93.75 Precision: 92.00 Recall: 95.83
#
# Fold 5
#
# -----Train----------
# AUC: 95.57 Precision: 95.00 Recall: 96.20
#
# -----Validation-----
# AUC: 93.75 Precision: 92.00 Recall: 95.83
#
# Fold 6
#
# -----Train----------
# AUC: 95.78 Precision: 95.02 Recall: 96.62
#
# -----Validation-----
# AUC: 89.58 Precision: 91.30 Recall: 87.50
#
# Fold 7
#
# -----Train----------
# AUC: 95.57 Precision: 95.00 Recall: 96.20
#
# -----Validation-----
# AUC: 93.75 Precision: 95.65 Recall: 91.67
#
# Fold 8
#
# -----Train----------
# AUC: 95.57 Precision: 95.38 Recall: 95.78
#
# -----Validation-----
# AUC: 91.67 Precision: 88.46 Recall: 95.83
#
# Fold 9
#
# -----Train----------
# AUC: 95.59 Precision: 95.02 Recall: 96.22
#
# -----Validation-----
# AUC: 89.13 Precision: 87.50 Recall: 91.30
#
# Fold 10
#
# -----Train----------
# AUC: 95.80 Precision: 95.80 Recall: 95.80
#
# -----Validation-----
# AUC: 91.30 Precision: 88.00 Recall: 95.65
#
# Fold 11
#
# -----Train----------
# AUC: 96.01 Precision: 96.20 Recall: 95.80
#
# -----Validation-----
# AUC: 84.78 Precision: 83.33 Recall: 86.96
#
# wheezy-copper-turtle-magic 509
#
# Fold 1
#
# -----Train----------
# AUC: 97.57 Precision: 97.75 Recall: 97.31
#
# -----Validation-----
# AUC: 91.49 Precision: 91.30 Recall: 91.30
#
# Fold 2
#
# -----Train----------
# AUC: 97.58 Precision: 97.32 Recall: 97.76
#
# -----Validation-----
# AUC: 89.40 Precision: 87.50 Recall: 91.30
#
# Fold 3
#
# -----Train----------
# AUC: 97.15 Precision: 96.46 Recall: 97.76
#
# -----Validation-----
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# Fold 4
#
# -----Train----------
# AUC: 97.15 Precision: 96.46 Recall: 97.76
#
# -----Validation-----
# AUC: 93.48 Precision: 91.67 Recall: 95.65
#
# Fold 5
#
# -----Train----------
# AUC: 97.81 Precision: 97.77 Recall: 97.77
#
# -----Validation-----
# AUC: 91.21 Precision: 87.50 Recall: 95.45
#
# Fold 6
#
# -----Train----------
# AUC: 97.60 Precision: 96.92 Recall: 98.21
#
# -----Validation-----
# AUC: 91.01 Precision: 95.00 Recall: 86.36
#
# Fold 7
#
# -----Train----------
# AUC: 97.14 Precision: 97.31 Recall: 96.88
#
# -----Validation-----
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# Fold 8
#
# -----Train----------
# AUC: 97.59 Precision: 97.33 Recall: 97.77
#
# -----Validation-----
# AUC: 93.28 Precision: 95.24 Recall: 90.91
#
# Fold 9
#
# -----Train----------
# AUC: 98.04 Precision: 97.36 Recall: 98.66
#
# -----Validation-----
# AUC: 91.01 Precision: 95.00 Recall: 86.36
#
# Fold 10
#
# -----Train----------
# AUC: 96.94 Precision: 96.46 Recall: 97.32
#
# -----Validation-----
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# Fold 11
#
# -----Train----------
# AUC: 97.38 Precision: 96.90 Recall: 97.77
#
# -----Validation-----
# AUC: 95.65 Precision: 91.67 Recall: 100.00
#
# wheezy-copper-turtle-magic 510
#
# Fold 1
#
# -----Train----------
# AUC: 96.56 Precision: 97.33 Recall: 95.63
#
# -----Validation-----
# AUC: 93.57 Precision: 95.45 Recall: 91.30
#
# Fold 2
#
# -----Train----------
# AUC: 96.78 Precision: 97.35 Recall: 96.07
#
# -----Validation-----
# AUC: 97.83 Precision: 100.00 Recall: 95.65
#
# Fold 3
#
# -----Train----------
# AUC: 96.35 Precision: 96.90 Recall: 95.63
#
# -----Validation-----
# AUC: 87.14 Precision: 90.48 Recall: 82.61
#
# Fold 4
#
# -----Train----------
# AUC: 96.79 Precision: 96.93 Recall: 96.51
#
# -----Validation-----
# AUC: 85.33 Precision: 78.57 Recall: 95.65
#
# Fold 5
#
# -----Train----------
# AUC: 96.14 Precision: 96.48 Recall: 95.63
#
# -----Validation-----
# AUC: 91.39 Precision: 95.24 Recall: 86.96
#
# Fold 6
#
# -----Train----------
# AUC: 97.43 Precision: 97.38 Recall: 97.38
#
# -----Validation-----
# AUC: 89.40 Precision: 87.50 Recall: 91.30
#
# Fold 7
#
# -----Train----------
# AUC: 97.42 Precision: 98.22 Recall: 96.51
#
# -----Validation-----
# AUC: 85.24 Precision: 80.77 Recall: 91.30
#
# Fold 8
#
# -----Train----------
# AUC: 97.22 Precision: 97.37 Recall: 96.94
#
# -----Validation-----
# AUC: 89.31 Precision: 90.91 Recall: 86.96
#
# Fold 9
#
# -----Train----------
# AUC: 97.42 Precision: 98.22 Recall: 96.51
#
# -----Validation-----
# AUC: 89.40 Precision: 87.50 Recall: 91.30
#
# Fold 10
#
# -----Train----------
# AUC: 96.99 Precision: 97.78 Recall: 96.07
#
# -----Validation-----
# AUC: 95.74 Precision: 95.65 Recall: 95.65
#
# Fold 11
#
# -----Train----------
# AUC: 97.22 Precision: 97.80 Recall: 96.52
#
# -----Validation-----
# AUC: 79.74 Precision: 88.24 Recall: 68.18
#
# wheezy-copper-turtle-magic 511
#
# Fold 1
#
# -----Train----------
# AUC: 96.71 Precision: 97.00 Recall: 96.58
#
# -----Validation-----
# AUC: 85.14 Precision: 86.96 Recall: 83.33
#
# Fold 2
#
# -----Train----------
# AUC: 96.28 Precision: 96.97 Recall: 95.73
#
# -----Validation-----
# AUC: 93.48 Precision: 88.89 Recall: 100.00
#
# Fold 3
#
# -----Train----------
# AUC: 96.49 Precision: 96.58 Recall: 96.58
#
# -----Validation-----
# AUC: 95.64 Precision: 95.83 Recall: 95.83
#
# Fold 4
#
# -----Train----------
# AUC: 96.73 Precision: 97.40 Recall: 96.15
#
# -----Validation-----
# AUC: 91.29 Precision: 91.67 Recall: 91.67
#
# Fold 5
#
# -----Train----------
# AUC: 96.50 Precision: 96.98 Recall: 96.15
#
# -----Validation-----
# AUC: 93.37 Precision: 92.00 Recall: 95.83
#
# Fold 6
#
# -----Train----------
# AUC: 96.73 Precision: 97.41 Recall: 96.17
#
# -----Validation-----
# AUC: 95.45 Precision: 92.00 Recall: 100.00
#
# Fold 7
#
# -----Train----------
# AUC: 96.95 Precision: 97.42 Recall: 96.60
#
# -----Validation-----
# AUC: 91.21 Precision: 95.24 Recall: 86.96
#
# Fold 8
#
# -----Train----------
# AUC: 96.51 Precision: 97.00 Recall: 96.17
#
# -----Validation-----
# AUC: 91.21 Precision: 95.24 Recall: 86.96
#
# Fold 9
#
# -----Train----------
# AUC: 96.30 Precision: 96.98 Recall: 95.74
#
# -----Validation-----
# AUC: 93.18 Precision: 88.46 Recall: 100.00
#
# Fold 10
#
# -----Train----------
# AUC: 96.72 Precision: 97.01 Recall: 96.60
#
# -----Validation-----
# AUC: 80.34 Precision: 93.75 Recall: 65.22
#
# Fold 11
#
# -----Train----------
# AUC: 96.96 Precision: 97.84 Recall: 96.17
#
# -----Validation-----
# AUC: 84.39 Precision: 83.33 Recall: 86.96

# %% [markdown]
# # Model evaluation
# ## Confusion matrix

# %%
f = plt.subplots(1, 1, figsize=(16, 5), sharex=True)
train_cnf_matrix = confusion_matrix(train['target'], [np.round(x) for x in train['preds']])
train_cnf_matrix_norm = train_cnf_matrix / train_cnf_matrix.sum(axis=1)[:, np.newaxis]
train_df_cm = pd.DataFrame(train_cnf_matrix_norm, index=[0, 1], columns=[0, 1])
sns.heatmap(train_df_cm, annot=True, fmt='.2f', cmap="Blues")
plt.show()

# %% [markdown]
# ## Metrics ROC AUC

# %%
print('AUC %.2f' % roc_auc_score(train['target'], train['preds']))
# Out:
# AUC 0.99

# %% [markdown]
# # Test predictions

# %%
submission = test[['id', 'target']]
submission.to_csv('submission.csv', index=False)
submission.head(10)
# Out:
#                                  id        target
# 0  1c13f2701648e0b0d46d8a2a5a131a53  9.999712e-01
# 1  ba88c155ba898fc8b5099893036ef205  9.879759e-01
# 2  7cbab5cea99169139e7e6d8ff74ebb77  2.529365e-07
# 3  ca820ad57809f62eb7b4d13f5d4371a0  7.526842e-02
# 4  7baaf361537fbd8a1aaa2c97a6d4ccc7  4.380961e-01
# 5  8b3116e5e3e92e971dac305d1a093bf6  2.969658e-08
# 6  35cfd7cab9bfa29bc963d1b8c94dd280  5.630912e-10
# 7  83cf532df8ff4642a3e33a70fffdac37  9.999995e-01
# 8  2e1350fe94ec9f2220bec5245e5e9265  9.997077e-01
# 9  e62020afa72eb54a15725473e3a8475b  1.560315e-02
