# %% [markdown]
# # Dependencies

# %%
import warnings
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

from sklearn.neighbors import KNeighborsClassifier
from sklearn.feature_selection import VarianceThreshold
from sklearn.preprocessing import MinMaxScaler, StandardScaler
from sklearn.model_selection import train_test_split, StratifiedKFold
from sklearn.metrics import confusion_matrix, roc_auc_score, recall_score, precision_score

# Set seeds to make the experiment more reproducible.
from numpy.random import seed
seed(0)

# %matplotlib inline
sns.set_style("whitegrid")
warnings.filterwarnings("ignore")

# %% [markdown]
# # Load data

# %%
train = pd.read_csv('../input/train.csv')
test = pd.read_csv('../input/test.csv')

# %%
print('Train set shape:', train.shape)
print('Test set shape:', test.shape)
print('Train set overview:')
display(train.head())
# Out:
# Train set shape: (262144, 258)
# Test set shape: (131073, 257)
# Train set overview:
#                                  id   ...    target
# 0  707b395ecdcbb4dc2eabea00e4d1b179   ...         0
# 1  5880c03c6582a7b42248668e56b4bdec   ...         0
# 2  4ccbcb3d13e5072ff1d9c61afe2c4f77   ...         1
# 3  e350f17a357f12a1941f0837afb7eb8d   ...         0
# 4  a8f910ea6075b6376af079055965ff68   ...         0
#
# [5 rows x 258 columns]

# %% [markdown]
# ## Preprocess

# %% [markdown]
# # Model
#
# ## Model parameters

# %%
N_FOLDS = 11

# %%
# INITIALIZE VARIABLES
cols = [c for c in train.columns if c not in ['id', 'target', 'wheezy-copper-turtle-magic', 'preds']]
test['target'] = 0
train['preds'] = 0

# BUILD 512 MODELS
for i in range(512):
    print('wheezy-copper-turtle-magic {}\n'.format(i))
    
    # EXTRACT SUBSET OF DATASET WHERE WHEEZY-MAGIC EQUALS I
    train2 = train[train['wheezy-copper-turtle-magic']==i]
    test2 = test[test['wheezy-copper-turtle-magic']==i]
    idx1 = train2.index
    idx2 = test2.index
    train2.reset_index(drop=True, inplace=True)
    
    # FEATURE SELECTION (USE APPROX 40 OF 255 FEATURES)
    sel = VarianceThreshold(threshold=1.5).fit(train2[cols])
    train3 = sel.transform(train2[cols])
    test3 = sel.transform(test2[cols])

    skf = StratifiedKFold(n_splits=N_FOLDS, random_state=0)
    counter = 0

    for train_index, val_index in skf.split(train3, train2['target']):
        counter += 1
        print('Fold {}\n'.format(counter))
        model = KNeighborsClassifier()
        model.fit(train3[train_index,:], train2.loc[train_index]['target'])
        
        train_predictions = model.predict(train3[train_index,:])
        val_predictions = model.predict(train3[val_index,:])

        train_auc = roc_auc_score(train2.loc[train_index]['target'], train_predictions) * 100
        val_auc = roc_auc_score(train2.loc[val_index]['target'], val_predictions) * 100
        train_precision = precision_score(train2.loc[train_index]['target'], train_predictions) * 100
        val_precision = precision_score(train2.loc[val_index]['target'], val_predictions) * 100
        train_recall = recall_score(train2.loc[train_index]['target'], train_predictions) * 100
        val_recall = recall_score(train2.loc[val_index]['target'], val_predictions) * 100
        print('-----Train----------')
        print('AUC: %.2f Precision: %.2f Recall: %.2f \n' % (train_auc, train_precision, train_recall))
        print('-----Validation-----')
        print('AUC: %.2f Precision: %.2f Recall: %.2f \n' % (val_auc, val_precision, val_recall))

        # Make predictions
        train['preds'].loc[idx1] += model.predict_proba(train3)[:,1] / N_FOLDS
        test['target'].loc[idx2] += model.predict_proba(test3)[:,1] / N_FOLDS
# Out:
# wheezy-copper-turtle-magic 0
#
# Fold 1
#
# -----Train----------
# AUC: 90.92 Precision: 91.14 Recall: 90.38
#
# -----Validation-----
# AUC: 85.58 Precision: 90.48 Recall: 79.17
#
# Fold 2
#
# -----Train----------
# AUC: 90.27 Precision: 92.11 Recall: 87.87
#
# -----Validation-----
# AUC: 81.50 Precision: 85.71 Recall: 75.00
#
# Fold 3
#
# -----Train----------
# AUC: 92.15 Precision: 93.13 Recall: 90.79
#
# -----Validation-----
# AUC: 79.50 Precision: 81.82 Recall: 75.00
#
# Fold 4
#
# -----Train----------
# AUC: 89.84 Precision: 92.79 Recall: 86.19
#
# -----Validation-----
# AUC: 85.75 Precision: 84.00 Recall: 87.50
#
# Fold 5
#
# -----Train----------
# AUC: 91.12 Precision: 91.88 Recall: 89.96
#
# -----Validation-----
# AUC: 89.67 Precision: 95.24 Recall: 83.33
#
# Fold 6
#
# -----Train----------
# AUC: 90.90 Precision: 92.21 Recall: 89.12
#
# -----Validation-----
# AUC: 89.58 Precision: 100.00 Recall: 79.17
#
# Fold 7
#
# -----Train----------
# AUC: 91.30 Precision: 93.78 Recall: 88.28
#
# -----Validation-----
# AUC: 81.67 Precision: 80.00 Recall: 83.33
#
# Fold 8
#
# -----Train----------
# AUC: 90.27 Precision: 93.24 Recall: 86.61
#
# -----Validation-----
# AUC: 93.75 Precision: 95.65 Recall: 91.67
#
# Fold 9
#
# -----Train----------
# AUC: 91.96 Precision: 92.74 Recall: 90.79
#
# -----Validation-----
# AUC: 72.92 Precision: 76.19 Recall: 66.67
#
# Fold 10
#
# -----Train----------
# AUC: 91.11 Precision: 92.98 Recall: 88.70
#
# -----Validation-----
# AUC: 85.42 Precision: 84.00 Recall: 87.50
#
# Fold 11
#
# -----Train----------
# AUC: 89.70 Precision: 91.30 Recall: 87.50
#
# -----Validation-----
# AUC: 78.62 Precision: 80.95 Recall: 73.91
#
# wheezy-copper-turtle-magic 1
#
# Fold 1
#
# -----Train----------
# AUC: 93.78 Precision: 92.17 Recall: 95.07
#
# -----Validation-----
# AUC: 83.33 Precision: 74.19 Recall: 100.00
#
# Fold 2
#
# -----Train----------
# AUC: 91.94 Precision: 88.07 Recall: 95.96
#
# -----Validation-----
# AUC: 97.92 Precision: 95.83 Recall: 100.00
#
# Fold 3
#
# -----Train----------
# AUC: 94.06 Precision: 91.14 Recall: 96.86
#
# -----Validation-----
# AUC: 87.23 Precision: 86.96 Recall: 86.96
#
# Fold 4
#
# -----Train----------
# AUC: 94.06 Precision: 91.14 Recall: 96.86
#
# -----Validation-----
# AUC: 85.14 Precision: 83.33 Recall: 86.96
#
# Fold 5
#
# -----Train----------
# AUC: 93.44 Precision: 90.04 Recall: 96.88
#
# -----Validation-----
# AUC: 93.56 Precision: 91.30 Recall: 95.45
#
# Fold 6
#
# -----Train----------
# AUC: 93.01 Precision: 89.63 Recall: 96.43
#
# -----Validation-----
# AUC: 85.04 Precision: 80.00 Recall: 90.91
#
# Fold 7
#
# -----Train----------
# AUC: 94.06 Precision: 91.18 Recall: 96.88
#
# -----Validation-----
# AUC: 87.31 Precision: 80.77 Recall: 95.45
#
# Fold 8
#
# -----Train----------
# AUC: 93.47 Precision: 89.39 Recall: 97.77
#
# -----Validation-----
# AUC: 84.66 Precision: 85.71 Recall: 81.82
#
# Fold 9
#
# -----Train----------
# AUC: 94.29 Precision: 91.21 Recall: 97.32
#
# -----Validation-----
# AUC: 80.49 Precision: 78.26 Recall: 81.82
#
# Fold 10
#
# -----Train----------
# AUC: 92.57 Precision: 89.21 Recall: 95.98
#
# -----Validation-----
# AUC: 95.83 Precision: 91.67 Recall: 100.00
#
# Fold 11
#
# -----Train----------
# AUC: 93.01 Precision: 89.63 Recall: 96.43
#
# -----Validation-----
# AUC: 83.14 Precision: 75.00 Recall: 95.45
#
# wheezy-copper-turtle-magic 2
#
# Fold 1
#
# -----Train----------
# AUC: 91.06 Precision: 92.06 Recall: 89.55
#
# -----Validation-----
# AUC: 80.43 Precision: 88.89 Recall: 69.57
#
# Fold 2
#
# -----Train----------
# AUC: 91.51 Precision: 93.78 Recall: 88.69
#
# -----Validation-----
# AUC: 82.21 Precision: 81.82 Recall: 81.82
#
# Fold 3
#
# -----Train----------
# AUC: 90.14 Precision: 94.03 Recall: 85.52
#
# -----Validation-----
# AUC: 84.39 Precision: 85.71 Recall: 81.82
#
# Fold 4
#
# -----Train----------
# AUC: 90.87 Precision: 91.67 Recall: 89.59
#
# -----Validation-----
# AUC: 86.66 Precision: 86.36 Recall: 86.36
#
# Fold 5
#
# -----Train----------
# AUC: 91.51 Precision: 93.78 Recall: 88.69
#
# -----Validation-----
# AUC: 77.67 Precision: 80.00 Recall: 72.73
#
# Fold 6
#
# -----Train----------
# AUC: 92.39 Precision: 94.74 Recall: 89.59
#
# -----Validation-----
# AUC: 88.93 Precision: 86.96 Recall: 90.91
#
# Fold 7
#
# -----Train----------
# AUC: 92.39 Precision: 94.74 Recall: 89.59
#
# -----Validation-----
# AUC: 77.67 Precision: 80.00 Recall: 72.73
#
# Fold 8
#
# -----Train----------
# AUC: 90.60 Precision: 93.66 Recall: 86.88
#
# -----Validation-----
# AUC: 93.18 Precision: 100.00 Recall: 86.36
#
# Fold 9
#
# -----Train----------
# AUC: 91.72 Precision: 94.66 Recall: 88.24
#
# -----Validation-----
# AUC: 81.92 Precision: 93.75 Recall: 68.18
#
# Fold 10
#
# -----Train----------
# AUC: 90.83 Precision: 93.27 Recall: 87.78
#
# -----Validation-----
# AUC: 77.37 Precision: 92.86 Recall: 59.09
#
# Fold 11
#
# -----Train----------
# AUC: 90.18 Precision: 92.75 Recall: 86.88
#
# -----Validation-----
# AUC: 86.36 Precision: 94.44 Recall: 77.27
#
# wheezy-copper-turtle-magic 3
#
# Fold 1
#
# -----Train----------
# AUC: 90.87 Precision: 86.81 Recall: 98.04
#
# -----Validation-----
# AUC: 85.42 Precision: 78.79 Recall: 100.00
#
# Fold 2
#
# -----Train----------
# AUC: 92.35 Precision: 88.69 Recall: 98.43
#
# -----Validation-----
# AUC: 81.41 Precision: 75.76 Recall: 96.15
#
# Fold 3
#
# -----Train----------
# AUC: 92.15 Precision: 88.65 Recall: 98.04
#
# -----Validation-----
# AUC: 89.90 Precision: 88.89 Recall: 92.31
#
# Fold 4
#
# -----Train----------
# AUC: 90.28 Precision: 86.67 Recall: 96.86
#
# -----Validation-----
# AUC: 89.58 Precision: 83.87 Recall: 100.00
#
# Fold 5
#
# -----Train----------
# AUC: 92.59 Precision: 89.01 Recall: 98.43
#
# -----Validation-----
# AUC: 78.51 Precision: 73.53 Recall: 96.15
#
# Fold 6
#
# -----Train----------
# AUC: 92.00 Precision: 88.89 Recall: 97.25
#
# -----Validation-----
# AUC: 85.03 Precision: 80.65 Recall: 96.15
#
# Fold 7
#
# -----Train----------
# AUC: 91.54 Precision: 87.76 Recall: 98.05
#
# -----Validation-----
# AUC: 91.65 Precision: 92.00 Recall: 92.00
#
# Fold 8
#
# -----Train----------
# AUC: 90.30 Precision: 86.46 Recall: 97.27
#
# -----Validation-----
# AUC: 89.48 Precision: 88.46 Recall: 92.00
#
# Fold 9
#
# -----Train----------
# AUC: 92.65 Precision: 89.89 Recall: 97.27
#
# -----Validation-----
# AUC: 85.13 Precision: 82.14 Recall: 92.00
#
# Fold 10
#
# -----Train----------
# AUC: 93.25 Precision: 90.29 Recall: 98.05
#
# -----Validation-----
# AUC: 87.48 Precision: 88.00 Recall: 88.00
#
# Fold 11
#
# -----Train----------
# AUC: 92.63 Precision: 89.61 Recall: 97.66
#
# -----Validation-----
# AUC: 71.91 Precision: 66.67 Recall: 96.00
#
# wheezy-copper-turtle-magic 4
#
# Fold 1
#
# -----Train----------
# AUC: 91.03 Precision: 91.49 Recall: 90.72
#
# -----Validation-----
# AUC: 83.33 Precision: 80.77 Recall: 87.50
#
# Fold 2
#
# -----Train----------
# AUC: 91.67 Precision: 92.31 Recall: 91.14
#
# -----Validation-----
# AUC: 85.42 Precision: 84.00 Recall: 87.50
#
# Fold 3
#
# -----Train----------
# AUC: 90.21 Precision: 92.07 Recall: 88.19
#
# -----Validation-----
# AUC: 89.31 Precision: 88.00 Recall: 91.67
#
# Fold 4
#
# -----Train----------
# AUC: 90.42 Precision: 91.74 Recall: 89.03
#
# -----Validation-----
# AUC: 89.40 Precision: 91.30 Recall: 87.50
#
# Fold 5
#
# -----Train----------
# AUC: 91.06 Precision: 92.21 Recall: 89.87
#
# -----Validation-----
# AUC: 85.33 Precision: 94.74 Recall: 75.00
#
# Fold 6
#
# -----Train----------
# AUC: 92.97 Precision: 93.97 Recall: 91.98
#
# -----Validation-----
# AUC: 85.14 Precision: 86.96 Recall: 83.33
#
# Fold 7
#
# -----Train----------
# AUC: 90.84 Precision: 91.45 Recall: 90.30
#
# -----Validation-----
# AUC: 76.72 Precision: 80.95 Recall: 70.83
#
# Fold 8
#
# -----Train----------
# AUC: 89.78 Precision: 90.91 Recall: 88.61
#
# -----Validation-----
# AUC: 89.31 Precision: 88.00 Recall: 91.67
#
# Fold 9
#
# -----Train----------
# AUC: 90.65 Precision: 91.81 Recall: 89.50
#
# -----Validation-----
# AUC: 91.30 Precision: 88.00 Recall: 95.65
#
# Fold 10
#
# -----Train----------
# AUC: 91.71 Precision: 92.70 Recall: 90.76
#
# -----Validation-----
# AUC: 89.13 Precision: 90.91 Recall: 86.96
#
# Fold 11
#
# -----Train----------
# AUC: 91.51 Precision: 93.04 Recall: 89.92
#
# -----Validation-----
# AUC: 78.26 Precision: 80.95 Recall: 73.91
#
# wheezy-copper-turtle-magic 5
#
# Fold 1
#
# -----Train----------
# AUC: 89.20 Precision: 91.82 Recall: 85.96
#
# -----Validation-----
# AUC: 83.33 Precision: 80.77 Recall: 87.50
#
# Fold 2
#
# -----Train----------
# AUC: 88.56 Precision: 90.95 Recall: 85.53
#
# -----Validation-----
# AUC: 79.17 Precision: 79.17 Recall: 79.17
#
# Fold 3
#
# -----Train----------
# AUC: 88.77 Precision: 92.13 Recall: 84.68
#
# -----Validation-----
# AUC: 85.42 Precision: 90.48 Recall: 79.17
#
# Fold 4
#
# -----Train----------
# AUC: 92.16 Precision: 94.20 Recall: 89.79
#
# -----Validation-----
# AUC: 85.42 Precision: 86.96 Recall: 83.33
#
# Fold 5
#
# -----Train----------
# AUC: 89.62 Precision: 92.66 Recall: 85.96
#
# -----Validation-----
# AUC: 89.58 Precision: 95.24 Recall: 83.33
#
# Fold 6
#
# -----Train----------
# AUC: 89.61 Precision: 94.29 Recall: 84.26
#
# -----Validation-----
# AUC: 77.08 Precision: 78.26 Recall: 75.00
#
# Fold 7
#
# -----Train----------
# AUC: 90.28 Precision: 93.58 Recall: 86.44
#
# -----Validation-----
# AUC: 78.53 Precision: 84.21 Recall: 69.57
#
# Fold 8
#
# -----Train----------
# AUC: 89.65 Precision: 93.09 Recall: 85.59
#
# -----Validation-----
# AUC: 84.87 Precision: 94.44 Recall: 73.91
#
# Fold 9
#
# -----Train----------
# AUC: 89.00 Precision: 94.66 Recall: 82.63
#
# -----Validation-----
# AUC: 87.41 Precision: 81.48 Recall: 95.65
#
# Fold 10
#
# -----Train----------
# AUC: 88.81 Precision: 93.36 Recall: 83.47
#
# -----Validation-----
# AUC: 89.13 Precision: 95.00 Recall: 82.61
#
# Fold 11
#
# -----Train----------
# AUC: 89.25 Precision: 91.11 Recall: 86.86
#
# -----Validation-----
# AUC: 80.43 Precision: 93.75 Recall: 65.22
#
# wheezy-copper-turtle-magic 6
#
# Fold 1
#
# -----Train----------
# AUC: 93.79 Precision: 92.37 Recall: 95.83
#
# -----Validation-----
# AUC: 89.48 Precision: 88.46 Recall: 92.00
#
# Fold 2
#
# -----Train----------
# AUC: 94.88 Precision: 94.29 Recall: 95.85
#
# -----Validation-----
# AUC: 82.97 Precision: 83.33 Recall: 83.33
#
# Fold 3
#
# -----Train----------
# AUC: 93.61 Precision: 93.06 Recall: 94.61
#
# -----Validation-----
# AUC: 85.05 Precision: 84.00 Recall: 87.50
#
# Fold 4
#
# -----Train----------
# AUC: 92.77 Precision: 92.59 Recall: 93.36
#
# -----Validation-----
# AUC: 93.57 Precision: 92.00 Recall: 95.83
#
# Fold 5
#
# -----Train----------
# AUC: 93.84 Precision: 94.17 Recall: 93.78
#
# -----Validation-----
# AUC: 89.13 Precision: 82.76 Recall: 100.00
#
# Fold 6
#
# -----Train----------
# AUC: 93.16 Precision: 91.97 Recall: 95.02
#
# -----Validation-----
# AUC: 86.96 Precision: 80.00 Recall: 100.00
#
# Fold 7
#
# -----Train----------
# AUC: 93.37 Precision: 92.00 Recall: 95.44
#
# -----Validation-----
# AUC: 87.23 Precision: 87.50 Recall: 87.50
#
# Fold 8
#
# -----Train----------
# AUC: 93.83 Precision: 93.80 Recall: 94.19
#
# -----Validation-----
# AUC: 87.14 Precision: 84.62 Recall: 91.67
#
# Fold 9
#
# -----Train----------
# AUC: 93.17 Precision: 92.31 Recall: 94.61
#
# -----Validation-----
# AUC: 89.31 Precision: 88.00 Recall: 91.67
#
# Fold 10
#
# -----Train----------
# AUC: 93.79 Precision: 92.40 Recall: 95.85
#
# -----Validation-----
# AUC: 89.31 Precision: 88.00 Recall: 91.67
#
# Fold 11
#
# -----Train----------
# AUC: 93.40 Precision: 93.03 Recall: 94.19
#
# -----Validation-----
# AUC: 91.30 Precision: 85.71 Recall: 100.00
#
# wheezy-copper-turtle-magic 7
#
# Fold 1
#
# -----Train----------
# AUC: 89.98 Precision: 92.20 Recall: 87.39
#
# -----Validation-----
# AUC: 74.55 Precision: 77.27 Recall: 70.83
#
# Fold 2
#
# -----Train----------
# AUC: 89.79 Precision: 92.20 Recall: 87.01
#
# -----Validation-----
# AUC: 76.09 Precision: 87.50 Recall: 60.87
#
# Fold 3
#
# -----Train----------
# AUC: 90.45 Precision: 93.49 Recall: 87.01
#
# -----Validation-----
# AUC: 73.91 Precision: 72.00 Recall: 78.26
#
# Fold 4
#
# -----Train----------
# AUC: 89.36 Precision: 90.99 Recall: 87.45
#
# -----Validation-----
# AUC: 80.43 Precision: 81.82 Recall: 78.26
#
# Fold 5
#
# -----Train----------
# AUC: 89.14 Precision: 91.32 Recall: 86.58
#
# -----Validation-----
# AUC: 80.43 Precision: 88.89 Recall: 69.57
#
# Fold 6
#
# -----Train----------
# AUC: 90.01 Precision: 93.02 Recall: 86.58
#
# -----Validation-----
# AUC: 86.96 Precision: 94.74 Recall: 78.26
#
# Fold 7
#
# -----Train----------
# AUC: 89.59 Precision: 93.78 Recall: 84.85
#
# -----Validation-----
# AUC: 82.61 Precision: 89.47 Recall: 73.91
#
# Fold 8
#
# -----Train----------
# AUC: 90.23 Precision: 93.06 Recall: 87.01
#
# -----Validation-----
# AUC: 86.96 Precision: 94.74 Recall: 78.26
#
# Fold 9
#
# -----Train----------
# AUC: 89.58 Precision: 92.17 Recall: 86.58
#
# -----Validation-----
# AUC: 82.61 Precision: 82.61 Recall: 82.61
#
# Fold 10
#
# -----Train----------
# AUC: 91.10 Precision: 93.98 Recall: 87.88
#
# -----Validation-----
# AUC: 78.26 Precision: 80.95 Recall: 73.91
#
# Fold 11
#
# -----Train----------
# AUC: 88.72 Precision: 90.13 Recall: 87.01
#
# -----Validation-----
# AUC: 84.58 Precision: 90.00 Recall: 78.26
#
# wheezy-copper-turtle-magic 8
#
# Fold 1
#
# -----Train----------
# AUC: 90.08 Precision: 91.14 Recall: 89.26
#
# -----Validation-----
# AUC: 85.67 Precision: 84.62 Recall: 88.00
#
# Fold 2
#
# -----Train----------
# AUC: 91.33 Precision: 91.70 Recall: 91.32
#
# -----Validation-----
# AUC: 87.58 Precision: 82.76 Recall: 96.00
#
# Fold 3
#
# -----Train----------
# AUC: 91.16 Precision: 92.37 Recall: 90.08
#
# -----Validation-----
# AUC: 85.65 Precision: 90.91 Recall: 80.00
#
# Fold 4
#
# -----Train----------
# AUC: 92.44 Precision: 93.31 Recall: 91.77
#
# -----Validation-----
# AUC: 85.05 Precision: 84.00 Recall: 87.50
#
# Fold 5
#
# -----Train----------
# AUC: 92.48 Precision: 94.81 Recall: 90.12
#
# -----Validation-----
# AUC: 78.89 Precision: 85.00 Recall: 70.83
#
# Fold 6
#
# -----Train----------
# AUC: 91.83 Precision: 93.59 Recall: 90.12
#
# -----Validation-----
# AUC: 85.14 Precision: 86.96 Recall: 83.33
#
# Fold 7
#
# -----Train----------
# AUC: 92.63 Precision: 92.98 Recall: 92.59
#
# -----Validation-----
# AUC: 72.19 Precision: 70.37 Recall: 79.17
#
# Fold 8
#
# -----Train----------
# AUC: 90.49 Precision: 89.60 Recall: 92.18
#
# -----Validation-----
# AUC: 78.80 Precision: 81.82 Recall: 75.00
#
# Fold 9
#
# -----Train----------
# AUC: 91.38 Precision: 92.08 Recall: 90.95
#
# -----Validation-----
# AUC: 83.06 Precision: 86.36 Recall: 79.17
#
# Fold 10
#
# -----Train----------
# AUC: 90.99 Precision: 92.74 Recall: 89.30
#
# -----Validation-----
# AUC: 78.62 Precision: 76.92 Recall: 83.33
#
# Fold 11
#
# -----Train----------
# AUC: 90.13 Precision: 91.53 Recall: 88.89
#
# -----Validation-----
# AUC: 87.32 Precision: 90.91 Recall: 83.33
#
# wheezy-copper-turtle-magic 9
#
# Fold 1
#
# -----Train----------
# AUC: 92.71 Precision: 91.50 Recall: 94.17
#
# -----Validation-----
# AUC: 81.25 Precision: 77.78 Recall: 87.50
#
# Fold 2
#
# -----Train----------
# AUC: 92.71 Precision: 90.84 Recall: 95.00
#
# -----Validation-----
# AUC: 87.50 Precision: 82.14 Recall: 95.83
#
# Fold 3
#
# -----Train----------
# AUC: 93.33 Precision: 90.94 Recall: 96.25
#
# -----Validation-----
# AUC: 81.25 Precision: 80.00 Recall: 83.33
#
# Fold 4
#
# -----Train----------
# AUC: 92.08 Precision: 88.55 Recall: 96.67
#
# -----Validation-----
# AUC: 83.33 Precision: 78.57 Recall: 91.67
#
# Fold 5
#
# -----Train----------
# AUC: 92.50 Precision: 90.16 Recall: 95.42
#
# -----Validation-----
# AUC: 93.75 Precision: 92.00 Recall: 95.83
#
# Fold 6
#
# -----Train----------
# AUC: 92.50 Precision: 89.84 Recall: 95.83
#
# -----Validation-----
# AUC: 83.33 Precision: 75.00 Recall: 100.00
#
# Fold 7
#
# -----Train----------
# AUC: 92.92 Precision: 91.20 Recall: 95.00
#
# -----Validation-----
# AUC: 75.00 Precision: 71.43 Recall: 83.33
#
# Fold 8
#
# -----Train----------
# AUC: 92.92 Precision: 91.20 Recall: 95.00
#
# -----Validation-----
# AUC: 85.42 Precision: 86.96 Recall: 83.33
#
# Fold 9
#
# -----Train----------
# AUC: 92.92 Precision: 89.92 Recall: 96.67
#
# -----Validation-----
# AUC: 83.33 Precision: 80.77 Recall: 87.50
#
# Fold 10
#
# -----Train----------
# AUC: 92.92 Precision: 90.55 Recall: 95.83
#
# -----Validation-----
# AUC: 81.25 Precision: 75.86 Recall: 91.67
#
# Fold 11
#
# -----Train----------
# AUC: 92.71 Precision: 91.50 Recall: 94.17
#
# -----Validation-----
# AUC: 83.33 Precision: 83.33 Recall: 83.33
#
# wheezy-copper-turtle-magic 10
#
# Fold 1
#
# -----Train----------
# AUC: 92.91 Precision: 93.21 Recall: 92.38
#
# -----Validation-----
# AUC: 82.61 Precision: 85.71 Recall: 78.26
#
# Fold 2
#
# -----Train----------
# AUC: 92.67 Precision: 94.39 Recall: 90.58
#
# -----Validation-----
# AUC: 80.43 Precision: 76.92 Recall: 86.96
#
# Fold 3
#
# -----Train----------
# AUC: 92.71 Precision: 91.67 Recall: 93.72
#
# -----Validation-----
# AUC: 91.30 Precision: 91.30 Recall: 91.30
#
# Fold 4
#
# -----Train----------
# AUC: 91.13 Precision: 92.56 Recall: 89.24
#
# -----Validation-----
# AUC: 91.30 Precision: 91.30 Recall: 91.30
#
# Fold 5
#
# -----Train----------
# AUC: 92.71 Precision: 93.21 Recall: 91.96
#
# -----Validation-----
# AUC: 88.93 Precision: 86.96 Recall: 90.91
#
# Fold 6
#
# -----Train----------
# AUC: 91.83 Precision: 91.56 Recall: 91.96
#
# -----Validation-----
# AUC: 82.02 Precision: 88.89 Recall: 72.73
#
# Fold 7
#
# -----Train----------
# AUC: 91.83 Precision: 91.56 Recall: 91.96
#
# -----Validation-----
# AUC: 86.66 Precision: 86.36 Recall: 86.36
#
# Fold 8
#
# -----Train----------
# AUC: 92.92 Precision: 94.44 Recall: 91.07
#
# -----Validation-----
# AUC: 75.59 Precision: 73.91 Recall: 77.27
#
# Fold 9
#
# -----Train----------
# AUC: 91.61 Precision: 91.52 Recall: 91.52
#
# -----Validation-----
# AUC: 88.83 Precision: 90.48 Recall: 86.36
#
# Fold 10
#
# -----Train----------
# AUC: 91.84 Precision: 90.83 Recall: 92.86
#
# -----Validation-----
# AUC: 84.39 Precision: 85.71 Recall: 81.82
#
# Fold 11
#
# -----Train----------
# AUC: 92.76 Precision: 90.99 Recall: 94.64
#
# -----Validation-----
# AUC: 79.55 Precision: 88.24 Recall: 68.18
#
# wheezy-copper-turtle-magic 11
#
# Fold 1
#
# -----Train----------
# AUC: 92.57 Precision: 89.33 Recall: 95.71
#
# -----Validation-----
# AUC: 89.03 Precision: 84.00 Recall: 95.45
#
# Fold 2
#
# -----Train----------
# AUC: 93.21 Precision: 91.32 Recall: 94.79
#
# -----Validation-----
# AUC: 90.89 Precision: 90.48 Recall: 90.48
#
# Fold 3
#
# -----Train----------
# AUC: 94.06 Precision: 93.84 Recall: 93.84
#
# -----Validation-----
# AUC: 84.58 Precision: 76.92 Recall: 95.24
#
# Fold 4
#
# -----Train----------
# AUC: 93.58 Precision: 93.78 Recall: 92.89
#
# -----Validation-----
# AUC: 82.19 Precision: 76.00 Recall: 90.48
#
# Fold 5
#
# -----Train----------
# AUC: 95.00 Precision: 93.95 Recall: 95.73
#
# -----Validation-----
# AUC: 84.16 Precision: 81.82 Recall: 85.71
#
# Fold 6
#
# -----Train----------
# AUC: 92.02 Precision: 91.12 Recall: 92.42
#
# -----Validation-----
# AUC: 88.72 Precision: 86.36 Recall: 90.48
#
# Fold 7
#
# -----Train----------
# AUC: 95.17 Precision: 95.67 Recall: 94.31
#
# -----Validation-----
# AUC: 86.13 Precision: 89.47 Recall: 80.95
#
# Fold 8
#
# -----Train----------
# AUC: 92.73 Precision: 91.24 Recall: 93.84
#
# -----Validation-----
# AUC: 95.45 Precision: 95.24 Recall: 95.24
#
# Fold 9
#
# -----Train----------
# AUC: 93.50 Precision: 90.62 Recall: 96.21
#
# -----Validation-----
# AUC: 86.26 Precision: 80.00 Recall: 95.24
#
# Fold 10
#
# -----Train----------
# AUC: 93.48 Precision: 90.99 Recall: 95.73
#
# -----Validation-----
# AUC: 88.31 Precision: 90.00 Recall: 85.71
#
# Fold 11
#
# -----Train----------
# AUC: 92.55 Precision: 90.45 Recall: 94.31
#
# -----Validation-----
# AUC: 86.04 Precision: 85.71 Recall: 85.71
#
# wheezy-copper-turtle-magic 12
#
# Fold 1
#
# -----Train----------
# AUC: 90.84 Precision: 88.16 Recall: 94.74
#
# -----Validation-----
# AUC: 82.61 Precision: 82.61 Recall: 82.61
#
# Fold 2
#
# -----Train----------
# AUC: 91.74 Precision: 89.96 Recall: 94.30
#
# -----Validation-----
# AUC: 86.96 Precision: 84.00 Recall: 91.30
#
# Fold 3
#
# -----Train----------
# AUC: 90.83 Precision: 87.85 Recall: 95.18
#
# -----Validation-----
# AUC: 91.30 Precision: 85.19 Recall: 100.00
#
# Fold 4
#
# -----Train----------
# AUC: 91.75 Precision: 88.98 Recall: 95.61
#
# -----Validation-----
# AUC: 82.11 Precision: 80.00 Recall: 86.96
#
# Fold 5
#
# -----Train----------
# AUC: 90.86 Precision: 87.55 Recall: 95.61
#
# -----Validation-----
# AUC: 86.56 Precision: 84.00 Recall: 91.30
#
# Fold 6
#
# -----Train----------
# AUC: 91.31 Precision: 88.89 Recall: 94.74
#
# -----Validation-----
# AUC: 77.37 Precision: 70.97 Recall: 95.65
#
# Fold 7
#
# -----Train----------
# AUC: 91.30 Precision: 88.26 Recall: 95.61
#
# -----Validation-----
# AUC: 88.93 Precision: 90.91 Recall: 86.96
#
# Fold 8
#
# -----Train----------
# AUC: 92.20 Precision: 89.71 Recall: 95.61
#
# -----Validation-----
# AUC: 84.19 Precision: 78.57 Recall: 95.65
#
# Fold 9
#
# -----Train----------
# AUC: 91.96 Precision: 88.40 Recall: 96.93
#
# -----Validation-----
# AUC: 86.56 Precision: 84.00 Recall: 91.30
#
# Fold 10
#
# -----Train----------
# AUC: 91.31 Precision: 88.31 Recall: 95.63
#
# -----Validation-----
# AUC: 95.45 Precision: 91.67 Recall: 100.00
#
# Fold 11
#
# -----Train----------
# AUC: 91.33 Precision: 88.93 Recall: 94.76
#
# -----Validation-----
# AUC: 81.82 Precision: 79.17 Recall: 86.36
#
# wheezy-copper-turtle-magic 13
#
# Fold 1
#
# -----Train----------
# AUC: 90.67 Precision: 90.57 Recall: 90.14
#
# -----Validation-----
# AUC: 82.21 Precision: 81.82 Recall: 81.82
#
# Fold 2
#
# -----Train----------
# AUC: 89.23 Precision: 91.09 Recall: 86.38
#
# -----Validation-----
# AUC: 79.84 Precision: 84.21 Recall: 72.73
#
# Fold 3
#
# -----Train----------
# AUC: 90.15 Precision: 91.67 Recall: 87.79
#
# -----Validation-----
# AUC: 79.94 Precision: 80.95 Recall: 77.27
#
# Fold 4
#
# -----Train----------
# AUC: 92.02 Precision: 92.38 Recall: 91.08
#
# -----Validation-----
# AUC: 75.69 Precision: 72.00 Recall: 81.82
#
# Fold 5
#
# -----Train----------
# AUC: 90.45 Precision: 90.57 Recall: 89.72
#
# -----Validation-----
# AUC: 79.61 Precision: 77.27 Recall: 80.95
#
# Fold 6
#
# -----Train----------
# AUC: 90.85 Precision: 92.65 Recall: 88.32
#
# -----Validation-----
# AUC: 81.37 Precision: 88.24 Recall: 71.43
#
# Fold 7
#
# -----Train----------
# AUC: 90.26 Precision: 89.40 Recall: 90.65
#
# -----Validation-----
# AUC: 83.95 Precision: 85.00 Recall: 80.95
#
# Fold 8
#
# -----Train----------
# AUC: 91.08 Precision: 93.10 Recall: 88.32
#
# -----Validation-----
# AUC: 79.19 Precision: 83.33 Recall: 71.43
#
# Fold 9
#
# -----Train----------
# AUC: 90.20 Precision: 91.71 Recall: 87.85
#
# -----Validation-----
# AUC: 88.31 Precision: 90.00 Recall: 85.71
#
# Fold 10
#
# -----Train----------
# AUC: 91.19 Precision: 90.32 Recall: 91.59
#
# -----Validation-----
# AUC: 78.90 Precision: 83.33 Recall: 71.43
#
# Fold 11
#
# -----Train----------
# AUC: 90.69 Precision: 91.00 Recall: 89.72
#
# -----Validation-----
# AUC: 81.28 Precision: 84.21 Recall: 76.19
#
# wheezy-copper-turtle-magic 14
#
# Fold 1
#
# -----Train----------
# AUC: 94.35 Precision: 93.33 Recall: 94.69
#
# -----Validation-----
# AUC: 88.99 Precision: 86.36 Recall: 90.48
#
# Fold 2
#
# -----Train----------
# AUC: 94.81 Precision: 93.81 Recall: 95.17
#
# -----Validation-----
# AUC: 89.29 Precision: 83.33 Recall: 95.24
#
# Fold 3
#
# -----Train----------
# AUC: 94.32 Precision: 93.75 Recall: 94.20
#
# -----Validation-----
# AUC: 91.07 Precision: 90.48 Recall: 90.48
#
# Fold 4
#
# -----Train----------
# AUC: 94.48 Precision: 95.07 Recall: 93.24
#
# -----Validation-----
# AUC: 93.15 Precision: 95.00 Recall: 90.48
#
# Fold 5
#
# -----Train----------
# AUC: 93.12 Precision: 93.60 Recall: 91.79
#
# -----Validation-----
# AUC: 97.92 Precision: 95.45 Recall: 100.00
#
# Fold 6
#
# -----Train----------
# AUC: 94.39 Precision: 92.92 Recall: 95.17
#
# -----Validation-----
# AUC: 84.16 Precision: 81.82 Recall: 85.71
#
# Fold 7
#
# -----Train----------
# AUC: 94.82 Precision: 93.81 Recall: 95.17
#
# -----Validation-----
# AUC: 85.92 Precision: 94.12 Recall: 76.19
#
# Fold 8
#
# -----Train----------
# AUC: 94.55 Precision: 94.20 Recall: 94.20
#
# -----Validation-----
# AUC: 86.13 Precision: 89.47 Recall: 80.95
#
# Fold 9
#
# -----Train----------
# AUC: 93.12 Precision: 94.06 Recall: 91.35
#
# -----Validation-----
# AUC: 87.83 Precision: 94.12 Recall: 80.00
#
# Fold 10
#
# -----Train----------
# AUC: 94.56 Precision: 94.23 Recall: 94.23
#
# -----Validation-----
# AUC: 86.30 Precision: 81.82 Recall: 90.00
#
# Fold 11
#
# -----Train----------
# AUC: 93.66 Precision: 93.27 Recall: 93.27
#
# -----Validation-----
# AUC: 80.33 Precision: 92.86 Recall: 65.00
#
# wheezy-copper-turtle-magic 15
#
# Fold 1
#
# -----Train----------
# AUC: 90.15 Precision: 89.30 Recall: 91.56
#
# -----Validation-----
# AUC: 87.50 Precision: 87.50 Recall: 87.50
#
# Fold 2
#
# -----Train----------
# AUC: 92.74 Precision: 93.19 Recall: 92.41
#
# -----Validation-----
# AUC: 83.33 Precision: 86.36 Recall: 79.17
#
# Fold 3
#
# -----Train----------
# AUC: 92.11 Precision: 92.02 Recall: 92.41
#
# -----Validation-----
# AUC: 91.39 Precision: 88.46 Recall: 95.83
#
# Fold 4
#
# -----Train----------
# AUC: 92.74 Precision: 92.12 Recall: 93.67
#
# -----Validation-----
# AUC: 85.24 Precision: 90.48 Recall: 79.17
#
# Fold 5
#
# -----Train----------
# AUC: 92.32 Precision: 92.05 Recall: 92.83
#
# -----Validation-----
# AUC: 82.88 Precision: 80.77 Recall: 87.50
#
# Fold 6
#
# -----Train----------
# AUC: 92.53 Precision: 92.44 Recall: 92.83
#
# -----Validation-----
# AUC: 84.96 Precision: 81.48 Recall: 91.67
#
# Fold 7
#
# -----Train----------
# AUC: 92.31 Precision: 91.70 Recall: 93.25
#
# -----Validation-----
# AUC: 87.05 Precision: 82.14 Recall: 95.83
#
# Fold 8
#
# -----Train----------
# AUC: 92.52 Precision: 91.39 Recall: 94.09
#
# -----Validation-----
# AUC: 83.15 Precision: 90.00 Recall: 75.00
#
# Fold 9
#
# -----Train----------
# AUC: 92.14 Precision: 93.13 Recall: 91.18
#
# -----Validation-----
# AUC: 86.96 Precision: 84.00 Recall: 91.30
#
# Fold 10
#
# -----Train----------
# AUC: 93.18 Precision: 92.92 Recall: 93.70
#
# -----Validation-----
# AUC: 78.26 Precision: 78.26 Recall: 78.26
#
# Fold 11
#
# -----Train----------
# AUC: 92.55 Precision: 92.83 Recall: 92.44
#
# -----Validation-----
# AUC: 84.78 Precision: 83.33 Recall: 86.96
#
# wheezy-copper-turtle-magic 16
#
# Fold 1
#
# -----Train----------
# AUC: 91.75 Precision: 89.21 Recall: 94.30
#
# -----Validation-----
# AUC: 87.83 Precision: 81.48 Recall: 95.65
#
# Fold 2
#
# -----Train----------
# AUC: 91.14 Precision: 87.80 Recall: 94.74
#
# -----Validation-----
# AUC: 75.48 Precision: 68.97 Recall: 86.96
#
# Fold 3
#
# -----Train----------
# AUC: 89.75 Precision: 84.82 Recall: 95.61
#
# -----Validation-----
# AUC: 83.15 Precision: 77.78 Recall: 91.30
#
# Fold 4
#
# -----Train----------
# AUC: 90.76 Precision: 87.10 Recall: 94.74
#
# -----Validation-----
# AUC: 81.07 Precision: 75.00 Recall: 91.30
#
# Fold 5
#
# -----Train----------
# AUC: 90.91 Precision: 88.70 Recall: 92.98
#
# -----Validation-----
# AUC: 87.41 Precision: 81.48 Recall: 95.65
#
# Fold 6
#
# -----Train----------
# AUC: 91.00 Precision: 86.56 Recall: 96.05
#
# -----Validation-----
# AUC: 79.08 Precision: 70.97 Recall: 95.65
#
# Fold 7
#
# -----Train----------
# AUC: 92.22 Precision: 89.30 Recall: 95.18
#
# -----Validation-----
# AUC: 85.24 Precision: 80.77 Recall: 91.30
#
# Fold 8
#
# -----Train----------
# AUC: 91.31 Precision: 89.79 Recall: 92.54
#
# -----Validation-----
# AUC: 91.49 Precision: 91.30 Recall: 91.30
#
# Fold 9
#
# -----Train----------
# AUC: 90.99 Precision: 86.85 Recall: 95.61
#
# -----Validation-----
# AUC: 72.46 Precision: 69.23 Recall: 78.26
#
# Fold 10
#
# -----Train----------
# AUC: 90.61 Precision: 85.66 Recall: 96.51
#
# -----Validation-----
# AUC: 89.20 Precision: 86.96 Recall: 90.91
#
# Fold 11
#
# -----Train----------
# AUC: 90.79 Precision: 86.56 Recall: 95.63
#
# -----Validation-----
# AUC: 76.52 Precision: 70.37 Recall: 86.36
#
# wheezy-copper-turtle-magic 17
#
# Fold 1
#
# -----Train----------
# AUC: 93.52 Precision: 93.33 Recall: 94.12
#
# -----Validation-----
# AUC: 84.96 Precision: 81.48 Recall: 91.67
#
# Fold 2
#
# -----Train----------
# AUC: 93.72 Precision: 93.00 Recall: 94.96
#
# -----Validation-----
# AUC: 72.46 Precision: 76.19 Recall: 66.67
#
# Fold 3
#
# -----Train----------
# AUC: 93.11 Precision: 93.64 Recall: 92.86
#
# -----Validation-----
# AUC: 85.05 Precision: 84.00 Recall: 87.50
#
# Fold 4
#
# -----Train----------
# AUC: 93.53 Precision: 93.70 Recall: 93.70
#
# -----Validation-----
# AUC: 83.06 Precision: 86.36 Recall: 79.17
#
# Fold 5
#
# -----Train----------
# AUC: 91.32 Precision: 89.92 Recall: 93.70
#
# -----Validation-----
# AUC: 85.14 Precision: 86.96 Recall: 83.33
#
# Fold 6
#
# -----Train----------
# AUC: 92.87 Precision: 92.53 Recall: 93.70
#
# -----Validation-----
# AUC: 89.13 Precision: 82.76 Recall: 100.00
#
# Fold 7
#
# -----Train----------
# AUC: 92.45 Precision: 92.47 Recall: 92.86
#
# -----Validation-----
# AUC: 91.49 Precision: 91.67 Recall: 91.67
#
# Fold 8
#
# -----Train----------
# AUC: 92.67 Precision: 92.50 Recall: 93.28
#
# -----Validation-----
# AUC: 86.93 Precision: 87.50 Recall: 87.50
#
# Fold 9
#
# -----Train----------
# AUC: 93.54 Precision: 93.70 Recall: 93.70
#
# -----Validation-----
# AUC: 82.58 Precision: 83.33 Recall: 83.33
#
# Fold 10
#
# -----Train----------
# AUC: 93.55 Precision: 93.36 Recall: 94.14
#
# -----Validation-----
# AUC: 86.56 Precision: 84.00 Recall: 91.30
#
# Fold 11
#
# -----Train----------
# AUC: 93.58 Precision: 94.47 Recall: 92.89
#
# -----Validation-----
# AUC: 77.96 Precision: 84.21 Recall: 69.57
#
# wheezy-copper-turtle-magic 18
#
# Fold 1
#
# -----Train----------
# AUC: 94.06 Precision: 94.92 Recall: 93.33
#
# -----Validation-----
# AUC: 83.65 Precision: 90.48 Recall: 76.00
#
# Fold 2
#
# -----Train----------
# AUC: 93.84 Precision: 94.17 Recall: 93.78
#
# -----Validation-----
# AUC: 82.88 Precision: 80.77 Recall: 87.50
#
# Fold 3
#
# -----Train----------
# AUC: 94.69 Precision: 95.00 Recall: 94.61
#
# -----Validation-----
# AUC: 78.71 Precision: 79.17 Recall: 79.17
#
# Fold 4
#
# -----Train----------
# AUC: 94.27 Precision: 94.58 Recall: 94.19
#
# -----Validation-----
# AUC: 95.74 Precision: 95.83 Recall: 95.83
#
# Fold 5
#
# -----Train----------
# AUC: 94.46 Precision: 93.88 Recall: 95.44
#
# -----Validation-----
# AUC: 80.53 Precision: 74.19 Recall: 95.83
#
# Fold 6
#
# -----Train----------
# AUC: 93.85 Precision: 94.54 Recall: 93.36
#
# -----Validation-----
# AUC: 85.05 Precision: 84.00 Recall: 87.50
#
# Fold 7
#
# -----Train----------
# AUC: 94.29 Precision: 95.34 Recall: 93.36
#
# -----Validation-----
# AUC: 89.31 Precision: 88.00 Recall: 91.67
#
# Fold 8
#
# -----Train----------
# AUC: 94.25 Precision: 93.85 Recall: 95.02
#
# -----Validation-----
# AUC: 89.31 Precision: 88.00 Recall: 91.67
#
# Fold 9
#
# -----Train----------
# AUC: 92.14 Precision: 92.15 Recall: 92.53
#
# -----Validation-----
# AUC: 86.96 Precision: 80.00 Recall: 100.00
#
# Fold 10
#
# -----Train----------
# AUC: 92.97 Precision: 92.62 Recall: 93.78
#
# -----Validation-----
# AUC: 87.32 Precision: 90.91 Recall: 83.33
#
# Fold 11
#
# -----Train----------
# AUC: 93.83 Precision: 93.80 Recall: 94.19
#
# -----Validation-----
# AUC: 87.14 Precision: 84.62 Recall: 91.67
#
# wheezy-copper-turtle-magic 19
#
# Fold 1
#
# -----Train----------
# AUC: 94.75 Precision: 94.24 Recall: 95.42
#
# -----Validation-----
# AUC: 91.92 Precision: 95.65 Recall: 88.00
#
# Fold 2
#
# -----Train----------
# AUC: 94.34 Precision: 93.15 Recall: 95.85
#
# -----Validation-----
# AUC: 89.58 Precision: 82.76 Recall: 100.00
#
# Fold 3
#
# -----Train----------
# AUC: 95.40 Precision: 95.44 Recall: 95.44
#
# -----Validation-----
# AUC: 85.42 Precision: 81.48 Recall: 91.67
#
# Fold 4
#
# -----Train----------
# AUC: 92.88 Precision: 92.59 Recall: 93.36
#
# -----Validation-----
# AUC: 85.42 Precision: 84.00 Recall: 87.50
#
# Fold 5
#
# -----Train----------
# AUC: 94.55 Precision: 93.52 Recall: 95.85
#
# -----Validation-----
# AUC: 87.50 Precision: 82.14 Recall: 95.83
#
# Fold 6
#
# -----Train----------
# AUC: 94.55 Precision: 93.17 Recall: 96.27
#
# -----Validation-----
# AUC: 87.50 Precision: 82.14 Recall: 95.83
#
# Fold 7
#
# -----Train----------
# AUC: 94.55 Precision: 93.52 Recall: 95.85
#
# -----Validation-----
# AUC: 83.33 Precision: 83.33 Recall: 83.33
#
# Fold 8
#
# -----Train----------
# AUC: 94.13 Precision: 93.12 Recall: 95.44
#
# -----Validation-----
# AUC: 91.67 Precision: 95.45 Recall: 87.50
#
# Fold 9
#
# -----Train----------
# AUC: 94.14 Precision: 92.43 Recall: 96.27
#
# -----Validation-----
# AUC: 89.58 Precision: 100.00 Recall: 79.17
#
# Fold 10
#
# -----Train----------
# AUC: 94.36 Precision: 93.50 Recall: 95.44
#
# -----Validation-----
# AUC: 89.40 Precision: 91.30 Recall: 87.50
#
# Fold 11
#
# -----Train----------
# AUC: 95.40 Precision: 95.06 Recall: 95.85
#
# -----Validation-----
# AUC: 85.14 Precision: 86.96 Recall: 83.33
#
# wheezy-copper-turtle-magic 20
#
# Fold 1
#
# -----Train----------
# AUC: 92.32 Precision: 95.19 Recall: 88.79
#
# -----Validation-----
# AUC: 76.78 Precision: 80.00 Recall: 69.57
#
# Fold 2
#
# -----Train----------
# AUC: 90.64 Precision: 92.06 Recall: 88.34
#
# -----Validation-----
# AUC: 89.65 Precision: 87.50 Recall: 91.30
#
# Fold 3
#
# -----Train----------
# AUC: 91.04 Precision: 93.75 Recall: 87.44
#
# -----Validation-----
# AUC: 76.54 Precision: 77.27 Recall: 73.91
#
# Fold 4
#
# -----Train----------
# AUC: 91.48 Precision: 93.81 Recall: 88.34
#
# -----Validation-----
# AUC: 78.62 Precision: 80.95 Recall: 73.91
#
# Fold 5
#
# -----Train----------
# AUC: 92.35 Precision: 95.22 Recall: 88.84
#
# -----Validation-----
# AUC: 93.56 Precision: 91.30 Recall: 95.45
#
# Fold 6
#
# -----Train----------
# AUC: 91.24 Precision: 95.10 Recall: 86.61
#
# -----Validation-----
# AUC: 84.47 Precision: 89.47 Recall: 77.27
#
# Fold 7
#
# -----Train----------
# AUC: 91.49 Precision: 94.26 Recall: 87.95
#
# -----Validation-----
# AUC: 80.11 Precision: 84.21 Recall: 72.73
#
# Fold 8
#
# -----Train----------
# AUC: 90.65 Precision: 92.89 Recall: 87.50
#
# -----Validation-----
# AUC: 91.29 Precision: 90.91 Recall: 90.91
#
# Fold 9
#
# -----Train----------
# AUC: 92.37 Precision: 94.79 Recall: 89.29
#
# -----Validation-----
# AUC: 86.36 Precision: 100.00 Recall: 72.73
#
# Fold 10
#
# -----Train----------
# AUC: 90.67 Precision: 92.49 Recall: 87.95
#
# -----Validation-----
# AUC: 82.58 Precision: 81.82 Recall: 81.82
#
# Fold 11
#
# -----Train----------
# AUC: 92.58 Precision: 95.24 Recall: 89.29
#
# -----Validation-----
# AUC: 88.83 Precision: 94.74 Recall: 81.82
#
# wheezy-copper-turtle-magic 21
#
# Fold 1
#
# -----Train----------
# AUC: 91.68 Precision: 89.88 Recall: 94.29
#
# -----Validation-----
# AUC: 87.67 Precision: 85.19 Recall: 92.00
#
# Fold 2
#
# -----Train----------
# AUC: 91.90 Precision: 90.87 Recall: 93.47
#
# -----Validation-----
# AUC: 85.75 Precision: 87.50 Recall: 84.00
#
# Fold 3
#
# -----Train----------
# AUC: 91.09 Precision: 90.73 Recall: 91.84
#
# -----Validation-----
# AUC: 93.92 Precision: 95.83 Recall: 92.00
#
# Fold 4
#
# -----Train----------
# AUC: 91.26 Precision: 89.19 Recall: 94.29
#
# -----Validation-----
# AUC: 75.33 Precision: 72.41 Recall: 84.00
#
# Fold 5
#
# -----Train----------
# AUC: 89.59 Precision: 87.07 Recall: 93.47
#
# -----Validation-----
# AUC: 89.58 Precision: 83.33 Recall: 100.00
#
# Fold 6
#
# -----Train----------
# AUC: 91.06 Precision: 89.45 Recall: 93.47
#
# -----Validation-----
# AUC: 89.58 Precision: 83.33 Recall: 100.00
#
# Fold 7
#
# -----Train----------
# AUC: 91.91 Precision: 90.59 Recall: 93.90
#
# -----Validation-----
# AUC: 81.25 Precision: 80.00 Recall: 83.33
#
# Fold 8
#
# -----Train----------
# AUC: 91.29 Precision: 90.16 Recall: 93.09
#
# -----Validation-----
# AUC: 85.42 Precision: 84.00 Recall: 87.50
#
# Fold 9
#
# -----Train----------
# AUC: 91.71 Precision: 90.87 Recall: 93.09
#
# -----Validation-----
# AUC: 83.33 Precision: 80.77 Recall: 87.50
#
# Fold 10
#
# -----Train----------
# AUC: 91.30 Precision: 89.53 Recall: 93.90
#
# -----Validation-----
# AUC: 80.80 Precision: 80.00 Recall: 83.33
#
# Fold 11
#
# -----Train----------
# AUC: 90.87 Precision: 87.97 Recall: 95.12
#
# -----Validation-----
# AUC: 85.05 Precision: 84.00 Recall: 87.50
#
# wheezy-copper-turtle-magic 22
#
# Fold 1
#
# -----Train----------
# AUC: 92.51 Precision: 90.57 Recall: 95.62
#
# -----Validation-----
# AUC: 92.15 Precision: 95.83 Recall: 88.46
#
# Fold 2
#
# -----Train----------
# AUC: 92.10 Precision: 90.19 Recall: 95.22
#
# -----Validation-----
# AUC: 89.90 Precision: 88.89 Recall: 92.31
#
# Fold 3
#
# -----Train----------
# AUC: 93.35 Precision: 91.67 Recall: 96.03
#
# -----Validation-----
# AUC: 85.50 Precision: 80.00 Recall: 96.00
#
# Fold 4
#
# -----Train----------
# AUC: 94.16 Precision: 92.11 Recall: 97.22
#
# -----Validation-----
# AUC: 85.50 Precision: 80.00 Recall: 96.00
#
# Fold 5
#
# -----Train----------
# AUC: 93.54 Precision: 91.39 Recall: 96.83
#
# -----Validation-----
# AUC: 83.75 Precision: 86.96 Recall: 80.00
#
# Fold 6
#
# -----Train----------
# AUC: 92.31 Precision: 90.26 Recall: 95.63
#
# -----Validation-----
# AUC: 91.83 Precision: 92.00 Recall: 92.00
#
# Fold 7
#
# -----Train----------
# AUC: 91.52 Precision: 90.11 Recall: 94.05
#
# -----Validation-----
# AUC: 85.67 Precision: 84.62 Recall: 88.00
#
# Fold 8
#
# -----Train----------
# AUC: 92.99 Precision: 91.92 Recall: 94.84
#
# -----Validation-----
# AUC: 80.78 Precision: 76.67 Recall: 92.00
#
# Fold 9
#
# -----Train----------
# AUC: 93.56 Precision: 91.39 Recall: 96.83
#
# -----Validation-----
# AUC: 81.13 Precision: 80.77 Recall: 84.00
#
# Fold 10
#
# -----Train----------
# AUC: 93.64 Precision: 93.33 Recall: 94.44
#
# -----Validation-----
# AUC: 89.48 Precision: 88.46 Recall: 92.00
#
# Fold 11
#
# -----Train----------
# AUC: 92.57 Precision: 91.22 Recall: 94.84
#
# -----Validation-----
# AUC: 89.30 Precision: 85.71 Recall: 96.00
#
# wheezy-copper-turtle-magic 23
#
# Fold 1
#
# -----Train----------
# AUC: 90.31 Precision: 92.21 Recall: 88.38
#
# -----Validation-----
# AUC: 85.67 Precision: 84.62 Recall: 88.00
#
# Fold 2
#
# -----Train----------
# AUC: 91.16 Precision: 93.07 Recall: 89.21
#
# -----Validation-----
# AUC: 77.67 Precision: 81.82 Recall: 72.00
#
# Fold 3
#
# -----Train----------
# AUC: 91.37 Precision: 92.41 Recall: 90.50
#
# -----Validation-----
# AUC: 87.50 Precision: 90.91 Recall: 83.33
#
# Fold 4
#
# -----Train----------
# AUC: 91.82 Precision: 93.56 Recall: 90.08
#
# -----Validation-----
# AUC: 89.40 Precision: 91.30 Recall: 87.50
#
# Fold 5
#
# -----Train----------
# AUC: 92.24 Precision: 93.62 Recall: 90.91
#
# -----Validation-----
# AUC: 78.80 Precision: 81.82 Recall: 75.00
#
# Fold 6
#
# -----Train----------
# AUC: 91.62 Precision: 93.53 Recall: 89.67
#
# -----Validation-----
# AUC: 83.15 Precision: 90.00 Recall: 75.00
#
# Fold 7
#
# -----Train----------
# AUC: 90.78 Precision: 93.04 Recall: 88.43
#
# -----Validation-----
# AUC: 85.14 Precision: 86.96 Recall: 83.33
#
# Fold 8
#
# -----Train----------
# AUC: 91.62 Precision: 93.91 Recall: 89.26
#
# -----Validation-----
# AUC: 80.98 Precision: 85.71 Recall: 75.00
#
# Fold 9
#
# -----Train----------
# AUC: 90.39 Precision: 94.14 Recall: 86.36
#
# -----Validation-----
# AUC: 85.24 Precision: 90.48 Recall: 79.17
#
# Fold 10
#
# -----Train----------
# AUC: 90.79 Precision: 93.42 Recall: 88.02
#
# -----Validation-----
# AUC: 81.07 Precision: 89.47 Recall: 70.83
#
# Fold 11
#
# -----Train----------
# AUC: 91.81 Precision: 93.19 Recall: 90.50
#
# -----Validation-----
# AUC: 87.41 Precision: 95.00 Recall: 79.17
#
# wheezy-copper-turtle-magic 24
#
# Fold 1
#
# -----Train----------
# AUC: 91.72 Precision: 88.11 Recall: 94.79
#
# -----Validation-----
# AUC: 84.66 Precision: 85.71 Recall: 81.82
#
# Fold 2
#
# -----Train----------
# AUC: 92.74 Precision: 90.45 Recall: 94.31
#
# -----Validation-----
# AUC: 85.04 Precision: 80.00 Recall: 90.91
#
# Fold 3
#
# -----Train----------
# AUC: 92.00 Precision: 91.12 Recall: 91.98
#
# -----Validation-----
# AUC: 77.98 Precision: 73.91 Recall: 80.95
#
# Fold 4
#
# -----Train----------
# AUC: 90.76 Precision: 88.29 Recall: 92.45
#
# -----Validation-----
# AUC: 86.61 Precision: 85.71 Recall: 85.71
#
# Fold 5
#
# -----Train----------
# AUC: 92.34 Precision: 93.20 Recall: 90.57
#
# -----Validation-----
# AUC: 88.99 Precision: 86.36 Recall: 90.48
#
# Fold 6
#
# -----Train----------
# AUC: 91.06 Precision: 90.95 Recall: 90.09
#
# -----Validation-----
# AUC: 86.31 Precision: 89.47 Recall: 80.95
#
# Fold 7
#
# -----Train----------
# AUC: 91.48 Precision: 91.83 Recall: 90.09
#
# -----Validation-----
# AUC: 82.44 Precision: 78.26 Recall: 85.71
#
# Fold 8
#
# -----Train----------
# AUC: 91.76 Precision: 91.08 Recall: 91.51
#
# -----Validation-----
# AUC: 82.14 Precision: 80.95 Recall: 80.95
#
# Fold 9
#
# -----Train----------
# AUC: 91.76 Precision: 91.08 Recall: 91.51
#
# -----Validation-----
# AUC: 86.90 Precision: 82.61 Recall: 90.48
#
# Fold 10
#
# -----Train----------
# AUC: 92.22 Precision: 91.55 Recall: 91.98
#
# -----Validation-----
# AUC: 86.34 Precision: 85.71 Recall: 85.71
#
# Fold 11
#
# -----Train----------
# AUC: 91.54 Precision: 91.04 Recall: 91.04
#
# -----Validation-----
# AUC: 81.78 Precision: 80.95 Recall: 80.95
#
# wheezy-copper-turtle-magic 25
#
# Fold 1
#
# -----Train----------
# AUC: 90.59 Precision: 93.37 Recall: 86.73
#
# -----Validation-----
# AUC: 86.74 Precision: 90.00 Recall: 81.82
#
# Fold 2
#
# -----Train----------
# AUC: 90.07 Precision: 94.21 Recall: 84.83
#
# -----Validation-----
# AUC: 84.47 Precision: 89.47 Recall: 77.27
#
# Fold 3
#
# -----Train----------
# AUC: 90.88 Precision: 93.00 Recall: 87.74
#
# -----Validation-----
# AUC: 79.76 Precision: 80.00 Recall: 76.19
#
# Fold 4
#
# -----Train----------
# AUC: 91.54 Precision: 93.97 Recall: 88.21
#
# -----Validation-----
# AUC: 72.92 Precision: 73.68 Recall: 66.67
#
# Fold 5
#
# -----Train----------
# AUC: 90.17 Precision: 92.89 Recall: 86.32
#
# -----Validation-----
# AUC: 88.69 Precision: 90.00 Recall: 85.71
#
# Fold 6
#
# -----Train----------
# AUC: 90.63 Precision: 93.40 Recall: 86.79
#
# -----Validation-----
# AUC: 88.51 Precision: 90.00 Recall: 85.71
#
# Fold 7
#
# -----Train----------
# AUC: 90.39 Precision: 93.37 Recall: 86.32
#
# -----Validation-----
# AUC: 93.06 Precision: 95.00 Recall: 90.48
#
# Fold 8
#
# -----Train----------
# AUC: 89.50 Precision: 92.35 Recall: 85.38
#
# -----Validation-----
# AUC: 88.51 Precision: 90.00 Recall: 85.71
#
# Fold 9
#
# -----Train----------
# AUC: 91.15 Precision: 92.61 Recall: 88.68
#
# -----Validation-----
# AUC: 90.48 Precision: 100.00 Recall: 80.95
#
# Fold 10
#
# -----Train----------
# AUC: 91.74 Precision: 94.90 Recall: 87.74
#
# -----Validation-----
# AUC: 86.13 Precision: 89.47 Recall: 80.95
#
# Fold 11
#
# -----Train----------
# AUC: 90.58 Precision: 94.30 Recall: 85.85
#
# -----Validation-----
# AUC: 90.89 Precision: 90.48 Recall: 90.48
#
# wheezy-copper-turtle-magic 26
#
# Fold 1
#
# -----Train----------
# AUC: 89.84 Precision: 89.67 Recall: 89.25
#
# -----Validation-----
# AUC: 84.29 Precision: 89.47 Recall: 77.27
#
# Fold 2
#
# -----Train----------
# AUC: 90.48 Precision: 91.35 Recall: 88.79
#
# -----Validation-----
# AUC: 82.31 Precision: 79.17 Recall: 86.36
#
# Fold 3
#
# -----Train----------
# AUC: 90.29 Precision: 90.14 Recall: 89.72
#
# -----Validation-----
# AUC: 89.03 Precision: 84.00 Recall: 95.45
#
# Fold 4
#
# -----Train----------
# AUC: 90.84 Precision: 88.44 Recall: 92.99
#
# -----Validation-----
# AUC: 82.21 Precision: 81.82 Recall: 81.82
#
# Fold 5
#
# -----Train----------
# AUC: 89.43 Precision: 88.48 Recall: 89.72
#
# -----Validation-----
# AUC: 86.66 Precision: 86.36 Recall: 86.36
#
# Fold 6
#
# -----Train----------
# AUC: 92.12 Precision: 92.06 Recall: 91.63
#
# -----Validation-----
# AUC: 75.05 Precision: 72.73 Recall: 76.19
#
# Fold 7
#
# -----Train----------
# AUC: 91.23 Precision: 90.74 Recall: 91.16
#
# -----Validation-----
# AUC: 75.26 Precision: 70.83 Recall: 80.95
#
# Fold 8
#
# -----Train----------
# AUC: 90.51 Precision: 91.39 Recall: 88.84
#
# -----Validation-----
# AUC: 90.89 Precision: 90.48 Recall: 90.48
#
# Fold 9
#
# -----Train----------
# AUC: 90.38 Precision: 88.74 Recall: 91.63
#
# -----Validation-----
# AUC: 83.75 Precision: 88.89 Recall: 76.19
#
# Fold 10
#
# -----Train----------
# AUC: 91.45 Precision: 91.16 Recall: 91.16
#
# -----Validation-----
# AUC: 84.16 Precision: 81.82 Recall: 85.71
#
# Fold 11
#
# -----Train----------
# AUC: 92.37 Precision: 91.71 Recall: 92.56
#
# -----Validation-----
# AUC: 79.40 Precision: 80.00 Recall: 76.19
#
# wheezy-copper-turtle-magic 27
#
# Fold 1
#
# -----Train----------
# AUC: 91.17 Precision: 91.51 Recall: 89.81
#
# -----Validation-----
# AUC: 91.45 Precision: 90.91 Recall: 90.91
#
# Fold 2
#
# -----Train----------
# AUC: 90.90 Precision: 88.50 Recall: 92.59
#
# -----Validation-----
# AUC: 80.91 Precision: 78.26 Recall: 81.82
#
# Fold 3
#
# -----Train----------
# AUC: 91.08 Precision: 89.59 Recall: 91.67
#
# -----Validation-----
# AUC: 82.95 Precision: 76.92 Recall: 90.91
#
# Fold 4
#
# -----Train----------
# AUC: 90.62 Precision: 89.50 Recall: 90.74
#
# -----Validation-----
# AUC: 80.49 Precision: 78.26 Recall: 81.82
#
# Fold 5
#
# -----Train----------
# AUC: 90.90 Precision: 88.84 Recall: 92.13
#
# -----Validation-----
# AUC: 82.39 Precision: 85.00 Recall: 77.27
#
# Fold 6
#
# -----Train----------
# AUC: 90.90 Precision: 88.84 Recall: 92.13
#
# -----Validation-----
# AUC: 71.97 Precision: 68.00 Recall: 77.27
#
# Fold 7
#
# -----Train----------
# AUC: 91.08 Precision: 89.59 Recall: 91.67
#
# -----Validation-----
# AUC: 89.20 Precision: 86.96 Recall: 90.91
#
# Fold 8
#
# -----Train----------
# AUC: 90.66 Precision: 89.19 Recall: 91.24
#
# -----Validation-----
# AUC: 85.12 Precision: 76.92 Recall: 95.24
#
# Fold 9
#
# -----Train----------
# AUC: 90.82 Precision: 90.32 Recall: 90.32
#
# -----Validation-----
# AUC: 84.52 Precision: 81.82 Recall: 85.71
#
# Fold 10
#
# -----Train----------
# AUC: 91.31 Precision: 90.05 Recall: 91.71
#
# -----Validation-----
# AUC: 88.99 Precision: 86.36 Recall: 90.48
#
# Fold 11
#
# -----Train----------
# AUC: 91.35 Precision: 89.33 Recall: 92.63
#
# -----Validation-----
# AUC: 81.85 Precision: 84.21 Recall: 76.19
#
# wheezy-copper-turtle-magic 28
#
# Fold 1
#
# -----Train----------
# AUC: 91.58 Precision: 91.43 Recall: 91.80
#
# -----Validation-----
# AUC: 88.00 Precision: 88.00 Recall: 88.00
#
# Fold 2
#
# -----Train----------
# AUC: 93.63 Precision: 93.83 Recall: 93.44
#
# -----Validation-----
# AUC: 78.00 Precision: 76.92 Recall: 80.00
#
# Fold 3
#
# -----Train----------
# AUC: 91.99 Precision: 92.89 Recall: 90.98
#
# -----Validation-----
# AUC: 78.00 Precision: 75.00 Recall: 84.00
#
# Fold 4
#
# -----Train----------
# AUC: 91.58 Precision: 91.77 Recall: 91.39
#
# -----Validation-----
# AUC: 84.00 Precision: 79.31 Recall: 92.00
#
# Fold 5
#
# -----Train----------
# AUC: 92.01 Precision: 91.50 Recall: 92.62
#
# -----Validation-----
# AUC: 89.75 Precision: 88.46 Recall: 92.00
#
# Fold 6
#
# -----Train----------
# AUC: 91.82 Precision: 90.20 Recall: 93.88
#
# -----Validation-----
# AUC: 91.67 Precision: 95.45 Recall: 87.50
#
# Fold 7
#
# -----Train----------
# AUC: 92.84 Precision: 93.03 Recall: 92.65
#
# -----Validation-----
# AUC: 81.25 Precision: 80.00 Recall: 83.33
#
# Fold 8
#
# -----Train----------
# AUC: 90.80 Precision: 90.65 Recall: 91.02
#
# -----Validation-----
# AUC: 89.58 Precision: 91.30 Recall: 87.50
#
# Fold 9
#
# -----Train----------
# AUC: 90.59 Precision: 90.28 Recall: 91.02
#
# -----Validation-----
# AUC: 93.75 Precision: 92.00 Recall: 95.83
#
# Fold 10
#
# -----Train----------
# AUC: 92.02 Precision: 91.53 Recall: 92.65
#
# -----Validation-----
# AUC: 85.42 Precision: 84.00 Recall: 87.50
#
# Fold 11
#
# -----Train----------
# AUC: 91.41 Precision: 90.44 Recall: 92.65
#
# -----Validation-----
# AUC: 85.42 Precision: 86.96 Recall: 83.33
#
# wheezy-copper-turtle-magic 29
#
# Fold 1
#
# -----Train----------
# AUC: 92.03 Precision: 90.30 Recall: 94.27
#
# -----Validation-----
# AUC: 84.78 Precision: 86.36 Recall: 82.61
#
# Fold 2
#
# -----Train----------
# AUC: 92.46 Precision: 89.39 Recall: 96.48
#
# -----Validation-----
# AUC: 80.43 Precision: 76.92 Recall: 86.96
#
# Fold 3
#
# -----Train----------
# AUC: 92.68 Precision: 89.75 Recall: 96.48
#
# -----Validation-----
# AUC: 80.43 Precision: 81.82 Recall: 78.26
#
# Fold 4
#
# -----Train----------
# AUC: 92.91 Precision: 91.14 Recall: 95.15
#
# -----Validation-----
# AUC: 76.09 Precision: 71.43 Recall: 86.96
#
# Fold 5
#
# -----Train----------
# AUC: 92.02 Precision: 89.63 Recall: 95.15
#
# -----Validation-----
# AUC: 84.78 Precision: 76.67 Recall: 100.00
#
# Fold 6
#
# -----Train----------
# AUC: 90.92 Precision: 88.75 Recall: 93.83
#
# -----Validation-----
# AUC: 86.96 Precision: 86.96 Recall: 86.96
#
# Fold 7
#
# -----Train----------
# AUC: 92.05 Precision: 89.96 Recall: 94.71
#
# -----Validation-----
# AUC: 91.01 Precision: 88.00 Recall: 95.65
#
# Fold 8
#
# -----Train----------
# AUC: 92.49 Precision: 89.71 Recall: 96.04
#
# -----Validation-----
# AUC: 86.66 Precision: 86.96 Recall: 86.96
#
# Fold 9
#
# -----Train----------
# AUC: 92.50 Precision: 90.42 Recall: 95.18
#
# -----Validation-----
# AUC: 86.36 Precision: 83.33 Recall: 90.91
#
# Fold 10
#
# -----Train----------
# AUC: 93.38 Precision: 91.25 Recall: 96.05
#
# -----Validation-----
# AUC: 75.00 Precision: 70.37 Recall: 86.36
#
# Fold 11
#
# -----Train----------
# AUC: 92.28 Precision: 90.72 Recall: 94.30
#
# -----Validation-----
# AUC: 79.55 Precision: 70.97 Recall: 100.00
#
# wheezy-copper-turtle-magic 30
#
# Fold 1
#
# -----Train----------
# AUC: 92.37 Precision: 94.44 Recall: 90.57
#
# -----Validation-----
# AUC: 89.48 Precision: 88.46 Recall: 92.00
#
# Fold 2
#
# -----Train----------
# AUC: 93.42 Precision: 94.94 Recall: 92.21
#
# -----Validation-----
# AUC: 85.48 Precision: 87.50 Recall: 84.00
#
# Fold 3
#
# -----Train----------
# AUC: 93.38 Precision: 94.19 Recall: 93.03
#
# -----Validation-----
# AUC: 85.65 Precision: 90.91 Recall: 80.00
#
# Fold 4
#
# -----Train----------
# AUC: 92.35 Precision: 94.07 Recall: 90.98
#
# -----Validation-----
# AUC: 89.48 Precision: 88.46 Recall: 92.00
#
# Fold 5
#
# -----Train----------
# AUC: 93.35 Precision: 93.47 Recall: 93.85
#
# -----Validation-----
# AUC: 85.18 Precision: 87.50 Recall: 84.00
#
# Fold 6
#
# -----Train----------
# AUC: 94.28 Precision: 95.42 Recall: 93.47
#
# -----Validation-----
# AUC: 78.03 Precision: 76.92 Recall: 83.33
#
# Fold 7
#
# -----Train----------
# AUC: 93.63 Precision: 94.61 Recall: 93.06
#
# -----Validation-----
# AUC: 85.42 Precision: 100.00 Recall: 70.83
#
# Fold 8
#
# -----Train----------
# AUC: 93.00 Precision: 94.17 Recall: 92.24
#
# -----Validation-----
# AUC: 86.93 Precision: 87.50 Recall: 87.50
#
# Fold 9
#
# -----Train----------
# AUC: 93.22 Precision: 94.56 Recall: 92.24
#
# -----Validation-----
# AUC: 82.77 Precision: 86.36 Recall: 79.17
#
# Fold 10
#
# -----Train----------
# AUC: 92.94 Precision: 93.09 Recall: 93.47
#
# -----Validation-----
# AUC: 86.74 Precision: 84.62 Recall: 91.67
#
# Fold 11
#
# -----Train----------
# ...
# AUC: 81.96 Precision: 89.47 Recall: 73.91
#
# Fold 9
#
# -----Train----------
# AUC: 89.60 Precision: 89.07 Recall: 92.83
#
# -----Validation-----
# AUC: 78.95 Precision: 74.19 Recall: 100.00
#
# Fold 10
#
# -----Train----------
# AUC: 89.90 Precision: 86.84 Recall: 97.47
#
# -----Validation-----
# AUC: 83.41 Precision: 86.36 Recall: 82.61
#
# Fold 11
#
# -----Train----------
# AUC: 87.87 Precision: 86.90 Recall: 92.41
#
# -----Validation-----
# AUC: 82.95 Precision: 83.33 Recall: 86.96
#
# wheezy-copper-turtle-magic 502
#
# Fold 1
#
# -----Train----------
# AUC: 93.27 Precision: 92.44 Recall: 94.02
#
# -----Validation-----
# AUC: 85.75 Precision: 84.00 Recall: 87.50
#
# Fold 2
#
# -----Train----------
# AUC: 92.86 Precision: 91.67 Recall: 94.02
#
# -----Validation-----
# AUC: 85.83 Precision: 81.48 Recall: 91.67
#
# Fold 3
#
# -----Train----------
# AUC: 93.69 Precision: 93.97 Recall: 93.16
#
# -----Validation-----
# AUC: 93.75 Precision: 95.65 Recall: 91.67
#
# Fold 4
#
# -----Train----------
# AUC: 93.49 Precision: 93.19 Recall: 93.59
#
# -----Validation-----
# AUC: 85.42 Precision: 81.48 Recall: 91.67
#
# Fold 5
#
# -----Train----------
# AUC: 92.86 Precision: 92.74 Recall: 92.74
#
# -----Validation-----
# AUC: 87.50 Precision: 87.50 Recall: 87.50
#
# Fold 6
#
# -----Train----------
# AUC: 93.10 Precision: 92.08 Recall: 94.04
#
# -----Validation-----
# AUC: 89.22 Precision: 95.00 Recall: 82.61
#
# Fold 7
#
# -----Train----------
# AUC: 93.95 Precision: 92.21 Recall: 95.74
#
# -----Validation-----
# AUC: 87.14 Precision: 90.48 Recall: 82.61
#
# Fold 8
#
# -----Train----------
# AUC: 93.93 Precision: 92.92 Recall: 94.89
#
# -----Validation-----
# AUC: 89.40 Precision: 87.50 Recall: 91.30
#
# Fold 9
#
# -----Train----------
# AUC: 93.30 Precision: 92.47 Recall: 94.04
#
# -----Validation-----
# AUC: 83.24 Precision: 75.86 Recall: 95.65
#
# Fold 10
#
# -----Train----------
# AUC: 93.73 Precision: 92.18 Recall: 95.32
#
# -----Validation-----
# AUC: 85.14 Precision: 83.33 Recall: 86.96
#
# Fold 11
#
# -----Train----------
# AUC: 92.67 Precision: 92.02 Recall: 93.19
#
# -----Validation-----
# AUC: 85.14 Precision: 83.33 Recall: 86.96
#
# wheezy-copper-turtle-magic 503
#
# Fold 1
#
# -----Train----------
# AUC: 92.83 Precision: 96.92 Recall: 88.32
#
# -----Validation-----
# AUC: 82.02 Precision: 88.89 Recall: 72.73
#
# Fold 2
#
# -----Train----------
# AUC: 92.38 Precision: 95.94 Recall: 88.32
#
# -----Validation-----
# AUC: 79.55 Precision: 100.00 Recall: 59.09
#
# Fold 3
#
# -----Train----------
# AUC: 91.94 Precision: 94.97 Recall: 88.32
#
# -----Validation-----
# AUC: 84.19 Precision: 94.12 Recall: 72.73
#
# Fold 4
#
# -----Train----------
# AUC: 92.40 Precision: 95.02 Recall: 89.25
#
# -----Validation-----
# AUC: 84.39 Precision: 85.71 Recall: 81.82
#
# Fold 5
#
# -----Train----------
# AUC: 92.15 Precision: 95.92 Recall: 87.85
#
# -----Validation-----
# AUC: 84.39 Precision: 85.71 Recall: 81.82
#
# Fold 6
#
# -----Train----------
# AUC: 91.52 Precision: 94.06 Recall: 88.37
#
# -----Validation-----
# AUC: 90.68 Precision: 94.74 Recall: 85.71
#
# Fold 7
#
# -----Train----------
# AUC: 90.82 Precision: 94.42 Recall: 86.51
#
# -----Validation-----
# AUC: 88.10 Precision: 100.00 Recall: 76.19
#
# Fold 8
#
# -----Train----------
# AUC: 89.89 Precision: 94.30 Recall: 84.65
#
# -----Validation-----
# AUC: 93.07 Precision: 90.91 Recall: 95.24
#
# Fold 9
#
# -----Train----------
# AUC: 92.01 Precision: 93.69 Recall: 89.77
#
# -----Validation-----
# AUC: 95.35 Precision: 95.24 Recall: 95.24
#
# Fold 10
#
# -----Train----------
# AUC: 92.21 Precision: 95.02 Recall: 88.84
#
# -----Validation-----
# AUC: 83.55 Precision: 88.89 Recall: 76.19
#
# Fold 11
#
# -----Train----------
# AUC: 90.59 Precision: 94.39 Recall: 86.05
#
# -----Validation-----
# AUC: 90.58 Precision: 94.74 Recall: 85.71
#
# wheezy-copper-turtle-magic 504
#
# Fold 1
#
# -----Train----------
# AUC: 92.77 Precision: 92.47 Recall: 93.64
#
# -----Validation-----
# AUC: 87.23 Precision: 87.50 Recall: 87.50
#
# Fold 2
#
# -----Train----------
# AUC: 93.21 Precision: 92.89 Recall: 94.07
#
# -----Validation-----
# AUC: 78.62 Precision: 76.92 Recall: 83.33
#
# Fold 3
#
# -----Train----------
# AUC: 92.34 Precision: 92.41 Recall: 92.80
#
# -----Validation-----
# AUC: 95.74 Precision: 95.83 Recall: 95.83
#
# Fold 4
#
# -----Train----------
# AUC: 93.87 Precision: 93.33 Recall: 94.92
#
# -----Validation-----
# AUC: 89.02 Precision: 88.00 Recall: 91.67
#
# Fold 5
#
# -----Train----------
# AUC: 93.67 Precision: 93.67 Recall: 94.07
#
# -----Validation-----
# AUC: 87.12 Precision: 90.91 Recall: 83.33
#
# Fold 6
#
# -----Train----------
# AUC: 94.31 Precision: 93.75 Recall: 95.34
#
# -----Validation-----
# AUC: 87.12 Precision: 90.91 Recall: 83.33
#
# Fold 7
#
# -----Train----------
# AUC: 92.37 Precision: 92.77 Recall: 92.37
#
# -----Validation-----
# AUC: 84.47 Precision: 81.48 Recall: 91.67
#
# Fold 8
#
# -----Train----------
# AUC: 92.81 Precision: 92.86 Recall: 93.25
#
# -----Validation-----
# AUC: 82.11 Precision: 80.00 Recall: 86.96
#
# Fold 9
#
# -----Train----------
# AUC: 93.91 Precision: 94.09 Recall: 94.09
#
# -----Validation-----
# AUC: 86.76 Precision: 90.48 Recall: 82.61
#
# Fold 10
#
# -----Train----------
# AUC: 91.94 Precision: 92.02 Recall: 92.41
#
# -----Validation-----
# AUC: 88.93 Precision: 90.91 Recall: 86.96
#
# Fold 11
#
# -----Train----------
# AUC: 92.56 Precision: 91.77 Recall: 94.09
#
# -----Validation-----
# AUC: 86.56 Precision: 84.00 Recall: 91.30
#
# wheezy-copper-turtle-magic 505
#
# Fold 1
#
# -----Train----------
# AUC: 91.02 Precision: 90.17 Recall: 91.74
#
# -----Validation-----
# AUC: 93.75 Precision: 100.00 Recall: 87.50
#
# Fold 2
#
# -----Train----------
# AUC: 92.52 Precision: 92.61 Recall: 92.21
#
# -----Validation-----
# AUC: 93.57 Precision: 95.45 Recall: 91.30
#
# Fold 3
#
# -----Train----------
# AUC: 92.07 Precision: 93.30 Recall: 90.48
#
# -----Validation-----
# AUC: 80.71 Precision: 85.00 Recall: 73.91
#
# Fold 4
#
# -----Train----------
# AUC: 91.22 Precision: 92.04 Recall: 90.04
#
# -----Validation-----
# AUC: 82.97 Precision: 82.61 Recall: 82.61
#
# Fold 5
#
# -----Train----------
# AUC: 92.30 Precision: 92.58 Recall: 91.77
#
# -----Validation-----
# AUC: 85.24 Precision: 80.77 Recall: 91.30
#
# Fold 6
#
# -----Train----------
# AUC: 93.81 Precision: 93.16 Recall: 94.37
#
# -----Validation-----
# AUC: 87.23 Precision: 86.96 Recall: 86.96
#
# Fold 7
#
# -----Train----------
# AUC: 92.52 Precision: 92.24 Recall: 92.64
#
# -----Validation-----
# AUC: 85.14 Precision: 83.33 Recall: 86.96
#
# Fold 8
#
# -----Train----------
# AUC: 92.50 Precision: 93.75 Recall: 90.91
#
# -----Validation-----
# AUC: 84.96 Precision: 90.00 Recall: 78.26
#
# Fold 9
#
# -----Train----------
# AUC: 92.75 Precision: 92.64 Recall: 92.64
#
# -----Validation-----
# AUC: 84.78 Precision: 86.36 Recall: 82.61
#
# Fold 10
#
# -----Train----------
# AUC: 93.19 Precision: 92.34 Recall: 93.94
#
# -----Validation-----
# AUC: 78.26 Precision: 78.26 Recall: 78.26
#
# Fold 11
#
# -----Train----------
# AUC: 93.39 Precision: 93.48 Recall: 93.07
#
# -----Validation-----
# AUC: 78.26 Precision: 74.07 Recall: 86.96
#
# wheezy-copper-turtle-magic 506
#
# Fold 1
#
# -----Train----------
# AUC: 92.34 Precision: 91.80 Recall: 92.95
#
# -----Validation-----
# AUC: 88.00 Precision: 95.24 Recall: 80.00
#
# Fold 2
#
# -----Train----------
# AUC: 92.13 Precision: 92.12 Recall: 92.12
#
# -----Validation-----
# AUC: 86.00 Precision: 80.00 Recall: 96.00
#
# Fold 3
#
# -----Train----------
# AUC: 91.12 Precision: 89.64 Recall: 92.98
#
# -----Validation-----
# AUC: 85.83 Precision: 81.48 Recall: 91.67
#
# Fold 4
#
# -----Train----------
# AUC: 93.20 Precision: 91.97 Recall: 94.63
#
# -----Validation-----
# AUC: 85.42 Precision: 81.48 Recall: 91.67
#
# Fold 5
#
# -----Train----------
# AUC: 92.78 Precision: 92.95 Recall: 92.56
#
# -----Validation-----
# AUC: 87.50 Precision: 90.91 Recall: 83.33
#
# Fold 6
#
# -----Train----------
# AUC: 91.96 Precision: 91.77 Recall: 92.15
#
# -----Validation-----
# AUC: 87.50 Precision: 84.62 Recall: 91.67
#
# Fold 7
#
# -----Train----------
# AUC: 92.17 Precision: 91.13 Recall: 93.39
#
# -----Validation-----
# AUC: 75.00 Precision: 75.00 Recall: 75.00
#
# Fold 8
#
# -----Train----------
# AUC: 90.72 Precision: 90.53 Recall: 90.91
#
# -----Validation-----
# AUC: 91.67 Precision: 100.00 Recall: 83.33
#
# Fold 9
#
# -----Train----------
# AUC: 90.93 Precision: 90.91 Recall: 90.91
#
# -----Validation-----
# AUC: 89.58 Precision: 88.00 Recall: 91.67
#
# Fold 10
#
# -----Train----------
# AUC: 91.55 Precision: 89.72 Recall: 93.80
#
# -----Validation-----
# AUC: 85.42 Precision: 84.00 Recall: 87.50
#
# Fold 11
#
# -----Train----------
# AUC: 91.75 Precision: 91.06 Recall: 92.56
#
# -----Validation-----
# AUC: 79.17 Precision: 85.00 Recall: 70.83
#
# wheezy-copper-turtle-magic 507
#
# Fold 1
#
# -----Train----------
# AUC: 91.17 Precision: 92.99 Recall: 88.44
#
# -----Validation-----
# AUC: 89.48 Precision: 90.91 Recall: 86.96
#
# Fold 2
#
# -----Train----------
# AUC: 91.67 Precision: 91.89 Recall: 90.67
#
# -----Validation-----
# AUC: 89.48 Precision: 90.91 Recall: 86.96
#
# Fold 3
#
# -----Train----------
# AUC: 93.54 Precision: 94.93 Recall: 91.56
#
# -----Validation-----
# AUC: 80.78 Precision: 88.89 Recall: 69.57
#
# Fold 4
#
# -----Train----------
# AUC: 91.14 Precision: 93.81 Recall: 87.56
#
# -----Validation-----
# AUC: 82.96 Precision: 89.47 Recall: 73.91
#
# Fold 5
#
# -----Train----------
# AUC: 91.88 Precision: 92.31 Recall: 90.67
#
# -----Validation-----
# AUC: 85.65 Precision: 80.77 Recall: 91.30
#
# Fold 6
#
# -----Train----------
# AUC: 91.45 Precision: 91.86 Recall: 90.22
#
# -----Validation-----
# AUC: 80.96 Precision: 85.00 Recall: 73.91
#
# Fold 7
#
# -----Train----------
# AUC: 92.34 Precision: 92.41 Recall: 91.59
#
# -----Validation-----
# AUC: 80.36 Precision: 84.21 Recall: 72.73
#
# Fold 8
#
# -----Train----------
# AUC: 91.14 Precision: 90.00 Recall: 91.59
#
# -----Validation-----
# AUC: 85.04 Precision: 80.00 Recall: 90.91
#
# Fold 9
#
# -----Train----------
# AUC: 90.84 Precision: 91.40 Recall: 89.38
#
# -----Validation-----
# AUC: 86.74 Precision: 90.00 Recall: 81.82
#
# Fold 10
#
# -----Train----------
# AUC: 91.89 Precision: 92.73 Recall: 90.27
#
# -----Validation-----
# AUC: 89.20 Precision: 86.96 Recall: 90.91
#
# Fold 11
#
# -----Train----------
# AUC: 91.75 Precision: 91.19 Recall: 91.59
#
# -----Validation-----
# AUC: 80.87 Precision: 74.07 Recall: 90.91
#
# wheezy-copper-turtle-magic 508
#
# Fold 1
#
# -----Train----------
# AUC: 84.39 Precision: 85.90 Recall: 82.28
#
# -----Validation-----
# AUC: 77.08 Precision: 84.21 Recall: 66.67
#
# Fold 2
#
# -----Train----------
# AUC: 86.29 Precision: 88.05 Recall: 83.97
#
# -----Validation-----
# AUC: 79.17 Precision: 88.89 Recall: 66.67
#
# Fold 3
#
# -----Train----------
# AUC: 86.71 Precision: 87.50 Recall: 85.65
#
# -----Validation-----
# AUC: 75.00 Precision: 87.50 Recall: 58.33
#
# Fold 4
#
# -----Train----------
# AUC: 86.71 Precision: 89.19 Recall: 83.54
#
# -----Validation-----
# AUC: 77.08 Precision: 80.95 Recall: 70.83
#
# Fold 5
#
# -----Train----------
# AUC: 86.08 Precision: 87.67 Recall: 83.97
#
# -----Validation-----
# AUC: 77.08 Precision: 74.07 Recall: 83.33
#
# Fold 6
#
# -----Train----------
# AUC: 86.08 Precision: 88.69 Recall: 82.70
#
# -----Validation-----
# AUC: 81.25 Precision: 80.00 Recall: 83.33
#
# Fold 7
#
# -----Train----------
# AUC: 86.50 Precision: 89.14 Recall: 83.12
#
# -----Validation-----
# AUC: 81.25 Precision: 80.00 Recall: 83.33
#
# Fold 8
#
# -----Train----------
# AUC: 86.29 Precision: 88.05 Recall: 83.97
#
# -----Validation-----
# AUC: 79.17 Precision: 76.92 Recall: 83.33
#
# Fold 9
#
# -----Train----------
# AUC: 86.76 Precision: 89.24 Recall: 83.61
#
# -----Validation-----
# AUC: 73.91 Precision: 82.35 Recall: 60.87
#
# Fold 10
#
# -----Train----------
# AUC: 87.82 Precision: 89.13 Recall: 86.13
#
# -----Validation-----
# AUC: 78.26 Precision: 84.21 Recall: 69.57
#
# Fold 11
#
# -----Train----------
# AUC: 85.29 Precision: 88.53 Recall: 81.09
#
# -----Validation-----
# AUC: 80.43 Precision: 79.17 Recall: 82.61
#
# wheezy-copper-turtle-magic 509
#
# Fold 1
#
# -----Train----------
# AUC: 92.73 Precision: 92.79 Recall: 92.38
#
# -----Validation-----
# AUC: 76.45 Precision: 80.00 Recall: 69.57
#
# Fold 2
#
# -----Train----------
# AUC: 91.36 Precision: 93.40 Recall: 88.79
#
# -----Validation-----
# AUC: 80.89 Precision: 79.17 Recall: 82.61
#
# Fold 3
#
# -----Train----------
# AUC: 91.83 Precision: 93.46 Recall: 89.69
#
# -----Validation-----
# AUC: 78.26 Precision: 84.21 Recall: 69.57
#
# Fold 4
#
# -----Train----------
# AUC: 90.95 Precision: 92.52 Recall: 88.79
#
# -----Validation-----
# AUC: 86.96 Precision: 86.96 Recall: 86.96
#
# Fold 5
#
# -----Train----------
# AUC: 91.41 Precision: 93.02 Recall: 89.29
#
# -----Validation-----
# AUC: 88.83 Precision: 90.48 Recall: 86.36
#
# Fold 6
#
# -----Train----------
# AUC: 90.74 Precision: 92.92 Recall: 87.95
#
# -----Validation-----
# AUC: 90.91 Precision: 100.00 Recall: 81.82
#
# Fold 7
#
# -----Train----------
# AUC: 91.43 Precision: 92.24 Recall: 90.18
#
# -----Validation-----
# AUC: 91.01 Precision: 95.00 Recall: 86.36
#
# Fold 8
#
# -----Train----------
# AUC: 91.85 Precision: 93.49 Recall: 89.73
#
# -----Validation-----
# AUC: 86.66 Precision: 86.36 Recall: 86.36
#
# Fold 9
#
# -----Train----------
# AUC: 91.40 Precision: 93.43 Recall: 88.84
#
# -----Validation-----
# AUC: 79.74 Precision: 88.24 Recall: 68.18
#
# Fold 10
#
# -----Train----------
# AUC: 89.86 Precision: 91.98 Recall: 87.05
#
# -----Validation-----
# AUC: 75.59 Precision: 73.91 Recall: 77.27
#
# Fold 11
#
# -----Train----------
# AUC: 90.52 Precision: 92.89 Recall: 87.50
#
# -----Validation-----
# AUC: 86.56 Precision: 90.00 Recall: 81.82
#
# wheezy-copper-turtle-magic 510
#
# Fold 1
#
# -----Train----------
# AUC: 92.72 Precision: 92.95 Recall: 92.14
#
# -----Validation-----
# AUC: 87.14 Precision: 90.48 Recall: 82.61
#
# Fold 2
#
# -----Train----------
# AUC: 92.07 Precision: 92.86 Recall: 90.83
#
# -----Validation-----
# AUC: 82.79 Precision: 89.47 Recall: 73.91
#
# Fold 3
#
# -----Train----------
# AUC: 91.64 Precision: 92.41 Recall: 90.39
#
# -----Validation-----
# AUC: 91.30 Precision: 100.00 Recall: 82.61
#
# Fold 4
#
# -----Train----------
# AUC: 92.27 Precision: 93.67 Recall: 90.39
#
# -----Validation-----
# AUC: 80.80 Precision: 81.82 Recall: 78.26
#
# Fold 5
#
# -----Train----------
# AUC: 92.07 Precision: 92.86 Recall: 90.83
#
# -----Validation-----
# AUC: 87.14 Precision: 90.48 Recall: 82.61
#
# Fold 6
#
# -----Train----------
# AUC: 91.40 Precision: 93.15 Recall: 89.08
#
# -----Validation-----
# AUC: 87.23 Precision: 86.96 Recall: 86.96
#
# Fold 7
#
# -----Train----------
# AUC: 93.34 Precision: 94.59 Recall: 91.70
#
# -----Validation-----
# AUC: 83.06 Precision: 80.00 Recall: 86.96
#
# Fold 8
#
# -----Train----------
# AUC: 92.27 Precision: 93.67 Recall: 90.39
#
# -----Validation-----
# AUC: 87.23 Precision: 86.96 Recall: 86.96
#
# Fold 9
#
# -----Train----------
# AUC: 92.69 Precision: 94.52 Recall: 90.39
#
# -----Validation-----
# AUC: 85.14 Precision: 83.33 Recall: 86.96
#
# Fold 10
#
# -----Train----------
# AUC: 93.11 Precision: 94.98 Recall: 90.83
#
# -----Validation-----
# AUC: 82.88 Precision: 85.71 Recall: 78.26
#
# Fold 11
#
# -----Train----------
# AUC: 92.75 Precision: 92.98 Recall: 92.17
#
# -----Validation-----
# AUC: 79.84 Precision: 84.21 Recall: 72.73
#
# wheezy-copper-turtle-magic 511
#
# Fold 1
#
# -----Train----------
# AUC: 89.38 Precision: 88.11 Recall: 91.88
#
# -----Validation-----
# AUC: 83.06 Precision: 86.36 Recall: 79.17
#
# Fold 2
#
# -----Train----------
# AUC: 88.70 Precision: 87.04 Recall: 91.88
#
# -----Validation-----
# AUC: 87.14 Precision: 84.62 Recall: 91.67
#
# Fold 3
#
# -----Train----------
# AUC: 88.73 Precision: 87.04 Recall: 91.88
#
# -----Validation-----
# AUC: 91.29 Precision: 91.67 Recall: 91.67
#
# Fold 4
#
# -----Train----------
# AUC: 90.04 Precision: 87.95 Recall: 93.59
#
# -----Validation-----
# AUC: 88.83 Precision: 85.19 Recall: 95.83
#
# Fold 5
#
# -----Train----------
# AUC: 91.15 Precision: 89.43 Recall: 94.02
#
# -----Validation-----
# AUC: 82.58 Precision: 83.33 Recall: 83.33
#
# Fold 6
#
# -----Train----------
# AUC: 89.63 Precision: 87.90 Recall: 92.77
#
# -----Validation-----
# AUC: 88.64 Precision: 82.14 Recall: 100.00
#
# Fold 7
#
# -----Train----------
# AUC: 89.19 Precision: 87.50 Recall: 92.34
#
# -----Validation-----
# AUC: 75.30 Precision: 71.43 Recall: 86.96
#
# Fold 8
#
# -----Train----------
# AUC: 90.26 Precision: 88.05 Recall: 94.04
#
# -----Validation-----
# AUC: 82.21 Precision: 82.61 Recall: 82.61
#
# Fold 9
#
# -----Train----------
# AUC: 90.26 Precision: 88.05 Recall: 94.04
#
# -----Validation-----
# AUC: 68.68 Precision: 66.67 Recall: 78.26
#
# Fold 10
#
# -----Train----------
# AUC: 90.06 Precision: 88.31 Recall: 93.19
#
# -----Validation-----
# AUC: 73.42 Precision: 76.19 Recall: 69.57
#
# Fold 11
#
# -----Train----------
# AUC: 90.48 Precision: 88.10 Recall: 94.47
#
# -----Validation-----
# AUC: 82.21 Precision: 82.61 Recall: 82.61

# %% [markdown]
# # Model evaluation
# ## Confusion matrix

# %%
f = plt.subplots(1, 1, figsize=(16, 5), sharex=True)
train_cnf_matrix = confusion_matrix(train['target'], [np.round(x) for x in train['preds']])
train_cnf_matrix_norm = train_cnf_matrix / train_cnf_matrix.sum(axis=1)[:, np.newaxis]
train_df_cm = pd.DataFrame(train_cnf_matrix_norm, index=[0, 1], columns=[0, 1])
sns.heatmap(train_df_cm, annot=True, fmt='.2f', cmap="Blues")
plt.show()

# %% [markdown]
# ## Metrics ROC AUC

# %%
print('AUC %.2f' % roc_auc_score(train['target'], train['preds']))
# Out:
# AUC 0.97

# %% [markdown]
# # Test predictions

# %%
submission = test[['id', 'target']]
submission.to_csv('submission.csv', index=False)
submission.head(10)
# Out:
#                                  id    target
# 0  1c13f2701648e0b0d46d8a2a5a131a53  0.381818
# 1  ba88c155ba898fc8b5099893036ef205  0.600000
# 2  7cbab5cea99169139e7e6d8ff74ebb77  0.818182
# 3  ca820ad57809f62eb7b4d13f5d4371a0  0.418182
# 4  7baaf361537fbd8a1aaa2c97a6d4ccc7  0.418182
# 5  8b3116e5e3e92e971dac305d1a093bf6  0.454545
# 6  35cfd7cab9bfa29bc963d1b8c94dd280  0.000000
# 7  83cf532df8ff4642a3e33a70fffdac37  0.945455
# 8  2e1350fe94ec9f2220bec5245e5e9265  0.800000
# 9  e62020afa72eb54a15725473e3a8475b  0.218182
