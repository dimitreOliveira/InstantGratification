# %% [markdown]
# # Dependencies

# %%
import warnings
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

from sklearn.discriminant_analysis import QuadraticDiscriminantAnalysis
from sklearn.feature_selection import VarianceThreshold
from sklearn.preprocessing import MinMaxScaler, StandardScaler
from sklearn.model_selection import train_test_split, StratifiedKFold
from sklearn.metrics import confusion_matrix, roc_auc_score, recall_score, precision_score

# Set seeds to make the experiment more reproducible.
from numpy.random import seed
seed(0)

# %matplotlib inline
sns.set_style("whitegrid")
warnings.filterwarnings("ignore")

# %% [markdown]
# # Load data

# %%
train = pd.read_csv('../input/train.csv')
test = pd.read_csv('../input/test.csv')

# %%
print('Train set shape:', train.shape)
print('Test set shape:', test.shape)
print('Train set overview:')
display(train.head())
# Out:
# Train set shape: (262144, 258)
# Test set shape: (131073, 257)
# Train set overview:
#                                  id   ...    target
# 0  707b395ecdcbb4dc2eabea00e4d1b179   ...         0
# 1  5880c03c6582a7b42248668e56b4bdec   ...         0
# 2  4ccbcb3d13e5072ff1d9c61afe2c4f77   ...         1
# 3  e350f17a357f12a1941f0837afb7eb8d   ...         0
# 4  a8f910ea6075b6376af079055965ff68   ...         0
#
# [5 rows x 258 columns]

# %% [markdown]
# ## Preprocess

# %% [markdown]
# # Model
#
# ## Model parameters

# %%
N_FOLDS = 25

# %%
# INITIALIZE VARIABLES
cols = [c for c in train.columns if c not in ['id', 'target', 'wheezy-copper-turtle-magic', 'preds']]
test['target'] = 0
train['preds'] = 0

# BUILD 512 MODELS
for i in range(512):
    print('wheezy-copper-turtle-magic {}\n'.format(i))
    
    # EXTRACT SUBSET OF DATASET WHERE WHEEZY-MAGIC EQUALS I
    train2 = train[train['wheezy-copper-turtle-magic']==i]
    test2 = test[test['wheezy-copper-turtle-magic']==i]
    idx1 = train2.index
    idx2 = test2.index
    train2.reset_index(drop=True, inplace=True)
    
    # FEATURE SELECTION (USE APPROX 40 OF 255 FEATURES)
    sel = VarianceThreshold(threshold=1.5).fit(train2[cols])
    train3 = sel.transform(train2[cols])
    test3 = sel.transform(test2[cols])

    skf = StratifiedKFold(n_splits=N_FOLDS, random_state=0)
    counter = 0

    for train_index, val_index in skf.split(train3, train2['target']):
        counter += 1
        print('Fold {}\n'.format(counter))
        model = QuadraticDiscriminantAnalysis()
        model.fit(train3[train_index,:], train2.loc[train_index]['target'])
        
        train_predictions = model.predict(train3[train_index,:])
        val_predictions = model.predict(train3[val_index,:])

        train_auc = roc_auc_score(train2.loc[train_index]['target'], train_predictions) * 100
        val_auc = roc_auc_score(train2.loc[val_index]['target'], val_predictions) * 100
        train_precision = precision_score(train2.loc[train_index]['target'], train_predictions) * 100
        val_precision = precision_score(train2.loc[val_index]['target'], val_predictions) * 100
        train_recall = recall_score(train2.loc[train_index]['target'], train_predictions) * 100
        val_recall = recall_score(train2.loc[val_index]['target'], val_predictions) * 100
        print('-----Train----------')
        print('AUC: %.2f Precision: %.2f Recall: %.2f \n' % (train_auc, train_precision, train_recall))
        print('-----Validation-----')
        print('AUC: %.2f Precision: %.2f Recall: %.2f \n' % (val_auc, val_precision, val_recall))

        # Make predictions
        train['preds'].loc[idx1] += model.predict_proba(train3)[:,1] / N_FOLDS
        test['target'].loc[idx2] += model.predict_proba(test3)[:,1] / N_FOLDS
# Out:
# wheezy-copper-turtle-magic 0
#
# Fold 1
#
# -----Train----------
# AUC: 97.27 Precision: 96.85 Recall: 97.62
#
# -----Validation-----
# AUC: 81.82 Precision: 81.82 Recall: 81.82
#
# Fold 2
#
# -----Train----------
# AUC: 96.87 Precision: 96.83 Recall: 96.83
#
# -----Validation-----
# AUC: 81.82 Precision: 81.82 Recall: 81.82
#
# Fold 3
#
# -----Train----------
# AUC: 96.48 Precision: 96.43 Recall: 96.43
#
# -----Validation-----
# AUC: 95.45 Precision: 91.67 Recall: 100.00
#
# Fold 4
#
# -----Train----------
# AUC: 96.87 Precision: 96.83 Recall: 96.83
#
# -----Validation-----
# AUC: 95.45 Precision: 100.00 Recall: 90.91
#
# Fold 5
#
# -----Train----------
# AUC: 96.88 Precision: 96.46 Recall: 97.22
#
# -----Validation-----
# AUC: 90.91 Precision: 90.91 Recall: 90.91
#
# Fold 6
#
# -----Train----------
# AUC: 97.08 Precision: 96.47 Recall: 97.62
#
# -----Validation-----
# AUC: 95.45 Precision: 100.00 Recall: 90.91
#
# Fold 7
#
# -----Train----------
# AUC: 96.88 Precision: 96.46 Recall: 97.22
#
# -----Validation-----
# AUC: 95.45 Precision: 91.67 Recall: 100.00
#
# Fold 8
#
# -----Train----------
# AUC: 96.68 Precision: 96.44 Recall: 96.83
#
# -----Validation-----
# AUC: 95.45 Precision: 100.00 Recall: 90.91
#
# Fold 9
#
# -----Train----------
# AUC: 96.87 Precision: 96.83 Recall: 96.83
#
# -----Validation-----
# AUC: 95.45 Precision: 91.67 Recall: 100.00
#
# Fold 10
#
# -----Train----------
# AUC: 96.49 Precision: 96.06 Recall: 96.83
#
# -----Validation-----
# AUC: 95.45 Precision: 100.00 Recall: 90.91
#
# Fold 11
#
# -----Train----------
# AUC: 96.87 Precision: 96.83 Recall: 96.83
#
# -----Validation-----
# AUC: 95.45 Precision: 100.00 Recall: 90.91
#
# Fold 12
#
# -----Train----------
# AUC: 96.48 Precision: 96.43 Recall: 96.43
#
# -----Validation-----
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# Fold 13
#
# -----Train----------
# AUC: 96.89 Precision: 96.09 Recall: 97.62
#
# -----Validation-----
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# Fold 14
#
# -----Train----------
# AUC: 96.88 Precision: 96.84 Recall: 96.84
#
# -----Validation-----
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# Fold 15
#
# -----Train----------
# AUC: 96.88 Precision: 96.84 Recall: 96.84
#
# -----Validation-----
# AUC: 95.45 Precision: 90.91 Recall: 100.00
#
# Fold 16
#
# -----Train----------
# AUC: 97.08 Precision: 96.85 Recall: 97.23
#
# -----Validation-----
# AUC: 90.00 Precision: 100.00 Recall: 80.00
#
# Fold 17
#
# -----Train----------
# AUC: 96.88 Precision: 97.21 Recall: 96.44
#
# -----Validation-----
# AUC: 95.45 Precision: 90.91 Recall: 100.00
#
# Fold 18
#
# -----Train----------
# AUC: 96.50 Precision: 96.08 Recall: 96.84
#
# -----Validation-----
# AUC: 85.45 Precision: 88.89 Recall: 80.00
#
# Fold 19
#
# -----Train----------
# AUC: 97.47 Precision: 97.24 Recall: 97.63
#
# -----Validation-----
# AUC: 85.91 Precision: 81.82 Recall: 90.00
#
# Fold 20
#
# -----Train----------
# AUC: 96.69 Precision: 96.46 Recall: 96.84
#
# -----Validation-----
# AUC: 85.45 Precision: 88.89 Recall: 80.00
#
# Fold 21
#
# -----Train----------
# AUC: 97.27 Precision: 97.23 Recall: 97.23
#
# -----Validation-----
# AUC: 90.00 Precision: 100.00 Recall: 80.00
#
# Fold 22
#
# -----Train----------
# AUC: 96.51 Precision: 95.72 Recall: 97.23
#
# -----Validation-----
# AUC: 95.00 Precision: 100.00 Recall: 90.00
#
# Fold 23
#
# -----Train----------
# AUC: 97.08 Precision: 96.85 Recall: 97.23
#
# -----Validation-----
# AUC: 85.00 Precision: 88.89 Recall: 80.00
#
# Fold 24
#
# -----Train----------
# AUC: 96.69 Precision: 96.46 Recall: 96.84
#
# -----Validation-----
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# Fold 25
#
# -----Train----------
# AUC: 96.69 Precision: 96.83 Recall: 96.44
#
# -----Validation-----
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# wheezy-copper-turtle-magic 1
#
# Fold 1
#
# -----Train----------
# AUC: 96.58 Precision: 94.69 Recall: 98.31
#
# -----Validation-----
# AUC: 95.45 Precision: 90.91 Recall: 100.00
#
# Fold 2
#
# -----Train----------
# AUC: 96.57 Precision: 95.06 Recall: 97.88
#
# -----Validation-----
# AUC: 90.91 Precision: 83.33 Recall: 100.00
#
# Fold 3
#
# -----Train----------
# AUC: 96.39 Precision: 94.31 Recall: 98.31
#
# -----Validation-----
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# Fold 4
#
# -----Train----------
# AUC: 96.17 Precision: 94.29 Recall: 97.88
#
# -----Validation-----
# AUC: 95.00 Precision: 100.00 Recall: 90.00
#
# Fold 5
#
# -----Train----------
# AUC: 96.58 Precision: 94.69 Recall: 98.31
#
# -----Validation-----
# AUC: 85.45 Precision: 88.89 Recall: 80.00
#
# Fold 6
#
# -----Train----------
# AUC: 96.60 Precision: 94.33 Recall: 98.73
#
# -----Validation-----
# AUC: 95.00 Precision: 100.00 Recall: 90.00
#
# Fold 7
#
# -----Train----------
# AUC: 96.37 Precision: 94.67 Recall: 97.88
#
# -----Validation-----
# AUC: 90.45 Precision: 90.00 Recall: 90.00
#
# Fold 8
#
# -----Train----------
# AUC: 96.78 Precision: 95.08 Recall: 98.31
#
# -----Validation-----
# AUC: 95.45 Precision: 90.91 Recall: 100.00
#
# Fold 9
#
# -----Train----------
# AUC: 96.98 Precision: 95.47 Recall: 98.31
#
# -----Validation-----
# AUC: 81.36 Precision: 75.00 Recall: 90.00
#
# Fold 10
#
# -----Train----------
# AUC: 96.58 Precision: 94.69 Recall: 98.31
#
# -----Validation-----
# AUC: 80.91 Precision: 80.00 Recall: 80.00
#
# Fold 11
#
# -----Train----------
# AUC: 96.37 Precision: 94.67 Recall: 97.88
#
# -----Validation-----
# AUC: 90.45 Precision: 90.00 Recall: 90.00
#
# Fold 12
#
# -----Train----------
# AUC: 96.39 Precision: 94.31 Recall: 98.31
#
# -----Validation-----
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# Fold 13
#
# -----Train----------
# AUC: 96.58 Precision: 94.69 Recall: 98.31
#
# -----Validation-----
# AUC: 90.45 Precision: 90.00 Recall: 90.00
#
# Fold 14
#
# -----Train----------
# AUC: 96.77 Precision: 95.45 Recall: 97.88
#
# -----Validation-----
# AUC: 80.45 Precision: 87.50 Recall: 70.00
#
# Fold 15
#
# -----Train----------
# AUC: 96.58 Precision: 95.06 Recall: 97.88
#
# -----Validation-----
# AUC: 90.00 Precision: 83.33 Recall: 100.00
#
# Fold 16
#
# -----Train----------
# AUC: 96.40 Precision: 94.31 Recall: 98.31
#
# -----Validation-----
# AUC: 90.00 Precision: 90.00 Recall: 90.00
#
# Fold 17
#
# -----Train----------
# AUC: 97.00 Precision: 95.10 Recall: 98.73
#
# -----Validation-----
# AUC: 90.00 Precision: 90.00 Recall: 90.00
#
# Fold 18
#
# -----Train----------
# AUC: 96.40 Precision: 94.31 Recall: 98.31
#
# -----Validation-----
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# Fold 19
#
# -----Train----------
# AUC: 96.81 Precision: 94.72 Recall: 98.73
#
# -----Validation-----
# AUC: 80.00 Precision: 87.50 Recall: 70.00
#
# Fold 20
#
# -----Train----------
# AUC: 96.17 Precision: 94.65 Recall: 97.46
#
# -----Validation-----
# AUC: 95.00 Precision: 90.91 Recall: 100.00
#
# Fold 21
#
# -----Train----------
# AUC: 97.20 Precision: 95.49 Recall: 98.73
#
# -----Validation-----
# AUC: 95.00 Precision: 90.91 Recall: 100.00
#
# Fold 22
#
# -----Train----------
# AUC: 96.19 Precision: 94.31 Recall: 97.89
#
# -----Validation-----
# AUC: 95.00 Precision: 90.00 Recall: 100.00
#
# Fold 23
#
# -----Train----------
# AUC: 97.00 Precision: 95.12 Recall: 98.73
#
# -----Validation-----
# AUC: 94.44 Precision: 100.00 Recall: 88.89
#
# Fold 24
#
# -----Train----------
# AUC: 96.60 Precision: 94.72 Recall: 98.31
#
# -----Validation-----
# AUC: 90.00 Precision: 81.82 Recall: 100.00
#
# Fold 25
#
# -----Train----------
# AUC: 96.40 Precision: 94.33 Recall: 98.31
#
# -----Validation-----
# AUC: 94.44 Precision: 100.00 Recall: 88.89
#
# wheezy-copper-turtle-magic 2
#
# Fold 1
#
# -----Train----------
# AUC: 97.47 Precision: 97.42 Recall: 97.42
#
# -----Validation-----
# AUC: 95.00 Precision: 100.00 Recall: 90.00
#
# Fold 2
#
# -----Train----------
# AUC: 97.26 Precision: 97.01 Recall: 97.42
#
# -----Validation-----
# AUC: 95.45 Precision: 90.91 Recall: 100.00
#
# Fold 3
#
# -----Train----------
# AUC: 98.11 Precision: 97.86 Recall: 98.28
#
# -----Validation-----
# AUC: 90.00 Precision: 100.00 Recall: 80.00
#
# Fold 4
#
# -----Train----------
# AUC: 97.27 Precision: 97.01 Recall: 97.42
#
# -----Validation-----
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# Fold 5
#
# -----Train----------
# AUC: 97.47 Precision: 97.42 Recall: 97.42
#
# -----Validation-----
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# Fold 6
#
# -----Train----------
# AUC: 97.69 Precision: 97.44 Recall: 97.85
#
# -----Validation-----
# AUC: 85.00 Precision: 88.89 Recall: 80.00
#
# Fold 7
#
# -----Train----------
# AUC: 98.11 Precision: 97.86 Recall: 98.28
#
# -----Validation-----
# AUC: 90.00 Precision: 83.33 Recall: 100.00
#
# Fold 8
#
# -----Train----------
# AUC: 97.68 Precision: 97.84 Recall: 97.42
#
# -----Validation-----
# AUC: 90.00 Precision: 90.00 Recall: 90.00
#
# Fold 9
#
# -----Train----------
# AUC: 97.27 Precision: 97.01 Recall: 97.42
#
# -----Validation-----
# AUC: 90.00 Precision: 90.00 Recall: 90.00
#
# Fold 10
#
# -----Train----------
# AUC: 97.48 Precision: 97.02 Recall: 97.85
#
# -----Validation-----
# AUC: 85.00 Precision: 76.92 Recall: 100.00
#
# Fold 11
#
# -----Train----------
# AUC: 97.68 Precision: 97.84 Recall: 97.42
#
# -----Validation-----
# AUC: 95.00 Precision: 100.00 Recall: 90.00
#
# Fold 12
#
# -----Train----------
# AUC: 97.68 Precision: 97.84 Recall: 97.42
#
# -----Validation-----
# AUC: 95.00 Precision: 90.91 Recall: 100.00
#
# Fold 13
#
# -----Train----------
# AUC: 98.11 Precision: 97.86 Recall: 98.28
#
# -----Validation-----
# AUC: 85.00 Precision: 88.89 Recall: 80.00
#
# Fold 14
#
# -----Train----------
# AUC: 97.68 Precision: 97.84 Recall: 97.42
#
# -----Validation-----
# AUC: 90.00 Precision: 83.33 Recall: 100.00
#
# Fold 15
#
# -----Train----------
# AUC: 97.47 Precision: 97.42 Recall: 97.42
#
# -----Validation-----
# AUC: 90.00 Precision: 90.00 Recall: 90.00
#
# Fold 16
#
# -----Train----------
# AUC: 97.27 Precision: 96.61 Recall: 97.85
#
# -----Validation-----
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# Fold 17
#
# -----Train----------
# AUC: 97.27 Precision: 97.01 Recall: 97.42
#
# -----Validation-----
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# Fold 18
#
# -----Train----------
# AUC: 97.48 Precision: 97.02 Recall: 97.85
#
# -----Validation-----
# AUC: 90.00 Precision: 100.00 Recall: 80.00
#
# Fold 19
#
# -----Train----------
# AUC: 97.70 Precision: 97.05 Recall: 98.29
#
# -----Validation-----
# AUC: 88.89 Precision: 100.00 Recall: 77.78
#
# Fold 20
#
# -----Train----------
# AUC: 97.69 Precision: 97.45 Recall: 97.86
#
# -----Validation-----
# AUC: 94.44 Precision: 100.00 Recall: 88.89
#
# Fold 21
#
# -----Train----------
# AUC: 97.27 Precision: 97.02 Recall: 97.44
#
# -----Validation-----
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# Fold 22
#
# -----Train----------
# AUC: 97.68 Precision: 97.85 Recall: 97.44
#
# -----Validation-----
# AUC: 95.00 Precision: 90.00 Recall: 100.00
#
# Fold 23
#
# -----Train----------
# AUC: 97.48 Precision: 97.44 Recall: 97.44
#
# -----Validation-----
# AUC: 95.00 Precision: 90.00 Recall: 100.00
#
# Fold 24
#
# -----Train----------
# AUC: 97.48 Precision: 97.44 Recall: 97.44
#
# -----Validation-----
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# Fold 25
#
# -----Train----------
# AUC: 97.27 Precision: 97.02 Recall: 97.44
#
# -----Validation-----
# AUC: 95.00 Precision: 90.00 Recall: 100.00
#
# wheezy-copper-turtle-magic 3
#
# Fold 1
#
# -----Train----------
# AUC: 98.46 Precision: 98.88 Recall: 98.14
#
# -----Validation-----
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# Fold 2
#
# -----Train----------
# AUC: 98.66 Precision: 99.25 Recall: 98.14
#
# -----Validation-----
# AUC: 95.83 Precision: 100.00 Recall: 91.67
#
# Fold 3
#
# -----Train----------
# AUC: 98.46 Precision: 98.88 Recall: 98.14
#
# -----Validation-----
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# Fold 4
#
# -----Train----------
# AUC: 98.46 Precision: 98.88 Recall: 98.14
#
# -----Validation-----
# AUC: 86.74 Precision: 84.62 Recall: 91.67
#
# Fold 5
#
# -----Train----------
# AUC: 98.66 Precision: 99.25 Recall: 98.14
#
# -----Validation-----
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# Fold 6
#
# -----Train----------
# AUC: 98.66 Precision: 99.25 Recall: 98.14
#
# -----Validation-----
# AUC: 95.83 Precision: 100.00 Recall: 91.67
#
# Fold 7
#
# -----Train----------
# AUC: 98.69 Precision: 99.62 Recall: 97.78
#
# -----Validation-----
# AUC: 95.45 Precision: 91.67 Recall: 100.00
#
# Fold 8
#
# -----Train----------
# AUC: 98.67 Precision: 99.25 Recall: 98.15
#
# -----Validation-----
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# Fold 9
#
# -----Train----------
# AUC: 98.87 Precision: 99.62 Recall: 98.15
#
# -----Validation-----
# AUC: 90.00 Precision: 84.62 Recall: 100.00
#
# Fold 10
#
# -----Train----------
# AUC: 98.69 Precision: 99.62 Recall: 97.78
#
# -----Validation-----
# AUC: 95.00 Precision: 91.67 Recall: 100.00
#
# Fold 11
#
# -----Train----------
# AUC: 98.48 Precision: 99.25 Recall: 97.78
#
# -----Validation-----
# AUC: 80.45 Precision: 76.92 Recall: 90.91
#
# Fold 12
#
# -----Train----------
# AUC: 98.67 Precision: 99.25 Recall: 98.15
#
# -----Validation-----
# AUC: 95.00 Precision: 91.67 Recall: 100.00
#
# Fold 13
#
# -----Train----------
# AUC: 98.67 Precision: 99.25 Recall: 98.15
#
# -----Validation-----
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# Fold 14
#
# -----Train----------
# AUC: 98.67 Precision: 99.25 Recall: 98.15
#
# -----Validation-----
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# Fold 15
#
# -----Train----------
# AUC: 98.67 Precision: 99.25 Recall: 98.15
#
# -----Validation-----
# AUC: 95.00 Precision: 91.67 Recall: 100.00
#
# Fold 16
#
# -----Train----------
# AUC: 98.67 Precision: 99.25 Recall: 98.15
#
# -----Validation-----
# AUC: 90.91 Precision: 100.00 Recall: 81.82
#
# Fold 17
#
# -----Train----------
# AUC: 98.85 Precision: 99.25 Recall: 98.52
#
# -----Validation-----
# AUC: 95.45 Precision: 100.00 Recall: 90.91
#
# Fold 18
#
# -----Train----------
# AUC: 98.47 Precision: 98.88 Recall: 98.15
#
# -----Validation-----
# AUC: 90.45 Precision: 90.91 Recall: 90.91
#
# Fold 19
#
# -----Train----------
# AUC: 98.67 Precision: 99.25 Recall: 98.15
#
# -----Validation-----
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# Fold 20
#
# -----Train----------
# AUC: 98.87 Precision: 99.62 Recall: 98.15
#
# -----Validation-----
# AUC: 90.45 Precision: 90.91 Recall: 90.91
#
# Fold 21
#
# -----Train----------
# AUC: 98.67 Precision: 99.25 Recall: 98.15
#
# -----Validation-----
# AUC: 95.45 Precision: 100.00 Recall: 90.91
#
# Fold 22
#
# -----Train----------
# AUC: 98.69 Precision: 99.62 Recall: 97.78
#
# -----Validation-----
# AUC: 95.00 Precision: 91.67 Recall: 100.00
#
# Fold 23
#
# -----Train----------
# AUC: 98.87 Precision: 99.62 Recall: 98.15
#
# -----Validation-----
# AUC: 90.91 Precision: 100.00 Recall: 81.82
#
# Fold 24
#
# -----Train----------
# AUC: 98.67 Precision: 99.25 Recall: 98.15
#
# -----Validation-----
# AUC: 85.45 Precision: 83.33 Recall: 90.91
#
# Fold 25
#
# -----Train----------
# AUC: 98.28 Precision: 98.88 Recall: 97.78
#
# -----Validation-----
# AUC: 90.45 Precision: 90.91 Recall: 90.91
#
# wheezy-copper-turtle-magic 4
#
# Fold 1
#
# -----Train----------
# AUC: 97.38 Precision: 98.37 Recall: 96.40
#
# -----Validation-----
# AUC: 86.36 Precision: 83.33 Recall: 90.91
#
# Fold 2
#
# -----Train----------
# AUC: 97.58 Precision: 97.98 Recall: 97.20
#
# -----Validation-----
# AUC: 90.91 Precision: 100.00 Recall: 81.82
#
# Fold 3
#
# -----Train----------
# AUC: 96.17 Precision: 97.14 Recall: 95.20
#
# -----Validation-----
# AUC: 90.91 Precision: 84.62 Recall: 100.00
#
# Fold 4
#
# -----Train----------
# AUC: 96.97 Precision: 97.57 Recall: 96.40
#
# -----Validation-----
# AUC: 90.91 Precision: 84.62 Recall: 100.00
#
# Fold 5
#
# -----Train----------
# AUC: 96.98 Precision: 97.96 Recall: 96.00
#
# -----Validation-----
# AUC: 86.36 Precision: 90.00 Recall: 81.82
#
# Fold 6
#
# -----Train----------
# AUC: 96.98 Precision: 97.96 Recall: 96.00
#
# -----Validation-----
# AUC: 85.45 Precision: 83.33 Recall: 90.91
#
# Fold 7
#
# -----Train----------
# AUC: 96.37 Precision: 97.15 Recall: 95.60
#
# -----Validation-----
# AUC: 95.45 Precision: 100.00 Recall: 90.91
#
# Fold 8
#
# -----Train----------
# AUC: 96.98 Precision: 97.96 Recall: 96.00
#
# -----Validation-----
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# Fold 9
#
# -----Train----------
# AUC: 96.78 Precision: 97.56 Recall: 96.00
#
# -----Validation-----
# AUC: 95.45 Precision: 100.00 Recall: 90.91
#
# Fold 10
#
# -----Train----------
# AUC: 96.98 Precision: 97.57 Recall: 96.40
#
# -----Validation-----
# AUC: 90.91 Precision: 100.00 Recall: 81.82
#
# Fold 11
#
# -----Train----------
# AUC: 96.78 Precision: 97.56 Recall: 96.00
#
# -----Validation-----
# AUC: 95.45 Precision: 100.00 Recall: 90.91
#
# Fold 12
#
# -----Train----------
# AUC: 96.99 Precision: 98.36 Recall: 95.62
#
# -----Validation-----
# AUC: 80.00 Precision: 75.00 Recall: 90.00
#
# Fold 13
#
# -----Train----------
# AUC: 97.19 Precision: 97.98 Recall: 96.41
#
# -----Validation-----
# AUC: 85.00 Precision: 81.82 Recall: 90.00
#
# Fold 14
#
# -----Train----------
# AUC: 96.99 Precision: 97.97 Recall: 96.02
#
# -----Validation-----
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# Fold 15
#
# -----Train----------
# AUC: 96.18 Precision: 97.15 Recall: 95.22
#
# -----Validation-----
# AUC: 85.00 Precision: 81.82 Recall: 90.00
#
# Fold 16
#
# -----Train----------
# AUC: 97.59 Precision: 97.99 Recall: 97.21
#
# -----Validation-----
# AUC: 80.00 Precision: 75.00 Recall: 90.00
#
# Fold 17
#
# -----Train----------
# AUC: 97.59 Precision: 98.38 Recall: 96.81
#
# -----Validation-----
# AUC: 90.00 Precision: 83.33 Recall: 100.00
#
# Fold 18
#
# -----Train----------
# AUC: 96.98 Precision: 97.58 Recall: 96.41
#
# -----Validation-----
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# Fold 19
#
# -----Train----------
# AUC: 96.78 Precision: 97.57 Recall: 96.02
#
# -----Validation-----
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# Fold 20
#
# -----Train----------
# AUC: 96.99 Precision: 97.97 Recall: 96.02
#
# -----Validation-----
# AUC: 95.00 Precision: 100.00 Recall: 90.00
#
# Fold 21
#
# -----Train----------
# AUC: 97.59 Precision: 97.99 Recall: 97.21
#
# -----Validation-----
# AUC: 90.00 Precision: 100.00 Recall: 80.00
#
# Fold 22
#
# -----Train----------
# AUC: 96.79 Precision: 97.96 Recall: 95.62
#
# -----Validation-----
# AUC: 90.00 Precision: 90.00 Recall: 90.00
#
# Fold 23
#
# -----Train----------
# AUC: 96.58 Precision: 97.18 Recall: 96.02
#
# -----Validation-----
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# Fold 24
#
# -----Train----------
# AUC: 96.98 Precision: 97.58 Recall: 96.41
#
# -----Validation-----
# AUC: 95.00 Precision: 90.91 Recall: 100.00
#
# Fold 25
#
# -----Train----------
# AUC: 97.19 Precision: 98.37 Recall: 96.02
#
# -----Validation-----
# AUC: 90.00 Precision: 83.33 Recall: 100.00
#
# wheezy-copper-turtle-magic 5
#
# Fold 1
#
# -----Train----------
# AUC: 96.99 Precision: 98.34 Recall: 95.56
#
# -----Validation-----
# AUC: 90.91 Precision: 90.91 Recall: 90.91
#
# Fold 2
#
# -----Train----------
# AUC: 97.39 Precision: 98.35 Recall: 96.37
#
# -----Validation-----
# AUC: 90.91 Precision: 100.00 Recall: 81.82
#
# Fold 3
#
# -----Train----------
# AUC: 97.39 Precision: 98.35 Recall: 96.37
#
# -----Validation-----
# AUC: 77.27 Precision: 80.00 Recall: 72.73
#
# Fold 4
#
# -----Train----------
# AUC: 97.59 Precision: 98.76 Recall: 96.37
#
# -----Validation-----
# AUC: 81.82 Precision: 76.92 Recall: 90.91
#
# Fold 5
#
# -----Train----------
# AUC: 96.99 Precision: 97.94 Recall: 95.97
#
# -----Validation-----
# AUC: 90.91 Precision: 84.62 Recall: 100.00
#
# Fold 6
#
# -----Train----------
# AUC: 97.19 Precision: 98.35 Recall: 95.97
#
# -----Validation-----
# AUC: 95.45 Precision: 100.00 Recall: 90.91
#
# Fold 7
#
# -----Train----------
# AUC: 96.99 Precision: 97.94 Recall: 95.97
#
# -----Validation-----
# AUC: 95.45 Precision: 100.00 Recall: 90.91
#
# Fold 8
#
# -----Train----------
# AUC: 96.79 Precision: 97.93 Recall: 95.56
#
# -----Validation-----
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# Fold 9
#
# -----Train----------
# AUC: 96.79 Precision: 97.54 Recall: 95.97
#
# -----Validation-----
# AUC: 95.45 Precision: 100.00 Recall: 90.91
#
# Fold 10
#
# -----Train----------
# AUC: 97.39 Precision: 98.76 Recall: 95.98
#
# -----Validation-----
# AUC: 95.45 Precision: 90.91 Recall: 100.00
#
# Fold 11
#
# -----Train----------
# AUC: 97.40 Precision: 98.36 Recall: 96.39
#
# -----Validation-----
# AUC: 90.00 Precision: 100.00 Recall: 80.00
#
# Fold 12
#
# -----Train----------
# AUC: 97.40 Precision: 98.36 Recall: 96.39
#
# -----Validation-----
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# Fold 13
#
# -----Train----------
# AUC: 96.80 Precision: 97.94 Recall: 95.58
#
# -----Validation-----
# AUC: 90.00 Precision: 90.00 Recall: 90.00
#
# Fold 14
#
# -----Train----------
# AUC: 97.60 Precision: 98.37 Recall: 96.79
#
# -----Validation-----
# AUC: 90.00 Precision: 100.00 Recall: 80.00
#
# Fold 15
#
# -----Train----------
# AUC: 97.40 Precision: 97.97 Recall: 96.79
#
# -----Validation-----
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# Fold 16
#
# -----Train----------
# AUC: 97.20 Precision: 97.96 Recall: 96.39
#
# -----Validation-----
# AUC: 90.00 Precision: 100.00 Recall: 80.00
#
# Fold 17
#
# -----Train----------
# AUC: 97.20 Precision: 97.96 Recall: 96.39
#
# -----Validation-----
# AUC: 90.00 Precision: 100.00 Recall: 80.00
#
# Fold 18
#
# -----Train----------
# AUC: 97.20 Precision: 98.35 Recall: 95.98
#
# -----Validation-----
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# Fold 19
#
# -----Train----------
# AUC: 97.40 Precision: 98.36 Recall: 96.39
#
# -----Validation-----
# AUC: 95.00 Precision: 90.91 Recall: 100.00
#
# Fold 20
#
# -----Train----------
# AUC: 97.40 Precision: 98.36 Recall: 96.39
#
# -----Validation-----
# AUC: 95.00 Precision: 90.91 Recall: 100.00
#
# Fold 21
#
# -----Train----------
# AUC: 97.20 Precision: 97.96 Recall: 96.39
#
# -----Validation-----
# AUC: 90.00 Precision: 90.00 Recall: 90.00
#
# Fold 22
#
# -----Train----------
# AUC: 97.40 Precision: 98.36 Recall: 96.39
#
# -----Validation-----
# AUC: 85.00 Precision: 88.89 Recall: 80.00
#
# Fold 23
#
# -----Train----------
# AUC: 97.60 Precision: 98.77 Recall: 96.39
#
# -----Validation-----
# AUC: 85.00 Precision: 88.89 Recall: 80.00
#
# Fold 24
#
# -----Train----------
# AUC: 97.40 Precision: 98.36 Recall: 96.39
#
# -----Validation-----
# AUC: 95.00 Precision: 100.00 Recall: 90.00
#
# Fold 25
#
# -----Train----------
# AUC: 97.20 Precision: 98.35 Recall: 95.98
#
# -----Validation-----
# AUC: 90.00 Precision: 90.00 Recall: 90.00
#
# wheezy-copper-turtle-magic 6
#
# Fold 1
#
# -----Train----------
# AUC: 98.18 Precision: 98.04 Recall: 98.43
#
# -----Validation-----
# AUC: 95.45 Precision: 100.00 Recall: 90.91
#
# Fold 2
#
# -----Train----------
# AUC: 97.99 Precision: 98.41 Recall: 97.64
#
# -----Validation-----
# AUC: 90.91 Precision: 84.62 Recall: 100.00
#
# Fold 3
#
# -----Train----------
# AUC: 97.98 Precision: 98.03 Recall: 98.03
#
# -----Validation-----
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# Fold 4
#
# -----Train----------
# AUC: 98.18 Precision: 98.04 Recall: 98.43
#
# -----Validation-----
# AUC: 90.91 Precision: 100.00 Recall: 81.82
#
# Fold 5
#
# -----Train----------
# AUC: 97.99 Precision: 98.03 Recall: 98.03
#
# -----Validation-----
# AUC: 90.91 Precision: 100.00 Recall: 81.82
#
# Fold 6
#
# -----Train----------
# AUC: 98.19 Precision: 98.42 Recall: 98.03
#
# -----Validation-----
# AUC: 95.00 Precision: 91.67 Recall: 100.00
#
# Fold 7
#
# -----Train----------
# AUC: 98.00 Precision: 98.41 Recall: 97.64
#
# -----Validation-----
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# Fold 8
#
# -----Train----------
# AUC: 97.79 Precision: 98.02 Recall: 97.64
#
# -----Validation-----
# AUC: 95.45 Precision: 100.00 Recall: 90.91
#
# Fold 9
#
# -----Train----------
# AUC: 98.19 Precision: 98.42 Recall: 98.03
#
# -----Validation-----
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# Fold 10
#
# -----Train----------
# AUC: 98.39 Precision: 98.43 Recall: 98.43
#
# -----Validation-----
# AUC: 90.45 Precision: 90.91 Recall: 90.91
#
# Fold 11
#
# -----Train----------
# AUC: 97.99 Precision: 98.03 Recall: 98.03
#
# -----Validation-----
# AUC: 95.45 Precision: 100.00 Recall: 90.91
#
# Fold 12
#
# -----Train----------
# AUC: 98.19 Precision: 98.42 Recall: 98.03
#
# -----Validation-----
# AUC: 95.00 Precision: 91.67 Recall: 100.00
#
# Fold 13
#
# -----Train----------
# AUC: 98.40 Precision: 98.81 Recall: 98.03
#
# -----Validation-----
# AUC: 90.00 Precision: 84.62 Recall: 100.00
#
# Fold 14
#
# -----Train----------
# AUC: 97.99 Precision: 98.03 Recall: 98.03
#
# -----Validation-----
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# Fold 15
#
# -----Train----------
# AUC: 97.99 Precision: 98.03 Recall: 98.03
#
# -----Validation-----
# AUC: 90.45 Precision: 90.91 Recall: 90.91
#
# Fold 16
#
# -----Train----------
# AUC: 97.99 Precision: 98.04 Recall: 98.04
#
# -----Validation-----
# AUC: 95.00 Precision: 100.00 Recall: 90.00
#
# Fold 17
#
# -----Train----------
# AUC: 98.20 Precision: 98.43 Recall: 98.04
#
# -----Validation-----
# AUC: 95.00 Precision: 90.91 Recall: 100.00
#
# Fold 18
#
# -----Train----------
# AUC: 97.99 Precision: 98.04 Recall: 98.04
#
# -----Validation-----
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# Fold 19
#
# -----Train----------
# AUC: 97.99 Precision: 98.04 Recall: 98.04
#
# -----Validation-----
# AUC: 95.00 Precision: 100.00 Recall: 90.00
#
# Fold 20
#
# -----Train----------
# AUC: 97.99 Precision: 98.04 Recall: 98.04
#
# -----Validation-----
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# Fold 21
#
# -----Train----------
# AUC: 98.20 Precision: 98.43 Recall: 98.04
#
# -----Validation-----
# AUC: 95.00 Precision: 90.91 Recall: 100.00
#
# Fold 22
#
# -----Train----------
# AUC: 98.20 Precision: 98.43 Recall: 98.04
#
# -----Validation-----
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# Fold 23
#
# -----Train----------
# AUC: 98.19 Precision: 98.05 Recall: 98.43
#
# -----Validation-----
# AUC: 90.00 Precision: 100.00 Recall: 80.00
#
# Fold 24
#
# -----Train----------
# AUC: 98.40 Precision: 98.81 Recall: 98.04
#
# -----Validation-----
# AUC: 90.00 Precision: 90.00 Recall: 90.00
#
# Fold 25
#
# -----Train----------
# AUC: 97.99 Precision: 98.04 Recall: 98.04
#
# -----Validation-----
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# wheezy-copper-turtle-magic 7
#
# Fold 1
#
# -----Train----------
# AUC: 97.52 Precision: 97.14 Recall: 97.94
#
# -----Validation-----
# AUC: 86.36 Precision: 90.00 Recall: 81.82
#
# Fold 2
#
# -----Train----------
# AUC: 97.93 Precision: 97.94 Recall: 97.94
#
# -----Validation-----
# AUC: 95.45 Precision: 100.00 Recall: 90.91
#
# Fold 3
#
# -----Train----------
# AUC: 97.53 Precision: 97.53 Recall: 97.53
#
# -----Validation-----
# AUC: 81.82 Precision: 100.00 Recall: 63.64
#
# Fold 4
#
# -----Train----------
# AUC: 97.32 Precision: 97.92 Recall: 96.71
#
# -----Validation-----
# AUC: 90.00 Precision: 84.62 Recall: 100.00
#
# Fold 5
#
# -----Train----------
# AUC: 97.94 Precision: 98.35 Recall: 97.54
#
# -----Validation-----
# AUC: 95.00 Precision: 90.91 Recall: 100.00
#
# Fold 6
#
# -----Train----------
# AUC: 97.33 Precision: 97.93 Recall: 96.72
#
# -----Validation-----
# AUC: 80.00 Precision: 80.00 Recall: 80.00
#
# Fold 7
#
# -----Train----------
# AUC: 97.74 Precision: 97.94 Recall: 97.54
#
# -----Validation-----
# AUC: 95.00 Precision: 100.00 Recall: 90.00
#
# Fold 8
#
# -----Train----------
# AUC: 97.95 Precision: 98.75 Recall: 97.13
#
# -----Validation-----
# AUC: 85.00 Precision: 76.92 Recall: 100.00
#
# Fold 9
#
# -----Train----------
# AUC: 97.74 Precision: 97.94 Recall: 97.54
#
# -----Validation-----
# AUC: 85.00 Precision: 88.89 Recall: 80.00
#
# Fold 10
#
# -----Train----------
# AUC: 97.53 Precision: 97.93 Recall: 97.13
#
# -----Validation-----
# AUC: 90.00 Precision: 100.00 Recall: 80.00
#
# Fold 11
#
# -----Train----------
# AUC: 97.53 Precision: 97.54 Recall: 97.54
#
# -----Validation-----
# AUC: 90.00 Precision: 83.33 Recall: 100.00
#
# Fold 12
#
# -----Train----------
# AUC: 97.74 Precision: 97.55 Recall: 97.95
#
# -----Validation-----
# AUC: 95.00 Precision: 100.00 Recall: 90.00
#
# Fold 13
#
# -----Train----------
# AUC: 98.35 Precision: 98.36 Recall: 98.36
#
# -----Validation-----
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# Fold 14
#
# -----Train----------
# AUC: 97.94 Precision: 97.95 Recall: 97.95
#
# -----Validation-----
# AUC: 80.00 Precision: 87.50 Recall: 70.00
#
# Fold 15
#
# -----Train----------
# AUC: 97.74 Precision: 97.94 Recall: 97.54
#
# -----Validation-----
# AUC: 95.00 Precision: 100.00 Recall: 90.00
#
# Fold 16
#
# -----Train----------
# AUC: 97.33 Precision: 97.93 Recall: 96.72
#
# -----Validation-----
# AUC: 95.00 Precision: 100.00 Recall: 90.00
#
# Fold 17
#
# -----Train----------
# AUC: 97.94 Precision: 98.35 Recall: 97.54
#
# -----Validation-----
# AUC: 80.00 Precision: 87.50 Recall: 70.00
#
# Fold 18
#
# -----Train----------
# AUC: 98.15 Precision: 98.35 Recall: 97.95
#
# -----Validation-----
# AUC: 95.00 Precision: 100.00 Recall: 90.00
#
# Fold 19
#
# -----Train----------
# AUC: 97.94 Precision: 98.35 Recall: 97.54
#
# -----Validation-----
# AUC: 95.00 Precision: 90.91 Recall: 100.00
#
# Fold 20
#
# -----Train----------
# AUC: 97.53 Precision: 97.93 Recall: 97.13
#
# -----Validation-----
# AUC: 95.00 Precision: 100.00 Recall: 90.00
#
# Fold 21
#
# -----Train----------
# AUC: 97.33 Precision: 97.53 Recall: 97.13
#
# -----Validation-----
# AUC: 80.00 Precision: 71.43 Recall: 100.00
#
# Fold 22
#
# -----Train----------
# AUC: 97.94 Precision: 97.95 Recall: 97.95
#
# -----Validation-----
# AUC: 90.00 Precision: 90.00 Recall: 90.00
#
# Fold 23
#
# -----Train----------
# AUC: 97.94 Precision: 97.95 Recall: 97.95
#
# -----Validation-----
# AUC: 85.00 Precision: 88.89 Recall: 80.00
#
# Fold 24
#
# -----Train----------
# AUC: 97.74 Precision: 97.94 Recall: 97.54
#
# -----Validation-----
# AUC: 90.00 Precision: 100.00 Recall: 80.00
#
# Fold 25
#
# -----Train----------
# AUC: 97.74 Precision: 98.34 Recall: 97.13
#
# -----Validation-----
# AUC: 90.00 Precision: 90.00 Recall: 90.00
#
# wheezy-copper-turtle-magic 8
#
# Fold 1
#
# -----Train----------
# AUC: 97.79 Precision: 97.67 Recall: 98.05
#
# -----Validation-----
# AUC: 95.45 Precision: 100.00 Recall: 90.91
#
# Fold 2
#
# -----Train----------
# AUC: 97.79 Precision: 97.67 Recall: 98.05
#
# -----Validation-----
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# Fold 3
#
# -----Train----------
# AUC: 98.39 Precision: 98.06 Recall: 98.83
#
# -----Validation-----
# AUC: 95.45 Precision: 100.00 Recall: 90.91
#
# Fold 4
#
# -----Train----------
# AUC: 97.79 Precision: 97.67 Recall: 98.05
#
# -----Validation-----
# AUC: 95.45 Precision: 91.67 Recall: 100.00
#
# Fold 5
#
# -----Train----------
# AUC: 98.00 Precision: 98.05 Recall: 98.05
#
# -----Validation-----
# AUC: 90.91 Precision: 100.00 Recall: 81.82
#
# Fold 6
#
# -----Train----------
# AUC: 97.80 Precision: 97.67 Recall: 98.05
#
# -----Validation-----
# AUC: 85.45 Precision: 83.33 Recall: 90.91
#
# Fold 7
#
# -----Train----------
# AUC: 98.00 Precision: 98.05 Recall: 98.05
#
# -----Validation-----
# AUC: 95.45 Precision: 100.00 Recall: 90.91
#
# Fold 8
#
# -----Train----------
# AUC: 97.80 Precision: 97.67 Recall: 98.05
#
# -----Validation-----
# AUC: 95.00 Precision: 91.67 Recall: 100.00
#
# Fold 9
#
# -----Train----------
# AUC: 98.00 Precision: 98.05 Recall: 98.05
#
# -----Validation-----
# AUC: 95.45 Precision: 100.00 Recall: 90.91
#
# Fold 10
#
# -----Train----------
# AUC: 97.80 Precision: 97.67 Recall: 98.05
#
# -----Validation-----
# AUC: 95.00 Precision: 91.67 Recall: 100.00
#
# Fold 11
#
# -----Train----------
# AUC: 98.20 Precision: 98.05 Recall: 98.44
#
# -----Validation-----
# AUC: 95.45 Precision: 100.00 Recall: 90.91
#
# Fold 12
#
# -----Train----------
# AUC: 97.80 Precision: 97.67 Recall: 98.05
#
# -----Validation-----
# AUC: 75.91 Precision: 75.00 Recall: 81.82
#
# Fold 13
#
# -----Train----------
# AUC: 98.00 Precision: 98.05 Recall: 98.05
#
# -----Validation-----
# AUC: 95.45 Precision: 100.00 Recall: 90.91
#
# Fold 14
#
# -----Train----------
# AUC: 97.80 Precision: 97.67 Recall: 98.05
#
# -----Validation-----
# AUC: 95.45 Precision: 100.00 Recall: 90.91
#
# Fold 15
#
# -----Train----------
# AUC: 97.80 Precision: 97.67 Recall: 98.05
#
# -----Validation-----
# AUC: 95.45 Precision: 100.00 Recall: 90.91
#
# Fold 16
#
# -----Train----------
# AUC: 98.20 Precision: 98.05 Recall: 98.44
#
# -----Validation-----
# AUC: 95.45 Precision: 100.00 Recall: 90.91
#
# Fold 17
#
# -----Train----------
# AUC: 97.81 Precision: 98.04 Recall: 97.66
#
# -----Validation-----
# AUC: 95.00 Precision: 91.67 Recall: 100.00
#
# Fold 18
#
# -----Train----------
# AUC: 97.80 Precision: 97.67 Recall: 98.05
#
# -----Validation-----
# AUC: 90.00 Precision: 100.00 Recall: 80.00
#
# Fold 19
#
# -----Train----------
# AUC: 98.00 Precision: 97.68 Recall: 98.44
#
# -----Validation-----
# AUC: 85.00 Precision: 100.00 Recall: 70.00
#
# Fold 20
#
# -----Train----------
# AUC: 97.80 Precision: 97.67 Recall: 98.05
#
# -----Validation-----
# AUC: 90.00 Precision: 83.33 Recall: 100.00
#
# Fold 21
#
# -----Train----------
# AUC: 98.01 Precision: 98.05 Recall: 98.05
#
# -----Validation-----
# AUC: 85.00 Precision: 81.82 Recall: 90.00
#
# Fold 22
#
# -----Train----------
# AUC: 97.80 Precision: 97.67 Recall: 98.05
#
# -----Validation-----
# AUC: 95.00 Precision: 100.00 Recall: 90.00
#
# Fold 23
#
# -----Train----------
# AUC: 98.40 Precision: 98.07 Recall: 98.83
#
# -----Validation-----
# AUC: 90.00 Precision: 90.00 Recall: 90.00
#
# Fold 24
#
# -----Train----------
# AUC: 98.01 Precision: 98.05 Recall: 98.05
#
# -----Validation-----
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# Fold 25
#
# -----Train----------
# AUC: 98.00 Precision: 97.68 Recall: 98.44
#
# -----Validation-----
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# wheezy-copper-turtle-magic 9
#
# Fold 1
#
# -----Train----------
# AUC: 97.23 Precision: 98.38 Recall: 96.05
#
# -----Validation-----
# AUC: 90.91 Precision: 90.91 Recall: 90.91
#
# Fold 2
#
# -----Train----------
# AUC: 96.84 Precision: 97.98 Recall: 95.65
#
# -----Validation-----
# AUC: 95.45 Precision: 100.00 Recall: 90.91
#
# Fold 3
#
# -----Train----------
# AUC: 96.84 Precision: 97.98 Recall: 95.65
#
# -----Validation-----
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# Fold 4
#
# -----Train----------
# AUC: 96.84 Precision: 97.21 Recall: 96.44
#
# -----Validation-----
# AUC: 95.45 Precision: 100.00 Recall: 90.91
#
# Fold 5
#
# -----Train----------
# AUC: 96.84 Precision: 97.98 Recall: 95.65
#
# -----Validation-----
# AUC: 95.45 Precision: 91.67 Recall: 100.00
#
# Fold 6
#
# -----Train----------
# AUC: 97.04 Precision: 98.37 Recall: 95.65
#
# -----Validation-----
# AUC: 90.91 Precision: 100.00 Recall: 81.82
#
# Fold 7
#
# -----Train----------
# AUC: 96.64 Precision: 97.58 Recall: 95.65
#
# -----Validation-----
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# Fold 8
#
# -----Train----------
# AUC: 97.23 Precision: 98.38 Recall: 96.05
#
# -----Validation-----
# AUC: 90.91 Precision: 90.91 Recall: 90.91
#
# Fold 9
#
# -----Train----------
# AUC: 97.23 Precision: 98.38 Recall: 96.05
#
# -----Validation-----
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# Fold 10
#
# -----Train----------
# AUC: 96.44 Precision: 97.57 Recall: 95.26
#
# -----Validation-----
# AUC: 90.91 Precision: 100.00 Recall: 81.82
#
# Fold 11
#
# -----Train----------
# AUC: 97.04 Precision: 98.37 Recall: 95.65
#
# -----Validation-----
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# Fold 12
#
# -----Train----------
# AUC: 96.44 Precision: 97.96 Recall: 94.86
#
# -----Validation-----
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# Fold 13
#
# -----Train----------
# AUC: 97.23 Precision: 98.38 Recall: 96.05
#
# -----Validation-----
# AUC: 86.36 Precision: 90.00 Recall: 81.82
#
# Fold 14
#
# -----Train----------
# AUC: 97.04 Precision: 98.77 Recall: 95.26
#
# -----Validation-----
# AUC: 90.91 Precision: 84.62 Recall: 100.00
#
# Fold 15
#
# -----Train----------
# AUC: 96.46 Precision: 97.58 Recall: 95.28
#
# -----Validation-----
# AUC: 90.00 Precision: 90.00 Recall: 90.00
#
# Fold 16
#
# -----Train----------
# AUC: 97.24 Precision: 98.39 Recall: 96.06
#
# -----Validation-----
# AUC: 80.00 Precision: 80.00 Recall: 80.00
#
# Fold 17
#
# -----Train----------
# AUC: 97.05 Precision: 98.38 Recall: 95.67
#
# -----Validation-----
# AUC: 95.00 Precision: 100.00 Recall: 90.00
#
# Fold 18
#
# -----Train----------
# AUC: 97.44 Precision: 98.39 Recall: 96.46
#
# -----Validation-----
# AUC: 80.00 Precision: 87.50 Recall: 70.00
#
# Fold 19
#
# -----Train----------
# AUC: 96.65 Precision: 97.98 Recall: 95.28
#
# -----Validation-----
# AUC: 95.00 Precision: 100.00 Recall: 90.00
#
# Fold 20
#
# -----Train----------
# AUC: 96.65 Precision: 97.98 Recall: 95.28
#
# -----Validation-----
# AUC: 90.00 Precision: 90.00 Recall: 90.00
#
# Fold 21
#
# -----Train----------
# AUC: 96.85 Precision: 97.98 Recall: 95.67
#
# -----Validation-----
# AUC: 90.00 Precision: 83.33 Recall: 100.00
#
# Fold 22
#
# -----Train----------
# AUC: 97.24 Precision: 98.39 Recall: 96.06
#
# -----Validation-----
# AUC: 95.00 Precision: 100.00 Recall: 90.00
#
# Fold 23
#
# -----Train----------
# AUC: 96.85 Precision: 97.98 Recall: 95.67
#
# -----Validation-----
# AUC: 95.00 Precision: 100.00 Recall: 90.00
#
# Fold 24
#
# -----Train----------
# AUC: 96.65 Precision: 97.98 Recall: 95.28
#
# -----Validation-----
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# Fold 25
#
# -----Train----------
# AUC: 96.65 Precision: 97.98 Recall: 95.28
#
# -----Validation-----
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# wheezy-copper-turtle-magic 10
#
# Fold 1
#
# -----Train----------
# AUC: 97.91 Precision: 97.08 Recall: 98.73
#
# -----Validation-----
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# Fold 2
#
# -----Train----------
# AUC: 98.75 Precision: 97.92 Recall: 99.58
#
# -----Validation-----
# AUC: 90.45 Precision: 90.00 Recall: 90.00
#
# Fold 3
#
# -----Train----------
# AUC: 98.34 Precision: 97.50 Recall: 99.15
#
# -----Validation-----
# AUC: 95.00 Precision: 90.91 Recall: 100.00
#
# Fold 4
#
# -----Train----------
# AUC: 98.34 Precision: 97.50 Recall: 99.15
#
# -----Validation-----
# AUC: 95.00 Precision: 90.91 Recall: 100.00
#
# Fold 5
#
# -----Train----------
# AUC: 98.34 Precision: 97.50 Recall: 99.15
#
# -----Validation-----
# AUC: 95.00 Precision: 100.00 Recall: 90.00
#
# Fold 6
#
# -----Train----------
# AUC: 98.13 Precision: 97.10 Recall: 99.15
#
# -----Validation-----
# AUC: 95.00 Precision: 90.91 Recall: 100.00
#
# Fold 7
#
# -----Train----------
# AUC: 98.13 Precision: 97.10 Recall: 99.15
#
# -----Validation-----
# AUC: 95.00 Precision: 100.00 Recall: 90.00
#
# Fold 8
#
# -----Train----------
# AUC: 98.13 Precision: 97.10 Recall: 99.15
#
# -----Validation-----
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# Fold 9
#
# -----Train----------
# AUC: 98.13 Precision: 97.10 Recall: 99.15
#
# -----Validation-----
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# Fold 10
#
# -----Train----------
# AUC: 98.34 Precision: 97.50 Recall: 99.15
#
# -----Validation-----
# AUC: 95.00 Precision: 90.91 Recall: 100.00
#
# Fold 11
#
# -----Train----------
# AUC: 98.34 Precision: 97.50 Recall: 99.15
#
# -----Validation-----
# AUC: 80.00 Precision: 80.00 Recall: 80.00
#
# Fold 12
#
# -----Train----------
# AUC: 98.34 Precision: 97.50 Recall: 99.15
#
# -----Validation-----
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# Fold 13
#
# -----Train----------
# AUC: 97.92 Precision: 96.69 Recall: 99.15
#
# -----Validation-----
# AUC: 85.00 Precision: 88.89 Recall: 80.00
#
# Fold 14
#
# -----Train----------
# AUC: 98.33 Precision: 97.90 Recall: 98.73
#
# -----Validation-----
# AUC: 85.00 Precision: 81.82 Recall: 90.00
#
# Fold 15
#
# -----Train----------
# AUC: 97.92 Precision: 96.69 Recall: 99.15
#
# -----Validation-----
# AUC: 95.00 Precision: 100.00 Recall: 90.00
#
# Fold 16
#
# -----Train----------
# AUC: 98.12 Precision: 97.49 Recall: 98.73
#
# -----Validation-----
# AUC: 90.00 Precision: 90.00 Recall: 90.00
#
# Fold 17
#
# -----Train----------
# AUC: 98.13 Precision: 97.10 Recall: 99.15
#
# -----Validation-----
# AUC: 95.00 Precision: 100.00 Recall: 90.00
#
# Fold 18
#
# -----Train----------
# AUC: 98.13 Precision: 97.10 Recall: 99.15
#
# -----Validation-----
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# Fold 19
#
# -----Train----------
# AUC: 98.13 Precision: 97.10 Recall: 99.15
#
# -----Validation-----
# AUC: 90.00 Precision: 90.00 Recall: 90.00
#
# Fold 20
#
# -----Train----------
# AUC: 98.13 Precision: 97.10 Recall: 99.15
#
# -----Validation-----
# AUC: 95.00 Precision: 100.00 Recall: 90.00
#
# Fold 21
#
# -----Train----------
# AUC: 97.92 Precision: 96.69 Recall: 99.15
#
# -----Validation-----
# AUC: 95.00 Precision: 90.91 Recall: 100.00
#
# Fold 22
#
# -----Train----------
# AUC: 97.93 Precision: 96.71 Recall: 99.16
#
# -----Validation-----
# AUC: 95.00 Precision: 90.00 Recall: 100.00
#
# Fold 23
#
# -----Train----------
# AUC: 98.34 Precision: 97.12 Recall: 99.58
#
# -----Validation-----
# AUC: 89.44 Precision: 88.89 Recall: 88.89
#
# Fold 24
#
# -----Train----------
# AUC: 98.13 Precision: 97.11 Recall: 99.16
#
# -----Validation-----
# AUC: 88.89 Precision: 100.00 Recall: 77.78
#
# Fold 25
#
# -----Train----------
# AUC: 98.55 Precision: 97.92 Recall: 99.16
#
# -----Validation-----
# AUC: 95.00 Precision: 90.00 Recall: 100.00
#
# wheezy-copper-turtle-magic 11
#
# Fold 1
#
# -----Train----------
# AUC: 97.83 Precision: 97.75 Recall: 97.75
#
# -----Validation-----
# AUC: 85.00 Precision: 81.82 Recall: 90.00
#
# Fold 2
#
# -----Train----------
# AUC: 97.62 Precision: 97.31 Recall: 97.75
#
# -----Validation-----
# AUC: 95.00 Precision: 90.91 Recall: 100.00
#
# Fold 3
#
# -----Train----------
# AUC: 97.82 Precision: 98.18 Recall: 97.30
#
# -----Validation-----
# AUC: 90.00 Precision: 90.00 Recall: 90.00
#
# Fold 4
#
# -----Train----------
# AUC: 97.61 Precision: 97.74 Recall: 97.30
#
# -----Validation-----
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# Fold 5
#
# -----Train----------
# AUC: 97.61 Precision: 97.74 Recall: 97.30
#
# -----Validation-----
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# Fold 6
#
# -----Train----------
# AUC: 98.06 Precision: 97.76 Recall: 98.20
#
# -----Validation-----
# AUC: 95.00 Precision: 100.00 Recall: 90.00
#
# Fold 7
#
# -----Train----------
# AUC: 97.83 Precision: 97.75 Recall: 97.75
#
# -----Validation-----
# AUC: 95.00 Precision: 100.00 Recall: 90.00
#
# Fold 8
#
# -----Train----------
# AUC: 97.84 Precision: 97.76 Recall: 97.76
#
# -----Validation-----
# AUC: 94.44 Precision: 100.00 Recall: 88.89
#
# Fold 9
#
# -----Train----------
# AUC: 97.61 Precision: 97.75 Recall: 97.31
#
# -----Validation-----
# AUC: 89.44 Precision: 88.89 Recall: 88.89
#
# Fold 10
#
# -----Train----------
# AUC: 97.84 Precision: 97.76 Recall: 97.76
#
# -----Validation-----
# AUC: 94.44 Precision: 100.00 Recall: 88.89
#
# Fold 11
#
# -----Train----------
# AUC: 97.82 Precision: 98.19 Recall: 97.31
#
# -----Validation-----
# AUC: 89.44 Precision: 88.89 Recall: 88.89
#
# Fold 12
#
# -----Train----------
# AUC: 97.84 Precision: 97.76 Recall: 97.76
#
# -----Validation-----
# AUC: 95.00 Precision: 90.00 Recall: 100.00
#
# Fold 13
#
# -----Train----------
# AUC: 97.84 Precision: 97.76 Recall: 97.76
#
# -----Validation-----
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# Fold 14
#
# -----Train----------
# AUC: 97.84 Precision: 97.76 Recall: 97.76
#
# -----Validation-----
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# Fold 15
#
# -----Train----------
# AUC: 97.61 Precision: 97.75 Recall: 97.31
#
# -----Validation-----
# AUC: 95.00 Precision: 90.00 Recall: 100.00
#
# Fold 16
#
# -----Train----------
# AUC: 97.84 Precision: 97.76 Recall: 97.76
#
# -----Validation-----
# AUC: 94.44 Precision: 100.00 Recall: 88.89
#
# Fold 17
#
# -----Train----------
# AUC: 97.40 Precision: 97.31 Recall: 97.31
#
# -----Validation-----
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# Fold 18
#
# -----Train----------
# AUC: 97.40 Precision: 97.31 Recall: 97.31
#
# -----Validation-----
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# Fold 19
#
# -----Train----------
# AUC: 97.40 Precision: 97.31 Recall: 97.31
#
# -----Validation-----
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# Fold 20
#
# -----Train----------
# AUC: 98.25 Precision: 98.64 Recall: 97.76
#
# -----Validation-----
# AUC: 85.00 Precision: 75.00 Recall: 100.00
#
# Fold 21
#
# -----Train----------
# AUC: 97.61 Precision: 97.75 Recall: 97.31
#
# -----Validation-----
# AUC: 83.89 Precision: 87.50 Recall: 77.78
#
# Fold 22
#
# -----Train----------
# AUC: 97.40 Precision: 97.31 Recall: 97.31
#
# -----Validation-----
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# Fold 23
#
# -----Train----------
# AUC: 97.61 Precision: 97.75 Recall: 97.31
#
# -----Validation-----
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# Fold 24
#
# -----Train----------
# AUC: 97.61 Precision: 97.75 Recall: 97.31
#
# -----Validation-----
# AUC: 89.44 Precision: 88.89 Recall: 88.89
#
# Fold 25
#
# -----Train----------
# AUC: 97.61 Precision: 97.75 Recall: 97.31
#
# -----Validation-----
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# wheezy-copper-turtle-magic 12
#
# Fold 1
#
# -----Train----------
# AUC: 97.69 Precision: 98.31 Recall: 97.08
#
# -----Validation-----
# AUC: 95.45 Precision: 100.00 Recall: 90.91
#
# Fold 2
#
# -----Train----------
# AUC: 97.70 Precision: 98.32 Recall: 97.10
#
# -----Validation-----
# AUC: 95.00 Precision: 100.00 Recall: 90.00
#
# Fold 3
#
# -----Train----------
# AUC: 97.28 Precision: 98.31 Recall: 96.27
#
# -----Validation-----
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# Fold 4
#
# -----Train----------
# AUC: 97.07 Precision: 97.89 Recall: 96.27
#
# -----Validation-----
# AUC: 90.00 Precision: 100.00 Recall: 80.00
#
# Fold 5
#
# -----Train----------
# AUC: 97.48 Precision: 97.91 Recall: 97.10
#
# -----Validation-----
# AUC: 90.00 Precision: 90.00 Recall: 90.00
#
# Fold 6
#
# -----Train----------
# AUC: 97.49 Precision: 98.31 Recall: 96.68
#
# -----Validation-----
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# Fold 7
#
# -----Train----------
# AUC: 97.49 Precision: 98.72 Recall: 96.27
#
# -----Validation-----
# AUC: 95.00 Precision: 90.91 Recall: 100.00
#
# Fold 8
#
# -----Train----------
# AUC: 97.70 Precision: 98.73 Recall: 96.68
#
# -----Validation-----
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# Fold 9
#
# -----Train----------
# AUC: 97.28 Precision: 98.31 Recall: 96.27
#
# -----Validation-----
# AUC: 95.00 Precision: 90.91 Recall: 100.00
#
# Fold 10
#
# -----Train----------
# AUC: 97.49 Precision: 98.31 Recall: 96.68
#
# -----Validation-----
# AUC: 95.00 Precision: 100.00 Recall: 90.00
#
# Fold 11
#
# -----Train----------
# AUC: 97.70 Precision: 98.73 Recall: 96.68
#
# -----Validation-----
# AUC: 95.00 Precision: 90.91 Recall: 100.00
#
# Fold 12
#
# -----Train----------
# AUC: 97.28 Precision: 98.31 Recall: 96.27
#
# -----Validation-----
# AUC: 95.00 Precision: 90.91 Recall: 100.00
#
# Fold 13
#
# -----Train----------
# AUC: 97.49 Precision: 98.31 Recall: 96.68
#
# -----Validation-----
# AUC: 90.00 Precision: 83.33 Recall: 100.00
#
# Fold 14
#
# -----Train----------
# AUC: 97.70 Precision: 98.73 Recall: 96.68
#
# -----Validation-----
# AUC: 85.00 Precision: 81.82 Recall: 90.00
#
# Fold 15
#
# -----Train----------
# AUC: 97.48 Precision: 97.91 Recall: 97.10
#
# -----Validation-----
# AUC: 75.00 Precision: 100.00 Recall: 50.00
#
# Fold 16
#
# -----Train----------
# AUC: 97.28 Precision: 97.90 Recall: 96.68
#
# -----Validation-----
# AUC: 95.00 Precision: 100.00 Recall: 90.00
#
# Fold 17
#
# -----Train----------
# AUC: 97.28 Precision: 98.31 Recall: 96.27
#
# -----Validation-----
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# Fold 18
#
# -----Train----------
# AUC: 97.49 Precision: 98.31 Recall: 96.68
#
# -----Validation-----
# AUC: 90.00 Precision: 83.33 Recall: 100.00
#
# Fold 19
#
# -----Train----------
# AUC: 97.49 Precision: 98.72 Recall: 96.27
#
# -----Validation-----
# AUC: 95.00 Precision: 100.00 Recall: 90.00
#
# Fold 20
#
# -----Train----------
# AUC: 97.70 Precision: 98.73 Recall: 96.68
#
# -----Validation-----
# AUC: 95.00 Precision: 100.00 Recall: 90.00
#
# Fold 21
#
# -----Train----------
# AUC: 97.49 Precision: 98.31 Recall: 96.68
#
# -----Validation-----
# AUC: 95.00 Precision: 100.00 Recall: 90.00
#
# Fold 22
#
# -----Train----------
# AUC: 97.49 Precision: 98.31 Recall: 96.68
#
# -----Validation-----
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# Fold 23
#
# -----Train----------
# AUC: 97.49 Precision: 98.31 Recall: 96.68
#
# -----Validation-----
# AUC: 78.89 Precision: 80.00 Recall: 80.00
#
# Fold 24
#
# -----Train----------
# AUC: 97.91 Precision: 98.73 Recall: 97.10
#
# -----Validation-----
# AUC: 95.00 Precision: 100.00 Recall: 90.00
#
# Fold 25
#
# -----Train----------
# AUC: 97.49 Precision: 98.31 Recall: 96.68
#
# -----Validation-----
# AUC: 84.44 Precision: 88.89 Recall: 80.00
#
# wheezy-copper-turtle-magic 13
#
# Fold 1
#
# -----Train----------
# AUC: 97.42 Precision: 97.33 Recall: 97.33
#
# -----Validation-----
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# Fold 2
#
# -----Train----------
# AUC: 97.64 Precision: 97.35 Recall: 97.78
#
# -----Validation-----
# AUC: 95.00 Precision: 90.91 Recall: 100.00
#
# Fold 3
#
# -----Train----------
# AUC: 97.86 Precision: 97.36 Recall: 98.22
#
# -----Validation-----
# AUC: 90.00 Precision: 90.00 Recall: 90.00
#
# Fold 4
#
# -----Train----------
# AUC: 98.07 Precision: 97.79 Recall: 98.22
#
# -----Validation-----
# AUC: 90.00 Precision: 90.00 Recall: 90.00
#
# Fold 5
#
# -----Train----------
# AUC: 97.64 Precision: 97.35 Recall: 97.78
#
# -----Validation-----
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# Fold 6
#
# -----Train----------
# AUC: 97.86 Precision: 97.36 Recall: 98.22
#
# -----Validation-----
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# Fold 7
#
# -----Train----------
# AUC: 97.64 Precision: 97.35 Recall: 97.78
#
# -----Validation-----
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# Fold 8
#
# -----Train----------
# AUC: 97.43 Precision: 96.92 Recall: 97.78
#
# -----Validation-----
# AUC: 85.00 Precision: 88.89 Recall: 80.00
#
# Fold 9
#
# -----Train----------
# AUC: 97.64 Precision: 97.35 Recall: 97.78
#
# -----Validation-----
# AUC: 95.00 Precision: 90.91 Recall: 100.00
#
# Fold 10
#
# -----Train----------
# AUC: 97.64 Precision: 97.35 Recall: 97.78
#
# -----Validation-----
# AUC: 95.00 Precision: 100.00 Recall: 90.00
#
# Fold 11
#
# -----Train----------
# AUC: 98.06 Precision: 98.22 Recall: 97.79
#
# -----Validation-----
# AUC: 89.44 Precision: 88.89 Recall: 88.89
#
# Fold 12
#
# -----Train----------
# AUC: 97.64 Precision: 97.36 Recall: 97.79
#
# -----Validation-----
# AUC: 94.44 Precision: 100.00 Recall: 88.89
#
# Fold 13
#
# -----Train----------
# AUC: 97.64 Precision: 97.36 Recall: 97.79
#
# -----Validation-----
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# Fold 14
#
# -----Train----------
# AUC: 97.63 Precision: 97.78 Recall: 97.35
#
# -----Validation-----
# AUC: 89.44 Precision: 88.89 Recall: 88.89
#
# Fold 15
#
# -----Train----------
# AUC: 97.64 Precision: 97.36 Recall: 97.79
#
# -----Validation-----
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# Fold 16
#
# -----Train----------
# ...
#
# Fold 20
#
# -----Train----------
# AUC: 97.97 Precision: 97.92 Recall: 97.92
#
# -----Validation-----
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# Fold 21
#
# -----Train----------
# AUC: 97.98 Precision: 97.52 Recall: 98.33
#
# -----Validation-----
# AUC: 95.00 Precision: 100.00 Recall: 90.00
#
# Fold 22
#
# -----Train----------
# AUC: 98.17 Precision: 98.33 Recall: 97.92
#
# -----Validation-----
# AUC: 95.00 Precision: 90.91 Recall: 100.00
#
# Fold 23
#
# -----Train----------
# AUC: 97.97 Precision: 97.92 Recall: 97.92
#
# -----Validation-----
# AUC: 95.00 Precision: 90.91 Recall: 100.00
#
# Fold 24
#
# -----Train----------
# AUC: 97.57 Precision: 97.11 Recall: 97.92
#
# -----Validation-----
# AUC: 90.00 Precision: 83.33 Recall: 100.00
#
# Fold 25
#
# -----Train----------
# AUC: 98.58 Precision: 98.34 Recall: 98.75
#
# -----Validation-----
# AUC: 85.00 Precision: 88.89 Recall: 80.00
#
# wheezy-copper-turtle-magic 255
#
# Fold 1
#
# -----Train----------
# AUC: 96.80 Precision: 97.28 Recall: 96.53
#
# -----Validation-----
# AUC: 90.00 Precision: 84.62 Recall: 100.00
#
# Fold 2
#
# -----Train----------
# AUC: 96.59 Precision: 96.90 Recall: 96.53
#
# -----Validation-----
# AUC: 95.00 Precision: 91.67 Recall: 100.00
#
# Fold 3
#
# -----Train----------
# AUC: 96.78 Precision: 96.91 Recall: 96.91
#
# -----Validation-----
# AUC: 86.36 Precision: 100.00 Recall: 72.73
#
# Fold 4
#
# -----Train----------
# AUC: 96.77 Precision: 96.55 Recall: 97.30
#
# -----Validation-----
# AUC: 90.45 Precision: 90.91 Recall: 90.91
#
# Fold 5
#
# -----Train----------
# AUC: 96.80 Precision: 97.28 Recall: 96.53
#
# -----Validation-----
# AUC: 85.45 Precision: 83.33 Recall: 90.91
#
# Fold 6
#
# -----Train----------
# AUC: 96.57 Precision: 96.54 Recall: 96.91
#
# -----Validation-----
# AUC: 85.91 Precision: 90.00 Recall: 81.82
#
# Fold 7
#
# -----Train----------
# AUC: 96.38 Precision: 96.53 Recall: 96.53
#
# -----Validation-----
# AUC: 90.45 Precision: 90.91 Recall: 90.91
#
# Fold 8
#
# -----Train----------
# AUC: 96.78 Precision: 96.91 Recall: 96.91
#
# -----Validation-----
# AUC: 95.00 Precision: 91.67 Recall: 100.00
#
# Fold 9
#
# -----Train----------
# AUC: 96.19 Precision: 96.51 Recall: 96.14
#
# -----Validation-----
# AUC: 95.00 Precision: 91.67 Recall: 100.00
#
# Fold 10
#
# -----Train----------
# AUC: 95.98 Precision: 96.14 Recall: 96.14
#
# -----Validation-----
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# Fold 11
#
# -----Train----------
# AUC: 96.57 Precision: 96.54 Recall: 96.91
#
# -----Validation-----
# AUC: 95.45 Precision: 100.00 Recall: 90.91
#
# Fold 12
#
# -----Train----------
# AUC: 96.38 Precision: 96.53 Recall: 96.53
#
# -----Validation-----
# AUC: 90.00 Precision: 84.62 Recall: 100.00
#
# Fold 13
#
# -----Train----------
# AUC: 96.17 Precision: 96.15 Recall: 96.53
#
# -----Validation-----
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# Fold 14
#
# -----Train----------
# AUC: 96.38 Precision: 96.53 Recall: 96.53
#
# -----Validation-----
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# Fold 15
#
# -----Train----------
# AUC: 96.38 Precision: 96.53 Recall: 96.53
#
# -----Validation-----
# AUC: 95.45 Precision: 100.00 Recall: 90.91
#
# Fold 16
#
# -----Train----------
# AUC: 96.56 Precision: 96.18 Recall: 97.30
#
# -----Validation-----
# AUC: 95.45 Precision: 100.00 Recall: 90.91
#
# Fold 17
#
# -----Train----------
# AUC: 96.57 Precision: 96.54 Recall: 96.91
#
# -----Validation-----
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# Fold 18
#
# -----Train----------
# AUC: 96.80 Precision: 97.28 Recall: 96.53
#
# -----Validation-----
# AUC: 85.45 Precision: 83.33 Recall: 90.91
#
# Fold 19
#
# -----Train----------
# AUC: 96.20 Precision: 96.88 Recall: 95.75
#
# -----Validation-----
# AUC: 95.00 Precision: 91.67 Recall: 100.00
#
# Fold 20
#
# -----Train----------
# AUC: 96.40 Precision: 96.89 Recall: 96.14
#
# -----Validation-----
# AUC: 95.00 Precision: 91.67 Recall: 100.00
#
# Fold 21
#
# -----Train----------
# AUC: 95.98 Precision: 96.15 Recall: 96.15
#
# -----Validation-----
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# Fold 22
#
# -----Train----------
# AUC: 96.37 Precision: 96.18 Recall: 96.92
#
# -----Validation-----
# AUC: 95.00 Precision: 100.00 Recall: 90.00
#
# Fold 23
#
# -----Train----------
# AUC: 96.40 Precision: 96.90 Recall: 96.15
#
# -----Validation-----
# AUC: 95.00 Precision: 90.91 Recall: 100.00
#
# Fold 24
#
# -----Train----------
# AUC: 96.58 Precision: 96.55 Recall: 96.92
#
# -----Validation-----
# AUC: 90.00 Precision: 100.00 Recall: 80.00
#
# Fold 25
#
# -----Train----------
# AUC: 96.39 Precision: 96.54 Recall: 96.54
#
# -----Validation-----
# AUC: 95.00 Precision: 100.00 Recall: 90.00
#
# wheezy-copper-turtle-magic 256
#
# Fold 1
#
# -----Train----------
# AUC: 98.41 Precision: 99.60 Recall: 97.28
#
# -----Validation-----
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# Fold 2
#
# -----Train----------
# AUC: 98.64 Precision: 100.00 Recall: 97.28
#
# -----Validation-----
# AUC: 95.00 Precision: 91.67 Recall: 100.00
#
# Fold 3
#
# -----Train----------
# AUC: 98.80 Precision: 99.60 Recall: 98.05
#
# -----Validation-----
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# Fold 4
#
# -----Train----------
# AUC: 98.60 Precision: 99.60 Recall: 97.67
#
# -----Validation-----
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# Fold 5
#
# -----Train----------
# AUC: 98.60 Precision: 99.60 Recall: 97.67
#
# -----Validation-----
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# Fold 6
#
# -----Train----------
# AUC: 98.60 Precision: 99.60 Recall: 97.67
#
# -----Validation-----
# AUC: 89.90 Precision: 90.91 Recall: 90.91
#
# Fold 7
#
# -----Train----------
# AUC: 98.60 Precision: 99.60 Recall: 97.67
#
# -----Validation-----
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# Fold 8
#
# -----Train----------
# AUC: 98.60 Precision: 99.60 Recall: 97.67
#
# -----Validation-----
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# Fold 9
#
# -----Train----------
# AUC: 98.60 Precision: 99.60 Recall: 97.67
#
# -----Validation-----
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# Fold 10
#
# -----Train----------
# AUC: 98.80 Precision: 99.60 Recall: 98.05
#
# -----Validation-----
# AUC: 94.44 Precision: 91.67 Recall: 100.00
#
# Fold 11
#
# -----Train----------
# AUC: 98.80 Precision: 99.60 Recall: 98.05
#
# -----Validation-----
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# Fold 12
#
# -----Train----------
# AUC: 98.41 Precision: 99.60 Recall: 97.28
#
# -----Validation-----
# AUC: 95.45 Precision: 100.00 Recall: 90.91
#
# Fold 13
#
# -----Train----------
# AUC: 98.60 Precision: 99.60 Recall: 97.67
#
# -----Validation-----
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# Fold 14
#
# -----Train----------
# AUC: 98.41 Precision: 99.60 Recall: 97.28
#
# -----Validation-----
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# Fold 15
#
# -----Train----------
# AUC: 98.60 Precision: 99.60 Recall: 97.67
#
# -----Validation-----
# AUC: 94.44 Precision: 91.67 Recall: 100.00
#
# Fold 16
#
# -----Train----------
# AUC: 98.60 Precision: 99.60 Recall: 97.67
#
# -----Validation-----
# AUC: 88.89 Precision: 84.62 Recall: 100.00
#
# Fold 17
#
# -----Train----------
# AUC: 98.99 Precision: 99.61 Recall: 98.44
#
# -----Validation-----
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# Fold 18
#
# -----Train----------
# AUC: 99.19 Precision: 99.61 Recall: 98.83
#
# -----Validation-----
# AUC: 80.81 Precision: 88.89 Recall: 72.73
#
# Fold 19
#
# -----Train----------
# AUC: 98.80 Precision: 99.61 Recall: 98.06
#
# -----Validation-----
# AUC: 84.44 Precision: 88.89 Recall: 80.00
#
# Fold 20
#
# -----Train----------
# AUC: 98.42 Precision: 99.60 Recall: 97.29
#
# -----Validation-----
# AUC: 88.89 Precision: 83.33 Recall: 100.00
#
# Fold 21
#
# -----Train----------
# AUC: 98.80 Precision: 99.61 Recall: 98.06
#
# -----Validation-----
# AUC: 90.00 Precision: 100.00 Recall: 80.00
#
# Fold 22
#
# -----Train----------
# AUC: 98.42 Precision: 99.60 Recall: 97.29
#
# -----Validation-----
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# Fold 23
#
# -----Train----------
# AUC: 98.61 Precision: 99.60 Recall: 97.67
#
# -----Validation-----
# AUC: 95.00 Precision: 100.00 Recall: 90.00
#
# Fold 24
#
# -----Train----------
# AUC: 98.61 Precision: 99.60 Recall: 97.67
#
# -----Validation-----
# AUC: 95.00 Precision: 100.00 Recall: 90.00
#
# Fold 25
#
# -----Train----------
# AUC: 98.61 Precision: 99.60 Recall: 97.67
#
# -----Validation-----
# AUC: 94.44 Precision: 90.91 Recall: 100.00
#
# wheezy-copper-turtle-magic 257
#
# Fold 1
#
# -----Train----------
# AUC: 97.50 Precision: 97.90 Recall: 97.08
#
# -----Validation-----
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# Fold 2
#
# -----Train----------
# AUC: 97.30 Precision: 97.90 Recall: 96.68
#
# -----Validation-----
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# Fold 3
#
# -----Train----------
# AUC: 97.51 Precision: 97.91 Recall: 97.10
#
# -----Validation-----
# AUC: 95.00 Precision: 100.00 Recall: 90.00
#
# Fold 4
#
# -----Train----------
# AUC: 97.72 Precision: 98.32 Recall: 97.10
#
# -----Validation-----
# AUC: 80.00 Precision: 75.00 Recall: 90.00
#
# Fold 5
#
# -----Train----------
# AUC: 97.30 Precision: 97.90 Recall: 96.68
#
# -----Validation-----
# AUC: 85.00 Precision: 81.82 Recall: 90.00
#
# Fold 6
#
# -----Train----------
# AUC: 97.30 Precision: 97.90 Recall: 96.68
#
# -----Validation-----
# AUC: 95.00 Precision: 90.91 Recall: 100.00
#
# Fold 7
#
# -----Train----------
# AUC: 97.30 Precision: 98.31 Recall: 96.27
#
# -----Validation-----
# AUC: 95.00 Precision: 90.91 Recall: 100.00
#
# Fold 8
#
# -----Train----------
# AUC: 97.51 Precision: 97.91 Recall: 97.10
#
# -----Validation-----
# AUC: 90.00 Precision: 90.00 Recall: 90.00
#
# Fold 9
#
# -----Train----------
# AUC: 97.30 Precision: 97.90 Recall: 96.68
#
# -----Validation-----
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# Fold 10
#
# -----Train----------
# AUC: 97.51 Precision: 97.91 Recall: 97.10
#
# -----Validation-----
# AUC: 85.00 Precision: 88.89 Recall: 80.00
#
# Fold 11
#
# -----Train----------
# AUC: 97.51 Precision: 97.91 Recall: 97.10
#
# -----Validation-----
# AUC: 95.00 Precision: 90.91 Recall: 100.00
#
# Fold 12
#
# -----Train----------
# AUC: 97.10 Precision: 97.89 Recall: 96.27
#
# -----Validation-----
# AUC: 95.00 Precision: 90.91 Recall: 100.00
#
# Fold 13
#
# -----Train----------
# AUC: 97.30 Precision: 97.90 Recall: 96.68
#
# -----Validation-----
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# Fold 14
#
# -----Train----------
# AUC: 97.30 Precision: 97.90 Recall: 96.68
#
# -----Validation-----
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# Fold 15
#
# -----Train----------
# AUC: 97.30 Precision: 97.90 Recall: 96.68
#
# -----Validation-----
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# Fold 16
#
# -----Train----------
# AUC: 97.72 Precision: 98.32 Recall: 97.10
#
# -----Validation-----
# AUC: 90.00 Precision: 90.00 Recall: 90.00
#
# Fold 17
#
# -----Train----------
# AUC: 97.51 Precision: 97.91 Recall: 97.10
#
# -----Validation-----
# AUC: 95.00 Precision: 100.00 Recall: 90.00
#
# Fold 18
#
# -----Train----------
# AUC: 97.30 Precision: 97.90 Recall: 96.68
#
# -----Validation-----
# AUC: 85.00 Precision: 76.92 Recall: 100.00
#
# Fold 19
#
# -----Train----------
# AUC: 97.30 Precision: 97.90 Recall: 96.68
#
# -----Validation-----
# AUC: 95.00 Precision: 100.00 Recall: 90.00
#
# Fold 20
#
# -----Train----------
# AUC: 97.93 Precision: 97.93 Recall: 97.93
#
# -----Validation-----
# AUC: 85.00 Precision: 100.00 Recall: 70.00
#
# Fold 21
#
# -----Train----------
# AUC: 97.51 Precision: 97.91 Recall: 97.10
#
# -----Validation-----
# AUC: 95.00 Precision: 90.91 Recall: 100.00
#
# Fold 22
#
# -----Train----------
# AUC: 97.30 Precision: 97.90 Recall: 96.68
#
# -----Validation-----
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# Fold 23
#
# -----Train----------
# AUC: 97.30 Precision: 97.90 Recall: 96.68
#
# -----Validation-----
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# Fold 24
#
# -----Train----------
# AUC: 97.10 Precision: 97.89 Recall: 96.27
#
# -----Validation-----
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# Fold 25
#
# -----Train----------
# AUC: 97.51 Precision: 98.31 Recall: 96.68
#
# -----Validation-----
# AUC: 90.00 Precision: 90.00 Recall: 90.00
#
# wheezy-copper-turtle-magic 258
#
# Fold 1
#
# -----Train----------
# AUC: 96.16 Precision: 96.76 Recall: 95.60
#
# -----Validation-----
# AUC: 90.91 Precision: 100.00 Recall: 81.82
#
# Fold 2
#
# -----Train----------
# AUC: 95.96 Precision: 96.75 Recall: 95.20
#
# -----Validation-----
# AUC: 90.91 Precision: 90.91 Recall: 90.91
#
# Fold 3
#
# -----Train----------
# AUC: 95.56 Precision: 96.72 Recall: 94.40
#
# -----Validation-----
# AUC: 95.45 Precision: 91.67 Recall: 100.00
#
# Fold 4
#
# -----Train----------
# AUC: 96.57 Precision: 97.17 Recall: 96.00
#
# -----Validation-----
# AUC: 90.91 Precision: 90.91 Recall: 90.91
#
# Fold 5
#
# -----Train----------
# AUC: 95.76 Precision: 96.73 Recall: 94.80
#
# -----Validation-----
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# Fold 6
#
# -----Train----------
# AUC: 96.17 Precision: 96.76 Recall: 95.60
#
# -----Validation-----
# AUC: 95.45 Precision: 100.00 Recall: 90.91
#
# Fold 7
#
# -----Train----------
# AUC: 95.76 Precision: 96.36 Recall: 95.20
#
# -----Validation-----
# AUC: 90.45 Precision: 90.91 Recall: 90.91
#
# Fold 8
#
# -----Train----------
# AUC: 96.17 Precision: 97.14 Recall: 95.20
#
# -----Validation-----
# AUC: 85.91 Precision: 90.00 Recall: 81.82
#
# Fold 9
#
# -----Train----------
# AUC: 95.77 Precision: 96.73 Recall: 94.80
#
# -----Validation-----
# AUC: 90.91 Precision: 100.00 Recall: 81.82
#
# Fold 10
#
# -----Train----------
# AUC: 96.58 Precision: 97.55 Recall: 95.60
#
# -----Validation-----
# AUC: 95.00 Precision: 91.67 Recall: 100.00
#
# Fold 11
#
# -----Train----------
# AUC: 95.76 Precision: 96.36 Recall: 95.20
#
# -----Validation-----
# AUC: 90.91 Precision: 100.00 Recall: 81.82
#
# Fold 12
#
# -----Train----------
# AUC: 96.38 Precision: 97.17 Recall: 95.62
#
# -----Validation-----
# AUC: 85.00 Precision: 88.89 Recall: 80.00
#
# Fold 13
#
# -----Train----------
# AUC: 95.98 Precision: 97.14 Recall: 94.82
#
# -----Validation-----
# AUC: 90.00 Precision: 90.00 Recall: 90.00
#
# Fold 14
#
# -----Train----------
# AUC: 96.18 Precision: 97.15 Recall: 95.22
#
# -----Validation-----
# AUC: 90.00 Precision: 90.00 Recall: 90.00
#
# Fold 15
#
# -----Train----------
# AUC: 96.18 Precision: 96.77 Recall: 95.62
#
# -----Validation-----
# AUC: 90.00 Precision: 100.00 Recall: 80.00
#
# Fold 16
#
# -----Train----------
# AUC: 95.98 Precision: 96.76 Recall: 95.22
#
# -----Validation-----
# AUC: 95.00 Precision: 100.00 Recall: 90.00
#
# Fold 17
#
# -----Train----------
# AUC: 95.98 Precision: 96.76 Recall: 95.22
#
# -----Validation-----
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# Fold 18
#
# -----Train----------
# AUC: 95.77 Precision: 96.37 Recall: 95.22
#
# -----Validation-----
# AUC: 95.00 Precision: 100.00 Recall: 90.00
#
# Fold 19
#
# -----Train----------
# AUC: 96.38 Precision: 96.79 Recall: 96.02
#
# -----Validation-----
# AUC: 90.00 Precision: 90.00 Recall: 90.00
#
# Fold 20
#
# -----Train----------
# AUC: 95.98 Precision: 96.76 Recall: 95.22
#
# -----Validation-----
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# Fold 21
#
# -----Train----------
# AUC: 96.58 Precision: 97.18 Recall: 96.02
#
# -----Validation-----
# AUC: 85.00 Precision: 81.82 Recall: 90.00
#
# Fold 22
#
# -----Train----------
# AUC: 95.98 Precision: 96.76 Recall: 95.22
#
# -----Validation-----
# AUC: 90.00 Precision: 100.00 Recall: 80.00
#
# Fold 23
#
# -----Train----------
# AUC: 95.58 Precision: 97.12 Recall: 94.02
#
# -----Validation-----
# AUC: 95.00 Precision: 90.91 Recall: 100.00
#
# Fold 24
#
# -----Train----------
# AUC: 95.38 Precision: 96.72 Recall: 94.02
#
# -----Validation-----
# AUC: 85.00 Precision: 88.89 Recall: 80.00
#
# Fold 25
#
# -----Train----------
# AUC: 95.98 Precision: 96.76 Recall: 95.22
#
# -----Validation-----
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# wheezy-copper-turtle-magic 259
#
# Fold 1
#
# -----Train----------
# AUC: 97.47 Precision: 95.97 Recall: 99.17
#
# -----Validation-----
# AUC: 95.00 Precision: 90.91 Recall: 100.00
#
# Fold 2
#
# -----Train----------
# AUC: 97.47 Precision: 95.97 Recall: 99.17
#
# -----Validation-----
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# Fold 3
#
# -----Train----------
# AUC: 97.68 Precision: 96.36 Recall: 99.17
#
# -----Validation-----
# AUC: 95.00 Precision: 90.91 Recall: 100.00
#
# Fold 4
#
# -----Train----------
# AUC: 97.68 Precision: 96.36 Recall: 99.17
#
# -----Validation-----
# AUC: 95.00 Precision: 90.91 Recall: 100.00
#
# Fold 5
#
# -----Train----------
# AUC: 97.47 Precision: 95.97 Recall: 99.17
#
# -----Validation-----
# AUC: 95.00 Precision: 100.00 Recall: 90.00
#
# Fold 6
#
# -----Train----------
# AUC: 97.68 Precision: 96.36 Recall: 99.17
#
# -----Validation-----
# AUC: 90.00 Precision: 90.00 Recall: 90.00
#
# Fold 7
#
# -----Train----------
# AUC: 97.89 Precision: 96.37 Recall: 99.58
#
# -----Validation-----
# AUC: 80.00 Precision: 75.00 Recall: 90.00

# %% [markdown]
# # Model evaluation
# ## Confusion matrix

# %%
f = plt.subplots(1, 1, figsize=(16, 5), sharex=True)
train_cnf_matrix = confusion_matrix(train['target'], [np.round(x) for x in train['preds']])
train_cnf_matrix_norm = train_cnf_matrix / train_cnf_matrix.sum(axis=1)[:, np.newaxis]
train_df_cm = pd.DataFrame(train_cnf_matrix_norm, index=[0, 1], columns=[0, 1])
sns.heatmap(train_df_cm, annot=True, fmt='.2f', cmap="Blues")
plt.show()

# %% [markdown]
# ## Metrics ROC AUC

# %%
print('AUC %.2f' % roc_auc_score(train['target'], train['preds']))
# Out:
# AUC 0.99

# %% [markdown]
# # Test predictions

# %%
submission = test[['id', 'target']]
submission.to_csv('submission.csv', index=False)
submission.head(10)
# Out:
#                                  id        target
# 0  1c13f2701648e0b0d46d8a2a5a131a53  9.999861e-01
# 1  ba88c155ba898fc8b5099893036ef205  9.952805e-01
# 2  7cbab5cea99169139e7e6d8ff74ebb77  7.408093e-08
# 3  ca820ad57809f62eb7b4d13f5d4371a0  6.887466e-02
# 4  7baaf361537fbd8a1aaa2c97a6d4ccc7  3.731578e-01
# 5  8b3116e5e3e92e971dac305d1a093bf6  1.582243e-08
# 6  35cfd7cab9bfa29bc963d1b8c94dd280  3.556095e-10
# 7  83cf532df8ff4642a3e33a70fffdac37  9.999997e-01
# 8  2e1350fe94ec9f2220bec5245e5e9265  9.997094e-01
# 9  e62020afa72eb54a15725473e3a8475b  1.614618e-02
