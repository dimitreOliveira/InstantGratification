# %% [markdown]
# # Dependencies

# %%
import warnings
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

from sklearn.svm import NuSVC
from sklearn.feature_selection import VarianceThreshold
from sklearn.preprocessing import MinMaxScaler, StandardScaler
from sklearn.model_selection import train_test_split, StratifiedKFold
from sklearn.metrics import confusion_matrix, roc_auc_score, recall_score, precision_score

# Set seeds to make the experiment more reproducible.
from numpy.random import seed
seed(0)

# %matplotlib inline
sns.set_style("whitegrid")
warnings.filterwarnings("ignore")

# %% [markdown]
# # Load data

# %%
train = pd.read_csv('../input/train.csv')
test = pd.read_csv('../input/test.csv')
# submission = pd.read_csv('../input/sample_submission.csv')

# %%
print('Train set shape:', train.shape)
print('Test set shape:', test.shape)
print('Train set overview:')
display(train.head())
# Out:
# Train set shape: (262144, 258)
# Test set shape: (131073, 257)
# Train set overview:
#                                  id   ...    target
# 0  707b395ecdcbb4dc2eabea00e4d1b179   ...         0
# 1  5880c03c6582a7b42248668e56b4bdec   ...         0
# 2  4ccbcb3d13e5072ff1d9c61afe2c4f77   ...         1
# 3  e350f17a357f12a1941f0837afb7eb8d   ...         0
# 4  a8f910ea6075b6376af079055965ff68   ...         0
#
# [5 rows x 258 columns]

# %% [markdown]
# ## Preprocess

# %% [markdown]
# # Model
#
# ## Model parameters

# %%
N_FOLDS = 25

# %%
# INITIALIZE VARIABLES
cols = [c for c in train.columns if c not in ['id', 'target', 'wheezy-copper-turtle-magic', 'preds']]
test['target'] = 0
train['preds'] = 0

# BUILD 512 MODELS
for i in range(512):
    print('wheezy-copper-turtle-magic {}\n'.format(i))
    
    # EXTRACT SUBSET OF DATASET WHERE WHEEZY-MAGIC EQUALS I
    train2 = train[train['wheezy-copper-turtle-magic']==i]
    test2 = test[test['wheezy-copper-turtle-magic']==i]
    idx1 = train2.index
    idx2 = test2.index
    train2.reset_index(drop=True, inplace=True)
    
    # FEATURE SELECTION (USE APPROX 40 OF 255 FEATURES)
    sel = VarianceThreshold(threshold=1.5).fit(train2[cols])
    train3 = sel.transform(train2[cols])
    test3 = sel.transform(test2[cols])

    skf = StratifiedKFold(n_splits=N_FOLDS, random_state=0)
    counter = 0

    for train_index, val_index in skf.split(train3, train2['target']):
        counter += 1
        print('Fold {}\n'.format(counter))
        model = NuSVC(probability=True,kernel='poly',degree=4,gamma='auto')

        model.fit(train3[train_index,:], train2.loc[train_index]['target'])
        
        train_predictions = model.predict(train3[train_index,:])
        val_predictions = model.predict(train3[val_index,:])

        train_auc = roc_auc_score(train2.loc[train_index]['target'], train_predictions) * 100
        val_auc = roc_auc_score(train2.loc[val_index]['target'], val_predictions) * 100
        train_precision = precision_score(train2.loc[train_index]['target'], train_predictions) * 100
        val_precision = precision_score(train2.loc[val_index]['target'], val_predictions) * 100
        train_recall = recall_score(train2.loc[train_index]['target'], train_predictions) * 100
        val_recall = recall_score(train2.loc[val_index]['target'], val_predictions) * 100
        print('-----Train----------')
        print('AUC: %.2f Precision: %.2f Recall: %.2f \n' % (train_auc, train_precision, train_recall))
        print('-----Validation-----')
        print('AUC: %.2f Precision: %.2f Recall: %.2f \n' % (val_auc, val_precision, val_recall))

        # Make predictions
        train['preds'].loc[idx1] += model.predict_proba(train3)[:,1] / N_FOLDS
        test['target'].loc[idx2] += model.predict_proba(test3)[:,1] / N_FOLDS
# Out:
# wheezy-copper-turtle-magic 0
#
# Fold 1
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 77.27 Precision: 80.00 Recall: 72.73
#
# Fold 2
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 95.45 Precision: 91.67 Recall: 100.00
#
# Fold 3
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 95.45 Precision: 91.67 Recall: 100.00
#
# Fold 4
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 86.36 Precision: 100.00 Recall: 72.73
#
# Fold 5
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 81.82 Precision: 88.89 Recall: 72.73
#
# Fold 6
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 95.45 Precision: 100.00 Recall: 90.91
#
# Fold 7
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 81.82 Precision: 88.89 Recall: 72.73
#
# Fold 8
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 95.45 Precision: 100.00 Recall: 90.91
#
# Fold 9
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 90.91 Precision: 84.62 Recall: 100.00
#
# Fold 10
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 95.45 Precision: 100.00 Recall: 90.91
#
# Fold 11
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 95.45 Precision: 100.00 Recall: 90.91
#
# Fold 12
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 86.36 Precision: 90.00 Recall: 81.82
#
# Fold 13
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 81.82 Precision: 81.82 Recall: 81.82
#
# Fold 14
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 90.00 Precision: 100.00 Recall: 80.00
#
# Fold 15
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 81.36 Precision: 75.00 Recall: 90.00
#
# Fold 16
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 90.00 Precision: 100.00 Recall: 80.00
#
# Fold 17
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 90.91 Precision: 83.33 Recall: 100.00
#
# Fold 18
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 90.00 Precision: 100.00 Recall: 80.00
#
# Fold 19
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 85.91 Precision: 81.82 Recall: 90.00
#
# Fold 20
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 85.91 Precision: 81.82 Recall: 90.00
#
# Fold 21
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 75.00 Precision: 100.00 Recall: 50.00
#
# Fold 22
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 90.00 Precision: 90.00 Recall: 90.00
#
# Fold 23
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 85.00 Precision: 100.00 Recall: 70.00
#
# Fold 24
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# Fold 25
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 95.00 Precision: 90.91 Recall: 100.00
#
# wheezy-copper-turtle-magic 1
#
# Fold 1
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 90.91 Precision: 83.33 Recall: 100.00
#
# Fold 2
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 72.73 Precision: 62.50 Recall: 100.00
#
# Fold 3
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# Fold 4
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 95.00 Precision: 100.00 Recall: 90.00
#
# Fold 5
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 95.45 Precision: 90.91 Recall: 100.00
#
# Fold 6
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 95.00 Precision: 100.00 Recall: 90.00
#
# Fold 7
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 90.91 Precision: 83.33 Recall: 100.00
#
# Fold 8
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 90.91 Precision: 83.33 Recall: 100.00
#
# Fold 9
#
# -----Train----------
# AUC: 99.79 Precision: 100.00 Recall: 99.58
#
# -----Validation-----
# AUC: 71.36 Precision: 70.00 Recall: 70.00
#
# Fold 10
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 85.91 Precision: 81.82 Recall: 90.00
#
# Fold 11
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 95.00 Precision: 100.00 Recall: 90.00
#
# Fold 12
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 90.91 Precision: 83.33 Recall: 100.00
#
# Fold 13
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 90.45 Precision: 90.00 Recall: 90.00
#
# Fold 14
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 85.45 Precision: 88.89 Recall: 80.00
#
# Fold 15
#
# -----Train----------
# AUC: 99.58 Precision: 100.00 Recall: 99.15
#
# -----Validation-----
# AUC: 90.00 Precision: 90.00 Recall: 90.00
#
# Fold 16
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 90.00 Precision: 83.33 Recall: 100.00
#
# Fold 17
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 75.00 Precision: 72.73 Recall: 80.00
#
# Fold 18
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 90.00 Precision: 90.00 Recall: 90.00
#
# Fold 19
#
# -----Train----------
# AUC: 99.79 Precision: 100.00 Recall: 99.58
#
# -----Validation-----
# AUC: 85.00 Precision: 88.89 Recall: 80.00
#
# Fold 20
#
# -----Train----------
# AUC: 99.58 Precision: 100.00 Recall: 99.15
#
# -----Validation-----
# AUC: 90.00 Precision: 90.00 Recall: 90.00
#
# Fold 21
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 90.00 Precision: 90.00 Recall: 90.00
#
# Fold 22
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 89.44 Precision: 88.89 Recall: 88.89
#
# Fold 23
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 94.44 Precision: 100.00 Recall: 88.89
#
# Fold 24
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 85.00 Precision: 75.00 Recall: 100.00
#
# Fold 25
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# wheezy-copper-turtle-magic 2
#
# Fold 1
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 80.00 Precision: 100.00 Recall: 60.00
#
# Fold 2
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 90.00 Precision: 100.00 Recall: 80.00
#
# Fold 3
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 80.00 Precision: 87.50 Recall: 70.00
#
# Fold 4
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 90.00 Precision: 100.00 Recall: 80.00
#
# Fold 5
#
# -----Train----------
# AUC: 99.79 Precision: 100.00 Recall: 99.57
#
# -----Validation-----
# AUC: 85.00 Precision: 100.00 Recall: 70.00
#
# Fold 6
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 90.00 Precision: 90.00 Recall: 90.00
#
# Fold 7
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 80.00 Precision: 75.00 Recall: 90.00
#
# Fold 8
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 90.00 Precision: 100.00 Recall: 80.00
#
# Fold 9
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 95.00 Precision: 90.91 Recall: 100.00
#
# Fold 10
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 90.00 Precision: 90.00 Recall: 90.00
#
# Fold 11
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 80.00 Precision: 87.50 Recall: 70.00
#
# Fold 12
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 80.00 Precision: 80.00 Recall: 80.00
#
# Fold 13
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 85.00 Precision: 88.89 Recall: 80.00
#
# Fold 14
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 85.00 Precision: 81.82 Recall: 90.00
#
# Fold 15
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 80.00 Precision: 100.00 Recall: 60.00
#
# Fold 16
#
# -----Train----------
# AUC: 99.79 Precision: 100.00 Recall: 99.57
#
# -----Validation-----
# AUC: 80.00 Precision: 100.00 Recall: 60.00
#
# Fold 17
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 90.00 Precision: 100.00 Recall: 80.00
#
# Fold 18
#
# -----Train----------
# AUC: 99.79 Precision: 100.00 Recall: 99.57
#
# -----Validation-----
# AUC: 85.00 Precision: 88.89 Recall: 80.00
#
# Fold 19
#
# -----Train----------
# AUC: 99.79 Precision: 100.00 Recall: 99.57
#
# -----Validation-----
# AUC: 88.89 Precision: 100.00 Recall: 77.78
#
# Fold 20
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 83.89 Precision: 87.50 Recall: 77.78
#
# Fold 21
#
# -----Train----------
# AUC: 99.79 Precision: 100.00 Recall: 99.57
#
# -----Validation-----
# AUC: 83.33 Precision: 100.00 Recall: 66.67
#
# Fold 22
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 88.89 Precision: 100.00 Recall: 77.78
#
# Fold 23
#
# -----Train----------
# AUC: 99.79 Precision: 100.00 Recall: 99.57
#
# -----Validation-----
# AUC: 72.78 Precision: 83.33 Recall: 55.56
#
# Fold 24
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 94.44 Precision: 100.00 Recall: 88.89
#
# Fold 25
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 88.89 Precision: 100.00 Recall: 77.78
#
# wheezy-copper-turtle-magic 3
#
# Fold 1
#
# -----Train----------
# AUC: 98.58 Precision: 97.46 Recall: 100.00
#
# -----Validation-----
# AUC: 81.82 Precision: 75.00 Recall: 100.00
#
# Fold 2
#
# -----Train----------
# AUC: 98.37 Precision: 97.11 Recall: 100.00
#
# -----Validation-----
# AUC: 86.36 Precision: 80.00 Recall: 100.00
#
# Fold 3
#
# -----Train----------
# AUC: 98.58 Precision: 97.46 Recall: 100.00
#
# -----Validation-----
# AUC: 81.82 Precision: 75.00 Recall: 100.00
#
# Fold 4
#
# -----Train----------
# AUC: 98.37 Precision: 97.11 Recall: 100.00
#
# -----Validation-----
# AUC: 73.48 Precision: 71.43 Recall: 83.33
#
# Fold 5
#
# -----Train----------
# AUC: 98.78 Precision: 97.82 Recall: 100.00
#
# -----Validation-----
# AUC: 90.91 Precision: 85.71 Recall: 100.00
#
# Fold 6
#
# -----Train----------
# AUC: 98.58 Precision: 97.46 Recall: 100.00
#
# -----Validation-----
# AUC: 77.65 Precision: 73.33 Recall: 91.67
#
# Fold 7
#
# -----Train----------
# AUC: 98.37 Precision: 97.12 Recall: 100.00
#
# -----Validation-----
# AUC: 77.27 Precision: 71.43 Recall: 90.91
#
# Fold 8
#
# -----Train----------
# AUC: 98.79 Precision: 97.83 Recall: 100.00
#
# -----Validation-----
# AUC: 85.00 Precision: 78.57 Recall: 100.00
#
# Fold 9
#
# -----Train----------
# AUC: 98.58 Precision: 97.47 Recall: 100.00
#
# -----Validation-----
# AUC: 70.00 Precision: 64.71 Recall: 100.00
#
# Fold 10
#
# -----Train----------
# AUC: 98.79 Precision: 97.83 Recall: 100.00
#
# -----Validation-----
# AUC: 75.00 Precision: 68.75 Recall: 100.00
#
# Fold 11
#
# -----Train----------
# AUC: 98.99 Precision: 98.18 Recall: 100.00
#
# -----Validation-----
# AUC: 70.00 Precision: 64.71 Recall: 100.00
#
# Fold 12
#
# -----Train----------
# AUC: 98.79 Precision: 97.83 Recall: 100.00
#
# -----Validation-----
# AUC: 75.00 Precision: 68.75 Recall: 100.00
#
# Fold 13
#
# -----Train----------
# AUC: 98.58 Precision: 97.47 Recall: 100.00
#
# -----Validation-----
# AUC: 90.00 Precision: 84.62 Recall: 100.00
#
# Fold 14
#
# -----Train----------
# AUC: 98.58 Precision: 97.47 Recall: 100.00
#
# -----Validation-----
# AUC: 70.00 Precision: 64.71 Recall: 100.00
#
# Fold 15
#
# -----Train----------
# AUC: 98.79 Precision: 97.83 Recall: 100.00
#
# -----Validation-----
# AUC: 90.00 Precision: 84.62 Recall: 100.00
#
# Fold 16
#
# -----Train----------
# AUC: 98.58 Precision: 97.47 Recall: 100.00
#
# -----Validation-----
# AUC: 85.00 Precision: 78.57 Recall: 100.00
#
# Fold 17
#
# -----Train----------
# AUC: 98.58 Precision: 97.47 Recall: 100.00
#
# -----Validation-----
# AUC: 95.00 Precision: 91.67 Recall: 100.00
#
# Fold 18
#
# -----Train----------
# AUC: 98.58 Precision: 97.47 Recall: 100.00
#
# -----Validation-----
# AUC: 80.00 Precision: 73.33 Recall: 100.00
#
# Fold 19
#
# -----Train----------
# AUC: 98.58 Precision: 97.47 Recall: 100.00
#
# -----Validation-----
# AUC: 90.00 Precision: 84.62 Recall: 100.00
#
# Fold 20
#
# -----Train----------
# AUC: 98.58 Precision: 97.47 Recall: 100.00
#
# -----Validation-----
# AUC: 70.45 Precision: 66.67 Recall: 90.91
#
# Fold 21
#
# -----Train----------
# AUC: 98.58 Precision: 97.47 Recall: 100.00
#
# -----Validation-----
# AUC: 80.45 Precision: 76.92 Recall: 90.91
#
# Fold 22
#
# -----Train----------
# AUC: 98.58 Precision: 97.47 Recall: 100.00
#
# -----Validation-----
# AUC: 80.00 Precision: 73.33 Recall: 100.00
#
# Fold 23
#
# -----Train----------
# AUC: 98.58 Precision: 97.47 Recall: 100.00
#
# -----Validation-----
# AUC: 80.45 Precision: 76.92 Recall: 90.91
#
# Fold 24
#
# -----Train----------
# AUC: 98.58 Precision: 97.47 Recall: 100.00
#
# -----Validation-----
# AUC: 60.45 Precision: 58.82 Recall: 90.91
#
# Fold 25
#
# -----Train----------
# AUC: 98.79 Precision: 97.83 Recall: 100.00
#
# -----Validation-----
# AUC: 65.45 Precision: 62.50 Recall: 90.91
#
# wheezy-copper-turtle-magic 4
#
# Fold 1
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 86.36 Precision: 83.33 Recall: 90.91
#
# Fold 2
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 86.36 Precision: 90.00 Recall: 81.82
#
# Fold 3
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 86.36 Precision: 83.33 Recall: 90.91
#
# Fold 4
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 95.45 Precision: 91.67 Recall: 100.00
#
# Fold 5
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 86.36 Precision: 90.00 Recall: 81.82
#
# Fold 6
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 85.45 Precision: 83.33 Recall: 90.91
#
# Fold 7
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 90.45 Precision: 90.91 Recall: 90.91
#
# Fold 8
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# Fold 9
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 90.91 Precision: 100.00 Recall: 81.82
#
# Fold 10
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 86.36 Precision: 100.00 Recall: 72.73
#
# Fold 11
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 95.45 Precision: 100.00 Recall: 90.91
#
# Fold 12
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 80.00 Precision: 80.00 Recall: 80.00
#
# Fold 13
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 75.00 Precision: 72.73 Recall: 80.00
#
# Fold 14
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 90.00 Precision: 100.00 Recall: 80.00
#
# Fold 15
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 75.00 Precision: 77.78 Recall: 70.00
#
# Fold 16
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 85.00 Precision: 81.82 Recall: 90.00
#
# Fold 17
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 85.00 Precision: 76.92 Recall: 100.00
#
# Fold 18
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# Fold 19
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# Fold 20
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 85.00 Precision: 81.82 Recall: 90.00
#
# Fold 21
#
# -----Train----------
# AUC: 99.80 Precision: 100.00 Recall: 99.60
#
# -----Validation-----
# AUC: 80.00 Precision: 87.50 Recall: 70.00
#
# Fold 22
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 90.00 Precision: 90.00 Recall: 90.00
#
# Fold 23
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# Fold 24
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 80.00 Precision: 87.50 Recall: 70.00
#
# Fold 25
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 75.00 Precision: 72.73 Recall: 80.00
#
# wheezy-copper-turtle-magic 5
#
# Fold 1
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 90.91 Precision: 90.91 Recall: 90.91
#
# Fold 2
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 81.82 Precision: 76.92 Recall: 90.91
#
# Fold 3
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 77.27 Precision: 80.00 Recall: 72.73
#
# Fold 4
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 81.82 Precision: 76.92 Recall: 90.91
#
# Fold 5
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 86.36 Precision: 78.57 Recall: 100.00
#
# Fold 6
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 95.45 Precision: 100.00 Recall: 90.91
#
# Fold 7
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 90.91 Precision: 90.91 Recall: 90.91
#
# Fold 8
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 90.91 Precision: 84.62 Recall: 100.00
#
# Fold 9
#
# -----Train----------
# AUC: 99.80 Precision: 100.00 Recall: 99.60
#
# -----Validation-----
# AUC: 86.36 Precision: 83.33 Recall: 90.91
#
# Fold 10
#
# -----Train----------
# AUC: 99.60 Precision: 99.20 Recall: 100.00
#
# -----Validation-----
# AUC: 81.82 Precision: 71.43 Recall: 100.00
#
# Fold 11
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 90.00 Precision: 100.00 Recall: 80.00
#
# Fold 12
#
# -----Train----------
# AUC: 99.80 Precision: 100.00 Recall: 99.60
#
# -----Validation-----
# AUC: 95.00 Precision: 100.00 Recall: 90.00
#
# Fold 13
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 90.00 Precision: 90.00 Recall: 90.00
#
# Fold 14
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 85.00 Precision: 100.00 Recall: 70.00
#
# Fold 15
#
# -----Train----------
# AUC: 99.80 Precision: 100.00 Recall: 99.60
#
# -----Validation-----
# AUC: 80.00 Precision: 80.00 Recall: 80.00
#
# Fold 16
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 90.00 Precision: 90.00 Recall: 90.00
#
# Fold 17
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 90.00 Precision: 100.00 Recall: 80.00
#
# Fold 18
#
# -----Train----------
# AUC: 99.80 Precision: 100.00 Recall: 99.60
#
# -----Validation-----
# AUC: 85.00 Precision: 100.00 Recall: 70.00
#
# Fold 19
#
# -----Train----------
# AUC: 99.80 Precision: 100.00 Recall: 99.60
#
# -----Validation-----
# AUC: 85.00 Precision: 76.92 Recall: 100.00
#
# Fold 20
#
# -----Train----------
# AUC: 99.80 Precision: 100.00 Recall: 99.60
#
# -----Validation-----
# AUC: 95.00 Precision: 90.91 Recall: 100.00
#
# Fold 21
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 90.00 Precision: 90.00 Recall: 90.00
#
# Fold 22
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 90.00 Precision: 90.00 Recall: 90.00
#
# Fold 23
#
# -----Train----------
# AUC: 99.80 Precision: 100.00 Recall: 99.60
#
# -----Validation-----
# AUC: 85.00 Precision: 88.89 Recall: 80.00
#
# Fold 24
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 90.00 Precision: 90.00 Recall: 90.00
#
# Fold 25
#
# -----Train----------
# AUC: 99.80 Precision: 100.00 Recall: 99.60
#
# -----Validation-----
# AUC: 90.00 Precision: 90.00 Recall: 90.00
#
# wheezy-copper-turtle-magic 6
#
# Fold 1
#
# -----Train----------
# AUC: 99.59 Precision: 99.22 Recall: 100.00
#
# -----Validation-----
# AUC: 90.91 Precision: 84.62 Recall: 100.00
#
# Fold 2
#
# -----Train----------
# AUC: 99.38 Precision: 98.83 Recall: 100.00
#
# -----Validation-----
# AUC: 77.27 Precision: 71.43 Recall: 90.91
#
# Fold 3
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 90.91 Precision: 84.62 Recall: 100.00
#
# Fold 4
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 85.00 Precision: 78.57 Recall: 100.00
#
# Fold 5
#
# -----Train----------
# AUC: 99.79 Precision: 99.61 Recall: 100.00
#
# -----Validation-----
# AUC: 95.00 Precision: 91.67 Recall: 100.00
#
# Fold 6
#
# -----Train----------
# AUC: 99.59 Precision: 99.22 Recall: 100.00
#
# -----Validation-----
# AUC: 90.00 Precision: 84.62 Recall: 100.00
#
# Fold 7
#
# -----Train----------
# AUC: 99.59 Precision: 99.22 Recall: 100.00
#
# -----Validation-----
# AUC: 75.45 Precision: 71.43 Recall: 90.91
#
# Fold 8
#
# -----Train----------
# AUC: 99.59 Precision: 99.22 Recall: 100.00
#
# -----Validation-----
# AUC: 80.00 Precision: 73.33 Recall: 100.00
#
# Fold 9
#
# -----Train----------
# AUC: 99.79 Precision: 99.61 Recall: 100.00
#
# -----Validation-----
# AUC: 85.00 Precision: 78.57 Recall: 100.00
#
# Fold 10
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 85.45 Precision: 83.33 Recall: 90.91
#
# Fold 11
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 90.00 Precision: 84.62 Recall: 100.00
#
# Fold 12
#
# -----Train----------
# AUC: 99.38 Precision: 98.83 Recall: 100.00
#
# -----Validation-----
# AUC: 95.00 Precision: 91.67 Recall: 100.00
#
# Fold 13
#
# -----Train----------
# AUC: 99.79 Precision: 99.61 Recall: 100.00
#
# -----Validation-----
# AUC: 90.00 Precision: 84.62 Recall: 100.00
#
# Fold 14
#
# -----Train----------
# AUC: 99.59 Precision: 99.22 Recall: 100.00
#
# -----Validation-----
# AUC: 80.45 Precision: 76.92 Recall: 90.91
#
# Fold 15
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# Fold 16
#
# -----Train----------
# AUC: 99.59 Precision: 99.22 Recall: 100.00
#
# -----Validation-----
# AUC: 70.00 Precision: 64.29 Recall: 90.00
#
# Fold 17
#
# -----Train----------
# AUC: 99.38 Precision: 98.84 Recall: 100.00
#
# -----Validation-----
# AUC: 80.00 Precision: 71.43 Recall: 100.00
#
# Fold 18
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 85.00 Precision: 81.82 Recall: 90.00
#
# Fold 19
#
# -----Train----------
# AUC: 99.59 Precision: 99.22 Recall: 100.00
#
# -----Validation-----
# AUC: 90.00 Precision: 83.33 Recall: 100.00
#
# Fold 20
#
# -----Train----------
# AUC: 99.59 Precision: 99.22 Recall: 100.00
#
# -----Validation-----
# AUC: 90.00 Precision: 83.33 Recall: 100.00
#
# Fold 21
#
# -----Train----------
# AUC: 99.38 Precision: 98.84 Recall: 100.00
#
# -----Validation-----
# AUC: 75.00 Precision: 66.67 Recall: 100.00
#
# Fold 22
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# Fold 23
#
# -----Train----------
# AUC: 99.59 Precision: 99.22 Recall: 100.00
#
# -----Validation-----
# AUC: 80.00 Precision: 75.00 Recall: 90.00
#
# Fold 24
#
# -----Train----------
# AUC: 99.38 Precision: 98.84 Recall: 100.00
#
# -----Validation-----
# AUC: 75.00 Precision: 66.67 Recall: 100.00
#
# Fold 25
#
# -----Train----------
# AUC: 99.38 Precision: 98.84 Recall: 100.00
#
# -----Validation-----
# AUC: 80.00 Precision: 71.43 Recall: 100.00
#
# wheezy-copper-turtle-magic 7
#
# Fold 1
#
# -----Train----------
# AUC: 99.59 Precision: 100.00 Recall: 99.18
#
# -----Validation-----
# AUC: 81.82 Precision: 81.82 Recall: 81.82
#
# Fold 2
#
# -----Train----------
# AUC: 99.38 Precision: 100.00 Recall: 98.77
#
# -----Validation-----
# AUC: 77.27 Precision: 100.00 Recall: 54.55
#
# Fold 3
#
# -----Train----------
# AUC: 99.38 Precision: 100.00 Recall: 98.77
#
# -----Validation-----
# AUC: 81.82 Precision: 100.00 Recall: 63.64
#
# Fold 4
#
# -----Train----------
# AUC: 99.18 Precision: 100.00 Recall: 98.35
#
# -----Validation-----
# AUC: 76.82 Precision: 87.50 Recall: 63.64
#
# Fold 5
#
# -----Train----------
# AUC: 99.39 Precision: 100.00 Recall: 98.77
#
# -----Validation-----
# AUC: 80.00 Precision: 100.00 Recall: 60.00
#
# Fold 6
#
# -----Train----------
# AUC: 99.18 Precision: 100.00 Recall: 98.36
#
# -----Validation-----
# AUC: 70.00 Precision: 83.33 Recall: 50.00
#
# Fold 7
#
# -----Train----------
# AUC: 99.39 Precision: 100.00 Recall: 98.77
#
# -----Validation-----
# AUC: 70.00 Precision: 100.00 Recall: 40.00
#
# Fold 8
#
# -----Train----------
# AUC: 99.39 Precision: 100.00 Recall: 98.77
#
# -----Validation-----
# AUC: 75.00 Precision: 77.78 Recall: 70.00
#
# Fold 9
#
# -----Train----------
# AUC: 99.18 Precision: 100.00 Recall: 98.36
#
# -----Validation-----
# AUC: 85.00 Precision: 100.00 Recall: 70.00
#
# Fold 10
#
# -----Train----------
# AUC: 99.39 Precision: 100.00 Recall: 98.77
#
# -----Validation-----
# AUC: 80.00 Precision: 100.00 Recall: 60.00
#
# Fold 11
#
# -----Train----------
# AUC: 99.39 Precision: 100.00 Recall: 98.77
#
# -----Validation-----
# AUC: 85.00 Precision: 88.89 Recall: 80.00
#
# Fold 12
#
# -----Train----------
# AUC: 99.39 Precision: 100.00 Recall: 98.77
#
# -----Validation-----
# AUC: 80.00 Precision: 87.50 Recall: 70.00
#
# Fold 13
#
# -----Train----------
# AUC: 99.18 Precision: 100.00 Recall: 98.36
#
# -----Validation-----
# AUC: 90.00 Precision: 100.00 Recall: 80.00
#
# Fold 14
#
# -----Train----------
# AUC: 99.18 Precision: 100.00 Recall: 98.36
#
# -----Validation-----
# AUC: 80.00 Precision: 100.00 Recall: 60.00
#
# Fold 15
#
# -----Train----------
# AUC: 99.39 Precision: 100.00 Recall: 98.77
#
# -----Validation-----
# AUC: 90.00 Precision: 90.00 Recall: 90.00
#
# Fold 16
#
# -----Train----------
# AUC: 99.59 Precision: 100.00 Recall: 99.18
#
# -----Validation-----
# AUC: 85.00 Precision: 100.00 Recall: 70.00
#
# Fold 17
#
# -----Train----------
# AUC: 99.39 Precision: 100.00 Recall: 98.77
#
# -----Validation-----
# AUC: 80.00 Precision: 80.00 Recall: 80.00
#
# Fold 18
#
# -----Train----------
# AUC: 99.39 Precision: 100.00 Recall: 98.77
#
# -----Validation-----
# AUC: 75.00 Precision: 100.00 Recall: 50.00
#
# Fold 19
#
# -----Train----------
# AUC: 99.18 Precision: 100.00 Recall: 98.36
#
# -----Validation-----
# AUC: 85.00 Precision: 88.89 Recall: 80.00
#
# Fold 20
#
# -----Train----------
# AUC: 99.18 Precision: 100.00 Recall: 98.36
#
# -----Validation-----
# AUC: 85.00 Precision: 100.00 Recall: 70.00
#
# Fold 21
#
# -----Train----------
# AUC: 99.39 Precision: 100.00 Recall: 98.77
#
# -----Validation-----
# AUC: 75.00 Precision: 77.78 Recall: 70.00
#
# Fold 22
#
# -----Train----------
# AUC: 99.59 Precision: 100.00 Recall: 99.18
#
# -----Validation-----
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# Fold 23
#
# -----Train----------
# AUC: 99.80 Precision: 100.00 Recall: 99.59
#
# -----Validation-----
# AUC: 75.00 Precision: 77.78 Recall: 70.00
#
# Fold 24
#
# -----Train----------
# AUC: 99.39 Precision: 100.00 Recall: 98.77
#
# -----Validation-----
# AUC: 85.00 Precision: 100.00 Recall: 70.00
#
# Fold 25
#
# -----Train----------
# AUC: 99.39 Precision: 100.00 Recall: 98.77
#
# -----Validation-----
# AUC: 85.00 Precision: 88.89 Recall: 80.00
#
# wheezy-copper-turtle-magic 8
#
# Fold 1
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 77.27 Precision: 75.00 Recall: 81.82
#
# Fold 2
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 95.45 Precision: 91.67 Recall: 100.00
#
# Fold 3
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 86.36 Precision: 83.33 Recall: 90.91
#
# Fold 4
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 90.91 Precision: 84.62 Recall: 100.00
#
# Fold 5
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 90.91 Precision: 90.91 Recall: 90.91
#
# Fold 6
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 85.45 Precision: 83.33 Recall: 90.91
#
# Fold 7
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 85.00 Precision: 78.57 Recall: 100.00
#
# Fold 8
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 85.00 Precision: 78.57 Recall: 100.00
#
# Fold 9
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# Fold 10
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 85.00 Precision: 78.57 Recall: 100.00
#
# Fold 11
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 80.91 Precision: 81.82 Recall: 81.82
#
# Fold 12
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 75.45 Precision: 71.43 Recall: 90.91
#
# Fold 13
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 85.00 Precision: 78.57 Recall: 100.00
#
# Fold 14
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 85.45 Precision: 83.33 Recall: 90.91
#
# Fold 15
#
# -----Train----------
# AUC: 99.80 Precision: 99.61 Recall: 100.00
#
# -----Validation-----
# AUC: 80.00 Precision: 73.33 Recall: 100.00
#
# Fold 16
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 90.91 Precision: 100.00 Recall: 81.82
#
# Fold 17
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 90.00 Precision: 84.62 Recall: 100.00
#
# Fold 18
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 80.00 Precision: 75.00 Recall: 90.00
#
# Fold 19
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 90.00 Precision: 90.00 Recall: 90.00
#
# Fold 20
#
# -----Train----------
# AUC: 99.80 Precision: 99.61 Recall: 100.00
#
# -----Validation-----
# AUC: 85.00 Precision: 76.92 Recall: 100.00
#
# Fold 21
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 90.00 Precision: 83.33 Recall: 100.00
#
# Fold 22
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 95.00 Precision: 100.00 Recall: 90.00
#
# Fold 23
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 85.00 Precision: 81.82 Recall: 90.00
#
# Fold 24
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# Fold 25
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 90.00 Precision: 83.33 Recall: 100.00
#
# wheezy-copper-turtle-magic 9
#
# Fold 1
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 81.82 Precision: 81.82 Recall: 81.82
#
# Fold 2
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 90.91 Precision: 90.91 Recall: 90.91
#
# Fold 3
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 95.45 Precision: 91.67 Recall: 100.00
#
# Fold 4
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 72.73 Precision: 66.67 Recall: 90.91
#
# Fold 5
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 90.91 Precision: 90.91 Recall: 90.91
#
# Fold 6
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 90.91 Precision: 90.91 Recall: 90.91
#
# Fold 7
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 90.91 Precision: 84.62 Recall: 100.00
#
# Fold 8
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 86.36 Precision: 83.33 Recall: 90.91
#
# Fold 9
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 86.36 Precision: 83.33 Recall: 90.91
#
# Fold 10
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 81.82 Precision: 100.00 Recall: 63.64
#
# Fold 11
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 95.45 Precision: 91.67 Recall: 100.00
#
# Fold 12
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 95.45 Precision: 91.67 Recall: 100.00
#
# Fold 13
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 86.36 Precision: 78.57 Recall: 100.00
#
# Fold 14
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 86.36 Precision: 78.57 Recall: 100.00
#
# Fold 15
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 95.00 Precision: 100.00 Recall: 90.00
#
# Fold 16
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 80.00 Precision: 87.50 Recall: 70.00
#
# Fold 17
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# Fold 18
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 85.00 Precision: 88.89 Recall: 80.00
#
# Fold 19
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 80.00 Precision: 80.00 Recall: 80.00
#
# Fold 20
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 90.00 Precision: 90.00 Recall: 90.00
#
# Fold 21
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 80.00 Precision: 71.43 Recall: 100.00
#
# Fold 22
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 90.00 Precision: 90.00 Recall: 90.00
#
# Fold 23
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# Fold 24
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# Fold 25
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 95.00 Precision: 90.91 Recall: 100.00
#
# wheezy-copper-turtle-magic 10
#
# Fold 1
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 95.45 Precision: 90.91 Recall: 100.00
#
# Fold 2
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 80.91 Precision: 80.00 Recall: 80.00
#
# Fold 3
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 90.00 Precision: 83.33 Recall: 100.00
#
# Fold 4
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 80.00 Precision: 87.50 Recall: 70.00
#
# Fold 5
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# Fold 6
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# Fold 7
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 95.00 Precision: 90.91 Recall: 100.00
#
# Fold 8
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 95.00 Precision: 100.00 Recall: 90.00
#
# Fold 9
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 90.00 Precision: 90.00 Recall: 90.00
#
# Fold 10
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 85.00 Precision: 81.82 Recall: 90.00
#
# Fold 11
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 95.00 Precision: 100.00 Recall: 90.00
#
# Fold 12
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 95.00 Precision: 90.91 Recall: 100.00
#
# Fold 13
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 95.00 Precision: 100.00 Recall: 90.00
#
# Fold 14
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 85.00 Precision: 76.92 Recall: 100.00
#
# Fold 15
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 85.00 Precision: 88.89 Recall: 80.00
#
# Fold 16
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 95.00 Precision: 100.00 Recall: 90.00
#
# Fold 17
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 95.00 Precision: 100.00 Recall: 90.00
#
# Fold 18
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 85.00 Precision: 100.00 Recall: 70.00
#
# Fold 19
#
# -----Train----------
# AUC: 99.79 Precision: 99.58 Recall: 100.00
#
# -----Validation-----
# AUC: 85.00 Precision: 81.82 Recall: 90.00
#
# Fold 20
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 95.00 Precision: 100.00 Recall: 90.00
#
# Fold 21
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 90.00 Precision: 83.33 Recall: 100.00
#
# Fold 22
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 85.00 Precision: 75.00 Recall: 100.00
#
# Fold 23
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 88.89 Precision: 100.00 Recall: 77.78
#
# Fold 24
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 83.89 Precision: 87.50 Recall: 77.78
#
# Fold 25
#
# -----Train----------
# AUC: 99.79 Precision: 99.58 Recall: 100.00
#
# -----Validation-----
# AUC: 79.44 Precision: 72.73 Recall: 88.89
#
# wheezy-copper-turtle-magic 11
#
# Fold 1
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 85.00 Precision: 88.89 Recall: 80.00
#
# Fold 2
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 95.00 Precision: 90.91 Recall: 100.00
#
# Fold 3
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 90.00 Precision: 90.00 Recall: 90.00
#
# Fold 4
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# Fold 5
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 95.00 Precision: 100.00 Recall: 90.00
#
# Fold 6
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# Fold 7
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 80.00 Precision: 87.50 Recall: 70.00
#
# Fold 8
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# Fold 9
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 95.00 Precision: 90.00 Recall: 100.00
#
# Fold 10
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 88.89 Precision: 100.00 Recall: 77.78
#
# Fold 11
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 85.00 Precision: 75.00 Recall: 100.00
#
# Fold 12
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 95.00 Precision: 90.00 Recall: 100.00
#
# Fold 13
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 94.44 Precision: 100.00 Recall: 88.89
#
# Fold 14
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 90.00 Precision: 81.82 Recall: 100.00
#
# Fold 15
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 95.00 Precision: 90.00 Recall: 100.00
#
# Fold 16
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 83.89 Precision: 87.50 Recall: 77.78
#
# Fold 17
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# Fold 18
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 94.44 Precision: 100.00 Recall: 88.89
#
# Fold 19
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# Fold 20
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 90.00 Precision: 81.82 Recall: 100.00
#
# Fold 21
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 67.78 Precision: 71.43 Recall: 55.56
#
# Fold 22
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 84.44 Precision: 80.00 Recall: 88.89
#
# Fold 23
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 94.44 Precision: 100.00 Recall: 88.89
#
# Fold 24
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 95.00 Precision: 90.00 Recall: 100.00
#
# Fold 25
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 88.89 Precision: 100.00 Recall: 77.78
#
# wheezy-copper-turtle-magic 12
#
# Fold 1
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 80.45 Precision: 76.92 Recall: 90.91
#
# Fold 2
#
# -----Train----------
# AUC: 99.79 Precision: 99.59 Recall: 100.00
#
# -----Validation-----
# AUC: 90.00 Precision: 83.33 Recall: 100.00
#
# Fold 3
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 90.00 Precision: 100.00 Recall: 80.00
#
# Fold 4
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 95.00 Precision: 90.91 Recall: 100.00
#
# Fold 5
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 80.00 Precision: 75.00 Recall: 90.00
#
# Fold 6
#
# -----Train----------
# AUC: 99.79 Precision: 99.59 Recall: 100.00
#
# -----Validation-----
# AUC: 90.00 Precision: 90.00 Recall: 90.00
#
# Fold 7
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 95.00 Precision: 90.91 Recall: 100.00
#
# Fold 8
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 85.00 Precision: 76.92 Recall: 100.00
#
# Fold 9
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 95.00 Precision: 90.91 Recall: 100.00
#
# Fold 10
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# Fold 11
#
# -----Train----------
# AUC: 99.79 Precision: 99.59 Recall: 100.00
#
# -----Validation-----
# AUC: 75.00 Precision: 66.67 Recall: 100.00
#
# Fold 12
#
# -----Train----------
# AUC: 99.79 Precision: 99.59 Recall: 100.00
#
# -----Validation-----
# AUC: 80.00 Precision: 71.43 Recall: 100.00
#
# Fold 13
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 85.00 Precision: 76.92 Recall: 100.00
#
# Fold 14
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 75.00 Precision: 69.23 Recall: 90.00
#
# Fold 15
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 95.00 Precision: 90.91 Recall: 100.00
#
# Fold 16
#
# -----Train----------
# AUC: 99.79 Precision: 99.59 Recall: 100.00
#
# -----Validation-----
# AUC: 85.00 Precision: 81.82 Recall: 90.00
#
# Fold 17
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 80.00 Precision: 75.00 Recall: 90.00
#
# Fold 18
#
# -----Train----------
# AUC: 99.79 Precision: 99.59 Recall: 100.00
#
# -----Validation-----
# AUC: 85.00 Precision: 76.92 Recall: 100.00
#
# Fold 19
#
# -----Train----------
# AUC: 99.79 Precision: 99.59 Recall: 100.00
#
# -----Validation-----
# AUC: 80.00 Precision: 71.43 Recall: 100.00
#
# Fold 20
#
# -----Train----------
# AUC: 99.79 Precision: 99.59 Recall: 100.00
#
# -----Validation-----
# AUC: 65.00 Precision: 61.54 Recall: 80.00
#
# Fold 21
#
# -----Train----------
# AUC: 99.79 Precision: 99.59 Recall: 100.00
#
# -----Validation-----
# AUC: 72.78 Precision: 69.23 Recall: 90.00
#
# Fold 22
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 94.44 Precision: 90.91 Recall: 100.00
#
# Fold 23
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 89.44 Precision: 90.00 Recall: 90.00
#
# Fold 24
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 94.44 Precision: 90.91 Recall: 100.00
#
# Fold 25
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 83.89 Precision: 81.82 Recall: 90.00
#
# wheezy-copper-turtle-magic 13
#
# Fold 1
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 95.00 Precision: 100.00 Recall: 90.00
#
# Fold 2
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 90.00 Precision: 90.00 Recall: 90.00
#
# Fold 3
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 90.00 Precision: 100.00 Recall: 80.00
#
# Fold 4
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 90.00 Precision: 90.00 Recall: 90.00
#
# Fold 5
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 90.00 Precision: 100.00 Recall: 80.00
#
# Fold 6
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# Fold 7
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 85.00 Precision: 100.00 Recall: 70.00
#
# Fold 8
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 75.00 Precision: 85.71 Recall: 60.00
#
# Fold 9
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# Fold 10
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 95.00 Precision: 100.00 Recall: 90.00
#
# Fold 11
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# ...
#
# -----Validation-----
# AUC: 85.00 Precision: 100.00 Recall: 70.00
#
# Fold 17
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 90.00 Precision: 100.00 Recall: 80.00
#
# Fold 18
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 90.00 Precision: 100.00 Recall: 80.00
#
# Fold 19
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 85.00 Precision: 100.00 Recall: 70.00
#
# Fold 20
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 85.00 Precision: 100.00 Recall: 70.00
#
# Fold 21
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 90.00 Precision: 100.00 Recall: 80.00
#
# Fold 22
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 85.00 Precision: 88.89 Recall: 80.00
#
# Fold 23
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 85.00 Precision: 88.89 Recall: 80.00
#
# Fold 24
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 70.00 Precision: 75.00 Recall: 60.00
#
# Fold 25
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 85.00 Precision: 100.00 Recall: 70.00
#
# wheezy-copper-turtle-magic 255
#
# Fold 1
#
# -----Train----------
# AUC: 99.81 Precision: 100.00 Recall: 99.61
#
# -----Validation-----
# AUC: 85.45 Precision: 83.33 Recall: 90.91
#
# Fold 2
#
# -----Train----------
# AUC: 99.81 Precision: 100.00 Recall: 99.61
#
# -----Validation-----
# AUC: 90.45 Precision: 90.91 Recall: 90.91
#
# Fold 3
#
# -----Train----------
# AUC: 99.81 Precision: 100.00 Recall: 99.61
#
# -----Validation-----
# AUC: 86.36 Precision: 100.00 Recall: 72.73
#
# Fold 4
#
# -----Train----------
# AUC: 99.81 Precision: 100.00 Recall: 99.61
#
# -----Validation-----
# AUC: 90.91 Precision: 100.00 Recall: 81.82
#
# Fold 5
#
# -----Train----------
# AUC: 99.81 Precision: 100.00 Recall: 99.61
#
# -----Validation-----
# AUC: 95.45 Precision: 100.00 Recall: 90.91
#
# Fold 6
#
# -----Train----------
# AUC: 99.81 Precision: 100.00 Recall: 99.61
#
# -----Validation-----
# AUC: 86.36 Precision: 100.00 Recall: 72.73
#
# Fold 7
#
# -----Train----------
# AUC: 99.81 Precision: 100.00 Recall: 99.61
#
# -----Validation-----
# AUC: 90.45 Precision: 90.91 Recall: 90.91
#
# Fold 8
#
# -----Train----------
# AUC: 99.81 Precision: 100.00 Recall: 99.61
#
# -----Validation-----
# AUC: 95.45 Precision: 100.00 Recall: 90.91
#
# Fold 9
#
# -----Train----------
# AUC: 99.81 Precision: 100.00 Recall: 99.61
#
# -----Validation-----
# AUC: 90.91 Precision: 100.00 Recall: 81.82
#
# Fold 10
#
# -----Train----------
# AUC: 99.81 Precision: 100.00 Recall: 99.61
#
# -----Validation-----
# AUC: 95.45 Precision: 100.00 Recall: 90.91
#
# Fold 11
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 81.82 Precision: 100.00 Recall: 63.64
#
# Fold 12
#
# -----Train----------
# AUC: 99.81 Precision: 100.00 Recall: 99.61
#
# -----Validation-----
# AUC: 90.00 Precision: 84.62 Recall: 100.00
#
# Fold 13
#
# -----Train----------
# AUC: 99.81 Precision: 100.00 Recall: 99.61
#
# -----Validation-----
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# Fold 14
#
# -----Train----------
# AUC: 99.81 Precision: 100.00 Recall: 99.61
#
# -----Validation-----
# AUC: 95.45 Precision: 100.00 Recall: 90.91
#
# Fold 15
#
# -----Train----------
# AUC: 99.81 Precision: 100.00 Recall: 99.61
#
# -----Validation-----
# AUC: 86.36 Precision: 100.00 Recall: 72.73
#
# Fold 16
#
# -----Train----------
# AUC: 99.81 Precision: 100.00 Recall: 99.61
#
# -----Validation-----
# AUC: 81.82 Precision: 100.00 Recall: 63.64
#
# Fold 17
#
# -----Train----------
# AUC: 99.42 Precision: 100.00 Recall: 98.84
#
# -----Validation-----
# AUC: 72.27 Precision: 85.71 Recall: 54.55
#
# Fold 18
#
# -----Train----------
# AUC: 99.81 Precision: 100.00 Recall: 99.61
#
# -----Validation-----
# AUC: 90.45 Precision: 90.91 Recall: 90.91
#
# Fold 19
#
# -----Train----------
# AUC: 99.81 Precision: 100.00 Recall: 99.61
#
# -----Validation-----
# AUC: 90.45 Precision: 90.91 Recall: 90.91
#
# Fold 20
#
# -----Train----------
# AUC: 99.81 Precision: 100.00 Recall: 99.61
#
# -----Validation-----
# AUC: 90.00 Precision: 84.62 Recall: 100.00
#
# Fold 21
#
# -----Train----------
# AUC: 99.81 Precision: 100.00 Recall: 99.62
#
# -----Validation-----
# AUC: 95.00 Precision: 100.00 Recall: 90.00
#
# Fold 22
#
# -----Train----------
# AUC: 99.81 Precision: 100.00 Recall: 99.62
#
# -----Validation-----
# AUC: 95.00 Precision: 100.00 Recall: 90.00
#
# Fold 23
#
# -----Train----------
# AUC: 99.81 Precision: 100.00 Recall: 99.62
#
# -----Validation-----
# AUC: 90.00 Precision: 90.00 Recall: 90.00
#
# Fold 24
#
# -----Train----------
# AUC: 99.81 Precision: 100.00 Recall: 99.62
#
# -----Validation-----
# AUC: 75.00 Precision: 85.71 Recall: 60.00
#
# Fold 25
#
# -----Train----------
# AUC: 99.81 Precision: 100.00 Recall: 99.62
#
# -----Validation-----
# AUC: 95.00 Precision: 100.00 Recall: 90.00
#
# wheezy-copper-turtle-magic 256
#
# Fold 1
#
# -----Train----------
# AUC: 98.85 Precision: 98.09 Recall: 100.00
#
# -----Validation-----
# AUC: 95.00 Precision: 91.67 Recall: 100.00
#
# Fold 2
#
# -----Train----------
# AUC: 99.54 Precision: 99.23 Recall: 100.00
#
# -----Validation-----
# AUC: 80.00 Precision: 73.33 Recall: 100.00
#
# Fold 3
#
# -----Train----------
# AUC: 99.31 Precision: 98.85 Recall: 100.00
#
# -----Validation-----
# AUC: 90.00 Precision: 84.62 Recall: 100.00
#
# Fold 4
#
# -----Train----------
# AUC: 99.32 Precision: 98.85 Recall: 100.00
#
# -----Validation-----
# AUC: 77.78 Precision: 73.33 Recall: 100.00
#
# Fold 5
#
# -----Train----------
# AUC: 99.54 Precision: 99.23 Recall: 100.00
#
# -----Validation-----
# AUC: 83.33 Precision: 78.57 Recall: 100.00
#
# Fold 6
#
# -----Train----------
# AUC: 99.54 Precision: 99.23 Recall: 100.00
#
# -----Validation-----
# AUC: 83.33 Precision: 78.57 Recall: 100.00
#
# Fold 7
#
# -----Train----------
# AUC: 99.77 Precision: 99.61 Recall: 100.00
#
# -----Validation-----
# AUC: 83.33 Precision: 78.57 Recall: 100.00
#
# Fold 8
#
# -----Train----------
# AUC: 98.86 Precision: 98.09 Recall: 100.00
#
# -----Validation-----
# AUC: 72.22 Precision: 68.75 Recall: 100.00
#
# Fold 9
#
# -----Train----------
# AUC: 99.54 Precision: 99.23 Recall: 100.00
#
# -----Validation-----
# AUC: 66.67 Precision: 64.71 Recall: 100.00
#
# Fold 10
#
# -----Train----------
# AUC: 99.54 Precision: 99.23 Recall: 100.00
#
# -----Validation-----
# AUC: 72.22 Precision: 68.75 Recall: 100.00
#
# Fold 11
#
# -----Train----------
# AUC: 99.54 Precision: 99.23 Recall: 100.00
#
# -----Validation-----
# AUC: 88.89 Precision: 84.62 Recall: 100.00
#
# Fold 12
#
# -----Train----------
# AUC: 99.54 Precision: 99.23 Recall: 100.00
#
# -----Validation-----
# AUC: 77.78 Precision: 73.33 Recall: 100.00
#
# Fold 13
#
# -----Train----------
# AUC: 99.54 Precision: 99.23 Recall: 100.00
#
# -----Validation-----
# AUC: 83.33 Precision: 78.57 Recall: 100.00
#
# Fold 14
#
# -----Train----------
# AUC: 99.54 Precision: 99.23 Recall: 100.00
#
# -----Validation-----
# AUC: 77.78 Precision: 73.33 Recall: 100.00
#
# Fold 15
#
# -----Train----------
# AUC: 99.54 Precision: 99.23 Recall: 100.00
#
# -----Validation-----
# AUC: 72.22 Precision: 68.75 Recall: 100.00
#
# Fold 16
#
# -----Train----------
# AUC: 99.54 Precision: 99.23 Recall: 100.00
#
# -----Validation-----
# AUC: 78.79 Precision: 76.92 Recall: 90.91
#
# Fold 17
#
# -----Train----------
# AUC: 99.09 Precision: 98.47 Recall: 100.00
#
# -----Validation-----
# AUC: 67.68 Precision: 66.67 Recall: 90.91
#
# Fold 18
#
# -----Train----------
# AUC: 99.54 Precision: 99.23 Recall: 100.00
#
# -----Validation-----
# AUC: 73.23 Precision: 71.43 Recall: 90.91
#
# Fold 19
#
# -----Train----------
# AUC: 99.54 Precision: 99.23 Recall: 100.00
#
# -----Validation-----
# AUC: 83.33 Precision: 76.92 Recall: 100.00
#
# Fold 20
#
# -----Train----------
# AUC: 99.77 Precision: 99.61 Recall: 100.00
#
# -----Validation-----
# AUC: 72.22 Precision: 66.67 Recall: 100.00
#
# Fold 21
#
# -----Train----------
# AUC: 99.54 Precision: 99.23 Recall: 100.00
#
# -----Validation-----
# AUC: 78.33 Precision: 75.00 Recall: 90.00
#
# Fold 22
#
# -----Train----------
# AUC: 99.32 Precision: 98.85 Recall: 100.00
#
# -----Validation-----
# AUC: 61.11 Precision: 58.82 Recall: 100.00
#
# Fold 23
#
# -----Train----------
# AUC: 99.54 Precision: 99.23 Recall: 100.00
#
# -----Validation-----
# AUC: 89.44 Precision: 90.00 Recall: 90.00
#
# Fold 24
#
# -----Train----------
# AUC: 99.54 Precision: 99.23 Recall: 100.00
#
# -----Validation-----
# AUC: 89.44 Precision: 90.00 Recall: 90.00
#
# Fold 25
#
# -----Train----------
# AUC: 99.54 Precision: 99.23 Recall: 100.00
#
# -----Validation-----
# AUC: 83.33 Precision: 76.92 Recall: 100.00
#
# wheezy-copper-turtle-magic 257
#
# Fold 1
#
# -----Train----------
# AUC: 99.38 Precision: 100.00 Recall: 98.75
#
# -----Validation-----
# AUC: 90.91 Precision: 100.00 Recall: 81.82
#
# Fold 2
#
# -----Train----------
# AUC: 99.79 Precision: 100.00 Recall: 99.59
#
# -----Validation-----
# AUC: 95.00 Precision: 100.00 Recall: 90.00
#
# Fold 3
#
# -----Train----------
# AUC: 99.38 Precision: 100.00 Recall: 98.76
#
# -----Validation-----
# AUC: 90.00 Precision: 100.00 Recall: 80.00
#
# Fold 4
#
# -----Train----------
# AUC: 99.59 Precision: 100.00 Recall: 99.17
#
# -----Validation-----
# AUC: 75.00 Precision: 85.71 Recall: 60.00
#
# Fold 5
#
# -----Train----------
# AUC: 99.79 Precision: 100.00 Recall: 99.59
#
# -----Validation-----
# AUC: 90.00 Precision: 83.33 Recall: 100.00
#
# Fold 6
#
# -----Train----------
# AUC: 99.59 Precision: 100.00 Recall: 99.17
#
# -----Validation-----
# AUC: 80.00 Precision: 87.50 Recall: 70.00
#
# Fold 7
#
# -----Train----------
# AUC: 99.59 Precision: 100.00 Recall: 99.17
#
# -----Validation-----
# AUC: 95.00 Precision: 100.00 Recall: 90.00
#
# Fold 8
#
# -----Train----------
# AUC: 99.59 Precision: 100.00 Recall: 99.17
#
# -----Validation-----
# AUC: 95.00 Precision: 100.00 Recall: 90.00
#
# Fold 9
#
# -----Train----------
# AUC: 99.38 Precision: 100.00 Recall: 98.76
#
# -----Validation-----
# AUC: 85.00 Precision: 100.00 Recall: 70.00
#
# Fold 10
#
# -----Train----------
# AUC: 99.38 Precision: 100.00 Recall: 98.76
#
# -----Validation-----
# AUC: 85.00 Precision: 100.00 Recall: 70.00
#
# Fold 11
#
# -----Train----------
# AUC: 99.59 Precision: 100.00 Recall: 99.17
#
# -----Validation-----
# AUC: 85.00 Precision: 81.82 Recall: 90.00
#
# Fold 12
#
# -----Train----------
# AUC: 99.79 Precision: 100.00 Recall: 99.59
#
# -----Validation-----
# AUC: 95.00 Precision: 100.00 Recall: 90.00
#
# Fold 13
#
# -----Train----------
# AUC: 99.59 Precision: 100.00 Recall: 99.17
#
# -----Validation-----
# AUC: 95.00 Precision: 100.00 Recall: 90.00
#
# Fold 14
#
# -----Train----------
# AUC: 99.38 Precision: 100.00 Recall: 98.76
#
# -----Validation-----
# AUC: 95.00 Precision: 100.00 Recall: 90.00
#
# Fold 15
#
# -----Train----------
# AUC: 99.38 Precision: 100.00 Recall: 98.76
#
# -----Validation-----
# AUC: 90.00 Precision: 100.00 Recall: 80.00
#
# Fold 16
#
# -----Train----------
# AUC: 99.79 Precision: 100.00 Recall: 99.59
#
# -----Validation-----
# AUC: 90.00 Precision: 90.00 Recall: 90.00
#
# Fold 17
#
# -----Train----------
# AUC: 99.79 Precision: 100.00 Recall: 99.59
#
# -----Validation-----
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# Fold 18
#
# -----Train----------
# AUC: 99.59 Precision: 100.00 Recall: 99.17
#
# -----Validation-----
# AUC: 90.00 Precision: 83.33 Recall: 100.00
#
# Fold 19
#
# -----Train----------
# AUC: 99.38 Precision: 100.00 Recall: 98.76
#
# -----Validation-----
# AUC: 90.00 Precision: 100.00 Recall: 80.00
#
# Fold 20
#
# -----Train----------
# AUC: 99.59 Precision: 100.00 Recall: 99.17
#
# -----Validation-----
# AUC: 80.00 Precision: 100.00 Recall: 60.00
#
# Fold 21
#
# -----Train----------
# AUC: 99.79 Precision: 100.00 Recall: 99.59
#
# -----Validation-----
# AUC: 95.00 Precision: 90.91 Recall: 100.00
#
# Fold 22
#
# -----Train----------
# AUC: 99.17 Precision: 100.00 Recall: 98.34
#
# -----Validation-----
# AUC: 80.00 Precision: 100.00 Recall: 60.00
#
# Fold 23
#
# -----Train----------
# AUC: 99.38 Precision: 100.00 Recall: 98.76
#
# -----Validation-----
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# Fold 24
#
# -----Train----------
# AUC: 99.38 Precision: 100.00 Recall: 98.76
#
# -----Validation-----
# AUC: 95.00 Precision: 90.91 Recall: 100.00
#
# Fold 25
#
# -----Train----------
# AUC: 99.38 Precision: 100.00 Recall: 98.76
#
# -----Validation-----
# AUC: 95.00 Precision: 90.91 Recall: 100.00
#
# wheezy-copper-turtle-magic 258
#
# Fold 1
#
# -----Train----------
# AUC: 99.59 Precision: 99.21 Recall: 100.00
#
# -----Validation-----
# AUC: 81.82 Precision: 81.82 Recall: 81.82
#
# Fold 2
#
# -----Train----------
# AUC: 99.59 Precision: 99.21 Recall: 100.00
#
# -----Validation-----
# AUC: 86.36 Precision: 78.57 Recall: 100.00
#
# Fold 3
#
# -----Train----------
# AUC: 99.59 Precision: 99.21 Recall: 100.00
#
# -----Validation-----
# AUC: 77.27 Precision: 71.43 Recall: 90.91
#
# Fold 4
#
# -----Train----------
# AUC: 99.59 Precision: 99.21 Recall: 100.00
#
# -----Validation-----
# AUC: 81.82 Precision: 76.92 Recall: 90.91
#
# Fold 5
#
# -----Train----------
# AUC: 99.59 Precision: 99.21 Recall: 100.00
#
# -----Validation-----
# AUC: 95.45 Precision: 91.67 Recall: 100.00
#
# Fold 6
#
# -----Train----------
# AUC: 99.59 Precision: 99.21 Recall: 100.00
#
# -----Validation-----
# AUC: 80.00 Precision: 73.33 Recall: 100.00
#
# Fold 7
#
# -----Train----------
# AUC: 99.80 Precision: 99.60 Recall: 100.00
#
# -----Validation-----
# AUC: 70.00 Precision: 64.71 Recall: 100.00
#
# Fold 8
#
# -----Train----------
# AUC: 99.59 Precision: 99.21 Recall: 100.00
#
# -----Validation-----
# AUC: 65.91 Precision: 64.29 Recall: 81.82
#
# Fold 9
#
# -----Train----------
# AUC: 99.80 Precision: 99.60 Recall: 100.00
#
# -----Validation-----
# AUC: 90.45 Precision: 90.91 Recall: 90.91
#
# Fold 10
#
# -----Train----------
# AUC: 99.80 Precision: 99.60 Recall: 100.00
#
# -----Validation-----
# AUC: 85.00 Precision: 78.57 Recall: 100.00
#
# Fold 11
#
# -----Train----------
# AUC: 99.80 Precision: 99.60 Recall: 100.00
#
# -----Validation-----
# AUC: 85.45 Precision: 83.33 Recall: 90.91
#
# Fold 12
#
# -----Train----------
# AUC: 99.59 Precision: 99.21 Recall: 100.00
#
# -----Validation-----
# AUC: 75.00 Precision: 69.23 Recall: 90.00
#
# Fold 13
#
# -----Train----------
# AUC: 99.59 Precision: 99.21 Recall: 100.00
#
# -----Validation-----
# AUC: 75.00 Precision: 66.67 Recall: 100.00
#
# Fold 14
#
# -----Train----------
# AUC: 99.59 Precision: 99.21 Recall: 100.00
#
# -----Validation-----
# AUC: 80.00 Precision: 71.43 Recall: 100.00
#
# Fold 15
#
# -----Train----------
# AUC: 99.80 Precision: 99.60 Recall: 100.00
#
# -----Validation-----
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# Fold 16
#
# -----Train----------
# AUC: 99.59 Precision: 99.21 Recall: 100.00
#
# -----Validation-----
# AUC: 80.00 Precision: 80.00 Recall: 80.00
#
# Fold 17
#
# -----Train----------
# AUC: 99.59 Precision: 99.21 Recall: 100.00
#
# -----Validation-----
# AUC: 85.00 Precision: 76.92 Recall: 100.00
#
# Fold 18
#
# -----Train----------
# AUC: 99.59 Precision: 99.21 Recall: 100.00
#
# -----Validation-----
# AUC: 85.00 Precision: 81.82 Recall: 90.00
#
# Fold 19
#
# -----Train----------
# AUC: 99.59 Precision: 99.21 Recall: 100.00
#
# -----Validation-----
# AUC: 85.00 Precision: 76.92 Recall: 100.00
#
# Fold 20
#
# -----Train----------
# AUC: 99.80 Precision: 99.60 Recall: 100.00
#
# -----Validation-----
# AUC: 95.00 Precision: 90.91 Recall: 100.00
#
# Fold 21
#
# -----Train----------
# AUC: 99.59 Precision: 99.21 Recall: 100.00
#
# -----Validation-----
# AUC: 80.00 Precision: 75.00 Recall: 90.00
#
# Fold 22
#
# -----Train----------
# AUC: 99.59 Precision: 99.21 Recall: 100.00
#
# -----Validation-----
# AUC: 80.00 Precision: 75.00 Recall: 90.00
#
# Fold 23
#
# -----Train----------
# AUC: 99.59 Precision: 99.21 Recall: 100.00
#
# -----Validation-----
# AUC: 70.00 Precision: 64.29 Recall: 90.00
#
# Fold 24
#
# -----Train----------
# AUC: 99.80 Precision: 99.60 Recall: 100.00
#
# -----Validation-----
# AUC: 85.00 Precision: 76.92 Recall: 100.00
#
# Fold 25
#
# -----Train----------
# AUC: 99.80 Precision: 99.60 Recall: 100.00
#
# -----Validation-----
# AUC: 95.00 Precision: 90.91 Recall: 100.00
#
# wheezy-copper-turtle-magic 259
#
# Fold 1
#
# -----Train----------
# AUC: 99.58 Precision: 99.17 Recall: 100.00
#
# -----Validation-----
# AUC: 95.00 Precision: 100.00 Recall: 90.00
#
# Fold 2
#
# -----Train----------
# AUC: 99.79 Precision: 99.59 Recall: 100.00
#
# -----Validation-----
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# Fold 3
#
# -----Train----------
# AUC: 99.58 Precision: 99.17 Recall: 100.00
#
# -----Validation-----
# AUC: 80.00 Precision: 71.43 Recall: 100.00

# %% [markdown]
# # Model evaluation
# ## Confusion matrix

# %%
f = plt.subplots(1, 1, figsize=(16, 5), sharex=True)
train_cnf_matrix = confusion_matrix(train['target'], [np.round(x) for x in train['preds']])
train_cnf_matrix_norm = train_cnf_matrix / train_cnf_matrix.sum(axis=1)[:, np.newaxis]
train_df_cm = pd.DataFrame(train_cnf_matrix_norm, index=[0, 1], columns=[0, 1])
sns.heatmap(train_df_cm, annot=True, fmt='.2f', cmap="Blues")
plt.show()

# %% [markdown]
# ## Metrics ROC AUC

# %%
print('AUC %.2f' % roc_auc_score(train['target'], train['preds']))
# Out:
# AUC 1.00

# %% [markdown]
# # Test predictions

# %%
submission = test[['id', 'target']]
submission.to_csv('submission.csv', index=False)
submission.head(10)
# Out:
#                                  id    target
# 0  1c13f2701648e0b0d46d8a2a5a131a53  0.742615
# 1  ba88c155ba898fc8b5099893036ef205  0.507798
# 2  7cbab5cea99169139e7e6d8ff74ebb77  0.421077
# 3  ca820ad57809f62eb7b4d13f5d4371a0  0.620291
# 4  7baaf361537fbd8a1aaa2c97a6d4ccc7  0.152116
# 5  8b3116e5e3e92e971dac305d1a093bf6  0.001765
# 6  35cfd7cab9bfa29bc963d1b8c94dd280  0.012593
# 7  83cf532df8ff4642a3e33a70fffdac37  0.931050
# 8  2e1350fe94ec9f2220bec5245e5e9265  0.717985
# 9  e62020afa72eb54a15725473e3a8475b  0.367421
