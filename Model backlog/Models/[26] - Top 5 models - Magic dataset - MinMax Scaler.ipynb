# %% [markdown]
# # Dependencies

# %%
import warnings
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

from sklearn.svm import SVC, NuSVC
from sklearn.neural_network import MLPClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.feature_selection import VarianceThreshold
from sklearn.discriminant_analysis import QuadraticDiscriminantAnalysis
from sklearn.preprocessing import MinMaxScaler, StandardScaler
from sklearn.model_selection import train_test_split, StratifiedKFold
from sklearn.metrics import confusion_matrix, roc_auc_score, recall_score, precision_score

# Set seeds to make the experiment more reproducible.
from numpy.random import seed
seed(0)

# %matplotlib inline
sns.set_style("whitegrid")
warnings.filterwarnings("ignore")

# %% [markdown]
# # Load data

# %%
train = pd.read_csv('../input/train.csv')
test = pd.read_csv('../input/test.csv')

print('Train set shape:', train.shape)
print('Test set shape:', test.shape)
print('Train set overview:')
display(train.head())
# Out:
# Train set shape: (262144, 258)
# Test set shape: (131073, 257)
# Train set overview:
#                                  id   ...    target
# 0  707b395ecdcbb4dc2eabea00e4d1b179   ...         0
# 1  5880c03c6582a7b42248668e56b4bdec   ...         0
# 2  4ccbcb3d13e5072ff1d9c61afe2c4f77   ...         1
# 3  e350f17a357f12a1941f0837afb7eb8d   ...         0
# 4  a8f910ea6075b6376af079055965ff68   ...         0
#
# [5 rows x 258 columns]

# %% [markdown]
# # Model
#
# ## Model parameters

# %%
N_FOLDS = 11

# %% [markdown]
# ### You can find evaluation metrics for each model on each fold below on this cell output log. (It's hidden to keep the code clean)

# %%
# INITIALIZE VARIABLES
cols = [c for c in train.columns if c not in ['id', 'target', 'wheezy-copper-turtle-magic', 'preds']]
test['target_qda'] = 0
train['preds_qda'] = 0
test['target_knn'] = 0
train['preds_knn'] = 0
test['target_mlp'] = 0
train['preds_mlp'] = 0
test['target_lr'] = 0
train['preds_lr'] = 0
test['target_nusvc'] = 0
train['preds_nusvc'] = 0

# BUILD 512 MODELS
for i in range(512):
    print('wheezy-copper-turtle-magic {}\n'.format(i))
    
    # EXTRACT SUBSET OF DATASET WHERE WHEEZY-MAGIC EQUALS I
    train2 = train[train['wheezy-copper-turtle-magic']==i]
    test2 = test[test['wheezy-copper-turtle-magic']==i]
    idx1 = train2.index
    idx2 = test2.index
    train2.reset_index(drop=True, inplace=True)
    
    # FEATURE SELECTION (USE APPROX 40 OF 255 FEATURES)
    sel = VarianceThreshold(threshold=1.5).fit(train2[cols])
    train3 = sel.transform(train2[cols])
    test3 = sel.transform(test2[cols])
    scaler = MinMaxScaler().fit(train3)
    train3 = scaler.transform(train3)
    test3 = scaler.transform(test3)

    skf = StratifiedKFold(n_splits=N_FOLDS, random_state=0)
    counter = 0

    for train_index, val_index in skf.split(train3, train2['target']):
        counter += 1
        print('Fold {}\n'.format(counter))
        model_names = ['qda', 'knn', 'mlp', 'lr', 'nusvc']
        models = [QuadraticDiscriminantAnalysis(), KNeighborsClassifier(n_neighbors=17, p=2.9), MLPClassifier(), 
                  LogisticRegression(solver='liblinear',penalty='l1',C=0.1), 
                  NuSVC(probability=True, kernel='poly', degree=4, gamma='auto', random_state=4)]
        
        for i in range(len(model_names)):
            model = models[i]
            model_name = model_names[i]
            model.fit(train3[train_index,:], train2.loc[train_index]['target'])

            train_predictions = model.predict(train3[train_index,:])
            val_predictions = model.predict(train3[val_index,:])

            train_auc = roc_auc_score(train2.loc[train_index]['target'], train_predictions) * 100
            val_auc = roc_auc_score(train2.loc[val_index]['target'], val_predictions) * 100
            train_precision = precision_score(train2.loc[train_index]['target'], train_predictions) * 100
            val_precision = precision_score(train2.loc[val_index]['target'], val_predictions) * 100
            train_recall = recall_score(train2.loc[train_index]['target'], train_predictions) * 100
            val_recall = recall_score(train2.loc[val_index]['target'], val_predictions) * 100
            print('-----%s - Train----------' % model_name)
            print('AUC: %.2f Precision: %.2f Recall: %.2f \n' % (train_auc, train_precision, train_recall))
            print('-----%s - Validation-----' % model_name)
            print('AUC: %.2f Precision: %.2f Recall: %.2f \n' % (val_auc, val_precision, val_recall))

            # Make predictions
            train[('preds_%s' % model_name)].loc[idx1] += model.predict_proba(train3)[:,1] / N_FOLDS
            test[('target_%s' % model_name)].loc[idx2] += model.predict_proba(test3)[:,1] / N_FOLDS
# Out:
# wheezy-copper-turtle-magic 0
#
# Fold 1
#
# -----qda - Train----------
# AUC: 97.32 Precision: 97.48 Recall: 97.07
#
# -----qda - Validation-----
# AUC: 81.58 Precision: 82.61 Recall: 79.17
#
# -----knn - Train----------
# AUC: 89.03 Precision: 91.15 Recall: 86.19
#
# -----knn - Validation-----
# AUC: 79.42 Precision: 85.00 Recall: 70.83
#
# -----mlp - Train----------
# AUC: 85.76 Precision: 86.32 Recall: 84.52
#
# -----mlp - Validation-----
# AUC: 81.25 Precision: 100.00 Recall: 62.50
#
# -----lr - Train----------
# AUC: 50.00 Precision: 0.00 Recall: 0.00
#
# -----lr - Validation-----
# AUC: 50.00 Precision: 0.00 Recall: 0.00
#
# -----nusvc - Train----------
# AUC: 92.59 Precision: 91.43 Recall: 93.72
#
# -----nusvc - Validation-----
# AUC: 85.67 Precision: 86.96 Recall: 83.33
#
# Fold 2
#
# -----qda - Train----------
# AUC: 96.90 Precision: 97.06 Recall: 96.65
#
# -----qda - Validation-----
# AUC: 87.75 Precision: 87.50 Recall: 87.50
#
# -----knn - Train----------
# AUC: 87.75 Precision: 92.86 Recall: 81.59
#
# -----knn - Validation-----
# AUC: 81.33 Precision: 94.12 Recall: 66.67
#
# -----mlp - Train----------
# AUC: 86.43 Precision: 84.19 Recall: 89.12
#
# -----mlp - Validation-----
# AUC: 77.67 Precision: 74.07 Recall: 83.33
#
# -----lr - Train----------
# AUC: 50.00 Precision: 0.00 Recall: 0.00
#
# -----lr - Validation-----
# AUC: 50.00 Precision: 0.00 Recall: 0.00
#
# -----nusvc - Train----------
# AUC: 91.35 Precision: 90.53 Recall: 92.05
#
# -----nusvc - Validation-----
# AUC: 79.67 Precision: 76.92 Recall: 83.33
#
# Fold 3
#
# -----qda - Train----------
# AUC: 97.12 Precision: 96.68 Recall: 97.49
#
# -----qda - Validation-----
# AUC: 95.92 Precision: 95.83 Recall: 95.83
#
# -----knn - Train----------
# AUC: 87.78 Precision: 90.54 Recall: 84.10
#
# -----knn - Validation-----
# AUC: 83.67 Precision: 83.33 Recall: 83.33
#
# -----mlp - Train----------
# AUC: 86.98 Precision: 88.26 Recall: 84.94
#
# -----mlp - Validation-----
# AUC: 77.58 Precision: 76.00 Recall: 79.17
#
# -----lr - Train----------
# AUC: 50.00 Precision: 0.00 Recall: 0.00
#
# -----lr - Validation-----
# AUC: 50.00 Precision: 0.00 Recall: 0.00
#
# -----nusvc - Train----------
# AUC: 89.90 Precision: 89.58 Recall: 89.96
#
# -----nusvc - Validation-----
# AUC: 81.75 Precision: 77.78 Recall: 87.50
#
# Fold 4
#
# -----qda - Train----------
# AUC: 96.91 Precision: 96.67 Recall: 97.07
#
# -----qda - Validation-----
# AUC: 95.92 Precision: 95.83 Recall: 95.83
#
# -----knn - Train----------
# AUC: 86.49 Precision: 93.07 Recall: 78.66
#
# -----knn - Validation-----
# AUC: 75.33 Precision: 80.00 Recall: 66.67
#
# -----mlp - Train----------
# AUC: 82.89 Precision: 82.50 Recall: 82.85
#
# -----mlp - Validation-----
# AUC: 77.58 Precision: 76.00 Recall: 79.17
#
# -----lr - Train----------
# AUC: 50.00 Precision: 0.00 Recall: 0.00
#
# -----lr - Validation-----
# AUC: 50.00 Precision: 0.00 Recall: 0.00
#
# -----nusvc - Train----------
# AUC: 93.20 Precision: 92.92 Recall: 93.31
#
# -----nusvc - Validation-----
# AUC: 85.58 Precision: 90.48 Recall: 79.17
#
# Fold 5
#
# -----qda - Train----------
# AUC: 96.90 Precision: 97.06 Recall: 96.65
#
# -----qda - Validation-----
# AUC: 95.83 Precision: 100.00 Recall: 91.67
#
# -----knn - Train----------
# AUC: 87.58 Precision: 90.13 Recall: 84.10
#
# -----knn - Validation-----
# AUC: 85.67 Precision: 86.96 Recall: 83.33
#
# -----mlp - Train----------
# AUC: 85.54 Precision: 86.58 Recall: 83.68
#
# -----mlp - Validation-----
# AUC: 75.75 Precision: 70.00 Recall: 87.50
#
# -----lr - Train----------
# AUC: 50.00 Precision: 0.00 Recall: 0.00
#
# -----lr - Validation-----
# AUC: 50.00 Precision: 0.00 Recall: 0.00
#
# -----nusvc - Train----------
# AUC: 90.52 Precision: 90.04 Recall: 90.79
#
# -----nusvc - Validation-----
# AUC: 81.75 Precision: 77.78 Recall: 87.50
#
# Fold 6
#
# -----qda - Train----------
# AUC: 96.71 Precision: 96.27 Recall: 97.07
#
# -----qda - Validation-----
# AUC: 97.92 Precision: 100.00 Recall: 95.83
#
# -----knn - Train----------
# AUC: 87.55 Precision: 91.63 Recall: 82.43
#
# -----knn - Validation-----
# AUC: 91.75 Precision: 95.45 Recall: 87.50
#
# -----mlp - Train----------
# AUC: 86.34 Precision: 88.79 Recall: 82.85
#
# -----mlp - Validation-----
# AUC: 85.50 Precision: 94.74 Recall: 75.00
#
# -----lr - Train----------
# AUC: 50.00 Precision: 0.00 Recall: 0.00
#
# -----lr - Validation-----
# AUC: 50.00 Precision: 0.00 Recall: 0.00
#
# -----nusvc - Train----------
# AUC: 91.76 Precision: 90.95 Recall: 92.47
#
# -----nusvc - Validation-----
# AUC: 89.67 Precision: 95.24 Recall: 83.33
#
# Fold 7
#
# -----qda - Train----------
# AUC: 97.12 Precision: 96.68 Recall: 97.49
#
# -----qda - Validation-----
# AUC: 95.92 Precision: 95.83 Recall: 95.83
#
# -----knn - Train----------
# AUC: 87.77 Precision: 91.28 Recall: 83.26
#
# -----knn - Validation-----
# AUC: 81.67 Precision: 80.00 Recall: 83.33
#
# -----mlp - Train----------
# AUC: 88.42 Precision: 89.96 Recall: 86.19
#
# -----mlp - Validation-----
# AUC: 73.33 Precision: 76.19 Recall: 66.67
#
# -----lr - Train----------
# AUC: 50.00 Precision: 0.00 Recall: 0.00
#
# -----lr - Validation-----
# AUC: 50.00 Precision: 0.00 Recall: 0.00
#
# -----nusvc - Train----------
# AUC: 91.34 Precision: 91.21 Recall: 91.21
#
# -----nusvc - Validation-----
# AUC: 79.50 Precision: 81.82 Recall: 75.00
#
# Fold 8
#
# -----qda - Train----------
# AUC: 96.91 Precision: 97.06 Recall: 96.65
#
# -----qda - Validation-----
# AUC: 89.58 Precision: 91.30 Recall: 87.50
#
# -----knn - Train----------
# AUC: 86.96 Precision: 90.74 Recall: 82.01
#
# -----knn - Validation-----
# AUC: 91.67 Precision: 91.67 Recall: 91.67
#
# -----mlp - Train----------
# AUC: 83.53 Precision: 83.26 Recall: 83.26
#
# -----mlp - Validation-----
# AUC: 70.83 Precision: 70.83 Recall: 70.83
#
# -----lr - Train----------
# AUC: 50.00 Precision: 0.00 Recall: 0.00
#
# -----lr - Validation-----
# AUC: 50.00 Precision: 0.00 Recall: 0.00
#
# -----nusvc - Train----------
# AUC: 91.56 Precision: 91.25 Recall: 91.63
#
# -----nusvc - Validation-----
# AUC: 75.00 Precision: 73.08 Recall: 79.17
#
# Fold 9
#
# -----qda - Train----------
# AUC: 97.74 Precision: 97.50 Recall: 97.91
#
# -----qda - Validation-----
# AUC: 87.50 Precision: 90.91 Recall: 83.33
#
# -----knn - Train----------
# AUC: 89.24 Precision: 91.93 Recall: 85.77
#
# -----knn - Validation-----
# AUC: 79.17 Precision: 81.82 Recall: 75.00
#
# -----mlp - Train----------
# AUC: 87.23 Precision: 87.66 Recall: 86.19
#
# -----mlp - Validation-----
# AUC: 81.25 Precision: 80.00 Recall: 83.33
#
# -----lr - Train----------
# AUC: 50.00 Precision: 0.00 Recall: 0.00
#
# -----lr - Validation-----
# AUC: 50.00 Precision: 0.00 Recall: 0.00
#
# -----nusvc - Train----------
# AUC: 94.07 Precision: 92.00 Recall: 96.23
#
# -----nusvc - Validation-----
# AUC: 87.50 Precision: 87.50 Recall: 87.50
#
# Fold 10
#
# -----qda - Train----------
# AUC: 96.71 Precision: 96.65 Recall: 96.65
#
# -----qda - Validation-----
# AUC: 93.75 Precision: 95.65 Recall: 91.67
#
# -----knn - Train----------
# AUC: 87.37 Precision: 90.83 Recall: 82.85
#
# -----knn - Validation-----
# AUC: 75.00 Precision: 87.50 Recall: 58.33
#
# -----mlp - Train----------
# AUC: 87.46 Precision: 86.78 Recall: 87.87
#
# -----mlp - Validation-----
# AUC: 85.42 Precision: 86.96 Recall: 83.33
#
# -----lr - Train----------
# AUC: 50.00 Precision: 0.00 Recall: 0.00
#
# -----lr - Validation-----
# AUC: 50.00 Precision: 0.00 Recall: 0.00
#
# -----nusvc - Train----------
# AUC: 91.37 Precision: 90.53 Recall: 92.05
#
# -----nusvc - Validation-----
# AUC: 85.42 Precision: 86.96 Recall: 83.33
#
# Fold 11
#
# -----qda - Train----------
# AUC: 96.71 Precision: 96.67 Recall: 96.67
#
# -----qda - Validation-----
# AUC: 97.83 Precision: 100.00 Recall: 95.65
#
# -----knn - Train----------
# AUC: 87.21 Precision: 90.45 Recall: 82.92
#
# -----knn - Validation-----
# AUC: 89.49 Precision: 84.62 Recall: 95.65
#
# -----mlp - Train----------
# AUC: 83.06 Precision: 78.34 Recall: 90.42
#
# -----mlp - Validation-----
# AUC: 74.73 Precision: 68.97 Recall: 86.96
#
# -----lr - Train----------
# AUC: 50.00 Precision: 0.00 Recall: 0.00
#
# -----lr - Validation-----
# AUC: 50.00 Precision: 0.00 Recall: 0.00
#
# -----nusvc - Train----------
# AUC: 91.38 Precision: 90.91 Recall: 91.67
#
# -----nusvc - Validation-----
# AUC: 85.14 Precision: 83.33 Recall: 86.96
#
# wheezy-copper-turtle-magic 1
#
# Fold 1
#
# -----qda - Train----------
# AUC: 96.60 Precision: 94.81 Recall: 98.21
#
# -----qda - Validation-----
# AUC: 91.58 Precision: 88.00 Recall: 95.65
#
# -----knn - Train----------
# AUC: 93.19 Precision: 90.30 Recall: 95.96
#
# -----knn - Validation-----
# AUC: 83.15 Precision: 77.78 Recall: 91.30
#
# -----mlp - Train----------
# AUC: 86.51 Precision: 87.79 Recall: 83.86
#
# -----mlp - Validation-----
# AUC: 72.19 Precision: 75.00 Recall: 65.22
#
# -----lr - Train----------
# AUC: 57.96 Precision: 85.71 Recall: 18.83
#
# -----lr - Validation-----
# AUC: 56.61 Precision: 80.00 Recall: 17.39
#
# -----nusvc - Train----------
# AUC: 90.48 Precision: 90.13 Recall: 90.13
#
# -----nusvc - Validation-----
# AUC: 76.63 Precision: 75.00 Recall: 78.26
#
# Fold 2
#
# -----qda - Train----------
# AUC: 96.17 Precision: 94.37 Recall: 97.76
#
# -----qda - Validation-----
# AUC: 97.83 Precision: 100.00 Recall: 95.65
#
# -----knn - Train----------
# AUC: 91.56 Precision: 86.75 Recall: 96.86
#
# -----knn - Validation-----
# AUC: 95.83 Precision: 92.00 Recall: 100.00
#
# -----mlp - Train----------
# AUC: 85.20 Precision: 86.73 Recall: 82.06
#
# -----mlp - Validation-----
# AUC: 82.97 Precision: 82.61 Recall: 82.61
#
# -----lr - Train----------
# AUC: 52.26 Precision: 91.67 Recall: 4.93
#
# -----lr - Validation-----
# AUC: 54.35 Precision: 100.00 Recall: 8.70
#
# -----nusvc - Train----------
# AUC: 89.43 Precision: 88.50 Recall: 89.69
#
# -----nusvc - Validation-----
# AUC: 87.23 Precision: 86.96 Recall: 86.96
#
# Fold 3
#
# -----qda - Train----------
# AUC: 96.39 Precision: 94.40 Recall: 98.21
#
# -----qda - Validation-----
# AUC: 93.57 Precision: 95.45 Recall: 91.30
#
# -----knn - Train----------
# AUC: 92.76 Precision: 89.87 Recall: 95.52
#
# -----knn - Validation-----
# AUC: 91.67 Precision: 85.19 Recall: 100.00
#
# -----mlp - Train----------
# AUC: 83.81 Precision: 87.44 Recall: 78.03
#
# -----mlp - Validation-----
# AUC: 91.49 Precision: 91.30 Recall: 91.30
#
# -----lr - Train----------
# AUC: 56.85 Precision: 82.61 Recall: 17.04
#
# -----lr - Validation-----
# AUC: 54.35 Precision: 100.00 Recall: 8.70
#
# -----nusvc - Train----------
# AUC: 88.95 Precision: 89.09 Recall: 87.89
#
# -----nusvc - Validation-----
# AUC: 93.66 Precision: 91.67 Recall: 95.65
#
# Fold 4
#
# -----qda - Train----------
# AUC: 96.60 Precision: 94.81 Recall: 98.21
#
# -----qda - Validation-----
# AUC: 87.32 Precision: 84.00 Recall: 91.30
#
# -----knn - Train----------
# AUC: 91.68 Precision: 88.66 Recall: 94.62
#
# -----knn - Validation-----
# AUC: 87.32 Precision: 84.00 Recall: 91.30
#
# -----mlp - Train----------
# AUC: 87.02 Precision: 86.55 Recall: 86.55
#
# -----mlp - Validation-----
# AUC: 78.99 Precision: 72.41 Recall: 91.30
#
# -----lr - Train----------
# AUC: 52.91 Precision: 100.00 Recall: 5.83
#
# -----lr - Validation-----
# AUC: 58.70 Precision: 100.00 Recall: 17.39
#
# -----nusvc - Train----------
# AUC: 90.28 Precision: 89.73 Recall: 90.13
#
# -----nusvc - Validation-----
# AUC: 83.06 Precision: 80.00 Recall: 86.96
#
# Fold 5
#
# -----qda - Train----------
# AUC: 96.59 Precision: 95.22 Recall: 97.77
#
# -----qda - Validation-----
# AUC: 87.12 Precision: 83.33 Recall: 90.91
#
# -----knn - Train----------
# AUC: 91.49 Precision: 88.33 Recall: 94.64
#
# -----knn - Validation-----
# AUC: 85.04 Precision: 80.00 Recall: 90.91
#
# -----mlp - Train----------
# AUC: 85.97 Precision: 85.65 Recall: 85.27
#
# -----mlp - Validation-----
# AUC: 79.92 Precision: 88.24 Recall: 68.18
#
# -----lr - Train----------
# AUC: 50.89 Precision: 100.00 Recall: 1.79
#
# -----lr - Validation-----
# AUC: 52.27 Precision: 100.00 Recall: 4.55
#
# -----nusvc - Train----------
# AUC: 88.57 Precision: 88.00 Recall: 88.39
#
# -----nusvc - Validation-----
# AUC: 73.48 Precision: 77.78 Recall: 63.64
#
# Fold 6
#
# -----qda - Train----------
# AUC: 96.18 Precision: 94.40 Recall: 97.77
#
# -----qda - Validation-----
# AUC: 93.18 Precision: 100.00 Recall: 86.36
#
# -----knn - Train----------
# AUC: 93.02 Precision: 89.30 Recall: 96.88
#
# -----knn - Validation-----
# AUC: 85.04 Precision: 80.00 Recall: 90.91
#
# -----mlp - Train----------
# AUC: 86.96 Precision: 88.68 Recall: 83.93
#
# -----mlp - Validation-----
# AUC: 78.22 Precision: 77.27 Recall: 77.27
#
# -----lr - Train----------
# AUC: 57.28 Precision: 82.00 Recall: 18.30
#
# -----lr - Validation-----
# AUC: 54.92 Precision: 66.67 Recall: 18.18
#
# -----nusvc - Train----------
# AUC: 89.43 Precision: 88.89 Recall: 89.29
#
# -----nusvc - Validation-----
# AUC: 82.58 Precision: 81.82 Recall: 81.82
#
# Fold 7
#
# -----qda - Train----------
# AUC: 96.80 Precision: 95.63 Recall: 97.77
#
# -----qda - Validation-----
# AUC: 82.58 Precision: 81.82 Recall: 81.82
#
# -----knn - Train----------
# AUC: 91.46 Precision: 88.98 Recall: 93.75
#
# -----knn - Validation-----
# AUC: 89.20 Precision: 86.96 Recall: 90.91
#
# -----mlp - Train----------
# AUC: 84.39 Precision: 85.51 Recall: 81.70
#
# -----mlp - Validation-----
# AUC: 88.83 Precision: 94.74 Recall: 81.82
#
# -----lr - Train----------
# AUC: 56.35 Precision: 83.33 Recall: 15.62
#
# -----lr - Validation-----
# AUC: 48.11 Precision: 33.33 Recall: 4.55
#
# -----nusvc - Train----------
# AUC: 89.45 Precision: 88.55 Recall: 89.73
#
# -----nusvc - Validation-----
# AUC: 89.20 Precision: 86.96 Recall: 90.91
#
# Fold 8
#
# -----qda - Train----------
# AUC: 96.62 Precision: 94.44 Recall: 98.66
#
# -----qda - Validation-----
# AUC: 93.37 Precision: 95.24 Recall: 90.91
#
# -----knn - Train----------
# AUC: 92.57 Precision: 89.21 Recall: 95.98
#
# -----knn - Validation-----
# AUC: 84.85 Precision: 82.61 Recall: 86.36
#
# -----mlp - Train----------
# AUC: 86.99 Precision: 83.27 Recall: 91.07
#
# -----mlp - Validation-----
# AUC: 86.93 Precision: 86.36 Recall: 86.36
#
# -----lr - Train----------
# AUC: 55.16 Precision: 92.59 Recall: 11.16
#
# -----lr - Validation-----
# AUC: 50.00 Precision: 0.00 Recall: 0.00
#
# -----nusvc - Train----------
# AUC: 89.63 Precision: 89.64 Recall: 88.84
#
# -----nusvc - Validation-----
# AUC: 86.74 Precision: 90.00 Recall: 81.82
#
# Fold 9
#
# -----qda - Train----------
# AUC: 96.61 Precision: 94.83 Recall: 98.21
#
# -----qda - Validation-----
# AUC: 91.29 Precision: 90.91 Recall: 90.91
#
# -----knn - Train----------
# AUC: 92.54 Precision: 89.87 Recall: 95.09
#
# -----knn - Validation-----
# AUC: 91.29 Precision: 90.91 Recall: 90.91
#
# -----mlp - Train----------
# AUC: 87.08 Precision: 85.96 Recall: 87.50
#
# -----mlp - Validation-----
# AUC: 67.80 Precision: 62.96 Recall: 77.27
#
# -----lr - Train----------
# AUC: 55.68 Precision: 82.05 Recall: 14.29
#
# -----lr - Validation-----
# AUC: 52.46 Precision: 66.67 Recall: 9.09
#
# -----nusvc - Train----------
# AUC: 88.74 Precision: 89.45 Recall: 87.05
#
# -----nusvc - Validation-----
# AUC: 74.43 Precision: 67.86 Recall: 86.36
#
# Fold 10
#
# -----qda - Train----------
# AUC: 97.04 Precision: 95.26 Recall: 98.66
#
# -----qda - Validation-----
# AUC: 95.83 Precision: 91.67 Recall: 100.00
#
# -----knn - Train----------
# AUC: 92.19 Precision: 87.85 Recall: 96.88
#
# -----knn - Validation-----
# AUC: 95.64 Precision: 95.45 Recall: 95.45
#
# -----mlp - Train----------
# AUC: 85.25 Precision: 86.45 Recall: 82.59
#
# -----mlp - Validation-----
# AUC: 88.83 Precision: 94.74 Recall: 81.82
#
# -----lr - Train----------
# AUC: 50.00 Precision: 0.00 Recall: 0.00
#
# -----lr - Validation-----
# AUC: 52.27 Precision: 100.00 Recall: 4.55
#
# -----nusvc - Train----------
# AUC: 87.90 Precision: 87.84 Recall: 87.05
#
# -----nusvc - Validation-----
# AUC: 89.20 Precision: 86.96 Recall: 90.91
#
# Fold 11
#
# -----qda - Train----------
# AUC: 96.83 Precision: 94.85 Recall: 98.66
#
# -----qda - Validation-----
# AUC: 95.64 Precision: 95.45 Recall: 95.45
#
# -----knn - Train----------
# AUC: 92.38 Precision: 88.52 Recall: 96.43
#
# -----knn - Validation-----
# AUC: 87.12 Precision: 83.33 Recall: 90.91
#
# -----mlp - Train----------
# AUC: 85.30 Precision: 85.45 Recall: 83.93
#
# -----mlp - Validation-----
# AUC: 86.36 Precision: 100.00 Recall: 72.73
#
# -----lr - Train----------
# AUC: 54.82 Precision: 76.92 Recall: 13.39
#
# -----lr - Validation-----
# AUC: 54.55 Precision: 100.00 Recall: 9.09
#
# -----nusvc - Train----------
# AUC: 89.70 Precision: 87.93 Recall: 91.07
#
# -----nusvc - Validation-----
# AUC: 82.20 Precision: 88.89 Recall: 72.73
#
# wheezy-copper-turtle-magic 2
#
# Fold 1
#
# -----qda - Train----------
# AUC: 97.77 Precision: 97.73 Recall: 97.73
#
# -----qda - Validation-----
# AUC: 93.48 Precision: 95.45 Recall: 91.30
#
# -----knn - Train----------
# AUC: 87.21 Precision: 90.95 Recall: 82.27
#
# -----knn - Validation-----
# AUC: 71.74 Precision: 77.78 Recall: 60.87
#
# -----mlp - Train----------
# AUC: 83.08 Precision: 82.14 Recall: 83.64
#
# -----mlp - Validation-----
# AUC: 76.09 Precision: 80.00 Recall: 69.57
#
# -----lr - Train----------
# AUC: 50.00 Precision: 0.00 Recall: 0.00
#
# -----lr - Validation-----
# AUC: 50.00 Precision: 0.00 Recall: 0.00
#
# -----nusvc - Train----------
# AUC: 92.16 Precision: 93.84 Recall: 90.00
#
# -----nusvc - Validation-----
# AUC: 84.78 Precision: 86.36 Recall: 82.61
#
# Fold 2
#
# -----qda - Train----------
# AUC: 97.34 Precision: 96.86 Recall: 97.74
#
# -----qda - Validation-----
# AUC: 95.55 Precision: 95.45 Recall: 95.45
#
# -----knn - Train----------
# AUC: 87.00 Precision: 92.23 Recall: 80.54
#
# -----knn - Validation-----
# AUC: 82.02 Precision: 88.89 Recall: 72.73
#
# -----mlp - Train----------
# AUC: 82.01 Precision: 80.97 Recall: 82.81
#
# -----mlp - Validation-----
# AUC: 75.40 Precision: 78.95 Recall: 68.18
#
# -----lr - Train----------
# AUC: 50.00 Precision: 0.00 Recall: 0.00
#
# -----lr - Validation-----
# AUC: 50.00 Precision: 0.00 Recall: 0.00
#
# -----nusvc - Train----------
# AUC: 92.03 Precision: 90.39 Recall: 93.67
#
# -----nusvc - Validation-----
# AUC: 71.05 Precision: 71.43 Recall: 68.18
#
# Fold 3
#
# -----qda - Train----------
# AUC: 97.78 Precision: 97.31 Recall: 98.19
#
# -----qda - Validation-----
# AUC: 88.83 Precision: 90.48 Recall: 86.36
#
# -----knn - Train----------
# AUC: 86.10 Precision: 91.62 Recall: 79.19
#
# -----knn - Validation-----
# AUC: 79.74 Precision: 88.24 Recall: 68.18
#
# -----mlp - Train----------
# AUC: 81.93 Precision: 84.31 Recall: 77.83
#
# -----mlp - Validation-----
# AUC: 73.22 Precision: 75.00 Recall: 68.18
#
# -----lr - Train----------
# AUC: 50.00 Precision: 0.00 Recall: 0.00
#
# -----lr - Validation-----
# AUC: 50.00 Precision: 0.00 Recall: 0.00
#
# -----nusvc - Train----------
# AUC: 90.65 Precision: 91.24 Recall: 89.59
#
# -----nusvc - Validation-----
# AUC: 82.11 Precision: 85.00 Recall: 77.27
#
# Fold 4
#
# -----qda - Train----------
# AUC: 97.55 Precision: 97.73 Recall: 97.29
#
# -----qda - Validation-----
# AUC: 91.11 Precision: 90.91 Recall: 90.91
#
# -----knn - Train----------
# AUC: 88.37 Precision: 91.63 Recall: 84.16
#
# -----knn - Validation-----
# AUC: 88.93 Precision: 86.96 Recall: 90.91
#
# -----mlp - Train----------
# AUC: 81.59 Precision: 80.00 Recall: 83.26
#
# -----mlp - Validation-----
# AUC: 71.15 Precision: 69.57 Recall: 72.73
#
# -----lr - Train----------
# AUC: 50.00 Precision: 0.00 Recall: 0.00
#
# -----lr - Validation-----
# AUC: 50.00 Precision: 0.00 Recall: 0.00
#
# -----nusvc - Train----------
# AUC: 92.45 Precision: 91.93 Recall: 92.76
#
# -----nusvc - Validation-----
# AUC: 80.14 Precision: 76.00 Recall: 86.36
#
# Fold 5
#
# -----qda - Train----------
# AUC: 97.78 Precision: 97.74 Recall: 97.74
#
# -----qda - Validation-----
# AUC: 93.38 Precision: 91.30 Recall: 95.45
#
# -----knn - Train----------
# AUC: 85.69 Precision: 89.05 Recall: 81.00
#
# -----knn - Validation-----
# AUC: 86.56 Precision: 90.00 Recall: 81.82
#
# -----mlp - Train----------
# AUC: 81.54 Precision: 81.65 Recall: 80.54
#
# -----mlp - Validation-----
# AUC: 75.59 Precision: 73.91 Recall: 77.27
#
# -----lr - Train----------
# AUC: 50.00 Precision: 0.00 Recall: 0.00
#
# -----lr - Validation-----
# AUC: 50.00 Precision: 0.00 Recall: 0.00
#
# -----nusvc - Train----------
# AUC: 92.45 Precision: 91.93 Recall: 92.76
#
# -----nusvc - Validation-----
# AUC: 77.77 Precision: 77.27 Recall: 77.27
#
# Fold 6
#
# -----qda - Train----------
# AUC: 98.44 Precision: 98.64 Recall: 98.19
#
# -----qda - Validation-----
# AUC: 88.93 Precision: 86.96 Recall: 90.91
#
# -----knn - Train----------
# AUC: 89.03 Precision: 92.57 Recall: 84.62
#
# -----knn - Validation-----
# AUC: 77.67 Precision: 80.00 Recall: 72.73
#
# -----mlp - Train----------
# AUC: 82.59 Precision: 85.22 Recall: 78.28
#
# -----mlp - Validation-----
# AUC: 71.25 Precision: 68.00 Recall: 77.27
#
# -----lr - Train----------
# AUC: 50.00 Precision: 0.00 Recall: 0.00
#
# -----lr - Validation-----
# AUC: 50.00 Precision: 0.00 Recall: 0.00
#
# -----nusvc - Train----------
# AUC: 93.32 Precision: 93.61 Recall: 92.76
#
# -----nusvc - Validation-----
# AUC: 75.69 Precision: 72.00 Recall: 81.82
#
# Fold 7
#
# -----qda - Train----------
# AUC: 97.55 Precision: 97.73 Recall: 97.29
#
# -----qda - Validation-----
# AUC: 93.48 Precision: 88.00 Recall: 100.00
#
# -----knn - Train----------
# AUC: 87.46 Precision: 91.46 Recall: 82.35
#
# -----knn - Validation-----
# AUC: 84.19 Precision: 94.12 Recall: 72.73
#
# -----mlp - Train----------
# AUC: 80.64 Precision: 81.02 Recall: 79.19
#
# -----mlp - Validation-----
# AUC: 70.95 Precision: 73.68 Recall: 63.64
#
# -----lr - Train----------
# AUC: 50.00 Precision: 0.00 Recall: 0.00
#
# -----lr - Validation-----
# AUC: 50.00 Precision: 0.00 Recall: 0.00
#
# -----nusvc - Train----------
# AUC: 91.36 Precision: 89.91 Recall: 92.76
#
# -----nusvc - Validation-----
# AUC: 80.04 Precision: 78.26 Recall: 81.82
#
# Fold 8
#
# -----qda - Train----------
# AUC: 97.56 Precision: 97.30 Recall: 97.74
#
# -----qda - Validation-----
# AUC: 93.28 Precision: 95.24 Recall: 90.91
#
# -----knn - Train----------
# AUC: 86.35 Precision: 90.40 Recall: 81.00
#
# -----knn - Validation-----
# AUC: 88.64 Precision: 100.00 Recall: 77.27
#
# -----mlp - Train----------
# AUC: 78.72 Precision: 76.37 Recall: 81.90
#
# -----mlp - Validation-----
# AUC: 86.66 Precision: 86.36 Recall: 86.36
#
# -----lr - Train----------
# AUC: 50.00 Precision: 0.00 Recall: 0.00
#
# -----lr - Validation-----
# AUC: 50.00 Precision: 0.00 Recall: 0.00
#
# -----nusvc - Train----------
# AUC: 92.24 Precision: 91.15 Recall: 93.21
#
# -----nusvc - Validation-----
# AUC: 90.91 Precision: 100.00 Recall: 81.82
#
# Fold 9
#
# -----qda - Train----------
# AUC: 98.24 Precision: 97.33 Recall: 99.10
#
# -----qda - Validation-----
# AUC: 93.18 Precision: 100.00 Recall: 86.36
#
# -----knn - Train----------
# AUC: 85.87 Precision: 91.58 Recall: 78.73
#
# -----knn - Validation-----
# AUC: 84.19 Precision: 94.12 Recall: 72.73
#
# -----mlp - Train----------
# AUC: 81.96 Precision: 83.02 Recall: 79.64
#
# -----mlp - Validation-----
# AUC: 71.05 Precision: 71.43 Recall: 68.18
#
# -----lr - Train----------
# AUC: 50.00 Precision: 0.00 Recall: 0.00
#
# -----lr - Validation-----
# AUC: 50.00 Precision: 0.00 Recall: 0.00
#
# -----nusvc - Train----------
# AUC: 92.71 Precision: 90.52 Recall: 95.02
#
# -----nusvc - Validation-----
# AUC: 77.87 Precision: 75.00 Recall: 81.82
#
# Fold 10
#
# -----qda - Train----------
# AUC: 97.55 Precision: 97.73 Recall: 97.29
#
# -----qda - Validation-----
# AUC: 97.83 Precision: 95.65 Recall: 100.00
#
# -----knn - Train----------
# AUC: 85.88 Precision: 91.15 Recall: 79.19
#
# -----knn - Validation-----
# AUC: 82.02 Precision: 88.89 Recall: 72.73
#
# -----mlp - Train----------
# AUC: 83.07 Precision: 84.04 Recall: 81.00
#
# -----mlp - Validation-----
# AUC: 73.32 Precision: 72.73 Recall: 72.73
#
# -----lr - Train----------
# AUC: 50.00 Precision: 0.00 Recall: 0.00
#
# -----lr - Validation-----
# AUC: 50.00 Precision: 0.00 Recall: 0.00
#
# -----nusvc - Train----------
# AUC: 91.79 Precision: 91.07 Recall: 92.31
#
# -----nusvc - Validation-----
# AUC: 77.96 Precision: 73.08 Recall: 86.36
#
# Fold 11
#
# -----qda - Train----------
# AUC: 97.12 Precision: 96.85 Recall: 97.29
#
# -----qda - Validation-----
# AUC: 97.73 Precision: 95.65 Recall: 100.00
#
# -----knn - Train----------
# AUC: 87.06 Precision: 89.76 Recall: 83.26
#
# -----knn - Validation-----
# AUC: 79.55 Precision: 88.24 Recall: 68.18
#
# -----mlp - Train----------
# AUC: 83.44 Precision: 80.67 Recall: 86.88
#
# -----mlp - Validation-----
# AUC: 77.27 Precision: 75.00 Recall: 81.82
#
# -----lr - Train----------
# AUC: 50.00 Precision: 0.00 Recall: 0.00
#
# -----lr - Validation-----
# AUC: 50.00 Precision: 0.00 Recall: 0.00
#
# -----nusvc - Train----------
# AUC: 91.40 Precision: 89.22 Recall: 93.67
#
# -----nusvc - Validation-----
# AUC: 84.09 Precision: 82.61 Recall: 86.36
#
# wheezy-copper-turtle-magic 3
#
# Fold 1
#
# -----qda - Train----------
# AUC: 98.79 Precision: 99.21 Recall: 98.43
#
# -----qda - Validation-----
# AUC: 98.08 Precision: 100.00 Recall: 96.15
#
# -----knn - Train----------
# AUC: 84.93 Precision: 79.87 Recall: 96.47
#
# -----knn - Validation-----
# AUC: 87.50 Precision: 81.25 Recall: 100.00
#
# -----mlp - Train----------
# AUC: 84.37 Precision: 82.14 Recall: 90.20
#
# -----mlp - Validation-----
# AUC: 82.05 Precision: 84.00 Recall: 80.77
#
# -----lr - Train----------
# AUC: 50.21 Precision: 52.36 Recall: 100.00
#
# -----lr - Validation-----
# AUC: 50.00 Precision: 52.00 Recall: 100.00
#
# -----nusvc - Train----------
# AUC: 92.94 Precision: 92.02 Recall: 94.90
#
# -----nusvc - Validation-----
# AUC: 89.90 Precision: 88.89 Recall: 92.31
#
# Fold 2
#
# -----qda - Train----------
# AUC: 98.79 Precision: 99.21 Recall: 98.43
#
# -----qda - Validation-----
# AUC: 93.91 Precision: 92.59 Recall: 96.15
#
# -----knn - Train----------
# AUC: 87.06 Precision: 82.33 Recall: 96.86
#
# -----knn - Validation-----
# AUC: 79.33 Precision: 73.53 Recall: 96.15
#
# -----mlp - Train----------
# AUC: 83.87 Precision: 83.15 Recall: 87.06
#
# -----mlp - Validation-----
# AUC: 71.79 Precision: 71.43 Recall: 76.92
#
# -----lr - Train----------
# AUC: 50.00 Precision: 52.25 Recall: 100.00
#
# -----lr - Validation-----
# AUC: 52.08 Precision: 53.06 Recall: 100.00
#
# -----nusvc - Train----------
# AUC: 90.77 Precision: 91.34 Recall: 90.98
#
# -----nusvc - Validation-----
# AUC: 77.56 Precision: 74.19 Recall: 88.46
#
# Fold 3
#
# -----qda - Train----------
# AUC: 98.39 Precision: 99.20 Recall: 97.65
#
# -----qda - Validation-----
# AUC: 93.91 Precision: 92.59 Recall: 96.15
#
# -----knn - Train----------
# AUC: 87.52 Precision: 83.33 Recall: 96.08
#
# -----knn - Validation-----
# AUC: 81.57 Precision: 77.42 Recall: 92.31
#
# -----mlp - Train----------
# AUC: 82.23 Precision: 81.65 Recall: 85.49
#
# -----mlp - Validation-----
# AUC: 69.55 Precision: 67.74 Recall: 80.77
#
# -----lr - Train----------
# AUC: 50.00 Precision: 52.25 Recall: 100.00
#
# -----lr - Validation-----
# AUC: 50.00 Precision: 52.00 Recall: 100.00
#
# -----nusvc - Train----------
# AUC: 90.77 Precision: 91.34 Recall: 90.98
#
# -----nusvc - Validation-----
# AUC: 75.80 Precision: 75.00 Recall: 80.77
#
# Fold 4
#
# -----qda - Train----------
# AUC: 98.59 Precision: 99.21 Recall: 98.04
#
# -----qda - Validation-----
# AUC: 93.75 Precision: 89.66 Recall: 100.00
#
# -----knn - Train----------
# AUC: 85.79 Precision: 80.92 Recall: 96.47
#
# -----knn - Validation-----
# AUC: 93.91 Precision: 92.59 Recall: 96.15
#
# -----mlp - Train----------
# AUC: 79.77 Precision: 79.40 Recall: 83.14
#
# -----mlp - Validation-----
# AUC: 78.53 Precision: 89.47 Recall: 65.38
#
# -----lr - Train----------
# AUC: 50.21 Precision: 52.36 Recall: 100.00
#
# -----lr - Validation-----
# AUC: 50.00 Precision: 52.00 Recall: 100.00
#
# -----nusvc - Train----------
# AUC: 91.61 Precision: 92.46 Recall: 91.37
#
# -----nusvc - Validation-----
# AUC: 84.29 Precision: 90.91 Recall: 76.92
#
# Fold 5
#
# -----qda - Train----------
# AUC: 98.82 Precision: 100.00 Recall: 97.65
#
# -----qda - Validation-----
# AUC: 89.38 Precision: 86.21 Recall: 96.15
#
# -----knn - Train----------
# AUC: 85.61 Precision: 80.46 Recall: 96.86
#
# -----knn - Validation-----
# AUC: 70.07 Precision: 66.67 Recall: 92.31
#
# -----mlp - Train----------
# AUC: 82.70 Precision: 79.86 Recall: 90.20
#
# -----mlp - Validation-----
# AUC: 64.55 Precision: 64.52 Recall: 76.92
#
# -----lr - Train----------
# AUC: 50.21 Precision: 52.25 Recall: 100.00
#
# -----lr - Validation-----
# AUC: 50.00 Precision: 53.06 Recall: 100.00
#
# -----nusvc - Train----------
# AUC: 92.77 Precision: 91.98 Recall: 94.51
#
# -----nusvc - Validation-----
# AUC: 70.82 Precision: 70.00 Recall: 80.77
#
# Fold 6
#
# -----qda - Train----------
# AUC: 98.59 Precision: 99.21 Recall: 98.04
#
# -----qda - Validation-----
# AUC: 97.83 Precision: 96.30 Recall: 100.00
#
# -----knn - Train----------
# AUC: 88.19 Precision: 83.96 Recall: 96.47
#
# -----knn - Validation-----
# AUC: 82.61 Precision: 76.47 Recall: 100.00
#
# -----mlp - Train----------
# AUC: 79.97 Precision: 81.53 Recall: 79.61
#
# -----mlp - Validation-----
# AUC: 85.54 Precision: 85.19 Recall: 88.46
#
# -----lr - Train----------
# AUC: 50.21 Precision: 52.25 Recall: 100.00
#
# -----lr - Validation-----
# AUC: 50.00 Precision: 53.06 Recall: 100.00
#
# -----nusvc - Train----------
# AUC: 92.27 Precision: 90.07 Recall: 96.08
#
# -----nusvc - Validation-----
# AUC: 85.54 Precision: 85.19 Recall: 88.46
#
# Fold 7
#
# -----qda - Train----------
# AUC: 98.60 Precision: 99.21 Recall: 98.05
#
# -----qda - Validation-----
# AUC: 93.83 Precision: 95.83 Recall: 92.00
#
# -----knn - Train----------
# AUC: 87.83 Precision: 84.14 Recall: 95.31
#
# -----knn - Validation-----
# AUC: 89.30 Precision: 85.71 Recall: 96.00
#
# -----mlp - Train----------
# AUC: 81.93 Precision: 81.82 Recall: 84.38
#
# -----mlp - Validation-----
# AUC: 76.96 Precision: 76.92 Recall: 80.00
#
# -----lr - Train----------
# AUC: 50.21 Precision: 52.35 Recall: 100.00
#
# -----lr - Validation-----
# AUC: 50.00 Precision: 52.08 Recall: 100.00
#
# -----nusvc - Train----------
# AUC: 90.77 Precision: 90.73 Recall: 91.80
#
# -----nusvc - Validation-----
# AUC: 79.13 Precision: 80.00 Recall: 80.00
#
# Fold 8
#
# -----qda - Train----------
# AUC: 98.58 Precision: 98.82 Recall: 98.44
#
# -----qda - Validation-----
# AUC: 93.83 Precision: 95.83 Recall: 92.00
#
# -----knn - Train----------
# AUC: 86.95 Precision: 82.77 Recall: 95.70
#
# -----knn - Validation-----
# AUC: 89.48 Precision: 88.46 Recall: 92.00
#
# -----mlp - Train----------
# AUC: 82.16 Precision: 82.38 Recall: 83.98
#
# -----mlp - Validation-----
# AUC: 77.13 Precision: 79.17 Recall: 76.00
#
# -----lr - Train----------
# AUC: 50.21 Precision: 52.35 Recall: 100.00
#
# -----lr - Validation-----
# AUC: 50.00 Precision: 52.08 Recall: 100.00
#
# -----nusvc - Train----------
# AUC: 92.16 Precision: 91.29 Recall: 94.14
#
# -----nusvc - Validation-----
# AUC: 85.48 Precision: 87.50 Recall: 84.00
#
# Fold 9
#
# -----qda - Train----------
# AUC: 99.01 Precision: 99.60 Recall: 98.44
#
# -----qda - Validation-----
# AUC: 91.83 Precision: 95.65 Recall: 88.00
#
# -----knn - Train----------
# AUC: 87.60 Precision: 83.62 Recall: 95.70
#
# -----knn - Validation-----
# AUC: 76.61 Precision: 73.33 Recall: 88.00
#
# -----mlp - Train----------
# AUC: 81.19 Precision: 82.03 Recall: 82.03
#
# -----mlp - Validation-----
# AUC: 72.96 Precision: 75.00 Recall: 72.00
#
# -----lr - Train----------
# AUC: 50.21 Precision: 52.35 Recall: 100.00
#
# -----lr - Validation-----
# AUC: 50.00 Precision: 52.08 Recall: 100.00
#
# -----nusvc - Train----------
# AUC: 91.61 Precision: 91.83 Recall: 92.19
#
# -----nusvc - Validation-----
# AUC: 79.13 Precision: 80.00 Recall: 80.00
#
# Fold 10
#
# -----qda - Train----------
# AUC: 98.61 Precision: 99.60 Recall: 97.66
#
# -----qda - Validation-----
# AUC: 93.83 Precision: 95.83 Recall: 92.00
#
# -----knn - Train----------
# AUC: 89.09 Precision: 85.66 Recall: 95.70
#
# -----knn - Validation-----
# AUC: 89.48 Precision: 88.46 Recall: 92.00
#
# -----mlp - Train----------
# AUC: 83.14 Precision: 82.71 Recall: 85.94
#
# -----mlp - Validation-----
# AUC: 81.13 Precision: 80.77 Recall: 84.00
#
# -----lr - Train----------
# AUC: 50.21 Precision: 52.35 Recall: 100.00
#
# -----lr - Validation-----
# AUC: 50.00 Precision: 52.08 Recall: 100.00
#
# -----nusvc - Train----------
# AUC: 92.69 Precision: 94.00 Recall: 91.80
#
# -----nusvc - Validation-----
# AUC: 85.30 Precision: 84.62 Recall: 88.00
#
# Fold 11
#
# -----qda - Train----------
# AUC: 98.60 Precision: 99.21 Recall: 98.05
#
# -----qda - Validation-----
# AUC: 85.30 Precision: 84.62 Recall: 88.00
#
# -----knn - Train----------
# AUC: 87.52 Precision: 82.72 Recall: 97.27
#
# -----knn - Validation-----
# AUC: 71.91 Precision: 66.67 Recall: 96.00
#
# -----mlp - Train----------
# AUC: 82.52 Precision: 82.02 Recall: 85.55
#
# -----mlp - Validation-----
# AUC: 66.43 Precision: 66.67 Recall: 72.00
#
# -----lr - Train----------
# AUC: 50.21 Precision: 52.35 Recall: 100.00
#
# -----lr - Validation-----
# AUC: 50.00 Precision: 52.08 Recall: 100.00
#
# -----nusvc - Train----------
# AUC: 90.81 Precision: 91.37 Recall: 91.02
#
# -----nusvc - Validation-----
# AUC: 68.43 Precision: 67.86 Recall: 76.00
#
# wheezy-copper-turtle-magic 4
#
# Fold 1
#
# -----qda - Train----------
# AUC: 97.45 Precision: 98.28 Recall: 96.62
#
# -----qda - Validation-----
# AUC: 85.42 Precision: 86.96 Recall: 83.33
#
# -----knn - Train----------
# AUC: 86.97 Precision: 87.29 Recall: 86.92
#
# -----knn - Validation-----
# AUC: 85.42 Precision: 86.96 Recall: 83.33
#
# -----mlp - Train----------
# AUC: 84.17 Precision: 83.54 Recall: 85.65
#
# -----mlp - Validation-----
# AUC: 81.25 Precision: 85.71 Recall: 75.00
#
# -----lr - Train----------
# AUC: 50.00 Precision: 0.00 Recall: 0.00
#
# -----lr - Validation-----
# AUC: 50.00 Precision: 0.00 Recall: 0.00
#
# -----nusvc - Train----------
# AUC: 92.12 Precision: 93.86 Recall: 90.30
#
# -----nusvc - Validation-----
# AUC: 85.42 Precision: 94.74 Recall: 75.00
#
# Fold 2
#
# -----qda - Train----------
# AUC: 96.16 Precision: 96.60 Recall: 95.78
#
# -----qda - Validation-----
# AUC: 87.50 Precision: 82.14 Recall: 95.83
#
# -----knn - Train----------
# AUC: 88.05 Precision: 89.18 Recall: 86.92
#
# -----knn - Validation-----
# AUC: 85.42 Precision: 86.96 Recall: 83.33
#
# -----mlp - Train----------
# AUC: 85.90 Precision: 86.38 Recall: 85.65
#
# -----mlp - Validation-----
# AUC: 72.92 Precision: 76.19 Recall: 66.67
#
# -----lr - Train----------
# AUC: 50.00 Precision: 0.00 Recall: 0.00
#
# -----lr - Validation-----
# AUC: 50.00 Precision: 0.00 Recall: 0.00
#
# -----nusvc - Train----------
# AUC: 89.96 Precision: 90.60 Recall: 89.45
#
# -----nusvc - Validation-----
# AUC: 72.92 Precision: 72.00 Recall: 75.00
#
# Fold 3
#
# -----qda - Train----------
# AUC: 96.80 Precision: 97.03 Recall: 96.62
#
# -----qda - Validation-----
# AUC: 89.40 Precision: 91.30 Recall: 87.50
#
# -----knn - Train----------
# AUC: 87.87 Precision: 89.47 Recall: 86.08
#
# -----knn - Validation-----
# AUC: 89.49 Precision: 95.24 Recall: 83.33
#
# -----mlp - Train----------
# AUC: 84.01 Precision: 84.62 Recall: 83.54
#
# -----mlp - Validation-----
# AUC: 80.89 Precision: 82.61 Recall: 79.17
#
# -----lr - Train----------
# AUC: 50.00 Precision: 0.00 Recall: 0.00
#
# -----lr - Validation-----
# AUC: 50.00 Precision: 0.00 Recall: 0.00
#
# -----nusvc - Train----------
# AUC: 90.84 Precision: 91.45 Recall: 90.30
#
# -----nusvc - Validation-----
# AUC: 85.24 Precision: 90.48 Recall: 79.17
#
# Fold 4
#
# -----qda - Train----------
# AUC: 96.81 Precision: 97.44 Recall: 96.20
#
# -----qda - Validation-----
# AUC: 95.83 Precision: 100.00 Recall: 91.67
#
# -----knn - Train----------
# AUC: 85.94 Precision: 87.34 Recall: 84.39
#
# -----knn - Validation-----
# AUC: 91.58 Precision: 95.45 Recall: 87.50
#
# -----mlp - Train----------
# AUC: 83.99 Precision: 83.20 Recall: 85.65
#
# -----mlp - Validation-----
# AUC: 80.80 Precision: 80.00 Recall: 83.33
#
# -----lr - Train----------
# AUC: 49.79 Precision: 50.43 Recall: 99.58
#
# -----lr - Validation-----
# AUC: 50.00 Precision: 51.06 Recall: 100.00
#
# -----nusvc - Train----------
# AUC: 91.04 Precision: 90.79 Recall: 91.56
#
# -----nusvc - Validation-----
# AUC: 80.62 Precision: 75.86 Recall: 91.67
#
# Fold 5
#
# -----qda - Train----------
# AUC: 97.23 Precision: 97.86 Recall: 96.62
#
# -----qda - Validation-----
# AUC: 91.58 Precision: 95.45 Recall: 87.50
#
# -----knn - Train----------
# AUC: 87.64 Precision: 88.41 Recall: 86.92
#
# -----knn - Validation-----
# AUC: 83.33 Precision: 100.00 Recall: 66.67
#
# -----mlp - Train----------
# AUC: 83.17 Precision: 84.05 Recall: 82.28
#
# -----mlp - Validation-----
# AUC: 76.63 Precision: 78.26 Recall: 75.00
#
# -----lr - Train----------
# AUC: 50.00 Precision: 0.00 Recall: 0.00
#
# -----lr - Validation-----
# AUC: 50.00 Precision: 0.00 Recall: 0.00
#
# -----nusvc - Train----------
# AUC: 89.99 Precision: 91.30 Recall: 88.61
#
# -----nusvc - Validation-----
# AUC: 80.98 Precision: 85.71 Recall: 75.00
#
# Fold 6
#
# -----qda - Train----------
# AUC: 97.66 Precision: 98.29 Recall: 97.05
#
# -----qda - Validation-----
# AUC: 87.14 Precision: 84.62 Recall: 91.67
#
# -----knn - Train----------
# AUC: 88.72 Precision: 90.35 Recall: 86.92
#
# -----knn - Validation-----
# AUC: 87.14 Precision: 84.62 Recall: 91.67
#
# -----mlp - Train----------
# AUC: 84.66 Precision: 85.41 Recall: 83.97
#
# -----mlp - Validation-----
# AUC: 74.46 Precision: 75.00 Recall: 75.00
#
# -----lr - Train----------
# AUC: 50.00 Precision: 0.00 Recall: 0.00
#
# -----lr - Validation-----
# AUC: 50.00 Precision: 0.00 Recall: 0.00
#
# -----nusvc - Train----------
# AUC: 90.62 Precision: 90.72 Recall: 90.72
#
# -----nusvc - Validation-----
# AUC: 76.54 Precision: 76.00 Recall: 79.17
#
# Fold 7
#
# -----qda - Train----------
# AUC: 97.23 Precision: 97.86 Recall: 96.62
#
# -----qda - Validation-----
# AUC: 87.14 Precision: 84.62 Recall: 91.67
#
# -----knn - Train----------
# AUC: 87.66 Precision: 89.78 Recall: 85.23
#
# -----knn - Validation-----
# AUC: 78.71 Precision: 79.17 Recall: 79.17
#
# -----mlp - Train----------
# AUC: 86.14 Precision: 86.13 Recall: 86.50
#
# -----mlp - Validation-----
# AUC: 78.53 Precision: 75.00 Recall: 87.50
#
# -----lr - Train----------
# AUC: 50.00 Precision: 0.00 Recall: 0.00
#
# -----lr - Validation-----
# AUC: 50.00 Precision: 0.00 Recall: 0.00
#
# -----nusvc - Train----------
# AUC: 90.84 Precision: 91.45 Recall: 90.30
#
# -----nusvc - Validation-----
# AUC: 87.14 Precision: 84.62 Recall: 91.67
#
# Fold 8
#
# -----qda - Train----------
# AUC: 97.66 Precision: 98.29 Recall: 97.05
#
# -----qda - Validation-----
# AUC: 93.57 Precision: 92.00 Recall: 95.83
#
# -----knn - Train----------
# AUC: 87.02 Precision: 89.29 Recall: 84.39
#
# -----knn - Validation-----
# AUC: 84.96 Precision: 81.48 Recall: 91.67
#
# -----mlp - Train----------
# AUC: 82.04 Precision: 79.77 Recall: 86.50
#
# -----mlp - Validation-----
# AUC: 84.87 Precision: 79.31 Recall: 95.83
#
# -----lr - Train----------
# AUC: 50.00 Precision: 0.00 Recall: 0.00
#
# -----lr - Validation-----
# AUC: 50.00 Precision: 0.00 Recall: 0.00
#
# -----nusvc - Train----------
# AUC: 91.27 Precision: 92.61 Recall: 89.87
#
# -----nusvc - Validation-----
# AUC: 91.39 Precision: 88.46 Recall: 95.83
#
# Fold 9
#
# -----qda - Train----------
# AUC: 97.03 Precision: 97.86 Recall: 96.22
#
# -----qda - Validation-----
# AUC: 97.83 Precision: 100.00 Recall: 95.65
#
# -----knn - Train----------
# AUC: 86.84 Precision: 88.94 Recall: 84.45
#
# -----knn - Validation-----
# AUC: 89.13 Precision: 87.50 Recall: 91.30
#
# -----mlp - Train----------
# AUC: 85.76 Precision: 87.01 Recall: 84.45
#
# -----mlp - Validation-----
# AUC: 80.43 Precision: 79.17 Recall: 82.61
#
# -----lr - Train----------
# AUC: 50.00 Precision: 0.00 Recall: 0.00
#
# -----lr - Validation-----
# AUC: 50.00 Precision: 0.00 Recall: 0.00
#
# -----nusvc - Train----------
# AUC: 90.64 Precision: 91.10 Recall: 90.34
#
# -----nusvc - Validation-----
# AUC: 80.43 Precision: 79.17 Recall: 82.61
#
# Fold 10
#
# -----qda - Train----------
# AUC: 97.24 Precision: 97.87 Recall: 96.64
#
# -----qda - Validation-----
# AUC: 93.48 Precision: 95.45 Recall: 91.30
#
# -----knn - Train----------
# AUC: 88.51 Precision: 88.98 Recall: 88.24
#
# -----knn - Validation-----
# AUC: 84.78 Precision: 90.00 Recall: 78.26
#
# -----mlp - Train----------
# AUC: 84.23 Precision: 83.06 Recall: 86.55
#
# -----mlp - Validation-----
# AUC: 67.39 Precision: 65.38 Recall: 73.91
#
# -----lr - Train----------
# AUC: 49.79 Precision: 50.53 Recall: 99.58
#
# -----lr - Validation-----
# AUC: 50.00 Precision: 50.00 Recall: 100.00
#
# -----nusvc - Train----------
# AUC: 90.44 Precision: 91.77 Recall: 89.08
#
# -----nusvc - Validation-----
# AUC: 78.26 Precision: 76.00 Recall: 82.61
#
# Fold 11
#
# -----qda - Train----------
# AUC: 97.66 Precision: 97.89 Recall: 97.48
#
# -----qda - Validation-----
# AUC: 91.30 Precision: 88.00 Recall: 95.65
#
# -----knn - Train----------
# AUC: 87.91 Precision: 90.58 Recall: 84.87
#
# -----knn - Validation-----
# AUC: 86.96 Precision: 90.48 Recall: 82.61
#
# -----mlp - Train----------
# AUC: 83.79 Precision: 82.40 Recall: 86.55
#
# -----mlp - Validation-----
# AUC: 71.74 Precision: 72.73 Recall: 69.57
#
# -----lr - Train----------
# AUC: 50.00 Precision: 0.00 Recall: 0.00
#
# -----lr - Validation-----
# AUC: 50.00 Precision: 0.00 Recall: 0.00
#
# -----nusvc - Train----------
# AUC: 90.65 Precision: 91.45 Recall: 89.92
#
# -----nusvc - Validation-----
# AUC: 69.57 Precision: 71.43 Recall: 65.22
#
# wheezy-copper-turtle-magic 5
#
# Fold 1
#
# -----qda - Train----------
# AUC: 97.46 Precision: 98.27 Recall: 96.60
#
# -----qda - Validation-----
# AUC: 89.58 Precision: 95.24 Recall: 83.33
#
# -----knn - Train----------
# AUC: 84.95 Precision: 90.20 Recall: 78.30
#
# -----knn - Validation-----
# AUC: 77.08 Precision: 76.00 Recall: 79.17
#
# -----mlp - Train----------
# AUC: 83.71 Precision: 84.65 Recall: 82.13
#
# -----mlp - Validation-----
# AUC: 64.58 Precision: 65.22 Recall: 62.50
#
# -----lr - Train----------
# AUC: 50.00 Precision: 0.00 Recall: 0.00
#
# -----lr - Validation-----
# AUC: 50.00 Precision: 0.00 Recall: 0.00
#
# -----nusvc - Train----------
# AUC: 91.97 Precision: 91.21 Recall: 92.77
#
# -----nusvc - Validation-----
# AUC: 72.92 Precision: 70.37 Recall: 79.17
#
# Fold 2
#
# -----qda - Train----------
# AUC: 97.45 Precision: 98.69 Recall: 96.17
#
# -----qda - Validation-----
# AUC: 81.25 Precision: 77.78 Recall: 87.50
#
# -----knn - Train----------
# AUC: 86.01 Precision: 90.82 Recall: 80.00
#
# -----knn - Validation-----
# AUC: 77.08 Precision: 84.21 Recall: 66.67
#
# -----mlp - Train----------
# AUC: 83.73 Precision: 82.92 Recall: 84.68
#
# -----mlp - Validation-----
# AUC: 81.25 Precision: 82.61 Recall: 79.17
#
# -----lr - Train----------
# AUC: 50.00 Precision: 0.00 Recall: 0.00
#
# -----lr - Validation-----
# AUC: 50.00 Precision: 0.00 Recall: 0.00
#
# -----nusvc - Train----------
# AUC: 90.90 Precision: 91.74 Recall: 89.79
#
# -----nusvc - Validation-----
# AUC: 83.33 Precision: 86.36 Recall: 79.17
#
# Fold 3
#
# -----qda - Train----------
# AUC: 97.24 Precision: 98.26 Recall: 96.17
#
# -----qda - Validation-----
# AUC: 93.75 Precision: 95.65 Recall: 91.67
#
# -----knn - Train----------
# AUC: 86.23 Precision: 90.09 Recall: 81.28
#
# -----knn - Validation-----
# AUC: 83.33 Precision: 90.00 Recall: 75.00
#
# -----mlp - Train----------
# AUC: 82.88 Precision: 82.35 Recall: 83.40
#
# -----mlp - Validation-----
# AUC: 79.17 Precision: 79.17 Recall: 79.17
#
# -----lr - Train----------
# AUC: 50.00 Precision: 0.00 Recall: 0.00
#
# -----lr - Validation-----
# AUC: 50.00 Precision: 0.00 Recall: 0.00
#
# -----nusvc - Train----------
# AUC: 91.34 Precision: 90.08 Recall: 92.77
#
# -----nusvc - Validation-----
# AUC: 83.33 Precision: 83.33 Recall: 83.33
#
# Fold 4
#
# -----qda - Train----------
# AUC: 96.82 Precision: 97.83 Recall: 95.74
#
# -----qda - Validation-----
# AUC: 95.83 Precision: 100.00 Recall: 91.67
#
# -----knn - Train----------
# AUC: 85.81 Precision: 89.25 Recall: 81.28
#
# -----knn - Validation-----
# AUC: 85.42 Precision: 86.96 Recall: 83.33
#
# -----mlp - Train----------
# AUC: 83.30 Precision: 82.50 Recall: 84.26
#
# -----mlp - Validation-----
# AUC: 72.92 Precision: 70.37 Recall: 79.17
#
# -----lr - Train----------
# AUC: 50.00 Precision: 0.00 Recall: 0.00
#
# -----lr - Validation-----
# AUC: 50.00 Precision: 0.00 Recall: 0.00
#
# -----nusvc - Train----------
# AUC: 92.59 Precision: 93.48 Recall: 91.49
#
# -----nusvc - Validation-----
# AUC: 75.00 Precision: 71.43 Recall: 83.33
#
# Fold 5
#
# -----qda - Train----------
# AUC: 97.24 Precision: 98.26 Recall: 96.17
#
# -----qda - Validation-----
# AUC: 93.75 Precision: 92.00 Recall: 95.83
#
# -----knn - Train----------
# AUC: 86.86 Precision: 91.00 Recall: 81.70
#
# -----knn - Validation-----
# AUC: 81.25 Precision: 85.71 Recall: 75.00
#
# -----mlp - Train----------
# AUC: 85.64 Precision: 83.27 Recall: 88.94
#
# -----mlp - Validation-----
# AUC: 89.58 Precision: 85.19 Recall: 95.83
#
# -----lr - Train----------
# AUC: 50.00 Precision: 0.00 Recall: 0.00
#
# -----lr - Validation-----
# AUC: 50.00 Precision: 0.00 Recall: 0.00
#
# -----nusvc - Train----------
# AUC: 92.17 Precision: 92.67 Recall: 91.49
#
# -----nusvc - Validation-----
# AUC: 91.67 Precision: 91.67 Recall: 91.67
#
# Fold 6
#
# -----qda - Train----------
# AUC: 97.45 Precision: 98.69 Recall: 96.17
#
# -----qda - Validation-----
# AUC: 95.83 Precision: 95.83 Recall: 95.83
#
# -----knn - Train----------
# AUC: 85.80 Precision: 90.78 Recall: 79.57
#
# -----knn - Validation-----
# AUC: 83.33 Precision: 94.44 Recall: 70.83
#
# -----mlp - Train----------
# AUC: 83.28 Precision: 85.45 Recall: 80.00
#
# -----mlp - Validation-----
# AUC: 68.75 Precision: 69.57 Recall: 66.67
#
# -----lr - Train----------
# AUC: 50.00 Precision: 0.00 Recall: 0.00
#
# -----lr - Validation-----
# AUC: 50.00 Precision: 0.00 Recall: 0.00
#
# -----nusvc - Train----------
# AUC: 91.12 Precision: 91.06 Recall: 91.06
#
# -----nusvc - Validation-----
# AUC: 83.33 Precision: 83.33 Recall: 83.33
#
# Fold 7
#
# -----qda - Train----------
# AUC: 97.47 Precision: 97.86 Recall: 97.03
#
# -----qda - Validation-----
# AUC: 95.65 Precision: 100.00 Recall: 91.30
#
# -----knn - Train----------
# AUC: 85.21 Precision: 89.15 Recall: 80.08
#
# -----knn - Validation-----
# AUC: 82.79 Precision: 89.47 Recall: 73.91
#
# -----mlp - Train----------
# AUC: 85.01 Precision: 86.03 Recall: 83.47
#
# -----mlp - Validation-----
# AUC: 70.02 Precision: 73.68 Recall: 60.87
#
# -----lr - Train----------
# AUC: 50.00 Precision: 0.00 Recall: 0.00
#
# -----lr - Validation-----
# AUC: 50.00 Precision: 0.00 Recall: 0.00
#
# -----nusvc - Train----------
# AUC: 90.93 Precision: 91.42 Recall: 90.25
#
# -----nusvc - Validation-----
# AUC: 72.28 Precision: 72.73 Recall: 69.57
#
# Fold 8
#
# -----qda - Train----------
# AUC: 97.25 Precision: 98.27 Recall: 96.19
#
# -----qda - Validation-----
# AUC: 93.48 Precision: 100.00 Recall: 86.96
#
# -----knn - Train----------
# AUC: 86.69 Precision: 91.00 Recall: 81.36
#
# -----knn - Validation-----
# AUC: 80.53 Precision: 93.75 Recall: 65.22
#
# -----mlp - Train----------
# AUC: 86.08 Precision: 85.42 Recall: 86.86
#
# -----mlp - Validation-----
# AUC: 72.19 Precision: 75.00 Recall: 65.22
#
# -----lr - Train----------
# AUC: 50.00 Precision: 0.00 Recall: 0.00
#
# -----lr - Validation-----
# AUC: 50.00 Precision: 0.00 Recall: 0.00
#
# -----nusvc - Train----------
# AUC: 91.35 Precision: 90.46 Recall: 92.37
#
# -----nusvc - Validation-----
# AUC: 78.53 Precision: 84.21 Recall: 69.57
#
# Fold 9
#
# -----qda - Train----------
# AUC: 97.46 Precision: 98.70 Recall: 96.19
#
# -----qda - Validation-----
# AUC: 95.83 Precision: 92.00 Recall: 100.00
#
# -----knn - Train----------
# AUC: 86.26 Precision: 92.12 Recall: 79.24
#
# -----knn - Validation-----
# AUC: 87.32 Precision: 84.00 Recall: 91.30
#
# -----mlp - Train----------
# AUC: 83.33 Precision: 83.12 Recall: 83.47
#
# -----mlp - Validation-----
# AUC: 83.15 Precision: 77.78 Recall: 91.30
#
# -----lr - Train----------
# AUC: 50.00 Precision: 0.00 Recall: 0.00
#
# -----lr - Validation-----
# AUC: 50.00 Precision: 0.00 Recall: 0.00
#
# -----nusvc - Train----------
# AUC: 91.77 Precision: 91.21 Recall: 92.37
#
# -----nusvc - Validation-----
# AUC: 87.41 Precision: 81.48 Recall: 95.65
#
# Fold 10
#
# -----qda - Train----------
# AUC: 97.89 Precision: 98.71 Recall: 97.03
#
# -----qda - Validation-----
# AUC: 82.61 Precision: 85.71 Recall: 78.26
#
# -----knn - Train----------
# AUC: 85.22 Precision: 90.69 Recall: 78.39
#
# -----knn - Validation-----
# AUC: 80.43 Precision: 88.89 Recall: 69.57
#
# -----mlp - Train----------
# AUC: 83.15 Precision: 83.91 Recall: 81.78
#
# -----mlp - Validation-----
# AUC: 91.30 Precision: 91.30 Recall: 91.30
#
# -----lr - Train----------
# AUC: 50.00 Precision: 0.00 Recall: 0.00
#
# -----lr - Validation-----
# AUC: 50.00 Precision: 0.00 Recall: 0.00
#
# -----nusvc - Train----------
# AUC: 91.58 Precision: 90.83 Recall: 92.37
#
# -----nusvc - Validation-----
# AUC: 86.96 Precision: 86.96 Recall: 86.96
#
# Fold 11
#
# -----qda - Train----------
# AUC: 97.04 Precision: 98.26 Recall: 95.76
#
# -----qda - Validation-----
# AUC: 93.48 Precision: 95.45 Recall: 91.30
#
# -----knn - Train----------
# AUC: 87.13 Precision: 90.70 Recall: 82.63
#
# -----knn - Validation-----
# AUC: 80.43 Precision: 93.75 Recall: 65.22
#
# -----mlp - Train----------
# AUC: 84.65 Precision: 83.00 Recall: 86.86
#
# -----mlp - Validation-----
# AUC: 69.57 Precision: 76.47 Recall: 56.52
#
# -----lr - Train----------
# AUC: 50.00 Precision: 0.00 Recall: 0.00
#
# -----lr - Validation-----
# AUC: 50.00 Precision: 0.00 Recall: 0.00
#
# -----nusvc - Train----------
# AUC: 90.53 Precision: 89.63 Recall: 91.53
#
# -----nusvc - Validation-----
# AUC: 73.91 Precision: 82.35 Recall: 60.87
#
# wheezy-copper-turtle-magic 6
#
# Fold 1
#
# -----qda - Train----------
# AUC: 98.30 Precision: 98.33 Recall: 98.33
#
# -----qda - Validation-----
# AUC: 93.65 Precision: 92.31 Recall: 96.00
#
# -----knn - Train----------
# AUC: 88.13 Precision: 83.64 Recall: 95.83
#
# -----knn - Validation-----
# AUC: 85.13 Precision: 82.14 Recall: 92.00
#
# -----mlp - Train----------
# AUC: 84.20 Precision: 83.20 Recall: 86.67
#
# ...
# AUC: 98.70 Precision: 98.31 Recall: 99.15
#
# -----qda - Validation-----
# AUC: 93.18 Precision: 88.46 Recall: 100.00
#
# -----knn - Train----------
# AUC: 88.53 Precision: 87.24 Recall: 90.60
#
# -----knn - Validation-----
# AUC: 86.46 Precision: 81.48 Recall: 95.65
#
# -----mlp - Train----------
# AUC: 84.45 Precision: 84.62 Recall: 84.62
#
# -----mlp - Validation-----
# AUC: 84.58 Precision: 90.00 Recall: 78.26
#
# -----lr - Train----------
# AUC: 50.00 Precision: 0.00 Recall: 0.00
#
# -----lr - Validation-----
# AUC: 50.00 Precision: 0.00 Recall: 0.00
#
# -----nusvc - Train----------
# AUC: 92.85 Precision: 91.36 Recall: 94.87
#
# -----nusvc - Validation-----
# AUC: 82.11 Precision: 80.00 Recall: 86.96
#
# Fold 11
#
# -----qda - Train----------
# AUC: 98.70 Precision: 98.31 Recall: 99.15
#
# -----qda - Validation-----
# AUC: 95.65 Precision: 100.00 Recall: 91.30
#
# -----knn - Train----------
# AUC: 87.88 Precision: 86.48 Recall: 90.17
#
# -----knn - Validation-----
# AUC: 91.21 Precision: 95.24 Recall: 86.96
#
# -----mlp - Train----------
# AUC: 85.49 Precision: 83.53 Recall: 88.89
#
# -----mlp - Validation-----
# AUC: 71.05 Precision: 70.83 Recall: 73.91
#
# -----lr - Train----------
# AUC: 50.00 Precision: 0.00 Recall: 0.00
#
# -----lr - Validation-----
# AUC: 50.00 Precision: 0.00 Recall: 0.00
#
# -----nusvc - Train----------
# AUC: 90.47 Precision: 88.93 Recall: 92.74
#
# -----nusvc - Validation-----
# AUC: 73.22 Precision: 72.00 Recall: 78.26
#
# wheezy-copper-turtle-magic 117
#
# Fold 1
#
# -----qda - Train----------
# AUC: 98.01 Precision: 98.68 Recall: 97.39
#
# -----qda - Validation-----
# AUC: 95.83 Precision: 100.00 Recall: 91.67
#
# -----knn - Train----------
# AUC: 87.75 Precision: 87.23 Recall: 89.13
#
# -----knn - Validation-----
# AUC: 93.66 Precision: 95.65 Recall: 91.67
#
# -----mlp - Train----------
# AUC: 85.05 Precision: 83.82 Recall: 87.83
#
# -----mlp - Validation-----
# AUC: 74.37 Precision: 73.08 Recall: 79.17
#
# -----lr - Train----------
# AUC: 49.78 Precision: 51.00 Recall: 99.57
#
# -----lr - Validation-----
# AUC: 50.00 Precision: 51.06 Recall: 100.00
#
# -----nusvc - Train----------
# AUC: 90.88 Precision: 90.91 Recall: 91.30
#
# -----nusvc - Validation-----
# AUC: 85.14 Precision: 86.96 Recall: 83.33
#
# Fold 2
#
# -----qda - Train----------
# AUC: 98.03 Precision: 99.12 Recall: 96.97
#
# -----qda - Validation-----
# AUC: 88.74 Precision: 84.62 Recall: 95.65
#
# -----knn - Train----------
# AUC: 89.39 Precision: 89.96 Recall: 89.18
#
# -----knn - Validation-----
# AUC: 86.66 Precision: 86.96 Recall: 86.96
#
# -----mlp - Train----------
# AUC: 84.50 Precision: 84.55 Recall: 85.28
#
# -----mlp - Validation-----
# AUC: 84.39 Precision: 83.33 Recall: 86.96
#
# -----lr - Train----------
# AUC: 50.00 Precision: 0.00 Recall: 0.00
#
# -----lr - Validation-----
# AUC: 50.00 Precision: 0.00 Recall: 0.00
#
# -----nusvc - Train----------
# AUC: 91.81 Precision: 91.81 Recall: 92.21
#
# -----nusvc - Validation-----
# AUC: 84.39 Precision: 83.33 Recall: 86.96
#
# Fold 3
#
# -----qda - Train----------
# AUC: 98.02 Precision: 98.68 Recall: 97.40
#
# -----qda - Validation-----
# AUC: 86.76 Precision: 90.48 Recall: 82.61
#
# -----knn - Train----------
# AUC: 88.75 Precision: 90.18 Recall: 87.45
#
# -----knn - Validation-----
# AUC: 77.96 Precision: 84.21 Recall: 69.57
#
# -----mlp - Train----------
# AUC: 85.81 Precision: 85.53 Recall: 87.01
#
# -----mlp - Validation-----
# AUC: 68.97 Precision: 71.43 Recall: 65.22
#
# -----lr - Train----------
# AUC: 49.78 Precision: 51.00 Recall: 99.57
#
# -----lr - Validation-----
# AUC: 50.00 Precision: 51.11 Recall: 100.00
#
# -----nusvc - Train----------
# AUC: 91.63 Precision: 93.27 Recall: 90.04
#
# -----nusvc - Validation-----
# AUC: 71.15 Precision: 72.73 Recall: 69.57
#
# Fold 4
#
# -----qda - Train----------
# AUC: 97.59 Precision: 98.67 Recall: 96.54
#
# -----qda - Validation-----
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----knn - Train----------
# AUC: 89.16 Precision: 89.57 Recall: 89.18
#
# -----knn - Validation-----
# AUC: 82.31 Precision: 85.71 Recall: 78.26
#
# -----mlp - Train----------
# AUC: 85.01 Precision: 87.21 Recall: 82.68
#
# -----mlp - Validation-----
# AUC: 73.32 Precision: 73.91 Recall: 73.91
#
# -----lr - Train----------
# AUC: 49.78 Precision: 51.00 Recall: 99.57
#
# -----lr - Validation-----
# AUC: 50.00 Precision: 51.11 Recall: 100.00
#
# -----nusvc - Train----------
# AUC: 92.69 Precision: 92.67 Recall: 93.07
#
# -----nusvc - Validation-----
# AUC: 73.12 Precision: 70.37 Recall: 82.61
#
# Fold 5
#
# -----qda - Train----------
# AUC: 97.58 Precision: 98.25 Recall: 96.97
#
# -----qda - Validation-----
# AUC: 97.83 Precision: 100.00 Recall: 95.65
#
# -----knn - Train----------
# AUC: 86.55 Precision: 88.64 Recall: 84.42
#
# -----knn - Validation-----
# AUC: 93.18 Precision: 88.46 Recall: 100.00
#
# -----mlp - Train----------
# AUC: 86.66 Precision: 85.19 Recall: 89.61
#
# -----mlp - Validation-----
# AUC: 70.85 Precision: 67.86 Recall: 82.61
#
# -----lr - Train----------
# AUC: 49.78 Precision: 51.00 Recall: 99.57
#
# -----lr - Validation-----
# AUC: 50.00 Precision: 51.11 Recall: 100.00
#
# -----nusvc - Train----------
# AUC: 92.93 Precision: 93.45 Recall: 92.64
#
# -----nusvc - Validation-----
# AUC: 77.67 Precision: 76.00 Recall: 82.61
#
# Fold 6
#
# -----qda - Train----------
# AUC: 98.24 Precision: 98.69 Recall: 97.84
#
# -----qda - Validation-----
# AUC: 95.55 Precision: 95.65 Recall: 95.65
#
# -----knn - Train----------
# AUC: 88.88 Precision: 87.55 Recall: 91.34
#
# -----knn - Validation-----
# AUC: 86.66 Precision: 86.96 Recall: 86.96
#
# -----mlp - Train----------
# AUC: 86.76 Precision: 88.34 Recall: 85.28
#
# -----mlp - Validation-----
# AUC: 75.49 Precision: 75.00 Recall: 78.26
#
# -----lr - Train----------
# AUC: 49.78 Precision: 51.00 Recall: 99.57
#
# -----lr - Validation-----
# AUC: 50.00 Precision: 51.11 Recall: 100.00
#
# -----nusvc - Train----------
# AUC: 91.58 Precision: 91.42 Recall: 92.21
#
# -----nusvc - Validation-----
# AUC: 79.94 Precision: 79.17 Recall: 82.61
#
# Fold 7
#
# -----qda - Train----------
# AUC: 98.02 Precision: 98.68 Recall: 97.40
#
# -----qda - Validation-----
# AUC: 93.28 Precision: 91.67 Recall: 95.65
#
# -----knn - Train----------
# AUC: 88.22 Precision: 87.08 Recall: 90.48
#
# -----knn - Validation-----
# AUC: 86.86 Precision: 94.74 Recall: 78.26
#
# -----mlp - Train----------
# AUC: 85.83 Precision: 86.15 Recall: 86.15
#
# -----mlp - Validation-----
# AUC: 80.24 Precision: 88.89 Recall: 69.57
#
# -----lr - Train----------
# AUC: 49.78 Precision: 51.00 Recall: 99.57
#
# -----lr - Validation-----
# AUC: 50.00 Precision: 51.11 Recall: 100.00
#
# -----nusvc - Train----------
# AUC: 93.11 Precision: 92.37 Recall: 94.37
#
# -----nusvc - Validation-----
# AUC: 88.93 Precision: 90.91 Recall: 86.96
#
# Fold 8
#
# -----qda - Train----------
# AUC: 98.02 Precision: 98.68 Recall: 97.40
#
# -----qda - Validation-----
# AUC: 95.55 Precision: 95.65 Recall: 95.65
#
# -----knn - Train----------
# AUC: 88.97 Precision: 90.58 Recall: 87.45
#
# -----knn - Validation-----
# AUC: 80.14 Precision: 85.00 Recall: 73.91
#
# -----mlp - Train----------
# AUC: 86.94 Precision: 87.07 Recall: 87.45
#
# -----mlp - Validation-----
# AUC: 75.69 Precision: 80.00 Recall: 69.57
#
# -----lr - Train----------
# AUC: 49.78 Precision: 51.00 Recall: 99.57
#
# -----lr - Validation-----
# AUC: 50.00 Precision: 51.11 Recall: 100.00
#
# -----nusvc - Train----------
# AUC: 93.13 Precision: 93.10 Recall: 93.51
#
# -----nusvc - Validation-----
# AUC: 77.87 Precision: 80.95 Recall: 73.91
#
# Fold 9
#
# -----qda - Train----------
# AUC: 98.03 Precision: 99.12 Recall: 96.97
#
# -----qda - Validation-----
# AUC: 93.48 Precision: 100.00 Recall: 86.96
#
# -----knn - Train----------
# AUC: 88.70 Precision: 88.46 Recall: 89.61
#
# -----knn - Validation-----
# AUC: 89.03 Precision: 95.00 Recall: 82.61
#
# -----mlp - Train----------
# AUC: 84.87 Precision: 83.00 Recall: 88.74
#
# -----mlp - Validation-----
# AUC: 70.85 Precision: 67.86 Recall: 82.61
#
# -----lr - Train----------
# AUC: 50.00 Precision: 0.00 Recall: 0.00
#
# -----lr - Validation-----
# AUC: 50.00 Precision: 0.00 Recall: 0.00
#
# -----nusvc - Train----------
# AUC: 92.01 Precision: 91.49 Recall: 93.07
#
# -----nusvc - Validation-----
# AUC: 82.21 Precision: 82.61 Recall: 82.61
#
# Fold 10
#
# -----qda - Train----------
# AUC: 98.25 Precision: 99.12 Recall: 97.40
#
# -----qda - Validation-----
# AUC: 91.11 Precision: 91.30 Recall: 91.30
#
# -----knn - Train----------
# AUC: 88.72 Precision: 89.13 Recall: 88.74
#
# -----knn - Validation-----
# AUC: 80.24 Precision: 88.89 Recall: 69.57
#
# -----mlp - Train----------
# AUC: 83.62 Precision: 83.98 Recall: 83.98
#
# -----mlp - Validation-----
# AUC: 70.95 Precision: 69.23 Recall: 78.26
#
# -----lr - Train----------
# AUC: 49.78 Precision: 51.00 Recall: 99.57
#
# -----lr - Validation-----
# AUC: 50.00 Precision: 51.11 Recall: 100.00
#
# -----nusvc - Train----------
# AUC: 92.02 Precision: 91.85 Recall: 92.64
#
# -----nusvc - Validation-----
# AUC: 77.77 Precision: 78.26 Recall: 78.26
#
# Fold 11
#
# -----qda - Train----------
# AUC: 97.81 Precision: 98.68 Recall: 96.97
#
# -----qda - Validation-----
# AUC: 93.18 Precision: 88.46 Recall: 100.00
#
# -----knn - Train----------
# AUC: 87.14 Precision: 86.81 Recall: 88.31
#
# -----knn - Validation-----
# AUC: 86.46 Precision: 81.48 Recall: 95.65
#
# -----mlp - Train----------
# AUC: 86.71 Precision: 86.70 Recall: 87.45
#
# -----mlp - Validation-----
# AUC: 80.04 Precision: 81.82 Recall: 78.26
#
# -----lr - Train----------
# AUC: 49.78 Precision: 51.00 Recall: 99.57
#
# -----lr - Validation-----
# AUC: 50.00 Precision: 51.11 Recall: 100.00
#
# -----nusvc - Train----------
# AUC: 92.27 Precision: 92.98 Recall: 91.77
#
# -----nusvc - Validation-----
# AUC: 86.76 Precision: 90.48 Recall: 82.61
#
# wheezy-copper-turtle-magic 118
#
# Fold 1
#
# -----qda - Train----------
# AUC: 97.53 Precision: 97.72 Recall: 97.27
#
# -----qda - Validation-----
# AUC: 95.65 Precision: 91.67 Recall: 100.00
#
# -----knn - Train----------
# AUC: 89.15 Precision: 93.88 Recall: 83.64
#
# -----knn - Validation-----
# AUC: 95.55 Precision: 95.45 Recall: 95.45
#
# -----mlp - Train----------
# AUC: 87.86 Precision: 88.07 Recall: 87.27
#
# -----mlp - Validation-----
# AUC: 80.04 Precision: 78.26 Recall: 81.82
#
# -----lr - Train----------
# AUC: 50.00 Precision: 0.00 Recall: 0.00
#
# -----lr - Validation-----
# AUC: 50.00 Precision: 0.00 Recall: 0.00
#
# -----nusvc - Train----------
# AUC: 92.36 Precision: 92.27 Recall: 92.27
#
# -----nusvc - Validation-----
# AUC: 80.14 Precision: 76.00 Recall: 86.36
#
# Fold 2
#
# -----qda - Train----------
# AUC: 97.97 Precision: 98.17 Recall: 97.73
#
# -----qda - Validation-----
# AUC: 93.38 Precision: 91.30 Recall: 95.45
#
# -----knn - Train----------
# AUC: 88.47 Precision: 93.78 Recall: 82.27
#
# -----knn - Validation-----
# AUC: 90.91 Precision: 100.00 Recall: 81.82
#
# -----mlp - Train----------
# AUC: 83.36 Precision: 83.49 Recall: 82.73
#
# -----mlp - Validation-----
# AUC: 86.56 Precision: 90.00 Recall: 81.82
#
# -----lr - Train----------
# AUC: 50.00 Precision: 0.00 Recall: 0.00
#
# -----lr - Validation-----
# AUC: 50.00 Precision: 0.00 Recall: 0.00
#
# -----nusvc - Train----------
# AUC: 93.04 Precision: 92.38 Recall: 93.64
#
# -----nusvc - Validation-----
# AUC: 84.49 Precision: 82.61 Recall: 86.36
#
# Fold 3
#
# -----qda - Train----------
# AUC: 97.53 Precision: 97.72 Recall: 97.27
#
# -----qda - Validation-----
# AUC: 95.55 Precision: 95.45 Recall: 95.45
#
# -----knn - Train----------
# AUC: 86.68 Precision: 91.28 Recall: 80.91
#
# -----knn - Validation-----
# AUC: 93.18 Precision: 100.00 Recall: 86.36
#
# -----mlp - Train----------
# AUC: 83.78 Precision: 85.92 Recall: 80.45
#
# -----mlp - Validation-----
# AUC: 86.46 Precision: 94.44 Recall: 77.27
#
# -----lr - Train----------
# AUC: 50.00 Precision: 0.00 Recall: 0.00
#
# -----lr - Validation-----
# AUC: 50.00 Precision: 0.00 Recall: 0.00
#
# -----nusvc - Train----------
# AUC: 93.03 Precision: 93.55 Recall: 92.27
#
# -----nusvc - Validation-----
# AUC: 91.01 Precision: 95.00 Recall: 86.36
#
# Fold 4
#
# -----qda - Train----------
# AUC: 97.75 Precision: 97.73 Recall: 97.73
#
# -----qda - Validation-----
# AUC: 88.83 Precision: 90.48 Recall: 86.36
#
# -----knn - Train----------
# AUC: 87.80 Precision: 92.78 Recall: 81.82
#
# -----knn - Validation-----
# AUC: 81.92 Precision: 93.75 Recall: 68.18
#
# -----mlp - Train----------
# AUC: 84.90 Precision: 87.32 Recall: 81.36
#
# -----mlp - Validation-----
# AUC: 59.58 Precision: 64.29 Recall: 40.91
#
# -----lr - Train----------
# AUC: 50.00 Precision: 0.00 Recall: 0.00
#
# -----lr - Validation-----
# AUC: 50.00 Precision: 0.00 Recall: 0.00
#
# -----nusvc - Train----------
# AUC: 90.79 Precision: 90.50 Recall: 90.91
#
# -----nusvc - Validation-----
# AUC: 70.95 Precision: 73.68 Recall: 63.64
#
# Fold 5
#
# -----qda - Train----------
# AUC: 98.20 Precision: 98.18 Recall: 98.18
#
# -----qda - Validation-----
# AUC: 95.45 Precision: 100.00 Recall: 90.91
#
# -----knn - Train----------
# AUC: 87.58 Precision: 92.31 Recall: 81.82
#
# -----knn - Validation-----
# AUC: 88.64 Precision: 100.00 Recall: 77.27
#
# -----mlp - Train----------
# AUC: 82.87 Precision: 85.64 Recall: 78.64
#
# -----mlp - Validation-----
# AUC: 84.19 Precision: 94.12 Recall: 72.73
#
# -----lr - Train----------
# AUC: 50.00 Precision: 0.00 Recall: 0.00
#
# -----lr - Validation-----
# AUC: 50.00 Precision: 0.00 Recall: 0.00
#
# -----nusvc - Train----------
# AUC: 93.03 Precision: 93.15 Recall: 92.73
#
# -----nusvc - Validation-----
# AUC: 88.74 Precision: 94.74 Recall: 81.82
#
# Fold 6
#
# -----qda - Train----------
# AUC: 97.75 Precision: 97.73 Recall: 97.73
#
# -----qda - Validation-----
# AUC: 91.11 Precision: 90.91 Recall: 90.91
#
# -----knn - Train----------
# AUC: 86.40 Precision: 95.45 Recall: 76.36
#
# -----knn - Validation-----
# AUC: 77.67 Precision: 80.00 Recall: 72.73
#
# -----mlp - Train----------
# AUC: 84.27 Precision: 84.09 Recall: 84.09
#
# -----mlp - Validation-----
# AUC: 66.80 Precision: 64.00 Recall: 72.73
#
# -----lr - Train----------
# AUC: 50.00 Precision: 0.00 Recall: 0.00
#
# -----lr - Validation-----
# AUC: 50.00 Precision: 0.00 Recall: 0.00
#
# -----nusvc - Train----------
# AUC: 92.11 Precision: 94.26 Recall: 89.55
#
# -----nusvc - Validation-----
# AUC: 73.32 Precision: 72.73 Recall: 72.73
#
# Fold 7
#
# -----qda - Train----------
# AUC: 98.42 Precision: 99.08 Recall: 97.73
#
# -----qda - Validation-----
# AUC: 93.18 Precision: 91.30 Recall: 95.45
#
# -----knn - Train----------
# AUC: 89.39 Precision: 93.91 Recall: 84.09
#
# -----knn - Validation-----
# AUC: 90.91 Precision: 90.91 Recall: 90.91
#
# -----mlp - Train----------
# AUC: 81.83 Precision: 82.03 Recall: 80.91
#
# -----mlp - Validation-----
# AUC: 79.55 Precision: 78.26 Recall: 81.82
#
# -----lr - Train----------
# AUC: 50.00 Precision: 0.00 Recall: 0.00
#
# -----lr - Validation-----
# AUC: 50.00 Precision: 0.00 Recall: 0.00
#
# -----nusvc - Train----------
# AUC: 91.47 Precision: 92.13 Recall: 90.45
#
# -----nusvc - Validation-----
# AUC: 88.64 Precision: 90.48 Recall: 86.36
#
# Fold 8
#
# -----qda - Train----------
# AUC: 97.98 Precision: 98.17 Recall: 97.73
#
# -----qda - Validation-----
# AUC: 93.18 Precision: 91.30 Recall: 95.45
#
# -----knn - Train----------
# AUC: 89.40 Precision: 93.47 Recall: 84.55
#
# -----knn - Validation-----
# AUC: 75.00 Precision: 78.95 Recall: 68.18
#
# -----mlp - Train----------
# AUC: 86.98 Precision: 87.85 Recall: 85.45
#
# -----mlp - Validation-----
# AUC: 61.36 Precision: 59.26 Recall: 72.73
#
# -----lr - Train----------
# AUC: 50.00 Precision: 0.00 Recall: 0.00
#
# -----lr - Validation-----
# AUC: 50.00 Precision: 0.00 Recall: 0.00
#
# -----nusvc - Train----------
# AUC: 91.90 Precision: 93.40 Recall: 90.00
#
# -----nusvc - Validation-----
# AUC: 72.73 Precision: 69.23 Recall: 81.82
#
# Fold 9
#
# -----qda - Train----------
# AUC: 97.31 Precision: 97.27 Recall: 97.27
#
# -----qda - Validation-----
# AUC: 95.45 Precision: 95.45 Recall: 95.45
#
# -----knn - Train----------
# AUC: 88.49 Precision: 92.89 Recall: 83.18
#
# -----knn - Validation-----
# AUC: 84.09 Precision: 94.12 Recall: 72.73
#
# -----mlp - Train----------
# AUC: 82.38 Precision: 77.87 Recall: 89.55
#
# -----mlp - Validation-----
# AUC: 86.36 Precision: 90.00 Recall: 81.82
#
# -----lr - Train----------
# AUC: 50.00 Precision: 0.00 Recall: 0.00
#
# -----lr - Validation-----
# AUC: 50.00 Precision: 0.00 Recall: 0.00
#
# -----nusvc - Train----------
# AUC: 91.69 Precision: 92.17 Recall: 90.91
#
# -----nusvc - Validation-----
# AUC: 90.91 Precision: 95.00 Recall: 86.36
#
# Fold 10
#
# -----qda - Train----------
# AUC: 97.98 Precision: 98.17 Recall: 97.73
#
# -----qda - Validation-----
# AUC: 95.45 Precision: 95.45 Recall: 95.45

# %% [markdown]
# # Ensemble models
#
# Here you can ensemble any combination of models, and give the desired weight for each one.

# %%
train['preds_top2'] = (train['preds_qda'] * 0.5) + (train['preds_nusvc'] * 0.5)
test['target_top2'] = (test['target_qda'] * 0.5) + (test['target_nusvc'] * 0.5)

train['preds_top3'] = (train['preds_qda'] * 0.35) + (train['preds_mlp'] * 0.3) + (train['preds_nusvc'] * 0.35)
test['target_top3'] = (test['target_qda'] * 0.35) + (test['target_mlp'] * 0.3) + (test['target_nusvc'] * 0.35)

train['preds_top4'] = (train['preds_qda'] * 0.25) + (train['preds_mlp'] * 0.25) + (train['preds_lr'] * 0.25) + (train['preds_nusvc'] * 0.25)
test['target_top4'] = (test['target_qda'] * 0.25) + (test['target_mlp'] * 0.25) + (test['target_lr'] * 0.25) + (test['target_nusvc'] * 0.25)

train['preds_avg'] = (train['preds_qda'] * 0.2) + (train['preds_knn'] * 0.2) + (train['preds_mlp'] * 0.2) + (train['preds_lr'] * 0.2) + (train['preds_nusvc'] * 0.2)
test['target_avg'] = (test['target_qda'] * 0.2) + (test['target_knn'] * 0.2) + (test['target_mlp'] * 0.2) + (test['target_lr'] * 0.2) + (test['target_nusvc'] * 0.2)

# %% [markdown]
# # Model evaluation
# ## Confusion matrix (averaged model)

# %%
f = plt.subplots(1, 1, figsize=(16, 5), sharex=True)
train_cnf_matrix = confusion_matrix(train['target'], [np.round(x) for x in train['preds_avg']])
train_cnf_matrix_norm = train_cnf_matrix / train_cnf_matrix.sum(axis=1)[:, np.newaxis]
train_df_cm = pd.DataFrame(train_cnf_matrix_norm, index=[0, 1], columns=[0, 1])
sns.heatmap(train_df_cm, annot=True, fmt='.2f', cmap="Blues")
plt.show()

# %% [markdown]
# ## Metrics ROC AUC

# %%
print('QDA AUC %.2f' % roc_auc_score(train['target'], train['preds_qda']))
print('KNN AUC %.2f' % roc_auc_score(train['target'], train['preds_knn']))
print('MLP AUC %.2f' % roc_auc_score(train['target'], train['preds_mlp']))
print('LR AUC %.2f' % roc_auc_score(train['target'], train['preds_lr']))
print('NuSVC AUC %.2f' % roc_auc_score(train['target'], train['preds_nusvc']))
print('Top 2 AUC %.2f' % roc_auc_score(train['target'], train['preds_top2']))
print('Top 3 AUC %.2f' % roc_auc_score(train['target'], train['preds_top3']))
print('Top 4 AUC %.2f' % roc_auc_score(train['target'], train['preds_top4']))
print('Averaged AUC %.2f' % roc_auc_score(train['target'], train['preds_avg']))
# Out:
# QDA AUC 0.99
# KNN AUC 0.95
# MLP AUC 0.91
# LR AUC 0.56
# NuSVC AUC 0.97
# Top 2 AUC 0.99
# Top 3 AUC 0.99
# Top 4 AUC 0.99
# Averaged AUC 0.98

# %% [markdown]
# ### Test set with all models predictions

# %%
test[['id', 'target_avg', 'target_qda', 'target_knn', 'target_mlp', 'target_lr', 'target_nusvc']].head()
# Out:
#                                  id      ...       target_nusvc
# 0  1c13f2701648e0b0d46d8a2a5a131a53      ...           0.544861
# 1  ba88c155ba898fc8b5099893036ef205      ...           0.665736
# 2  7cbab5cea99169139e7e6d8ff74ebb77      ...           0.311650
# 3  ca820ad57809f62eb7b4d13f5d4371a0      ...           0.132472
# 4  7baaf361537fbd8a1aaa2c97a6d4ccc7      ...           0.112849
#
# [5 rows x 7 columns]

# %% [markdown]
# # Test predictions
# Now you can output predictions for each individual model and the ensembled models as well.
#
# #### Averaged models submission

# %%
submission = test[['id', 'target_avg']]
submission.columns = ['id', 'target']
submission.to_csv('submission_avg.csv', index=False)
submission.head()
# Out:
#                                  id    target
# 0  1c13f2701648e0b0d46d8a2a5a131a53  0.612375
# 1  ba88c155ba898fc8b5099893036ef205  0.667982
# 2  7cbab5cea99169139e7e6d8ff74ebb77  0.338951
# 3  ca820ad57809f62eb7b4d13f5d4371a0  0.244387
# 4  7baaf361537fbd8a1aaa2c97a6d4ccc7  0.299382

# %%
submission = test[['id', 'target_top2']]
submission.columns = ['id', 'target']
submission.to_csv('submission_top2.csv', index=False)
submission.head()
# Out:
#                                  id    target
# 0  1c13f2701648e0b0d46d8a2a5a131a53  0.772416
# 1  ba88c155ba898fc8b5099893036ef205  0.826856
# 2  7cbab5cea99169139e7e6d8ff74ebb77  0.155825
# 3  ca820ad57809f62eb7b4d13f5d4371a0  0.103870
# 4  7baaf361537fbd8a1aaa2c97a6d4ccc7  0.275472

# %%
submission = test[['id', 'target_top3']]
submission.columns = ['id', 'target']
submission.to_csv('submission_top3.csv', index=False)
submission.head()
# Out:
#                                  id    target
# 0  1c13f2701648e0b0d46d8a2a5a131a53  0.690188
# 1  ba88c155ba898fc8b5099893036ef205  0.802648
# 2  7cbab5cea99169139e7e6d8ff74ebb77  0.218260
# 3  ca820ad57809f62eb7b4d13f5d4371a0  0.111459
# 4  7baaf361537fbd8a1aaa2c97a6d4ccc7  0.217694

# %%
submission = test[['id', 'target_top4']]
submission.columns = ['id', 'target']
submission.to_csv('submission_top4.csv', index=False)
submission.head()
# Out:
#                                  id    target
# 0  1c13f2701648e0b0d46d8a2a5a131a53  0.635789
# 1  ba88c155ba898fc8b5099893036ef205  0.721342
# 2  7cbab5cea99169139e7e6d8ff74ebb77  0.296684
# 3  ca820ad57809f62eb7b4d13f5d4371a0  0.209227
# 4  7baaf361537fbd8a1aaa2c97a6d4ccc7  0.283318

# %%
submission = test[['id', 'target_qda']]
submission.columns = ['id', 'target']
submission.to_csv('submission_qda.csv', index=False)
submission.head()
# Out:
#                                  id        target
# 0  1c13f2701648e0b0d46d8a2a5a131a53  9.999712e-01
# 1  ba88c155ba898fc8b5099893036ef205  9.879759e-01
# 2  7cbab5cea99169139e7e6d8ff74ebb77  2.529365e-07
# 3  ca820ad57809f62eb7b4d13f5d4371a0  7.526842e-02
# 4  7baaf361537fbd8a1aaa2c97a6d4ccc7  4.380961e-01

# %%
submission = test[['id', 'target_knn']]
submission.columns = ['id', 'target']
submission.to_csv('submission_knn.csv', index=False)
submission.head()
# Out:
#                                  id    target
# 0  1c13f2701648e0b0d46d8a2a5a131a53  0.518717
# 1  ba88c155ba898fc8b5099893036ef205  0.454545
# 2  7cbab5cea99169139e7e6d8ff74ebb77  0.508021
# 3  ca820ad57809f62eb7b4d13f5d4371a0  0.385027
# 4  7baaf361537fbd8a1aaa2c97a6d4ccc7  0.363636

# %%
submission = test[['id', 'target_mlp']]
submission.columns = ['id', 'target']
submission.to_csv('submission_mlp.csv', index=False)
submission.head()
# Out:
#                                  id    target
# 0  1c13f2701648e0b0d46d8a2a5a131a53  0.498324
# 1  ba88c155ba898fc8b5099893036ef205  0.746164
# 2  7cbab5cea99169139e7e6d8ff74ebb77  0.363939
# 3  ca820ad57809f62eb7b4d13f5d4371a0  0.129167
# 4  7baaf361537fbd8a1aaa2c97a6d4ccc7  0.082877

# %%
submission = test[['id', 'target_lr']]
submission.columns = ['id', 'target']
submission.to_csv('submission_lr.csv', index=False)
submission.head()
# Out:
#                                  id    target
# 0  1c13f2701648e0b0d46d8a2a5a131a53  0.500000
# 1  ba88c155ba898fc8b5099893036ef205  0.485491
# 2  7cbab5cea99169139e7e6d8ff74ebb77  0.511145
# 3  ca820ad57809f62eb7b4d13f5d4371a0  0.500000
# 4  7baaf361537fbd8a1aaa2c97a6d4ccc7  0.499450

# %%
submission = test[['id', 'target_nusvc']]
submission.columns = ['id', 'target']
submission.to_csv('submission_nusvc.csv', index=False)
submission.head()
# Out:
#                                  id    target
# 0  1c13f2701648e0b0d46d8a2a5a131a53  0.544861
# 1  ba88c155ba898fc8b5099893036ef205  0.665736
# 2  7cbab5cea99169139e7e6d8ff74ebb77  0.311650
# 3  ca820ad57809f62eb7b4d13f5d4371a0  0.132472
# 4  7baaf361537fbd8a1aaa2c97a6d4ccc7  0.112849
