# %% [markdown]
# # Dependencies

# %%
import warnings
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

from sklearn.ensemble import AdaBoostClassifier
from sklearn.feature_selection import VarianceThreshold
from sklearn.preprocessing import MinMaxScaler, StandardScaler
from sklearn.model_selection import train_test_split, StratifiedKFold
from sklearn.metrics import confusion_matrix, roc_auc_score, recall_score, precision_score

# Set seeds to make the experiment more reproducible.
from numpy.random import seed
seed(0)

# %matplotlib inline
sns.set_style("whitegrid")
warnings.filterwarnings("ignore")

# %% [markdown]
# # Load data

# %%
train = pd.read_csv('../input/train.csv')
test = pd.read_csv('../input/test.csv')

# %%
print('Train set shape:', train.shape)
print('Test set shape:', test.shape)
print('Train set overview:')
display(train.head())
# Out:
# Train set shape: (262144, 258)
# Test set shape: (131073, 257)
# Train set overview:
#                                  id   ...    target
# 0  707b395ecdcbb4dc2eabea00e4d1b179   ...         0
# 1  5880c03c6582a7b42248668e56b4bdec   ...         0
# 2  4ccbcb3d13e5072ff1d9c61afe2c4f77   ...         1
# 3  e350f17a357f12a1941f0837afb7eb8d   ...         0
# 4  a8f910ea6075b6376af079055965ff68   ...         0
#
# [5 rows x 258 columns]

# %% [markdown]
# ## Preprocess

# %% [markdown]
# # Model
#
# ## Model parameters

# %%
N_FOLDS = 11

# %%
# INITIALIZE VARIABLES
cols = [c for c in train.columns if c not in ['id', 'target', 'wheezy-copper-turtle-magic', 'preds']]
test['target'] = 0
train['preds'] = 0

# BUILD 512 MODELS
for i in range(512):
    print('wheezy-copper-turtle-magic {}\n'.format(i))
    
    # EXTRACT SUBSET OF DATASET WHERE WHEEZY-MAGIC EQUALS I
    train2 = train[train['wheezy-copper-turtle-magic']==i]
    test2 = test[test['wheezy-copper-turtle-magic']==i]
    idx1 = train2.index
    idx2 = test2.index
    train2.reset_index(drop=True, inplace=True)
    
    # FEATURE SELECTION (USE APPROX 40 OF 255 FEATURES)
    sel = VarianceThreshold(threshold=1.5).fit(train2[cols])
    train3 = sel.transform(train2[cols])
    test3 = sel.transform(test2[cols])

    skf = StratifiedKFold(n_splits=N_FOLDS, random_state=0)
    counter = 0

    for train_index, val_index in skf.split(train3, train2['target']):
        counter += 1
        print('Fold {}\n'.format(counter))
        model = AdaBoostClassifier()
        model.fit(train3[train_index,:], train2.loc[train_index]['target'])
        
        train_predictions = model.predict(train3[train_index,:])
        val_predictions = model.predict(train3[val_index,:])

        train_auc = roc_auc_score(train2.loc[train_index]['target'], train_predictions) * 100
        val_auc = roc_auc_score(train2.loc[val_index]['target'], val_predictions) * 100
        train_precision = precision_score(train2.loc[train_index]['target'], train_predictions) * 100
        val_precision = precision_score(train2.loc[val_index]['target'], val_predictions) * 100
        train_recall = recall_score(train2.loc[train_index]['target'], train_predictions) * 100
        val_recall = recall_score(train2.loc[val_index]['target'], val_predictions) * 100
        print('-----Train----------')
        print('AUC: %.2f Precision: %.2f Recall: %.2f \n' % (train_auc, train_precision, train_recall))
        print('-----Validation-----')
        print('AUC: %.2f Precision: %.2f Recall: %.2f \n' % (val_auc, val_precision, val_recall))

        # Make predictions
        train['preds'].loc[idx1] += model.predict_proba(train3)[:,1] / N_FOLDS
        test['target'].loc[idx2] += model.predict_proba(test3)[:,1] / N_FOLDS
# Out:
# wheezy-copper-turtle-magic 0
#
# Fold 1
#
# -----Train----------
# AUC: 91.33 Precision: 91.56 Recall: 90.79
#
# -----Validation-----
# AUC: 73.17 Precision: 82.35 Recall: 58.33
#
# Fold 2
#
# -----Train----------
# AUC: 93.38 Precision: 94.42 Recall: 92.05
#
# -----Validation-----
# AUC: 75.58 Precision: 73.08 Recall: 79.17
#
# Fold 3
#
# -----Train----------
# AUC: 92.37 Precision: 92.44 Recall: 92.05
#
# -----Validation-----
# AUC: 75.50 Precision: 75.00 Recall: 75.00
#
# Fold 4
#
# -----Train----------
# AUC: 90.50 Precision: 91.42 Recall: 89.12
#
# -----Validation-----
# AUC: 61.25 Precision: 60.00 Recall: 62.50
#
# Fold 5
#
# -----Train----------
# AUC: 92.58 Precision: 92.12 Recall: 92.89
#
# -----Validation-----
# AUC: 59.33 Precision: 57.14 Recall: 66.67
#
# Fold 6
#
# -----Train----------
# AUC: 90.72 Precision: 90.42 Recall: 90.79
#
# -----Validation-----
# AUC: 65.08 Precision: 68.42 Recall: 54.17
#
# Fold 7
#
# -----Train----------
# AUC: 91.74 Precision: 92.34 Recall: 90.79
#
# -----Validation-----
# AUC: 69.08 Precision: 76.47 Recall: 54.17
#
# Fold 8
#
# -----Train----------
# AUC: 90.73 Precision: 90.76 Recall: 90.38
#
# -----Validation-----
# AUC: 66.67 Precision: 65.38 Recall: 70.83
#
# Fold 9
#
# -----Train----------
# AUC: 91.77 Precision: 91.63 Recall: 91.63
#
# -----Validation-----
# AUC: 58.33 Precision: 56.67 Recall: 70.83
#
# Fold 10
#
# -----Train----------
# AUC: 91.14 Precision: 91.53 Recall: 90.38
#
# -----Validation-----
# AUC: 66.67 Precision: 70.00 Recall: 58.33
#
# Fold 11
#
# -----Train----------
# AUC: 92.83 Precision: 91.84 Recall: 93.75
#
# -----Validation-----
# AUC: 70.20 Precision: 69.57 Recall: 69.57
#
# wheezy-copper-turtle-magic 1
#
# Fold 1
#
# -----Train----------
# AUC: 93.27 Precision: 93.64 Recall: 92.38
#
# -----Validation-----
# AUC: 81.07 Precision: 75.00 Recall: 91.30
#
# Fold 2
#
# -----Train----------
# AUC: 93.88 Precision: 95.35 Recall: 91.93
#
# -----Validation-----
# AUC: 80.89 Precision: 79.17 Recall: 82.61
#
# Fold 3
#
# -----Train----------
# AUC: 94.62 Precision: 93.81 Recall: 95.07
#
# -----Validation-----
# AUC: 67.93 Precision: 70.00 Recall: 60.87
#
# Fold 4
#
# -----Train----------
# AUC: 92.52 Precision: 90.17 Recall: 94.62
#
# -----Validation-----
# AUC: 80.80 Precision: 81.82 Recall: 78.26
#
# Fold 5
#
# -----Train----------
# AUC: 93.10 Precision: 92.86 Recall: 92.86
#
# -----Validation-----
# AUC: 73.48 Precision: 77.78 Recall: 63.64
#
# Fold 6
#
# -----Train----------
# AUC: 94.82 Precision: 94.64 Recall: 94.64
#
# -----Validation-----
# AUC: 71.78 Precision: 69.57 Recall: 72.73
#
# Fold 7
#
# -----Train----------
# AUC: 92.02 Precision: 91.56 Recall: 91.96
#
# -----Validation-----
# AUC: 80.30 Precision: 80.95 Recall: 77.27
#
# Fold 8
#
# -----Train----------
# AUC: 94.58 Precision: 95.02 Recall: 93.75
#
# -----Validation-----
# AUC: 77.84 Precision: 83.33 Recall: 68.18
#
# Fold 9
#
# -----Train----------
# AUC: 93.93 Precision: 94.55 Recall: 92.86
#
# -----Validation-----
# AUC: 69.70 Precision: 66.67 Recall: 72.73
#
# Fold 10
#
# -----Train----------
# AUC: 92.44 Precision: 92.38 Recall: 91.96
#
# -----Validation-----
# AUC: 82.77 Precision: 79.17 Recall: 86.36
#
# Fold 11
#
# -----Train----------
# AUC: 93.96 Precision: 93.75 Recall: 93.75
#
# -----Validation-----
# AUC: 73.48 Precision: 77.78 Recall: 63.64
#
# wheezy-copper-turtle-magic 2
#
# Fold 1
#
# -----Train----------
# AUC: 89.31 Precision: 89.09 Recall: 89.09
#
# -----Validation-----
# AUC: 65.22 Precision: 62.96 Recall: 73.91
#
# Fold 2
#
# -----Train----------
# AUC: 89.56 Precision: 88.84 Recall: 90.05
#
# -----Validation-----
# AUC: 57.81 Precision: 56.52 Recall: 59.09
#
# Fold 3
#
# -----Train----------
# AUC: 90.02 Precision: 88.94 Recall: 90.95
#
# -----Validation-----
# AUC: 64.53 Precision: 62.50 Recall: 68.18
#
# Fold 4
#
# -----Train----------
# AUC: 88.00 Precision: 87.44 Recall: 88.24
#
# -----Validation-----
# AUC: 68.97 Precision: 66.67 Recall: 72.73
#
# Fold 5
#
# -----Train----------
# AUC: 89.12 Precision: 88.39 Recall: 89.59
#
# -----Validation-----
# AUC: 62.35 Precision: 60.00 Recall: 68.18
#
# Fold 6
#
# -----Train----------
# AUC: 89.33 Precision: 89.14 Recall: 89.14
#
# -----Validation-----
# AUC: 71.25 Precision: 68.00 Recall: 77.27
#
# Fold 7
#
# -----Train----------
# AUC: 90.23 Precision: 89.69 Recall: 90.50
#
# -----Validation-----
# AUC: 62.06 Precision: 63.16 Recall: 54.55
#
# Fold 8
#
# -----Train----------
# AUC: 86.86 Precision: 87.50 Recall: 85.52
#
# -----Validation-----
# AUC: 66.50 Precision: 68.42 Recall: 59.09
#
# Fold 9
#
# -----Train----------
# AUC: 91.33 Precision: 91.36 Recall: 90.95
#
# -----Validation-----
# AUC: 66.70 Precision: 65.22 Recall: 68.18
#
# Fold 10
#
# -----Train----------
# AUC: 89.29 Precision: 91.00 Recall: 86.88
#
# -----Validation-----
# AUC: 60.08 Precision: 58.33 Recall: 63.64
#
# Fold 11
#
# -----Train----------
# AUC: 87.55 Precision: 88.37 Recall: 85.97
#
# -----Validation-----
# AUC: 79.55 Precision: 84.21 Recall: 72.73
#
# wheezy-copper-turtle-magic 3
#
# Fold 1
#
# -----Train----------
# AUC: 90.30 Precision: 90.00 Recall: 91.76
#
# -----Validation-----
# AUC: 75.80 Precision: 75.00 Recall: 80.77
#
# Fold 2
#
# -----Train----------
# AUC: 90.38 Precision: 91.27 Recall: 90.20
#
# -----Validation-----
# AUC: 69.87 Precision: 70.37 Recall: 73.08
#
# Fold 3
#
# -----Train----------
# AUC: 91.55 Precision: 91.47 Recall: 92.55
#
# -----Validation-----
# AUC: 71.96 Precision: 73.08 Recall: 73.08
#
# Fold 4
#
# -----Train----------
# AUC: 90.48 Precision: 89.73 Recall: 92.55
#
# -----Validation-----
# AUC: 78.21 Precision: 82.61 Recall: 73.08
#
# Fold 5
#
# -----Train----------
# AUC: 91.79 Precision: 91.83 Recall: 92.55
#
# -----Validation-----
# AUC: 65.55 Precision: 69.57 Recall: 61.54
#
# Fold 6
#
# -----Train----------
# AUC: 89.08 Precision: 88.55 Recall: 90.98
#
# -----Validation-----
# AUC: 85.54 Precision: 85.19 Recall: 88.46
#
# Fold 7
#
# -----Train----------
# AUC: 91.14 Precision: 90.49 Recall: 92.97
#
# -----Validation-----
# AUC: 68.61 Precision: 69.23 Recall: 72.00
#
# Fold 8
#
# -----Train----------
# AUC: 90.77 Precision: 90.73 Recall: 91.80
#
# -----Validation-----
# AUC: 60.26 Precision: 61.54 Recall: 64.00
#
# Fold 9
#
# -----Train----------
# AUC: 89.93 Precision: 89.66 Recall: 91.41
#
# -----Validation-----
# AUC: 60.09 Precision: 60.71 Recall: 68.00
#
# Fold 10
#
# -----Train----------
# AUC: 90.79 Precision: 91.05 Recall: 91.41
#
# -----Validation-----
# AUC: 72.78 Precision: 73.08 Recall: 76.00
#
# Fold 11
#
# -----Train----------
# AUC: 91.18 Precision: 91.12 Recall: 92.19
#
# -----Validation-----
# AUC: 72.96 Precision: 75.00 Recall: 72.00
#
# wheezy-copper-turtle-magic 4
#
# Fold 1
#
# -----Train----------
# AUC: 92.94 Precision: 92.50 Recall: 93.67
#
# -----Validation-----
# AUC: 70.83 Precision: 72.73 Recall: 66.67
#
# Fold 2
#
# -----Train----------
# AUC: 92.08 Precision: 91.67 Recall: 92.83
#
# -----Validation-----
# AUC: 64.58 Precision: 64.00 Recall: 66.67
#
# Fold 3
#
# -----Train----------
# AUC: 90.41 Precision: 91.03 Recall: 89.87
#
# -----Validation-----
# AUC: 74.55 Precision: 77.27 Recall: 70.83
#
# Fold 4
#
# -----Train----------
# AUC: 91.69 Precision: 92.67 Recall: 90.72
#
# -----Validation-----
# AUC: 72.19 Precision: 70.37 Recall: 79.17
#
# Fold 5
#
# -----Train----------
# AUC: 91.68 Precision: 91.60 Recall: 91.98
#
# -----Validation-----
# AUC: 70.20 Precision: 70.83 Recall: 70.83
#
# Fold 6
#
# -----Train----------
# AUC: 92.55 Precision: 93.53 Recall: 91.56
#
# -----Validation-----
# AUC: 72.55 Precision: 78.95 Recall: 62.50
#
# Fold 7
#
# -----Train----------
# AUC: 91.91 Precision: 93.07 Recall: 90.72
#
# -----Validation-----
# AUC: 74.46 Precision: 75.00 Recall: 75.00
#
# Fold 8
#
# -----Train----------
# AUC: 89.98 Precision: 90.60 Recall: 89.45
#
# -----Validation-----
# AUC: 68.03 Precision: 68.00 Recall: 70.83
#
# Fold 9
#
# -----Train----------
# AUC: 91.26 Precision: 90.53 Recall: 92.44
#
# -----Validation-----
# AUC: 73.91 Precision: 76.19 Recall: 69.57
#
# Fold 10
#
# -----Train----------
# AUC: 91.71 Precision: 92.34 Recall: 91.18
#
# -----Validation-----
# AUC: 67.39 Precision: 66.67 Recall: 69.57
#
# Fold 11
#
# -----Train----------
# AUC: 91.71 Precision: 92.70 Recall: 90.76
#
# -----Validation-----
# AUC: 73.91 Precision: 73.91 Recall: 73.91
#
# wheezy-copper-turtle-magic 5
#
# Fold 1
#
# -----Train----------
# AUC: 91.33 Precision: 91.45 Recall: 91.06
#
# -----Validation-----
# AUC: 72.92 Precision: 73.91 Recall: 70.83
#
# Fold 2
#
# -----Train----------
# AUC: 90.90 Precision: 91.38 Recall: 90.21
#
# -----Validation-----
# AUC: 64.58 Precision: 64.00 Recall: 66.67
#
# Fold 3
#
# -----Train----------
# AUC: 91.33 Precision: 91.10 Recall: 91.49
#
# -----Validation-----
# AUC: 66.67 Precision: 65.38 Recall: 70.83
#
# Fold 4
#
# -----Train----------
# AUC: 90.06 Precision: 90.87 Recall: 88.94
#
# -----Validation-----
# AUC: 68.75 Precision: 65.52 Recall: 79.17
#
# Fold 5
#
# -----Train----------
# AUC: 90.50 Precision: 89.26 Recall: 91.91
#
# -----Validation-----
# AUC: 64.58 Precision: 64.00 Recall: 66.67
#
# Fold 6
#
# -----Train----------
# AUC: 91.32 Precision: 92.54 Recall: 89.79
#
# -----Validation-----
# AUC: 58.33 Precision: 60.00 Recall: 50.00
#
# Fold 7
#
# -----Train----------
# AUC: 90.51 Precision: 89.96 Recall: 91.10
#
# -----Validation-----
# AUC: 65.85 Precision: 66.67 Recall: 60.87
#
# Fold 8
#
# -----Train----------
# AUC: 91.35 Precision: 91.14 Recall: 91.53
#
# -----Validation-----
# AUC: 63.68 Precision: 65.00 Recall: 56.52
#
# Fold 9
#
# -----Train----------
# AUC: 90.51 Precision: 90.64 Recall: 90.25
#
# -----Validation-----
# AUC: 70.56 Precision: 64.52 Recall: 86.96
#
# Fold 10
#
# -----Train----------
# AUC: 89.04 Precision: 90.00 Recall: 87.71
#
# -----Validation-----
# AUC: 73.91 Precision: 68.97 Recall: 86.96
#
# Fold 11
#
# -----Train----------
# AUC: 92.64 Precision: 92.05 Recall: 93.22
#
# -----Validation-----
# AUC: 67.39 Precision: 66.67 Recall: 69.57
#
# wheezy-copper-turtle-magic 6
#
# Fold 1
#
# -----Train----------
# AUC: 92.76 Precision: 92.92 Recall: 92.92
#
# -----Validation-----
# AUC: 66.43 Precision: 66.67 Recall: 72.00
#
# Fold 2
#
# -----Train----------
# AUC: 92.14 Precision: 92.15 Recall: 92.53
#
# -----Validation-----
# AUC: 76.54 Precision: 76.00 Recall: 79.17
#
# Fold 3
#
# -----Train----------
# AUC: 93.20 Precision: 93.36 Recall: 93.36
#
# -----Validation-----
# AUC: 76.45 Precision: 74.07 Recall: 83.33
#
# Fold 4
#
# -----Train----------
# AUC: 91.92 Precision: 91.77 Recall: 92.53
#
# -----Validation-----
# AUC: 89.31 Precision: 88.00 Recall: 91.67
#
# Fold 5
#
# -----Train----------
# AUC: 92.97 Precision: 92.62 Recall: 93.78
#
# -----Validation-----
# AUC: 55.43 Precision: 57.14 Recall: 50.00
#
# Fold 6
#
# -----Train----------
# AUC: 92.34 Precision: 92.18 Recall: 92.95
#
# -----Validation-----
# AUC: 74.55 Precision: 77.27 Recall: 70.83
#
# Fold 7
#
# -----Train----------
# AUC: 89.77 Precision: 89.07 Recall: 91.29
#
# -----Validation-----
# AUC: 74.46 Precision: 75.00 Recall: 75.00
#
# Fold 8
#
# -----Train----------
# AUC: 90.65 Precision: 90.87 Recall: 90.87
#
# -----Validation-----
# AUC: 70.20 Precision: 70.83 Recall: 70.83
#
# Fold 9
#
# -----Train----------
# AUC: 93.62 Precision: 93.42 Recall: 94.19
#
# -----Validation-----
# AUC: 68.03 Precision: 68.00 Recall: 70.83
#
# Fold 10
#
# -----Train----------
# AUC: 93.63 Precision: 93.78 Recall: 93.78
#
# -----Validation-----
# AUC: 63.77 Precision: 64.00 Recall: 66.67
#
# Fold 11
#
# -----Train----------
# AUC: 92.17 Precision: 93.59 Recall: 90.87
#
# -----Validation-----
# AUC: 59.51 Precision: 60.00 Recall: 62.50
#
# wheezy-copper-turtle-magic 7
#
# Fold 1
#
# -----Train----------
# AUC: 91.72 Precision: 89.67 Recall: 94.35
#
# -----Validation-----
# AUC: 67.93 Precision: 66.67 Recall: 75.00
#
# Fold 2
#
# -----Train----------
# AUC: 92.17 Precision: 92.21 Recall: 92.21
#
# -----Validation-----
# AUC: 65.22 Precision: 73.33 Recall: 47.83
#
# Fold 3
#
# -----Train----------
# AUC: 90.87 Precision: 91.27 Recall: 90.48
#
# -----Validation-----
# AUC: 71.74 Precision: 75.00 Recall: 65.22
#
# Fold 4
#
# -----Train----------
# AUC: 91.52 Precision: 91.74 Recall: 91.34
#
# -----Validation-----
# AUC: 58.70 Precision: 60.00 Recall: 52.17
#
# Fold 5
#
# -----Train----------
# AUC: 91.30 Precision: 91.34 Recall: 91.34
#
# -----Validation-----
# AUC: 67.39 Precision: 68.18 Recall: 65.22
#
# Fold 6
#
# -----Train----------
# AUC: 90.88 Precision: 92.76 Recall: 88.74
#
# -----Validation-----
# AUC: 71.74 Precision: 69.23 Recall: 78.26
#
# Fold 7
#
# -----Train----------
# AUC: 90.00 Precision: 90.04 Recall: 90.04
#
# -----Validation-----
# AUC: 63.04 Precision: 65.00 Recall: 56.52
#
# Fold 8
#
# -----Train----------
# AUC: 91.74 Precision: 92.14 Recall: 91.34
#
# -----Validation-----
# AUC: 71.74 Precision: 72.73 Recall: 69.57
#
# Fold 9
#
# -----Train----------
# AUC: 90.65 Precision: 91.23 Recall: 90.04
#
# -----Validation-----
# AUC: 67.39 Precision: 65.38 Recall: 73.91
#
# Fold 10
#
# -----Train----------
# AUC: 89.57 Precision: 89.61 Recall: 89.61
#
# -----Validation-----
# AUC: 78.26 Precision: 76.00 Recall: 82.61
#
# Fold 11
#
# -----Train----------
# AUC: 90.46 Precision: 91.19 Recall: 89.61
#
# -----Validation-----
# AUC: 66.70 Precision: 68.18 Recall: 65.22
#
# wheezy-copper-turtle-magic 8
#
# Fold 1
#
# -----Train----------
# AUC: 87.11 Precision: 87.87 Recall: 86.78
#
# -----Validation-----
# AUC: 71.25 Precision: 68.97 Recall: 80.00
#
# Fold 2
#
# -----Train----------
# AUC: 90.67 Precision: 90.24 Recall: 91.74
#
# -----Validation-----
# AUC: 61.17 Precision: 61.54 Recall: 64.00
#
# Fold 3
#
# -----Train----------
# AUC: 89.03 Precision: 89.58 Recall: 88.84
#
# -----Validation-----
# AUC: 62.09 Precision: 62.07 Recall: 72.00
#
# Fold 4
#
# -----Train----------
# AUC: 87.34 Precision: 87.04 Recall: 88.48
#
# -----Validation-----
# AUC: 72.46 Precision: 76.19 Recall: 66.67
#
# Fold 5
#
# -----Train----------
# AUC: 89.71 Precision: 91.10 Recall: 88.48
#
# -----Validation-----
# AUC: 67.75 Precision: 64.52 Recall: 83.33
#
# Fold 6
#
# -----Train----------
# AUC: 89.66 Precision: 89.43 Recall: 90.53
#
# -----Validation-----
# AUC: 76.72 Precision: 80.95 Recall: 70.83
#
# Fold 7
#
# -----Train----------
# AUC: 89.69 Precision: 90.42 Recall: 89.30
#
# -----Validation-----
# AUC: 59.60 Precision: 60.87 Recall: 58.33
#
# Fold 8
#
# -----Train----------
# AUC: 89.08 Precision: 90.30 Recall: 88.07
#
# -----Validation-----
# AUC: 59.60 Precision: 60.87 Recall: 58.33
#
# Fold 9
#
# -----Train----------
# AUC: 91.36 Precision: 91.39 Recall: 91.77
#
# -----Validation-----
# AUC: 61.68 Precision: 62.50 Recall: 62.50
#
# Fold 10
#
# -----Train----------
# AUC: 88.45 Precision: 89.83 Recall: 87.24
#
# -----Validation-----
# AUC: 59.42 Precision: 59.26 Recall: 66.67
#
# Fold 11
#
# -----Train----------
# AUC: 89.44 Precision: 88.76 Recall: 90.95
#
# -----Validation-----
# AUC: 57.61 Precision: 60.00 Recall: 50.00
#
# wheezy-copper-turtle-magic 9
#
# Fold 1
#
# -----Train----------
# AUC: 89.58 Precision: 90.60 Recall: 88.33
#
# -----Validation-----
# AUC: 62.50 Precision: 65.00 Recall: 54.17
#
# Fold 2
#
# -----Train----------
# AUC: 90.00 Precision: 89.67 Recall: 90.42
#
# -----Validation-----
# AUC: 64.58 Precision: 62.07 Recall: 75.00
#
# Fold 3
#
# -----Train----------
# AUC: 89.79 Precision: 89.63 Recall: 90.00
#
# -----Validation-----
# AUC: 64.58 Precision: 65.22 Recall: 62.50
#
# Fold 4
#
# -----Train----------
# AUC: 90.42 Precision: 91.10 Recall: 89.58
#
# -----Validation-----
# AUC: 64.58 Precision: 62.07 Recall: 75.00
#
# Fold 5
#
# -----Train----------
# AUC: 90.83 Precision: 91.53 Recall: 90.00
#
# -----Validation-----
# AUC: 68.75 Precision: 68.00 Recall: 70.83
#
# Fold 6
#
# -----Train----------
# AUC: 89.17 Precision: 87.90 Recall: 90.83
#
# -----Validation-----
# AUC: 75.00 Precision: 83.33 Recall: 62.50
#
# Fold 7
#
# -----Train----------
# AUC: 89.79 Precision: 88.35 Recall: 91.67
#
# -----Validation-----
# AUC: 68.75 Precision: 71.43 Recall: 62.50
#
# Fold 8
#
# -----Train----------
# AUC: 91.25 Precision: 90.91 Recall: 91.67
#
# -----Validation-----
# AUC: 56.25 Precision: 55.17 Recall: 66.67
#
# Fold 9
#
# -----Train----------
# AUC: 88.96 Precision: 87.85 Recall: 90.42
#
# -----Validation-----
# AUC: 60.42 Precision: 58.62 Recall: 70.83
#
# Fold 10
#
# -----Train----------
# AUC: 88.75 Precision: 89.41 Recall: 87.92
#
# -----Validation-----
# AUC: 64.58 Precision: 62.96 Recall: 70.83
#
# Fold 11
#
# -----Train----------
# AUC: 90.62 Precision: 91.85 Recall: 89.17
#
# -----Validation-----
# AUC: 56.25 Precision: 57.89 Recall: 45.83
#
# wheezy-copper-turtle-magic 10
#
# Fold 1
#
# -----Train----------
# AUC: 94.01 Precision: 94.95 Recall: 92.83
#
# -----Validation-----
# AUC: 73.91 Precision: 76.19 Recall: 69.57
#
# Fold 2
#
# -----Train----------
# AUC: 93.80 Precision: 94.12 Recall: 93.27
#
# -----Validation-----
# AUC: 71.74 Precision: 70.83 Recall: 73.91
#
# Fold 3
#
# -----Train----------
# AUC: 94.91 Precision: 95.05 Recall: 94.62
#
# -----Validation-----
# AUC: 71.74 Precision: 75.00 Recall: 65.22
#
# Fold 4
#
# -----Train----------
# AUC: 95.80 Precision: 95.13 Recall: 96.41
#
# -----Validation-----
# AUC: 60.87 Precision: 60.00 Recall: 65.22
#
# Fold 5
#
# -----Train----------
# AUC: 93.16 Precision: 92.51 Recall: 93.75
#
# -----Validation-----
# AUC: 66.60 Precision: 66.67 Recall: 63.64
#
# Fold 6
#
# -----Train----------
# AUC: 93.60 Precision: 93.33 Recall: 93.75
#
# -----Validation-----
# AUC: 62.25 Precision: 60.87 Recall: 63.64
#
# Fold 7
#
# -----Train----------
# AUC: 92.93 Precision: 93.64 Recall: 91.96
#
# -----Validation-----
# AUC: 73.32 Precision: 72.73 Recall: 72.73
#
# Fold 8
#
# -----Train----------
# AUC: 94.91 Precision: 95.89 Recall: 93.75
#
# -----Validation-----
# AUC: 71.25 Precision: 68.00 Recall: 77.27
#
# Fold 9
#
# -----Train----------
# AUC: 93.59 Precision: 94.12 Recall: 92.86
#
# -----Validation-----
# AUC: 84.49 Precision: 82.61 Recall: 86.36
#
# Fold 10
#
# -----Train----------
# AUC: 94.05 Precision: 93.39 Recall: 94.64
#
# -----Validation-----
# AUC: 79.94 Precision: 80.95 Recall: 77.27
#
# Fold 11
#
# -----Train----------
# AUC: 94.48 Precision: 95.02 Recall: 93.75
#
# -----Validation-----
# AUC: 63.64 Precision: 66.67 Recall: 54.55
#
# wheezy-copper-turtle-magic 11
#
# Fold 1
#
# -----Train----------
# AUC: 91.82 Precision: 89.91 Recall: 93.33
#
# -----Validation-----
# AUC: 73.42 Precision: 70.83 Recall: 77.27
#
# Fold 2
#
# -----Train----------
# AUC: 91.97 Precision: 92.31 Recall: 91.00
#
# -----Validation-----
# AUC: 70.08 Precision: 72.22 Recall: 61.90
#
# Fold 3
#
# -----Train----------
# AUC: 91.72 Precision: 92.68 Recall: 90.05
#
# -----Validation-----
# AUC: 77.23 Precision: 76.19 Recall: 76.19
#
# Fold 4
#
# -----Train----------
# AUC: 92.63 Precision: 93.66 Recall: 91.00
#
# -----Validation-----
# AUC: 66.36 Precision: 61.54 Recall: 76.19
#
# Fold 5
#
# -----Train----------
# AUC: 89.87 Precision: 91.13 Recall: 87.68
#
# -----Validation-----
# AUC: 70.08 Precision: 72.22 Recall: 61.90
#
# Fold 6
#
# -----Train----------
# AUC: 91.06 Precision: 91.35 Recall: 90.05
#
# -----Validation-----
# AUC: 68.32 Precision: 65.22 Recall: 71.43
#
# Fold 7
#
# -----Train----------
# AUC: 92.45 Precision: 92.38 Recall: 91.94
#
# -----Validation-----
# AUC: 61.59 Precision: 58.33 Recall: 66.67
#
# Fold 8
#
# -----Train----------
# AUC: 92.24 Precision: 91.55 Recall: 92.42
#
# -----Validation-----
# AUC: 65.32 Precision: 68.75 Recall: 52.38
#
# Fold 9
#
# -----Train----------
# AUC: 90.87 Precision: 90.52 Recall: 90.52
#
# -----Validation-----
# AUC: 74.57 Precision: 70.83 Recall: 80.95
#
# Fold 10
#
# -----Train----------
# AUC: 91.79 Precision: 91.47 Recall: 91.47
#
# -----Validation-----
# AUC: 69.59 Precision: 72.22 Recall: 61.90
#
# Fold 11
#
# -----Train----------
# AUC: 92.66 Precision: 93.24 Recall: 91.47
#
# -----Validation-----
# AUC: 67.42 Precision: 66.67 Recall: 66.67
#
# wheezy-copper-turtle-magic 12
#
# Fold 1
#
# -----Train----------
# AUC: 94.22 Precision: 93.91 Recall: 94.74
#
# -----Validation-----
# AUC: 69.57 Precision: 71.43 Recall: 65.22
#
# Fold 2
#
# -----Train----------
# AUC: 94.46 Precision: 95.52 Recall: 93.42
#
# -----Validation-----
# AUC: 73.91 Precision: 70.37 Recall: 82.61
#
# Fold 3
#
# -----Train----------
# AUC: 92.69 Precision: 94.12 Recall: 91.23
#
# -----Validation-----
# AUC: 69.57 Precision: 71.43 Recall: 65.22
#
# Fold 4
#
# -----Train----------
# AUC: 93.80 Precision: 94.25 Recall: 93.42
#
# -----Validation-----
# AUC: 73.22 Precision: 72.00 Recall: 78.26
#
# Fold 5
#
# -----Train----------
# AUC: 94.68 Precision: 94.74 Recall: 94.74
#
# -----Validation-----
# AUC: 68.87 Precision: 69.57 Recall: 69.57
#
# Fold 6
#
# -----Train----------
# AUC: 93.56 Precision: 92.70 Recall: 94.74
#
# -----Validation-----
# AUC: 60.08 Precision: 61.90 Recall: 56.52
#
# Fold 7
#
# -----Train----------
# AUC: 91.80 Precision: 92.07 Recall: 91.67
#
# -----Validation-----
# AUC: 75.40 Precision: 73.08 Recall: 82.61
#
# Fold 8
#
# -----Train----------
# AUC: 92.68 Precision: 92.95 Recall: 92.54
#
# -----Validation-----
# AUC: 68.77 Precision: 68.00 Recall: 73.91
#
# Fold 9
#
# -----Train----------
# AUC: 93.79 Precision: 93.86 Recall: 93.86
#
# -----Validation-----
# AUC: 66.70 Precision: 68.18 Recall: 65.22
#
# Fold 10
#
# -----Train----------
# AUC: 94.03 Precision: 94.69 Recall: 93.45
#
# -----Validation-----
# AUC: 77.27 Precision: 77.27 Recall: 77.27
#
# Fold 11
#
# -----Train----------
# AUC: 92.03 Precision: 92.14 Recall: 92.14
#
# -----Validation-----
# AUC: 61.36 Precision: 63.16 Recall: 54.55
#
# wheezy-copper-turtle-magic 13
#
# Fold 1
#
# -----Train----------
# AUC: 87.70 Precision: 87.68 Recall: 86.85
#
# -----Validation-----
# AUC: 62.45 Precision: 59.26 Recall: 72.73
#
# Fold 2
#
# -----Train----------
# AUC: 87.94 Precision: 87.74 Recall: 87.32
#
# -----Validation-----
# AUC: 71.15 Precision: 69.57 Recall: 72.73
#
# Fold 3
#
# -----Train----------
# AUC: 91.55 Precision: 92.31 Recall: 90.14
#
# -----Validation-----
# AUC: 64.53 Precision: 62.50 Recall: 68.18
#
# Fold 4
#
# -----Train----------
# AUC: 90.64 Precision: 91.35 Recall: 89.20
#
# -----Validation-----
# AUC: 66.60 Precision: 66.67 Recall: 63.64
#
# Fold 5
#
# -----Train----------
# AUC: 91.12 Precision: 91.87 Recall: 89.72
#
# -----Validation-----
# AUC: 67.91 Precision: 68.42 Recall: 61.90
#
# Fold 6
#
# -----Train----------
# AUC: 90.00 Precision: 90.09 Recall: 89.25
#
# -----Validation-----
# AUC: 67.70 Precision: 70.59 Recall: 57.14
#
# Fold 7
#
# -----Train----------
# AUC: 90.90 Precision: 91.43 Recall: 89.72
#
# -----Validation-----
# AUC: 68.32 Precision: 65.22 Recall: 71.43
#
# Fold 8
#
# -----Train----------
# AUC: 91.60 Precision: 91.55 Recall: 91.12
#
# -----Validation-----
# AUC: 70.08 Precision: 72.22 Recall: 61.90
#
# Fold 9
#
# -----Train----------
# AUC: 90.01 Precision: 90.48 Recall: 88.79
#
# -----Validation-----
# AUC: 66.99 Precision: 76.92 Recall: 47.62
#
# Fold 10
#
# -----Train----------
# AUC: 89.57 Precision: 89.62 Recall: 88.79
#
# -----Validation-----
# AUC: 67.42 Precision: 66.67 Recall: 66.67
#
# Fold 11
#
# -----Train----------
# AUC: 91.12 Precision: 92.27 Recall: 89.25
#
# -----Validation-----
# AUC: 53.35 Precision: 52.63 Recall: 47.62
#
# wheezy-copper-turtle-magic 14
#
# Fold 1
#
# -----Train----------
# AUC: 91.16 Precision: 90.00 Recall: 91.30
#
# -----Validation-----
# AUC: 70.83 Precision: 70.00 Recall: 66.67
#
# Fold 2
#
# -----Train----------
# AUC: 91.75 Precision: 92.12 Recall: 90.34
#
# -----Validation-----
# AUC: 72.62 Precision: 76.47 Recall: 61.90
#
# Fold 3
#
# -----Train----------
# AUC: 94.32 Precision: 93.75 Recall: 94.20
#
# -----Validation-----
# AUC: 64.58 Precision: 60.87 Recall: 66.67
#
# Fold 4
#
# -----Train----------
# AUC: 91.78 Precision: 91.71 Recall: 90.82
#
# -----Validation-----
# AUC: 82.14 Precision: 80.95 Recall: 80.95
#
# Fold 5
#
# -----Train----------
# AUC: 93.36 Precision: 93.63 Recall: 92.27
#
# -----Validation-----
# AUC: 79.76 Precision: 80.00 Recall: 76.19
#
# Fold 6
#
# -----Train----------
# AUC: 93.40 Precision: 93.20 Recall: 92.75
#
# -----Validation-----
# AUC: 70.50 Precision: 68.18 Recall: 71.43
#
# Fold 7
#
# -----Train----------
# AUC: 92.04 Precision: 91.75 Recall: 91.30
#
# -----Validation-----
# AUC: 63.56 Precision: 61.90 Recall: 61.90
#
# Fold 8
#
# -----Train----------
# AUC: 92.64 Precision: 93.53 Recall: 90.82
#
# -----Validation-----
# AUC: 76.60 Precision: 86.67 Recall: 61.90
#
# Fold 9
#
# -----Train----------
# AUC: 90.91 Precision: 90.78 Recall: 89.90
#
# -----Validation-----
# AUC: 69.46 Precision: 68.42 Recall: 65.00
#
# Fold 10
#
# -----Train----------
# AUC: 93.05 Precision: 91.55 Recall: 93.75
#
# -----Validation-----
# AUC: 60.76 Precision: 56.52 Recall: 65.00
#
# Fold 11
#
# -----Train----------
# AUC: 94.96 Precision: 95.59 Recall: 93.75
#
# -----Validation-----
# AUC: 64.46 Precision: 64.71 Recall: 55.00
#
# wheezy-copper-turtle-magic 15
#
# Fold 1
#
# -----Train----------
# AUC: 92.51 Precision: 92.08 Recall: 93.25
#
# -----Validation-----
# AUC: 79.17 Precision: 75.00 Recall: 87.50
#
# Fold 2
#
# -----Train----------
# AUC: 91.01 Precision: 90.46 Recall: 91.98
#
# -----Validation-----
# AUC: 68.75 Precision: 69.57 Recall: 66.67
#
# Fold 3
#
# -----Train----------
# AUC: 91.90 Precision: 92.34 Recall: 91.56
#
# -----Validation-----
# AUC: 70.11 Precision: 69.23 Recall: 75.00
#
# Fold 4
#
# -----Train----------
# AUC: 90.41 Precision: 90.68 Recall: 90.30
#
# -----Validation-----
# AUC: 74.37 Precision: 73.08 Recall: 79.17
#
# Fold 5
#
# -----Train----------
# AUC: 92.32 Precision: 92.41 Recall: 92.41
#
# -----Validation-----
# AUC: 74.37 Precision: 73.08 Recall: 79.17
#
# Fold 6
#
# -----Train----------
# AUC: 91.90 Precision: 91.98 Recall: 91.98
#
# -----Validation-----
# AUC: 52.90 Precision: 53.33 Recall: 66.67
#
# Fold 7
#
# -----Train----------
# AUC: 91.25 Precision: 91.18 Recall: 91.56
#
# -----Validation-----
# AUC: 76.72 Precision: 80.95 Recall: 70.83
#
# Fold 8
#
# -----Train----------
# AUC: 92.97 Precision: 93.59 Recall: 92.41
#
# -----Validation-----
# AUC: 68.30 Precision: 73.68 Recall: 58.33
#
# Fold 9
#
# -----Train----------
# AUC: 91.08 Precision: 92.61 Recall: 89.50
#
# -----Validation-----
# AUC: 71.74 Precision: 72.73 Recall: 69.57
#
# Fold 10
#
# -----Train----------
# AUC: 90.63 Precision: 90.42 Recall: 91.18
#
# -----Validation-----
# AUC: 67.39 Precision: 72.22 Recall: 56.52
#
# Fold 11
#
# -----Train----------
# AUC: 92.55 Precision: 92.47 Recall: 92.86
#
# -----Validation-----
# AUC: 78.26 Precision: 80.95 Recall: 73.91
#
# wheezy-copper-turtle-magic 16
#
# Fold 1
#
# -----Train----------
# AUC: 91.68 Precision: 91.27 Recall: 91.67
#
# -----Validation-----
# AUC: 77.13 Precision: 75.00 Recall: 78.26
#
# Fold 2
#
# -----Train----------
# AUC: 93.59 Precision: 93.81 Recall: 92.98
#
# -----Validation-----
# AUC: 66.61 Precision: 65.22 Recall: 65.22
#
# Fold 3
#
# -----Train----------
# AUC: 90.63 Precision: 90.35 Recall: 90.35
#
# -----Validation-----
# AUC: 67.93 Precision: 70.00 Recall: 60.87
#
# Fold 4
#
# -----Train----------
# AUC: 93.40 Precision: 93.01 Recall: 93.42
#
# -----Validation-----
# AUC: 59.60 Precision: 58.33 Recall: 60.87
#
# Fold 5
#
# -----Train----------
# AUC: 92.82 Precision: 90.76 Recall: 94.74
#
# -----Validation-----
# AUC: 72.19 Precision: 75.00 Recall: 65.22
#
# Fold 6
#
# -----Train----------
# AUC: 93.81 Precision: 94.22 Recall: 92.98
#
# -----Validation-----
# AUC: 63.95 Precision: 61.54 Recall: 69.57
#
# Fold 7
#
# -----Train----------
# AUC: 92.54 Precision: 92.51 Recall: 92.11
#
# -----Validation-----
# AUC: 70.20 Precision: 69.57 Recall: 69.57
#
# Fold 8
#
# -----Train----------
# AUC: 91.90 Precision: 92.04 Recall: 91.23
#
# -----Validation-----
# AUC: 78.71 Precision: 78.26 Recall: 78.26
#
# Fold 9
#
# -----Train----------
# AUC: 90.45 Precision: 89.27 Recall: 91.23
#
# -----Validation-----
# AUC: 70.11 Precision: 71.43 Recall: 65.22
#
# Fold 10
#
# -----Train----------
# AUC: 92.11 Precision: 92.86 Recall: 90.83
#
# -----Validation-----
# AUC: 71.78 Precision: 69.57 Recall: 72.73
#
# Fold 11
#
# -----Train----------
# AUC: 91.28 Precision: 91.23 Recall: 90.83
#
# -----Validation-----
# AUC: 71.40 Precision: 73.68 Recall: 63.64
#
# wheezy-copper-turtle-magic 17
#
# Fold 1
#
# -----Train----------
# AUC: 89.89 Precision: 90.99 Recall: 89.08
#
# -----Validation-----
# AUC: 57.34 Precision: 57.69 Recall: 62.50
#
# Fold 2
#
# -----Train----------
# AUC: 89.65 Precision: 89.92 Recall: 89.92
#
# -----Validation-----
# AUC: 65.85 Precision: 65.38 Recall: 70.83
#
# Fold 3
#
# -----Train----------
# AUC: 89.45 Precision: 90.21 Recall: 89.08
#
# -----Validation-----
# AUC: 70.38 Precision: 75.00 Recall: 62.50
#
# Fold 4
#
# -----Train----------
# AUC: 89.44 Precision: 89.87 Recall: 89.50
#
# -----Validation-----
# AUC: 59.69 Precision: 61.90 Recall: 54.17
#
# Fold 5
#
# -----Train----------
# AUC: 90.68 Precision: 89.47 Recall: 92.86
#
# -----Validation-----
# AUC: 59.33 Precision: 58.62 Recall: 70.83
#
# Fold 6
#
# -----Train----------
# AUC: 88.98 Precision: 88.80 Recall: 89.92
#
# -----Validation-----
# AUC: 61.78 Precision: 63.64 Recall: 58.33
#
# Fold 7
#
# -----Train----------
# AUC: 88.56 Precision: 88.70 Recall: 89.08
#
# -----Validation-----
# AUC: 72.46 Precision: 76.19 Recall: 66.67
#
# Fold 8
#
# -----Train----------
# AUC: 90.14 Precision: 91.74 Recall: 88.66
#
# -----Validation-----
# AUC: 54.36 Precision: 56.52 Recall: 54.17
#
# Fold 9
#
# -----Train----------
# AUC: 90.75 Precision: 91.14 Recall: 90.76
#
# -----Validation-----
# AUC: 65.15 Precision: 66.67 Recall: 66.67
#
# Fold 10
#
# -----Train----------
# AUC: 87.12 Precision: 87.45 Recall: 87.45
#
# -----Validation-----
# AUC: 73.22 Precision: 72.00 Recall: 78.26
#
# Fold 11
#
# -----Train----------
# AUC: 89.68 Precision: 89.63 Recall: 90.38
#
# -----Validation-----
# AUC: 50.99 Precision: 52.00 Recall: 56.52
#
# wheezy-copper-turtle-magic 18
#
# Fold 1
#
# -----Train----------
# AUC: 90.43 Precision: 90.79 Recall: 90.42
#
# -----Validation-----
# AUC: 81.13 Precision: 80.77 Recall: 84.00
#
# Fold 2
#
# -----Train----------
# AUC: 93.18 Precision: 92.65 Recall: 94.19
#
# -----Validation-----
# AUC: 68.21 Precision: 71.43 Recall: 62.50
#
# Fold 3
#
# -----Train----------
# AUC: 90.58 Precision: 88.63 Recall: 93.78
#
# -----Validation-----
# AUC: 68.03 Precision: 68.00 Recall: 70.83
#
# Fold 4
#
# -----Train----------
# AUC: 92.30 Precision: 90.84 Recall: 94.61
#
# -----Validation-----
# AUC: 74.28 Precision: 71.43 Recall: 83.33
#
# Fold 5
#
# -----Train----------
# AUC: 91.08 Precision: 91.29 Recall: 91.29
#
# -----Validation-----
# AUC: 70.29 Precision: 72.73 Recall: 66.67
#
# Fold 6
#
# -----Train----------
# AUC: 94.46 Precision: 93.88 Recall: 95.44
#
# -----Validation-----
# AUC: 63.77 Precision: 64.00 Recall: 66.67
#
# Fold 7
#
# -----Train----------
# AUC: 92.77 Precision: 92.59 Recall: 93.36
#
# -----Validation-----
# AUC: 70.29 Precision: 72.73 Recall: 66.67
#
# Fold 8
#
# -----Train----------
# AUC: 92.52 Precision: 91.20 Recall: 94.61
#
# -----Validation-----
# AUC: 68.03 Precision: 68.00 Recall: 70.83
#
# Fold 9
#
# -----Train----------
# AUC: 92.97 Precision: 92.62 Recall: 93.78
#
# -----Validation-----
# AUC: 65.76 Precision: 64.29 Recall: 75.00
#
# Fold 10
#
# -----Train----------
# AUC: 90.60 Precision: 89.24 Recall: 92.95
#
# -----Validation-----
# AUC: 72.37 Precision: 73.91 Recall: 70.83
#
# Fold 11
#
# -----Train----------
# AUC: 91.72 Precision: 92.08 Recall: 91.70
#
# -----Validation-----
# AUC: 70.11 Precision: 69.23 Recall: 75.00
#
# wheezy-copper-turtle-magic 19
#
# Fold 1
#
# -----Train----------
# AUC: 89.30 Precision: 87.95 Recall: 91.25
#
# -----Validation-----
# AUC: 61.17 Precision: 61.54 Recall: 64.00
#
# Fold 2
#
# -----Train----------
# AUC: 87.86 Precision: 87.35 Recall: 88.80
#
# -----Validation-----
# AUC: 56.25 Precision: 55.56 Recall: 62.50
#
# Fold 3
#
# -----Train----------
# AUC: 89.33 Precision: 89.58 Recall: 89.21
#
# -----Validation-----
# AUC: 54.17 Precision: 55.56 Recall: 41.67
#
# Fold 4
#
# -----Train----------
# AUC: 88.51 Precision: 89.74 Recall: 87.14
#
# -----Validation-----
# AUC: 72.92 Precision: 73.91 Recall: 70.83
#
# Fold 5
#
# -----Train----------
# AUC: 87.24 Precision: 87.82 Recall: 86.72
#
# -----Validation-----
# AUC: 58.33 Precision: 57.69 Recall: 62.50
#
# Fold 6
#
# -----Train----------
# AUC: 89.74 Precision: 89.02 Recall: 90.87
#
# -----Validation-----
# AUC: 79.17 Precision: 76.92 Recall: 83.33
#
# Fold 7
#
# -----Train----------
# AUC: 90.38 Precision: 90.46 Recall: 90.46
#
# -----Validation-----
# AUC: 62.50 Precision: 63.64 Recall: 58.33
#
# Fold 8
#
# -----Train----------
# AUC: 90.37 Precision: 89.80 Recall: 91.29
#
# -----Validation-----
# AUC: 60.42 Precision: 60.87 Recall: 58.33
#
# Fold 9
#
# -----Train----------
# AUC: 88.30 Precision: 87.15 Recall: 90.04
#
# -----Validation-----
# AUC: 57.79 Precision: 62.50 Recall: 41.67
#
# Fold 10
#
# -----Train----------
# AUC: 89.35 Precision: 88.62 Recall: 90.46
#
# -----Validation-----
# AUC: 68.21 Precision: 71.43 Recall: 62.50
#
# Fold 11
#
# -----Train----------
# AUC: 87.27 Precision: 88.14 Recall: 86.31
#
# -----Validation-----
# AUC: 68.30 Precision: 73.68 Recall: 58.33
#
# wheezy-copper-turtle-magic 20
#
# Fold 1
#
# -----Train----------
# AUC: 89.00 Precision: 88.39 Recall: 88.79
#
# -----Validation-----
# AUC: 72.43 Precision: 77.78 Recall: 60.87
#
# Fold 2
#
# -----Train----------
# AUC: 91.56 Precision: 91.82 Recall: 90.58
#
# -----Validation-----
# AUC: 75.13 Precision: 72.00 Recall: 78.26
#
# Fold 3
#
# -----Train----------
# AUC: 91.44 Precision: 89.96 Recall: 92.38
#
# -----Validation-----
# AUC: 63.41 Precision: 71.43 Recall: 43.48
#
# Fold 4
#
# -----Train----------
# AUC: 91.14 Precision: 91.36 Recall: 90.13
#
# -----Validation-----
# AUC: 59.51 Precision: 59.09 Recall: 56.52
#
# Fold 5
#
# -----Train----------
# AUC: 91.20 Precision: 90.67 Recall: 91.07
#
# -----Validation-----
# AUC: 82.95 Precision: 76.92 Recall: 90.91
#
# Fold 6
#
# -----Train----------
# AUC: 90.97 Precision: 90.62 Recall: 90.62
#
# -----Validation-----
# AUC: 71.59 Precision: 71.43 Recall: 68.18
#
# Fold 7
#
# -----Train----------
# AUC: 90.77 Precision: 90.22 Recall: 90.62
#
# -----Validation-----
# AUC: 63.45 Precision: 59.26 Recall: 72.73
#
# Fold 8
#
# -----Train----------
# AUC: 90.37 Precision: 89.08 Recall: 91.07
#
# -----Validation-----
# AUC: 69.70 Precision: 66.67 Recall: 72.73
#
# Fold 9
#
# -----Train----------
# AUC: 91.02 Precision: 89.57 Recall: 91.96
#
# -----Validation-----
# AUC: 60.61 Precision: 60.00 Recall: 54.55
#
# Fold 10
#
# -----Train----------
# AUC: 91.87 Precision: 90.79 Recall: 92.41
#
# -----Validation-----
# AUC: 64.96 Precision: 65.00 Recall: 59.09
#
# Fold 11
#
# -----Train----------
# AUC: 91.04 Precision: 89.22 Recall: 92.41
#
# -----Validation-----
# AUC: 67.42 Precision: 65.22 Recall: 68.18
#
# wheezy-copper-turtle-magic 21
#
# Fold 1
#
# -----Train----------
# AUC: 93.58 Precision: 93.85 Recall: 93.47
#
# -----Validation-----
# AUC: 69.25 Precision: 67.86 Recall: 76.00
#
# Fold 2
#
# -----Train----------
# AUC: 91.90 Precision: 90.87 Recall: 93.47
#
# -----Validation-----
# AUC: 79.75 Precision: 85.71 Recall: 72.00
#
# Fold 3
#
# -----Train----------
# AUC: 91.92 Precision: 91.87 Recall: 92.24
#
# -----Validation-----
# AUC: 67.42 Precision: 69.57 Recall: 64.00
#
# Fold 4
#
# -----Train----------
# AUC: 91.51 Precision: 91.46 Recall: 91.84
#
# -----Validation-----
# AUC: 71.42 Precision: 72.00 Recall: 72.00
#
# Fold 5
#
# -----Train----------
# AUC: 93.99 Precision: 93.90 Recall: 94.29
#
# -----Validation-----
# AUC: 75.42 Precision: 74.07 Recall: 80.00
#
# Fold 6
#
# -----Train----------
# AUC: 93.17 Precision: 93.44 Recall: 93.06
#
# -----Validation-----
# AUC: 75.58 Precision: 78.26 Recall: 72.00
#
# Fold 7
#
# -----Train----------
# AUC: 92.53 Precision: 91.34 Recall: 94.31
#
# -----Validation-----
# AUC: 68.75 Precision: 65.52 Recall: 79.17
#
# Fold 8
#
# -----Train----------
# AUC: 92.55 Precision: 92.00 Recall: 93.50
#
# -----Validation-----
# AUC: 79.17 Precision: 79.17 Recall: 79.17
#
# Fold 9
#
# -----Train----------
# AUC: 93.35 Precision: 91.80 Recall: 95.53
#
# -----Validation-----
# AUC: 77.08 Precision: 72.41 Recall: 87.50
#
# Fold 10
#
# -----Train----------
# AUC: 92.79 Precision: 93.42 Recall: 92.28
#
# -----Validation-----
# AUC: 65.76 Precision: 64.29 Recall: 75.00
#
# Fold 11
#
# -----Train----------
# AUC: 94.02 Precision: 94.29 Recall: 93.90
#
# -----Validation-----
# AUC: 67.93 Precision: 66.67 Recall: 75.00
#
# wheezy-copper-turtle-magic 22
#
# Fold 1
#
# -----Train----------
# AUC: 93.61 Precision: 93.31 Recall: 94.42
#
# -----Validation-----
# AUC: 73.88 Precision: 74.07 Recall: 76.92
#
# Fold 2
#
# -----Train----------
# AUC: 94.03 Precision: 94.05 Recall: 94.42
#
# -----Validation-----
# AUC: 70.19 Precision: 73.91 Recall: 65.38
#
# Fold 3
#
# -----Train----------
# AUC: 93.61 Precision: 93.00 Recall: 94.84
#
# -----Validation-----
# AUC: 77.58 Precision: 79.17 Recall: 76.00
#
# Fold 4
#
# -----Train----------
# AUC: 93.66 Precision: 94.38 Recall: 93.25
#
# -----Validation-----
# AUC: 71.42 Precision: 72.00 Recall: 72.00
#
# Fold 5
#
# -----Train----------
# AUC: 93.87 Precision: 94.76 Recall: 93.25
#
# -----Validation-----
# AUC: 71.50 Precision: 73.91 Recall: 68.00
#
# Fold 6
#
# -----Train----------
# AUC: 91.78 Precision: 91.73 Recall: 92.46
#
# -----Validation-----
# AUC: 73.58 Precision: 77.27 Recall: 68.00
#
# Fold 7
#
# -----Train----------
# AUC: 90.59 Precision: 91.53 Recall: 90.08
#
# -----Validation-----
# AUC: 65.25 Precision: 65.38 Recall: 68.00
#
# Fold 8
#
# -----Train----------
# AUC: 94.49 Precision: 95.18 Recall: 94.05
#
# -----Validation-----
# AUC: 72.26 Precision: 68.75 Recall: 88.00
#
# Fold 9
#
# -----Train----------
# AUC: 93.04 Precision: 93.25 Recall: 93.25
#
# -----Validation-----
# AUC: 70.78 Precision: 72.00 Recall: 72.00
#
# Fold 10
#
# -----Train----------
# AUC: 92.48 Precision: 94.24 Recall: 90.87
#
# -----Validation-----
# AUC: 83.13 Precision: 81.48 Recall: 88.00
#
# Fold 11
#
# -----Train----------
# AUC: 91.81 Precision: 92.06 Recall: 92.06
#
# -----Validation-----
# AUC: 68.61 Precision: 69.23 Recall: 72.00
#
# wheezy-copper-turtle-magic 23
#
# Fold 1
#
# -----Train----------
# AUC: 89.04 Precision: 90.91 Recall: 87.14
#
# -----Validation-----
# AUC: 73.50 Precision: 75.00 Recall: 72.00
#
# Fold 2
#
# -----Train----------
# AUC: 88.79 Precision: 89.17 Recall: 88.80
#
# -----Validation-----
# AUC: 59.25 Precision: 60.87 Recall: 56.00
#
# Fold 3
#
# -----Train----------
# AUC: 91.14 Precision: 91.32 Recall: 91.32
#
# -----Validation-----
# AUC: 68.75 Precision: 68.00 Recall: 70.83
#
# Fold 4
#
# -----Train----------
# AUC: 88.85 Precision: 89.54 Recall: 88.43
#
# -----Validation-----
# AUC: 57.34 Precision: 57.69 Recall: 62.50
#
# Fold 5
#
# -----Train----------
# AUC: 89.70 Precision: 90.72 Recall: 88.84
#
# -----Validation-----
# AUC: 68.21 Precision: 71.43 Recall: 62.50
#
# Fold 6
#
# -----Train----------
# AUC: 90.76 Precision: 91.95 Recall: 89.67
#
# -----Validation-----
# AUC: 65.94 Precision: 66.67 Recall: 66.67
#
# Fold 7
#
# -----Train----------
# AUC: 89.65 Precision: 88.76 Recall: 91.32
#
# -----Validation-----
# AUC: 59.42 Precision: 59.26 Recall: 66.67
#
# Fold 8
#
# -----Train----------
# AUC: 90.73 Precision: 90.57 Recall: 91.32
#
# -----Validation-----
# AUC: 50.72 Precision: 51.61 Recall: 66.67
#
# Fold 9
#
# -----Train----------
# AUC: 89.72 Precision: 91.42 Recall: 88.02
#
# -----Validation-----
# AUC: 76.36 Precision: 72.41 Recall: 87.50
#
# Fold 10
#
# -----Train----------
# AUC: 89.89 Precision: 90.08 Recall: 90.08
#
# -----Validation-----
# AUC: 68.21 Precision: 71.43 Recall: 62.50
#
# Fold 11
#
# -----Train----------
# AUC: 90.13 Precision: 91.49 Recall: 88.84
#
# -----Validation-----
# AUC: 68.39 Precision: 76.47 Recall: 54.17
#
# wheezy-copper-turtle-magic 24
#
# Fold 1
#
# -----Train----------
# AUC: 94.69 Precision: 93.49 Recall: 95.26
#
# -----Validation-----
# AUC: 76.14 Precision: 73.91 Recall: 77.27
#
# Fold 2
#
# -----Train----------
# AUC: 95.61 Precision: 94.01 Recall: 96.68
#
# -----Validation-----
# AUC: 82.39 Precision: 85.00 Recall: 77.27
#
# Fold 3
#
# -----Train----------
# AUC: 95.09 Precision: 94.81 Recall: 94.81
#
# -----Validation-----
# AUC: 69.64 Precision: 62.96 Recall: 80.95
#
# Fold 4
#
# -----Train----------
# AUC: 95.20 Precision: 93.18 Recall: 96.70
#
# -----Validation-----
# AUC: 86.61 Precision: 85.71 Recall: 85.71
#
# Fold 5
#
# -----Train----------
# AUC: 95.62 Precision: 94.04 Recall: 96.70
#
# -----Validation-----
# AUC: 68.45 Precision: 68.42 Recall: 61.90
#
# Fold 6
#
# -----Train----------
# AUC: 95.96 Precision: 96.19 Recall: 95.28
#
# -----Validation-----
# AUC: 55.65 Precision: 52.17 Recall: 57.14
#
# Fold 7
#
# -----Train----------
# AUC: 96.64 Precision: 96.68 Recall: 96.23
#
# -----Validation-----
# AUC: 75.30 Precision: 75.00 Recall: 71.43
#
# Fold 8
#
# -----Train----------
# AUC: 95.80 Precision: 94.88 Recall: 96.23
#
# -----Validation-----
# AUC: 77.08 Precision: 82.35 Recall: 66.67
#
# Fold 9
#
# -----Train----------
# AUC: 95.09 Precision: 94.81 Recall: 94.81
#
# -----Validation-----
# AUC: 75.30 Precision: 75.00 Recall: 71.43
#
# Fold 10
#
# -----Train----------
# AUC: 94.87 Precision: 94.79 Recall: 94.34
#
# -----Validation-----
# AUC: 77.02 Precision: 78.95 Recall: 71.43
#
# Fold 11
#
# -----Train----------
# AUC: 95.79 Precision: 95.31 Recall: 95.75
#
# -----Validation-----
# AUC: 62.94 Precision: 66.67 Recall: 47.62
#
# wheezy-copper-turtle-magic 25
#
# Fold 1
#
# -----Train----------
# AUC: 93.90 Precision: 93.81 Recall: 93.36
#
# -----Validation-----
# AUC: 60.61 Precision: 60.00 Recall: 54.55
#
# Fold 2
#
# -----Train----------
# AUC: 94.43 Precision: 93.06 Recall: 95.26
#
# -----Validation-----
# AUC: 65.15 Precision: 63.64 Recall: 63.64
#
# Fold 3
#
# -----Train----------
# AUC: 92.83 Precision: 92.06 Recall: 92.92
#
# -----Validation-----
# AUC: 57.74 Precision: 54.55 Recall: 57.14
#
# Fold 4
#
# -----Train----------
# AUC: 92.74 Precision: 93.69 Recall: 91.04
#
# -----Validation-----
# AUC: 62.20 Precision: 59.09 Recall: 61.90
#
# Fold 5
#
# -----Train----------
# AUC: 93.99 Precision: 92.63 Recall: 94.81
#
# -----Validation-----
# AUC: 68.45 Precision: 68.42 Recall: 61.90
#
# Fold 6
#
# -----Train----------
# AUC: 92.82 Precision: 92.45 Recall: 92.45
#
# -----Validation-----
# AUC: 68.53 Precision: 64.00 Recall: 76.19
#
# Fold 7
#
# -----Train----------
# AUC: 92.14 Precision: 91.94 Recall: 91.51
#
# -----Validation-----
# AUC: 75.05 Precision: 72.73 Recall: 76.19
#
# Fold 8
#
# -----Train----------
# AUC: 93.03 Precision: 92.89 Recall: 92.45
#
# -----Validation-----
# AUC: 81.99 Precision: 78.26 Recall: 85.71
#
# Fold 9
#
# -----Train----------
# AUC: 93.29 Precision: 92.52 Recall: 93.40
#
# -----Validation-----
# AUC: 72.88 Precision: 69.57 Recall: 76.19
#
# Fold 10
#
# -----Train----------
# AUC: 94.08 Precision: 95.59 Recall: 91.98
#
# -----Validation-----
# AUC: 68.12 Precision: 66.67 Recall: 66.67
#
# Fold 11
#
# -----Train----------
# AUC: 92.78 Precision: 93.27 Recall: 91.51
#
# -----Validation-----
# AUC: 75.26 Precision: 70.83 Recall: 80.95
#
# wheezy-copper-turtle-magic 26
#
# Fold 1
#
# -----Train----------
# AUC: 92.97 Precision: 93.78 Recall: 91.59
#
# -----Validation-----
# AUC: 50.89 Precision: 50.00 Recall: 40.91
#
# Fold 2
#
# -----Train----------
# AUC: 92.77 Precision: 92.92 Recall: 92.06
#
# -----Validation-----
# AUC: 59.98 Precision: 59.09 Recall: 59.09
#
# Fold 3
#
# -----Train----------
# AUC: 92.55 Precision: 92.49 Recall: 92.06
#
# -----Validation-----
# AUC: 68.68 Precision: 72.22 Recall: 59.09
#
# Fold 4
#
# -----Train----------
# AUC: 92.33 Precision: 92.06 Recall: 92.06
#
# -----Validation-----
# AUC: 70.75 Precision: 80.00 Recall: 54.55
#
# Fold 5
#
# -----Train----------
# AUC: 93.25 Precision: 92.59 Recall: 93.46
#
# -----Validation-----
# AUC: 70.85 Precision: 76.47 Recall: 59.09
#
# Fold 6
#
# -----Train----------
# AUC: 91.42 Precision: 91.94 Recall: 90.23
#
# -----Validation-----
# AUC: 61.59 Precision: 58.33 Recall: 66.67
#
# Fold 7
#
# -----Train----------
# AUC: 92.63 Precision: 90.99 Recall: 93.95
#
# -----Validation-----
# AUC: 74.84 Precision: 75.00 Recall: 71.43
#
# Fold 8
#
# -----Train----------
# AUC: 90.96 Precision: 91.87 Recall: 89.30
#
# -----Validation-----
# AUC: 77.85 Precision: 70.37 Recall: 90.48
#
# Fold 9
#
# -----Train----------
# AUC: 92.34 Precision: 92.49 Recall: 91.63
#
# -----Validation-----
# AUC: 72.46 Precision: 73.68 Recall: 66.67
#
# Fold 10
#
# -----Train----------
# AUC: 90.81 Precision: 89.55 Recall: 91.63
#
# -----Validation-----
# AUC: 65.73 Precision: 65.00 Recall: 61.90
#
# Fold 11
#
# -----Train----------
# AUC: 90.06 Precision: 90.91 Recall: 88.37
#
# -----Validation-----
# AUC: 70.29 Precision: 70.00 Recall: 66.67
#
# wheezy-copper-turtle-magic 27
#
# Fold 1
#
# -----Train----------
# AUC: 91.20 Precision: 91.12 Recall: 90.28
#
# -----Validation-----
# AUC: 75.82 Precision: 82.35 Recall: 63.64
#
# Fold 2
#
# -----Train----------
# AUC: 93.42 Precision: 93.06 Recall: 93.06
#
# -----Validation-----
# AUC: 55.91 Precision: 58.33 Recall: 31.82
#
# Fold 3
#
# -----Train----------
# AUC: 92.55 Precision: 92.13 Recall: 92.13
#
# -----Validation-----
# AUC: 65.34 Precision: 62.50 Recall: 68.18
#
# Fold 4
#
# -----Train----------
# AUC: 90.46 Precision: 88.39 Recall: 91.67
#
# -----Validation-----
# AUC: 78.22 Precision: 77.27 Recall: 77.27
#
# Fold 5
#
# -----Train----------
# AUC: 91.49 Precision: 90.41 Recall: 91.67
#
# -----Validation-----
# AUC: 66.86 Precision: 70.59 Recall: 54.55
#
# Fold 6
#
# -----Train----------
# AUC: 91.93 Precision: 90.87 Recall: 92.13
#
# -----Validation-----
# AUC: 65.15 Precision: 63.64 Recall: 63.64
#
# Fold 7
#
# -----Train----------
# AUC: 90.78 Precision: 90.65 Recall: 89.81
#
# -----Validation-----
# AUC: 67.42 Precision: 65.22 Recall: 68.18
#
# Fold 8
#
# -----Train----------
# AUC: 91.90 Precision: 91.67 Recall: 91.24
#
# -----Validation-----
# AUC: 68.45 Precision: 68.42 Recall: 61.90
#
# Fold 9
#
# -----Train----------
# AUC: 91.44 Precision: 91.59 Recall: 90.32
#
# -----Validation-----
# AUC: 75.30 Precision: 75.00 Recall: 71.43
#
# Fold 10
#
# -----Train----------
# AUC: 93.03 Precision: 92.24 Recall: 93.09
#
# -----Validation-----
# AUC: 69.64 Precision: 62.96 Recall: 80.95
#
# Fold 11
#
# -----Train----------
# AUC: 90.77 Precision: 91.08 Recall: 89.40
#
# -----Validation-----
# AUC: 77.68 Precision: 76.19 Recall: 76.19
#
# wheezy-copper-turtle-magic 28
#
# Fold 1
#
# -----Train----------
# AUC: 88.09 Precision: 89.41 Recall: 86.48
#
# -----Validation-----
# AUC: 64.00 Precision: 62.07 Recall: 72.00
#
# Fold 2
#
# -----Train----------
# AUC: 90.14 Precision: 90.16 Recall: 90.16
#
# -----Validation-----
# AUC: 62.00 Precision: 62.50 Recall: 60.00
#
# Fold 3
#
# -----Train----------
# AUC: 88.30 Precision: 89.12 Recall: 87.30
#
# -----Validation-----
# AUC: 68.00 Precision: 66.67 Recall: 72.00
#
# Fold 4
#
# -----Train----------
# AUC: 87.88 Precision: 87.76 Recall: 88.11
#
# -----Validation-----
# AUC: 70.00 Precision: 67.86 Recall: 76.00
#
# Fold 5
#
# -----Train----------
# AUC: 90.98 Precision: 90.65 Recall: 91.39
#
# -----Validation-----
# AUC: 53.00 Precision: 53.85 Recall: 56.00
#
# Fold 6
#
# -----Train----------
# AUC: 88.96 Precision: 88.98 Recall: 88.98
#
# -----Validation-----
# AUC: 72.92 Precision: 76.19 Recall: 66.67
#
# Fold 7
#
# -----Train----------
# AUC: 88.35 Precision: 89.17 Recall: 87.35
#
# -----Validation-----
# AUC: 58.33 Precision: 60.00 Recall: 50.00
#
# Fold 8
#
# -----Train----------
# AUC: 89.36 Precision: 88.76 Recall: 90.20
#
# -----Validation-----
# AUC: 72.92 Precision: 73.91 Recall: 70.83
#
# Fold 9
#
# -----Train----------
# AUC: 90.18 Precision: 90.20 Recall: 90.20
#
# -----Validation-----
# AUC: 60.42 Precision: 60.00 Recall: 62.50
#
# Fold 10
#
# -----Train----------
# AUC: 88.95 Precision: 87.45 Recall: 91.02
#
# -----Validation-----
# AUC: 66.67 Precision: 64.29 Recall: 75.00
#
# Fold 11
#
# -----Train----------
# AUC: 89.37 Precision: 90.38 Recall: 88.16
#
# -----Validation-----
# AUC: 62.50 Precision: 60.71 Recall: 70.83
#
# wheezy-copper-turtle-magic 29
#
# Fold 1
#
# -----Train----------
# AUC: 91.15 Precision: 90.83 Recall: 91.63
#
# -----Validation-----
# AUC: 71.74 Precision: 70.83 Recall: 73.91
#
# Fold 2
#
# -----Train----------
# AUC: 91.81 Precision: 92.04 Recall: 91.63
#
# -----Validation-----
# AUC: 73.91 Precision: 70.37 Recall: 82.61
#
# Fold 3
#
# -----Train----------
# AUC: 92.03 Precision: 90.64 Recall: 93.83
#
# -----Validation-----
# AUC: 71.74 Precision: 70.83 Recall: 73.91
#
# Fold 4
#
# -----Train----------
# AUC: 91.59 Precision: 91.63 Recall: 91.63
#
# -----Validation-----
# AUC: 54.35 Precision: 55.00 Recall: 47.83
#
# Fold 5
#
# -----Train----------
# AUC: 91.81 Precision: 91.67 Recall: 92.07
#
# -----Validation-----
# AUC: 71.74 Precision: 72.73 Recall: 69.57
#
# Fold 6
#
# -----Train----------
# AUC: 90.93 Precision: 91.15 Recall: 90.75
#
# -----Validation-----
# AUC: 63.04 Precision: 63.64 Recall: 60.87
#
# Fold 7
#
# -----Train----------
# AUC: 91.17 Precision: 92.69 Recall: 89.43
#
# -----Validation-----
# AUC: 61.96 Precision: 60.71 Recall: 73.91
#
# Fold 8
#
# -----Train----------
# AUC: 93.38 Precision: 93.39 Recall: 93.39
#
# -----Validation-----
# AUC: 64.62 Precision: 68.42 Recall: 56.52
#
# Fold 9
#
# -----Train----------
# AUC: 92.96 Precision: 94.14 Recall: 91.67
#
# -----Validation-----
# AUC: 65.91 Precision: 65.22 Recall: 68.18
#
# Fold 10
#
# -----Train----------
# AUC: 90.52 Precision: 89.70 Recall: 91.67
#
# -----Validation-----
# AUC: 77.27 Precision: 87.50 Recall: 63.64
#
# Fold 11
#
# -----Train----------
# AUC: 92.51 Precision: 92.92 Recall: 92.11
#
# -----Validation-----
# AUC: 65.91 Precision: 66.67 Recall: 63.64
#
# wheezy-copper-turtle-magic 30
#
# Fold 1
#
# -----Train----------
# AUC: 91.19 Precision: 91.43 Recall: 91.80
#
# -----Validation-----
# AUC: 78.96 Precision: 77.78 Recall: 84.00
#
# Fold 2
#
# -----Train----------
# AUC: 88.82 Precision: 89.02 Recall: 89.75
#
# -----Validation-----
# AUC: 58.09 Precision: 59.26 Recall: 64.00
#
# Fold 3
#
# -----Train----------
# AUC: 91.75 Precision: 90.55 Recall: 94.26
#
# -----Validation-----
# AUC: 64.78 Precision: 68.18 Recall: 60.00
#
# Fold 4
#
# -----Train----------
# AUC: 91.05 Precision: 92.44 Recall: 90.16
#
# -----Validation-----
# AUC: 60.43 Precision: 62.50 Recall: 60.00
#
# Fold 5
#
# -----Train----------
# AUC: 92.72 Precision: 93.03 Recall: 93.03
#
# -----Validation-----
# AUC: 53.82 Precision: 57.89 Recall: 44.00
#
# Fold 6
#
# -----Train----------
# AUC: 89.99 Precision: 90.91 Recall: 89.80
#
# -----Validation-----
# AUC: 64.58 Precision: 63.33 Recall: 79.17
#
# Fold 7
#
# -----Train----------
# AUC: 90.40 Precision: 90.98 Recall: 90.61
#
# -----Validation-----
# AUC: 58.71 Precision: 60.87 Recall: 58.33
#
# Fold 8
#
# -----Train----------
# AUC: 91.25 Precision: 91.80 Recall: 91.43
#
# -----Validation-----
# AUC: 65.15 Precision: 66.67 Recall: 66.67
#
# Fold 9
#
# -----Train----------
# AUC: 89.34 Precision: 90.12 Recall: 89.39
#
# -----Validation-----
# AUC: 71.59 Precision: 72.00 Recall: 75.00
#
# Fold 10
#
# -----Train----------
# AUC: 91.01 Precision: 91.09 Recall: 91.84
#
# -----Validation-----
# AUC: 62.69 Precision: 62.96 Recall: 70.83
#
# Fold 11
#
# -----Train----------
# ...
#
# -----Validation-----
# AUC: 70.11 Precision: 75.00 Recall: 65.22
#
# Fold 9
#
# -----Train----------
# AUC: 93.13 Precision: 92.62 Recall: 95.36
#
# -----Validation-----
# AUC: 63.73 Precision: 66.67 Recall: 69.57
#
# Fold 10
#
# -----Train----------
# AUC: 92.29 Precision: 92.50 Recall: 93.67
#
# -----Validation-----
# AUC: 64.19 Precision: 68.18 Recall: 65.22
#
# Fold 11
#
# -----Train----------
# AUC: 91.40 Precision: 92.02 Recall: 92.41
#
# -----Validation-----
# AUC: 68.08 Precision: 69.23 Recall: 78.26
#
# wheezy-copper-turtle-magic 502
#
# Fold 1
#
# -----Train----------
# AUC: 92.42 Precision: 92.31 Recall: 92.31
#
# -----Validation-----
# AUC: 63.33 Precision: 61.54 Recall: 66.67
#
# Fold 2
#
# -----Train----------
# AUC: 92.65 Precision: 91.63 Recall: 93.59
#
# -----Validation-----
# AUC: 67.33 Precision: 66.67 Recall: 66.67
#
# Fold 3
#
# -----Train----------
# AUC: 90.96 Precision: 90.99 Recall: 90.60
#
# -----Validation-----
# AUC: 68.75 Precision: 71.43 Recall: 62.50
#
# Fold 4
#
# -----Train----------
# AUC: 92.03 Precision: 91.18 Recall: 92.74
#
# -----Validation-----
# AUC: 68.75 Precision: 71.43 Recall: 62.50
#
# Fold 5
#
# -----Train----------
# AUC: 92.02 Precision: 91.53 Recall: 92.31
#
# -----Validation-----
# AUC: 77.08 Precision: 78.26 Recall: 75.00
#
# Fold 6
#
# -----Train----------
# AUC: 90.35 Precision: 90.56 Recall: 89.79
#
# -----Validation-----
# AUC: 74.28 Precision: 78.95 Recall: 65.22
#
# Fold 7
#
# -----Train----------
# AUC: 91.82 Precision: 91.88 Recall: 91.49
#
# -----Validation-----
# AUC: 74.46 Precision: 73.91 Recall: 73.91
#
# Fold 8
#
# -----Train----------
# AUC: 88.66 Precision: 89.18 Recall: 87.66
#
# -----Validation-----
# AUC: 80.89 Precision: 79.17 Recall: 82.61
#
# Fold 9
#
# -----Train----------
# AUC: 92.24 Precision: 91.95 Recall: 92.34
#
# -----Validation-----
# AUC: 78.89 Precision: 74.07 Recall: 86.96
#
# Fold 10
#
# -----Train----------
# AUC: 91.44 Precision: 89.43 Recall: 93.62
#
# -----Validation-----
# AUC: 65.76 Precision: 68.42 Recall: 56.52
#
# Fold 11
#
# -----Train----------
# AUC: 92.87 Precision: 92.77 Recall: 92.77
#
# -----Validation-----
# AUC: 70.38 Precision: 66.67 Recall: 78.26
#
# wheezy-copper-turtle-magic 503
#
# Fold 1
#
# -----Train----------
# AUC: 90.65 Precision: 90.61 Recall: 90.19
#
# -----Validation-----
# AUC: 73.32 Precision: 72.73 Recall: 72.73
#
# Fold 2
#
# -----Train----------
# AUC: 93.61 Precision: 93.87 Recall: 92.99
#
# -----Validation-----
# AUC: 59.78 Precision: 61.11 Recall: 50.00
#
# Fold 3
#
# -----Train----------
# AUC: 91.78 Precision: 91.98 Recall: 91.12
#
# -----Validation-----
# AUC: 73.52 Precision: 69.23 Recall: 81.82
#
# Fold 4
#
# -----Train----------
# AUC: 93.83 Precision: 94.31 Recall: 92.99
#
# -----Validation-----
# AUC: 64.43 Precision: 63.64 Recall: 63.64
#
# Fold 5
#
# -----Train----------
# AUC: 92.26 Precision: 91.67 Recall: 92.52
#
# -----Validation-----
# AUC: 75.40 Precision: 78.95 Recall: 68.18
#
# Fold 6
#
# -----Train----------
# AUC: 91.60 Precision: 90.83 Recall: 92.09
#
# -----Validation-----
# AUC: 82.19 Precision: 76.00 Recall: 90.48
#
# Fold 7
#
# -----Train----------
# AUC: 93.20 Precision: 92.63 Recall: 93.49
#
# -----Validation-----
# AUC: 55.74 Precision: 55.00 Recall: 52.38
#
# Fold 8
#
# -----Train----------
# AUC: 89.78 Precision: 89.72 Recall: 89.30
#
# -----Validation-----
# AUC: 69.91 Precision: 66.67 Recall: 76.19
#
# Fold 9
#
# -----Train----------
# AUC: 91.62 Precision: 90.83 Recall: 92.09
#
# -----Validation-----
# AUC: 69.48 Precision: 75.00 Recall: 57.14
#
# Fold 10
#
# -----Train----------
# AUC: 92.08 Precision: 91.28 Recall: 92.56
#
# -----Validation-----
# AUC: 55.74 Precision: 55.00 Recall: 52.38
#
# Fold 11
#
# -----Train----------
# AUC: 92.47 Precision: 93.75 Recall: 90.70
#
# -----Validation-----
# AUC: 74.24 Precision: 77.78 Recall: 66.67
#
# wheezy-copper-turtle-magic 504
#
# Fold 1
#
# -----Train----------
# AUC: 92.33 Precision: 92.05 Recall: 93.22
#
# -----Validation-----
# AUC: 70.20 Precision: 70.83 Recall: 70.83
#
# Fold 2
#
# -----Train----------
# AUC: 94.54 Precision: 94.89 Recall: 94.49
#
# -----Validation-----
# AUC: 70.02 Precision: 67.86 Recall: 79.17
#
# Fold 3
#
# -----Train----------
# AUC: 94.09 Precision: 94.09 Recall: 94.49
#
# -----Validation-----
# AUC: 78.62 Precision: 76.92 Recall: 83.33
#
# Fold 4
#
# -----Train----------
# AUC: 93.42 Precision: 92.56 Recall: 94.92
#
# -----Validation-----
# AUC: 71.59 Precision: 72.00 Recall: 75.00
#
# Fold 5
#
# -----Train----------
# AUC: 92.61 Precision: 93.53 Recall: 91.95
#
# -----Validation-----
# AUC: 67.61 Precision: 71.43 Recall: 62.50
#
# Fold 6
#
# -----Train----------
# AUC: 92.14 Precision: 92.02 Recall: 92.80
#
# -----Validation-----
# AUC: 76.33 Precision: 80.95 Recall: 70.83
#
# Fold 7
#
# -----Train----------
# AUC: 92.81 Precision: 93.19 Recall: 92.80
#
# -----Validation-----
# AUC: 67.23 Precision: 68.00 Recall: 70.83
#
# Fold 8
#
# -----Train----------
# AUC: 93.67 Precision: 93.33 Recall: 94.51
#
# -----Validation-----
# AUC: 72.92 Precision: 67.74 Recall: 91.30
#
# Fold 9
#
# -----Train----------
# AUC: 94.12 Precision: 94.12 Recall: 94.51
#
# -----Validation-----
# AUC: 62.25 Precision: 63.64 Recall: 60.87
#
# Fold 10
#
# -----Train----------
# AUC: 92.62 Precision: 93.19 Recall: 92.41
#
# -----Validation-----
# AUC: 84.58 Precision: 90.00 Recall: 78.26
#
# Fold 11
#
# -----Train----------
# AUC: 93.47 Precision: 93.67 Recall: 93.67
#
# -----Validation-----
# AUC: 73.12 Precision: 70.37 Recall: 82.61
#
# wheezy-copper-turtle-magic 505
#
# Fold 1
#
# -----Train----------
# AUC: 90.77 Precision: 91.93 Recall: 89.13
#
# -----Validation-----
# AUC: 72.92 Precision: 70.37 Recall: 79.17
#
# Fold 2
#
# -----Train----------
# AUC: 91.23 Precision: 91.67 Recall: 90.48
#
# -----Validation-----
# AUC: 72.10 Precision: 77.78 Recall: 60.87
#
# Fold 3
#
# -----Train----------
# AUC: 92.53 Precision: 91.88 Recall: 93.07
#
# -----Validation-----
# AUC: 61.78 Precision: 60.00 Recall: 65.22
#
# Fold 4
#
# -----Train----------
# AUC: 92.51 Precision: 92.98 Recall: 91.77
#
# -----Validation-----
# AUC: 70.20 Precision: 69.57 Recall: 69.57
#
# Fold 5
#
# -----Train----------
# AUC: 90.17 Precision: 89.70 Recall: 90.48
#
# -----Validation-----
# AUC: 65.85 Precision: 66.67 Recall: 60.87
#
# Fold 6
#
# -----Train----------
# AUC: 89.51 Precision: 90.27 Recall: 88.31
#
# -----Validation-----
# AUC: 72.37 Precision: 70.83 Recall: 73.91
#
# Fold 7
#
# -----Train----------
# AUC: 90.61 Precision: 89.79 Recall: 91.34
#
# -----Validation-----
# AUC: 72.46 Precision: 69.23 Recall: 78.26
#
# Fold 8
#
# -----Train----------
# AUC: 91.65 Precision: 92.86 Recall: 90.04
#
# -----Validation-----
# AUC: 68.03 Precision: 68.18 Recall: 65.22
#
# Fold 9
#
# -----Train----------
# AUC: 92.11 Precision: 92.17 Recall: 91.77
#
# -----Validation-----
# AUC: 73.91 Precision: 72.00 Recall: 78.26
#
# Fold 10
#
# -----Train----------
# AUC: 89.97 Precision: 90.00 Recall: 89.61
#
# -----Validation-----
# AUC: 76.09 Precision: 77.27 Recall: 73.91
#
# Fold 11
#
# -----Train----------
# AUC: 92.76 Precision: 91.91 Recall: 93.51
#
# -----Validation-----
# AUC: 60.87 Precision: 60.87 Recall: 60.87
#
# wheezy-copper-turtle-magic 506
#
# Fold 1
#
# -----Train----------
# AUC: 90.27 Precision: 89.43 Recall: 91.29
#
# -----Validation-----
# AUC: 64.00 Precision: 62.07 Recall: 72.00
#
# Fold 2
#
# -----Train----------
# AUC: 90.48 Precision: 89.80 Recall: 91.29
#
# -----Validation-----
# AUC: 78.00 Precision: 76.92 Recall: 80.00
#
# Fold 3
#
# -----Train----------
# AUC: 90.50 Precision: 90.16 Recall: 90.91
#
# -----Validation-----
# AUC: 67.58 Precision: 63.33 Recall: 79.17
#
# Fold 4
#
# -----Train----------
# AUC: 90.72 Precision: 90.20 Recall: 91.32
#
# -----Validation-----
# AUC: 68.75 Precision: 68.00 Recall: 70.83
#
# Fold 5
#
# -----Train----------
# AUC: 90.52 Precision: 90.16 Recall: 90.91
#
# -----Validation-----
# AUC: 64.58 Precision: 62.96 Recall: 70.83
#
# Fold 6
#
# -----Train----------
# AUC: 91.55 Precision: 91.70 Recall: 91.32
#
# -----Validation-----
# AUC: 70.83 Precision: 67.86 Recall: 79.17
#
# Fold 7
#
# -----Train----------
# AUC: 91.75 Precision: 92.08 Recall: 91.32
#
# -----Validation-----
# AUC: 47.92 Precision: 48.00 Recall: 50.00
#
# Fold 8
#
# -----Train----------
# AUC: 88.05 Precision: 86.22 Recall: 90.50
#
# -----Validation-----
# AUC: 81.25 Precision: 80.00 Recall: 83.33
#
# Fold 9
#
# -----Train----------
# AUC: 90.10 Precision: 89.75 Recall: 90.50
#
# -----Validation-----
# AUC: 62.50 Precision: 61.54 Recall: 66.67
#
# Fold 10
#
# -----Train----------
# AUC: 91.34 Precision: 90.98 Recall: 91.74
#
# -----Validation-----
# AUC: 64.58 Precision: 70.59 Recall: 50.00
#
# Fold 11
#
# -----Train----------
# AUC: 90.31 Precision: 88.84 Recall: 92.15
#
# -----Validation-----
# AUC: 77.08 Precision: 84.21 Recall: 66.67
#
# wheezy-copper-turtle-magic 507
#
# Fold 1
#
# -----Train----------
# AUC: 89.73 Precision: 90.41 Recall: 88.00
#
# -----Validation-----
# AUC: 76.96 Precision: 77.27 Recall: 73.91
#
# Fold 2
#
# -----Train----------
# AUC: 90.84 Precision: 90.62 Recall: 90.22
#
# -----Validation-----
# AUC: 56.43 Precision: 53.85 Recall: 60.87
#
# Fold 3
#
# -----Train----------
# AUC: 91.45 Precision: 91.86 Recall: 90.22
#
# -----Validation-----
# AUC: 58.26 Precision: 56.52 Recall: 56.52
#
# Fold 4
#
# -----Train----------
# AUC: 90.38 Precision: 90.91 Recall: 88.89
#
# -----Validation-----
# AUC: 70.43 Precision: 73.68 Recall: 60.87
#
# Fold 5
#
# -----Train----------
# AUC: 90.23 Precision: 89.43 Recall: 90.22
#
# -----Validation-----
# AUC: 56.09 Precision: 54.55 Recall: 52.17
#
# Fold 6
#
# -----Train----------
# AUC: 88.03 Precision: 88.58 Recall: 86.22
#
# -----Validation-----
# AUC: 68.43 Precision: 70.00 Recall: 60.87
#
# Fold 7
#
# -----Train----------
# AUC: 89.13 Precision: 89.59 Recall: 87.61
#
# -----Validation-----
# AUC: 56.45 Precision: 56.25 Recall: 40.91
#
# Fold 8
#
# -----Train----------
# AUC: 91.27 Precision: 91.86 Recall: 89.82
#
# -----Validation-----
# AUC: 69.32 Precision: 70.00 Recall: 63.64
#
# Fold 9
#
# -----Train----------
# AUC: 90.20 Precision: 90.91 Recall: 88.50
#
# -----Validation-----
# AUC: 69.51 Precision: 68.18 Recall: 68.18
#
# Fold 10
#
# -----Train----------
# AUC: 90.16 Precision: 91.67 Recall: 87.61
#
# -----Validation-----
# AUC: 54.55 Precision: 52.00 Recall: 59.09
#
# Fold 11
#
# -----Train----------
# AUC: 89.59 Precision: 89.69 Recall: 88.50
#
# -----Validation-----
# AUC: 63.07 Precision: 60.87 Recall: 63.64
#
# wheezy-copper-turtle-magic 508
#
# Fold 1
#
# -----Train----------
# AUC: 89.03 Precision: 89.03 Recall: 89.03
#
# -----Validation-----
# AUC: 52.08 Precision: 52.17 Recall: 50.00
#
# Fold 2
#
# -----Train----------
# AUC: 87.97 Precision: 87.50 Recall: 88.61
#
# -----Validation-----
# AUC: 64.58 Precision: 65.22 Recall: 62.50
#
# Fold 3
#
# -----Train----------
# AUC: 87.55 Precision: 87.08 Recall: 88.19
#
# -----Validation-----
# AUC: 56.25 Precision: 56.00 Recall: 58.33
#
# Fold 4
#
# -----Train----------
# AUC: 86.92 Precision: 87.23 Recall: 86.50
#
# -----Validation-----
# AUC: 68.75 Precision: 71.43 Recall: 62.50
#
# Fold 5
#
# -----Train----------
# AUC: 86.50 Precision: 86.50 Recall: 86.50
#
# -----Validation-----
# AUC: 62.50 Precision: 61.54 Recall: 66.67
#
# Fold 6
#
# -----Train----------
# AUC: 87.55 Precision: 88.70 Recall: 86.08
#
# -----Validation-----
# AUC: 60.42 Precision: 60.00 Recall: 62.50
#
# Fold 7
#
# -----Train----------
# AUC: 87.97 Precision: 89.13 Recall: 86.50
#
# -----Validation-----
# AUC: 70.83 Precision: 67.86 Recall: 79.17
#
# Fold 8
#
# -----Train----------
# AUC: 87.13 Precision: 87.29 Recall: 86.92
#
# -----Validation-----
# AUC: 68.75 Precision: 73.68 Recall: 58.33
#
# Fold 9
#
# -----Train----------
# AUC: 87.61 Precision: 88.74 Recall: 86.13
#
# -----Validation-----
# AUC: 63.04 Precision: 61.54 Recall: 69.57
#
# Fold 10
#
# -----Train----------
# AUC: 89.29 Precision: 89.12 Recall: 89.50
#
# -----Validation-----
# AUC: 50.00 Precision: 50.00 Recall: 47.83
#
# Fold 11
#
# -----Train----------
# AUC: 87.39 Precision: 87.39 Recall: 87.39
#
# -----Validation-----
# AUC: 56.52 Precision: 57.14 Recall: 52.17
#
# wheezy-copper-turtle-magic 509
#
# Fold 1
#
# -----Train----------
# AUC: 92.06 Precision: 92.31 Recall: 91.48
#
# -----Validation-----
# AUC: 68.03 Precision: 68.18 Recall: 65.22
#
# Fold 2
#
# -----Train----------
# AUC: 90.52 Precision: 90.54 Recall: 90.13
#
# -----Validation-----
# AUC: 70.02 Precision: 73.68 Recall: 60.87
#
# Fold 3
#
# -----Train----------
# AUC: 91.40 Precision: 92.20 Recall: 90.13
#
# -----Validation-----
# AUC: 71.74 Precision: 75.00 Recall: 65.22
#
# Fold 4
#
# -----Train----------
# AUC: 92.11 Precision: 90.83 Recall: 93.27
#
# -----Validation-----
# AUC: 73.91 Precision: 78.95 Recall: 65.22
#
# Fold 5
#
# -----Train----------
# AUC: 92.09 Precision: 92.73 Recall: 91.07
#
# -----Validation-----
# AUC: 75.59 Precision: 73.91 Recall: 77.27
#
# Fold 6
#
# -----Train----------
# AUC: 94.31 Precision: 93.42 Recall: 95.09
#
# -----Validation-----
# AUC: 51.48 Precision: 50.00 Recall: 68.18
#
# Fold 7
#
# -----Train----------
# AUC: 91.44 Precision: 91.48 Recall: 91.07
#
# -----Validation-----
# AUC: 82.02 Precision: 88.89 Recall: 72.73
#
# Fold 8
#
# -----Train----------
# AUC: 92.76 Precision: 92.44 Recall: 92.86
#
# -----Validation-----
# AUC: 73.12 Precision: 77.78 Recall: 63.64
#
# Fold 9
#
# -----Train----------
# AUC: 93.20 Precision: 92.89 Recall: 93.30
#
# -----Validation-----
# AUC: 64.53 Precision: 62.50 Recall: 68.18
#
# Fold 10
#
# -----Train----------
# AUC: 90.79 Precision: 90.27 Recall: 91.07
#
# -----Validation-----
# AUC: 80.04 Precision: 78.26 Recall: 81.82
#
# Fold 11
#
# -----Train----------
# AUC: 93.40 Precision: 94.09 Recall: 92.41
#
# -----Validation-----
# AUC: 73.62 Precision: 67.86 Recall: 86.36
#
# wheezy-copper-turtle-magic 510
#
# Fold 1
#
# -----Train----------
# AUC: 90.36 Precision: 91.07 Recall: 89.08
#
# -----Validation-----
# AUC: 67.93 Precision: 70.00 Recall: 60.87
#
# Fold 2
#
# -----Train----------
# AUC: 88.84 Precision: 90.41 Recall: 86.46
#
# -----Validation-----
# AUC: 65.94 Precision: 65.22 Recall: 65.22
#
# Fold 3
#
# -----Train----------
# AUC: 89.71 Precision: 90.58 Recall: 88.21
#
# -----Validation-----
# AUC: 70.29 Precision: 68.00 Recall: 73.91
#
# Fold 4
#
# -----Train----------
# AUC: 89.07 Precision: 89.73 Recall: 87.77
#
# -----Validation-----
# AUC: 74.55 Precision: 72.00 Recall: 78.26
#
# Fold 5
#
# -----Train----------
# AUC: 89.94 Precision: 90.27 Recall: 89.08
#
# -----Validation-----
# AUC: 57.25 Precision: 57.89 Recall: 47.83
#
# Fold 6
#
# -----Train----------
# AUC: 88.47 Precision: 87.88 Recall: 88.65
#
# -----Validation-----
# AUC: 55.53 Precision: 53.57 Recall: 65.22
#
# Fold 7
#
# -----Train----------
# AUC: 89.07 Precision: 89.73 Recall: 87.77
#
# -----Validation-----
# AUC: 63.86 Precision: 62.50 Recall: 65.22
#
# Fold 8
#
# -----Train----------
# AUC: 91.86 Precision: 92.44 Recall: 90.83
#
# -----Validation-----
# AUC: 51.00 Precision: 50.00 Recall: 47.83
#
# Fold 9
#
# -----Train----------
# AUC: 88.66 Precision: 88.94 Recall: 87.77
#
# -----Validation-----
# AUC: 59.60 Precision: 58.33 Recall: 60.87
#
# Fold 10
#
# -----Train----------
# AUC: 88.90 Precision: 87.98 Recall: 89.52
#
# -----Validation-----
# AUC: 74.55 Precision: 72.00 Recall: 78.26
#
# Fold 11
#
# -----Train----------
# AUC: 88.26 Precision: 89.24 Recall: 86.52
#
# -----Validation-----
# AUC: 66.50 Precision: 68.42 Recall: 59.09
#
# wheezy-copper-turtle-magic 511
#
# Fold 1
#
# -----Train----------
# AUC: 90.79 Precision: 91.74 Recall: 90.17
#
# -----Validation-----
# AUC: 65.67 Precision: 63.33 Recall: 79.17
#
# Fold 2
#
# -----Train----------
# AUC: 92.03 Precision: 90.91 Recall: 94.02
#
# -----Validation-----
# AUC: 70.11 Precision: 69.23 Recall: 75.00
#
# Fold 3
#
# -----Train----------
# AUC: 89.68 Precision: 89.79 Recall: 90.17
#
# -----Validation-----
# AUC: 66.86 Precision: 65.52 Recall: 79.17
#
# Fold 4
#
# -----Train----------
# AUC: 89.45 Precision: 89.41 Recall: 90.17
#
# -----Validation-----
# AUC: 63.07 Precision: 65.22 Recall: 62.50
#
# Fold 5
#
# -----Train----------
# AUC: 89.69 Precision: 90.13 Recall: 89.74
#
# -----Validation-----
# AUC: 58.71 Precision: 60.87 Recall: 58.33
#
# Fold 6
#
# -----Train----------
# AUC: 90.15 Precision: 90.60 Recall: 90.21
#
# -----Validation-----
# AUC: 71.05 Precision: 70.83 Recall: 73.91
#
# Fold 7
#
# -----Train----------
# AUC: 90.10 Precision: 89.26 Recall: 91.91
#
# -----Validation-----
# AUC: 62.25 Precision: 63.64 Recall: 60.87
#
# Fold 8
#
# -----Train----------
# AUC: 90.35 Precision: 90.30 Recall: 91.06
#
# -----Validation-----
# AUC: 71.15 Precision: 72.73 Recall: 69.57
#
# Fold 9
#
# -----Train----------
# AUC: 89.50 Precision: 90.13 Recall: 89.36
#
# -----Validation-----
# AUC: 59.78 Precision: 59.26 Recall: 69.57
#
# Fold 10
#
# -----Train----------
# AUC: 89.96 Precision: 91.27 Recall: 88.94
#
# -----Validation-----
# AUC: 68.87 Precision: 69.57 Recall: 69.57
#
# Fold 11
#
# -----Train----------
# AUC: 90.40 Precision: 91.70 Recall: 89.36
#
# -----Validation-----
# AUC: 55.43 Precision: 56.00 Recall: 60.87

# %% [markdown]
# # Model evaluation
# ## Confusion matrix

# %%
f = plt.subplots(1, 1, figsize=(16, 5), sharex=True)
train_cnf_matrix = confusion_matrix(train['target'], [np.round(x) for x in train['preds']])
train_cnf_matrix_norm = train_cnf_matrix / train_cnf_matrix.sum(axis=1)[:, np.newaxis]
train_df_cm = pd.DataFrame(train_cnf_matrix_norm, index=[0, 1], columns=[0, 1])
sns.heatmap(train_df_cm, annot=True, fmt='.2f', cmap="Blues")
plt.show()

# %% [markdown]
# ## Metrics ROC AUC

# %%
print('AUC %.2f' % roc_auc_score(train['target'], train['preds']))
# Out:
# AUC 0.98

# %% [markdown]
# # Test predictions

# %%
submission = test[['id', 'target']]
submission.to_csv('submission.csv', index=False)
submission.head(10)
# Out:
#                                  id    target
# 0  1c13f2701648e0b0d46d8a2a5a131a53  0.510631
# 1  ba88c155ba898fc8b5099893036ef205  0.506642
# 2  7cbab5cea99169139e7e6d8ff74ebb77  0.507905
# 3  ca820ad57809f62eb7b4d13f5d4371a0  0.497071
# 4  7baaf361537fbd8a1aaa2c97a6d4ccc7  0.491893
# 5  8b3116e5e3e92e971dac305d1a093bf6  0.517948
# 6  35cfd7cab9bfa29bc963d1b8c94dd280  0.460226
# 7  83cf532df8ff4642a3e33a70fffdac37  0.518803
# 8  2e1350fe94ec9f2220bec5245e5e9265  0.507405
# 9  e62020afa72eb54a15725473e3a8475b  0.484511
