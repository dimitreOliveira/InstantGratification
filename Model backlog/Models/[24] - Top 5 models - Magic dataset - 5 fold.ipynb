# %% [markdown]
# # Dependencies

# %%
import warnings
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

from sklearn.svm import SVC, NuSVC
from sklearn.neural_network import MLPClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.discriminant_analysis import QuadraticDiscriminantAnalysis
from sklearn.feature_selection import VarianceThreshold
from sklearn.preprocessing import MinMaxScaler, StandardScaler
from sklearn.model_selection import train_test_split, StratifiedKFold
from sklearn.metrics import confusion_matrix, roc_auc_score, recall_score, precision_score

# Set seeds to make the experiment more reproducible.
from numpy.random import seed
seed(0)

# %matplotlib inline
sns.set_style("whitegrid")
warnings.filterwarnings("ignore")

# %% [markdown]
# # Load data

# %%
train = pd.read_csv('../input/train.csv')
test = pd.read_csv('../input/test.csv')

# %%
print('Train set shape:', train.shape)
print('Test set shape:', test.shape)
print('Train set overview:')
display(train.head())
# Out:
# Train set shape: (262144, 258)
# Test set shape: (131073, 257)
# Train set overview:
#                                  id   ...    target
# 0  707b395ecdcbb4dc2eabea00e4d1b179   ...         0
# 1  5880c03c6582a7b42248668e56b4bdec   ...         0
# 2  4ccbcb3d13e5072ff1d9c61afe2c4f77   ...         1
# 3  e350f17a357f12a1941f0837afb7eb8d   ...         0
# 4  a8f910ea6075b6376af079055965ff68   ...         0
#
# [5 rows x 258 columns]

# %% [markdown]
# ## Preprocess

# %% [markdown]
# # Model
#
# ## Model parameters

# %%
N_FOLDS = 5

# %% [markdown]
# ## QuadraticDiscriminantAnalysis

# %%
# INITIALIZE VARIABLES
cols = [c for c in train.columns if c not in ['id', 'target', 'wheezy-copper-turtle-magic', 'preds']]
test['target_qda'] = 0
train['preds_qda'] = 0

# BUILD 512 MODELS
for i in range(512):
    print('wheezy-copper-turtle-magic {}\n'.format(i))
    
    # EXTRACT SUBSET OF DATASET WHERE WHEEZY-MAGIC EQUALS I
    train2 = train[train['wheezy-copper-turtle-magic']==i]
    test2 = test[test['wheezy-copper-turtle-magic']==i]
    idx1 = train2.index
    idx2 = test2.index
    train2.reset_index(drop=True, inplace=True)
    
    # FEATURE SELECTION (USE APPROX 40 OF 255 FEATURES)
    sel = VarianceThreshold(threshold=1.5).fit(train2[cols])
    train3 = sel.transform(train2[cols])
    test3 = sel.transform(test2[cols])

    skf = StratifiedKFold(n_splits=N_FOLDS, random_state=0)
    counter = 0

    for train_index, val_index in skf.split(train3, train2['target']):
        counter += 1
        print('Fold {}\n'.format(counter))
        model = QuadraticDiscriminantAnalysis()
        model.fit(train3[train_index,:], train2.loc[train_index]['target'])
        
        train_predictions = model.predict(train3[train_index,:])
        val_predictions = model.predict(train3[val_index,:])

        train_auc = roc_auc_score(train2.loc[train_index]['target'], train_predictions) * 100
        val_auc = roc_auc_score(train2.loc[val_index]['target'], val_predictions) * 100
        train_precision = precision_score(train2.loc[train_index]['target'], train_predictions) * 100
        val_precision = precision_score(train2.loc[val_index]['target'], val_predictions) * 100
        train_recall = recall_score(train2.loc[train_index]['target'], train_predictions) * 100
        val_recall = recall_score(train2.loc[val_index]['target'], val_predictions) * 100
        print('-----Train----------')
        print('AUC: %.2f Precision: %.2f Recall: %.2f \n' % (train_auc, train_precision, train_recall))
        print('-----Validation-----')
        print('AUC: %.2f Precision: %.2f Recall: %.2f \n' % (val_auc, val_precision, val_recall))

        # Make predictions
        train['preds_qda'].loc[idx1] += model.predict_proba(train3)[:,1] / N_FOLDS
        test['target_qda'].loc[idx2] += model.predict_proba(test3)[:,1] / N_FOLDS
# Out:
# wheezy-copper-turtle-magic 0
#
# Fold 1
#
# -----Train----------
# AUC: 97.65 Precision: 98.08 Recall: 97.14
#
# -----Validation-----
# AUC: 88.85 Precision: 90.20 Recall: 86.79
#
# Fold 2
#
# -----Train----------
# AUC: 96.97 Precision: 96.24 Recall: 97.62
#
# -----Validation-----
# AUC: 94.37 Precision: 96.08 Recall: 92.45
#
# Fold 3
#
# -----Train----------
# AUC: 96.97 Precision: 96.24 Recall: 97.62
#
# -----Validation-----
# AUC: 99.06 Precision: 100.00 Recall: 98.11
#
# Fold 4
#
# -----Train----------
# AUC: 97.90 Precision: 97.64 Recall: 98.10
#
# -----Validation-----
# AUC: 88.64 Precision: 90.00 Recall: 86.54
#
# Fold 5
#
# -----Train----------
# AUC: 97.20 Precision: 96.71 Recall: 97.63
#
# -----Validation-----
# AUC: 92.38 Precision: 95.83 Recall: 88.46
#
# wheezy-copper-turtle-magic 1
#
# Fold 1
#
# -----Train----------
# AUC: 96.37 Precision: 94.58 Recall: 97.96
#
# -----Validation-----
# AUC: 95.17 Precision: 94.12 Recall: 96.00
#
# Fold 2
#
# -----Train----------
# AUC: 97.36 Precision: 95.59 Recall: 98.98
#
# -----Validation-----
# AUC: 87.35 Precision: 84.62 Recall: 89.80
#
# Fold 3
#
# -----Train----------
# AUC: 96.87 Precision: 95.10 Recall: 98.48
#
# -----Validation-----
# AUC: 91.12 Precision: 91.67 Recall: 89.80
#
# Fold 4
#
# -----Train----------
# AUC: 96.87 Precision: 95.10 Recall: 98.48
#
# -----Validation-----
# AUC: 91.12 Precision: 91.67 Recall: 89.80
#
# Fold 5
#
# -----Train----------
# AUC: 97.13 Precision: 95.12 Recall: 98.98
#
# -----Validation-----
# AUC: 94.05 Precision: 93.88 Recall: 93.88
#
# wheezy-copper-turtle-magic 2
#
# Fold 1
#
# -----Train----------
# AUC: 97.48 Precision: 96.94 Recall: 97.94
#
# -----Validation-----
# AUC: 92.98 Precision: 93.75 Recall: 91.84
#
# Fold 2
#
# -----Train----------
# AUC: 98.48 Precision: 98.45 Recall: 98.45
#
# -----Validation-----
# AUC: 89.06 Precision: 86.54 Recall: 91.84
#
# Fold 3
#
# -----Train----------
# AUC: 98.72 Precision: 99.48 Recall: 97.94
#
# -----Validation-----
# AUC: 87.90 Precision: 86.27 Recall: 89.80
#
# Fold 4
#
# -----Train----------
# AUC: 97.75 Precision: 96.50 Recall: 98.97
#
# -----Validation-----
# AUC: 92.79 Precision: 95.56 Recall: 89.58
#
# Fold 5
#
# -----Train----------
# AUC: 96.98 Precision: 96.92 Recall: 96.92
#
# -----Validation-----
# AUC: 97.00 Precision: 94.12 Recall: 100.00
#
# wheezy-copper-turtle-magic 3
#
# Fold 1
#
# -----Train----------
# AUC: 98.84 Precision: 99.10 Recall: 98.66
#
# -----Validation-----
# AUC: 94.48 Precision: 94.74 Recall: 94.74
#
# Fold 2
#
# -----Train----------
# AUC: 98.85 Precision: 99.11 Recall: 98.67
#
# -----Validation-----
# AUC: 92.51 Precision: 91.38 Recall: 94.64
#
# Fold 3
#
# -----Train----------
# AUC: 98.87 Precision: 99.55 Recall: 98.22
#
# -----Validation-----
# AUC: 92.42 Precision: 91.38 Recall: 94.64
#
# Fold 4
#
# -----Train----------
# AUC: 98.85 Precision: 99.11 Recall: 98.67
#
# -----Validation-----
# AUC: 87.24 Precision: 93.75 Recall: 80.36
#
# Fold 5
#
# -----Train----------
# AUC: 98.87 Precision: 99.55 Recall: 98.22
#
# -----Validation-----
# AUC: 91.61 Precision: 92.73 Recall: 91.07
#
# wheezy-copper-turtle-magic 4
#
# Fold 1
#
# -----Train----------
# AUC: 97.33 Precision: 97.58 Recall: 97.12
#
# -----Validation-----
# AUC: 88.46 Precision: 88.68 Recall: 88.68
#
# Fold 2
#
# -----Train----------
# AUC: 97.58 Precision: 97.61 Recall: 97.61
#
# -----Validation-----
# AUC: 92.27 Precision: 95.83 Recall: 88.46
#
# Fold 3
#
# -----Train----------
# AUC: 97.34 Precision: 98.06 Recall: 96.65
#
# -----Validation-----
# AUC: 88.33 Precision: 87.04 Recall: 90.38
#
# Fold 4
#
# -----Train----------
# AUC: 98.07 Precision: 98.55 Recall: 97.61
#
# -----Validation-----
# AUC: 93.17 Precision: 90.91 Recall: 96.15
#
# Fold 5
#
# -----Train----------
# AUC: 97.58 Precision: 98.07 Recall: 97.13
#
# -----Validation-----
# AUC: 93.19 Precision: 92.45 Recall: 94.23
#
# wheezy-copper-turtle-magic 5
#
# Fold 1
#
# -----Train----------
# AUC: 97.83 Precision: 98.53 Recall: 97.10
#
# -----Validation-----
# AUC: 87.61 Precision: 88.24 Recall: 86.54
#
# Fold 2
#
# -----Train----------
# AUC: 97.59 Precision: 99.00 Recall: 96.14
#
# -----Validation-----
# AUC: 93.32 Precision: 94.12 Recall: 92.31
#
# Fold 3
#
# -----Train----------
# AUC: 97.60 Precision: 98.05 Recall: 97.10
#
# -----Validation-----
# AUC: 88.46 Precision: 88.46 Recall: 88.46
#
# Fold 4
#
# -----Train----------
# AUC: 97.59 Precision: 98.52 Recall: 96.62
#
# -----Validation-----
# AUC: 92.31 Precision: 94.00 Recall: 90.38
#
# Fold 5
#
# -----Train----------
# AUC: 98.32 Precision: 99.02 Recall: 97.60
#
# -----Validation-----
# AUC: 90.25 Precision: 93.62 Recall: 86.27
#
# wheezy-copper-turtle-magic 6
#
# Fold 1
#
# -----Train----------
# AUC: 98.30 Precision: 98.12 Recall: 98.58
#
# -----Validation-----
# AUC: 95.28 Precision: 100.00 Recall: 90.57
#
# Fold 2
#
# -----Train----------
# AUC: 98.56 Precision: 99.05 Recall: 98.11
#
# -----Validation-----
# AUC: 95.17 Precision: 94.44 Recall: 96.23
#
# Fold 3
#
# -----Train----------
# AUC: 98.31 Precision: 98.58 Recall: 98.11
#
# -----Validation-----
# AUC: 95.14 Precision: 92.86 Recall: 98.11
#
# Fold 4
#
# -----Train----------
# AUC: 97.34 Precision: 97.18 Recall: 97.64
#
# -----Validation-----
# AUC: 95.17 Precision: 96.15 Recall: 94.34
#
# Fold 5
#
# -----Train----------
# AUC: 98.80 Precision: 99.05 Recall: 98.58
#
# -----Validation-----
# AUC: 93.23 Precision: 94.23 Recall: 92.45
#
# wheezy-copper-turtle-magic 7
#
# Fold 1
#
# -----Train----------
# AUC: 97.77 Precision: 97.55 Recall: 98.03
#
# -----Validation-----
# AUC: 88.24 Precision: 89.80 Recall: 86.27
#
# Fold 2
#
# -----Train----------
# AUC: 97.78 Precision: 98.99 Recall: 96.55
#
# -----Validation-----
# AUC: 89.22 Precision: 88.46 Recall: 90.20
#
# Fold 3
#
# -----Train----------
# AUC: 97.28 Precision: 97.06 Recall: 97.54
#
# -----Validation-----
# AUC: 85.12 Precision: 83.33 Recall: 88.24
#
# Fold 4
#
# -----Train----------
# AUC: 98.02 Precision: 98.03 Recall: 98.03
#
# -----Validation-----
# AUC: 91.14 Precision: 95.65 Recall: 86.27
#
# Fold 5
#
# -----Train----------
# AUC: 98.03 Precision: 98.51 Recall: 97.55
#
# -----Validation-----
# AUC: 85.00 Precision: 84.31 Recall: 86.00
#
# wheezy-copper-turtle-magic 8
#
# Fold 1
#
# -----Train----------
# AUC: 98.32 Precision: 98.13 Recall: 98.59
#
# -----Validation-----
# AUC: 92.48 Precision: 96.00 Recall: 88.89
#
# Fold 2
#
# -----Train----------
# AUC: 97.61 Precision: 98.10 Recall: 97.18
#
# -----Validation-----
# AUC: 93.41 Precision: 96.08 Recall: 90.74
#
# Fold 3
#
# -----Train----------
# AUC: 98.33 Precision: 98.59 Recall: 98.13
#
# -----Validation-----
# AUC: 90.46 Precision: 93.88 Recall: 86.79
#
# Fold 4
#
# -----Train----------
# AUC: 98.81 Precision: 99.06 Recall: 98.60
#
# -----Validation-----
# AUC: 89.44 Precision: 90.38 Recall: 88.68
#
# Fold 5
#
# -----Train----------
# AUC: 98.80 Precision: 98.60 Recall: 99.07
#
# -----Validation-----
# AUC: 93.25 Precision: 92.59 Recall: 94.34
#
# wheezy-copper-turtle-magic 9
#
# Fold 1
#
# -----Train----------
# AUC: 98.34 Precision: 99.51 Recall: 97.16
#
# -----Validation-----
# AUC: 93.40 Precision: 94.23 Recall: 92.45
#
# Fold 2
#
# -----Train----------
# AUC: 97.63 Precision: 98.09 Recall: 97.16
#
# -----Validation-----
# AUC: 91.51 Precision: 94.00 Recall: 88.68
#
# Fold 3
#
# -----Train----------
# AUC: 97.39 Precision: 99.02 Recall: 95.73
#
# -----Validation-----
# AUC: 94.34 Precision: 92.73 Recall: 96.23
#
# Fold 4
#
# -----Train----------
# AUC: 97.87 Precision: 99.03 Recall: 96.68
#
# -----Validation-----
# AUC: 84.91 Precision: 87.76 Recall: 81.13
#
# Fold 5
#
# -----Train----------
# AUC: 96.93 Precision: 97.61 Recall: 96.23
#
# -----Validation-----
# AUC: 96.15 Precision: 98.00 Recall: 94.23
#
# wheezy-copper-turtle-magic 10
#
# Fold 1
#
# -----Train----------
# AUC: 99.00 Precision: 98.48 Recall: 99.49
#
# -----Validation-----
# AUC: 95.06 Precision: 94.12 Recall: 96.00
#
# Fold 2
#
# -----Train----------
# AUC: 98.50 Precision: 97.99 Recall: 98.98
#
# -----Validation-----
# AUC: 96.00 Precision: 95.92 Recall: 95.92
#
# Fold 3
#
# -----Train----------
# AUC: 98.50 Precision: 97.99 Recall: 98.98
#
# -----Validation-----
# AUC: 90.92 Precision: 90.00 Recall: 91.84
#
# Fold 4
#
# -----Train----------
# AUC: 98.01 Precision: 97.01 Recall: 98.98
#
# -----Validation-----
# AUC: 91.90 Precision: 93.62 Recall: 89.80
#
# Fold 5
#
# -----Train----------
# AUC: 98.26 Precision: 97.03 Recall: 99.49
#
# -----Validation-----
# AUC: 91.90 Precision: 93.62 Recall: 89.80
#
# wheezy-copper-turtle-magic 11
#
# Fold 1
#
# -----Train----------
# AUC: 98.73 Precision: 97.87 Recall: 99.46
#
# -----Validation-----
# AUC: 91.74 Precision: 91.49 Recall: 91.49
#
# Fold 2
#
# -----Train----------
# AUC: 98.21 Precision: 97.34 Recall: 98.92
#
# -----Validation-----
# AUC: 93.74 Precision: 95.56 Recall: 91.49
#
# Fold 3
#
# -----Train----------
# AUC: 98.44 Precision: 98.39 Recall: 98.39
#
# -----Validation-----
# AUC: 91.83 Precision: 88.00 Recall: 95.65
#
# Fold 4
#
# -----Train----------
# AUC: 97.92 Precision: 97.85 Recall: 97.85
#
# -----Validation-----
# AUC: 92.74 Precision: 91.49 Recall: 93.48
#
# Fold 5
#
# -----Train----------
# AUC: 97.41 Precision: 97.31 Recall: 97.31
#
# -----Validation-----
# AUC: 93.65 Precision: 95.45 Recall: 91.30
#
# wheezy-copper-turtle-magic 12
#
# Fold 1
#
# -----Train----------
# AUC: 97.22 Precision: 97.49 Recall: 97.00
#
# -----Validation-----
# AUC: 94.04 Precision: 95.92 Recall: 92.16
#
# Fold 2
#
# -----Train----------
# AUC: 98.00 Precision: 99.49 Recall: 96.52
#
# -----Validation-----
# AUC: 97.98 Precision: 98.00 Recall: 98.00
#
# Fold 3
#
# -----Train----------
# AUC: 98.25 Precision: 99.49 Recall: 97.01
#
# -----Validation-----
# AUC: 87.84 Precision: 85.19 Recall: 92.00
#
# Fold 4
#
# -----Train----------
# AUC: 98.00 Precision: 98.98 Recall: 97.01
#
# -----Validation-----
# AUC: 92.94 Precision: 93.88 Recall: 92.00
#
# Fold 5
#
# -----Train----------
# AUC: 98.00 Precision: 98.98 Recall: 97.01
#
# -----Validation-----
# AUC: 92.96 Precision: 95.74 Recall: 90.00
#
# wheezy-copper-turtle-magic 13
#
# Fold 1
#
# -----Train----------
# AUC: 97.95 Precision: 97.37 Recall: 98.40
#
# -----Validation-----
# AUC: 94.87 Precision: 93.75 Recall: 95.74
#
# Fold 2
#
# -----Train----------
# AUC: 98.20 Precision: 97.88 Recall: 98.40
#
# -----Validation-----
# AUC: 95.87 Precision: 95.74 Recall: 95.74
#
# Fold 3
#
# -----Train----------
# AUC: 97.92 Precision: 98.39 Recall: 97.34
#
# -----Validation-----
# AUC: 94.81 Precision: 95.65 Recall: 93.62
#
# Fold 4
#
# -----Train----------
# AUC: 98.20 Precision: 97.88 Recall: 98.40
#
# -----Validation-----
# AUC: 91.81 Precision: 89.80 Recall: 93.62
#
# Fold 5
#
# -----Train----------
# AUC: 98.22 Precision: 97.38 Recall: 98.94
#
# -----Validation-----
# AUC: 90.68 Precision: 91.30 Recall: 89.36
#
# wheezy-copper-turtle-magic 14
#
# Fold 1
#
# -----Train----------
# AUC: 98.69 Precision: 98.90 Recall: 98.35
#
# -----Validation-----
# AUC: 90.59 Precision: 93.02 Recall: 86.96
#
# Fold 2
#
# -----Train----------
# AUC: 99.51 Precision: 98.91 Recall: 100.00
#
# -----Validation-----
# AUC: 94.94 Precision: 93.62 Recall: 95.65
#
# Fold 3
#
# -----Train----------
# AUC: 99.24 Precision: 98.91 Recall: 99.45
#
# -----Validation-----
# AUC: 93.73 Precision: 95.45 Recall: 91.30
#
# Fold 4
#
# -----Train----------
# AUC: 98.97 Precision: 98.91 Recall: 98.91
#
# -----Validation-----
# AUC: 94.71 Precision: 95.45 Recall: 93.33
#
# Fold 5
#
# -----Train----------
# AUC: 99.49 Precision: 99.45 Recall: 99.45
#
# -----Validation-----
# AUC: 93.59 Precision: 95.35 Recall: 91.11
#
# wheezy-copper-turtle-magic 15
#
# Fold 1
#
# -----Train----------
# AUC: 97.57 Precision: 97.60 Recall: 97.60
#
# -----Validation-----
# AUC: 93.29 Precision: 94.23 Recall: 92.45
#
# Fold 2
#
# -----Train----------
# AUC: 97.58 Precision: 98.07 Recall: 97.13
#
# -----Validation-----
# AUC: 95.14 Precision: 94.34 Recall: 96.15
#
# Fold 3
#
# -----Train----------
# AUC: 98.56 Precision: 99.51 Recall: 97.61
#
# -----Validation-----
# AUC: 90.27 Precision: 88.89 Recall: 92.31
#
# Fold 4
#
# -----Train----------
# AUC: 98.55 Precision: 98.56 Recall: 98.56
#
# -----Validation-----
# AUC: 94.19 Precision: 96.00 Recall: 92.31
#
# Fold 5
#
# -----Train----------
# AUC: 98.55 Precision: 99.03 Recall: 98.09
#
# -----Validation-----
# AUC: 88.31 Precision: 85.71 Recall: 92.31
#
# wheezy-copper-turtle-magic 16
#
# Fold 1
#
# -----Train----------
# AUC: 97.56 Precision: 97.98 Recall: 97.00
#
# -----Validation-----
# AUC: 91.56 Precision: 87.50 Recall: 96.08
#
# Fold 2
#
# -----Train----------
# AUC: 98.55 Precision: 98.51 Recall: 98.51
#
# -----Validation-----
# AUC: 91.40 Precision: 87.27 Recall: 96.00
#
# Fold 3
#
# -----Train----------
# AUC: 97.35 Precision: 97.03 Recall: 97.51
#
# -----Validation-----
# AUC: 96.06 Precision: 97.92 Recall: 94.00
#
# Fold 4
#
# -----Train----------
# AUC: 98.05 Precision: 98.49 Recall: 97.51
#
# -----Validation-----
# AUC: 94.11 Precision: 95.83 Recall: 92.00
#
# Fold 5
#
# -----Train----------
# AUC: 98.09 Precision: 97.07 Recall: 99.00
#
# -----Validation-----
# AUC: 93.17 Precision: 93.88 Recall: 92.00
#
# wheezy-copper-turtle-magic 17
#
# Fold 1
#
# -----Train----------
# AUC: 98.04 Precision: 98.09 Recall: 98.09
#
# -----Validation-----
# AUC: 94.23 Precision: 96.08 Recall: 92.45
#
# Fold 2
#
# -----Train----------
# AUC: 98.28 Precision: 98.10 Recall: 98.56
#
# -----Validation-----
# AUC: 93.17 Precision: 92.59 Recall: 94.34
#
# Fold 3
#
# -----Train----------
# AUC: 98.28 Precision: 98.10 Recall: 98.57
#
# -----Validation-----
# AUC: 93.15 Precision: 94.12 Recall: 92.31
#
# Fold 4
#
# -----Train----------
# AUC: 98.04 Precision: 98.10 Recall: 98.10
#
# -----Validation-----
# AUC: 93.12 Precision: 92.45 Recall: 94.23
#
# Fold 5
#
# -----Train----------
# AUC: 98.54 Precision: 98.57 Recall: 98.57
#
# -----Validation-----
# AUC: 96.04 Precision: 96.15 Recall: 96.15
#
# wheezy-copper-turtle-magic 18
#
# Fold 1
#
# -----Train----------
# AUC: 99.03 Precision: 99.06 Recall: 99.06
#
# -----Validation-----
# AUC: 96.19 Precision: 98.04 Recall: 94.34
#
# Fold 2
#
# -----Train----------
# AUC: 99.04 Precision: 99.52 Recall: 98.58
#
# -----Validation-----
# AUC: 95.17 Precision: 94.44 Recall: 96.23
#
# Fold 3
#
# -----Train----------
# AUC: 98.79 Precision: 98.59 Recall: 99.06
#
# -----Validation-----
# AUC: 89.36 Precision: 87.50 Recall: 92.45
#
# Fold 4
#
# -----Train----------
# AUC: 98.79 Precision: 98.59 Recall: 99.06
#
# -----Validation-----
# AUC: 96.17 Precision: 98.04 Recall: 94.34
#
# Fold 5
#
# -----Train----------
# AUC: 99.05 Precision: 99.52 Recall: 98.58
#
# -----Validation-----
# AUC: 97.06 Precision: 96.30 Recall: 98.11
#
# wheezy-copper-turtle-magic 19
#
# Fold 1
#
# -----Train----------
# AUC: 98.57 Precision: 98.13 Recall: 99.06
#
# -----Validation-----
# AUC: 90.57 Precision: 90.57 Recall: 90.57
#
# Fold 2
#
# -----Train----------
# AUC: 98.57 Precision: 98.58 Recall: 98.58
#
# -----Validation-----
# AUC: 89.50 Precision: 87.50 Recall: 92.45
#
# Fold 3
#
# -----Train----------
# AUC: 97.39 Precision: 97.18 Recall: 97.64
#
# -----Validation-----
# AUC: 92.36 Precision: 90.91 Recall: 94.34
#
# Fold 4
#
# -----Train----------
# AUC: 98.10 Precision: 98.57 Recall: 97.64
#
# -----Validation-----
# AUC: 90.42 Precision: 86.44 Recall: 96.23
#
# Fold 5
#
# -----Train----------
# AUC: 98.81 Precision: 99.05 Recall: 98.58
#
# -----Validation-----
# AUC: 92.42 Precision: 95.92 Recall: 88.68
#
# wheezy-copper-turtle-magic 20
#
# Fold 1
#
# -----Train----------
# AUC: 97.82 Precision: 96.98 Recall: 98.47
#
# -----Validation-----
# AUC: 87.30 Precision: 91.11 Recall: 82.00
#
# Fold 2
#
# -----Train----------
# AUC: 98.06 Precision: 97.49 Recall: 98.48
#
# -----Validation-----
# AUC: 87.43 Precision: 83.33 Recall: 91.84
#
# Fold 3
#
# -----Train----------
# AUC: 96.58 Precision: 96.45 Recall: 96.45
#
# -----Validation-----
# AUC: 90.34 Precision: 86.79 Recall: 93.88
#
# Fold 4
#
# -----Train----------
# AUC: 98.52 Precision: 98.97 Recall: 97.97
#
# -----Validation-----
# AUC: 95.21 Precision: 92.31 Recall: 97.96
#
# Fold 5
#
# -----Train----------
# AUC: 98.30 Precision: 97.98 Recall: 98.48
#
# -----Validation-----
# AUC: 90.03 Precision: 93.33 Recall: 85.71
#
# wheezy-copper-turtle-magic 21
#
# Fold 1
#
# -----Train----------
# AUC: 97.89 Precision: 98.14 Recall: 97.69
#
# -----Validation-----
# AUC: 94.39 Precision: 94.44 Recall: 94.44
#
# Fold 2
#
# -----Train----------
# AUC: 97.41 Precision: 97.67 Recall: 97.22
#
# -----Validation-----
# AUC: 91.60 Precision: 92.45 Recall: 90.74
#
# Fold 3
#
# -----Train----------
# AUC: 97.66 Precision: 98.13 Recall: 97.22
#
# -----Validation-----
# AUC: 94.30 Precision: 92.86 Recall: 96.30
#
# Fold 4
#
# -----Train----------
# AUC: 97.65 Precision: 97.69 Recall: 97.69
#
# -----Validation-----
# AUC: 95.30 Precision: 96.23 Recall: 94.44
#
# Fold 5
#
# -----Train----------
# AUC: 98.35 Precision: 98.16 Recall: 98.61
#
# -----Validation-----
# AUC: 91.56 Precision: 94.12 Recall: 88.89
#
# wheezy-copper-turtle-magic 22
#
# Fold 1
#
# -----Train----------
# AUC: 98.37 Precision: 98.64 Recall: 98.19
#
# -----Validation-----
# AUC: 94.30 Precision: 91.67 Recall: 98.21
#
# Fold 2
#
# -----Train----------
# AUC: 98.84 Precision: 99.09 Recall: 98.64
#
# -----Validation-----
# AUC: 96.29 Precision: 96.43 Recall: 96.43
#
# Fold 3
#
# -----Train----------
# AUC: 98.38 Precision: 98.64 Recall: 98.20
#
# -----Validation-----
# AUC: 96.26 Precision: 96.36 Recall: 96.36
#
# Fold 4
#
# -----Train----------
# AUC: 98.36 Precision: 98.21 Recall: 98.65
#
# -----Validation-----
# AUC: 95.35 Precision: 96.30 Recall: 94.55
#
# Fold 5
#
# -----Train----------
# AUC: 98.84 Precision: 99.10 Recall: 98.65
#
# -----Validation-----
# AUC: 94.34 Precision: 92.98 Recall: 96.36
#
# wheezy-copper-turtle-magic 23
#
# Fold 1
#
# -----Train----------
# AUC: 98.09 Precision: 99.04 Recall: 97.17
#
# -----Validation-----
# AUC: 95.30 Precision: 96.23 Recall: 94.44
#
# Fold 2
#
# -----Train----------
# AUC: 98.58 Precision: 99.52 Recall: 97.65
#
# -----Validation-----
# AUC: 88.38 Precision: 85.96 Recall: 92.45
#
# Fold 3
#
# -----Train----------
# AUC: 99.05 Precision: 99.53 Recall: 98.59
#
# -----Validation-----
# AUC: 92.30 Precision: 92.45 Recall: 92.45
#
# Fold 4
#
# -----Train----------
# AUC: 98.58 Precision: 99.52 Recall: 97.65
#
# -----Validation-----
# AUC: 87.55 Precision: 90.00 Recall: 84.91
#
# Fold 5
#
# -----Train----------
# AUC: 98.58 Precision: 99.52 Recall: 97.65
#
# -----Validation-----
# AUC: 94.23 Precision: 94.34 Recall: 94.34
#
# wheezy-copper-turtle-magic 24
#
# Fold 1
#
# -----Train----------
# AUC: 97.94 Precision: 98.37 Recall: 97.31
#
# -----Validation-----
# AUC: 95.87 Precision: 97.78 Recall: 93.62
#
# Fold 2
#
# -----Train----------
# AUC: 98.51 Precision: 97.87 Recall: 98.92
#
# -----Validation-----
# AUC: 88.08 Precision: 85.71 Recall: 89.36
#
# Fold 3
#
# -----Train----------
# AUC: 98.75 Precision: 98.40 Recall: 98.92
#
# -----Validation-----
# AUC: 87.75 Precision: 88.89 Recall: 85.11
#
# Fold 4
#
# -----Train----------
# AUC: 98.48 Precision: 98.40 Recall: 98.40
#
# -----Validation-----
# AUC: 94.57 Precision: 100.00 Recall: 89.13
#
# Fold 5
#
# -----Train----------
# AUC: 98.78 Precision: 97.89 Recall: 99.47
#
# -----Validation-----
# AUC: 89.38 Precision: 95.00 Recall: 82.61
#
# wheezy-copper-turtle-magic 25
#
# Fold 1
#
# -----Train----------
# AUC: 98.47 Precision: 98.39 Recall: 98.39
#
# -----Validation-----
# AUC: 90.83 Precision: 91.30 Recall: 89.36
#
# Fold 2
#
# -----Train----------
# AUC: 97.69 Precision: 97.84 Recall: 97.31
#
# -----Validation-----
# AUC: 94.99 Precision: 93.75 Recall: 95.74
#
# Fold 3
#
# -----Train----------
# AUC: 97.93 Precision: 98.37 Recall: 97.31
#
# -----Validation-----
# AUC: 90.63 Precision: 95.24 Recall: 85.11
#
# Fold 4
#
# -----Train----------
# AUC: 97.67 Precision: 98.37 Recall: 96.79
#
# -----Validation-----
# AUC: 95.87 Precision: 95.65 Recall: 95.65
#
# Fold 5
#
# -----Train----------
# AUC: 97.89 Precision: 99.45 Recall: 96.26
#
# -----Validation-----
# AUC: 91.62 Precision: 93.18 Recall: 89.13
#
# wheezy-copper-turtle-magic 26
#
# Fold 1
#
# -----Train----------
# AUC: 98.50 Precision: 97.40 Recall: 99.47
#
# -----Validation-----
# AUC: 87.81 Precision: 89.13 Recall: 85.42
#
# Fold 2
#
# -----Train----------
# AUC: 98.46 Precision: 98.41 Recall: 98.41
#
# -----Validation-----
# AUC: 89.86 Precision: 87.76 Recall: 91.49
#
# Fold 3
#
# -----Train----------
# AUC: 97.69 Precision: 97.87 Recall: 97.35
#
# -----Validation-----
# AUC: 91.91 Precision: 89.80 Recall: 93.62
#
# Fold 4
#
# -----Train----------
# AUC: 97.69 Precision: 97.87 Recall: 97.35
#
# -----Validation-----
# AUC: 96.94 Precision: 95.83 Recall: 97.87
#
# Fold 5
#
# -----Train----------
# AUC: 97.45 Precision: 97.35 Recall: 97.35
#
# -----Validation-----
# AUC: 92.74 Precision: 93.48 Recall: 91.49
#
# wheezy-copper-turtle-magic 27
#
# Fold 1
#
# -----Train----------
# AUC: 97.59 Precision: 95.92 Recall: 98.95
#
# -----Validation-----
# AUC: 92.94 Precision: 95.56 Recall: 89.58
#
# Fold 2
#
# -----Train----------
# AUC: 96.57 Precision: 95.36 Recall: 97.37
#
# -----Validation-----
# AUC: 92.81 Precision: 97.67 Recall: 87.50
#
# Fold 3
#
# -----Train----------
# AUC: 96.54 Precision: 95.83 Recall: 96.84
#
# -----Validation-----
# AUC: 92.90 Precision: 95.56 Recall: 89.58
#
# Fold 4
#
# -----Train----------
# AUC: 96.79 Precision: 96.35 Recall: 96.86
#
# -----Validation-----
# AUC: 91.03 Precision: 89.58 Recall: 91.49
#
# Fold 5
#
# -----Train----------
# AUC: 97.28 Precision: 96.88 Recall: 97.38
#
# -----Validation-----
# AUC: 88.08 Precision: 85.71 Recall: 89.36
#
# wheezy-copper-turtle-magic 28
#
# Fold 1
#
# -----Train----------
# AUC: 97.90 Precision: 98.13 Recall: 97.67
#
# -----Validation-----
# AUC: 91.67 Precision: 92.45 Recall: 90.74
#
# Fold 2
#
# -----Train----------
# AUC: 97.44 Precision: 97.66 Recall: 97.21
#
# -----Validation-----
# AUC: 92.59 Precision: 92.59 Recall: 92.59
#
# Fold 3
#
# -----Train----------
# AUC: 98.37 Precision: 99.06 Recall: 97.67
#
# -----Validation-----
# AUC: 92.59 Precision: 96.00 Recall: 88.89
#
# Fold 4
#
# -----Train----------
# AUC: 96.98 Precision: 98.56 Recall: 95.35
#
# -----Validation-----
# AUC: 98.15 Precision: 100.00 Recall: 96.30
#
# Fold 5
#
# -----Train----------
# AUC: 97.91 Precision: 98.59 Recall: 97.22
#
# -----Validation-----
# AUC: 88.68 Precision: 88.68 Recall: 88.68
#
# wheezy-copper-turtle-magic 29
#
# Fold 1
#
# -----Train----------
# AUC: 98.74 Precision: 98.51 Recall: 99.00
#
# -----Validation-----
# AUC: 92.00 Precision: 90.38 Recall: 94.00
#
# Fold 2
#
# -----Train----------
# AUC: 98.49 Precision: 98.02 Recall: 99.00
#
# -----Validation-----
# AUC: 88.00 Precision: 89.58 Recall: 86.00
#
# Fold 3
#
# -----Train----------
# AUC: 97.49 Precision: 97.50 Recall: 97.50
#
# -----Validation-----
# AUC: 94.00 Precision: 95.83 Recall: 92.00
#
# Fold 4
#
# -----Train----------
# AUC: 98.50 Precision: 98.99 Recall: 98.00
#
# -----Validation-----
# AUC: 92.92 Precision: 92.16 Recall: 94.00
#
# Fold 5
#
# -----Train----------
# AUC: 97.99 Precision: 98.00 Recall: 98.00
#
# -----Validation-----
# AUC: 95.94 Precision: 94.23 Recall: 98.00
#
# wheezy-copper-turtle-magic 30
#
# Fold 1
#
# -----Train----------
# AUC: 97.84 Precision: 98.58 Recall: 97.21
#
# -----Validation-----
# AUC: 94.37 Precision: 98.00 Recall: 90.74
#
# Fold 2
#
# -----Train----------
# AUC: 98.08 Precision: 98.59 Recall: 97.67
#
# -----Validation-----
# AUC: 93.14 Precision: 92.73 Recall: 94.44
#
# Fold 3
#
# -----Train----------
# AUC: 98.77 Precision: 98.61 Recall: 99.07
#
# -----Validation-----
# AUC: 92.12 Precision: 91.07 Recall: 94.44
#
# Fold 4
#
# -----Train----------
# AUC: 98.33 Precision: 99.06 Recall: 97.67
#
# -----Validation-----
# AUC: 95.09 Precision: 94.55 Recall: 96.30
#
# Fold 5
#
# -----Train----------
# AUC: 98.08 Precision: 98.60 Recall: 97.69
#
# -----Validation-----
# AUC: 94.97 Precision: 92.86 Recall: 98.11
#
# wheezy-copper-turtle-magic 31
#
# Fold 1
#
# -----Train----------
# AUC: 97.79 Precision: 97.51 Recall: 98.00
#
# -----Validation-----
# AUC: 89.37 Precision: 85.71 Recall: 94.12
#
# Fold 2
#
# -----Train----------
# AUC: 97.55 Precision: 97.04 Recall: 98.01
#
# -----Validation-----
# AUC: 90.19 Precision: 90.00 Recall: 90.00
#
# Fold 3
#
# -----Train----------
# AUC: 97.31 Precision: 96.57 Recall: 98.01
#
# -----Validation-----
# AUC: 91.15 Precision: 91.84 Recall: 90.00
#
# Fold 4
#
# -----Train----------
# AUC: 97.80 Precision: 97.52 Recall: 98.01
#
# -----Validation-----
# AUC: 91.14 Precision: 87.27 Recall: 96.00
#
# Fold 5
#
# -----Train----------
# AUC: 96.34 Precision: 95.15 Recall: 97.51
#
# -----Validation-----
# AUC: 92.08 Precision: 92.00 Recall: 92.00
#
# wheezy-copper-turtle-magic 32
#
# Fold 1
#
# -----Train----------
# AUC: 99.25 Precision: 98.42 Recall: 100.00
#
# -----Validation-----
# AUC: 90.74 Precision: 89.58 Recall: 91.49
#
# Fold 2
#
# -----Train----------
# AUC: 98.23 Precision: 96.88 Recall: 99.47
#
# -----Validation-----
# AUC: 87.62 Precision: 87.23 Recall: 87.23
#
# Fold 3
#
# -----Train----------
# AUC: 98.99 Precision: 97.91 Recall: 100.00
#
# -----Validation-----
# AUC: 91.68 Precision: 93.33 Recall: 89.36
#
# Fold 4
#
# -----Train----------
# AUC: 98.74 Precision: 97.40 Recall: 100.00
#
# -----Validation-----
# AUC: 93.94 Precision: 90.20 Recall: 97.87
#
# Fold 5
#
# -----Train----------
# AUC: 98.98 Precision: 98.42 Recall: 99.47
#
# -----Validation-----
# AUC: 89.40 Precision: 90.91 Recall: 86.96
#
# wheezy-copper-turtle-magic 33
#
# Fold 1
#
# -----Train----------
# AUC: 97.16 Precision: 97.64 Recall: 96.73
#
# -----Validation-----
# AUC: 88.64 Precision: 87.50 Recall: 90.74
#
# Fold 2
#
# -----Train----------
# AUC: 97.40 Precision: 98.10 Recall: 96.73
#
# -----Validation-----
# AUC: 91.56 Precision: 94.12 Recall: 88.89
#
# Fold 3
#
# -----Train----------
# AUC: 96.69 Precision: 97.17 Recall: 96.26
#
# -----Validation-----
# AUC: 95.37 Precision: 100.00 Recall: 90.74
#
# Fold 4
#
# -----Train----------
# AUC: 97.17 Precision: 97.65 Recall: 96.74
#
# -----Validation-----
# AUC: 93.34 Precision: 94.23 Recall: 92.45
#
# Fold 5
#
# -----Train----------
# AUC: 97.39 Precision: 96.79 Recall: 98.14
#
# -----Validation-----
# AUC: 94.30 Precision: 96.08 Recall: 92.45
#
# wheezy-copper-turtle-magic 34
#
# Fold 1
#
# -----Train----------
# AUC: 98.53 Precision: 98.21 Recall: 99.10
#
# -----Validation-----
# AUC: 89.64 Precision: 90.91 Recall: 89.29
#
# Fold 2
#
# -----Train----------
# AUC: 97.85 Precision: 98.18 Recall: 97.74
#
# -----Validation-----
# AUC: 95.32 Precision: 96.36 Recall: 94.64
#
# Fold 3
#
# -----Train----------
# AUC: 98.85 Precision: 99.54 Recall: 98.20
#
# -----Validation-----
# AUC: 93.99 Precision: 91.53 Recall: 98.18
#
# Fold 4
#
# -----Train----------
# AUC: 98.34 Precision: 98.64 Recall: 98.20
#
# -----Validation-----
# AUC: 94.32 Precision: 96.23 Recall: 92.73
#
# Fold 5
#
# -----Train----------
# AUC: 98.09 Precision: 98.20 Recall: 98.20
#
# -----Validation-----
# AUC: 94.90 Precision: 91.67 Recall: 100.00
#
# wheezy-copper-turtle-magic 35
#
# Fold 1
#
# -----Train----------
# AUC: 97.52 Precision: 97.12 Recall: 98.06
#
# -----Validation-----
# AUC: 96.12 Precision: 98.00 Recall: 94.23
#
# Fold 2
#
# -----Train----------
# AUC: 97.76 Precision: 97.13 Recall: 98.54
#
# -----Validation-----
# AUC: 93.12 Precision: 92.45 Recall: 94.23
#
# Fold 3
#
# -----Train----------
# AUC: 97.78 Precision: 98.05 Recall: 97.57
#
# -----Validation-----
# AUC: 88.23 Precision: 88.46 Recall: 88.46
#
# Fold 4
#
# -----Train----------
# AUC: 98.27 Precision: 98.08 Recall: 98.55
#
# -----Validation-----
# AUC: 91.14 Precision: 95.65 Recall: 86.27
#
# Fold 5
#
# -----Train----------
# AUC: 98.04 Precision: 98.54 Recall: 97.58
#
# -----Validation-----
# AUC: 90.00 Precision: 90.20 Recall: 90.20
#
# wheezy-copper-turtle-magic 36
#
# Fold 1
#
# -----Train----------
# AUC: 98.18 Precision: 98.33 Recall: 97.79
#
# -----Validation-----
# AUC: 90.79 Precision: 91.11 Recall: 89.13
#
# Fold 2
#
# -----Train----------
# AUC: 98.42 Precision: 98.88 Recall: 97.79
#
# -----Validation-----
# AUC: 94.05 Precision: 91.67 Recall: 95.65
#
# Fold 3
#
# -----Train----------
# AUC: 97.72 Precision: 97.27 Recall: 97.80
#
# -----Validation-----
# AUC: 94.95 Precision: 93.48 Recall: 95.56
#
# Fold 4
#
# -----Train----------
# AUC: 98.70 Precision: 98.90 Recall: 98.35
#
# -----Validation-----
# AUC: 85.79 Precision: 82.98 Recall: 86.67
#
# Fold 5
#
# -----Train----------
# AUC: 98.15 Precision: 98.88 Recall: 97.25
#
# -----Validation-----
# AUC: 94.59 Precision: 97.62 Recall: 91.11
#
# wheezy-copper-turtle-magic 37
#
# Fold 1
#
# -----Train----------
# AUC: 99.05 Precision: 99.52 Recall: 98.58
#
# -----Validation-----
# AUC: 88.68 Precision: 88.89 Recall: 88.89
#
# Fold 2
#
# -----Train----------
# AUC: 98.31 Precision: 97.69 Recall: 99.06
#
# -----Validation-----
# AUC: 98.08 Precision: 98.11 Recall: 98.11
#
# Fold 3
#
# -----Train----------
# AUC: 98.80 Precision: 98.60 Recall: 99.06
#
# -----Validation-----
# AUC: 90.38 Precision: 90.57 Recall: 90.57
#
# Fold 4
#
# -----Train----------
# AUC: 97.38 Precision: 98.10 Recall: 96.71
#
# -----Validation-----
# AUC: 93.25 Precision: 92.59 Recall: 94.34
#
# Fold 5
#
# -----Train----------
# AUC: 97.62 Precision: 98.10 Recall: 97.18
#
# -----Validation-----
# AUC: 98.08 Precision: 98.11 Recall: 98.11
#
# wheezy-copper-turtle-magic 38
#
# Fold 1
#
# -----Train----------
# AUC: 98.29 Precision: 98.98 Recall: 97.49
#
# -----Validation-----
# AUC: 95.32 Precision: 94.12 Recall: 96.00
#
# Fold 2
#
# -----Train----------
# AUC: 99.75 Precision: 100.00 Recall: 99.50
#
# -----Validation-----
# AUC: 92.32 Precision: 93.75 Recall: 90.00
#
# Fold 3
#
# -----Train----------
# AUC: 98.77 Precision: 99.49 Recall: 97.99
#
# -----Validation-----
# AUC: 95.32 Precision: 94.12 Recall: 96.00
#
# Fold 4
#
# -----Train----------
# AUC: 98.80 Precision: 98.99 Recall: 98.49
#
# -----Validation-----
# AUC: 94.27 Precision: 94.00 Recall: 94.00
#
# Fold 5
#
# -----Train----------
# AUC: 98.30 Precision: 98.98 Recall: 97.50
#
# -----Validation-----
# AUC: 95.12 Precision: 95.83 Recall: 93.88
#
# wheezy-copper-turtle-magic 39
#
# Fold 1
#
# -----Train----------
# AUC: 98.76 Precision: 98.99 Recall: 98.49
#
# -----Validation-----
# AUC: 90.15 Precision: 91.67 Recall: 88.00
#
# Fold 2
#
# -----Train----------
# AUC: 97.29 Precision: 97.00 Recall: 97.49
#
# -----Validation-----
# AUC: 91.15 Precision: 91.84 Recall: 90.00
#
# Fold 3
#
# -----Train----------
# AUC: 97.78 Precision: 97.50 Recall: 97.99
#
# -----Validation-----
# AUC: 94.15 Precision: 92.31 Recall: 96.00
#
# Fold 4
#
# -----Train----------
# AUC: 97.78 Precision: 97.98 Recall: 97.49
#
# -----Validation-----
# AUC: 91.08 Precision: 91.84 Recall: 90.00
#
# Fold 5
#
# -----Train----------
# AUC: 98.03 Precision: 98.00 Recall: 98.00
#
# -----Validation-----
# AUC: 91.02 Precision: 90.00 Recall: 91.84
#
# wheezy-copper-turtle-magic 40
#
# Fold 1
#
# -----Train----------
# AUC: 97.22 Precision: 96.95 Recall: 97.45
#
# -----Validation-----
# AUC: 94.00 Precision: 92.31 Recall: 96.00
#
# Fold 2
#
# -----Train----------
# AUC: 97.22 Precision: 97.94 Recall: 96.45
#
# -----Validation-----
# AUC: 88.88 Precision: 89.58 Recall: 87.76
#
# Fold 3
#
# -----Train----------
# AUC: 97.23 Precision: 96.50 Recall: 97.97
#
# -----Validation-----
# AUC: 90.88 Precision: 93.48 Recall: 87.76
#
# Fold 4
#
# -----Train----------
# AUC: 97.22 Precision: 97.94 Recall: 96.45
#
# -----Validation-----
# AUC: 94.96 Precision: 94.00 Recall: 95.92
#
# Fold 5
#
# -----Train----------
# AUC: 96.98 Precision: 96.95 Recall: 96.95
#
# -----Validation-----
# AUC: 92.86 Precision: 95.65 Recall: 89.80
#
# wheezy-copper-turtle-magic 41
#
# Fold 1
#
# -----Train----------
# AUC: 97.45 Precision: 98.12 Recall: 96.76
#
# -----Validation-----
# AUC: 89.81 Precision: 90.57 Recall: 88.89
#
# Fold 2
#
# -----Train----------
# AUC: 97.91 Precision: 98.59 Recall: 97.22
#
# -----Validation-----
# AUC: 96.30 Precision: 94.64 Recall: 98.15
#
# Fold 3
#
# -----Train----------
# AUC: 97.68 Precision: 98.13 Recall: 97.22
#
# -----Validation-----
# AUC: 92.59 Precision: 89.66 Recall: 96.30
#
# Fold 4
#
# -----Train----------
# AUC: 98.14 Precision: 98.15 Recall: 98.15
#
# -----Validation-----
# AUC: 93.52 Precision: 96.08 Recall: 90.74
#
# Fold 5
#
# -----Train----------
# AUC: 96.53 Precision: 96.31 Recall: 96.76
#
# -----Validation-----
# AUC: 93.50 Precision: 97.96 Recall: 88.89
#
# wheezy-copper-turtle-magic 42
#
# Fold 1
#
# -----Train----------
# AUC: 98.40 Precision: 97.91 Recall: 98.94
#
# -----Validation-----
# AUC: 92.66 Precision: 95.56 Recall: 89.58
#
# Fold 2
#
# -----Train----------
# AUC: 98.14 Precision: 98.40 Recall: 97.88
#
# -----Validation-----
# AUC: 97.89 Precision: 97.92 Recall: 97.92
#
# Fold 3
#
# -----Train----------
# AUC: 98.94 Precision: 98.95 Recall: 98.95
#
# -----Validation-----
# AUC: 89.36 Precision: 87.76 Recall: 91.49
#
# Fold 4
#
# -----Train----------
# AUC: 98.41 Precision: 98.42 Recall: 98.42
#
# -----Validation-----
# AUC: 93.62 Precision: 91.84 Recall: 95.74
#
# Fold 5
#
# -----Train----------
# AUC: 98.14 Precision: 97.41 Recall: 98.95
#
# -----Validation-----
# AUC: 92.46 Precision: 91.67 Recall: 93.62
#
# wheezy-copper-turtle-magic 43
#
# Fold 1
#
# -----Train----------
# AUC: 95.88 Precision: 96.48 Recall: 95.05
#
# -----Validation-----
# AUC: 87.75 Precision: 83.93 Recall: 92.16
#
# Fold 2
#
# -----Train----------
# AUC: 95.91 Precision: 95.57 Recall: 96.04
#
# -----Validation-----
# AUC: 89.54 Precision: 88.46 Recall: 90.20
#
# Fold 3
#
# -----Train----------
# AUC: 95.45 Precision: 94.63 Recall: 96.04
#
# -----Validation-----
# AUC: 92.19 Precision: 97.78 Recall: 86.27
#
# Fold 4
#
# -----Train----------
# AUC: 95.91 Precision: 96.04 Recall: 95.57
#
# -----Validation-----
# AUC: 91.17 Precision: 93.62 Recall: 88.00
#
# Fold 5
#
# -----Train----------
# AUC: 94.73 Precision: 94.15 Recall: 95.07
#
# -----Validation-----
# AUC: 90.40 Precision: 87.04 Recall: 94.00
#
# wheezy-copper-turtle-magic 44
#
# Fold 1
#
# -----Train----------
# AUC: 97.99 Precision: 98.10 Recall: 98.10
#
# -----Validation-----
# AUC: 91.86 Precision: 89.47 Recall: 96.23
#
# Fold 2
#
# -----Train----------
# AUC: 98.73 Precision: 98.58 Recall: 99.05
#
# -----Validation-----
# AUC: 94.04 Precision: 94.34 Recall: 94.34
#
# Fold 3
#
# -----Train----------
# AUC: 97.97 Precision: 97.65 Recall: 98.58
#
# -----Validation-----
# AUC: 96.23 Precision: 100.00 Recall: 92.45
#
# Fold 4
#
# -----Train----------
# AUC: 98.00 Precision: 98.10 Recall: 98.10
#
# -----Validation-----
# AUC: 97.99 Precision: 98.11 Recall: 98.11
#
# Fold 5
#
# -----Train----------
# AUC: 98.97 Precision: 98.60 Recall: 99.53
#
# -----Validation-----
# AUC: 91.80 Precision: 90.74 Recall: 94.23
#
# wheezy-copper-turtle-magic 45
#
# Fold 1
#
# -----Train----------
# AUC: 96.64 Precision: 96.12 Recall: 97.06
#
# -----Validation-----
# AUC: 95.17 Precision: 96.00 Recall: 94.12
#
# Fold 2
#
# -----Train----------
# AUC: 97.13 Precision: 96.15 Recall: 98.04
#
# -----Validation-----
# AUC: 95.14 Precision: 97.92 Recall: 92.16
#
# Fold 3
#
# -----Train----------
# AUC: 96.40 Precision: 96.10 Recall: 96.57
#
# -----Validation-----
# AUC: 95.14 Precision: 97.92 Recall: 92.16
#
# Fold 4
#
# -----Train----------
# AUC: 97.59 Precision: 98.02 Recall: 97.06
#
# -----Validation-----
# AUC: 88.57 Precision: 84.21 Recall: 94.12
#
# Fold 5
#
# -----Train----------
# AUC: 97.60 Precision: 97.55 Recall: 97.55
#
# -----Validation-----
# AUC: 88.46 Precision: 88.24 Recall: 88.24
#
# wheezy-copper-turtle-magic 46
#
# Fold 1
#
# -----Train----------
# AUC: 96.99 Precision: 96.52 Recall: 97.49
#
# -----Validation-----
# AUC: 94.04 Precision: 95.83 Recall: 92.00
#
# Fold 2
#
# -----Train----------
# AUC: 98.00 Precision: 98.48 Recall: 97.49
#
# -----Validation-----
# AUC: 90.00 Precision: 87.04 Recall: 94.00
#
# Fold 3
#
# -----Train----------
# AUC: 96.50 Precision: 96.02 Recall: 96.98
#
# -----Validation-----
# AUC: 94.00 Precision: 95.83 Recall: 92.00
#
# Fold 4
#
# -----Train----------
# AUC: 97.50 Precision: 97.49 Recall: 97.49
#
# -----Validation-----
# AUC: 90.00 Precision: 90.00 Recall: 90.00
#
# Fold 5
#
# -----Train----------
# AUC: 96.51 Precision: 96.50 Recall: 96.50
#
# -----Validation-----
# AUC: 93.94 Precision: 93.88 Recall: 93.88
#
# wheezy-copper-turtle-magic 47
#
# Fold 1
#
# -----Train----------
# AUC: 98.57 Precision: 99.07 Recall: 98.15
#
# -----Validation-----
# AUC: 89.45 Precision: 89.29 Recall: 90.91
#
# Fold 2
#
# -----Train----------
# AUC: 97.88 Precision: 99.06 Recall: 96.77
#
# -----Validation-----
# AUC: 93.15 Precision: 91.23 Recall: 96.30
#
# Fold 3
#
# -----Train----------
# AUC: 97.63 Precision: 98.59 Recall: 96.77
#
# -----Validation-----
# AUC: 96.22 Precision: 98.08 Recall: 94.44
#
# Fold 4
#
# -----Train----------
# AUC: 98.14 Precision: 99.53 Recall: 96.77
#
# -----Validation-----
# AUC: 94.30 Precision: 96.15 Recall: 92.59
#
# Fold 5
#
# -----Train----------
# AUC: 97.41 Precision: 98.58 Recall: 96.31
#
# -----Validation-----
# AUC: 92.31 Precision: 94.23 Recall: 90.74
#
# wheezy-copper-turtle-magic 48
#
# Fold 1
#
# -----Train----------
# AUC: 97.15 Precision: 96.80 Recall: 97.70
#
# -----Validation-----
# AUC: 96.26 Precision: 96.36 Recall: 96.36
#
# Fold 2
#
# -----Train----------
# AUC: 95.96 Precision: 95.45 Recall: 96.77
#
# -----Validation-----
# AUC: 91.71 Precision: 96.00 Recall: 87.27
#
# Fold 3
#
# -----Train----------
# AUC: 97.15 Precision: 96.82 Recall: 97.71
#
# -----Validation-----
# AUC: 91.49 Precision: 90.91 Recall: 92.59
#
# Fold 4
#
# -----Train----------
# AUC: 98.33 Precision: 97.74 Recall: 99.08
#
# -----Validation-----
# AUC: 82.73 Precision: 81.03 Recall: 87.04
#
# Fold 5
#
# -----Train----------
# AUC: 96.92 Precision: 96.38 Recall: 97.71
#
# -----Validation-----
# AUC: 94.17 Precision: 91.38 Recall: 98.15
#
# wheezy-copper-turtle-magic 49
#
# Fold 1
#
# -----Train----------
# AUC: 98.04 Precision: 98.01 Recall: 98.01
#
# -----Validation-----
# AUC: 91.25 Precision: 92.00 Recall: 90.20
#
# Fold 2
#
# -----Train----------
# AUC: 98.52 Precision: 99.49 Recall: 97.51
#
# -----Validation-----
# AUC: 94.19 Precision: 92.45 Recall: 96.08
#
# Fold 3
#
# -----Train----------
# AUC: 98.05 Precision: 98.02 Recall: 98.02
#
# -----Validation-----
# AUC: 94.15 Precision: 92.31 Recall: 96.00
#
# Fold 4
#
# -----Train----------
# AUC: 98.53 Precision: 99.00 Recall: 98.02
#
# -----Validation-----
# AUC: 94.19 Precision: 90.74 Recall: 98.00
#
# Fold 5
#
# -----Train----------
# AUC: 97.80 Precision: 98.01 Recall: 97.52
#
# -----Validation-----
# AUC: 96.12 Precision: 94.23 Recall: 98.00
#
# wheezy-copper-turtle-magic 50
#
# Fold 1
#
# -----Train----------
# AUC: 97.30 Precision: 95.95 Recall: 98.61
#
# -----Validation-----
# AUC: 90.08 Precision: 90.74 Recall: 89.09
#
# Fold 2
#
# -----Train----------
# AUC: 97.74 Precision: 97.26 Recall: 98.16
#
# -----Validation-----
# AUC: 90.15 Precision: 84.13 Recall: 98.15
#
# Fold 3
#
# -----Train----------
# AUC: 97.96 Precision: 97.71 Recall: 98.16
#
# -----Validation-----
# AUC: 95.54 Precision: 91.53 Recall: 100.00
#
# Fold 4
#
# -----Train----------
# AUC: 96.85 Precision: 95.52 Recall: 98.16
#
# -----Validation-----
# AUC: 94.54 Precision: 94.44 Recall: 94.44
#
# Fold 5
#
# -----Train----------
# AUC: 97.52 Precision: 96.40 Recall: 98.62
#
# -----Validation-----
# AUC: 95.40 Precision: 98.04 Recall: 92.59
#
# wheezy-copper-turtle-magic 51
#
# Fold 1
#
# -----Train----------
# AUC: 98.24 Precision: 97.40 Recall: 99.12
#
# -----Validation-----
# AUC: 91.29 Precision: 92.73 Recall: 89.47
#
# Fold 2
#
# -----Train----------
# AUC: 97.81 Precision: 96.97 Recall: 98.68
#
# -----Validation-----
# AUC: 92.98 Precision: 90.16 Recall: 96.49
#
# Fold 3
#
# -----Train----------
# AUC: 97.59 Precision: 96.96 Recall: 98.24
#
# -----Validation-----
# AUC: 92.11 Precision: 91.38 Recall: 92.98
#
# Fold 4
#
# -----Train----------
# AUC: 96.72 Precision: 95.69 Recall: 97.80
#
# -----Validation-----
# AUC: 93.86 Precision: 94.64 Recall: 92.98
#
# Fold 5
#
# -----Train----------
# AUC: 97.81 Precision: 96.98 Recall: 98.68
#
# -----Validation-----
# AUC: 92.04 Precision: 91.23 Recall: 92.86
#
# wheezy-copper-turtle-magic 52
#
# Fold 1
#
# -----Train----------
# AUC: 96.81 Precision: 98.50 Recall: 95.17
#
# -----Validation-----
# AUC: 87.03 Precision: 85.45 Recall: 90.38
#
# Fold 2
#
# -----Train----------
# AUC: 97.29 Precision: 98.51 Recall: 96.14
#
# -----Validation-----
# AUC: 89.19 Precision: 91.84 Recall: 86.54
#
# Fold 3
#
# -----Train----------
# AUC: 97.79 Precision: 99.01 Recall: 96.62
#
# -----Validation-----
# AUC: 87.90 Precision: 87.04 Recall: 90.38
#
# Fold 4
#
# -----Train----------
# AUC: 97.28 Precision: 98.04 Recall: 96.62
#
# -----Validation-----
# AUC: 94.15 Precision: 97.92 Recall: 90.38
#
# Fold 5
#
# -----Train----------
# AUC: 97.54 Precision: 98.53 Recall: 96.63
#
# -----Validation-----
# AUC: 92.95 Precision: 94.00 Recall: 92.16
#
# wheezy-copper-turtle-magic 53
#
# Fold 1
#
# -----Train----------
# AUC: 97.72 Precision: 98.08 Recall: 97.61
#
# -----Validation-----
# AUC: 91.85 Precision: 90.91 Recall: 94.34
#
# Fold 2
#
# -----Train----------
# AUC: 97.96 Precision: 98.09 Recall: 98.09
#
# -----Validation-----
# AUC: 91.08 Precision: 94.00 Recall: 88.68
#
# Fold 3
#
# -----Train----------
# AUC: 97.43 Precision: 97.17 Recall: 98.10
#
# -----Validation-----
# AUC: 92.89 Precision: 94.12 Recall: 92.31
#
# Fold 4
#
# -----Train----------
# AUC: 97.46 Precision: 97.62 Recall: 97.62
#
# -----Validation-----
# AUC: 89.63 Precision: 88.89 Recall: 92.31
#
# Fold 5
#
# -----Train----------
# AUC: 97.70 Precision: 97.63 Recall: 98.10
#
# -----Validation-----
# AUC: 96.03 Precision: 98.00 Recall: 94.23
#
# wheezy-copper-turtle-magic 54
#
# Fold 1
#
# -----Train----------
# AUC: 97.76 Precision: 97.16 Recall: 98.56
#
# -----Validation-----
# AUC: 86.62 Precision: 93.33 Recall: 79.25
#
# Fold 2
#
# -----Train----------
# AUC: 97.30 Precision: 97.60 Recall: 97.13
#
# -----Validation-----
# AUC: 96.00 Precision: 92.86 Recall: 100.00
#
# Fold 3
#
# -----Train----------
# AUC: 96.82 Precision: 97.57 Recall: 96.17
#
# -----Validation-----
# AUC: 92.92 Precision: 89.47 Recall: 98.08
#
# Fold 4
#
# -----Train----------
# AUC: 97.06 Precision: 97.58 Recall: 96.65
#
# -----Validation-----
# AUC: 92.07 Precision: 92.31 Recall: 92.31
#
# Fold 5
#
# -----Train----------
# AUC: 97.55 Precision: 98.07 Recall: 97.13
#
# -----Validation-----
# AUC: 91.11 Precision: 92.16 Recall: 90.38
#
# wheezy-copper-turtle-magic 55
#
# Fold 1
#
# -----Train----------
# AUC: 99.27 Precision: 99.50 Recall: 99.01
#
# -----Validation-----
# AUC: 96.12 Precision: 97.96 Recall: 94.12
#
# Fold 2
#
# -----Train----------
# AUC: 99.26 Precision: 100.00 Recall: 98.52
#
# -----Validation-----
# AUC: 94.23 Precision: 94.12 Recall: 94.12
#
# Fold 3
#
# -----Train----------
# AUC: 99.03 Precision: 99.50 Recall: 98.52
#
# -----Validation-----
# AUC: 91.36 Precision: 90.38 Recall: 92.16
#
# Fold 4
#
# -----Train----------
# AUC: 99.26 Precision: 100.00 Recall: 98.52
#
# -----Validation-----
# AUC: 95.25 Precision: 92.59 Recall: 98.04
#
# Fold 5
#
# -----Train----------
# AUC: 99.26 Precision: 100.00 Recall: 98.53
#
# -----Validation-----
# AUC: 97.17 Precision: 94.34 Recall: 100.00
#
# wheezy-copper-turtle-magic 56
#
# Fold 1
#
# -----Train----------
# AUC: 98.06 Precision: 98.12 Recall: 98.12
#
# -----Validation-----
# AUC: 90.37 Precision: 90.74 Recall: 90.74
#
# Fold 2
#
# -----Train----------
# AUC: 97.56 Precision: 97.21 Recall: 98.12
#
# -----Validation-----
# AUC: 90.37 Precision: 90.74 Recall: 90.74
#
# Fold 3
#
# -----Train----------
# AUC: 98.05 Precision: 97.69 Recall: 98.60
#
# -----Validation-----
# AUC: 92.23 Precision: 92.45 Recall: 92.45
#
# Fold 4
#
# -----Train----------
# AUC: 98.08 Precision: 98.58 Recall: 97.66
#
# -----Validation-----
# AUC: 94.06 Precision: 91.23 Recall: 98.11
#
# Fold 5
#
# -----Train----------
# AUC: 98.55 Precision: 98.60 Recall: 98.60
#
# -----Validation-----
# AUC: 92.17 Precision: 90.91 Recall: 94.34
#
# wheezy-copper-turtle-magic 57
#
# Fold 1
#
# -----Train----------
# AUC: 98.52 Precision: 98.13 Recall: 99.06
#
# -----Validation-----
# AUC: 92.30 Precision: 92.59 Recall: 92.59
#
# Fold 2
#
# -----Train----------
# AUC: 98.31 Precision: 98.58 Recall: 98.12
#
# -----Validation-----
# AUC: 95.17 Precision: 96.15 Recall: 94.34
#
# Fold 3
#
# -----Train----------
# AUC: 98.06 Precision: 98.12 Recall: 98.12
#
# -----Validation-----
# AUC: 93.11 Precision: 91.07 Recall: 96.23
#
# Fold 4
#
# -----Train----------
# AUC: 99.30 Precision: 100.00 Recall: 98.59
#
# -----Validation-----
# AUC: 93.17 Precision: 92.59 Recall: 94.34
#
# Fold 5
#
# -----Train----------
# AUC: 98.03 Precision: 97.24 Recall: 99.06
#
# -----Validation-----
# AUC: 89.39 Precision: 93.75 Recall: 84.91
#
# wheezy-copper-turtle-magic 58
#
# Fold 1
#
# -----Train----------
# AUC: 97.99 Precision: 98.43 Recall: 97.41
#
# -----Validation-----
# AUC: 95.05 Precision: 95.83 Recall: 93.88
#
# Fold 2
#
# -----Train----------
# AUC: 98.51 Precision: 98.45 Recall: 98.45
#
# -----Validation-----
# AUC: 91.99 Precision: 95.56 Recall: 87.76
#
# Fold 3
#
# -----Train----------
# AUC: 97.76 Precision: 97.93 Recall: 97.42
#
# -----Validation-----
# AUC: 93.95 Precision: 95.65 Recall: 91.67
#
# Fold 4
#
# -----Train----------
# AUC: 98.50 Precision: 98.96 Recall: 97.94
#
# -----Validation-----
# AUC: 92.06 Precision: 91.67 Recall: 91.67
#
# Fold 5
#
# -----Train----------
# AUC: 99.01 Precision: 98.97 Recall: 98.97
#
# -----Validation-----
# AUC: 95.99 Precision: 95.83 Recall: 95.83
#
# wheezy-copper-turtle-magic 59
#
# Fold 1
#
# -----Train----------
# AUC: 97.47 Precision: 97.97 Recall: 96.98
#
# -----Validation-----
# AUC: 89.00 Precision: 89.80 Recall: 88.00
#
# Fold 2
#
# -----Train----------
# AUC: 97.48 Precision: 97.97 Recall: 96.98
#
# -----Validation-----
# AUC: 89.88 Precision: 88.46 Recall: 92.00
#
# Fold 3
#
# -----Train----------
# AUC: 98.23 Precision: 98.00 Recall: 98.49
#
# -----Validation-----
# AUC: 87.86 Precision: 86.54 Recall: 90.00
#
# Fold 4
#
# -----Train----------
# AUC: 96.97 Precision: 97.95 Recall: 95.98
#
# -----Validation-----
# AUC: 91.94 Precision: 93.75 Recall: 90.00
#
# Fold 5
#
# -----Train----------
# AUC: 97.99 Precision: 98.48 Recall: 97.50
#
# -----Validation-----
# AUC: 90.82 Precision: 91.67 Recall: 89.80
#
# wheezy-copper-turtle-magic 60
#
# Fold 1
#
# -----Train----------
# AUC: 98.55 Precision: 98.57 Recall: 98.57
#
# -----Validation-----
# AUC: 93.36 Precision: 96.00 Recall: 90.57
#
# Fold 2
#
# -----Train----------
# AUC: 98.79 Precision: 98.58 Recall: 99.05
#
# -----Validation-----
# AUC: 95.25 Precision: 96.15 Recall: 94.34
#
# Fold 3
#
# -----Train----------
# AUC: 99.04 Precision: 99.05 Recall: 99.05
#
# -----Validation-----
# AUC: 88.46 Precision: 88.68 Recall: 88.68
#
# Fold 4
#
# -----Train----------
# AUC: 98.56 Precision: 98.58 Recall: 98.58
#
# -----Validation-----
# AUC: 91.29 Precision: 93.88 Recall: 88.46
#
# Fold 5
#
# -----Train----------
# AUC: 98.80 Precision: 98.58 Recall: 99.05
#
# -----Validation-----
# AUC: 93.19 Precision: 92.45 Recall: 94.23
#
# wheezy-copper-turtle-magic 61
#
# Fold 1
#
# -----Train----------
# AUC: 96.98 Precision: 96.43 Recall: 97.74
#
# -----Validation-----
# AUC: 92.69 Precision: 91.38 Recall: 94.64
#
# Fold 2
#
# -----Train----------
# AUC: 96.30 Precision: 95.56 Recall: 97.29
#
# -----Validation-----
# AUC: 93.60 Precision: 94.55 Recall: 92.86
#
# Fold 3
#
# -----Train----------
# AUC: 97.01 Precision: 96.86 Recall: 97.30
#
# -----Validation-----
# AUC: 91.61 Precision: 89.66 Recall: 94.55
#
# Fold 4
#
# -----Train----------
# AUC: 97.23 Precision: 96.88 Recall: 97.75
#
# -----Validation-----
# AUC: 88.01 Precision: 90.38 Recall: 85.45
#
# Fold 5
#
# -----Train----------
# AUC: 97.45 Precision: 96.48 Recall: 98.65
#
# -----Validation-----
# AUC: 87.07 Precision: 88.68 Recall: 85.45
#
# wheezy-copper-turtle-magic 62
#
# Fold 1
#
# -----Train----------
# AUC: 97.42 Precision: 96.02 Recall: 98.47
#
# -----Validation-----
# AUC: 93.32 Precision: 93.88 Recall: 92.00
#
# Fold 2
#
# -----Train----------
# AUC: 97.88 Precision: 97.00 Recall: 98.48
#
# -----Validation-----
# AUC: 89.16 Precision: 93.18 Recall: 83.67
#
# Fold 3
#
# -----Train----------
# AUC: 97.41 Precision: 96.50 Recall: 97.97
#
# -----Validation-----
# AUC: 91.26 Precision: 91.67 Recall: 89.80
#
# Fold 4
#
# -----Train----------
# AUC: 98.59 Precision: 97.99 Recall: 98.98
#
# -----Validation-----
# AUC: 92.39 Precision: 90.20 Recall: 93.88
#
# Fold 5
#
# -----Train----------
# AUC: 97.18 Precision: 96.02 Recall: 97.97
#
# -----Validation-----
# AUC: 94.10 Precision: 95.74 Recall: 91.84
#
# wheezy-copper-turtle-magic 63
#
# Fold 1
#
# -----Train----------
# AUC: 98.56 Precision: 98.64 Recall: 98.64
#
# -----Validation-----
# AUC: 91.43 Precision: 91.23 Recall: 92.86
#
# Fold 2
#
# -----Train----------
# AUC: 98.59 Precision: 99.09 Recall: 98.19
#
# -----Validation-----
# AUC: 92.27 Precision: 91.23 Recall: 94.55
#
# Fold 3
#
# -----Train----------
# AUC: 98.11 Precision: 98.63 Recall: 97.74
#
# -----Validation-----
# AUC: 94.36 Precision: 96.23 Recall: 92.73
#
# Fold 4
#
# -----Train----------
# AUC: 97.86 Precision: 98.18 Recall: 97.74
#
# -----Validation-----
# AUC: 92.06 Precision: 89.83 Recall: 96.36
#
# Fold 5
#
# -----Train----------
# AUC: 98.59 Precision: 99.09 Recall: 98.19
#
# -----Validation-----
# AUC: 90.58 Precision: 94.12 Recall: 87.27
#
# wheezy-copper-turtle-magic 64
#
# Fold 1
#
# -----Train----------
# AUC: 98.38 Precision: 97.67 Recall: 99.06
#
# -----Validation-----
# AUC: 95.42 Precision: 94.55 Recall: 96.30
#
# Fold 2
#
# -----Train----------
# AUC: 98.62 Precision: 97.70 Recall: 99.53
#
# -----Validation-----
# AUC: 91.65 Precision: 92.31 Recall: 90.57
#
# Fold 3
#
# -----Train----------
# AUC: 99.77 Precision: 100.00 Recall: 99.53
#
# -----Validation-----
# AUC: 91.65 Precision: 92.31 Recall: 90.57
#
# Fold 4
#
# -----Train----------
# AUC: 99.31 Precision: 99.07 Recall: 99.53
#
# -----Validation-----
# AUC: 94.37 Precision: 96.08 Recall: 92.45
#
# Fold 5
#
# -----Train----------
# AUC: 99.08 Precision: 98.60 Recall: 99.53
#
# -----Validation-----
# AUC: 94.37 Precision: 96.08 Recall: 92.45
#
# wheezy-copper-turtle-magic 65
#
# Fold 1
#
# -----Train----------
# AUC: 97.93 Precision: 96.53 Recall: 98.98
#
# -----Validation-----
# AUC: 91.11 Precision: 97.67 Recall: 84.00
#
# Fold 2
#
# -----Train----------
# AUC: 99.05 Precision: 98.98 Recall: 98.98
#
# -----Validation-----
# AUC: 91.64 Precision: 88.68 Recall: 94.00
#
# Fold 3
#
# -----Train----------
# AUC: 98.38 Precision: 97.51 Recall: 98.99
#
# -----Validation-----
# AUC: 90.05 Precision: 95.35 Recall: 83.67
#
# Fold 4
#
# -----Train----------
# AUC: 98.60 Precision: 98.00 Recall: 98.99
#
# -----Validation-----
# AUC: 89.54 Precision: 88.00 Recall: 89.80
#
# Fold 5
#
# -----Train----------
# AUC: 98.41 Precision: 97.04 Recall: 99.49
#
# -----Validation-----
# AUC: 90.43 Precision: 89.80 Recall: 89.80
#
# wheezy-copper-turtle-magic 66
#
# Fold 1
#
# -----Train----------
# AUC: 97.99 Precision: 98.45 Recall: 97.45
#
# -----Validation-----
# AUC: 94.00 Precision: 95.74 Recall: 91.84
#
# Fold 2
#
# -----Train----------
# AUC: 98.49 Precision: 98.97 Recall: 97.96
#
# -----Validation-----
# AUC: 91.95 Precision: 95.56 Recall: 87.76
#
# Fold 3
#
# -----Train----------
# AUC: 98.99 Precision: 99.48 Recall: 98.47
#
# -----Validation-----
# ...
# AUC: 96.67 Precision: 97.45 Recall: 96.22
#
# -----Validation-----
# AUC: 91.84 Precision: 93.10 Recall: 91.53
#
# wheezy-copper-turtle-magic 490
#
# Fold 1
#
# -----Train----------
# AUC: 97.48 Precision: 95.31 Recall: 99.46
#
# -----Validation-----
# AUC: 95.83 Precision: 97.78 Recall: 93.62
#
# Fold 2
#
# -----Train----------
# AUC: 97.43 Precision: 96.79 Recall: 97.84
#
# -----Validation-----
# AUC: 88.65 Precision: 85.71 Recall: 91.30
#
# Fold 3
#
# -----Train----------
# AUC: 96.95 Precision: 95.29 Recall: 98.38
#
# -----Validation-----
# AUC: 90.74 Precision: 87.76 Recall: 93.48
#
# Fold 4
#
# -----Train----------
# AUC: 97.47 Precision: 95.81 Recall: 98.92
#
# -----Validation-----
# AUC: 90.22 Precision: 100.00 Recall: 80.43
#
# Fold 5
#
# -----Train----------
# AUC: 97.16 Precision: 96.77 Recall: 97.30
#
# -----Validation-----
# AUC: 88.48 Precision: 88.89 Recall: 86.96
#
# wheezy-copper-turtle-magic 491
#
# Fold 1
#
# -----Train----------
# AUC: 97.98 Precision: 97.54 Recall: 98.51
#
# -----Validation-----
# AUC: 92.00 Precision: 92.16 Recall: 92.16
#
# Fold 2
#
# -----Train----------
# AUC: 97.72 Precision: 97.06 Recall: 98.51
#
# -----Validation-----
# AUC: 92.12 Precision: 97.78 Recall: 86.27
#
# Fold 3
#
# -----Train----------
# AUC: 96.99 Precision: 97.50 Recall: 96.53
#
# -----Validation-----
# AUC: 91.92 Precision: 92.00 Recall: 92.00
#
# Fold 4
#
# -----Train----------
# AUC: 97.75 Precision: 98.49 Recall: 97.03
#
# -----Validation-----
# AUC: 92.86 Precision: 87.72 Recall: 100.00
#
# Fold 5
#
# -----Train----------
# AUC: 97.49 Precision: 97.52 Recall: 97.52
#
# -----Validation-----
# AUC: 95.96 Precision: 96.00 Recall: 96.00
#
# wheezy-copper-turtle-magic 492
#
# Fold 1
#
# -----Train----------
# AUC: 98.36 Precision: 98.07 Recall: 98.54
#
# -----Validation-----
# AUC: 88.78 Precision: 88.46 Recall: 88.46
#
# Fold 2
#
# -----Train----------
# AUC: 97.62 Precision: 98.51 Recall: 96.60
#
# -----Validation-----
# AUC: 94.34 Precision: 96.00 Recall: 92.31
#
# Fold 3
#
# -----Train----------
# AUC: 96.90 Precision: 98.01 Recall: 95.63
#
# -----Validation-----
# AUC: 91.45 Precision: 95.74 Recall: 86.54
#
# Fold 4
#
# -----Train----------
# AUC: 98.11 Precision: 98.54 Recall: 97.58
#
# -----Validation-----
# AUC: 88.59 Precision: 89.80 Recall: 86.27
#
# Fold 5
#
# -----Train----------
# AUC: 96.92 Precision: 98.02 Recall: 95.65
#
# -----Validation-----
# AUC: 94.17 Precision: 97.87 Recall: 90.20
#
# wheezy-copper-turtle-magic 493
#
# Fold 1
#
# -----Train----------
# AUC: 98.05 Precision: 98.12 Recall: 98.12
#
# -----Validation-----
# AUC: 96.00 Precision: 93.10 Recall: 100.00
#
# Fold 2
#
# -----Train----------
# AUC: 99.02 Precision: 99.06 Recall: 99.06
#
# -----Validation-----
# AUC: 94.07 Precision: 91.38 Recall: 98.15
#
# Fold 3
#
# -----Train----------
# AUC: 98.54 Precision: 98.60 Recall: 98.60
#
# -----Validation-----
# AUC: 92.07 Precision: 90.91 Recall: 94.34
#
# Fold 4
#
# -----Train----------
# AUC: 98.02 Precision: 97.25 Recall: 99.07
#
# -----Validation-----
# AUC: 93.24 Precision: 96.00 Recall: 90.57
#
# Fold 5
#
# -----Train----------
# AUC: 98.29 Precision: 98.14 Recall: 98.60
#
# -----Validation-----
# AUC: 96.15 Precision: 98.04 Recall: 94.34
#
# wheezy-copper-turtle-magic 494
#
# Fold 1
#
# -----Train----------
# AUC: 98.35 Precision: 98.58 Recall: 98.11
#
# -----Validation-----
# AUC: 92.49 Precision: 95.92 Recall: 88.68
#
# Fold 2
#
# -----Train----------
# AUC: 99.53 Precision: 99.53 Recall: 99.53
#
# -----Validation-----
# AUC: 89.71 Precision: 90.38 Recall: 88.68
#
# Fold 3
#
# -----Train----------
# AUC: 98.35 Precision: 99.04 Recall: 97.64
#
# -----Validation-----
# AUC: 97.17 Precision: 96.30 Recall: 98.11
#
# Fold 4
#
# -----Train----------
# AUC: 98.59 Precision: 99.05 Recall: 98.11
#
# -----Validation-----
# AUC: 93.40 Precision: 89.66 Recall: 98.11
#
# Fold 5
#
# -----Train----------
# AUC: 98.83 Precision: 99.05 Recall: 98.58
#
# -----Validation-----
# AUC: 92.45 Precision: 95.92 Recall: 88.68
#
# wheezy-copper-turtle-magic 495
#
# Fold 1
#
# -----Train----------
# AUC: 96.69 Precision: 95.67 Recall: 97.55
#
# -----Validation-----
# AUC: 93.41 Precision: 90.74 Recall: 96.08
#
# Fold 2
#
# -----Train----------
# AUC: 95.23 Precision: 95.10 Recall: 95.10
#
# -----Validation-----
# AUC: 96.19 Precision: 96.08 Recall: 96.08
#
# Fold 3
#
# -----Train----------
# AUC: 97.36 Precision: 98.01 Recall: 96.57
#
# -----Validation-----
# AUC: 84.64 Precision: 87.23 Recall: 80.39
#
# Fold 4
#
# -----Train----------
# AUC: 96.20 Precision: 95.63 Recall: 96.57
#
# -----Validation-----
# AUC: 86.55 Precision: 89.36 Recall: 82.35
#
# Fold 5
#
# -----Train----------
# AUC: 95.98 Precision: 94.74 Recall: 97.06
#
# -----Validation-----
# AUC: 88.40 Precision: 93.33 Recall: 82.35
#
# wheezy-copper-turtle-magic 496
#
# Fold 1
#
# -----Train----------
# AUC: 98.51 Precision: 98.99 Recall: 98.00
#
# -----Validation-----
# AUC: 90.27 Precision: 91.84 Recall: 88.24
#
# Fold 2
#
# -----Train----------
# AUC: 98.27 Precision: 98.50 Recall: 98.01
#
# -----Validation-----
# AUC: 95.12 Precision: 94.12 Recall: 96.00
#
# Fold 3
#
# -----Train----------
# AUC: 98.76 Precision: 99.49 Recall: 98.01
#
# -----Validation-----
# AUC: 92.08 Precision: 92.00 Recall: 92.00
#
# Fold 4
#
# -----Train----------
# AUC: 98.77 Precision: 98.51 Recall: 99.00
#
# -----Validation-----
# AUC: 89.02 Precision: 97.56 Recall: 80.00
#
# Fold 5
#
# -----Train----------
# AUC: 98.53 Precision: 98.51 Recall: 98.51
#
# -----Validation-----
# AUC: 91.06 Precision: 93.62 Recall: 88.00
#
# wheezy-copper-turtle-magic 497
#
# Fold 1
#
# -----Train----------
# AUC: 97.62 Precision: 97.18 Recall: 98.10
#
# -----Validation-----
# AUC: 88.68 Precision: 90.20 Recall: 86.79
#
# Fold 2
#
# -----Train----------
# AUC: 98.34 Precision: 99.04 Recall: 97.63
#
# -----Validation-----
# AUC: 83.02 Precision: 87.23 Recall: 77.36
#
# Fold 3
#
# -----Train----------
# AUC: 96.44 Precision: 96.23 Recall: 96.68
#
# -----Validation-----
# AUC: 95.23 Precision: 94.44 Recall: 96.23
#
# Fold 4
#
# -----Train----------
# AUC: 96.91 Precision: 97.60 Recall: 96.21
#
# -----Validation-----
# AUC: 87.52 Precision: 81.25 Recall: 98.11
#
# Fold 5
#
# -----Train----------
# AUC: 96.91 Precision: 95.85 Recall: 98.11
#
# -----Validation-----
# AUC: 83.65 Precision: 85.71 Recall: 80.77
#
# wheezy-copper-turtle-magic 498
#
# Fold 1
#
# -----Train----------
# AUC: 97.36 Precision: 96.21 Recall: 98.54
#
# -----Validation-----
# AUC: 94.29 Precision: 94.23 Recall: 94.23
#
# Fold 2
#
# -----Train----------
# AUC: 97.12 Precision: 96.19 Recall: 98.06
#
# -----Validation-----
# AUC: 91.40 Precision: 93.88 Recall: 88.46
#
# Fold 3
#
# -----Train----------
# AUC: 96.88 Precision: 96.17 Recall: 97.57
#
# -----Validation-----
# AUC: 95.19 Precision: 96.08 Recall: 94.23
#
# Fold 4
#
# -----Train----------
# AUC: 97.13 Precision: 96.65 Recall: 97.58
#
# -----Validation-----
# AUC: 96.15 Precision: 92.73 Recall: 100.00
#
# Fold 5
#
# -----Train----------
# AUC: 97.12 Precision: 97.10 Recall: 97.10
#
# -----Validation-----
# AUC: 92.27 Precision: 89.09 Recall: 96.08
#
# wheezy-copper-turtle-magic 499
#
# Fold 1
#
# -----Train----------
# AUC: 96.48 Precision: 97.40 Recall: 95.41
#
# -----Validation-----
# AUC: 90.90 Precision: 95.45 Recall: 85.71
#
# Fold 2
#
# -----Train----------
# AUC: 97.21 Precision: 98.94 Recall: 95.41
#
# -----Validation-----
# AUC: 90.00 Precision: 89.80 Recall: 89.80
#
# Fold 3
#
# -----Train----------
# AUC: 97.24 Precision: 97.44 Recall: 96.94
#
# -----Validation-----
# AUC: 87.88 Precision: 93.02 Recall: 81.63
#
# Fold 4
#
# -----Train----------
# AUC: 97.22 Precision: 98.43 Recall: 95.92
#
# -----Validation-----
# AUC: 94.94 Precision: 97.83 Recall: 91.84
#
# Fold 5
#
# -----Train----------
# AUC: 97.23 Precision: 97.93 Recall: 96.43
#
# -----Validation-----
# AUC: 90.04 Precision: 88.24 Recall: 91.84
#
# wheezy-copper-turtle-magic 500
#
# Fold 1
#
# -----Train----------
# AUC: 97.50 Precision: 98.00 Recall: 97.03
#
# -----Validation-----
# AUC: 92.06 Precision: 90.57 Recall: 94.12
#
# Fold 2
#
# -----Train----------
# AUC: 96.50 Precision: 96.53 Recall: 96.53
#
# -----Validation-----
# AUC: 93.04 Precision: 90.74 Recall: 96.08
#
# Fold 3
#
# -----Train----------
# AUC: 97.25 Precision: 97.04 Recall: 97.52
#
# -----Validation-----
# AUC: 94.04 Precision: 92.45 Recall: 96.08
#
# Fold 4
#
# -----Train----------
# AUC: 97.76 Precision: 97.55 Recall: 98.03
#
# -----Validation-----
# AUC: 85.82 Precision: 83.33 Recall: 90.00
#
# Fold 5
#
# -----Train----------
# AUC: 98.00 Precision: 97.56 Recall: 98.52
#
# -----Validation-----
# AUC: 87.90 Precision: 89.58 Recall: 86.00
#
# wheezy-copper-turtle-magic 501
#
# Fold 1
#
# -----Train----------
# AUC: 97.16 Precision: 98.05 Recall: 96.63
#
# -----Validation-----
# AUC: 88.02 Precision: 85.96 Recall: 94.23
#
# Fold 2
#
# -----Train----------
# AUC: 96.82 Precision: 97.12 Recall: 97.12
#
# -----Validation-----
# AUC: 91.96 Precision: 95.83 Recall: 88.46
#
# Fold 3
#
# -----Train----------
# AUC: 96.59 Precision: 97.10 Recall: 96.63
#
# -----Validation-----
# AUC: 94.99 Precision: 97.96 Recall: 92.31
#
# Fold 4
#
# -----Train----------
# AUC: 96.35 Precision: 97.09 Recall: 96.15
#
# -----Validation-----
# AUC: 90.14 Precision: 89.09 Recall: 94.23
#
# Fold 5
#
# -----Train----------
# AUC: 96.11 Precision: 97.07 Recall: 95.67
#
# -----Validation-----
# AUC: 91.30 Precision: 90.74 Recall: 94.23
#
# wheezy-copper-turtle-magic 502
#
# Fold 1
#
# -----Train----------
# AUC: 96.89 Precision: 96.62 Recall: 97.09
#
# -----Validation-----
# AUC: 93.41 Precision: 92.45 Recall: 94.23
#
# Fold 2
#
# -----Train----------
# AUC: 97.84 Precision: 98.52 Recall: 97.09
#
# -----Validation-----
# AUC: 89.53 Precision: 88.68 Recall: 90.38
#
# Fold 3
#
# -----Train----------
# AUC: 96.66 Precision: 96.60 Recall: 96.60
#
# -----Validation-----
# AUC: 91.38 Precision: 95.74 Recall: 86.54
#
# Fold 4
#
# -----Train----------
# AUC: 96.17 Precision: 97.51 Recall: 94.69
#
# -----Validation-----
# AUC: 91.36 Precision: 90.38 Recall: 92.16
#
# Fold 5
#
# -----Train----------
# AUC: 97.38 Precision: 97.57 Recall: 97.10
#
# -----Validation-----
# AUC: 90.27 Precision: 95.56 Recall: 84.31
#
# wheezy-copper-turtle-magic 503
#
# Fold 1
#
# -----Train----------
# AUC: 97.67 Precision: 97.35 Recall: 97.87
#
# -----Validation-----
# AUC: 91.75 Precision: 95.45 Recall: 87.50
#
# Fold 2
#
# -----Train----------
# AUC: 97.93 Precision: 97.88 Recall: 97.88
#
# -----Validation-----
# AUC: 91.74 Precision: 91.49 Recall: 91.49
#
# Fold 3
#
# -----Train----------
# AUC: 98.18 Precision: 98.40 Recall: 97.88
#
# -----Validation-----
# AUC: 91.68 Precision: 93.33 Recall: 89.36
#
# Fold 4
#
# -----Train----------
# AUC: 97.16 Precision: 97.34 Recall: 96.83
#
# -----Validation-----
# AUC: 95.83 Precision: 95.74 Recall: 95.74
#
# Fold 5
#
# -----Train----------
# AUC: 97.92 Precision: 98.40 Recall: 97.35
#
# -----Validation-----
# AUC: 93.75 Precision: 93.62 Recall: 93.62
#
# wheezy-copper-turtle-magic 504
#
# Fold 1
#
# -----Train----------
# AUC: 97.01 Precision: 96.67 Recall: 97.60
#
# -----Validation-----
# AUC: 92.97 Precision: 90.91 Recall: 96.15
#
# Fold 2
#
# -----Train----------
# AUC: 97.04 Precision: 97.57 Recall: 96.63
#
# -----Validation-----
# AUC: 88.05 Precision: 87.04 Recall: 90.38
#
# Fold 3
#
# -----Train----------
# AUC: 96.53 Precision: 96.63 Recall: 96.63
#
# -----Validation-----
# AUC: 94.05 Precision: 94.23 Recall: 94.23
#
# Fold 4
#
# -----Train----------
# AUC: 98.00 Precision: 97.62 Recall: 98.56
#
# -----Validation-----
# AUC: 88.11 Precision: 88.46 Recall: 88.46
#
# Fold 5
#
# -----Train----------
# AUC: 96.53 Precision: 96.63 Recall: 96.63
#
# -----Validation-----
# AUC: 93.21 Precision: 97.87 Recall: 88.46
#
# wheezy-copper-turtle-magic 505
#
# Fold 1
#
# -----Train----------
# AUC: 97.10 Precision: 95.69 Recall: 98.52
#
# -----Validation-----
# AUC: 94.23 Precision: 94.12 Recall: 94.12
#
# Fold 2
#
# -----Train----------
# AUC: 97.83 Precision: 97.09 Recall: 98.52
#
# -----Validation-----
# AUC: 90.35 Precision: 85.96 Recall: 96.08
#
# Fold 3
#
# -----Train----------
# AUC: 98.06 Precision: 97.56 Recall: 98.52
#
# -----Validation-----
# AUC: 93.17 Precision: 95.83 Recall: 90.20
#
# Fold 4
#
# -----Train----------
# AUC: 98.07 Precision: 97.10 Recall: 99.01
#
# -----Validation-----
# AUC: 87.42 Precision: 83.93 Recall: 92.16
#
# Fold 5
#
# -----Train----------
# AUC: 97.11 Precision: 95.71 Recall: 98.53
#
# -----Validation-----
# AUC: 91.19 Precision: 90.20 Recall: 92.00
#
# wheezy-copper-turtle-magic 506
#
# Fold 1
#
# -----Train----------
# AUC: 97.41 Precision: 97.63 Recall: 97.17
#
# -----Validation-----
# AUC: 93.52 Precision: 94.34 Recall: 92.59
#
# Fold 2
#
# -----Train----------
# AUC: 97.89 Precision: 98.11 Recall: 97.65
#
# -----Validation-----
# AUC: 86.95 Precision: 84.21 Recall: 90.57
#
# Fold 3
#
# -----Train----------
# AUC: 98.13 Precision: 98.58 Recall: 97.65
#
# -----Validation-----
# AUC: 92.45 Precision: 89.47 Recall: 96.23
#
# Fold 4
#
# -----Train----------
# AUC: 97.66 Precision: 97.21 Recall: 98.12
#
# -----Validation-----
# AUC: 96.23 Precision: 98.04 Recall: 94.34
#
# Fold 5
#
# -----Train----------
# AUC: 97.89 Precision: 98.11 Recall: 97.65
#
# -----Validation-----
# AUC: 91.51 Precision: 92.31 Recall: 90.57
#
# wheezy-copper-turtle-magic 507
#
# Fold 1
#
# -----Train----------
# AUC: 98.76 Precision: 99.49 Recall: 97.98
#
# -----Validation-----
# AUC: 91.45 Precision: 90.20 Recall: 92.00
#
# Fold 2
#
# -----Train----------
# AUC: 98.80 Precision: 98.49 Recall: 98.99
#
# -----Validation-----
# AUC: 90.44 Precision: 88.46 Recall: 92.00
#
# Fold 3
#
# -----Train----------
# AUC: 98.80 Precision: 98.49 Recall: 98.99
#
# -----Validation-----
# AUC: 92.22 Precision: 93.75 Recall: 90.00
#
# Fold 4
#
# -----Train----------
# AUC: 98.26 Precision: 99.48 Recall: 96.98
#
# -----Validation-----
# AUC: 94.26 Precision: 92.16 Recall: 95.92
#
# Fold 5
#
# -----Train----------
# AUC: 97.84 Precision: 97.50 Recall: 97.99
#
# -----Validation-----
# AUC: 95.18 Precision: 94.00 Recall: 95.92
#
# wheezy-copper-turtle-magic 508
#
# Fold 1
#
# -----Train----------
# AUC: 96.15 Precision: 95.28 Recall: 97.12
#
# -----Validation-----
# AUC: 90.57 Precision: 92.16 Recall: 88.68
#
# Fold 2
#
# -----Train----------
# AUC: 95.69 Precision: 95.26 Recall: 96.17
#
# -----Validation-----
# AUC: 92.31 Precision: 90.74 Recall: 94.23
#
# Fold 3
#
# -----Train----------
# AUC: 96.17 Precision: 95.31 Recall: 97.13
#
# -----Validation-----
# AUC: 92.31 Precision: 94.00 Recall: 90.38
#
# Fold 4
#
# -----Train----------
# AUC: 95.93 Precision: 95.28 Recall: 96.65
#
# -----Validation-----
# AUC: 92.31 Precision: 90.74 Recall: 94.23
#
# Fold 5
#
# -----Train----------
# AUC: 96.65 Precision: 97.10 Recall: 96.17
#
# -----Validation-----
# AUC: 83.65 Precision: 80.70 Recall: 88.46
#
# wheezy-copper-turtle-magic 509
#
# Fold 1
#
# -----Train----------
# AUC: 97.99 Precision: 98.45 Recall: 97.45
#
# -----Validation-----
# AUC: 93.08 Precision: 92.16 Recall: 94.00
#
# Fold 2
#
# -----Train----------
# AUC: 97.02 Precision: 96.48 Recall: 97.46
#
# -----Validation-----
# AUC: 94.98 Precision: 95.83 Recall: 93.88
#
# Fold 3
#
# -----Train----------
# AUC: 98.00 Precision: 97.97 Recall: 97.97
#
# -----Validation-----
# AUC: 90.98 Precision: 91.67 Recall: 89.80
#
# Fold 4
#
# -----Train----------
# AUC: 98.01 Precision: 97.49 Recall: 98.48
#
# -----Validation-----
# AUC: 89.88 Precision: 95.35 Recall: 83.67
#
# Fold 5
#
# -----Train----------
# AUC: 97.51 Precision: 97.46 Recall: 97.46
#
# -----Validation-----
# AUC: 91.02 Precision: 90.00 Recall: 91.84
#
# wheezy-copper-turtle-magic 510
#
# Fold 1
#
# -----Train----------
# AUC: 97.07 Precision: 97.49 Recall: 96.52
#
# -----Validation-----
# AUC: 94.23 Precision: 94.12 Recall: 94.12
#
# Fold 2
#
# -----Train----------
# AUC: 96.84 Precision: 96.53 Recall: 97.01
#
# -----Validation-----
# AUC: 89.40 Precision: 90.00 Recall: 88.24
#
# Fold 3
#
# -----Train----------
# AUC: 97.55 Precision: 98.48 Recall: 96.53
#
# -----Validation-----
# AUC: 87.40 Precision: 86.27 Recall: 88.00
#
# Fold 4
#
# -----Train----------
# AUC: 97.81 Precision: 98.01 Recall: 97.52
#
# -----Validation-----
# AUC: 86.31 Precision: 84.62 Recall: 88.00
#
# Fold 5
#
# -----Train----------
# AUC: 97.80 Precision: 98.49 Recall: 97.03
#
# -----Validation-----
# AUC: 87.15 Precision: 91.11 Recall: 82.00
#
# wheezy-copper-turtle-magic 511
#
# Fold 1
#
# -----Train----------
# AUC: 96.52 Precision: 97.06 Recall: 96.12
#
# -----Validation-----
# AUC: 90.99 Precision: 89.09 Recall: 94.23
#
# Fold 2
#
# -----Train----------
# AUC: 97.02 Precision: 97.55 Recall: 96.60
#
# -----Validation-----
# AUC: 92.07 Precision: 92.31 Recall: 92.31
#
# Fold 3
#
# -----Train----------
# AUC: 97.01 Precision: 97.09 Recall: 97.09
#
# -----Validation-----
# AUC: 92.01 Precision: 90.74 Recall: 94.23
#
# Fold 4
#
# -----Train----------
# AUC: 96.51 Precision: 96.62 Recall: 96.62
#
# -----Validation-----
# AUC: 91.10 Precision: 95.65 Recall: 86.27
#
# Fold 5
#
# -----Train----------
# AUC: 97.52 Precision: 97.58 Recall: 97.58
#
# -----Validation-----
# AUC: 84.99 Precision: 89.13 Recall: 80.39

# %% [markdown]
# ## KNN

# %%
# INITIALIZE VARIABLES
test['target_knn'] = 0
train['preds_knn'] = 0

# BUILD 512 MODELS
for i in range(512):
    print('wheezy-copper-turtle-magic {}\n'.format(i))
    
    # EXTRACT SUBSET OF DATASET WHERE WHEEZY-MAGIC EQUALS I
    train2 = train[train['wheezy-copper-turtle-magic']==i]
    test2 = test[test['wheezy-copper-turtle-magic']==i]
    idx1 = train2.index
    idx2 = test2.index
    train2.reset_index(drop=True, inplace=True)
    
    # FEATURE SELECTION (USE APPROX 40 OF 255 FEATURES)
    sel = VarianceThreshold(threshold=1.5).fit(train2[cols])
    train3 = sel.transform(train2[cols])
    test3 = sel.transform(test2[cols])

    skf = StratifiedKFold(n_splits=N_FOLDS, random_state=0)
    counter = 0

    for train_index, val_index in skf.split(train3, train2['target']):
        counter += 1
        print('Fold {}\n'.format(counter))
        model = KNeighborsClassifier()
        model.fit(train3[train_index,:], train2.loc[train_index]['target'])
        
        train_predictions = model.predict(train3[train_index,:])
        val_predictions = model.predict(train3[val_index,:])

        train_auc = roc_auc_score(train2.loc[train_index]['target'], train_predictions) * 100
        val_auc = roc_auc_score(train2.loc[val_index]['target'], val_predictions) * 100
        train_precision = precision_score(train2.loc[train_index]['target'], train_predictions) * 100
        val_precision = precision_score(train2.loc[val_index]['target'], val_predictions) * 100
        train_recall = recall_score(train2.loc[train_index]['target'], train_predictions) * 100
        val_recall = recall_score(train2.loc[val_index]['target'], val_predictions) * 100
        print('-----Train----------')
        print('AUC: %.2f Precision: %.2f Recall: %.2f \n' % (train_auc, train_precision, train_recall))
        print('-----Validation-----')
        print('AUC: %.2f Precision: %.2f Recall: %.2f \n' % (val_auc, val_precision, val_recall))

        # Make predictions
        train['preds_knn'].loc[idx1] += model.predict_proba(train3)[:,1] / N_FOLDS
        test['target_knn'].loc[idx2] += model.predict_proba(test3)[:,1] / N_FOLDS
# Out:
# wheezy-copper-turtle-magic 0
#
# Fold 1
#
# -----Train----------
# AUC: 90.36 Precision: 90.82 Recall: 89.52
#
# -----Validation-----
# AUC: 86.09 Precision: 86.54 Recall: 84.91
#
# Fold 2
#
# -----Train----------
# AUC: 89.87 Precision: 92.82 Recall: 86.19
#
# -----Validation-----
# AUC: 80.33 Precision: 83.33 Recall: 75.47
#
# Fold 3
#
# -----Train----------
# AUC: 90.13 Precision: 91.58 Recall: 88.10
#
# -----Validation-----
# AUC: 89.69 Precision: 92.00 Recall: 86.79
#
# Fold 4
#
# -----Train----------
# AUC: 92.02 Precision: 94.47 Recall: 89.10
#
# -----Validation-----
# AUC: 82.05 Precision: 82.35 Recall: 80.77
#
# Fold 5
#
# -----Train----------
# AUC: 90.38 Precision: 92.93 Recall: 87.20
#
# -----Validation-----
# AUC: 80.13 Precision: 81.63 Recall: 76.92
#
# wheezy-copper-turtle-magic 1
#
# Fold 1
#
# -----Train----------
# AUC: 92.49 Precision: 89.47 Recall: 95.41
#
# -----Validation-----
# AUC: 90.51 Precision: 84.48 Recall: 98.00
#
# Fold 2
#
# -----Train----------
# AUC: 94.91 Precision: 93.14 Recall: 96.45
#
# -----Validation-----
# AUC: 82.40 Precision: 80.39 Recall: 83.67
#
# Fold 3
#
# -----Train----------
# AUC: 92.08 Precision: 87.61 Recall: 96.95
#
# -----Validation-----
# AUC: 87.43 Precision: 83.33 Recall: 91.84
#
# Fold 4
#
# -----Train----------
# AUC: 95.18 Precision: 92.75 Recall: 97.46
#
# -----Validation-----
# AUC: 87.20 Precision: 87.50 Recall: 85.71
#
# Fold 5
#
# -----Train----------
# AUC: 91.80 Precision: 88.63 Recall: 94.92
#
# -----Validation-----
# AUC: 88.34 Precision: 82.46 Recall: 95.92
#
# wheezy-copper-turtle-magic 2
#
# Fold 1
#
# -----Train----------
# AUC: 91.61 Precision: 93.05 Recall: 89.69
#
# -----Validation-----
# AUC: 78.85 Precision: 83.33 Recall: 71.43
#
# Fold 2
#
# -----Train----------
# AUC: 88.82 Precision: 90.32 Recall: 86.60
#
# -----Validation-----
# AUC: 84.97 Precision: 85.42 Recall: 83.67
#
# Fold 3
#
# -----Train----------
# AUC: 94.15 Precision: 95.72 Recall: 92.27
#
# -----Validation-----
# AUC: 84.86 Precision: 84.00 Recall: 85.71
#
# Fold 4
#
# -----Train----------
# AUC: 91.11 Precision: 94.44 Recall: 87.18
#
# -----Validation-----
# AUC: 82.33 Precision: 96.97 Recall: 66.67
#
# Fold 5
#
# -----Train----------
# AUC: 88.83 Precision: 92.66 Recall: 84.10
#
# -----Validation-----
# AUC: 78.33 Precision: 86.49 Recall: 66.67
#
# wheezy-copper-turtle-magic 3
#
# Fold 1
#
# -----Train----------
# AUC: 91.32 Precision: 87.60 Recall: 97.77
#
# -----Validation-----
# AUC: 84.70 Precision: 78.87 Recall: 98.25
#
# Fold 2
#
# -----Train----------
# AUC: 90.62 Precision: 86.90 Recall: 97.33
#
# -----Validation-----
# AUC: 82.97 Precision: 78.79 Recall: 92.86
#
# Fold 3
#
# -----Train----------
# AUC: 91.34 Precision: 87.35 Recall: 98.22
#
# -----Validation-----
# AUC: 81.46 Precision: 75.34 Recall: 98.21
#
# Fold 4
#
# -----Train----------
# AUC: 90.62 Precision: 86.33 Recall: 98.22
#
# -----Validation-----
# AUC: 87.87 Precision: 89.09 Recall: 87.50
#
# Fold 5
#
# -----Train----------
# AUC: 93.57 Precision: 91.25 Recall: 97.33
#
# -----Validation-----
# AUC: 74.23 Precision: 71.64 Recall: 85.71
#
# wheezy-copper-turtle-magic 4
#
# Fold 1
#
# -----Train----------
# AUC: 91.26 Precision: 90.95 Recall: 91.83
#
# -----Validation-----
# AUC: 82.72 Precision: 84.31 Recall: 81.13
#
# Fold 2
#
# -----Train----------
# AUC: 90.58 Precision: 92.50 Recall: 88.52
#
# -----Validation-----
# AUC: 88.37 Precision: 90.00 Recall: 86.54
#
# Fold 3
#
# -----Train----------
# AUC: 91.54 Precision: 92.65 Recall: 90.43
#
# -----Validation-----
# AUC: 82.56 Precision: 85.42 Recall: 78.85
#
# Fold 4
#
# -----Train----------
# AUC: 88.86 Precision: 89.00 Recall: 89.00
#
# -----Validation-----
# AUC: 86.39 Precision: 85.19 Recall: 88.46
#
# Fold 5
#
# -----Train----------
# AUC: 93.47 Precision: 94.17 Recall: 92.82
#
# -----Validation-----
# AUC: 88.40 Precision: 93.48 Recall: 82.69
#
# wheezy-copper-turtle-magic 5
#
# Fold 1
#
# -----Train----------
# AUC: 88.93 Precision: 90.45 Recall: 86.96
#
# -----Validation-----
# AUC: 80.93 Precision: 82.00 Recall: 78.85
#
# Fold 2
#
# -----Train----------
# AUC: 90.13 Precision: 91.92 Recall: 87.92
#
# -----Validation-----
# AUC: 83.78 Precision: 85.71 Recall: 80.77
#
# Fold 3
#
# -----Train----------
# AUC: 89.89 Precision: 94.12 Recall: 85.02
#
# -----Validation-----
# AUC: 78.85 Precision: 84.09 Recall: 71.15
#
# Fold 4
#
# -----Train----------
# AUC: 89.88 Precision: 96.09 Recall: 83.09
#
# -----Validation-----
# AUC: 82.69 Precision: 86.96 Recall: 76.92
#
# Fold 5
#
# -----Train----------
# AUC: 87.54 Precision: 90.62 Recall: 83.65
#
# -----Validation-----
# AUC: 86.31 Precision: 95.12 Recall: 76.47
#
# wheezy-copper-turtle-magic 6
#
# Fold 1
#
# -----Train----------
# AUC: 93.17 Precision: 91.44 Recall: 95.75
#
# -----Validation-----
# AUC: 86.50 Precision: 85.45 Recall: 88.68
#
# Fold 2
#
# -----Train----------
# AUC: 93.93 Precision: 93.09 Recall: 95.28
#
# -----Validation-----
# AUC: 87.40 Precision: 84.48 Recall: 92.45
#
# Fold 3
#
# -----Train----------
# AUC: 93.41 Precision: 91.48 Recall: 96.23
#
# -----Validation-----
# AUC: 87.44 Precision: 85.71 Recall: 90.57
#
# Fold 4
#
# -----Train----------
# AUC: 93.46 Precision: 92.63 Recall: 94.81
#
# -----Validation-----
# AUC: 87.23 Precision: 84.48 Recall: 92.45
#
# Fold 5
#
# -----Train----------
# AUC: 92.98 Precision: 92.17 Recall: 94.34
#
# -----Validation-----
# AUC: 86.17 Precision: 81.97 Recall: 94.34
#
# wheezy-copper-turtle-magic 7
#
# Fold 1
#
# -----Train----------
# AUC: 90.11 Precision: 91.79 Recall: 88.18
#
# -----Validation-----
# AUC: 77.45 Precision: 80.43 Recall: 72.55
#
# Fold 2
#
# -----Train----------
# AUC: 87.88 Precision: 89.29 Recall: 86.21
#
# -----Validation-----
# AUC: 79.41 Precision: 78.85 Recall: 80.39
#
# Fold 3
#
# -----Train----------
# AUC: 90.87 Precision: 92.78 Recall: 88.67
#
# -----Validation-----
# AUC: 76.33 Precision: 82.93 Recall: 66.67
#
# Fold 4
#
# -----Train----------
# AUC: 89.40 Precision: 93.96 Recall: 84.24
#
# -----Validation-----
# AUC: 80.29 Precision: 87.80 Recall: 70.59
#
# Fold 5
#
# -----Train----------
# AUC: 90.65 Precision: 93.23 Recall: 87.75
#
# -----Validation-----
# AUC: 80.00 Precision: 84.09 Recall: 74.00
#
# wheezy-copper-turtle-magic 8
#
# Fold 1
#
# -----Train----------
# AUC: 89.69 Precision: 90.09 Recall: 89.67
#
# -----Validation-----
# AUC: 83.77 Precision: 83.64 Recall: 85.19
#
# Fold 2
#
# -----Train----------
# AUC: 91.87 Precision: 93.24 Recall: 90.61
#
# -----Validation-----
# AUC: 85.68 Precision: 85.45 Recall: 87.04
#
# Fold 3
#
# -----Train----------
# AUC: 91.65 Precision: 92.82 Recall: 90.65
#
# -----Validation-----
# AUC: 77.86 Precision: 77.78 Recall: 79.25
#
# Fold 4
#
# -----Train----------
# AUC: 92.07 Precision: 91.32 Recall: 93.46
#
# -----Validation-----
# AUC: 76.91 Precision: 77.36 Recall: 77.36
#
# Fold 5
#
# -----Train----------
# AUC: 89.06 Precision: 91.58 Recall: 86.45
#
# -----Validation-----
# AUC: 81.74 Precision: 82.69 Recall: 81.13
#
# wheezy-copper-turtle-magic 9
#
# Fold 1
#
# -----Train----------
# AUC: 92.65 Precision: 90.91 Recall: 94.79
#
# -----Validation-----
# AUC: 83.96 Precision: 82.14 Recall: 86.79
#
# Fold 2
#
# -----Train----------
# AUC: 91.00 Precision: 86.81 Recall: 96.68
#
# -----Validation-----
# AUC: 81.13 Precision: 76.19 Recall: 90.57
#
# Fold 3
#
# -----Train----------
# AUC: 91.94 Precision: 90.05 Recall: 94.31
#
# -----Validation-----
# AUC: 81.13 Precision: 77.05 Recall: 88.68
#
# Fold 4
#
# -----Train----------
# AUC: 93.13 Precision: 90.99 Recall: 95.73
#
# -----Validation-----
# AUC: 85.85 Precision: 82.76 Recall: 90.57
#
# Fold 5
#
# -----Train----------
# AUC: 90.80 Precision: 89.50 Recall: 92.45
#
# -----Validation-----
# AUC: 82.69 Precision: 79.31 Recall: 88.46
#
# wheezy-copper-turtle-magic 10
#
# Fold 1
#
# -----Train----------
# AUC: 91.41 Precision: 93.09 Recall: 89.29
#
# -----Validation-----
# AUC: 83.14 Precision: 85.11 Recall: 80.00
#
# Fold 2
#
# -----Train----------
# AUC: 90.95 Precision: 91.28 Recall: 90.36
#
# -----Validation-----
# AUC: 85.95 Precision: 87.23 Recall: 83.67
#
# Fold 3
#
# -----Train----------
# AUC: 91.96 Precision: 93.19 Recall: 90.36
#
# -----Validation-----
# AUC: 84.78 Precision: 90.48 Recall: 77.55
#
# Fold 4
#
# -----Train----------
# AUC: 92.45 Precision: 94.18 Recall: 90.36
#
# -----Validation-----
# AUC: 77.78 Precision: 77.55 Recall: 77.55
#
# Fold 5
#
# -----Train----------
# AUC: 91.52 Precision: 89.00 Recall: 94.42
#
# -----Validation-----
# AUC: 83.78 Precision: 88.37 Recall: 77.55
#
# wheezy-copper-turtle-magic 11
#
# Fold 1
#
# -----Train----------
# AUC: 91.80 Precision: 88.83 Recall: 94.59
#
# -----Validation-----
# AUC: 86.87 Precision: 80.36 Recall: 95.74
#
# Fold 2
#
# -----Train----------
# AUC: 93.72 Precision: 94.48 Recall: 92.43
#
# -----Validation-----
# AUC: 81.55 Precision: 78.43 Recall: 85.11
#
# Fold 3
#
# -----Train----------
# AUC: 92.89 Precision: 95.43 Recall: 89.78
#
# -----Validation-----
# AUC: 86.65 Precision: 82.35 Recall: 91.30
#
# Fold 4
#
# -----Train----------
# AUC: 94.37 Precision: 92.27 Recall: 96.24
#
# -----Validation-----
# AUC: 92.74 Precision: 91.49 Recall: 93.48
#
# Fold 5
#
# -----Train----------
# AUC: 92.08 Precision: 88.94 Recall: 95.16
#
# -----Validation-----
# AUC: 87.48 Precision: 86.96 Recall: 86.96
#
# wheezy-copper-turtle-magic 12
#
# Fold 1
#
# -----Train----------
# AUC: 91.15 Precision: 90.24 Recall: 92.50
#
# -----Validation-----
# AUC: 84.97 Precision: 84.62 Recall: 86.27
#
# Fold 2
#
# -----Train----------
# AUC: 90.62 Precision: 87.61 Recall: 95.02
#
# -----Validation-----
# AUC: 84.80 Precision: 81.82 Recall: 90.00
#
# Fold 3
#
# -----Train----------
# AUC: 90.88 Precision: 88.02 Recall: 95.02
#
# -----Validation-----
# AUC: 77.63 Precision: 71.88 Recall: 92.00
#
# Fold 4
#
# -----Train----------
# AUC: 92.13 Precision: 88.64 Recall: 97.01
#
# -----Validation-----
# AUC: 83.73 Precision: 78.33 Recall: 94.00
#
# Fold 5
#
# -----Train----------
# AUC: 91.14 Precision: 88.79 Recall: 94.53
#
# -----Validation-----
# AUC: 85.80 Precision: 82.14 Recall: 92.00
#
# wheezy-copper-turtle-magic 13
#
# Fold 1
#
# -----Train----------
# AUC: 89.38 Precision: 90.16 Recall: 87.77
#
# -----Validation-----
# AUC: 78.23 Precision: 79.55 Recall: 74.47
#
# Fold 2
#
# -----Train----------
# AUC: 91.21 Precision: 91.40 Recall: 90.43
#
# -----Validation-----
# AUC: 77.36 Precision: 75.51 Recall: 78.72
#
# Fold 3
#
# -----Train----------
# AUC: 90.95 Precision: 91.35 Recall: 89.89
#
# -----Validation-----
# AUC: 84.49 Precision: 84.78 Recall: 82.98
#
# Fold 4
#
# -----Train----------
# AUC: 90.91 Precision: 92.27 Recall: 88.83
#
# -----Validation-----
# AUC: 83.30 Precision: 87.80 Recall: 76.60
#
# Fold 5
#
# -----Train----------
# AUC: 90.96 Precision: 90.91 Recall: 90.43
#
# -----Validation-----
# AUC: 84.43 Precision: 86.36 Recall: 80.85
#
# wheezy-copper-turtle-magic 14
#
# Fold 1
#
# -----Train----------
# AUC: 93.82 Precision: 92.93 Recall: 93.96
#
# -----Validation-----
# AUC: 93.98 Precision: 91.67 Recall: 95.65
#
# Fold 2
#
# -----Train----------
# AUC: 93.94 Precision: 95.43 Recall: 91.76
#
# -----Validation-----
# AUC: 91.81 Precision: 91.30 Recall: 91.30
#
# Fold 3
#
# -----Train----------
# AUC: 93.34 Precision: 91.94 Recall: 93.96
#
# -----Validation-----
# AUC: 88.92 Precision: 85.71 Recall: 91.30
#
# Fold 4
#
# -----Train----------
# AUC: 92.88 Precision: 95.35 Recall: 89.62
#
# -----Validation-----
# AUC: 82.75 Precision: 89.19 Recall: 73.33
#
# Fold 5
#
# -----Train----------
# AUC: 95.40 Precision: 94.59 Recall: 95.63
#
# -----Validation-----
# AUC: 81.76 Precision: 86.84 Recall: 73.33
#
# wheezy-copper-turtle-magic 15
#
# Fold 1
#
# -----Train----------
# AUC: 91.51 Precision: 91.79 Recall: 91.35
#
# -----Validation-----
# AUC: 88.53 Precision: 91.84 Recall: 84.91
#
# Fold 2
#
# -----Train----------
# AUC: 92.72 Precision: 92.02 Recall: 93.78
#
# -----Validation-----
# AUC: 84.48 Precision: 86.00 Recall: 82.69
#
# Fold 3
#
# -----Train----------
# AUC: 91.76 Precision: 91.47 Recall: 92.34
#
# -----Validation-----
# AUC: 85.37 Precision: 81.36 Recall: 92.31
#
# Fold 4
#
# -----Train----------
# AUC: 92.49 Precision: 92.38 Recall: 92.82
#
# -----Validation-----
# AUC: 86.44 Precision: 89.58 Recall: 82.69
#
# Fold 5
#
# -----Train----------
# AUC: 92.74 Precision: 92.82 Recall: 92.82
#
# -----Validation-----
# AUC: 85.43 Precision: 84.91 Recall: 86.54
#
# wheezy-copper-turtle-magic 16
#
# Fold 1
#
# -----Train----------
# AUC: 91.81 Precision: 89.52 Recall: 94.00
#
# -----Validation-----
# AUC: 82.14 Precision: 76.67 Recall: 90.20
#
# Fold 2
#
# -----Train----------
# AUC: 90.26 Precision: 85.40 Recall: 96.02
#
# -----Validation-----
# AUC: 80.91 Precision: 74.19 Recall: 92.00
#
# Fold 3
#
# -----Train----------
# AUC: 90.94 Precision: 87.21 Recall: 95.02
#
# -----Validation-----
# AUC: 81.74 Precision: 77.19 Recall: 88.00
#
# Fold 4
#
# -----Train----------
# AUC: 90.83 Precision: 90.15 Recall: 91.04
#
# -----Validation-----
# AUC: 90.34 Precision: 88.46 Recall: 92.00
#
# Fold 5
#
# -----Train----------
# AUC: 90.29 Precision: 84.78 Recall: 97.01
#
# -----Validation-----
# AUC: 80.68 Precision: 77.78 Recall: 84.00
#
# wheezy-copper-turtle-magic 17
#
# Fold 1
#
# -----Train----------
# AUC: 93.13 Precision: 93.30 Recall: 93.30
#
# -----Validation-----
# AUC: 80.62 Precision: 82.35 Recall: 79.25
#
# Fold 2
#
# -----Train----------
# AUC: 92.67 Precision: 93.66 Recall: 91.87
#
# -----Validation-----
# AUC: 86.34 Precision: 85.45 Recall: 88.68
#
# Fold 3
#
# -----Train----------
# AUC: 91.19 Precision: 91.43 Recall: 91.43
#
# -----Validation-----
# AUC: 88.27 Precision: 90.00 Recall: 86.54
#
# Fold 4
#
# -----Train----------
# AUC: 90.93 Precision: 90.61 Recall: 91.90
#
# -----Validation-----
# AUC: 85.23 Precision: 83.64 Recall: 88.46
#
# Fold 5
#
# -----Train----------
# AUC: 95.89 Precision: 97.54 Recall: 94.29
#
# -----Validation-----
# AUC: 83.24 Precision: 85.71 Recall: 80.77
#
# wheezy-copper-turtle-magic 18
#
# Fold 1
#
# -----Train----------
# AUC: 93.73 Precision: 94.29 Recall: 93.40
#
# -----Validation-----
# AUC: 83.74 Precision: 87.50 Recall: 79.25
#
# Fold 2
#
# -----Train----------
# AUC: 93.95 Precision: 93.90 Recall: 94.34
#
# -----Validation-----
# AUC: 86.46 Precision: 84.21 Recall: 90.57
#
# Fold 3
#
# -----Train----------
# AUC: 93.23 Precision: 93.40 Recall: 93.40
#
# -----Validation-----
# AUC: 89.36 Precision: 87.50 Recall: 92.45
#
# Fold 4
#
# -----Train----------
# AUC: 92.98 Precision: 92.17 Recall: 94.34
#
# -----Validation-----
# AUC: 81.40 Precision: 79.31 Recall: 86.79
#
# Fold 5
#
# -----Train----------
# AUC: 92.25 Precision: 91.28 Recall: 93.87
#
# -----Validation-----
# AUC: 84.51 Precision: 86.27 Recall: 83.02
#
# wheezy-copper-turtle-magic 19
#
# Fold 1
#
# -----Train----------
# AUC: 93.55 Precision: 92.24 Recall: 95.28
#
# -----Validation-----
# AUC: 93.40 Precision: 91.07 Recall: 96.23
#
# Fold 2
#
# -----Train----------
# AUC: 93.82 Precision: 93.46 Recall: 94.34
#
# -----Validation-----
# AUC: 82.80 Precision: 79.66 Recall: 88.68
#
# Fold 3
#
# -----Train----------
# AUC: 93.57 Precision: 91.86 Recall: 95.75
#
# -----Validation-----
# AUC: 86.61 Precision: 83.05 Recall: 92.45
#
# Fold 4
#
# -----Train----------
# AUC: 93.57 Precision: 91.86 Recall: 95.75
#
# -----Validation-----
# AUC: 88.61 Precision: 91.84 Recall: 84.91
#
# Fold 5
#
# -----Train----------
# AUC: 94.76 Precision: 93.58 Recall: 96.23
#
# -----Validation-----
# AUC: 85.78 Precision: 91.30 Recall: 79.25
#
# wheezy-copper-turtle-magic 20
#
# Fold 1
#
# -----Train----------
# AUC: 90.81 Precision: 92.97 Recall: 87.76
#
# -----Validation-----
# AUC: 83.52 Precision: 85.11 Recall: 80.00
#
# Fold 2
#
# -----Train----------
# AUC: 91.89 Precision: 92.71 Recall: 90.36
#
# -----Validation-----
# AUC: 79.34 Precision: 79.17 Recall: 77.55
#
# Fold 3
#
# -----Train----------
# AUC: 90.84 Precision: 93.48 Recall: 87.31
#
# -----Validation-----
# AUC: 82.96 Precision: 90.00 Recall: 73.47
#
# Fold 4
#
# -----Train----------
# AUC: 90.11 Precision: 92.43 Recall: 86.80
#
# -----Validation-----
# AUC: 85.16 Precision: 86.96 Recall: 81.63
#
# Fold 5
#
# -----Train----------
# AUC: 90.15 Precision: 91.53 Recall: 87.82
#
# -----Validation-----
# AUC: 87.20 Precision: 87.50 Recall: 85.71
#
# wheezy-copper-turtle-magic 21
#
# Fold 1
#
# -----Train----------
# AUC: 91.50 Precision: 90.54 Recall: 93.06
#
# -----Validation-----
# AUC: 86.93 Precision: 88.46 Recall: 85.19
#
# Fold 2
#
# -----Train----------
# AUC: 91.50 Precision: 90.18 Recall: 93.52
#
# -----Validation-----
# AUC: 83.14 Precision: 81.03 Recall: 87.04
#
# Fold 3
#
# -----Train----------
# AUC: 90.33 Precision: 88.21 Recall: 93.52
#
# -----Validation-----
# AUC: 85.65 Precision: 80.00 Recall: 96.30
#
# Fold 4
#
# -----Train----------
# AUC: 92.25 Precision: 92.17 Recall: 92.59
#
# -----Validation-----
# AUC: 90.53 Precision: 89.29 Recall: 92.59
#
# Fold 5
#
# -----Train----------
# AUC: 90.79 Precision: 87.98 Recall: 94.91
#
# -----Validation-----
# AUC: 81.05 Precision: 79.31 Recall: 85.19
#
# wheezy-copper-turtle-magic 22
#
# Fold 1
#
# -----Train----------
# AUC: 92.69 Precision: 90.95 Recall: 95.48
#
# -----Validation-----
# AUC: 94.37 Precision: 93.10 Recall: 96.43
#
# Fold 2
#
# -----Train----------
# AUC: 93.86 Precision: 92.21 Recall: 96.38
#
# -----Validation-----
# AUC: 84.96 Precision: 82.26 Recall: 91.07
#
# Fold 3
#
# -----Train----------
# AUC: 91.96 Precision: 89.50 Recall: 95.95
#
# -----Validation-----
# AUC: 88.72 Precision: 87.72 Recall: 90.91
#
# Fold 4
#
# -----Train----------
# AUC: 91.78 Precision: 90.48 Recall: 94.14
#
# -----Validation-----
# AUC: 83.06 Precision: 81.36 Recall: 87.27
#
# Fold 5
#
# -----Train----------
# AUC: 92.78 Precision: 92.83 Recall: 93.24
#
# -----Validation-----
# AUC: 89.74 Precision: 90.74 Recall: 89.09
#
# wheezy-copper-turtle-magic 23
#
# Fold 1
#
# -----Train----------
# AUC: 89.22 Precision: 91.13 Recall: 87.26
#
# -----Validation-----
# AUC: 81.16 Precision: 82.69 Recall: 79.63
#
# Fold 2
#
# -----Train----------
# AUC: 91.93 Precision: 94.97 Recall: 88.73
#
# -----Validation-----
# AUC: 81.74 Precision: 82.69 Recall: 81.13
#
# Fold 3
#
# -----Train----------
# AUC: 91.89 Precision: 93.24 Recall: 90.61
#
# -----Validation-----
# AUC: 78.88 Precision: 80.39 Recall: 77.36
#
# Fold 4
#
# -----Train----------
# AUC: 90.28 Precision: 94.79 Recall: 85.45
#
# -----Validation-----
# AUC: 80.87 Precision: 85.11 Recall: 75.47
#
# Fold 5
#
# -----Train----------
# AUC: 91.66 Precision: 93.20 Recall: 90.14
#
# -----Validation-----
# AUC: 83.78 Precision: 89.13 Recall: 77.36
#
# wheezy-copper-turtle-magic 24
#
# Fold 1
#
# -----Train----------
# AUC: 90.94 Precision: 85.65 Recall: 96.24
#
# -----Validation-----
# AUC: 86.43 Precision: 80.00 Recall: 93.62
#
# Fold 2
#
# -----Train----------
# AUC: 91.39 Precision: 90.43 Recall: 91.40
#
# -----Validation-----
# AUC: 79.35 Precision: 74.07 Recall: 85.11
#
# Fold 3
#
# -----Train----------
# AUC: 91.56 Precision: 92.27 Recall: 89.78
#
# -----Validation-----
# AUC: 84.76 Precision: 84.78 Recall: 82.98
#
# Fold 4
#
# -----Train----------
# AUC: 90.58 Precision: 91.21 Recall: 88.77
#
# -----Validation-----
# AUC: 84.20 Precision: 89.74 Recall: 76.09
#
# Fold 5
#
# -----Train----------
# AUC: 92.42 Precision: 91.98 Recall: 91.98
#
# -----Validation-----
# AUC: 80.60 Precision: 78.72 Recall: 80.43
#
# wheezy-copper-turtle-magic 25
#
# Fold 1
#
# -----Train----------
# AUC: 90.83 Precision: 94.67 Recall: 86.02
#
# -----Validation-----
# AUC: 84.55 Precision: 88.10 Recall: 78.72
#
# Fold 2
#
# -----Train----------
# AUC: 91.42 Precision: 93.71 Recall: 88.17
#
# -----Validation-----
# AUC: 79.44 Precision: 82.93 Recall: 72.34
#
# Fold 3
#
# -----Train----------
# AUC: 90.66 Precision: 92.61 Recall: 87.63
#
# -----Validation-----
# AUC: 88.81 Precision: 89.13 Recall: 87.23
#
# Fold 4
#
# -----Train----------
# AUC: 88.36 Precision: 91.28 Recall: 83.96
#
# -----Validation-----
# AUC: 88.26 Precision: 94.87 Recall: 80.43
#
# Fold 5
#
# -----Train----------
# AUC: 91.43 Precision: 94.25 Recall: 87.70
#
# -----Validation-----
# AUC: 88.47 Precision: 90.70 Recall: 84.78
#
# wheezy-copper-turtle-magic 26
#
# Fold 1
#
# -----Train----------
# AUC: 88.44 Precision: 88.24 Recall: 87.77
#
# -----Validation-----
# AUC: 83.70 Precision: 86.36 Recall: 79.17
#
# Fold 2
#
# -----Train----------
# AUC: 89.10 Precision: 86.14 Recall: 92.06
#
# -----Validation-----
# AUC: 81.85 Precision: 77.36 Recall: 87.23
#
# Fold 3
#
# -----Train----------
# AUC: 90.52 Precision: 90.43 Recall: 89.95
#
# -----Validation-----
# AUC: 77.68 Precision: 74.51 Recall: 80.85
#
# Fold 4
#
# -----Train----------
# AUC: 91.01 Precision: 91.85 Recall: 89.42
#
# -----Validation-----
# AUC: 87.62 Precision: 87.23 Recall: 87.23
#
# Fold 5
#
# -----Train----------
# AUC: 91.11 Precision: 89.69 Recall: 92.06
#
# -----Validation-----
# AUC: 84.55 Precision: 83.33 Recall: 85.11
#
# wheezy-copper-turtle-magic 27
#
# Fold 1
#
# -----Train----------
# AUC: 90.75 Precision: 90.48 Recall: 90.00
#
# -----Validation-----
# AUC: 80.44 Precision: 78.00 Recall: 81.25
#
# Fold 2
#
# -----Train----------
# AUC: 90.68 Precision: 88.00 Recall: 92.63
#
# -----Validation-----
# AUC: 78.36 Precision: 75.00 Recall: 81.25
#
# Fold 3
#
# -----Train----------
# AUC: 90.63 Precision: 88.78 Recall: 91.58
#
# -----Validation-----
# AUC: 79.40 Precision: 75.47 Recall: 83.33
#
# Fold 4
#
# -----Train----------
# AUC: 89.68 Precision: 87.44 Recall: 91.10
#
# -----Validation-----
# AUC: 87.25 Precision: 82.69 Recall: 91.49
#
# Fold 5
#
# -----Train----------
# AUC: 90.59 Precision: 89.64 Recall: 90.58
#
# -----Validation-----
# AUC: 83.00 Precision: 81.25 Recall: 82.98
#
# wheezy-copper-turtle-magic 28
#
# Fold 1
#
# -----Train----------
# AUC: 93.47 Precision: 93.49 Recall: 93.49
#
# -----Validation-----
# AUC: 84.26 Precision: 86.27 Recall: 81.48
#
# Fold 2
#
# -----Train----------
# AUC: 92.08 Precision: 92.89 Recall: 91.16
#
# -----Validation-----
# AUC: 80.56 Precision: 76.19 Recall: 88.89
#
# Fold 3
#
# -----Train----------
# AUC: 92.77 Precision: 91.82 Recall: 93.95
#
# -----Validation-----
# AUC: 85.19 Precision: 85.19 Recall: 85.19
#
# Fold 4
#
# -----Train----------
# AUC: 89.07 Precision: 87.84 Recall: 90.70
#
# -----Validation-----
# AUC: 88.82 Precision: 92.00 Recall: 85.19
#
# Fold 5
#
# -----Train----------
# AUC: 91.18 Precision: 90.09 Recall: 92.59
#
# -----Validation-----
# AUC: 83.96 Precision: 82.14 Recall: 86.79
#
# wheezy-copper-turtle-magic 29
#
# Fold 1
#
# -----Train----------
# AUC: 92.45 Precision: 90.87 Recall: 94.50
#
# -----Validation-----
# AUC: 85.00 Precision: 85.71 Recall: 84.00
#
# Fold 2
#
# -----Train----------
# AUC: 93.45 Precision: 91.04 Recall: 96.50
#
# -----Validation-----
# AUC: 81.00 Precision: 78.18 Recall: 86.00
#
# Fold 3
#
# -----Train----------
# AUC: 90.44 Precision: 88.21 Recall: 93.50
#
# -----Validation-----
# AUC: 85.00 Precision: 80.70 Recall: 92.00
#
# Fold 4
#
# -----Train----------
# AUC: 91.47 Precision: 89.15 Recall: 94.50
#
# -----Validation-----
# AUC: 85.82 Precision: 83.33 Recall: 90.00
#
# Fold 5
#
# -----Train----------
# AUC: 92.48 Precision: 90.87 Recall: 94.50
#
# -----Validation-----
# AUC: 78.61 Precision: 71.64 Recall: 96.00
#
# wheezy-copper-turtle-magic 30
#
# Fold 1
#
# -----Train----------
# AUC: 91.99 Precision: 92.92 Recall: 91.63
#
# -----Validation-----
# AUC: 83.74 Precision: 86.27 Recall: 81.48
#
# Fold 2
#
# -----Train----------
# AUC: 91.14 Precision: 94.06 Recall: 88.37
#
# -----Validation-----
# AUC: 86.47 Precision: 88.46 Recall: 85.19
#
# Fold 3
#
# -----Train----------
# AUC: 93.19 Precision: 93.49 Recall: 93.49
#
# -----Validation-----
# AUC: 82.39 Precision: 82.14 Recall: 85.19
#
# Fold 4
#
# -----Train----------
# AUC: 92.51 Precision: 93.81 Recall: 91.63
#
# -----Validation-----
# AUC: 82.58 Precision: 84.62 Recall: 81.48
#
# Fold 5
#
# -----Train----------
# AUC: 92.21 Precision: 92.20 Recall: 93.06
#
# -----Validation-----
# AUC: 87.20 Precision: 87.04 Recall: 88.68
#
# wheezy-copper-turtle-magic 31
#
# Fold 1
#
# -----Train----------
# AUC: 90.17 Precision: 88.46 Recall: 92.00
#
# -----Validation-----
# AUC: 81.58 Precision: 79.63 Recall: 84.31
#
# Fold 2
#
# -----Train----------
# AUC: 88.23 Precision: 86.26 Recall: 90.55
#
# -----Validation-----
# AUC: 84.38 Precision: 81.48 Recall: 88.00
#
# Fold 3
#
# -----Train----------
# AUC: 88.93 Precision: 89.80 Recall: 87.56
#
# -----Validation-----
# AUC: 78.38 Precision: 79.17 Recall: 76.00
#
# Fold 4
#
# -----Train----------
# AUC: 90.69 Precision: 90.15 Recall: 91.04
#
# -----Validation-----
# AUC: 79.20 Precision: 79.59 Recall: 78.00
#
# Fold 5
#
# -----Train----------
# AUC: 88.47 Precision: 88.89 Recall: 87.56
#
# -----Validation-----
# AUC: 79.14 Precision: 83.72 Recall: 72.00
#
# wheezy-copper-turtle-magic 32
#
# Fold 1
#
# -----Train----------
# AUC: 91.77 Precision: 89.74 Recall: 93.58
#
# -----Validation-----
# AUC: 86.81 Precision: 81.48 Recall: 93.62
#
# Fold 2
#
# -----Train----------
# AUC: 92.30 Precision: 89.85 Recall: 94.65
#
# -----Validation-----
# AUC: 83.62 Precision: 80.39 Recall: 87.23
#
# Fold 3
#
# -----Train----------
# AUC: 91.28 Precision: 88.44 Recall: 94.12
#
# -----Validation-----
# AUC: 78.36 Precision: 77.08 Recall: 78.72
#
# Fold 4
#
# -----Train----------
# AUC: 90.84 Precision: 86.12 Recall: 96.26
#
# -----Validation-----
# AUC: 82.68 Precision: 77.78 Recall: 89.36
#
# Fold 5
#
# -----Train----------
# AUC: 90.81 Precision: 88.00 Recall: 93.62
#
# -----Validation-----
# AUC: 81.30 Precision: 75.93 Recall: 89.13
#
# wheezy-copper-turtle-magic 33
#
# Fold 1
#
# -----Train----------
# AUC: 92.90 Precision: 93.81 Recall: 92.06
#
# -----Validation-----
# AUC: 84.94 Precision: 86.54 Recall: 83.33
#
# Fold 2
#
# -----Train----------
# AUC: 91.91 Precision: 90.54 Recall: 93.93
#
# -----Validation-----
# AUC: 81.05 Precision: 79.31 Recall: 85.19
#
# Fold 3
#
# -----Train----------
# AUC: 93.82 Precision: 92.73 Recall: 95.33
#
# -----Validation-----
# AUC: 88.75 Precision: 92.00 Recall: 85.19
#
# Fold 4
#
# -----Train----------
# AUC: 93.39 Precision: 94.31 Recall: 92.56
#
# -----Validation-----
# AUC: 87.59 Precision: 85.71 Recall: 90.57
#
# Fold 5
#
# -----Train----------
# AUC: 93.60 Precision: 93.12 Recall: 94.42
#
# -----Validation-----
# AUC: 82.86 Precision: 83.02 Recall: 83.02
#
# wheezy-copper-turtle-magic 34
#
# Fold 1
#
# -----Train----------
# AUC: 90.01 Precision: 86.35 Recall: 97.29
#
# -----Validation-----
# AUC: 82.43 Precision: 78.79 Recall: 92.86
#
# Fold 2
#
# -----Train----------
# AUC: 91.51 Precision: 88.16 Recall: 97.74
#
# -----Validation-----
# AUC: 88.43 Precision: 86.67 Recall: 92.86
#
# Fold 3
#
# -----Train----------
# AUC: 92.59 Precision: 90.00 Recall: 97.30
#
# -----Validation-----
# AUC: 85.94 Precision: 81.54 Recall: 96.36
#
# Fold 4
#
# -----Train----------
# AUC: 89.47 Precision: 87.14 Recall: 94.59
#
# -----Validation-----
# AUC: 90.82 Precision: 85.94 Recall: 100.00
#
# Fold 5
#
# -----Train----------
# AUC: 90.57 Precision: 87.10 Recall: 97.30
#
# -----Validation-----
# AUC: 85.94 Precision: 81.54 Recall: 96.36
#
# wheezy-copper-turtle-magic 35
#
# Fold 1
#
# -----Train----------
# AUC: 91.30 Precision: 89.04 Recall: 94.66
#
# -----Validation-----
# AUC: 82.42 Precision: 85.42 Recall: 78.85
#
# Fold 2
#
# -----Train----------
# AUC: 90.55 Precision: 87.84 Recall: 94.66
#
# -----Validation-----
# AUC: 83.27 Precision: 81.82 Recall: 86.54
#
# Fold 3
#
# -----Train----------
# AUC: 91.55 Precision: 89.45 Recall: 94.66
#
# -----Validation-----
# AUC: 80.19 Precision: 75.81 Recall: 90.38
#
# Fold 4
#
# -----Train----------
# AUC: 91.61 Precision: 91.39 Recall: 92.27
#
# -----Validation-----
# AUC: 81.20 Precision: 82.00 Recall: 80.39
#
# Fold 5
#
# -----Train----------
# AUC: 91.38 Precision: 90.57 Recall: 92.75
#
# -----Validation-----
# AUC: 85.75 Precision: 79.37 Recall: 98.04
#
# wheezy-copper-turtle-magic 36
#
# Fold 1
#
# -----Train----------
# AUC: 90.49 Precision: 93.41 Recall: 86.19
#
# -----Validation-----
# AUC: 88.90 Precision: 87.23 Recall: 89.13
#
# Fold 2
#
# -----Train----------
# AUC: 90.53 Precision: 92.90 Recall: 86.74
#
# -----Validation-----
# AUC: 78.84 Precision: 88.24 Recall: 65.22
#
# Fold 3
#
# -----Train----------
# AUC: 90.64 Precision: 91.95 Recall: 87.91
#
# -----Validation-----
# AUC: 89.22 Precision: 94.87 Recall: 82.22
#
# Fold 4
#
# -----Train----------
# AUC: 93.82 Precision: 93.89 Recall: 92.86
#
# -----Validation-----
# AUC: 76.73 Precision: 81.08 Recall: 66.67
#
# Fold 5
#
# -----Train----------
# AUC: 90.07 Precision: 92.35 Recall: 86.26
#
# -----Validation-----
# AUC: 83.63 Precision: 94.12 Recall: 71.11
#
# wheezy-copper-turtle-magic 37
#
# Fold 1
#
# -----Train----------
# AUC: 93.00 Precision: 92.17 Recall: 94.34
#
# -----Validation-----
# AUC: 77.35 Precision: 77.78 Recall: 77.78
#
# Fold 2
#
# -----Train----------
# AUC: 92.36 Precision: 93.30 Recall: 91.55
#
# -----Validation-----
# AUC: 85.63 Precision: 88.00 Recall: 83.02
#
# Fold 3
#
# -----Train----------
# AUC: 92.33 Precision: 92.09 Recall: 92.96
#
# -----Validation-----
# AUC: 78.80 Precision: 78.18 Recall: 81.13
#
# Fold 4
#
# -----Train----------
# AUC: 92.13 Precision: 93.27 Recall: 91.08
#
# -----Validation-----
# AUC: 89.44 Precision: 90.38 Recall: 88.68
#
# Fold 5
#
# -----Train----------
# AUC: 92.12 Precision: 92.86 Recall: 91.55
#
# -----Validation-----
# AUC: 84.65 Precision: 86.27 Recall: 83.02
#
# wheezy-copper-turtle-magic 38
#
# Fold 1
#
# -----Train----------
# AUC: 89.44 Precision: 90.16 Recall: 87.44
#
# -----Validation-----
# AUC: 77.50 Precision: 74.07 Recall: 80.00
#
# Fold 2
#
# -----Train----------
# AUC: 93.63 Precision: 92.16 Recall: 94.47
#
# -----Validation-----
# AUC: 82.86 Precision: 83.33 Recall: 80.00
#
# Fold 3
#
# -----Train----------
# AUC: 90.80 Precision: 88.83 Recall: 91.96
#
# -----Validation-----
# AUC: 84.75 Precision: 85.42 Recall: 82.00
#
# Fold 4
#
# -----Train----------
# AUC: 90.88 Precision: 91.71 Recall: 88.94
#
# -----Validation-----
# AUC: 77.73 Precision: 81.40 Recall: 70.00
#
# Fold 5
#
# -----Train----------
# AUC: 91.39 Precision: 92.27 Recall: 89.50
#
# -----Validation-----
# AUC: 81.50 Precision: 82.61 Recall: 77.55
#
# wheezy-copper-turtle-magic 39
#
# Fold 1
#
# -----Train----------
# AUC: 91.39 Precision: 89.42 Recall: 93.47
#
# -----Validation-----
# AUC: 84.42 Precision: 80.36 Recall: 90.00
#
# Fold 2
#
# -----Train----------
# AUC: 91.92 Precision: 88.43 Recall: 95.98
#
# -----Validation-----
# AUC: 87.38 Precision: 82.46 Recall: 94.00
#
# Fold 3
#
# -----Train----------
# AUC: 90.22 Precision: 85.65 Recall: 95.98
#
# -----Validation-----
# AUC: 82.58 Precision: 75.81 Recall: 94.00
#
# Fold 4
#
# -----Train----------
# AUC: 91.90 Precision: 90.29 Recall: 93.47
#
# -----Validation-----
# AUC: 86.18 Precision: 83.33 Recall: 90.00
#
# Fold 5
#
# -----Train----------
# AUC: 91.95 Precision: 88.84 Recall: 95.50
#
# -----Validation-----
# AUC: 76.15 Precision: 71.93 Recall: 83.67
#
# wheezy-copper-turtle-magic 40
#
# Fold 1
#
# -----Train----------
# AUC: 92.42 Precision: 91.09 Recall: 93.88
#
# -----Validation-----
# AUC: 76.00 Precision: 77.08 Recall: 74.00
#
# Fold 2
#
# -----Train----------
# AUC: 92.94 Precision: 90.82 Recall: 95.43
#
# -----Validation-----
# AUC: 84.88 Precision: 82.69 Recall: 87.76
#
# Fold 3
#
# -----Train----------
# AUC: 92.95 Precision: 89.67 Recall: 96.95
#
# -----Validation-----
# AUC: 85.90 Precision: 83.02 Recall: 89.80
#
# Fold 4
#
# -----Train----------
# AUC: 92.43 Precision: 91.13 Recall: 93.91
#
# -----Validation-----
# AUC: 86.94 Precision: 82.14 Recall: 93.88
#
# Fold 5
#
# -----Train----------
# AUC: 91.96 Precision: 89.47 Recall: 94.92
#
# -----Validation-----
# AUC: 89.80 Precision: 89.80 Recall: 89.80
#
# wheezy-copper-turtle-magic 41
#
# Fold 1
#
# -----Train----------
# AUC: 91.88 Precision: 90.95 Recall: 93.06
#
# -----Validation-----
# AUC: 81.48 Precision: 84.00 Recall: 77.78
#
# Fold 2
#
# -----Train----------
# AUC: 92.34 Precision: 91.40 Recall: 93.52
#
# -----Validation-----
# AUC: 89.81 Precision: 86.44 Recall: 94.44
#
# Fold 3
#
# -----Train----------
# AUC: 90.03 Precision: 91.79 Recall: 87.96
#
# -----Validation-----
# AUC: 84.26 Precision: 84.91 Recall: 83.33
#
# Fold 4
#
# -----Train----------
# AUC: 92.58 Precision: 92.99 Recall: 92.13
#
# -----Validation-----
# AUC: 84.26 Precision: 86.27 Recall: 81.48
#
# Fold 5
#
# -----Train----------
# AUC: 91.90 Precision: 89.87 Recall: 94.44
#
# -----Validation-----
# AUC: 84.12 Precision: 84.91 Recall: 83.33
#
# wheezy-copper-turtle-magic 42
#
# Fold 1
#
# -----Train----------
# AUC: 90.69 Precision: 90.96 Recall: 90.48
#
# -----Validation-----
# AUC: 84.18 Precision: 82.35 Recall: 87.50
#
# Fold 2
#
# -----Train----------
# AUC: 91.49 Precision: 91.10 Recall: 92.06
#
# -----Validation-----
# AUC: 78.90 Precision: 76.92 Recall: 83.33
#
# Fold 3
#
# -----Train----------
# AUC: 91.76 Precision: 90.36 Recall: 93.68
#
# -----Validation-----
# AUC: 76.60 Precision: 82.05 Recall: 68.09
#
# Fold 4
#
# -----Train----------
# AUC: 90.96 Precision: 89.39 Recall: 93.16
#
# -----Validation-----
# AUC: 82.98 Precision: 77.19 Recall: 93.62
#
# Fold 5
#
# -----Train----------
# AUC: 90.45 Precision: 87.38 Recall: 94.74
#
# -----Validation-----
# AUC: 91.37 Precision: 89.80 Recall: 93.62
#
# wheezy-copper-turtle-magic 43
#
# Fold 1
#
# -----Train----------
# AUC: 93.32 Precision: 90.65 Recall: 96.04
#
# -----Validation-----
# AUC: 80.23 Precision: 75.00 Recall: 88.24
#
# Fold 2
#
# -----Train----------
# AUC: 90.67 Precision: 88.26 Recall: 93.07
#
# -----Validation-----
# AUC: 80.99 Precision: 79.25 Recall: 82.35
#
# Fold 3
#
# -----Train----------
# AUC: 91.19 Precision: 88.37 Recall: 94.06
#
# -----Validation-----
# AUC: 85.55 Precision: 86.00 Recall: 84.31
#
# Fold 4
#
# -----Train----------
# AUC: 90.26 Precision: 87.16 Recall: 93.60
#
# -----Validation-----
# AUC: 82.45 Precision: 83.33 Recall: 80.00
#
# Fold 5
#
# -----Train----------
# AUC: 90.03 Precision: 86.43 Recall: 94.09
#
# -----Validation-----
# AUC: 83.68 Precision: 78.95 Recall: 90.00
#
# wheezy-copper-turtle-magic 44
#
# Fold 1
#
# -----Train----------
# AUC: 92.59 Precision: 94.58 Recall: 91.00
#
# -----Validation-----
# AUC: 82.43 Precision: 87.23 Recall: 77.36
#
# Fold 2
#
# -----Train----------
# AUC: 93.17 Precision: 96.45 Recall: 90.05
#
# -----Validation-----
# AUC: 85.46 Precision: 91.30 Recall: 79.25
#
# Fold 3
#
# -----Train----------
# AUC: 91.47 Precision: 91.55 Recall: 92.42
#
# -----Validation-----
# AUC: 90.33 Precision: 95.74 Recall: 84.91
#
# Fold 4
#
# -----Train----------
# AUC: 91.26 Precision: 91.90 Recall: 91.47
#
# -----Validation-----
# AUC: 88.20 Precision: 91.84 Recall: 84.91
#
# Fold 5
#
# -----Train----------
# AUC: 91.78 Precision: 92.42 Recall: 91.98
#
# -----Validation-----
# AUC: 84.86 Precision: 86.27 Recall: 84.62
#
# wheezy-copper-turtle-magic 45
#
# Fold 1
#
# -----Train----------
# AUC: 88.20 Precision: 88.56 Recall: 87.25
#
# -----Validation-----
# AUC: 79.86 Precision: 77.78 Recall: 82.35
#
# Fold 2
#
# -----Train----------
# AUC: 87.05 Precision: 85.38 Recall: 88.73
#
# -----Validation-----
# AUC: 83.70 Precision: 81.48 Recall: 86.27
#
# Fold 3
#
# -----Train----------
# AUC: 86.76 Precision: 87.06 Recall: 85.78
#
# -----Validation-----
# AUC: 82.65 Precision: 83.67 Recall: 80.39
#
# Fold 4
#
# -----Train----------
# AUC: 89.22 Precision: 87.32 Recall: 91.18
#
# -----Validation-----
# AUC: 79.78 Precision: 80.00 Recall: 78.43
#
# Fold 5
#
# -----Train----------
# AUC: 88.24 Precision: 87.08 Recall: 89.22
#
# -----Validation-----
# AUC: 77.97 Precision: 75.00 Recall: 82.35
#
# wheezy-copper-turtle-magic 46
#
# Fold 1
#
# -----Train----------
# AUC: 90.22 Precision: 91.67 Recall: 88.44
#
# -----Validation-----
# AUC: 88.08 Precision: 91.30 Recall: 84.00
#
# Fold 2
#
# -----Train----------
# AUC: 92.50 Precision: 92.46 Recall: 92.46
#
# -----Validation-----
# AUC: 83.00 Precision: 85.11 Recall: 80.00
#
# Fold 3
#
# -----Train----------
# AUC: 90.73 Precision: 94.51 Recall: 86.43
#
# -----Validation-----
# AUC: 82.00 Precision: 86.36 Recall: 76.00
#
# Fold 4
#
# -----Train----------
# AUC: 92.48 Precision: 96.17 Recall: 88.44
#
# -----Validation-----
# AUC: 85.00 Precision: 85.71 Recall: 84.00
#
# Fold 5
#
# -----Train----------
# AUC: 91.02 Precision: 91.41 Recall: 90.50
#
# -----Validation-----
# AUC: 89.94 Precision: 86.79 Recall: 93.88
#
# wheezy-copper-turtle-magic 47
#
# Fold 1
#
# -----Train----------
# AUC: 92.02 Precision: 92.17 Recall: 92.59
#
# -----Validation-----
# AUC: 82.91 Precision: 84.91 Recall: 81.82
#
# Fold 2
#
# -----Train----------
# AUC: 90.56 Precision: 90.09 Recall: 92.17
#
# -----Validation-----
# AUC: 79.67 Precision: 78.95 Recall: 83.33
#
# Fold 3
#
# -----Train----------
# AUC: 88.42 Precision: 88.58 Recall: 89.40
#
# -----Validation-----
# AUC: 83.59 Precision: 83.64 Recall: 85.19
#
# Fold 4
#
# -----Train----------
# AUC: 90.16 Precision: 91.12 Recall: 89.86
#
# -----Validation-----
# AUC: 80.81 Precision: 82.69 Recall: 79.63
#
# Fold 5
#
# -----Train----------
# AUC: 91.35 Precision: 91.71 Recall: 91.71
#
# -----Validation-----
# AUC: 84.15 Precision: 81.67 Recall: 90.74
#
# wheezy-copper-turtle-magic 48
#
# Fold 1
#
# -----Train----------
# AUC: 92.89 Precision: 92.69 Recall: 93.55
#
# -----Validation-----
# AUC: 88.72 Precision: 87.72 Recall: 90.91
#
# Fold 2
#
# -----Train----------
# AUC: 92.15 Precision: 91.07 Recall: 94.01
#
# -----Validation-----
# AUC: 88.93 Precision: 93.88 Recall: 83.64
#
# Fold 3
#
# -----Train----------
# AUC: 92.70 Precision: 93.49 Recall: 92.20
#
# -----Validation-----
# AUC: 82.91 Precision: 80.00 Recall: 88.89
#
# Fold 4
#
# -----Train----------
# AUC: 90.80 Precision: 90.50 Recall: 91.74
#
# -----Validation-----
# AUC: 80.77 Precision: 78.33 Recall: 87.04
#
# Fold 5
#
# -----Train----------
# AUC: 89.13 Precision: 88.39 Recall: 90.83
#
# -----Validation-----
# AUC: 86.55 Precision: 84.48 Recall: 90.74
#
# wheezy-copper-turtle-magic 49
#
# Fold 1
#
# -----Train----------
# AUC: 92.38 Precision: 94.27 Recall: 90.05
#
# -----Validation-----
# AUC: 83.50 Precision: 82.69 Recall: 84.31
#
# Fold 2
#
# -----Train----------
# AUC: 92.12 Precision: 95.19 Recall: 88.56
#
# -----Validation-----
# AUC: 78.54 Precision: 85.37 Recall: 68.63
#
# Fold 3
#
# -----Train----------
# AUC: 91.43 Precision: 93.26 Recall: 89.11
#
# -----Validation-----
# AUC: 85.23 Precision: 87.23 Recall: 82.00
#
# Fold 4
#
# -----Train----------
# AUC: 91.91 Precision: 94.24 Recall: 89.11
#
# -----Validation-----
# AUC: 85.19 Precision: 88.89 Recall: 80.00
#
# Fold 5
#
# -----Train----------
# AUC: 92.20 Precision: 91.67 Recall: 92.57
#
# -----Validation-----
# AUC: 86.31 Precision: 84.62 Recall: 88.00
#
# wheezy-copper-turtle-magic 50
#
# Fold 1
#
# -----Train----------
# AUC: 91.54 Precision: 93.66 Recall: 88.89
#
# -----Validation-----
# AUC: 87.31 Precision: 95.56 Recall: 78.18
#
# Fold 2
#
# -----Train----------
# AUC: 90.62 Precision: 95.36 Recall: 85.25
#
# -----Validation-----
# AUC: 83.60 Precision: 84.62 Recall: 81.48
#
# Fold 3
#
# -----Train----------
# AUC: 91.29 Precision: 96.37 Recall: 85.71
#
# -----Validation-----
# AUC: 84.56 Precision: 83.64 Recall: 85.19
#
# Fold 4
#
# -----Train----------
# AUC: 92.71 Precision: 94.69 Recall: 90.32
#
# -----Validation-----
# AUC: 80.75 Precision: 86.67 Recall: 72.22
#
# Fold 5
#
# -----Train----------
# AUC: 91.54 Precision: 95.45 Recall: 87.10
#
# -----Validation-----
# AUC: 78.80 Precision: 91.89 Recall: 62.96
#
# wheezy-copper-turtle-magic 51
#
# Fold 1
#
# -----Train----------
# AUC: 91.00 Precision: 87.80 Recall: 95.15
#
# -----Validation-----
# AUC: 81.76 Precision: 80.00 Recall: 84.21
#
# Fold 2
#
# -----Train----------
# AUC: 89.27 Precision: 86.78 Recall: 92.51
#
# -----Validation-----
# AUC: 85.96 Precision: 81.54 Recall: 92.98
#
# Fold 3
#
# -----Train----------
# AUC: 90.80 Precision: 88.07 Recall: 94.27
#
# -----Validation-----
# AUC: 79.82 Precision: 77.42 Recall: 84.21
#
# Fold 4
#
# -----Train----------
# AUC: 90.14 Precision: 88.24 Recall: 92.51
#
# -----Validation-----
# AUC: 85.09 Precision: 83.33 Recall: 87.72
#
# Fold 5
#
# -----Train----------
# AUC: 91.47 Precision: 90.21 Recall: 92.98
#
# -----Validation-----
# AUC: 87.69 Precision: 81.82 Recall: 96.43
#
# wheezy-copper-turtle-magic 52
#
# Fold 1
#
# -----Train----------
# AUC: 91.27 Precision: 92.16 Recall: 90.82
#
# -----Validation-----
# AUC: 84.32 Precision: 89.13 Recall: 78.85
#
# Fold 2
#
# -----Train----------
# AUC: 92.08 Precision: 94.42 Recall: 89.86
#
# -----Validation-----
# AUC: 83.36 Precision: 88.89 Recall: 76.92
#
# Fold 3
#
# -----Train----------
# AUC: 92.32 Precision: 94.00 Recall: 90.82
#
# -----Validation-----
# AUC: 81.97 Precision: 82.69 Recall: 82.69
#
# Fold 4
#
# -----Train----------
# AUC: 89.03 Precision: 89.76 Recall: 88.89
#
# -----Validation-----
# AUC: 85.98 Precision: 86.54 Recall: 86.54
#
# Fold 5
#
# -----Train----------
# AUC: 90.79 Precision: 91.30 Recall: 90.87
#
# -----Validation-----
# AUC: 81.74 Precision: 81.13 Recall: 84.31
#
# wheezy-copper-turtle-magic 53
#
# Fold 1
#
# -----Train----------
# AUC: 92.00 Precision: 91.59 Recall: 93.78
#
# -----Validation-----
# AUC: 82.88 Precision: 83.33 Recall: 84.91
#
# Fold 2
#
# -----Train----------
# AUC: 93.35 Precision: 93.36 Recall: 94.26
#
# -----Validation-----
# AUC: 82.10 Precision: 79.03 Recall: 92.45
#
# Fold 3
#
# -----Train----------
# AUC: 92.75 Precision: 91.74 Recall: 95.24
#
# -----Validation-----
# AUC: 85.03 Precision: 80.65 Recall: 96.15
#
# Fold 4
#
# -----Train----------
# AUC: 91.60 Precision: 91.94 Recall: 92.38
#
# -----Validation-----
# AUC: 87.71 Precision: 88.46 Recall: 88.46
#
# Fold 5
#
# -----Train----------
# AUC: 92.92 Precision: 93.75 Recall: 92.86
#
# -----Validation-----
# AUC: 83.86 Precision: 87.50 Recall: 80.77
#
# wheezy-copper-turtle-magic 54
#
# Fold 1
#
# -----Train----------
# AUC: 90.13 Precision: 90.78 Recall: 89.90
#
# -----Validation-----
# AUC: 84.57 Precision: 87.76 Recall: 81.13
#
# Fold 2
#
# -----Train----------
# AUC: 89.39 Precision: 89.52 Recall: 89.95
#
# -----Validation-----
# AUC: 81.38 Precision: 82.35 Recall: 80.77
#
# Fold 3
#
# -----Train----------
# AUC: 89.75 Precision: 92.39 Recall: 87.08
#
# -----Validation-----
# AUC: 83.12 Precision: 83.02 Recall: 84.62
#
# Fold 4
#
# -----Train----------
# AUC: 91.88 Precision: 91.90 Recall: 92.34
#
# -----Validation-----
# AUC: 83.07 Precision: 81.82 Recall: 86.54
#
# Fold 5
#
# -----Train----------
# AUC: 90.18 Precision: 90.82 Recall: 89.95
#
# -----Validation-----
# AUC: 86.19 Precision: 88.00 Recall: 84.62
#
# wheezy-copper-turtle-magic 55
#
# Fold 1
#
# -----Train----------
# AUC: 91.70 Precision: 96.17 Recall: 86.70
#
# -----Validation-----
# AUC: 82.57 Precision: 86.67 Recall: 76.47
#
# Fold 2
#
# -----Train----------
# AUC: 90.73 Precision: 95.08 Recall: 85.71
#
# -----Validation-----
# AUC: 82.61 Precision: 85.11 Recall: 78.43
#
# Fold 3
#
# -----Train----------
# AUC: 89.01 Precision: 94.89 Recall: 82.27
#
# -----Validation-----
# AUC: 86.35 Precision: 95.12 Recall: 76.47
#
# Fold 4
#
# -----Train----------
# AUC: 91.72 Precision: 95.19 Recall: 87.68
#
# -----Validation-----
# AUC: 89.25 Precision: 97.62 Recall: 80.39
#
# Fold 5
#
# -----Train----------
# AUC: 90.52 Precision: 95.08 Recall: 85.29
#
# -----Validation-----
# AUC: 85.40 Precision: 85.71 Recall: 84.00
#
# wheezy-copper-turtle-magic 56
#
# Fold 1
#
# -----Train----------
# AUC: 93.04 Precision: 95.10 Recall: 91.08
#
# -----Validation-----
# AUC: 82.67 Precision: 83.33 Recall: 83.33
#
# Fold 2
#
# -----Train----------
# AUC: 91.76 Precision: 92.02 Recall: 92.02
#
# -----Validation-----
# AUC: 85.52 Precision: 85.45 Recall: 87.04
#
# Fold 3
#
# -----Train----------
# AUC: 89.63 Precision: 90.52 Recall: 89.25
#
# -----Validation-----
# AUC: 82.68 Precision: 87.23 Recall: 77.36
#
# Fold 4
#
# -----Train----------
# AUC: 91.13 Precision: 93.17 Recall: 89.25
#
# -----Validation-----
# AUC: 88.34 Precision: 88.68 Recall: 88.68
#
# Fold 5
#
# -----Train----------
# AUC: 92.56 Precision: 94.20 Recall: 91.12
#
# -----Validation-----
# AUC: 82.57 Precision: 84.31 Recall: 81.13
#
# wheezy-copper-turtle-magic 57
#
# Fold 1
#
# -----Train----------
# AUC: 89.79 Precision: 90.48 Recall: 89.62
#
# -----Validation-----
# AUC: 81.74 Precision: 83.02 Recall: 81.48
#
# Fold 2
#
# -----Train----------
# AUC: 90.56 Precision: 91.83 Recall: 89.67
#
# -----Validation-----
# AUC: 87.51 Precision: 91.67 Recall: 83.02
#
# Fold 3
#
# -----Train----------
# AUC: 90.38 Precision: 93.03 Recall: 87.79
#
# -----Validation-----
# AUC: 82.40 Precision: 80.70 Recall: 86.79
#
# Fold 4
#
# -----Train----------
# AUC: 90.03 Precision: 90.19 Recall: 90.61
#
# -----Validation-----
# AUC: 83.57 Precision: 86.00 Recall: 81.13
#
# Fold 5
#
# -----Train----------
# AUC: 91.93 Precision: 90.54 Recall: 94.37
#
# -----Validation-----
# AUC: 84.14 Precision: 82.46 Recall: 88.68
#
# wheezy-copper-turtle-magic 58
#
# Fold 1
#
# -----Train----------
# AUC: 91.12 Precision: 89.85 Recall: 91.71
#
# -----Validation-----
# AUC: 83.27 Precision: 83.33 Recall: 81.63
#
# Fold 2
#
# -----Train----------
# AUC: 93.40 Precision: 91.09 Recall: 95.34
#
# -----Validation-----
# AUC: 84.37 Precision: 82.35 Recall: 85.71
#
# Fold 3
#
# -----Train----------
# AUC: 95.61 Precision: 94.00 Recall: 96.91
#
# -----Validation-----
# AUC: 85.26 Precision: 82.35 Recall: 87.50
#
# Fold 4
#
# -----Train----------
# AUC: 93.61 Precision: 92.42 Recall: 94.33
#
# -----Validation-----
# AUC: 85.16 Precision: 83.67 Recall: 85.42
#
# Fold 5
#
# -----Train----------
# AUC: 92.66 Precision: 91.00 Recall: 93.81
#
# -----Validation-----
# AUC: 87.02 Precision: 85.71 Recall: 87.50
#
# wheezy-copper-turtle-magic 59
#
# Fold 1
#
# -----Train----------
# AUC: 88.41 Precision: 95.27 Recall: 80.90
#
# -----Validation-----
# AUC: 78.00 Precision: 91.18 Recall: 62.00
#
# Fold 2
#
# -----Train----------
# AUC: 85.90 Precision: 93.33 Recall: 77.39
#
# -----Validation-----
# AUC: 81.94 Precision: 92.11 Recall: 70.00
#
# Fold 3
#
# -----Train----------
# AUC: 87.93 Precision: 96.89 Recall: 78.39
#
# -----Validation-----
# AUC: 83.94 Precision: 92.50 Recall: 74.00
#
# Fold 4
#
# -----Train----------
# AUC: 89.19 Precision: 98.75 Recall: 79.40
#
# -----Validation-----
# AUC: 74.84 Precision: 80.49 Recall: 66.00
#
# Fold 5
#
# -----Train----------
# AUC: 88.48 Precision: 96.95 Recall: 79.50
#
# -----Validation-----
# AUC: 83.67 Precision: 92.31 Recall: 73.47
#
# wheezy-copper-turtle-magic 60
#
# Fold 1
#
# -----Train----------
# AUC: 88.13 Precision: 84.85 Recall: 93.33
#
# -----Validation-----
# AUC: 91.44 Precision: 92.31 Recall: 90.57
#
# Fold 2
#
# -----Train----------
# AUC: 90.76 Precision: 86.13 Recall: 97.62
#
# -----Validation-----
# AUC: 82.78 Precision: 78.69 Recall: 90.57
#
# Fold 3
#
# -----Train----------
# AUC: 92.02 Precision: 88.65 Recall: 96.67
#
# -----Validation-----
# AUC: 80.73 Precision: 80.00 Recall: 83.02
#
# Fold 4
#
# -----Train----------
# AUC: 89.60 Precision: 85.00 Recall: 96.68
#
# -----Validation-----
# AUC: 86.33 Precision: 81.67 Recall: 94.23
#
# Fold 5
#
# -----Train----------
# AUC: 90.86 Precision: 89.14 Recall: 93.36
#
# -----Validation-----
# AUC: 77.55 Precision: 72.31 Recall: 90.38
#
# wheezy-copper-turtle-magic 61
#
# Fold 1
#
# -----Train----------
# AUC: 91.62 Precision: 89.70 Recall: 94.57
#
# -----Validation-----
# AUC: 87.20 Precision: 85.00 Recall: 91.07
#
# Fold 2
#
# -----Train----------
# AUC: 90.96 Precision: 89.22 Recall: 93.67
#
# -----Validation-----
# AUC: 87.89 Precision: 84.13 Recall: 94.64
#
# Fold 3
#
# -----Train----------
# AUC: 92.63 Precision: 92.41 Recall: 93.24
#
# -----Validation-----
# AUC: 79.35 Precision: 73.24 Recall: 94.55
#
# Fold 4
#
# -----Train----------
# AUC: 91.92 Precision: 90.83 Recall: 93.69
#
# -----Validation-----
# AUC: 85.11 Precision: 83.05 Recall: 89.09
#
# Fold 5
#
# -----Train----------
# AUC: 94.00 Precision: 93.36 Recall: 95.05
#
# -----Validation-----
# AUC: 86.09 Precision: 85.71 Recall: 87.27
#
# wheezy-copper-turtle-magic 62
#
# Fold 1
#
# -----Train----------
# AUC: 92.41 Precision: 94.12 Recall: 89.80
#
# -----Validation-----
# AUC: 92.64 Precision: 88.89 Recall: 96.00
#
# Fold 2
#
# -----Train----------
# AUC: 91.81 Precision: 91.79 Recall: 90.86
#
# -----Validation-----
# AUC: 86.35 Precision: 88.89 Recall: 81.63
#
# Fold 3
#
# -----Train----------
# AUC: 90.22 Precision: 92.90 Recall: 86.29
#
# -----Validation-----
# AUC: 82.19 Precision: 87.80 Recall: 73.47
#
# Fold 4
#
# -----Train----------
# AUC: 93.21 Precision: 94.24 Recall: 91.37
#
# -----Validation-----
# AUC: 77.76 Precision: 77.08 Recall: 75.51
#
# Fold 5
#
# -----Train----------
# AUC: 93.91 Precision: 95.26 Recall: 91.88
#
# -----Validation-----
# AUC: 79.24 Precision: 85.00 Recall: 69.39
#
# wheezy-copper-turtle-magic 63
#
# Fold 1
#
# -----Train----------
# AUC: 89.12 Precision: 88.55 Recall: 91.36
#
# -----Validation-----
# AUC: 84.75 Precision: 84.48 Recall: 87.50
#
# Fold 2
#
# -----Train----------
# AUC: 89.31 Precision: 87.98 Recall: 92.76
#
# -----Validation-----
# AUC: 82.64 Precision: 81.36 Recall: 87.27
#
# Fold 3
#
# -----Train----------
# AUC: 90.39 Precision: 87.60 Recall: 95.93
#
# -----Validation-----
# AUC: 77.09 Precision: 78.18 Recall: 78.18
#
# Fold 4
#
# -----Train----------
# AUC: 91.76 Precision: 90.48 Recall: 94.57
#
# -----Validation-----
# AUC: 82.63 Precision: 83.64 Recall: 83.64
#
# Fold 5
#
# -----Train----------
# AUC: 90.37 Precision: 89.87 Recall: 92.31
#
# -----Validation-----
# AUC: 84.34 Precision: 83.05 Recall: 89.09
#
# wheezy-copper-turtle-magic 64
#
# Fold 1
#
# -----Train----------
# AUC: 91.42 Precision: 89.95 Recall: 92.92
#
# -----Validation-----
# AUC: 89.88 Precision: 92.16 Recall: 87.04
#
# Fold 2
#
# -----Train----------
# AUC: 92.12 Precision: 91.24 Recall: 92.96
#
# -----Validation-----
# AUC: 87.03 Precision: 86.79 Recall: 86.79
#
# Fold 3
#
# -----Train----------
# AUC: 91.18 Precision: 91.47 Recall: 90.61
#
# -----Validation-----
# AUC: 85.25 Precision: 82.46 Recall: 88.68
#
# Fold 4
#
# -----Train----------
# AUC: 90.30 Precision: 88.69 Recall: 92.02
#
# -----Validation-----
# AUC: 87.84 Precision: 88.46 Recall: 86.79
#
# Fold 5
#
# -----Train----------
# AUC: 94.45 Precision: 93.95 Recall: 94.84
#
# -----Validation-----
# AUC: 79.44 Precision: 79.25 Recall: 79.25
#
# wheezy-copper-turtle-magic 65
#
# Fold 1
#
# -----Train----------
# AUC: 92.09 Precision: 96.09 Recall: 87.31
#
# -----Validation-----
# AUC: 84.11 Precision: 97.22 Recall: 70.00
#
# Fold 2
#
# -----Train----------
# AUC: 92.60 Precision: 96.13 Recall: 88.32
#
# -----Validation-----
# AUC: 83.86 Precision: 83.67 Recall: 82.00
#
# Fold 3
#
# -----Train----------
# AUC: 91.99 Precision: 94.12 Recall: 88.89
#
# -----Validation-----
# AUC: 85.59 Precision: 85.42 Recall: 83.67
#
# Fold 4
#
# -----Train----------
# AUC: 91.29 Precision: 93.09 Recall: 88.38
#
# -----Validation-----
# AUC: 81.38 Precision: 85.71 Recall: 73.47
#
# Fold 5
#
# -----Train----------
# AUC: 91.80 Precision: 93.16 Recall: 89.39
#
# -----Validation-----
# AUC: 88.01 Precision: 95.12 Recall: 79.59
#
# wheezy-copper-turtle-magic 66
#
# Fold 1
#
# -----Train----------
# AUC: 90.47 Precision: 92.02 Recall: 88.27
#
# -----Validation-----
# AUC: 86.07 Precision: 87.23 Recall: 83.67
#
# Fold 2
#
# -----Train----------
# AUC: 93.77 Precision: 93.40 Recall: 93.88
#
# -----Validation-----
# AUC: 81.14 Precision: 81.25 Recall: 79.59
#
# Fold 3
#
# -----Train----------
# AUC: 91.99 Precision: 93.62 Recall: 89.80
#
# -----Validation-----
# ...
# AUC: 89.97 Precision: 89.43 Recall: 92.44
#
# -----Validation-----
# AUC: 81.41 Precision: 88.00 Recall: 74.58
#
# wheezy-copper-turtle-magic 490
#
# Fold 1
#
# -----Train----------
# AUC: 91.13 Precision: 90.76 Recall: 90.76
#
# -----Validation-----
# AUC: 83.73 Precision: 81.63 Recall: 85.11
#
# Fold 2
#
# -----Train----------
# AUC: 92.03 Precision: 90.10 Recall: 93.51
#
# -----Validation-----
# AUC: 83.74 Precision: 76.79 Recall: 93.48
#
# Fold 3
#
# -----Train----------
# AUC: 91.24 Precision: 89.53 Recall: 92.43
#
# -----Validation-----
# AUC: 88.39 Precision: 90.70 Recall: 84.78
#
# Fold 4
#
# -----Train----------
# AUC: 91.76 Precision: 90.05 Recall: 92.97
#
# -----Validation-----
# AUC: 82.22 Precision: 82.22 Recall: 80.43
#
# Fold 5
#
# -----Train----------
# AUC: 91.28 Precision: 88.72 Recall: 93.51
#
# -----Validation-----
# AUC: 80.22 Precision: 78.72 Recall: 80.43
#
# wheezy-copper-turtle-magic 491
#
# Fold 1
#
# -----Train----------
# AUC: 89.94 Precision: 91.28 Recall: 88.56
#
# -----Validation-----
# AUC: 77.21 Precision: 85.00 Recall: 66.67
#
# Fold 2
#
# -----Train----------
# AUC: 91.71 Precision: 93.30 Recall: 90.05
#
# -----Validation-----
# AUC: 71.09 Precision: 73.91 Recall: 66.67
#
# Fold 3
#
# -----Train----------
# AUC: 90.24 Precision: 92.67 Recall: 87.62
#
# -----Validation-----
# AUC: 84.84 Precision: 84.31 Recall: 86.00
#
# Fold 4
#
# -----Train----------
# AUC: 90.98 Precision: 92.35 Recall: 89.60
#
# -----Validation-----
# AUC: 82.84 Precision: 83.67 Recall: 82.00
#
# Fold 5
#
# -----Train----------
# AUC: 88.72 Precision: 90.26 Recall: 87.13
#
# -----Validation-----
# AUC: 88.88 Precision: 88.24 Recall: 90.00
#
# wheezy-copper-turtle-magic 492
#
# Fold 1
#
# -----Train----------
# AUC: 92.48 Precision: 91.83 Recall: 92.72
#
# -----Validation-----
# AUC: 81.29 Precision: 80.77 Recall: 80.77
#
# Fold 2
#
# -----Train----------
# AUC: 90.95 Precision: 93.75 Recall: 87.38
#
# -----Validation-----
# AUC: 83.92 Precision: 88.89 Recall: 76.92
#
# Fold 3
#
# -----Train----------
# AUC: 89.54 Precision: 92.19 Recall: 85.92
#
# -----Validation-----
# AUC: 83.06 Precision: 85.42 Recall: 78.85
#
# Fold 4
#
# -----Train----------
# AUC: 92.16 Precision: 94.85 Recall: 88.89
#
# -----Validation-----
# AUC: 76.20 Precision: 78.26 Recall: 70.59
#
# Fold 5
#
# -----Train----------
# AUC: 89.80 Precision: 93.16 Recall: 85.51
#
# -----Validation-----
# AUC: 85.46 Precision: 92.86 Recall: 76.47
#
# wheezy-copper-turtle-magic 493
#
# Fold 1
#
# -----Train----------
# AUC: 93.71 Precision: 95.17 Recall: 92.49
#
# -----Validation-----
# AUC: 92.44 Precision: 96.00 Recall: 88.89
#
# Fold 2
#
# -----Train----------
# AUC: 95.31 Precision: 94.50 Recall: 96.71
#
# -----Validation-----
# AUC: 81.52 Precision: 79.66 Recall: 87.04
#
# Fold 3
#
# -----Train----------
# AUC: 93.14 Precision: 92.27 Recall: 94.86
#
# -----Validation-----
# AUC: 89.01 Precision: 86.21 Recall: 94.34
#
# Fold 4
#
# -----Train----------
# AUC: 93.88 Precision: 93.15 Recall: 95.33
#
# -----Validation-----
# AUC: 90.97 Precision: 87.93 Recall: 96.23
#
# Fold 5
#
# -----Train----------
# AUC: 93.50 Precision: 95.17 Recall: 92.06
#
# -----Validation-----
# AUC: 82.40 Precision: 84.31 Recall: 81.13
#
# wheezy-copper-turtle-magic 494
#
# Fold 1
#
# -----Train----------
# AUC: 91.30 Precision: 90.32 Recall: 92.45
#
# -----Validation-----
# AUC: 81.36 Precision: 77.97 Recall: 86.79
#
# Fold 2
#
# -----Train----------
# AUC: 92.47 Precision: 92.86 Recall: 91.98
#
# -----Validation-----
# AUC: 84.14 Precision: 82.14 Recall: 86.79
#
# Fold 3
#
# -----Train----------
# AUC: 92.49 Precision: 91.28 Recall: 93.87
#
# -----Validation-----
# AUC: 83.96 Precision: 86.00 Recall: 81.13
#
# Fold 4
#
# -----Train----------
# AUC: 92.24 Precision: 95.43 Recall: 88.68
#
# -----Validation-----
# AUC: 82.08 Precision: 81.48 Recall: 83.02
#
# Fold 5
#
# -----Train----------
# AUC: 91.09 Precision: 89.91 Recall: 92.45
#
# -----Validation-----
# AUC: 80.19 Precision: 80.77 Recall: 79.25
#
# wheezy-copper-turtle-magic 495
#
# Fold 1
#
# -----Train----------
# AUC: 90.44 Precision: 91.00 Recall: 89.22
#
# -----Validation-----
# AUC: 80.01 Precision: 78.85 Recall: 80.39
#
# Fold 2
#
# -----Train----------
# AUC: 89.01 Precision: 89.50 Recall: 87.75
#
# -----Validation-----
# AUC: 90.41 Precision: 91.84 Recall: 88.24
#
# Fold 3
#
# -----Train----------
# AUC: 89.96 Precision: 90.50 Recall: 88.73
#
# -----Validation-----
# AUC: 82.73 Precision: 85.11 Recall: 78.43
#
# Fold 4
#
# -----Train----------
# AUC: 91.82 Precision: 94.27 Recall: 88.73
#
# -----Validation-----
# AUC: 80.83 Precision: 82.98 Recall: 76.47
#
# Fold 5
#
# -----Train----------
# AUC: 91.63 Precision: 92.46 Recall: 90.20
#
# -----Validation-----
# AUC: 86.60 Precision: 87.76 Recall: 84.31
#
# wheezy-copper-turtle-magic 496
#
# Fold 1
#
# -----Train----------
# AUC: 91.36 Precision: 91.04 Recall: 91.50
#
# -----Validation-----
# AUC: 80.62 Precision: 78.18 Recall: 84.31
#
# Fold 2
#
# -----Train----------
# AUC: 90.13 Precision: 91.28 Recall: 88.56
#
# -----Validation-----
# AUC: 81.38 Precision: 80.39 Recall: 82.00
#
# Fold 3
#
# -----Train----------
# AUC: 90.91 Precision: 90.59 Recall: 91.04
#
# -----Validation-----
# AUC: 86.12 Precision: 87.50 Recall: 84.00
#
# Fold 4
#
# -----Train----------
# AUC: 90.86 Precision: 94.09 Recall: 87.06
#
# -----Validation-----
# AUC: 77.10 Precision: 86.49 Recall: 64.00
#
# Fold 5
#
# -----Train----------
# AUC: 90.15 Precision: 91.71 Recall: 88.06
#
# -----Validation-----
# AUC: 84.06 Precision: 92.50 Recall: 74.00
#
# wheezy-copper-turtle-magic 497
#
# Fold 1
#
# -----Train----------
# AUC: 90.71 Precision: 90.57 Recall: 91.00
#
# -----Validation-----
# AUC: 82.08 Precision: 84.00 Recall: 79.25
#
# Fold 2
#
# -----Train----------
# AUC: 91.44 Precision: 93.53 Recall: 89.10
#
# -----Validation-----
# AUC: 83.96 Precision: 89.13 Recall: 77.36
#
# Fold 3
#
# -----Train----------
# AUC: 90.98 Precision: 93.47 Recall: 88.15
#
# -----Validation-----
# AUC: 85.72 Precision: 86.54 Recall: 84.91
#
# Fold 4
#
# -----Train----------
# AUC: 90.74 Precision: 90.95 Recall: 90.52
#
# -----Validation-----
# AUC: 82.78 Precision: 78.69 Recall: 90.57
#
# Fold 5
#
# -----Train----------
# AUC: 92.18 Precision: 92.02 Recall: 92.45
#
# -----Validation-----
# AUC: 82.69 Precision: 88.64 Recall: 75.00
#
# wheezy-copper-turtle-magic 498
#
# Fold 1
#
# -----Train----------
# AUC: 90.84 Precision: 90.78 Recall: 90.78
#
# -----Validation-----
# AUC: 83.85 Precision: 80.70 Recall: 88.46
#
# Fold 2
#
# -----Train----------
# AUC: 92.04 Precision: 93.03 Recall: 90.78
#
# -----Validation-----
# AUC: 86.59 Precision: 93.18 Recall: 78.85
#
# Fold 3
#
# -----Train----------
# AUC: 90.64 Precision: 88.84 Recall: 92.72
#
# -----Validation-----
# AUC: 86.54 Precision: 81.67 Recall: 94.23
#
# Fold 4
#
# -----Train----------
# AUC: 91.37 Precision: 91.30 Recall: 91.30
#
# -----Validation-----
# AUC: 87.41 Precision: 85.19 Recall: 90.20
#
# Fold 5
#
# -----Train----------
# AUC: 93.05 Precision: 92.38 Recall: 93.72
#
# -----Validation-----
# AUC: 88.37 Precision: 86.79 Recall: 90.20
#
# wheezy-copper-turtle-magic 499
#
# Fold 1
#
# -----Train----------
# AUC: 89.71 Precision: 91.01 Recall: 87.76
#
# -----Validation-----
# AUC: 83.95 Precision: 85.11 Recall: 81.63
#
# Fold 2
#
# -----Train----------
# AUC: 90.48 Precision: 91.15 Recall: 89.29
#
# -----Validation-----
# AUC: 81.99 Precision: 81.63 Recall: 81.63
#
# Fold 3
#
# -----Train----------
# AUC: 89.76 Precision: 88.94 Recall: 90.31
#
# -----Validation-----
# AUC: 76.93 Precision: 78.26 Recall: 73.47
#
# Fold 4
#
# -----Train----------
# AUC: 89.51 Precision: 88.89 Recall: 89.80
#
# -----Validation-----
# AUC: 86.03 Precision: 84.31 Recall: 87.76
#
# Fold 5
#
# -----Train----------
# AUC: 89.02 Precision: 88.00 Recall: 89.80
#
# -----Validation-----
# AUC: 81.01 Precision: 80.00 Recall: 81.63
#
# wheezy-copper-turtle-magic 500
#
# Fold 1
#
# -----Train----------
# AUC: 90.78 Precision: 93.65 Recall: 87.62
#
# -----Validation-----
# AUC: 81.22 Precision: 83.33 Recall: 78.43
#
# Fold 2
#
# -----Train----------
# AUC: 92.78 Precision: 95.77 Recall: 89.60
#
# -----Validation-----
# AUC: 82.24 Precision: 86.67 Recall: 76.47
#
# Fold 3
#
# -----Train----------
# AUC: 91.27 Precision: 93.26 Recall: 89.11
#
# -----Validation-----
# AUC: 86.24 Precision: 95.12 Recall: 76.47
#
# Fold 4
#
# -----Train----------
# AUC: 90.60 Precision: 95.08 Recall: 85.71
#
# -----Validation-----
# AUC: 82.90 Precision: 88.37 Recall: 76.00
#
# Fold 5
#
# -----Train----------
# AUC: 89.86 Precision: 95.51 Recall: 83.74
#
# -----Validation-----
# AUC: 82.92 Precision: 90.24 Recall: 74.00
#
# wheezy-copper-turtle-magic 501
#
# Fold 1
#
# -----Train----------
# AUC: 89.74 Precision: 87.67 Recall: 95.67
#
# -----Validation-----
# AUC: 83.30 Precision: 79.37 Recall: 96.15
#
# Fold 2
#
# -----Train----------
# AUC: 90.66 Precision: 89.19 Recall: 95.19
#
# -----Validation-----
# AUC: 82.87 Precision: 82.14 Recall: 88.46
#
# Fold 3
#
# -----Train----------
# AUC: 87.87 Precision: 87.21 Recall: 91.83
#
# -----Validation-----
# AUC: 84.53 Precision: 82.76 Recall: 92.31
#
# Fold 4
#
# -----Train----------
# AUC: 90.17 Precision: 88.74 Recall: 94.71
#
# -----Validation-----
# AUC: 76.03 Precision: 75.86 Recall: 84.62
#
# Fold 5
#
# -----Train----------
# AUC: 89.07 Precision: 87.50 Recall: 94.23
#
# -----Validation-----
# AUC: 81.84 Precision: 83.02 Recall: 84.62
#
# wheezy-copper-turtle-magic 502
#
# Fold 1
#
# -----Train----------
# AUC: 92.36 Precision: 91.04 Recall: 93.69
#
# -----Validation-----
# AUC: 86.89 Precision: 82.76 Recall: 92.31
#
# Fold 2
#
# -----Train----------
# AUC: 93.78 Precision: 94.55 Recall: 92.72
#
# -----Validation-----
# AUC: 88.59 Precision: 87.04 Recall: 90.38
#
# Fold 3
#
# -----Train----------
# AUC: 93.80 Precision: 93.27 Recall: 94.17
#
# -----Validation-----
# AUC: 83.74 Precision: 88.89 Recall: 76.92
#
# Fold 4
#
# -----Train----------
# AUC: 93.59 Precision: 92.45 Recall: 94.69
#
# -----Validation-----
# AUC: 87.66 Precision: 81.67 Recall: 96.08
#
# Fold 5
#
# -----Train----------
# AUC: 92.64 Precision: 91.12 Recall: 94.20
#
# -----Validation-----
# AUC: 87.59 Precision: 83.93 Recall: 92.16
#
# wheezy-copper-turtle-magic 503
#
# Fold 1
#
# -----Train----------
# AUC: 92.12 Precision: 95.93 Recall: 87.77
#
# -----Validation-----
# AUC: 84.42 Precision: 97.14 Recall: 70.83
#
# Fold 2
#
# -----Train----------
# AUC: 91.94 Precision: 93.41 Recall: 89.95
#
# -----Validation-----
# AUC: 81.17 Precision: 87.18 Recall: 72.34
#
# Fold 3
#
# -----Train----------
# AUC: 90.87 Precision: 93.75 Recall: 87.30
#
# -----Validation-----
# AUC: 87.36 Precision: 94.87 Recall: 78.72
#
# Fold 4
#
# -----Train----------
# AUC: 88.55 Precision: 91.91 Recall: 84.13
#
# -----Validation-----
# AUC: 89.62 Precision: 87.76 Recall: 91.49
#
# Fold 5
#
# -----Train----------
# AUC: 90.87 Precision: 94.25 Recall: 86.77
#
# -----Validation-----
# AUC: 84.30 Precision: 86.36 Recall: 80.85
#
# wheezy-copper-turtle-magic 504
#
# Fold 1
#
# -----Train----------
# AUC: 92.28 Precision: 91.55 Recall: 93.75
#
# -----Validation-----
# AUC: 85.11 Precision: 84.91 Recall: 86.54
#
# Fold 2
#
# -----Train----------
# AUC: 93.81 Precision: 94.20 Recall: 93.75
#
# -----Validation-----
# AUC: 89.13 Precision: 90.20 Recall: 88.46
#
# Fold 3
#
# -----Train----------
# AUC: 91.77 Precision: 90.70 Recall: 93.75
#
# -----Validation-----
# AUC: 88.17 Precision: 90.00 Recall: 86.54
#
# Fold 4
#
# -----Train----------
# AUC: 93.57 Precision: 94.17 Recall: 93.27
#
# -----Validation-----
# AUC: 80.12 Precision: 79.63 Recall: 82.69
#
# Fold 5
#
# -----Train----------
# AUC: 91.53 Precision: 90.65 Recall: 93.27
#
# -----Validation-----
# AUC: 86.19 Precision: 88.00 Recall: 84.62
#
# wheezy-copper-turtle-magic 505
#
# Fold 1
#
# -----Train----------
# AUC: 90.52 Precision: 89.42 Recall: 91.63
#
# -----Validation-----
# AUC: 87.44 Precision: 89.58 Recall: 84.31
#
# Fold 2
#
# -----Train----------
# AUC: 91.96 Precision: 93.37 Recall: 90.15
#
# -----Validation-----
# AUC: 75.70 Precision: 77.08 Recall: 72.55
#
# Fold 3
#
# -----Train----------
# AUC: 92.00 Precision: 91.26 Recall: 92.61
#
# -----Validation-----
# AUC: 84.39 Precision: 90.70 Recall: 76.47
#
# Fold 4
#
# -----Train----------
# AUC: 92.93 Precision: 94.85 Recall: 90.64
#
# -----Validation-----
# AUC: 80.54 Precision: 82.98 Recall: 76.47
#
# Fold 5
#
# -----Train----------
# AUC: 92.51 Precision: 91.39 Recall: 93.63
#
# -----Validation-----
# AUC: 81.46 Precision: 78.18 Recall: 86.00
#
# wheezy-copper-turtle-magic 506
#
# Fold 1
#
# -----Train----------
# AUC: 91.29 Precision: 91.87 Recall: 90.57
#
# -----Validation-----
# AUC: 87.04 Precision: 85.71 Recall: 88.89
#
# Fold 2
#
# -----Train----------
# AUC: 92.72 Precision: 91.36 Recall: 94.37
#
# -----Validation-----
# AUC: 86.98 Precision: 81.97 Recall: 94.34
#
# Fold 3
#
# -----Train----------
# AUC: 91.80 Precision: 92.38 Recall: 91.08
#
# -----Validation-----
# AUC: 86.79 Precision: 85.45 Recall: 88.68
#
# Fold 4
#
# -----Train----------
# AUC: 89.46 Precision: 89.62 Recall: 89.20
#
# -----Validation-----
# AUC: 86.79 Precision: 85.45 Recall: 88.68
#
# Fold 5
#
# -----Train----------
# AUC: 90.40 Precision: 88.39 Recall: 92.96
#
# -----Validation-----
# AUC: 86.79 Precision: 84.21 Recall: 90.57
#
# wheezy-copper-turtle-magic 507
#
# Fold 1
#
# -----Train----------
# AUC: 89.77 Precision: 90.62 Recall: 87.88
#
# -----Validation-----
# AUC: 87.73 Precision: 84.91 Recall: 90.00
#
# Fold 2
#
# -----Train----------
# AUC: 92.07 Precision: 96.11 Recall: 87.37
#
# -----Validation-----
# AUC: 79.37 Precision: 87.18 Recall: 68.00
#
# Fold 3
#
# -----Train----------
# AUC: 91.24 Precision: 92.19 Recall: 89.39
#
# -----Validation-----
# AUC: 79.67 Precision: 80.85 Recall: 76.00
#
# Fold 4
#
# -----Train----------
# AUC: 90.95 Precision: 88.52 Recall: 92.96
#
# -----Validation-----
# AUC: 80.73 Precision: 77.36 Recall: 83.67
#
# Fold 5
#
# -----Train----------
# AUC: 90.37 Precision: 89.95 Recall: 89.95
#
# -----Validation-----
# AUC: 83.69 Precision: 79.63 Recall: 87.76
#
# wheezy-copper-turtle-magic 508
#
# Fold 1
#
# -----Train----------
# AUC: 83.65 Precision: 84.65 Recall: 82.21
#
# -----Validation-----
# AUC: 76.42 Precision: 83.33 Recall: 66.04
#
# Fold 2
#
# -----Train----------
# AUC: 86.60 Precision: 88.06 Recall: 84.69
#
# -----Validation-----
# AUC: 83.65 Precision: 87.23 Recall: 78.85
#
# Fold 3
#
# -----Train----------
# AUC: 86.12 Precision: 88.32 Recall: 83.25
#
# -----Validation-----
# AUC: 80.77 Precision: 84.78 Recall: 75.00
#
# Fold 4
#
# -----Train----------
# AUC: 85.17 Precision: 88.08 Recall: 81.34
#
# -----Validation-----
# AUC: 75.96 Precision: 77.55 Recall: 73.08
#
# Fold 5
#
# -----Train----------
# AUC: 87.08 Precision: 90.16 Recall: 83.25
#
# -----Validation-----
# AUC: 75.00 Precision: 75.00 Recall: 75.00
#
# wheezy-copper-turtle-magic 509
#
# Fold 1
#
# -----Train----------
# AUC: 92.24 Precision: 92.31 Recall: 91.84
#
# -----Validation-----
# AUC: 78.14 Precision: 83.33 Recall: 70.00
#
# Fold 2
#
# -----Train----------
# AUC: 89.45 Precision: 92.82 Recall: 85.28
#
# -----Validation-----
# AUC: 83.91 Precision: 86.67 Recall: 79.59
#
# Fold 3
#
# -----Train----------
# AUC: 89.23 Precision: 90.96 Recall: 86.80
#
# -----Validation-----
# AUC: 88.90 Precision: 93.18 Recall: 83.67
#
# Fold 4
#
# -----Train----------
# AUC: 91.24 Precision: 92.63 Recall: 89.34
#
# -----Validation-----
# AUC: 83.91 Precision: 86.67 Recall: 79.59
#
# Fold 5
#
# -----Train----------
# AUC: 88.98 Precision: 90.91 Recall: 86.29
#
# -----Validation-----
# AUC: 82.93 Precision: 84.78 Recall: 79.59
#
# wheezy-copper-turtle-magic 510
#
# Fold 1
#
# -----Train----------
# AUC: 91.24 Precision: 91.04 Recall: 91.04
#
# -----Validation-----
# AUC: 82.54 Precision: 88.37 Recall: 74.51
#
# Fold 2
#
# -----Train----------
# AUC: 90.96 Precision: 92.27 Recall: 89.05
#
# -----Validation-----
# AUC: 84.57 Precision: 85.71 Recall: 82.35
#
# Fold 3
#
# -----Train----------
# AUC: 90.51 Precision: 91.37 Recall: 89.11
#
# -----Validation-----
# AUC: 88.40 Precision: 86.54 Recall: 90.00
#
# Fold 4
#
# -----Train----------
# AUC: 91.22 Precision: 93.68 Recall: 88.12
#
# -----Validation-----
# AUC: 89.23 Precision: 88.24 Recall: 90.00
#
# Fold 5
#
# -----Train----------
# AUC: 92.70 Precision: 93.88 Recall: 91.09
#
# -----Validation-----
# AUC: 75.31 Precision: 80.49 Recall: 66.00
#
# wheezy-copper-turtle-magic 511
#
# Fold 1
#
# -----Train----------
# AUC: 88.18 Precision: 86.30 Recall: 91.75
#
# -----Validation-----
# AUC: 85.11 Precision: 84.91 Recall: 86.54
#
# Fold 2
#
# -----Train----------
# AUC: 89.71 Precision: 88.37 Recall: 92.23
#
# -----Validation-----
# AUC: 89.91 Precision: 86.21 Recall: 96.15
#
# Fold 3
#
# -----Train----------
# AUC: 87.95 Precision: 86.57 Recall: 90.78
#
# -----Validation-----
# AUC: 81.81 Precision: 76.56 Recall: 94.23
#
# Fold 4
#
# -----Train----------
# AUC: 89.91 Precision: 87.11 Recall: 94.69
#
# -----Validation-----
# AUC: 79.99 Precision: 80.39 Recall: 80.39
#
# Fold 5
#
# -----Train----------
# AUC: 90.72 Precision: 88.64 Recall: 94.20
#
# -----Validation-----
# AUC: 78.80 Precision: 80.00 Recall: 78.43

# %% [markdown]
# ## MLP

# %%
# INITIALIZE VARIABLES
test['target_mlp'] = 0
train['preds_mlp'] = 0

# BUILD 512 MODELS
for i in range(512):
    print('wheezy-copper-turtle-magic {}\n'.format(i))
    
    # EXTRACT SUBSET OF DATASET WHERE WHEEZY-MAGIC EQUALS I
    train2 = train[train['wheezy-copper-turtle-magic']==i]
    test2 = test[test['wheezy-copper-turtle-magic']==i]
    idx1 = train2.index
    idx2 = test2.index
    train2.reset_index(drop=True, inplace=True)
    
    # FEATURE SELECTION (USE APPROX 40 OF 255 FEATURES)
    sel = VarianceThreshold(threshold=1.5).fit(train2[cols])
    train3 = sel.transform(train2[cols])
    test3 = sel.transform(test2[cols])

    skf = StratifiedKFold(n_splits=N_FOLDS, random_state=0)
    counter = 0

    for train_index, val_index in skf.split(train3, train2['target']):
        counter += 1
        print('Fold {}\n'.format(counter))
        model = MLPClassifier()
        model.fit(train3[train_index,:], train2.loc[train_index]['target'])
        
        train_predictions = model.predict(train3[train_index,:])
        val_predictions = model.predict(train3[val_index,:])

        train_auc = roc_auc_score(train2.loc[train_index]['target'], train_predictions) * 100
        val_auc = roc_auc_score(train2.loc[val_index]['target'], val_predictions) * 100
        train_precision = precision_score(train2.loc[train_index]['target'], train_predictions) * 100
        val_precision = precision_score(train2.loc[val_index]['target'], val_predictions) * 100
        train_recall = recall_score(train2.loc[train_index]['target'], train_predictions) * 100
        val_recall = recall_score(train2.loc[val_index]['target'], val_predictions) * 100
        print('-----Train----------')
        print('AUC: %.2f Precision: %.2f Recall: %.2f \n' % (train_auc, train_precision, train_recall))
        print('-----Validation-----')
        print('AUC: %.2f Precision: %.2f Recall: %.2f \n' % (val_auc, val_precision, val_recall))

        # Make predictions
        train['preds_mlp'].loc[idx1] += model.predict_proba(train3)[:,1] / N_FOLDS
        test['target_mlp'].loc[idx2] += model.predict_proba(test3)[:,1] / N_FOLDS
# Out:
# wheezy-copper-turtle-magic 0
#
# Fold 1
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 84.31 Precision: 82.14 Recall: 86.79
#
# Fold 2
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 82.27 Precision: 80.36 Recall: 84.91
#
# Fold 3
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 81.36 Precision: 77.97 Recall: 86.79
#
# Fold 4
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 79.27 Precision: 77.78 Recall: 80.77
#
# Fold 5
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 79.34 Precision: 75.86 Recall: 84.62
#
# wheezy-copper-turtle-magic 1
#
# Fold 1
#
# -----Train----------
# AUC: 99.76 Precision: 99.49 Recall: 100.00
#
# -----Validation-----
# AUC: 84.62 Precision: 80.36 Recall: 90.00
#
# Fold 2
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 86.25 Precision: 85.71 Recall: 85.71
#
# Fold 3
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 81.15 Precision: 84.09 Recall: 75.51
#
# Fold 4
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 88.29 Precision: 86.27 Recall: 89.80
#
# Fold 5
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 84.03 Precision: 86.67 Recall: 79.59
#
# wheezy-copper-turtle-magic 2
#
# Fold 1
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 82.97 Precision: 83.33 Recall: 81.63
#
# Fold 2
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 81.95 Precision: 82.98 Recall: 79.59
#
# Fold 3
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 77.86 Precision: 73.68 Recall: 85.71
#
# Fold 4
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 83.54 Precision: 88.10 Recall: 77.08
#
# Fold 5
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 90.83 Precision: 89.80 Recall: 91.67
#
# wheezy-copper-turtle-magic 3
#
# Fold 1
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 85.37 Precision: 87.27 Recall: 84.21
#
# Fold 2
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 87.91 Precision: 87.72 Recall: 89.29
#
# Fold 3
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 80.92 Precision: 78.12 Recall: 89.29
#
# Fold 4
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 78.85 Precision: 85.11 Recall: 71.43
#
# Fold 5
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 88.59 Precision: 86.67 Recall: 92.86
#
# wheezy-copper-turtle-magic 4
#
# Fold 1
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 82.83 Precision: 88.89 Recall: 75.47
#
# Fold 2
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 85.46 Precision: 87.76 Recall: 82.69
#
# Fold 3
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 80.56 Precision: 79.63 Recall: 82.69
#
# Fold 4
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 86.35 Precision: 82.76 Recall: 92.31
#
# Fold 5
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 81.54 Precision: 81.13 Recall: 82.69
#
# wheezy-copper-turtle-magic 5
#
# Fold 1
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 82.93 Precision: 78.33 Recall: 90.38
#
# Fold 2
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 82.89 Precision: 80.36 Recall: 86.54
#
# Fold 3
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 78.85 Precision: 77.78 Recall: 80.77
#
# Fold 4
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 78.85 Precision: 77.78 Recall: 80.77
#
# Fold 5
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 82.50 Precision: 83.67 Recall: 80.39
#
# wheezy-copper-turtle-magic 6
#
# Fold 1
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 90.42 Precision: 92.16 Recall: 88.68
#
# Fold 2
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 80.80 Precision: 82.35 Recall: 79.25
#
# Fold 3
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 83.63 Precision: 83.33 Recall: 84.91
#
# Fold 4
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 84.51 Precision: 86.27 Recall: 83.02
#
# Fold 5
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 84.34 Precision: 82.46 Recall: 88.68
#
# wheezy-copper-turtle-magic 7
#
# Fold 1
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 82.35 Precision: 78.95 Recall: 88.24
#
# Fold 2
#
# -----Train----------
# AUC: 99.75 Precision: 100.00 Recall: 99.51
#
# -----Validation-----
# AUC: 73.53 Precision: 76.09 Recall: 68.63
#
# Fold 3
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 80.22 Precision: 81.63 Recall: 78.43
#
# Fold 4
#
# -----Train----------
# AUC: 99.75 Precision: 100.00 Recall: 99.51
#
# -----Validation-----
# AUC: 82.18 Precision: 82.35 Recall: 82.35
#
# Fold 5
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 75.00 Precision: 71.93 Recall: 82.00
#
# wheezy-copper-turtle-magic 8
#
# Fold 1
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 83.01 Precision: 87.50 Recall: 77.78
#
# Fold 2
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 87.53 Precision: 85.96 Recall: 90.74
#
# Fold 3
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 74.92 Precision: 73.68 Recall: 79.25
#
# Fold 4
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 84.72 Precision: 89.36 Recall: 79.25
#
# Fold 5
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 86.42 Precision: 83.05 Recall: 92.45
#
# wheezy-copper-turtle-magic 9
#
# Fold 1
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 81.13 Precision: 85.11 Recall: 75.47
#
# Fold 2
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 78.30 Precision: 80.00 Recall: 75.47
#
# Fold 3
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 90.57 Precision: 90.57 Recall: 90.57
#
# Fold 4
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 81.13 Precision: 82.35 Recall: 79.25
#
# Fold 5
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 76.92 Precision: 75.00 Recall: 80.77
#
# wheezy-copper-turtle-magic 10
#
# Fold 1
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 87.14 Precision: 86.27 Recall: 88.00
#
# Fold 2
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 81.95 Precision: 82.98 Recall: 79.59
#
# Fold 3
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 82.82 Precision: 83.33 Recall: 81.63
#
# Fold 4
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 85.90 Precision: 83.02 Recall: 89.80
#
# Fold 5
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 81.73 Precision: 87.80 Recall: 73.47
#
# wheezy-copper-turtle-magic 11
#
# Fold 1
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 81.30 Precision: 83.72 Recall: 76.60
#
# Fold 2
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 83.62 Precision: 80.39 Recall: 87.23
#
# Fold 3
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 85.30 Precision: 86.36 Recall: 82.61
#
# Fold 4
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 88.48 Precision: 88.89 Recall: 86.96
#
# Fold 5
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 84.22 Precision: 86.05 Recall: 80.43
#
# wheezy-copper-turtle-magic 12
#
# Fold 1
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 85.91 Precision: 83.64 Recall: 90.20
#
# Fold 2
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 83.84 Precision: 84.00 Recall: 84.00
#
# Fold 3
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 81.82 Precision: 82.00 Recall: 82.00
#
# Fold 4
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 77.76 Precision: 76.92 Recall: 80.00
#
# Fold 5
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 83.84 Precision: 84.00 Recall: 84.00
#
# wheezy-copper-turtle-magic 13
#
# Fold 1
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 87.55 Precision: 88.89 Recall: 85.11
#
# Fold 2
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 88.68 Precision: 87.50 Recall: 89.36
#
# Fold 3
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 85.43 Precision: 88.37 Recall: 80.85
#
# Fold 4
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 83.36 Precision: 86.05 Recall: 78.72
#
# Fold 5
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 76.30 Precision: 75.00 Recall: 76.60
#
# wheezy-copper-turtle-magic 14
#
# Fold 1
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 85.41 Precision: 88.10 Recall: 80.43
#
# Fold 2
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 90.97 Precision: 87.76 Recall: 93.48
#
# Fold 3
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 83.49 Precision: 84.09 Recall: 80.43
#
# Fold 4
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 88.30 Precision: 90.48 Recall: 84.44
#
# Fold 5
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 79.93 Precision: 80.95 Recall: 75.56
#
# wheezy-copper-turtle-magic 15
#
# Fold 1
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 91.40 Precision: 94.00 Recall: 88.68
#
# Fold 2
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 81.49 Precision: 77.97 Recall: 88.46
#
# Fold 3
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 85.41 Precision: 83.64 Recall: 88.46
#
# Fold 4
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 86.39 Precision: 85.19 Recall: 88.46
#
# Fold 5
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 81.56 Precision: 82.35 Recall: 80.77
#
# wheezy-copper-turtle-magic 16
#
# Fold 1
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 80.94 Precision: 80.39 Recall: 80.39
#
# Fold 2
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 78.74 Precision: 75.93 Recall: 82.00
#
# Fold 3
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 82.62 Precision: 79.63 Recall: 86.00
#
# Fold 4
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 86.28 Precision: 89.13 Recall: 82.00
#
# Fold 5
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 84.34 Precision: 86.96 Recall: 80.00
#
# wheezy-copper-turtle-magic 17
#
# Fold 1
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 82.34 Precision: 79.66 Recall: 88.68
#
# Fold 2
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 90.28 Precision: 90.57 Recall: 90.57
#
# Fold 3
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 81.38 Precision: 82.35 Recall: 80.77
#
# Fold 4
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 90.27 Precision: 93.75 Recall: 86.54
#
# Fold 5
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 80.24 Precision: 82.00 Recall: 78.85
#
# wheezy-copper-turtle-magic 18
#
# Fold 1
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 82.72 Precision: 84.31 Recall: 81.13
#
# Fold 2
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 88.42 Precision: 87.27 Recall: 90.57
#
# Fold 3
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 89.44 Precision: 90.38 Recall: 88.68
#
# Fold 4
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 78.74 Precision: 81.63 Recall: 75.47
#
# Fold 5
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 82.51 Precision: 83.02 Recall: 83.02
#
# wheezy-copper-turtle-magic 19
#
# Fold 1
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 83.96 Precision: 83.33 Recall: 84.91
#
# Fold 2
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 84.78 Precision: 86.27 Recall: 83.02
#
# Fold 3
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 82.89 Precision: 85.71 Recall: 79.25
#
# Fold 4
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 82.82 Precision: 80.70 Recall: 86.79
#
# Fold 5
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 82.93 Precision: 88.89 Recall: 75.47
#
# wheezy-copper-turtle-magic 20
#
# Fold 1
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 85.30 Precision: 90.70 Recall: 78.00
#
# Fold 2
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 82.48 Precision: 79.25 Recall: 85.71
#
# Fold 3
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 87.12 Precision: 89.13 Recall: 83.67
#
# Fold 4
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 81.38 Precision: 80.00 Recall: 81.63
#
# Fold 5
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 85.31 Precision: 84.00 Recall: 85.71
#
# wheezy-copper-turtle-magic 21
#
# Fold 1
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 85.99 Precision: 86.79 Recall: 85.19
#
# Fold 2
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 81.29 Precision: 80.36 Recall: 83.33
#
# Fold 3
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 86.79 Precision: 87.04 Recall: 87.04
#
# Fold 4
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 88.68 Precision: 88.89 Recall: 88.89
#
# Fold 5
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 83.08 Precision: 86.00 Recall: 79.63
#
# wheezy-copper-turtle-magic 22
#
# Fold 1
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 87.16 Precision: 90.38 Recall: 83.93
#
# Fold 2
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 86.74 Precision: 82.81 Recall: 94.64
#
# Fold 3
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 86.21 Precision: 93.48 Recall: 78.18
#
# Fold 4
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 84.93 Precision: 83.05 Recall: 89.09
#
# Fold 5
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 88.72 Precision: 87.72 Recall: 90.91
#
# wheezy-copper-turtle-magic 23
#
# Fold 1
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 86.79 Precision: 87.04 Recall: 87.04
#
# Fold 2
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 79.67 Precision: 76.67 Recall: 86.79
#
# Fold 3
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 76.99 Precision: 79.59 Recall: 73.58
#
# Fold 4
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 78.80 Precision: 78.18 Recall: 81.13
#
# Fold 5
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 79.86 Precision: 82.00 Recall: 77.36
#
# wheezy-copper-turtle-magic 24
#
# Fold 1
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 87.72 Precision: 90.70 Recall: 82.98
#
# Fold 2
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 89.50 Precision: 82.14 Recall: 97.87
#
# Fold 3
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 84.96 Precision: 82.00 Recall: 87.23
#
# Fold 4
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 83.49 Precision: 84.09 Recall: 80.43
#
# Fold 5
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 87.46 Precision: 90.48 Recall: 82.61
#
# wheezy-copper-turtle-magic 25
#
# Fold 1
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 80.81 Precision: 79.17 Recall: 80.85
#
# Fold 2
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 75.59 Precision: 75.56 Recall: 72.34
#
# Fold 3
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 85.82 Precision: 85.11 Recall: 85.11
#
# Fold 4
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 88.36 Precision: 92.68 Recall: 82.61
#
# Fold 5
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 90.75 Precision: 89.36 Recall: 91.30
#
# wheezy-copper-turtle-magic 26
#
# Fold 1
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 80.76 Precision: 80.85 Recall: 79.17
#
# Fold 2
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 83.48 Precision: 86.05 Recall: 78.72
#
# Fold 3
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 80.96 Precision: 75.00 Recall: 89.36
#
# Fold 4
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 87.62 Precision: 87.23 Recall: 87.23
#
# Fold 5
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 88.68 Precision: 87.50 Recall: 89.36
#
# wheezy-copper-turtle-magic 27
#
# Fold 1
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 77.89 Precision: 82.50 Recall: 68.75
#
# Fold 2
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 84.87 Precision: 88.37 Recall: 79.17
#
# Fold 3
#
# -----Train----------
# AUC: 99.74 Precision: 100.00 Recall: 99.47
#
# -----Validation-----
# AUC: 84.02 Precision: 84.78 Recall: 81.25
#
# Fold 4
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 80.05 Precision: 77.55 Recall: 80.85
#
# Fold 5
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 82.42 Precision: 76.36 Recall: 89.36
#
# wheezy-copper-turtle-magic 28
#
# Fold 1
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 78.70 Precision: 79.25 Recall: 77.78
#
# Fold 2
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 78.70 Precision: 75.41 Recall: 85.19
#
# Fold 3
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 85.19 Precision: 89.58 Recall: 79.63
#
# Fold 4
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 84.15 Precision: 87.76 Recall: 79.63
#
# Fold 5
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 81.13 Precision: 77.05 Recall: 88.68
#
# wheezy-copper-turtle-magic 29
#
# Fold 1
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 87.00 Precision: 93.02 Recall: 80.00
#
# Fold 2
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 82.00 Precision: 86.36 Recall: 76.00
#
# Fold 3
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 83.00 Precision: 83.67 Recall: 82.00
#
# Fold 4
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 81.78 Precision: 79.63 Recall: 86.00
#
# Fold 5
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 84.82 Precision: 83.02 Recall: 88.00
#
# wheezy-copper-turtle-magic 30
#
# Fold 1
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 85.74 Precision: 89.80 Recall: 81.48
#
# Fold 2
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 79.80 Precision: 83.67 Recall: 75.93
#
# Fold 3
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 77.38 Precision: 76.27 Recall: 83.33
#
# Fold 4
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 81.56 Precision: 83.02 Recall: 81.48
#
# Fold 5
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 88.14 Precision: 87.27 Recall: 90.57
#
# wheezy-copper-turtle-magic 31
#
# Fold 1
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 79.68 Precision: 75.86 Recall: 86.27
#
# Fold 2
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 78.38 Precision: 79.17 Recall: 76.00
#
# Fold 3
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 75.38 Precision: 77.78 Recall: 70.00
#
# Fold 4
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 77.18 Precision: 80.00 Recall: 72.00
#
# Fold 5
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 78.12 Precision: 85.00 Recall: 68.00
#
# wheezy-copper-turtle-magic 32
#
# Fold 1
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 87.55 Precision: 88.89 Recall: 85.11
#
# Fold 2
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 83.49 Precision: 82.98 Recall: 82.98
#
# Fold 3
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 83.23 Precision: 89.74 Recall: 74.47
#
# Fold 4
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 88.55 Precision: 90.91 Recall: 85.11
#
# Fold 5
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 80.97 Precision: 81.82 Recall: 78.26
#
# wheezy-copper-turtle-magic 33
#
# Fold 1
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 83.97 Precision: 84.91 Recall: 83.33
#
# Fold 2
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 83.01 Precision: 83.33 Recall: 83.33
#
# Fold 3
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 87.68 Precision: 85.96 Recall: 90.74
#
# Fold 4
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 91.44 Precision: 92.31 Recall: 90.57
#
# Fold 5
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 77.14 Precision: 77.36 Recall: 77.36
#
# wheezy-copper-turtle-magic 34
#
# Fold 1
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 84.07 Precision: 86.79 Recall: 82.14
#
# Fold 2
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 87.75 Precision: 89.09 Recall: 87.50
#
# Fold 3
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 83.43 Precision: 82.76 Recall: 87.27
#
# Fold 4
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 79.91 Precision: 82.69 Recall: 78.18
#
# Fold 5
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 84.92 Precision: 80.30 Recall: 96.36
#
# wheezy-copper-turtle-magic 35
#
# Fold 1
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 85.50 Precision: 95.12 Recall: 75.00
#
# Fold 2
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 76.50 Precision: 78.00 Recall: 75.00
#
# Fold 3
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 76.38 Precision: 75.00 Recall: 80.77
#
# Fold 4
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 77.24 Precision: 78.00 Recall: 76.47
#
# Fold 5
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 76.89 Precision: 75.00 Recall: 82.35
#
# wheezy-copper-turtle-magic 36
#
# Fold 1
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 81.44 Precision: 83.33 Recall: 76.09
#
# Fold 2
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 86.59 Precision: 88.37 Recall: 82.61
#
# Fold 3
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 79.12 Precision: 80.49 Recall: 73.33
#
# Fold 4
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 76.46 Precision: 73.91 Recall: 75.56
#
# Fold 5
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 78.82 Precision: 82.05 Recall: 71.11
#
# wheezy-copper-turtle-magic 37
#
# Fold 1
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 83.97 Precision: 84.91 Recall: 83.33
#
# Fold 2
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 86.57 Precision: 88.24 Recall: 84.91
#
# Fold 3
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 83.67 Precision: 84.62 Recall: 83.02
#
# Fold 4
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 84.65 Precision: 86.27 Recall: 83.02
#
# Fold 5
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 83.52 Precision: 80.00 Recall: 90.57
#
# wheezy-copper-turtle-magic 38
#
# Fold 1
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 86.96 Precision: 83.33 Recall: 90.00
#
# Fold 2
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 71.50 Precision: 70.83 Recall: 68.00
#
# Fold 3
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 82.54 Precision: 88.10 Recall: 74.00
#
# Fold 4
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 82.55 Precision: 86.36 Recall: 76.00
#
# Fold 5
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 82.41 Precision: 84.44 Recall: 77.55
#
# wheezy-copper-turtle-magic 39
#
# Fold 1
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 78.50 Precision: 75.93 Recall: 82.00
#
# Fold 2
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 89.15 Precision: 91.49 Recall: 86.00
#
# Fold 3
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 90.19 Precision: 90.00 Recall: 90.00
#
# Fold 4
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 91.08 Precision: 91.84 Recall: 90.00
#
# Fold 5
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 76.97 Precision: 77.08 Recall: 75.51
#
# wheezy-copper-turtle-magic 40
#
# Fold 1
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 90.00 Precision: 85.71 Recall: 96.00
#
# Fold 2
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 85.84 Precision: 87.23 Recall: 83.67
#
# Fold 3
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 75.78 Precision: 74.51 Recall: 77.55
#
# Fold 4
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 89.88 Precision: 91.49 Recall: 87.76
#
# Fold 5
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 88.78 Precision: 89.58 Recall: 87.76
#
# wheezy-copper-turtle-magic 41
#
# Fold 1
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 87.04 Precision: 91.67 Recall: 81.48
#
# Fold 2
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 87.96 Precision: 87.27 Recall: 88.89
#
# Fold 3
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 87.96 Precision: 84.75 Recall: 92.59
#
# Fold 4
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 77.78 Precision: 80.00 Recall: 74.07
#
# Fold 5
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 87.86 Precision: 88.68 Recall: 87.04
#
# wheezy-copper-turtle-magic 42
#
# Fold 1
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 83.16 Precision: 83.33 Recall: 83.33
#
# Fold 2
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 73.74 Precision: 76.74 Recall: 68.75
#
# Fold 3
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 84.04 Precision: 84.78 Recall: 82.98
#
# Fold 4
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 85.11 Precision: 81.13 Recall: 91.49
#
# Fold 5
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 89.25 Precision: 89.36 Recall: 89.36
#
# wheezy-copper-turtle-magic 43
#
# Fold 1
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 80.17 Precision: 75.86 Recall: 86.27
#
# Fold 2
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 83.77 Precision: 84.00 Recall: 82.35
#
# Fold 3
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 87.40 Precision: 91.30 Recall: 82.35
#
# Fold 4
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 82.45 Precision: 83.33 Recall: 80.00
#
# Fold 5
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 78.85 Precision: 74.14 Recall: 86.00
#
# wheezy-copper-turtle-magic 44
#
# Fold 1
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 81.64 Precision: 77.78 Recall: 92.45
#
# Fold 2
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 85.06 Precision: 85.19 Recall: 86.79
#
# Fold 3
#
# -----Train----------
# AUC: 95.08 Precision: 96.59 Recall: 93.84
#
# -----Validation-----
# AUC: 83.36 Precision: 89.13 Recall: 77.36
#
# Fold 4
#
# -----Train----------
# AUC: 96.21 Precision: 95.79 Recall: 97.16
#
# -----Validation-----
# AUC: 75.45 Precision: 81.82 Recall: 67.92
#
# Fold 5
#
# -----Train----------
# AUC: 99.74 Precision: 99.53 Recall: 100.00
#
# -----Validation-----
# AUC: 83.80 Precision: 84.62 Recall: 84.62
#
# wheezy-copper-turtle-magic 45
#
# Fold 1
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 79.67 Precision: 84.09 Recall: 72.55
#
# Fold 2
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 77.93 Precision: 75.93 Recall: 80.39
#
# Fold 3
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 81.78 Precision: 79.63 Recall: 84.31
#
# Fold 4
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 82.69 Precision: 82.35 Recall: 82.35
#
# Fold 5
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 81.78 Precision: 79.63 Recall: 84.31
#
# wheezy-copper-turtle-magic 46
#
# Fold 1
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 88.12 Precision: 88.00 Recall: 88.00
#
# Fold 2
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 80.00 Precision: 76.79 Recall: 86.00
#
# Fold 3
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 86.00 Precision: 92.86 Recall: 78.00
#
# Fold 4
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 80.00 Precision: 80.00 Recall: 80.00
#
# Fold 5
#
# -----Train----------
# AUC: 97.01 Precision: 96.08 Recall: 98.00
#
# -----Validation-----
# AUC: 82.88 Precision: 79.63 Recall: 87.76
#
# wheezy-copper-turtle-magic 47
#
# Fold 1
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 78.00 Precision: 78.57 Recall: 80.00
#
# Fold 2
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 78.89 Precision: 80.77 Recall: 77.78
#
# Fold 3
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 83.52 Precision: 82.46 Recall: 87.04
#
# Fold 4
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 83.59 Precision: 83.64 Recall: 85.19
#
# Fold 5
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 83.41 Precision: 83.64 Recall: 85.19
#
# wheezy-copper-turtle-magic 48
#
# Fold 1
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 82.31 Precision: 84.62 Recall: 80.00
#
# Fold 2
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 86.21 Precision: 93.48 Recall: 78.18
#
# Fold 3
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 85.79 Precision: 84.21 Recall: 88.89
#
# Fold 4
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 80.88 Precision: 80.36 Recall: 83.33
#
# Fold 5
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 85.68 Precision: 85.45 Recall: 87.04
#
# wheezy-copper-turtle-magic 49
#
# Fold 1
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 81.58 Precision: 79.63 Recall: 84.31
#
# Fold 2
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 82.52 Precision: 82.35 Recall: 82.35
#
# Fold 3
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 89.19 Precision: 89.80 Recall: 88.00
#
# Fold 4
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 83.27 Precision: 85.11 Recall: 80.00
#
# Fold 5
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 74.42 Precision: 76.09 Recall: 70.00
#
# wheezy-copper-turtle-magic 50
#
# Fold 1
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 83.77 Precision: 84.91 Recall: 81.82
#
# Fold 2
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 81.02 Precision: 77.05 Recall: 87.04
#
# Fold 3
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 82.77 Precision: 80.70 Recall: 85.19
#
# Fold 4
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 79.89 Precision: 83.33 Recall: 74.07
#
# Fold 5
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 81.75 Precision: 84.00 Recall: 77.78
#
# wheezy-copper-turtle-magic 51
#
# Fold 1
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 75.57 Precision: 80.85 Recall: 66.67
#
# Fold 2
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 84.21 Precision: 81.97 Recall: 87.72
#
# Fold 3
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 83.33 Precision: 79.69 Recall: 89.47
#
# Fold 4
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 84.21 Precision: 84.21 Recall: 84.21
#
# Fold 5
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 78.76 Precision: 78.57 Recall: 78.57
#
# wheezy-copper-turtle-magic 52
#
# Fold 1
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 78.38 Precision: 82.61 Recall: 73.08
#
# Fold 2
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 85.34 Precision: 91.11 Recall: 78.85
#
# Fold 3
#
# -----Train----------
# AUC: 97.02 Precision: 97.56 Recall: 96.62
#
# -----Validation-----
# AUC: 82.85 Precision: 81.82 Recall: 86.54
#
# Fold 4
#
# -----Train----------
# AUC: 95.73 Precision: 95.24 Recall: 96.62
#
# -----Validation-----
# AUC: 81.89 Precision: 81.48 Recall: 84.62
#
# Fold 5
#
# -----Train----------
# AUC: 98.23 Precision: 97.63 Recall: 99.04
#
# -----Validation-----
# AUC: 82.66 Precision: 80.36 Recall: 88.24
#
# wheezy-copper-turtle-magic 53
#
# Fold 1
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 78.04 Precision: 80.39 Recall: 77.36
#
# Fold 2
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 86.59 Precision: 85.71 Recall: 90.57
#
# Fold 3
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 84.82 Precision: 87.76 Recall: 82.69
#
# Fold 4
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 89.76 Precision: 90.38 Recall: 90.38
#
# Fold 5
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 80.60 Precision: 82.35 Recall: 80.77
#
# wheezy-copper-turtle-magic 54
#
# Fold 1
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 74.96 Precision: 80.00 Recall: 67.92
#
# Fold 2
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 88.19 Precision: 87.04 Recall: 90.38
#
# Fold 3
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 82.10 Precision: 81.48 Recall: 84.62
#
# Fold 4
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 75.08 Precision: 73.68 Recall: 80.77
#
# Fold 5
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 88.17 Precision: 90.00 Recall: 86.54
#
# wheezy-copper-turtle-magic 55
#
# Fold 1
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 85.52 Precision: 87.50 Recall: 82.35
#
# Fold 2
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 78.76 Precision: 80.85 Recall: 74.51
#
# Fold 3
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 85.48 Precision: 89.13 Recall: 80.39
#
# Fold 4
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 87.48 Precision: 88.00 Recall: 86.27
#
# Fold 5
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 83.74 Precision: 77.97 Recall: 92.00
#
# wheezy-copper-turtle-magic 56
#
# Fold 1
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 79.59 Precision: 77.97 Recall: 85.19
#
# Fold 2
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 85.37 Precision: 83.05 Recall: 90.74
#
# Fold 3
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 80.68 Precision: 83.67 Recall: 77.36
#
# Fold 4
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 83.62 Precision: 87.50 Recall: 79.25
#
# Fold 5
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 81.57 Precision: 82.69 Recall: 81.13
#
# wheezy-copper-turtle-magic 57
#
# Fold 1
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 84.52 Precision: 83.93 Recall: 87.04
#
# Fold 2
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 82.34 Precision: 79.66 Recall: 88.68
#
# Fold 3
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 85.40 Precision: 85.19 Recall: 86.79
#
# Fold 4
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 81.51 Precision: 81.48 Recall: 83.02
#
# Fold 5
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 80.52 Precision: 83.67 Recall: 77.36
#
# wheezy-copper-turtle-magic 58
#
# Fold 1
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 83.19 Precision: 84.78 Recall: 79.59
#
# Fold 2
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 85.23 Precision: 85.42 Recall: 83.67
#
# Fold 3
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 79.85 Precision: 83.33 Recall: 72.92
#
# Fold 4
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 89.13 Precision: 87.76 Recall: 89.58
#
# Fold 5
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 83.97 Precision: 83.33 Recall: 83.33
#
# wheezy-copper-turtle-magic 59
#
# Fold 1
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 86.00 Precision: 84.62 Recall: 88.00
#
# Fold 2
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 80.84 Precision: 82.98 Recall: 78.00
#
# Fold 3
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 78.80 Precision: 79.59 Recall: 78.00
#
# Fold 4
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 81.84 Precision: 83.33 Recall: 80.00
#
# Fold 5
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 77.55 Precision: 72.88 Recall: 87.76
#
# wheezy-copper-turtle-magic 60
#
# Fold 1
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 90.53 Precision: 95.74 Recall: 84.91
#
# Fold 2
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 82.82 Precision: 80.70 Recall: 86.79
#
# Fold 3
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 88.42 Precision: 87.27 Recall: 90.57
#
# Fold 4
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 89.35 Precision: 91.84 Recall: 86.54
#
# Fold 5
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 83.45 Precision: 80.70 Recall: 88.46
#
# wheezy-copper-turtle-magic 61
#
# Fold 1
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 84.59 Precision: 86.79 Recall: 82.14
#
# Fold 2
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 92.60 Precision: 91.38 Recall: 94.64
#
# Fold 3
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 87.03 Precision: 87.27 Recall: 87.27
#
# Fold 4
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 85.18 Precision: 85.45 Recall: 85.45
#
# Fold 5
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 77.84 Precision: 80.39 Recall: 74.55
#
# wheezy-copper-turtle-magic 62
#
# Fold 1
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 81.50 Precision: 75.86 Recall: 88.00
#
# Fold 2
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 81.25 Precision: 87.50 Recall: 71.43
#
# Fold 3
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 81.50 Precision: 82.61 Recall: 77.55
#
# Fold 4
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 82.97 Precision: 78.18 Recall: 87.76
#
# Fold 5
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 79.35 Precision: 83.33 Recall: 71.43
#
# wheezy-copper-turtle-magic 63
#
# Fold 1
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 76.29 Precision: 77.19 Recall: 78.57
#
# Fold 2
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 85.55 Precision: 84.48 Recall: 89.09
#
# Fold 3
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 76.36 Precision: 80.00 Recall: 72.73
#
# Fold 4
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 83.43 Precision: 82.76 Recall: 87.27
#
# Fold 5
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 80.93 Precision: 84.31 Recall: 78.18
#
# wheezy-copper-turtle-magic 64
#
# Fold 1
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 85.32 Precision: 85.19 Recall: 85.19
#
# Fold 2
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 86.05 Precision: 88.00 Recall: 83.02
#
# Fold 3
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 83.40 Precision: 80.70 Recall: 86.79
#
# Fold 4
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 91.60 Precision: 90.74 Recall: 92.45
#
# Fold 5
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 81.29 Precision: 82.35 Recall: 79.25
#
# wheezy-copper-turtle-magic 65
#
# Fold 1
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 83.75 Precision: 85.11 Recall: 80.00
#
# Fold 2
#
# ...
#
# Fold 2
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 84.30 Precision: 84.44 Recall: 82.61
#
# Fold 3
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 89.57 Precision: 89.13 Recall: 89.13
#
# Fold 4
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 78.96 Precision: 80.95 Recall: 73.91
#
# Fold 5
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 79.22 Precision: 77.08 Recall: 80.43
#
# wheezy-copper-turtle-magic 491
#
# Fold 1
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 77.05 Precision: 79.17 Recall: 74.51
#
# Fold 2
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 77.09 Precision: 80.43 Recall: 72.55
#
# Fold 3
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 77.76 Precision: 76.92 Recall: 80.00
#
# Fold 4
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 81.82 Precision: 82.00 Recall: 82.00
#
# Fold 5
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 79.73 Precision: 76.79 Recall: 86.00
#
# wheezy-copper-turtle-magic 492
#
# Fold 1
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 80.44 Precision: 78.18 Recall: 82.69
#
# Fold 2
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 83.97 Precision: 87.23 Recall: 78.85
#
# Fold 3
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 85.03 Precision: 84.62 Recall: 84.62
#
# Fold 4
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 73.62 Precision: 71.70 Recall: 74.51
#
# Fold 5
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 82.90 Precision: 81.13 Recall: 84.31
#
# wheezy-copper-turtle-magic 493
#
# Fold 1
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 84.52 Precision: 83.93 Recall: 87.04
#
# Fold 2
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 82.52 Precision: 81.03 Recall: 87.04
#
# Fold 3
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 79.98 Precision: 76.19 Recall: 90.57
#
# Fold 4
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 81.38 Precision: 82.69 Recall: 81.13
#
# Fold 5
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 90.18 Precision: 90.57 Recall: 90.57
#
# wheezy-copper-turtle-magic 494
#
# Fold 1
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 86.91 Precision: 86.79 Recall: 86.79
#
# Fold 2
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 81.31 Precision: 81.13 Recall: 81.13
#
# Fold 3
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 89.62 Precision: 88.89 Recall: 90.57
#
# Fold 4
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 83.96 Precision: 83.33 Recall: 84.91
#
# Fold 5
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 81.13 Precision: 83.67 Recall: 77.36
#
# wheezy-copper-turtle-magic 495
#
# Fold 1
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 79.08 Precision: 77.36 Recall: 80.39
#
# Fold 2
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 87.53 Precision: 89.58 Recall: 84.31
#
# Fold 3
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 80.88 Precision: 81.63 Recall: 78.43
#
# Fold 4
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 85.73 Precision: 84.62 Recall: 86.27
#
# Fold 5
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 79.90 Precision: 81.25 Recall: 76.47
#
# wheezy-copper-turtle-magic 496
#
# Fold 1
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 84.43 Precision: 87.23 Recall: 80.39
#
# Fold 2
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 83.38 Precision: 81.13 Recall: 86.00
#
# Fold 3
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 81.16 Precision: 82.98 Recall: 78.00
#
# Fold 4
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 80.18 Precision: 81.25 Recall: 78.00
#
# Fold 5
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 90.14 Precision: 87.04 Recall: 94.00
#
# wheezy-copper-turtle-magic 497
#
# Fold 1
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 77.36 Precision: 76.36 Recall: 79.25
#
# Fold 2
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 78.30 Precision: 78.85 Recall: 77.36
#
# Fold 3
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 89.50 Precision: 87.50 Recall: 92.45
#
# Fold 4
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 82.76 Precision: 77.78 Recall: 92.45
#
# Fold 5
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 75.96 Precision: 78.72 Recall: 71.15
#
# wheezy-copper-turtle-magic 498
#
# Fold 1
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 84.81 Precision: 81.03 Recall: 90.38
#
# Fold 2
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 85.65 Precision: 91.11 Recall: 78.85
#
# Fold 3
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 90.38 Precision: 87.50 Recall: 94.23
#
# Fold 4
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 83.54 Precision: 80.36 Recall: 88.24
#
# Fold 5
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 87.39 Precision: 86.54 Recall: 88.24
#
# wheezy-copper-turtle-magic 499
#
# Fold 1
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 79.83 Precision: 85.37 Recall: 71.43
#
# Fold 2
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 81.01 Precision: 80.00 Recall: 81.63
#
# Fold 3
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 79.95 Precision: 80.85 Recall: 77.55
#
# Fold 4
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 82.07 Precision: 79.25 Recall: 85.71
#
# Fold 5
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 80.97 Precision: 81.25 Recall: 79.59
#
# wheezy-copper-turtle-magic 500
#
# Fold 1
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 82.20 Precision: 83.67 Recall: 80.39
#
# Fold 2
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 80.16 Precision: 78.18 Recall: 84.31
#
# Fold 3
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 85.14 Precision: 84.62 Recall: 86.27
#
# Fold 4
#
# -----Train----------
# AUC: 99.50 Precision: 99.51 Recall: 99.51
#
# -----Validation-----
# AUC: 74.69 Precision: 72.73 Recall: 80.00
#
# Fold 5
#
# -----Train----------
# AUC: 98.76 Precision: 99.01 Recall: 98.52
#
# -----Validation-----
# AUC: 77.78 Precision: 78.00 Recall: 78.00
#
# wheezy-copper-turtle-magic 501
#
# Fold 1
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 85.14 Precision: 85.19 Recall: 88.46
#
# Fold 2
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 79.20 Precision: 82.00 Recall: 78.85
#
# Fold 3
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 87.25 Precision: 88.46 Recall: 88.46
#
# Fold 4
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 71.98 Precision: 73.21 Recall: 78.85
#
# Fold 5
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 86.29 Precision: 88.24 Recall: 86.54
#
# wheezy-copper-turtle-magic 502
#
# Fold 1
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 85.86 Precision: 84.91 Recall: 86.54
#
# Fold 2
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 80.06 Precision: 76.27 Recall: 86.54
#
# Fold 3
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 81.86 Precision: 85.11 Recall: 76.92
#
# Fold 4
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 88.49 Precision: 86.79 Recall: 90.20
#
# Fold 5
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 86.50 Precision: 87.76 Recall: 84.31
#
# wheezy-copper-turtle-magic 503
#
# Fold 1
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 84.75 Precision: 82.35 Recall: 87.50
#
# Fold 2
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 80.36 Precision: 80.43 Recall: 78.72
#
# Fold 3
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 83.43 Precision: 84.44 Recall: 80.85
#
# Fold 4
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 87.71 Precision: 80.70 Recall: 97.87
#
# Fold 5
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 78.05 Precision: 79.55 Recall: 74.47
#
# wheezy-copper-turtle-magic 504
#
# Fold 1
#
# -----Train----------
# AUC: 99.74 Precision: 99.52 Recall: 100.00
#
# -----Validation-----
# AUC: 81.02 Precision: 78.95 Recall: 86.54
#
# Fold 2
#
# -----Train----------
# AUC: 99.23 Precision: 98.58 Recall: 100.00
#
# -----Validation-----
# AUC: 81.14 Precision: 81.13 Recall: 82.69
#
# Fold 3
#
# -----Train----------
# AUC: 98.99 Precision: 98.57 Recall: 99.52
#
# -----Validation-----
# AUC: 86.30 Precision: 91.30 Recall: 80.77
#
# Fold 4
#
# -----Train----------
# AUC: 99.49 Precision: 99.05 Recall: 100.00
#
# -----Validation-----
# AUC: 77.06 Precision: 75.44 Recall: 82.69
#
# Fold 5
#
# -----Train----------
# AUC: 99.74 Precision: 99.52 Recall: 100.00
#
# -----Validation-----
# AUC: 86.24 Precision: 89.58 Recall: 82.69
#
# wheezy-copper-turtle-magic 505
#
# Fold 1
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 88.38 Precision: 91.49 Recall: 84.31
#
# Fold 2
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 76.66 Precision: 78.72 Recall: 72.55
#
# Fold 3
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 88.29 Precision: 93.33 Recall: 82.35
#
# Fold 4
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 82.56 Precision: 80.00 Recall: 86.27
#
# Fold 5
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 87.27 Precision: 86.27 Recall: 88.00
#
# wheezy-copper-turtle-magic 506
#
# Fold 1
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 81.48 Precision: 81.48 Recall: 81.48
#
# Fold 2
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 76.62 Precision: 76.92 Recall: 75.47
#
# Fold 3
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 83.02 Precision: 79.66 Recall: 88.68
#
# Fold 4
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 79.25 Precision: 77.19 Recall: 83.02
#
# Fold 5
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 82.08 Precision: 84.00 Recall: 79.25
#
# wheezy-copper-turtle-magic 507
#
# Fold 1
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 83.00 Precision: 79.63 Recall: 86.00
#
# Fold 2
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 78.59 Precision: 81.82 Recall: 72.00
#
# Fold 3
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 79.81 Precision: 78.43 Recall: 80.00
#
# Fold 4
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 77.38 Precision: 79.55 Recall: 71.43
#
# Fold 5
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 84.52 Precision: 82.35 Recall: 85.71
#
# wheezy-copper-turtle-magic 508
#
# Fold 1
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 82.08 Precision: 81.48 Recall: 83.02
#
# Fold 2
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 82.69 Precision: 81.48 Recall: 84.62
#
# Fold 3
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 81.73 Precision: 81.13 Recall: 82.69
#
# Fold 4
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 76.92 Precision: 80.43 Recall: 71.15
#
# Fold 5
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 70.19 Precision: 68.42 Recall: 75.00
#
# wheezy-copper-turtle-magic 509
#
# Fold 1
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 75.18 Precision: 79.07 Recall: 68.00
#
# Fold 2
#
# -----Train----------
# AUC: 92.94 Precision: 97.21 Recall: 88.32
#
# -----Validation-----
# AUC: 82.85 Precision: 88.10 Recall: 75.51
#
# Fold 3
#
# -----Train----------
# AUC: 87.93 Precision: 81.90 Recall: 96.45
#
# -----Validation-----
# AUC: 70.31 Precision: 64.62 Recall: 85.71
#
# Fold 4
#
# -----Train----------
# AUC: 99.50 Precision: 99.49 Recall: 99.49
#
# -----Validation-----
# AUC: 77.91 Precision: 80.00 Recall: 73.47
#
# Fold 5
#
# -----Train----------
# AUC: 99.51 Precision: 98.99 Recall: 100.00
#
# -----Validation-----
# AUC: 76.11 Precision: 72.73 Recall: 81.63
#
# wheezy-copper-turtle-magic 510
#
# Fold 1
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 78.88 Precision: 77.36 Recall: 80.39
#
# Fold 2
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 81.74 Precision: 80.77 Recall: 82.35
#
# Fold 3
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 75.74 Precision: 74.51 Recall: 76.00
#
# Fold 4
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 75.62 Precision: 71.93 Recall: 82.00
#
# Fold 5
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 81.23 Precision: 86.05 Recall: 74.00
#
# wheezy-copper-turtle-magic 511
#
# Fold 1
#
# -----Train----------
# AUC: 95.27 Precision: 95.61 Recall: 95.15
#
# -----Validation-----
# AUC: 79.04 Precision: 77.19 Recall: 84.62
#
# Fold 2
#
# -----Train----------
# AUC: 90.87 Precision: 87.28 Recall: 96.60
#
# -----Validation-----
# AUC: 71.00 Precision: 68.85 Recall: 80.77
#
# Fold 3
#
# -----Train----------
# AUC: 95.49 Precision: 95.19 Recall: 96.12
#
# -----Validation-----
# AUC: 79.89 Precision: 75.81 Recall: 90.38
#
# Fold 4
#
# -----Train----------
# AUC: 97.51 Precision: 97.58 Recall: 97.58
#
# -----Validation-----
# AUC: 83.09 Precision: 86.96 Recall: 78.43
#
# Fold 5
#
# -----Train----------
# AUC: 99.50 Precision: 99.52 Recall: 99.52
#
# -----Validation-----
# AUC: 75.92 Precision: 80.00 Recall: 70.59

# %% [markdown]
# ## SVC

# %%
# INITIALIZE VARIABLES
test['target_svc'] = 0
train['preds_svc'] = 0

# BUILD 512 MODELS
for i in range(512):
    print('wheezy-copper-turtle-magic {}\n'.format(i))
    
    # EXTRACT SUBSET OF DATASET WHERE WHEEZY-MAGIC EQUALS I
    train2 = train[train['wheezy-copper-turtle-magic']==i]
    test2 = test[test['wheezy-copper-turtle-magic']==i]
    idx1 = train2.index
    idx2 = test2.index
    train2.reset_index(drop=True, inplace=True)
    
    # FEATURE SELECTION (USE APPROX 40 OF 255 FEATURES)
    sel = VarianceThreshold(threshold=1.5).fit(train2[cols])
    train3 = sel.transform(train2[cols])
    test3 = sel.transform(test2[cols])

    skf = StratifiedKFold(n_splits=N_FOLDS, random_state=0)
    counter = 0

    for train_index, val_index in skf.split(train3, train2['target']):
        counter += 1
        print('Fold {}\n'.format(counter))
        model = SVC(probability=True,kernel='poly',degree=4,gamma='auto')
        model.fit(train3[train_index,:], train2.loc[train_index]['target'])
        
        train_predictions = model.predict(train3[train_index,:])
        val_predictions = model.predict(train3[val_index,:])

        train_auc = roc_auc_score(train2.loc[train_index]['target'], train_predictions) * 100
        val_auc = roc_auc_score(train2.loc[val_index]['target'], val_predictions) * 100
        train_precision = precision_score(train2.loc[train_index]['target'], train_predictions) * 100
        val_precision = precision_score(train2.loc[val_index]['target'], val_predictions) * 100
        train_recall = recall_score(train2.loc[train_index]['target'], train_predictions) * 100
        val_recall = recall_score(train2.loc[val_index]['target'], val_predictions) * 100
        print('-----Train----------')
        print('AUC: %.2f Precision: %.2f Recall: %.2f \n' % (train_auc, train_precision, train_recall))
        print('-----Validation-----')
        print('AUC: %.2f Precision: %.2f Recall: %.2f \n' % (val_auc, val_precision, val_recall))

        # Make predictions
        train['preds_svc'].loc[idx1] += model.predict_proba(train3)[:,1] / N_FOLDS
        test['target_svc'].loc[idx2] += model.predict_proba(test3)[:,1] / N_FOLDS
# Out:
# wheezy-copper-turtle-magic 0
#
# Fold 1
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 82.35 Precision: 84.00 Recall: 79.25
#
# Fold 2
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 83.09 Precision: 90.70 Recall: 73.58
#
# Fold 3
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 90.62 Precision: 93.88 Recall: 86.79
#
# Fold 4
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 88.64 Precision: 90.00 Recall: 86.54
#
# Fold 5
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 76.10 Precision: 88.57 Recall: 59.62
#
# wheezy-copper-turtle-magic 1
#
# Fold 1
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 82.08 Precision: 72.46 Recall: 100.00
#
# Fold 2
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 74.78 Precision: 70.18 Recall: 81.63
#
# Fold 3
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 79.09 Precision: 70.15 Recall: 95.92
#
# Fold 4
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 82.63 Precision: 77.19 Recall: 89.80
#
# Fold 5
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 71.88 Precision: 64.29 Recall: 91.84
#
# wheezy-copper-turtle-magic 2
#
# Fold 1
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 74.57 Precision: 92.86 Recall: 53.06
#
# Fold 2
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 79.75 Precision: 89.19 Recall: 67.35
#
# Fold 3
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 70.55 Precision: 79.41 Recall: 55.10
#
# Fold 4
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 77.12 Precision: 96.43 Recall: 56.25
#
# Fold 5
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 66.79 Precision: 86.36 Recall: 39.58
#
# wheezy-copper-turtle-magic 3
#
# Fold 1
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 77.97 Precision: 71.79 Recall: 98.25
#
# Fold 2
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 77.06 Precision: 71.05 Recall: 96.43
#
# Fold 3
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 72.55 Precision: 66.67 Recall: 100.00
#
# Fold 4
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 79.76 Precision: 75.36 Recall: 92.86
#
# Fold 5
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 72.99 Precision: 68.92 Recall: 91.07
#
# wheezy-copper-turtle-magic 4
#
# Fold 1
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 80.69 Precision: 78.95 Recall: 84.91
#
# Fold 2
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 84.50 Precision: 87.50 Recall: 80.77
#
# Fold 3
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 83.48 Precision: 83.02 Recall: 84.62
#
# Fold 4
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 81.47 Precision: 77.05 Recall: 90.38
#
# Fold 5
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 83.56 Precision: 88.89 Recall: 76.92
#
# wheezy-copper-turtle-magic 5
#
# Fold 1
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 79.88 Precision: 89.74 Recall: 67.31
#
# Fold 2
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 85.69 Precision: 87.76 Recall: 82.69
#
# Fold 3
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 72.12 Precision: 81.08 Recall: 57.69
#
# Fold 4
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 76.92 Precision: 91.18 Recall: 59.62
#
# Fold 5
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 84.39 Precision: 90.70 Recall: 76.47
#
# wheezy-copper-turtle-magic 6
#
# Fold 1
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 82.50 Precision: 77.78 Recall: 92.45
#
# Fold 2
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 81.63 Precision: 79.31 Recall: 86.79
#
# Fold 3
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 83.41 Precision: 77.27 Recall: 96.23
#
# Fold 4
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 77.23 Precision: 72.06 Recall: 92.45
#
# Fold 5
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 77.17 Precision: 71.43 Recall: 94.34
#
# wheezy-copper-turtle-magic 7
#
# Fold 1
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 81.37 Precision: 84.78 Recall: 76.47
#
# Fold 2
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 80.39 Precision: 75.41 Recall: 90.20
#
# Fold 3
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 79.16 Precision: 76.79 Recall: 84.31
#
# Fold 4
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 74.41 Precision: 85.71 Recall: 58.82
#
# Fold 5
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 85.00 Precision: 81.82 Recall: 90.00
#
# wheezy-copper-turtle-magic 8
#
# Fold 1
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 86.71 Precision: 88.46 Recall: 85.19
#
# Fold 2
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 88.56 Precision: 88.89 Recall: 88.89
#
# Fold 3
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 79.63 Precision: 75.81 Recall: 88.68
#
# Fold 4
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 84.46 Precision: 80.33 Recall: 92.45
#
# Fold 5
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 83.78 Precision: 89.13 Recall: 77.36
#
# wheezy-copper-turtle-magic 9
#
# Fold 1
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 77.36 Precision: 69.33 Recall: 98.11
#
# Fold 2
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 77.36 Precision: 69.86 Recall: 96.23
#
# Fold 3
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 80.19 Precision: 72.22 Recall: 98.11
#
# Fold 4
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 83.02 Precision: 79.66 Recall: 88.68
#
# Fold 5
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 79.81 Precision: 72.46 Recall: 96.15
#
# wheezy-copper-turtle-magic 10
#
# Fold 1
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 75.04 Precision: 93.10 Recall: 54.00
#
# Fold 2
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 80.65 Precision: 96.88 Recall: 63.27
#
# Fold 3
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 76.53 Precision: 100.00 Recall: 53.06
#
# Fold 4
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 70.43 Precision: 95.45 Recall: 42.86
#
# Fold 5
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 79.65 Precision: 91.43 Recall: 65.31
#
# wheezy-copper-turtle-magic 11
#
# Fold 1
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 84.74 Precision: 79.63 Recall: 91.49
#
# Fold 2
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 90.62 Precision: 93.18 Recall: 87.23
#
# Fold 3
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 78.61 Precision: 88.24 Recall: 65.22
#
# Fold 4
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 93.65 Precision: 95.45 Recall: 91.30
#
# Fold 5
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 89.57 Precision: 89.13 Recall: 89.13
#
# wheezy-copper-turtle-magic 12
#
# Fold 1
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 86.93 Precision: 85.19 Recall: 90.20
#
# Fold 2
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 84.76 Precision: 79.66 Recall: 94.00
#
# Fold 3
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 71.45 Precision: 64.47 Recall: 98.00
#
# Fold 4
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 73.53 Precision: 67.14 Recall: 94.00
#
# Fold 5
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 77.63 Precision: 71.88 Recall: 92.00
#
# wheezy-copper-turtle-magic 13
#
# Fold 1
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 81.11 Precision: 89.19 Recall: 70.21
#
# Fold 2
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 89.62 Precision: 91.11 Recall: 87.23
#
# Fold 3
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 89.74 Precision: 87.76 Recall: 91.49
#
# Fold 4
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 85.17 Precision: 97.14 Recall: 72.34
#
# Fold 5
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 86.36 Precision: 92.50 Recall: 78.72
#
# wheezy-copper-turtle-magic 14
#
# Fold 1
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 82.73 Precision: 96.88 Recall: 67.39
#
# Fold 2
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 71.15 Precision: 85.19 Recall: 50.00
#
# Fold 3
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 87.00 Precision: 82.35 Recall: 91.30
#
# Fold 4
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 74.58 Precision: 95.83 Recall: 51.11
#
# Fold 5
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 71.63 Precision: 85.19 Recall: 51.11
#
# wheezy-copper-turtle-magic 15
#
# Fold 1
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 89.62 Precision: 100.00 Recall: 79.25
#
# Fold 2
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 82.58 Precision: 86.96 Recall: 76.92
#
# Fold 3
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 84.46 Precision: 84.62 Recall: 84.62
#
# Fold 4
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 88.42 Precision: 95.45 Recall: 80.77
#
# Fold 5
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 81.56 Precision: 82.35 Recall: 80.77
#
# wheezy-copper-turtle-magic 16
#
# Fold 1
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 88.73 Precision: 84.21 Recall: 94.12
#
# Fold 2
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 84.85 Precision: 76.56 Recall: 98.00
#
# Fold 3
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 77.30 Precision: 68.06 Recall: 98.00
#
# Fold 4
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 88.23 Precision: 91.30 Recall: 84.00
#
# Fold 5
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 80.85 Precision: 75.00 Recall: 90.00
#
# wheezy-copper-turtle-magic 17
#
# Fold 1
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 86.45 Precision: 88.24 Recall: 84.91
#
# Fold 2
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 88.23 Precision: 85.96 Recall: 92.45
#
# Fold 3
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 83.31 Precision: 83.02 Recall: 84.62
#
# Fold 4
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 85.19 Precision: 82.46 Recall: 90.38
#
# Fold 5
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 79.57 Precision: 89.74 Recall: 67.31
#
# wheezy-copper-turtle-magic 18
#
# Fold 1
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 81.06 Precision: 94.59 Recall: 66.04
#
# Fold 2
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 83.52 Precision: 80.00 Recall: 90.57
#
# Fold 3
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 84.54 Precision: 82.46 Recall: 88.68
#
# Fold 4
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 88.23 Precision: 85.96 Recall: 92.45
#
# Fold 5
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 91.28 Precision: 92.31 Recall: 90.57
#
# wheezy-copper-turtle-magic 19
#
# Fold 1
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 87.74 Precision: 85.71 Recall: 90.57
#
# Fold 2
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 84.67 Precision: 79.37 Recall: 94.34
#
# Fold 3
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 77.92 Precision: 70.83 Recall: 96.23
#
# Fold 4
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 82.75 Precision: 76.92 Recall: 94.34
#
# Fold 5
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 84.83 Precision: 91.11 Recall: 77.36
#
# wheezy-copper-turtle-magic 20
#
# Fold 1
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 80.07 Precision: 96.88 Recall: 62.00
#
# Fold 2
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 83.83 Precision: 94.59 Recall: 71.43
#
# Fold 3
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 75.59 Precision: 96.30 Recall: 53.06
#
# Fold 4
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 68.91 Precision: 78.12 Recall: 51.02
#
# Fold 5
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 83.75 Precision: 97.14 Recall: 69.39
#
# wheezy-copper-turtle-magic 21
#
# Fold 1
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 75.66 Precision: 74.14 Recall: 79.63
#
# Fold 2
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 84.10 Precision: 83.64 Recall: 85.19
#
# Fold 3
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 75.00 Precision: 67.50 Recall: 100.00
#
# Fold 4
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 81.80 Precision: 75.36 Recall: 96.30
#
# Fold 5
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 78.06 Precision: 73.13 Recall: 90.74
#
# wheezy-copper-turtle-magic 22
#
# Fold 1
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 93.41 Precision: 91.53 Recall: 96.43
#
# Fold 2
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 75.07 Precision: 68.75 Recall: 98.21
#
# Fold 3
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 78.04 Precision: 72.22 Recall: 94.55
#
# Fold 4
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 79.91 Precision: 73.61 Recall: 96.36
#
# Fold 5
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 88.67 Precision: 86.44 Recall: 92.73
#
# wheezy-copper-turtle-magic 23
#
# Fold 1
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 86.97 Precision: 95.45 Recall: 77.78
#
# Fold 2
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 85.66 Precision: 89.58 Recall: 81.13
#
# Fold 3
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 92.30 Precision: 92.45 Recall: 92.45
#
# Fold 4
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 78.26 Precision: 96.88 Recall: 58.49
#
# Fold 5
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 87.66 Precision: 95.45 Recall: 79.25
#
# wheezy-copper-turtle-magic 24
#
# Fold 1
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 81.01 Precision: 70.77 Recall: 97.87
#
# Fold 2
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 77.58 Precision: 70.69 Recall: 87.23
#
# Fold 3
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 78.17 Precision: 86.11 Recall: 65.96
#
# Fold 4
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 86.25 Precision: 92.31 Recall: 78.26
#
# Fold 5
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 91.68 Precision: 93.18 Recall: 89.13
#
# wheezy-copper-turtle-magic 25
#
# Fold 1
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 81.67 Precision: 82.22 Recall: 78.72
#
# Fold 2
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 83.69 Precision: 84.44 Recall: 80.85
#
# Fold 3
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 87.09 Precision: 82.69 Recall: 91.49
#
# Fold 4
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 89.77 Precision: 87.50 Recall: 91.30
#
# Fold 5
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 79.77 Precision: 88.57 Recall: 67.39
#
# wheezy-copper-turtle-magic 26
#
# Fold 1
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 77.21 Precision: 93.33 Recall: 58.33
#
# Fold 2
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 79.72 Precision: 76.47 Recall: 82.98
#
# Fold 3
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 84.79 Precision: 82.00 Recall: 87.23
#
# Fold 4
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 75.98 Precision: 81.58 Recall: 65.96
#
# Fold 5
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 88.68 Precision: 87.50 Recall: 89.36
#
# wheezy-copper-turtle-magic 27
#
# Fold 1
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 86.23 Precision: 85.42 Recall: 85.42
#
# Fold 2
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 75.83 Precision: 68.85 Recall: 87.50
#
# Fold 3
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 85.46 Precision: 80.00 Recall: 91.67
#
# Fold 4
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 89.26 Precision: 84.62 Recall: 93.62
#
# Fold 5
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 88.20 Precision: 84.31 Recall: 91.49
#
# wheezy-copper-turtle-magic 28
#
# Fold 1
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 80.56 Precision: 88.37 Recall: 70.37
#
# Fold 2
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 85.19 Precision: 81.67 Recall: 90.74
#
# Fold 3
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 84.26 Precision: 86.27 Recall: 81.48
#
# Fold 4
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 92.54 Precision: 94.23 Recall: 90.74
#
# Fold 5
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 87.74 Precision: 88.46 Recall: 86.79
#
# wheezy-copper-turtle-magic 29
#
# Fold 1
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 87.00 Precision: 81.36 Recall: 96.00
#
# Fold 2
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 79.00 Precision: 71.64 Recall: 96.00
#
# Fold 3
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 81.00 Precision: 73.13 Recall: 98.00
#
# Fold 4
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 83.69 Precision: 76.56 Recall: 98.00
#
# Fold 5
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 79.59 Precision: 71.43 Recall: 100.00
#
# wheezy-copper-turtle-magic 30
#
# Fold 1
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 81.22 Precision: 76.12 Recall: 94.44
#
# Fold 2
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 88.23 Precision: 87.50 Recall: 90.74
#
# Fold 3
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 85.36 Precision: 85.45 Recall: 87.04
#
# Fold 4
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 86.19 Precision: 84.48 Recall: 90.74
#
# Fold 5
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 88.93 Precision: 85.00 Recall: 96.23
#
# wheezy-copper-turtle-magic 31
#
# Fold 1
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 82.65 Precision: 75.38 Recall: 96.08
#
# Fold 2
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 88.27 Precision: 86.54 Recall: 90.00
#
# Fold 3
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 85.27 Precision: 85.71 Recall: 84.00
#
# Fold 4
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 85.20 Precision: 81.82 Recall: 90.00
#
# Fold 5
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 85.12 Precision: 87.23 Recall: 82.00
#
# wheezy-copper-turtle-magic 32
#
# Fold 1
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 82.68 Precision: 77.78 Recall: 89.36
#
# Fold 2
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 87.81 Precision: 83.02 Recall: 93.62
#
# Fold 3
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 88.74 Precision: 86.00 Recall: 91.49
#
# Fold 4
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 86.94 Precision: 79.31 Recall: 97.87
#
# Fold 5
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 86.60 Precision: 80.00 Recall: 95.65
#
# wheezy-copper-turtle-magic 33
#
# Fold 1
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 81.05 Precision: 79.31 Recall: 85.19
#
# Fold 2
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 85.86 Precision: 86.79 Recall: 85.19
#
# Fold 3
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 89.64 Precision: 90.57 Recall: 88.89
#
# Fold 4
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 87.59 Precision: 85.71 Recall: 90.57
#
# Fold 5
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 82.75 Precision: 76.92 Recall: 94.34
#
# wheezy-copper-turtle-magic 34
#
# Fold 1
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 75.43 Precision: 71.23 Recall: 92.86
#
# Fold 2
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 78.00 Precision: 71.79 Recall: 100.00
#
# Fold 3
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 77.88 Precision: 73.24 Recall: 94.55
#
# Fold 4
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 84.01 Precision: 80.00 Recall: 94.55
#
# Fold 5
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 75.51 Precision: 69.62 Recall: 100.00
#
# wheezy-copper-turtle-magic 35
#
# Fold 1
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 90.19 Precision: 90.38 Recall: 90.38
#
# Fold 2
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 89.12 Precision: 85.96 Recall: 94.23
#
# Fold 3
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 83.08 Precision: 76.92 Recall: 96.15
#
# Fold 4
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 85.12 Precision: 83.33 Recall: 88.24
#
# Fold 5
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 84.73 Precision: 78.12 Recall: 98.04
#
# wheezy-copper-turtle-magic 36
#
# Fold 1
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 75.00 Precision: 100.00 Recall: 50.00
#
# Fold 2
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 62.24 Precision: 86.67 Recall: 28.26
#
# Fold 3
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 84.61 Precision: 96.97 Recall: 71.11
#
# Fold 4
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 72.73 Precision: 88.46 Recall: 51.11
#
# Fold 5
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 71.11 Precision: 100.00 Recall: 42.22
#
# wheezy-copper-turtle-magic 37
#
# Fold 1
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 81.09 Precision: 80.36 Recall: 83.33
#
# Fold 2
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 81.67 Precision: 80.36 Recall: 84.91
#
# Fold 3
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 82.46 Precision: 76.92 Recall: 94.34
#
# Fold 4
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 87.48 Precision: 87.04 Recall: 88.68
#
# Fold 5
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 83.59 Precision: 82.14 Recall: 86.79
#
# wheezy-copper-turtle-magic 38
#
# Fold 1
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 86.64 Precision: 87.50 Recall: 84.00
#
# Fold 2
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 83.43 Precision: 90.24 Recall: 74.00
#
# Fold 3
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 91.43 Precision: 91.84 Recall: 90.00
#
# Fold 4
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 84.36 Precision: 90.48 Recall: 76.00
#
# Fold 5
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 75.96 Precision: 87.88 Recall: 59.18
#
# wheezy-copper-turtle-magic 39
#
# Fold 1
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 86.42 Precision: 81.03 Recall: 94.00
#
# Fold 2
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 80.69 Precision: 72.73 Recall: 96.00
#
# Fold 3
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 80.77 Precision: 71.43 Recall: 100.00
#
# Fold 4
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 89.10 Precision: 89.80 Recall: 88.00
#
# Fold 5
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 73.45 Precision: 65.28 Recall: 95.92
#
# wheezy-copper-turtle-magic 40
#
# Fold 1
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 80.00 Precision: 91.67 Recall: 66.00
#
# Fold 2
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 80.69 Precision: 89.47 Recall: 69.39
#
# Fold 3
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 71.96 Precision: 64.38 Recall: 95.92
#
# Fold 4
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 80.80 Precision: 81.25 Recall: 79.59
#
# Fold 5
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 81.63 Precision: 89.74 Recall: 71.43
#
# wheezy-copper-turtle-magic 41
#
# Fold 1
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 83.33 Precision: 86.00 Recall: 79.63
#
# Fold 2
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 83.33 Precision: 76.47 Recall: 96.30
#
# Fold 3
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 85.19 Precision: 83.93 Recall: 87.04
#
# Fold 4
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 84.26 Precision: 83.64 Recall: 85.19
#
# Fold 5
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 82.20 Precision: 79.66 Recall: 87.04
#
# wheezy-copper-turtle-magic 42
#
# Fold 1
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 85.17 Precision: 80.36 Recall: 93.75
#
# Fold 2
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 77.75 Precision: 72.13 Recall: 91.67
#
# Fold 3
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 82.98 Precision: 80.39 Recall: 87.23
#
# Fold 4
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 85.11 Precision: 77.97 Recall: 97.87
#
# Fold 5
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 82.65 Precision: 76.27 Recall: 95.74
#
# wheezy-copper-turtle-magic 43
#
# Fold 1
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 82.35 Precision: 73.53 Recall: 98.04
#
# Fold 2
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 81.81 Precision: 83.33 Recall: 78.43
#
# Fold 3
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 86.50 Precision: 87.76 Recall: 84.31
#
# Fold 4
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 83.57 Precision: 81.13 Recall: 86.00
#
# Fold 5
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 83.51 Precision: 82.35 Recall: 84.00
#
# wheezy-copper-turtle-magic 44
#
# Fold 1
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 79.70 Precision: 88.10 Recall: 69.81
#
# Fold 2
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 75.18 Precision: 90.91 Recall: 56.60
#
# Fold 3
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 89.50 Precision: 97.73 Recall: 81.13
#
# Fold 4
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 88.90 Precision: 88.89 Recall: 90.57
#
# Fold 5
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 86.23 Precision: 93.18 Recall: 78.85
#
# wheezy-copper-turtle-magic 45
#
# Fold 1
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 79.82 Precision: 78.85 Recall: 80.39
#
# Fold 2
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 77.10 Precision: 72.13 Recall: 86.27
#
# Fold 3
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 81.67 Precision: 83.33 Recall: 78.43
#
# Fold 4
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 83.81 Precision: 78.33 Recall: 92.16
#
# Fold 5
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 80.98 Precision: 74.60 Recall: 92.16
#
# wheezy-copper-turtle-magic 46
#
# Fold 1
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 83.06 Precision: 92.31 Recall: 72.00
#
# Fold 2
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 85.00 Precision: 88.89 Recall: 80.00
#
# Fold 3
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 72.00 Precision: 92.31 Recall: 48.00
#
# Fold 4
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 88.00 Precision: 97.50 Recall: 78.00
#
# Fold 5
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 80.88 Precision: 76.79 Recall: 87.76
#
# wheezy-copper-turtle-magic 47
#
# Fold 1
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 80.64 Precision: 78.69 Recall: 87.27
#
# Fold 2
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 83.22 Precision: 78.46 Recall: 94.44
#
# Fold 3
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 80.52 Precision: 78.33 Recall: 87.04
#
# Fold 4
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 85.30 Precision: 81.97 Recall: 92.59
#
# Fold 5
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 85.90 Precision: 81.25 Recall: 96.30
#
# wheezy-copper-turtle-magic 48
#
# Fold 1
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 80.23 Precision: 78.33 Recall: 85.45
#
# Fold 2
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 87.12 Precision: 93.62 Recall: 80.00
#
# Fold 3
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 85.65 Precision: 80.00 Recall: 96.30
#
# Fold 4
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 84.53 Precision: 80.65 Recall: 92.59
#
# Fold 5
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 79.79 Precision: 77.05 Recall: 87.04
#
# wheezy-copper-turtle-magic 49
#
# Fold 1
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 87.29 Precision: 95.24 Recall: 78.43
#
# Fold 2
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 78.51 Precision: 89.19 Recall: 64.71
#
# Fold 3
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 76.15 Precision: 88.24 Recall: 60.00
#
# Fold 4
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 81.19 Precision: 87.80 Recall: 72.00
#
# Fold 5
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 90.23 Precision: 88.46 Recall: 92.00
#
# wheezy-copper-turtle-magic 50
#
# Fold 1
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 75.50 Precision: 91.18 Recall: 56.36
#
# Fold 2
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 81.58 Precision: 92.50 Recall: 68.52
#
# Fold 3
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 80.69 Precision: 90.24 Recall: 68.52
#
# Fold 4
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 76.88 Precision: 96.77 Recall: 55.56
#
# Fold 5
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 67.63 Precision: 95.24 Recall: 37.04
#
# wheezy-copper-turtle-magic 51
#
# Fold 1
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 82.68 Precision: 77.61 Recall: 91.23
#
# Fold 2
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 81.58 Precision: 74.32 Recall: 96.49
#
# Fold 3
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 84.21 Precision: 79.10 Recall: 92.98
#
# Fold 4
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 82.46 Precision: 77.61 Recall: 91.23
#
# Fold 5
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 78.87 Precision: 72.86 Recall: 91.07
#
# wheezy-copper-turtle-magic 52
#
# Fold 1
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 84.38 Precision: 90.91 Recall: 76.92
#
# Fold 2
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 82.57 Precision: 94.74 Recall: 69.23
#
# Fold 3
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 76.20 Precision: 80.43 Recall: 71.15
#
# Fold 4
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 86.22 Precision: 91.30 Recall: 80.77
#
# Fold 5
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 83.95 Precision: 87.23 Recall: 80.39
#
# wheezy-copper-turtle-magic 53
#
# Fold 1
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 80.51 Precision: 78.33 Recall: 88.68
#
# Fold 2
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 73.69 Precision: 71.21 Recall: 88.68
#
# Fold 3
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 75.63 Precision: 72.31 Recall: 90.38
#
# Fold 4
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 77.80 Precision: 74.60 Recall: 90.38
#
# Fold 5
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 80.48 Precision: 81.13 Recall: 82.69
#
# wheezy-copper-turtle-magic 54
#
# Fold 1
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 85.62 Precision: 91.30 Recall: 79.25
#
# Fold 2
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 84.35 Precision: 86.00 Recall: 82.69
#
# Fold 3
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 82.10 Precision: 81.48 Recall: 84.62
#
# Fold 4
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 76.04 Precision: 74.14 Recall: 82.69
#
# Fold 5
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 83.01 Precision: 80.70 Recall: 88.46
#
# wheezy-copper-turtle-magic 55
#
# Fold 1
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 80.43 Precision: 96.97 Recall: 62.75
#
# Fold 2
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 84.35 Precision: 97.30 Recall: 70.59
#
# Fold 3
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 64.85 Precision: 82.61 Recall: 37.25
#
# Fold 4
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 84.39 Precision: 94.87 Recall: 72.55
#
# Fold 5
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 86.11 Precision: 95.00 Recall: 76.00
#
# wheezy-copper-turtle-magic 56
#
# Fold 1
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 83.67 Precision: 84.91 Recall: 83.33
#
# Fold 2
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 87.30 Precision: 84.75 Recall: 92.59
#
# Fold 3
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 81.74 Precision: 86.96 Recall: 75.47
#
# Fold 4
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 84.79 Precision: 95.12 Recall: 73.58
#
# Fold 5
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 84.79 Precision: 95.12 Recall: 73.58
#
# wheezy-copper-turtle-magic 57
#
# Fold 1
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 83.04 Precision: 90.91 Recall: 74.07
#
# Fold 2
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 80.85 Precision: 88.37 Recall: 71.70
#
# Fold 3
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 78.96 Precision: 87.80 Recall: 67.92
#
# Fold 4
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 86.57 Precision: 91.49 Recall: 81.13
#
# Fold 5
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 79.98 Precision: 76.19 Recall: 90.57
#
# wheezy-copper-turtle-magic 58
#
# Fold 1
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 79.03 Precision: 85.00 Recall: 69.39
#
# Fold 2
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 83.50 Precision: 79.63 Recall: 87.76
#
# Fold 3
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 86.50 Precision: 80.36 Recall: 93.75
#
# Fold 4
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 88.38 Precision: 83.33 Recall: 93.75
#
# Fold 5
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 89.18 Precision: 84.91 Recall: 93.75
#
# wheezy-copper-turtle-magic 59
#
# Fold 1
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 69.00 Precision: 85.19 Recall: 46.00
#
# Fold 2
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 78.92 Precision: 89.19 Recall: 66.00
#
# Fold 3
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 73.98 Precision: 96.15 Recall: 50.00
#
# Fold 4
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 72.98 Precision: 96.00 Recall: 48.00
#
# Fold 5
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 75.51 Precision: 93.10 Recall: 55.10
#
# wheezy-copper-turtle-magic 60
#
# Fold 1
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 90.44 Precision: 87.72 Recall: 94.34
#
# Fold 2
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 77.98 Precision: 72.73 Recall: 90.57
#
# Fold 3
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 80.50 Precision: 74.63 Recall: 94.34
#
# Fold 4
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 77.51 Precision: 71.01 Recall: 94.23
#
# Fold 5
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 76.49 Precision: 68.92 Recall: 98.08
#
# wheezy-copper-turtle-magic 61
#
# Fold 1
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 88.92 Precision: 83.33 Recall: 98.21
#
# Fold 2
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 89.88 Precision: 89.47 Recall: 91.07
#
# Fold 3
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 82.21 Precision: 77.27 Recall: 92.73
#
# Fold 4
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 84.20 Precision: 82.76 Recall: 87.27
#
# Fold 5
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 82.35 Precision: 81.03 Recall: 85.45
#
# wheezy-copper-turtle-magic 62
#
# Fold 1
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 96.11 Precision: 97.92 Recall: 94.00
#
# Fold 2
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 86.99 Precision: 95.00 Recall: 77.55
#
# Fold 3
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 82.99 Precision: 92.11 Recall: 71.43
#
# Fold 4
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 79.35 Precision: 83.33 Recall: 71.43
#
# Fold 5
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 82.65 Precision: 100.00 Recall: 65.31
#
# wheezy-copper-turtle-magic 63
#
# Fold 1
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 74.43 Precision: 70.27 Recall: 92.86
#
# Fold 2
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 85.27 Precision: 81.25 Recall: 94.55
#
# Fold 3
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 81.36 Precision: 77.27 Recall: 92.73
#
# Fold 4
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 80.72 Precision: 75.00 Recall: 98.18
#
# Fold 5
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 84.01 Precision: 80.00 Recall: 94.55
#
# wheezy-copper-turtle-magic 64
#
# Fold 1
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 95.39 Precision: 98.04 Recall: 92.59
#
# Fold 2
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 89.76 Precision: 92.00 Recall: 86.79
#
# Fold 3
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 82.25 Precision: 88.64 Recall: 73.58
#
# Fold 4
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 92.51 Precision: 94.12 Recall: 90.57
#
# Fold 5
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 88.75 Precision: 91.84 Recall: 84.91
#
# wheezy-copper-turtle-magic 65
#
# Fold 1
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# ...
#
# -----Validation-----
# AUC: 74.83 Precision: 65.67 Recall: 95.65
#
# Fold 3
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 85.13 Precision: 90.00 Recall: 78.26
#
# Fold 4
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 85.30 Precision: 86.36 Recall: 82.61
#
# Fold 5
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 81.74 Precision: 74.14 Recall: 93.48
#
# wheezy-copper-turtle-magic 491
#
# Fold 1
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 81.25 Precision: 92.11 Recall: 68.63
#
# Fold 2
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 77.87 Precision: 75.44 Recall: 84.31
#
# Fold 3
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 84.86 Precision: 85.71 Recall: 84.00
#
# Fold 4
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 83.76 Precision: 79.31 Recall: 92.00
#
# Fold 5
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 79.63 Precision: 72.73 Recall: 96.00
#
# wheezy-copper-turtle-magic 492
#
# Fold 1
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 82.15 Precision: 83.67 Recall: 78.85
#
# Fold 2
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 70.45 Precision: 83.87 Recall: 50.00
#
# Fold 3
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 83.11 Precision: 84.00 Recall: 80.77
#
# Fold 4
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 73.40 Precision: 74.47 Recall: 68.63
#
# Fold 5
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 76.53 Precision: 96.55 Recall: 54.90
#
# wheezy-copper-turtle-magic 493
#
# Fold 1
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 85.81 Precision: 91.49 Recall: 79.63
#
# Fold 2
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 84.37 Precision: 81.67 Recall: 90.74
#
# Fold 3
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 81.07 Precision: 78.33 Recall: 88.68
#
# Fold 4
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 84.14 Precision: 82.46 Recall: 88.68
#
# Fold 5
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 90.26 Precision: 92.16 Recall: 88.68
#
# wheezy-copper-turtle-magic 494
#
# Fold 1
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 84.22 Precision: 77.27 Recall: 96.23
#
# Fold 2
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 80.40 Precision: 78.57 Recall: 83.02
#
# Fold 3
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 85.85 Precision: 82.76 Recall: 90.57
#
# Fold 4
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 90.57 Precision: 92.16 Recall: 88.68
#
# Fold 5
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 83.02 Precision: 77.78 Recall: 92.45
#
# wheezy-copper-turtle-magic 495
#
# Fold 1
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 84.75 Precision: 84.31 Recall: 84.31
#
# Fold 2
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 85.51 Precision: 90.91 Recall: 78.43
#
# Fold 3
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 79.68 Precision: 87.50 Recall: 68.63
#
# Fold 4
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 75.71 Precision: 88.24 Recall: 58.82
#
# Fold 5
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 88.45 Precision: 91.49 Recall: 84.31
#
# wheezy-copper-turtle-magic 496
#
# Fold 1
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 78.73 Precision: 73.77 Recall: 88.24
#
# Fold 2
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 84.42 Precision: 80.36 Recall: 90.00
#
# Fold 3
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 87.18 Precision: 83.64 Recall: 92.00
#
# Fold 4
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 69.04 Precision: 91.30 Recall: 42.00
#
# Fold 5
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 79.08 Precision: 89.19 Recall: 66.00
#
# wheezy-copper-turtle-magic 497
#
# Fold 1
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 86.79 Precision: 91.49 Recall: 81.13
#
# Fold 2
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 73.58 Precision: 83.78 Recall: 58.49
#
# Fold 3
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 87.66 Precision: 91.67 Recall: 83.02
#
# Fold 4
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 78.92 Precision: 73.13 Recall: 92.45
#
# Fold 5
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 81.73 Precision: 85.11 Recall: 76.92
#
# wheezy-copper-turtle-magic 498
#
# Fold 1
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 81.01 Precision: 77.59 Recall: 86.54
#
# Fold 2
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 79.88 Precision: 89.74 Recall: 67.31
#
# Fold 3
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 77.88 Precision: 69.86 Recall: 98.08
#
# Fold 4
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 88.35 Precision: 88.24 Recall: 88.24
#
# Fold 5
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 85.48 Precision: 82.14 Recall: 90.20
#
# wheezy-copper-turtle-magic 499
#
# Fold 1
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 85.95 Precision: 87.23 Recall: 83.67
#
# Fold 2
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 82.93 Precision: 84.78 Recall: 79.59
#
# Fold 3
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 84.07 Precision: 81.13 Recall: 87.76
#
# Fold 4
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 79.05 Precision: 76.92 Recall: 81.63
#
# Fold 5
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 86.93 Precision: 89.13 Recall: 83.67
#
# wheezy-copper-turtle-magic 500
#
# Fold 1
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 77.37 Precision: 88.89 Recall: 62.75
#
# Fold 2
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 78.37 Precision: 91.43 Recall: 62.75
#
# Fold 3
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 82.29 Precision: 92.31 Recall: 70.59
#
# Fold 4
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 80.96 Precision: 94.29 Recall: 66.00
#
# Fold 5
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 76.98 Precision: 96.55 Recall: 56.00
#
# wheezy-copper-turtle-magic 501
#
# Fold 1
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 76.84 Precision: 73.85 Recall: 92.31
#
# Fold 2
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 77.01 Precision: 74.60 Recall: 90.38
#
# Fold 3
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 78.31 Precision: 74.63 Recall: 96.15
#
# Fold 4
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 69.61 Precision: 68.12 Recall: 90.38
#
# Fold 5
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 85.69 Precision: 84.21 Recall: 92.31
#
# wheezy-copper-turtle-magic 502
#
# Fold 1
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 81.41 Precision: 73.53 Recall: 96.15
#
# Fold 2
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 87.61 Precision: 88.24 Recall: 86.54
#
# Fold 3
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 88.59 Precision: 87.04 Recall: 90.38
#
# Fold 4
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 78.19 Precision: 70.59 Recall: 94.12
#
# Fold 5
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 80.95 Precision: 75.41 Recall: 90.20
#
# wheezy-copper-turtle-magic 503
#
# Fold 1
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 75.21 Precision: 85.29 Recall: 60.42
#
# Fold 2
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 83.17 Precision: 91.89 Recall: 72.34
#
# Fold 3
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 80.11 Precision: 86.84 Recall: 70.21
#
# Fold 4
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 80.98 Precision: 91.43 Recall: 68.09
#
# Fold 5
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 84.17 Precision: 92.11 Recall: 74.47
#
# wheezy-copper-turtle-magic 504
#
# Fold 1
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 75.92 Precision: 72.58 Recall: 86.54
#
# Fold 2
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 87.03 Precision: 85.45 Recall: 90.38
#
# Fold 3
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 81.93 Precision: 78.33 Recall: 90.38
#
# Fold 4
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 83.30 Precision: 87.23 Recall: 78.85
#
# Fold 5
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 84.03 Precision: 82.14 Recall: 88.46
#
# wheezy-copper-turtle-magic 505
#
# Fold 1
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 86.64 Precision: 82.46 Recall: 92.16
#
# Fold 2
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 70.66 Precision: 86.21 Recall: 49.02
#
# Fold 3
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 84.43 Precision: 87.23 Recall: 80.39
#
# Fold 4
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 76.66 Precision: 78.72 Recall: 72.55
#
# Fold 5
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 87.23 Precision: 87.76 Recall: 86.00
#
# wheezy-copper-turtle-magic 506
#
# Fold 1
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 87.96 Precision: 87.27 Recall: 88.89
#
# Fold 2
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 76.80 Precision: 69.44 Recall: 94.34
#
# Fold 3
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 82.08 Precision: 76.56 Recall: 92.45
#
# Fold 4
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 91.51 Precision: 92.31 Recall: 90.57
#
# Fold 5
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 81.13 Precision: 74.63 Recall: 94.34
#
# wheezy-copper-turtle-magic 507
#
# Fold 1
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 90.36 Precision: 91.67 Recall: 88.00
#
# Fold 2
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 78.00 Precision: 100.00 Recall: 56.00
#
# Fold 3
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 83.15 Precision: 94.59 Recall: 70.00
#
# Fold 4
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 92.40 Precision: 88.68 Recall: 95.92
#
# Fold 5
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 88.23 Precision: 89.36 Recall: 85.71
#
# wheezy-copper-turtle-magic 508
#
# Fold 1
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 81.13 Precision: 92.31 Recall: 67.92
#
# Fold 2
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 81.73 Precision: 90.24 Recall: 71.15
#
# Fold 3
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 77.88 Precision: 91.43 Recall: 61.54
#
# Fold 4
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 75.96 Precision: 84.62 Recall: 63.46
#
# Fold 5
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 78.85 Precision: 81.25 Recall: 75.00
#
# wheezy-copper-turtle-magic 509
#
# Fold 1
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 80.06 Precision: 91.67 Recall: 66.00
#
# Fold 2
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 74.57 Precision: 92.86 Recall: 53.06
#
# Fold 3
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 78.61 Precision: 96.67 Recall: 59.18
#
# Fold 4
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 78.69 Precision: 91.18 Recall: 63.27
#
# Fold 5
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 72.61 Precision: 86.67 Recall: 53.06
#
# wheezy-copper-turtle-magic 510
#
# Fold 1
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 85.37 Precision: 95.00 Recall: 74.51
#
# Fold 2
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 82.46 Precision: 92.31 Recall: 70.59
#
# Fold 3
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 83.62 Precision: 80.00 Recall: 88.00
#
# Fold 4
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 80.19 Precision: 87.50 Recall: 70.00
#
# Fold 5
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 73.08 Precision: 92.59 Recall: 50.00
#
# wheezy-copper-turtle-magic 511
#
# Fold 1
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 87.15 Precision: 88.24 Recall: 86.54
#
# Fold 2
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 84.09 Precision: 83.33 Recall: 86.54
#
# Fold 3
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 83.79 Precision: 78.12 Recall: 96.15
#
# Fold 4
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 77.91 Precision: 76.36 Recall: 82.35
#
# Fold 5
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 82.78 Precision: 82.69 Recall: 84.31

# %% [markdown]
# ## NuSVC

# %%
# INITIALIZE VARIABLES
test['target_nusvc'] = 0
train['preds_nusvc'] = 0

# BUILD 512 MODELS
for i in range(512):
    print('wheezy-copper-turtle-magic {}\n'.format(i))
    
    # EXTRACT SUBSET OF DATASET WHERE WHEEZY-MAGIC EQUALS I
    train2 = train[train['wheezy-copper-turtle-magic']==i]
    test2 = test[test['wheezy-copper-turtle-magic']==i]
    idx1 = train2.index
    idx2 = test2.index
    train2.reset_index(drop=True, inplace=True)
    
    # FEATURE SELECTION (USE APPROX 40 OF 255 FEATURES)
    sel = VarianceThreshold(threshold=1.5).fit(train2[cols])
    train3 = sel.transform(train2[cols])
    test3 = sel.transform(test2[cols])

    skf = StratifiedKFold(n_splits=N_FOLDS, random_state=0)
    counter = 0

    for train_index, val_index in skf.split(train3, train2['target']):
        counter += 1
        print('Fold {}\n'.format(counter))
        model = NuSVC(probability=True,kernel='poly',degree=4,gamma='auto')
        model.fit(train3[train_index,:], train2.loc[train_index]['target'])
        
        train_predictions = model.predict(train3[train_index,:])
        val_predictions = model.predict(train3[val_index,:])

        train_auc = roc_auc_score(train2.loc[train_index]['target'], train_predictions) * 100
        val_auc = roc_auc_score(train2.loc[val_index]['target'], val_predictions) * 100
        train_precision = precision_score(train2.loc[train_index]['target'], train_predictions) * 100
        val_precision = precision_score(train2.loc[val_index]['target'], val_predictions) * 100
        train_recall = recall_score(train2.loc[train_index]['target'], train_predictions) * 100
        val_recall = recall_score(train2.loc[val_index]['target'], val_predictions) * 100
        print('-----Train----------')
        print('AUC: %.2f Precision: %.2f Recall: %.2f \n' % (train_auc, train_precision, train_recall))
        print('-----Validation-----')
        print('AUC: %.2f Precision: %.2f Recall: %.2f \n' % (val_auc, val_precision, val_recall))

        # Make predictions
        train['preds_nusvc'].loc[idx1] += model.predict_proba(train3)[:,1] / N_FOLDS
        test['target_nusvc'].loc[idx2] += model.predict_proba(test3)[:,1] / N_FOLDS
# Out:
# wheezy-copper-turtle-magic 0
#
# Fold 1
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 85.04 Precision: 91.11 Recall: 77.36
#
# Fold 2
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 90.62 Precision: 93.88 Recall: 86.79
#
# Fold 3
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 90.62 Precision: 93.88 Recall: 86.79
#
# Fold 4
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 87.82 Precision: 84.21 Recall: 92.31
#
# Fold 5
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 85.72 Precision: 91.11 Recall: 78.85
#
# wheezy-copper-turtle-magic 1
#
# Fold 1
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 89.57 Precision: 83.05 Recall: 98.00
#
# Fold 2
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 85.39 Precision: 82.69 Recall: 87.76
#
# Fold 3
#
# -----Train----------
# AUC: 99.49 Precision: 100.00 Recall: 98.98
#
# -----Validation-----
# AUC: 90.10 Precision: 91.49 Recall: 87.76
#
# Fold 4
#
# -----Train----------
# AUC: 99.75 Precision: 100.00 Recall: 99.49
#
# -----Validation-----
# AUC: 85.08 Precision: 88.64 Recall: 79.59
#
# Fold 5
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 86.36 Precision: 80.70 Recall: 93.88
#
# wheezy-copper-turtle-magic 2
#
# Fold 1
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 82.69 Precision: 97.06 Recall: 67.35
#
# Fold 2
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 84.97 Precision: 85.42 Recall: 83.67
#
# Fold 3
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 84.86 Precision: 84.00 Recall: 85.71
#
# Fold 4
#
# -----Train----------
# AUC: 99.74 Precision: 100.00 Recall: 99.49
#
# -----Validation-----
# AUC: 81.29 Precision: 96.88 Recall: 64.58
#
# Fold 5
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 77.12 Precision: 96.43 Recall: 56.25
#
# wheezy-copper-turtle-magic 3
#
# Fold 1
#
# -----Train----------
# AUC: 97.80 Precision: 96.14 Recall: 100.00
#
# -----Validation-----
# AUC: 71.32 Precision: 66.27 Recall: 96.49
#
# Fold 2
#
# -----Train----------
# AUC: 98.29 Precision: 96.98 Recall: 100.00
#
# -----Validation-----
# AUC: 71.29 Precision: 65.85 Recall: 96.43
#
# Fold 3
#
# -----Train----------
# AUC: 99.51 Precision: 99.12 Recall: 100.00
#
# -----Validation-----
# AUC: 77.45 Precision: 70.89 Recall: 100.00
#
# Fold 4
#
# -----Train----------
# AUC: 99.03 Precision: 98.25 Recall: 100.00
#
# -----Validation-----
# AUC: 87.43 Precision: 83.08 Recall: 96.43
#
# Fold 5
#
# -----Train----------
# AUC: 98.54 Precision: 97.40 Recall: 100.00
#
# -----Validation-----
# AUC: 74.86 Precision: 70.27 Recall: 92.86
#
# wheezy-copper-turtle-magic 4
#
# Fold 1
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 85.63 Precision: 88.00 Recall: 83.02
#
# Fold 2
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 87.44 Precision: 93.33 Recall: 80.77
#
# Fold 3
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 88.35 Precision: 88.46 Recall: 88.46
#
# Fold 4
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 87.33 Precision: 84.21 Recall: 92.31
#
# Fold 5
#
# -----Train----------
# AUC: 99.76 Precision: 100.00 Recall: 99.52
#
# -----Validation-----
# AUC: 84.56 Precision: 92.86 Recall: 75.00
#
# wheezy-copper-turtle-magic 5
#
# Fold 1
#
# -----Train----------
# AUC: 99.52 Precision: 99.04 Recall: 100.00
#
# -----Validation-----
# AUC: 78.25 Precision: 71.01 Recall: 94.23
#
# Fold 2
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 89.62 Precision: 82.54 Recall: 100.00
#
# Fold 3
#
# -----Train----------
# AUC: 99.76 Precision: 100.00 Recall: 99.52
#
# -----Validation-----
# AUC: 86.54 Precision: 89.58 Recall: 82.69
#
# Fold 4
#
# -----Train----------
# AUC: 99.76 Precision: 100.00 Recall: 99.52
#
# -----Validation-----
# AUC: 80.77 Precision: 88.10 Recall: 71.15
#
# Fold 5
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 85.41 Precision: 87.50 Recall: 82.35
#
# wheezy-copper-turtle-magic 6
#
# Fold 1
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 88.31 Precision: 83.61 Recall: 96.23
#
# Fold 2
#
# -----Train----------
# AUC: 99.75 Precision: 99.53 Recall: 100.00
#
# -----Validation-----
# AUC: 85.41 Precision: 80.65 Recall: 94.34
#
# Fold 3
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 90.23 Precision: 85.25 Recall: 98.11
#
# Fold 4
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 82.06 Precision: 75.36 Recall: 98.11
#
# Fold 5
#
# -----Train----------
# AUC: 99.26 Precision: 98.60 Recall: 100.00
#
# -----Validation-----
# AUC: 78.06 Precision: 71.23 Recall: 98.11
#
# wheezy-copper-turtle-magic 7
#
# Fold 1
#
# -----Train----------
# AUC: 99.26 Precision: 100.00 Recall: 98.52
#
# -----Validation-----
# AUC: 81.37 Precision: 97.06 Recall: 64.71
#
# Fold 2
#
# -----Train----------
# AUC: 99.01 Precision: 100.00 Recall: 98.03
#
# -----Validation-----
# AUC: 74.51 Precision: 87.88 Recall: 56.86
#
# Fold 3
#
# -----Train----------
# AUC: 99.51 Precision: 100.00 Recall: 99.01
#
# -----Validation-----
# AUC: 81.31 Precision: 92.11 Recall: 68.63
#
# Fold 4
#
# -----Train----------
# AUC: 99.26 Precision: 100.00 Recall: 98.52
#
# -----Validation-----
# AUC: 75.43 Precision: 90.62 Recall: 56.86
#
# Fold 5
#
# -----Train----------
# AUC: 99.75 Precision: 100.00 Recall: 99.51
#
# -----Validation-----
# AUC: 84.00 Precision: 90.48 Recall: 76.00
#
# wheezy-copper-turtle-magic 8
#
# Fold 1
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 87.42 Precision: 83.61 Recall: 94.44
#
# Fold 2
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 89.27 Precision: 84.13 Recall: 98.15
#
# Fold 3
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 80.58 Precision: 76.19 Recall: 90.57
#
# Fold 4
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 85.37 Precision: 79.69 Recall: 96.23
#
# Fold 5
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 91.36 Precision: 92.31 Recall: 90.57
#
# wheezy-copper-turtle-magic 9
#
# Fold 1
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 83.96 Precision: 81.03 Recall: 88.68
#
# Fold 2
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 83.02 Precision: 76.92 Recall: 94.34
#
# Fold 3
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 90.57 Precision: 85.25 Recall: 98.11
#
# Fold 4
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 83.96 Precision: 92.86 Recall: 73.58
#
# Fold 5
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 90.38 Precision: 87.50 Recall: 94.23
#
# wheezy-copper-turtle-magic 10
#
# Fold 1
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 90.08 Precision: 91.67 Recall: 88.00
#
# Fold 2
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 89.84 Precision: 97.56 Recall: 81.63
#
# Fold 3
#
# -----Train----------
# AUC: 99.75 Precision: 99.49 Recall: 100.00
#
# -----Validation-----
# AUC: 87.94 Precision: 83.64 Recall: 93.88
#
# Fold 4
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 85.82 Precision: 88.89 Recall: 81.63
#
# Fold 5
#
# -----Train----------
# AUC: 99.75 Precision: 99.49 Recall: 100.00
#
# -----Validation-----
# AUC: 85.94 Precision: 80.70 Recall: 93.88
#
# wheezy-copper-turtle-magic 11
#
# Fold 1
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 89.74 Precision: 87.76 Recall: 91.49
#
# Fold 2
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 92.68 Precision: 95.45 Recall: 89.36
#
# Fold 3
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 89.65 Precision: 87.50 Recall: 91.30
#
# Fold 4
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 90.57 Precision: 91.11 Recall: 89.13
#
# Fold 5
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 86.39 Precision: 86.67 Recall: 84.78
#
# wheezy-copper-turtle-magic 12
#
# Fold 1
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 88.98 Precision: 88.46 Recall: 90.20
#
# Fold 2
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 90.88 Precision: 88.68 Recall: 94.00
#
# Fold 3
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 78.59 Precision: 71.01 Recall: 98.00
#
# Fold 4
#
# -----Train----------
# AUC: 99.49 Precision: 99.01 Recall: 100.00
#
# -----Validation-----
# AUC: 74.55 Precision: 68.12 Recall: 94.00
#
# Fold 5
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 80.65 Precision: 73.85 Recall: 96.00
#
# wheezy-copper-turtle-magic 13
#
# Fold 1
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 87.43 Precision: 92.68 Recall: 80.85
#
# Fold 2
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 92.74 Precision: 93.48 Recall: 91.49
#
# Fold 3
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 85.17 Precision: 97.14 Recall: 72.34
#
# Fold 4
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 80.91 Precision: 96.77 Recall: 63.83
#
# Fold 5
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 83.11 Precision: 94.29 Recall: 70.21
#
# wheezy-copper-turtle-magic 14
#
# Fold 1
#
# -----Train----------
# AUC: 99.76 Precision: 99.45 Recall: 100.00
#
# -----Validation-----
# AUC: 87.83 Precision: 85.42 Recall: 89.13
#
# Fold 2
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 83.11 Precision: 89.47 Recall: 73.91
#
# Fold 3
#
# -----Train----------
# AUC: 99.76 Precision: 99.45 Recall: 100.00
#
# -----Validation-----
# AUC: 83.99 Precision: 78.85 Recall: 89.13
#
# Fold 4
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 84.58 Precision: 96.97 Recall: 71.11
#
# Fold 5
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 81.50 Precision: 91.18 Recall: 68.89
#
# wheezy-copper-turtle-magic 15
#
# Fold 1
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 95.25 Precision: 98.00 Recall: 92.45
#
# Fold 2
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 90.27 Precision: 88.89 Recall: 92.31
#
# Fold 3
#
# -----Train----------
# AUC: 99.51 Precision: 99.05 Recall: 100.00
#
# -----Validation-----
# AUC: 86.29 Precision: 79.69 Recall: 98.08
#
# Fold 4
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 88.42 Precision: 95.45 Recall: 80.77
#
# Fold 5
#
# -----Train----------
# AUC: 99.51 Precision: 99.05 Recall: 100.00
#
# -----Validation-----
# AUC: 83.39 Precision: 77.78 Recall: 94.23
#
# wheezy-copper-turtle-magic 16
#
# Fold 1
#
# -----Train----------
# AUC: 98.75 Precision: 100.00 Recall: 97.50
#
# -----Validation-----
# AUC: 82.52 Precision: 92.31 Recall: 70.59
#
# Fold 2
#
# -----Train----------
# AUC: 99.25 Precision: 100.00 Recall: 98.51
#
# -----Validation-----
# AUC: 88.17 Precision: 93.18 Recall: 82.00
#
# Fold 3
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 90.11 Precision: 95.45 Recall: 84.00
#
# Fold 4
#
# -----Train----------
# AUC: 98.51 Precision: 100.00 Recall: 97.01
#
# -----Validation-----
# AUC: 68.00 Precision: 100.00 Recall: 36.00
#
# Fold 5
#
# -----Train----------
# AUC: 99.50 Precision: 100.00 Recall: 99.00
#
# -----Validation-----
# AUC: 85.11 Precision: 94.87 Recall: 74.00
#
# wheezy-copper-turtle-magic 17
#
# Fold 1
#
# -----Train----------
# AUC: 98.99 Precision: 98.12 Recall: 100.00
#
# -----Validation-----
# AUC: 79.28 Precision: 75.00 Recall: 90.57
#
# Fold 2
#
# -----Train----------
# AUC: 98.99 Precision: 98.12 Recall: 100.00
#
# -----Validation-----
# AUC: 80.06 Precision: 73.24 Recall: 98.11
#
# Fold 3
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 85.23 Precision: 83.64 Recall: 88.46
#
# Fold 4
#
# -----Train----------
# AUC: 99.50 Precision: 99.06 Recall: 100.00
#
# -----Validation-----
# AUC: 79.12 Precision: 73.13 Recall: 94.23
#
# Fold 5
#
# -----Train----------
# AUC: 99.75 Precision: 99.53 Recall: 100.00
#
# -----Validation-----
# AUC: 87.09 Precision: 86.79 Recall: 88.46
#
# wheezy-copper-turtle-magic 18
#
# Fold 1
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 87.40 Precision: 84.48 Recall: 92.45
#
# Fold 2
#
# -----Train----------
# AUC: 99.75 Precision: 99.53 Recall: 100.00
#
# -----Validation-----
# AUC: 76.51 Precision: 69.33 Recall: 98.11
#
# Fold 3
#
# -----Train----------
# AUC: 99.75 Precision: 99.53 Recall: 100.00
#
# -----Validation-----
# AUC: 85.37 Precision: 79.69 Recall: 96.23
#
# Fold 4
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 86.28 Precision: 84.21 Recall: 90.57
#
# Fold 5
#
# -----Train----------
# AUC: 99.75 Precision: 99.53 Recall: 100.00
#
# -----Validation-----
# AUC: 88.00 Precision: 81.54 Recall: 100.00
#
# wheezy-copper-turtle-magic 19
#
# Fold 1
#
# -----Train----------
# AUC: 99.76 Precision: 99.53 Recall: 100.00
#
# -----Validation-----
# AUC: 86.79 Precision: 81.97 Recall: 94.34
#
# Fold 2
#
# -----Train----------
# AUC: 99.52 Precision: 99.07 Recall: 100.00
#
# -----Validation-----
# AUC: 81.77 Precision: 75.00 Recall: 96.23
#
# Fold 3
#
# -----Train----------
# AUC: 99.04 Precision: 98.15 Recall: 100.00
#
# -----Validation-----
# AUC: 78.85 Precision: 70.67 Recall: 100.00
#
# Fold 4
#
# -----Train----------
# AUC: 99.28 Precision: 98.60 Recall: 100.00
#
# -----Validation-----
# AUC: 87.52 Precision: 81.25 Recall: 98.11
#
# Fold 5
#
# -----Train----------
# AUC: 99.76 Precision: 99.53 Recall: 100.00
#
# -----Validation-----
# AUC: 87.57 Precision: 84.48 Recall: 92.45
#
# wheezy-copper-turtle-magic 20
#
# Fold 1
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 83.22 Precision: 92.31 Recall: 72.00
#
# Fold 2
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 84.92 Precision: 92.50 Recall: 75.51
#
# Fold 3
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 84.69 Precision: 100.00 Recall: 69.39
#
# Fold 4
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 83.90 Precision: 92.31 Recall: 73.47
#
# Fold 5
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 89.87 Precision: 97.56 Recall: 81.63
#
# wheezy-copper-turtle-magic 21
#
# Fold 1
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 85.97 Precision: 85.45 Recall: 87.04
#
# Fold 2
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 81.25 Precision: 78.33 Recall: 87.04
#
# Fold 3
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 91.45 Precision: 89.47 Recall: 94.44
#
# Fold 4
#
# -----Train----------
# AUC: 99.77 Precision: 100.00 Recall: 99.54
#
# -----Validation-----
# AUC: 79.45 Precision: 88.10 Recall: 68.52
#
# Fold 5
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 90.63 Precision: 94.00 Recall: 87.04
#
# wheezy-copper-turtle-magic 22
#
# Fold 1
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 85.65 Precision: 79.71 Recall: 98.21
#
# Fold 2
#
# -----Train----------
# AUC: 99.28 Precision: 98.66 Recall: 100.00
#
# -----Validation-----
# AUC: 71.22 Precision: 65.48 Recall: 98.21
#
# Fold 3
#
# -----Train----------
# AUC: 99.28 Precision: 98.67 Recall: 100.00
#
# -----Validation-----
# AUC: 79.97 Precision: 74.29 Recall: 94.55
#
# Fold 4
#
# -----Train----------
# AUC: 99.76 Precision: 99.55 Recall: 100.00
#
# -----Validation-----
# AUC: 78.90 Precision: 72.00 Recall: 98.18
#
# Fold 5
#
# -----Train----------
# AUC: 99.76 Precision: 99.55 Recall: 100.00
#
# -----Validation-----
# AUC: 83.76 Precision: 77.94 Recall: 96.36
#
# wheezy-copper-turtle-magic 23
#
# Fold 1
#
# -----Train----------
# AUC: 99.76 Precision: 100.00 Recall: 99.53
#
# -----Validation-----
# AUC: 88.89 Precision: 100.00 Recall: 77.78
#
# Fold 2
#
# -----Train----------
# AUC: 99.77 Precision: 100.00 Recall: 99.53
#
# -----Validation-----
# AUC: 79.13 Precision: 91.89 Recall: 64.15
#
# Fold 3
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 86.64 Precision: 91.49 Recall: 81.13
#
# Fold 4
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 80.15 Precision: 97.06 Recall: 62.26
#
# Fold 5
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 85.81 Precision: 97.50 Recall: 73.58
#
# wheezy-copper-turtle-magic 24
#
# Fold 1
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 89.72 Precision: 93.02 Recall: 85.11
#
# Fold 2
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 84.89 Precision: 84.78 Recall: 82.98
#
# Fold 3
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 72.75 Precision: 86.21 Recall: 53.19
#
# Fold 4
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 81.65 Precision: 96.77 Recall: 65.22
#
# Fold 5
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 80.69 Precision: 93.75 Recall: 65.22
#
# wheezy-copper-turtle-magic 25
#
# Fold 1
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 85.82 Precision: 85.11 Recall: 85.11
#
# Fold 2
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 86.89 Precision: 85.42 Recall: 87.23
#
# Fold 3
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 87.34 Precision: 97.30 Recall: 76.60
#
# Fold 4
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 88.13 Precision: 80.36 Recall: 97.83
#
# Fold 5
#
# -----Train----------
# AUC: 99.73 Precision: 100.00 Recall: 99.47
#
# -----Validation-----
# AUC: 78.69 Precision: 88.24 Recall: 65.22
#
# wheezy-copper-turtle-magic 26
#
# Fold 1
#
# -----Train----------
# AUC: 99.73 Precision: 100.00 Recall: 99.47
#
# -----Validation-----
# AUC: 68.87 Precision: 90.91 Recall: 41.67
#
# Fold 2
#
# -----Train----------
# AUC: 99.74 Precision: 100.00 Recall: 99.47
#
# -----Validation-----
# AUC: 80.85 Precision: 100.00 Recall: 61.70
#
# Fold 3
#
# -----Train----------
# AUC: 99.47 Precision: 100.00 Recall: 98.94
#
# -----Validation-----
# AUC: 84.13 Precision: 97.06 Recall: 70.21
#
# Fold 4
#
# -----Train----------
# AUC: 99.21 Precision: 100.00 Recall: 98.41
#
# -----Validation-----
# AUC: 67.15 Precision: 90.00 Recall: 38.30
#
# Fold 5
#
# -----Train----------
# AUC: 99.74 Precision: 100.00 Recall: 99.47
#
# -----Validation-----
# AUC: 85.11 Precision: 100.00 Recall: 70.21
#
# wheezy-copper-turtle-magic 27
#
# Fold 1
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 86.23 Precision: 85.42 Recall: 85.42
#
# Fold 2
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 83.47 Precision: 78.18 Recall: 89.58
#
# Fold 3
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 86.75 Precision: 92.68 Recall: 79.17
#
# Fold 4
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 92.09 Precision: 89.80 Recall: 93.62
#
# Fold 5
#
# -----Train----------
# AUC: 99.74 Precision: 100.00 Recall: 99.48
#
# -----Validation-----
# AUC: 84.64 Precision: 88.10 Recall: 78.72
#
# wheezy-copper-turtle-magic 28
#
# Fold 1
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 88.89 Precision: 85.00 Recall: 94.44
#
# Fold 2
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 79.63 Precision: 73.53 Recall: 92.59
#
# Fold 3
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 83.33 Precision: 79.03 Recall: 90.74
#
# Fold 4
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 95.35 Precision: 98.04 Recall: 92.59
#
# Fold 5
#
# -----Train----------
# AUC: 99.77 Precision: 99.54 Recall: 100.00
#
# -----Validation-----
# AUC: 82.08 Precision: 75.00 Recall: 96.23
#
# wheezy-copper-turtle-magic 29
#
# Fold 1
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 93.00 Precision: 92.16 Recall: 94.00
#
# Fold 2
#
# -----Train----------
# AUC: 99.49 Precision: 99.01 Recall: 100.00
#
# -----Validation-----
# AUC: 79.00 Precision: 71.01 Recall: 98.00
#
# Fold 3
#
# -----Train----------
# AUC: 99.49 Precision: 99.01 Recall: 100.00
#
# -----Validation-----
# AUC: 82.00 Precision: 74.24 Recall: 98.00
#
# Fold 4
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 87.78 Precision: 81.67 Recall: 98.00
#
# Fold 5
#
# -----Train----------
# AUC: 99.75 Precision: 99.50 Recall: 100.00
#
# -----Validation-----
# AUC: 83.67 Precision: 75.76 Recall: 100.00
#
# wheezy-copper-turtle-magic 30
#
# Fold 1
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 77.07 Precision: 70.67 Recall: 98.15
#
# Fold 2
#
# -----Train----------
# AUC: 99.49 Precision: 99.08 Recall: 100.00
#
# -----Validation-----
# AUC: 76.63 Precision: 70.67 Recall: 98.15
#
# Fold 3
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 77.74 Precision: 72.22 Recall: 96.30
#
# Fold 4
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 83.77 Precision: 77.94 Recall: 98.15
#
# Fold 5
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 84.69 Precision: 77.94 Recall: 100.00
#
# wheezy-copper-turtle-magic 31
#
# Fold 1
#
# -----Train----------
# AUC: 99.75 Precision: 100.00 Recall: 99.50
#
# -----Validation-----
# AUC: 84.35 Precision: 94.87 Recall: 72.55
#
# Fold 2
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 86.08 Precision: 95.00 Recall: 76.00
#
# Fold 3
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 76.08 Precision: 93.33 Recall: 56.00
#
# Fold 4
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 89.04 Precision: 95.35 Recall: 82.00
#
# Fold 5
#
# -----Train----------
# AUC: 99.75 Precision: 100.00 Recall: 99.50
#
# -----Validation-----
# AUC: 78.04 Precision: 93.75 Recall: 60.00
#
# wheezy-copper-turtle-magic 32
#
# Fold 1
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 87.81 Precision: 83.02 Recall: 93.62
#
# Fold 2
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 89.62 Precision: 91.11 Recall: 87.23
#
# Fold 3
#
# -----Train----------
# AUC: 99.47 Precision: 100.00 Recall: 98.93
#
# -----Validation-----
# AUC: 83.11 Precision: 94.29 Recall: 70.21
#
# Fold 4
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 82.81 Precision: 75.86 Recall: 93.62
#
# Fold 5
#
# -----Train----------
# AUC: 99.47 Precision: 100.00 Recall: 98.94
#
# -----Validation-----
# AUC: 87.36 Precision: 86.96 Recall: 86.96
#
# wheezy-copper-turtle-magic 33
#
# Fold 1
#
# -----Train----------
# AUC: 98.32 Precision: 96.83 Recall: 100.00
#
# -----Validation-----
# AUC: 80.77 Precision: 72.97 Recall: 100.00
#
# Fold 2
#
# -----Train----------
# AUC: 97.12 Precision: 94.69 Recall: 100.00
#
# -----Validation-----
# AUC: 68.30 Precision: 62.35 Recall: 98.15
#
# Fold 3
#
# -----Train----------
# AUC: 98.80 Precision: 97.72 Recall: 100.00
#
# -----Validation-----
# AUC: 80.88 Precision: 75.00 Recall: 94.44
#
# Fold 4
#
# -----Train----------
# AUC: 99.04 Precision: 98.17 Recall: 100.00
#
# -----Validation-----
# AUC: 84.63 Precision: 77.61 Recall: 98.11
#
# Fold 5
#
# -----Train----------
# AUC: 98.08 Precision: 96.41 Recall: 100.00
#
# -----Validation-----
# AUC: 71.19 Precision: 64.56 Recall: 96.23
#
# wheezy-copper-turtle-magic 34
#
# Fold 1
#
# -----Train----------
# AUC: 97.72 Precision: 96.09 Recall: 100.00
#
# -----Validation-----
# AUC: 66.21 Precision: 62.79 Recall: 96.43
#
# Fold 2
#
# -----Train----------
# AUC: 96.95 Precision: 94.85 Recall: 100.00
#
# -----Validation-----
# AUC: 66.00 Precision: 62.22 Recall: 100.00
#
# Fold 3
#
# -----Train----------
# AUC: 99.75 Precision: 99.55 Recall: 100.00
#
# -----Validation-----
# AUC: 75.62 Precision: 70.13 Recall: 98.18
#
# Fold 4
#
# -----Train----------
# AUC: 97.98 Precision: 96.52 Recall: 100.00
#
# -----Validation-----
# AUC: 76.64 Precision: 71.05 Recall: 98.18
#
# Fold 5
#
# -----Train----------
# AUC: 97.22 Precision: 95.28 Recall: 100.00
#
# -----Validation-----
# AUC: 65.31 Precision: 61.80 Recall: 100.00
#
# wheezy-copper-turtle-magic 35
#
# Fold 1
#
# -----Train----------
# AUC: 99.75 Precision: 99.52 Recall: 100.00
#
# -----Validation-----
# AUC: 81.00 Precision: 73.24 Recall: 100.00
#
# Fold 2
#
# -----Train----------
# AUC: 99.75 Precision: 99.52 Recall: 100.00
#
# -----Validation-----
# AUC: 81.04 Precision: 73.91 Recall: 98.08
#
# Fold 3
#
# -----Train----------
# AUC: 99.75 Precision: 99.52 Recall: 100.00
#
# -----Validation-----
# AUC: 77.04 Precision: 69.86 Recall: 98.08
#
# Fold 4
#
# -----Train----------
# AUC: 99.75 Precision: 99.52 Recall: 100.00
#
# -----Validation-----
# AUC: 84.08 Precision: 79.66 Recall: 92.16
#
# Fold 5
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 80.65 Precision: 73.53 Recall: 98.04
#
# wheezy-copper-turtle-magic 36
#
# Fold 1
#
# -----Train----------
# AUC: 98.62 Precision: 100.00 Recall: 97.24
#
# -----Validation-----
# AUC: 72.83 Precision: 100.00 Recall: 45.65
#
# Fold 2
#
# -----Train----------
# AUC: 98.07 Precision: 100.00 Recall: 96.13
#
# -----Validation-----
# AUC: 61.01 Precision: 91.67 Recall: 23.91
#
# Fold 3
#
# -----Train----------
# AUC: 97.80 Precision: 100.00 Recall: 95.60
#
# -----Validation-----
# AUC: 66.67 Precision: 100.00 Recall: 33.33
#
# Fold 4
#
# -----Train----------
# AUC: 98.35 Precision: 100.00 Recall: 96.70
#
# -----Validation-----
# AUC: 73.67 Precision: 92.00 Recall: 51.11
#
# Fold 5
#
# -----Train----------
# AUC: 98.63 Precision: 100.00 Recall: 97.25
#
# -----Validation-----
# AUC: 71.11 Precision: 100.00 Recall: 42.22
#
# wheezy-copper-turtle-magic 37
#
# Fold 1
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 83.90 Precision: 82.46 Recall: 87.04
#
# Fold 2
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 87.59 Precision: 91.67 Recall: 83.02
#
# Fold 3
#
# -----Train----------
# AUC: 99.76 Precision: 99.53 Recall: 100.00
#
# -----Validation-----
# AUC: 87.37 Precision: 83.33 Recall: 94.34
#
# Fold 4
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 83.89 Precision: 95.00 Recall: 71.70
#
# Fold 5
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 87.51 Precision: 88.46 Recall: 86.79
#
# wheezy-copper-turtle-magic 38
#
# Fold 1
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 83.21 Precision: 94.59 Recall: 70.00
#
# Fold 2
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 75.32 Precision: 90.32 Recall: 56.00
#
# Fold 3
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 87.00 Precision: 100.00 Recall: 74.00
#
# Fold 4
#
# -----Train----------
# AUC: 99.50 Precision: 100.00 Recall: 98.99
#
# -----Validation-----
# AUC: 80.09 Precision: 96.88 Recall: 62.00
#
# Fold 5
#
# -----Train----------
# AUC: 99.25 Precision: 100.00 Recall: 98.50
#
# -----Validation-----
# AUC: 69.72 Precision: 88.00 Recall: 44.90
#
# wheezy-copper-turtle-magic 39
#
# Fold 1
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 88.19 Precision: 89.58 Recall: 86.00
#
# Fold 2
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 93.12 Precision: 93.88 Recall: 92.00
#
# Fold 3
#
# -----Train----------
# AUC: 99.75 Precision: 100.00 Recall: 99.50
#
# -----Validation-----
# AUC: 94.08 Precision: 95.83 Recall: 92.00
#
# Fold 4
#
# -----Train----------
# AUC: 99.75 Precision: 100.00 Recall: 99.50
#
# -----Validation-----
# AUC: 87.06 Precision: 93.02 Recall: 80.00
#
# Fold 5
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 85.13 Precision: 80.36 Recall: 91.84
#
# wheezy-copper-turtle-magic 40
#
# Fold 1
#
# -----Train----------
# AUC: 99.50 Precision: 98.99 Recall: 100.00
#
# -----Validation-----
# AUC: 86.00 Precision: 79.03 Recall: 98.00
#
# Fold 2
#
# -----Train----------
# AUC: 99.75 Precision: 99.49 Recall: 100.00
#
# -----Validation-----
# AUC: 85.98 Precision: 78.69 Recall: 97.96
#
# Fold 3
#
# -----Train----------
# AUC: 98.74 Precision: 97.52 Recall: 100.00
#
# -----Validation-----
# AUC: 67.98 Precision: 60.76 Recall: 97.96
#
# Fold 4
#
# -----Train----------
# AUC: 99.50 Precision: 98.99 Recall: 100.00
#
# -----Validation-----
# AUC: 83.96 Precision: 77.05 Recall: 95.92
#
# Fold 5
#
# -----Train----------
# AUC: 99.50 Precision: 98.99 Recall: 100.00
#
# -----Validation-----
# AUC: 82.65 Precision: 77.59 Recall: 91.84
#
# wheezy-copper-turtle-magic 41
#
# Fold 1
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 84.26 Precision: 78.46 Recall: 94.44
#
# Fold 2
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 82.41 Precision: 74.65 Recall: 98.15
#
# Fold 3
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 83.33 Precision: 78.12 Recall: 92.59
#
# Fold 4
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 89.81 Precision: 89.09 Recall: 90.74
#
# Fold 5
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 84.99 Precision: 81.67 Recall: 90.74
#
# wheezy-copper-turtle-magic 42
#
# Fold 1
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 87.30 Precision: 83.33 Recall: 93.75
#
# Fold 2
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 88.39 Precision: 86.27 Recall: 91.67
#
# Fold 3
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 87.23 Precision: 81.82 Recall: 95.74
#
# Fold 4
#
# -----Train----------
# AUC: 99.73 Precision: 99.48 Recall: 100.00
#
# -----Validation-----
# AUC: 86.17 Precision: 79.31 Recall: 97.87
#
# Fold 5
#
# -----Train----------
# AUC: 99.73 Precision: 99.48 Recall: 100.00
#
# -----Validation-----
# AUC: 88.09 Precision: 83.33 Recall: 95.74
#
# wheezy-copper-turtle-magic 43
#
# Fold 1
#
# -----Train----------
# AUC: 99.77 Precision: 99.51 Recall: 100.00
#
# -----Validation-----
# AUC: 80.39 Precision: 72.73 Recall: 94.12
#
# Fold 2
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 81.64 Precision: 88.10 Recall: 72.55
#
# Fold 3
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 86.35 Precision: 95.12 Recall: 76.47
#
# Fold 4
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 86.40 Precision: 86.00 Recall: 86.00
#
# Fold 5
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 87.40 Precision: 86.27 Recall: 88.00
#
# wheezy-copper-turtle-magic 44
#
# Fold 1
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 91.86 Precision: 89.47 Recall: 96.23
#
# Fold 2
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 85.16 Precision: 86.54 Recall: 84.91
#
# Fold 3
#
# -----Train----------
# AUC: 99.47 Precision: 99.06 Recall: 100.00
#
# -----Validation-----
# AUC: 91.73 Precision: 89.47 Recall: 96.23
#
# Fold 4
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 91.61 Precision: 88.14 Recall: 98.11
#
# Fold 5
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 86.48 Precision: 83.05 Recall: 94.23
#
# wheezy-copper-turtle-magic 45
#
# Fold 1
#
# -----Train----------
# AUC: 99.76 Precision: 99.51 Recall: 100.00
#
# -----Validation-----
# AUC: 80.95 Precision: 75.41 Recall: 90.20
#
# Fold 2
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 80.95 Precision: 75.41 Recall: 90.20
#
# Fold 3
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 86.57 Precision: 84.91 Recall: 88.24
#
# Fold 4
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 87.59 Precision: 83.93 Recall: 92.16
#
# Fold 5
#
# -----Train----------
# AUC: 99.76 Precision: 99.51 Recall: 100.00
#
# -----Validation-----
# AUC: 80.08 Precision: 72.73 Recall: 94.12
#
# wheezy-copper-turtle-magic 46
#
# Fold 1
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 90.06 Precision: 93.48 Recall: 86.00
#
# Fold 2
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 82.00 Precision: 84.78 Recall: 78.00
#
# Fold 3
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 79.00 Precision: 96.77 Recall: 60.00
#
# Fold 4
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 93.00 Precision: 93.88 Recall: 92.00
#
# Fold 5
#
# -----Train----------
# AUC: 99.75 Precision: 99.50 Recall: 100.00
#
# -----Validation-----
# AUC: 82.96 Precision: 75.81 Recall: 95.92
#
# wheezy-copper-turtle-magic 47
#
# Fold 1
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 74.36 Precision: 69.86 Recall: 92.73
#
# Fold 2
#
# -----Train----------
# AUC: 99.75 Precision: 99.54 Recall: 100.00
#
# -----Validation-----
# AUC: 78.07 Precision: 71.62 Recall: 98.15
#
# Fold 3
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 80.07 Precision: 73.61 Recall: 98.15
#
# Fold 4
#
# -----Train----------
# AUC: 99.75 Precision: 99.54 Recall: 100.00
#
# -----Validation-----
# AUC: 78.07 Precision: 71.62 Recall: 98.15
#
# Fold 5
#
# -----Train----------
# AUC: 99.75 Precision: 99.54 Recall: 100.00
#
# -----Validation-----
# AUC: 80.61 Precision: 73.97 Recall: 100.00
#
# wheezy-copper-turtle-magic 48
#
# Fold 1
#
# -----Train----------
# AUC: 99.51 Precision: 99.09 Recall: 100.00
#
# -----Validation-----
# AUC: 85.03 Precision: 85.45 Recall: 85.45
#
# Fold 2
#
# -----Train----------
# AUC: 99.76 Precision: 99.54 Recall: 100.00
#
# -----Validation-----
# AUC: 83.27 Precision: 86.27 Recall: 80.00
#
# Fold 3
#
# -----Train----------
# AUC: 99.76 Precision: 99.54 Recall: 100.00
#
# -----Validation-----
# AUC: 83.73 Precision: 77.61 Recall: 96.30
#
# Fold 4
#
# -----Train----------
# AUC: 99.03 Precision: 98.20 Recall: 100.00
#
# -----Validation-----
# AUC: 84.37 Precision: 77.94 Recall: 98.15
#
# Fold 5
#
# -----Train----------
# AUC: 99.76 Precision: 99.54 Recall: 100.00
#
# -----Validation-----
# AUC: 86.33 Precision: 80.30 Recall: 98.15
#
# wheezy-copper-turtle-magic 49
#
# Fold 1
#
# -----Train----------
# AUC: 99.50 Precision: 100.00 Recall: 99.00
#
# -----Validation-----
# AUC: 82.39 Precision: 94.59 Recall: 68.63
#
# Fold 2
#
# -----Train----------
# AUC: 99.75 Precision: 100.00 Recall: 99.50
#
# -----Validation-----
# AUC: 71.61 Precision: 92.31 Recall: 47.06
#
# Fold 3
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 82.15 Precision: 90.00 Recall: 72.00
#
# Fold 4
#
# -----Train----------
# AUC: 99.50 Precision: 100.00 Recall: 99.01
#
# -----Validation-----
# AUC: 76.12 Precision: 90.62 Recall: 58.00
#
# Fold 5
#
# -----Train----------
# AUC: 99.50 Precision: 100.00 Recall: 99.01
#
# -----Validation-----
# AUC: 83.04 Precision: 97.14 Recall: 68.00
#
# wheezy-copper-turtle-magic 50
#
# Fold 1
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 75.49 Precision: 93.75 Recall: 54.55
#
# Fold 2
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 83.43 Precision: 92.86 Recall: 72.22
#
# Fold 3
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 84.39 Precision: 91.11 Recall: 75.93
#
# Fold 4
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 78.74 Precision: 96.97 Recall: 59.26
#
# Fold 5
#
# -----Train----------
# AUC: 99.54 Precision: 100.00 Recall: 99.08
#
# -----Validation-----
# AUC: 63.92 Precision: 94.12 Recall: 29.63
#
# wheezy-copper-turtle-magic 51
#
# Fold 1
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 83.53 Precision: 79.69 Recall: 89.47
#
# Fold 2
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 83.33 Precision: 76.39 Recall: 96.49
#
# Fold 3
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 85.09 Precision: 79.41 Recall: 94.74
#
# Fold 4
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 92.98 Precision: 94.55 Recall: 91.23
#
# Fold 5
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 80.67 Precision: 72.97 Recall: 96.43
#
# wheezy-copper-turtle-magic 52
#
# Fold 1
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 89.19 Precision: 91.84 Recall: 86.54
#
# Fold 2
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 89.31 Precision: 95.56 Recall: 82.69
#
# Fold 3
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 80.93 Precision: 81.13 Recall: 82.69
#
# Fold 4
#
# -----Train----------
# AUC: 99.74 Precision: 99.52 Recall: 100.00
#
# -----Validation-----
# AUC: 84.70 Precision: 81.36 Recall: 92.31
#
# Fold 5
#
# -----Train----------
# AUC: 99.74 Precision: 99.52 Recall: 100.00
#
# -----Validation-----
# AUC: 80.45 Precision: 75.81 Recall: 92.16
#
# wheezy-copper-turtle-magic 53
#
# Fold 1
#
# -----Train----------
# AUC: 97.83 Precision: 96.31 Recall: 100.00
#
# -----Validation-----
# AUC: 72.46 Precision: 67.53 Recall: 98.11
#
# Fold 2
#
# -----Train----------
# AUC: 98.65 Precision: 97.66 Recall: 100.00
#
# -----Validation-----
# AUC: 72.97 Precision: 68.42 Recall: 98.11
#
# Fold 3
#
# -----Train----------
# AUC: 98.92 Precision: 98.13 Recall: 100.00
#
# -----Validation-----
# AUC: 74.29 Precision: 70.00 Recall: 94.23
#
# Fold 4
#
# -----Train----------
# AUC: 98.65 Precision: 97.67 Recall: 100.00
#
# -----Validation-----
# AUC: 81.65 Precision: 76.12 Recall: 98.08
#
# Fold 5
#
# -----Train----------
# AUC: 98.65 Precision: 97.67 Recall: 100.00
#
# -----Validation-----
# AUC: 79.72 Precision: 75.38 Recall: 94.23
#
# wheezy-copper-turtle-magic 54
#
# Fold 1
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 85.68 Precision: 93.18 Recall: 77.36
#
# Fold 2
#
# -----Train----------
# AUC: 99.76 Precision: 100.00 Recall: 99.52
#
# -----Validation-----
# AUC: 89.19 Precision: 88.68 Recall: 90.38
#
# Fold 3
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 85.16 Precision: 86.27 Recall: 84.62
#
# Fold 4
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 83.36 Precision: 88.89 Recall: 76.92
#
# Fold 5
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 83.91 Precision: 80.00 Recall: 92.31
#
# wheezy-copper-turtle-magic 55
#
# Fold 1
#
# -----Train----------
# AUC: 99.75 Precision: 100.00 Recall: 99.51
#
# -----Validation-----
# AUC: 89.22 Precision: 100.00 Recall: 78.43
#
# Fold 2
#
# -----Train----------
# AUC: 99.75 Precision: 100.00 Recall: 99.51
#
# -----Validation-----
# AUC: 87.29 Precision: 97.50 Recall: 76.47
#
# Fold 3
#
# -----Train----------
# AUC: 99.75 Precision: 100.00 Recall: 99.51
#
# -----Validation-----
# AUC: 70.66 Precision: 92.00 Recall: 45.10
#
# Fold 4
#
# -----Train----------
# AUC: 99.75 Precision: 100.00 Recall: 99.51
#
# -----Validation-----
# AUC: 81.41 Precision: 97.06 Recall: 64.71
#
# Fold 5
#
# -----Train----------
# AUC: 99.75 Precision: 100.00 Recall: 99.51
#
# -----Validation-----
# AUC: 93.06 Precision: 97.78 Recall: 88.00
#
# wheezy-copper-turtle-magic 56
#
# Fold 1
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 85.52 Precision: 85.45 Recall: 87.04
#
# Fold 2
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 88.44 Precision: 88.89 Recall: 88.89
#
# Fold 3
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 86.57 Precision: 91.49 Recall: 81.13
#
# Fold 4
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 90.28 Precision: 90.57 Recall: 90.57
#
# Fold 5
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 90.40 Precision: 93.88 Recall: 86.79
#
# wheezy-copper-turtle-magic 57
#
# Fold 1
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 86.37 Precision: 84.48 Recall: 90.74
#
# Fold 2
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 89.11 Precision: 85.00 Recall: 96.23
#
# Fold 3
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 82.23 Precision: 77.78 Recall: 92.45
#
# Fold 4
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 84.23 Precision: 80.33 Recall: 92.45
#
# Fold 5
#
# -----Train----------
# AUC: 99.25 Precision: 98.61 Recall: 100.00
#
# -----Validation-----
# AUC: 74.80 Precision: 70.00 Recall: 92.45
#
# wheezy-copper-turtle-magic 58
#
# Fold 1
#
# -----Train----------
# AUC: 97.41 Precision: 100.00 Recall: 94.82
#
# -----Validation-----
# AUC: 72.53 Precision: 95.83 Recall: 46.94
#
# Fold 2
#
# -----Train----------
# AUC: 98.96 Precision: 100.00 Recall: 97.93
#
# -----Validation-----
# AUC: 88.78 Precision: 100.00 Recall: 77.55
#
# Fold 3
#
# -----Train----------
# AUC: 99.74 Precision: 100.00 Recall: 99.48
#
# -----Validation-----
# AUC: 88.54 Precision: 100.00 Recall: 77.08
#
# Fold 4
#
# -----Train----------
# AUC: 99.23 Precision: 100.00 Recall: 98.45
#
# -----Validation-----
# AUC: 80.50 Precision: 91.43 Recall: 66.67
#
# Fold 5
#
# -----Train----------
# AUC: 99.23 Precision: 100.00 Recall: 98.45
#
# -----Validation-----
# AUC: 89.66 Precision: 97.50 Recall: 81.25
#
# wheezy-copper-turtle-magic 59
#
# Fold 1
#
# -----Train----------
# AUC: 99.75 Precision: 100.00 Recall: 99.50
#
# -----Validation-----
# AUC: 86.00 Precision: 92.86 Recall: 78.00
#
# Fold 2
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 84.92 Precision: 90.70 Recall: 78.00
#
# Fold 3
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 80.96 Precision: 94.29 Recall: 66.00
#
# Fold 4
#
# -----Train----------
# AUC: 99.75 Precision: 100.00 Recall: 99.50
#
# -----Validation-----
# AUC: 78.98 Precision: 96.77 Recall: 60.00
#
# Fold 5
#
# -----Train----------
# AUC: 99.25 Precision: 100.00 Recall: 98.50
#
# -----Validation-----
# AUC: 76.53 Precision: 96.43 Recall: 55.10
#
# wheezy-copper-turtle-magic 60
#
# Fold 1
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 94.30 Precision: 96.08 Recall: 92.45
#
# Fold 2
#
# -----Train----------
# AUC: 99.76 Precision: 99.53 Recall: 100.00
#
# -----Validation-----
# AUC: 83.73 Precision: 79.03 Recall: 92.45
#
# Fold 3
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 86.42 Precision: 83.05 Recall: 92.45
#
# Fold 4
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 88.25 Precision: 82.26 Recall: 98.08
#
# Fold 5
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 79.45 Precision: 72.46 Recall: 96.15
#
# wheezy-copper-turtle-magic 61
#
# Fold 1
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 89.88 Precision: 85.71 Recall: 96.43
#
# Fold 2
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 93.40 Precision: 88.89 Recall: 100.00
#
# Fold 3
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 84.03 Precision: 77.94 Recall: 96.36
#
# Fold 4
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 89.83 Precision: 90.74 Recall: 89.09
#
# Fold 5
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 83.29 Precision: 82.46 Recall: 85.45
#
# wheezy-copper-turtle-magic 62
#
# Fold 1
#
# -----Train----------
# AUC: 99.49 Precision: 100.00 Recall: 98.98
#
# -----Validation-----
# AUC: 86.11 Precision: 97.37 Recall: 74.00
#
# Fold 2
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 87.88 Precision: 97.44 Recall: 77.55
#
# Fold 3
#
# -----Train----------
# AUC: 99.24 Precision: 100.00 Recall: 98.48
#
# -----Validation-----
# AUC: 67.46 Precision: 94.74 Recall: 36.73
#
# Fold 4
#
# -----Train----------
# AUC: 99.24 Precision: 100.00 Recall: 98.48
#
# -----Validation-----
# AUC: 70.74 Precision: 88.46 Recall: 46.94
#
# Fold 5
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 76.53 Precision: 100.00 Recall: 53.06
#
# wheezy-copper-turtle-magic 63
#
# Fold 1
#
# -----Train----------
# AUC: 99.75 Precision: 99.55 Recall: 100.00
#
# -----Validation-----
# AUC: 73.32 Precision: 68.83 Recall: 94.64
#
# Fold 2
#
# -----Train----------
# AUC: 99.24 Precision: 98.66 Recall: 100.00
#
# -----Validation-----
# AUC: 69.27 Precision: 65.00 Recall: 94.55
#
# Fold 3
#
# -----Train----------
# AUC: 99.75 Precision: 99.55 Recall: 100.00
#
# -----Validation-----
# AUC: 80.09 Precision: 73.97 Recall: 98.18
#
# Fold 4
#
# -----Train----------
# AUC: 99.50 Precision: 99.10 Recall: 100.00
#
# -----Validation-----
# AUC: 72.56 Precision: 67.50 Recall: 98.18
#
# Fold 5
#
# -----Train----------
# AUC: 98.99 Precision: 98.22 Recall: 100.00
#
# -----Validation-----
# AUC: 73.58 Precision: 68.35 Recall: 98.18
#
# wheezy-copper-turtle-magic 64
#
# Fold 1
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 94.51 Precision: 92.86 Recall: 96.30
#
# Fold 2
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 85.39 Precision: 78.46 Recall: 96.23
#
# Fold 3
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 88.99 Precision: 84.75 Recall: 94.34
#
# Fold 4
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 92.56 Precision: 89.47 Recall: 96.23
#
# Fold 5
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 91.60 Precision: 90.74 Recall: 92.45
#
# wheezy-copper-turtle-magic 65
#
# Fold 1
#
# -----Train----------
# AUC: 99.75 Precision: 100.00 Recall: 99.49
#
# -----Validation-----
# AUC: 76.00 Precision: 100.00 Recall: 52.00
#
# Fold 2
#
# -----Train----------
# AUC: 99.75 Precision: 100.00 Recall: 99.49
#
# -----Validation-----
# AUC: 85.43 Precision: 90.70 Recall: 78.00
#
# Fold 3
#
# -----Train----------
# AUC: 99.49 Precision: 100.00 Recall: 98.99
#
# -----Validation-----
# ...
#
# -----Validation-----
# AUC: 82.25 Precision: 89.47 Recall: 72.34
#
# Fold 2
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 80.83 Precision: 72.13 Recall: 95.65
#
# Fold 3
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 83.04 Precision: 87.50 Recall: 76.09
#
# Fold 4
#
# -----Train----------
# AUC: 99.73 Precision: 100.00 Recall: 99.46
#
# -----Validation-----
# AUC: 80.61 Precision: 93.75 Recall: 65.22
#
# Fold 5
#
# -----Train----------
# AUC: 99.46 Precision: 100.00 Recall: 98.92
#
# -----Validation-----
# AUC: 76.61 Precision: 83.33 Recall: 65.22
#
# wheezy-copper-turtle-magic 491
#
# Fold 1
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 83.17 Precision: 90.48 Recall: 74.51
#
# Fold 2
#
# -----Train----------
# AUC: 99.50 Precision: 100.00 Recall: 99.00
#
# -----Validation-----
# AUC: 80.27 Precision: 91.89 Recall: 66.67
#
# Fold 3
#
# -----Train----------
# AUC: 99.75 Precision: 100.00 Recall: 99.50
#
# -----Validation-----
# AUC: 82.94 Precision: 92.31 Recall: 72.00
#
# Fold 4
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 86.82 Precision: 83.64 Recall: 92.00
#
# Fold 5
#
# -----Train----------
# AUC: 99.75 Precision: 100.00 Recall: 99.50
#
# -----Validation-----
# AUC: 86.94 Precision: 93.02 Recall: 80.00
#
# wheezy-copper-turtle-magic 492
#
# Fold 1
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 85.84 Precision: 89.36 Recall: 80.77
#
# Fold 2
#
# -----Train----------
# AUC: 99.76 Precision: 100.00 Recall: 99.51
#
# -----Validation-----
# AUC: 73.34 Precision: 85.29 Recall: 55.77
#
# Fold 3
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 91.56 Precision: 92.16 Recall: 90.38
#
# Fold 4
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 76.97 Precision: 82.93 Recall: 66.67
#
# Fold 5
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 89.27 Precision: 97.62 Recall: 80.39
#
# wheezy-copper-turtle-magic 493
#
# Fold 1
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 79.07 Precision: 72.60 Recall: 98.15
#
# Fold 2
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 79.22 Precision: 73.91 Recall: 94.44
#
# Fold 3
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 89.01 Precision: 86.21 Recall: 94.34
#
# Fold 4
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 77.71 Precision: 71.83 Recall: 96.23
#
# Fold 5
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 92.22 Precision: 94.12 Recall: 90.57
#
# wheezy-copper-turtle-magic 494
#
# Fold 1
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 91.54 Precision: 95.83 Recall: 86.79
#
# Fold 2
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 83.07 Precision: 92.68 Recall: 71.70
#
# Fold 3
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 86.79 Precision: 100.00 Recall: 73.58
#
# Fold 4
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 87.74 Precision: 90.00 Recall: 84.91
#
# Fold 5
#
# -----Train----------
# AUC: 99.53 Precision: 99.07 Recall: 100.00
#
# -----Validation-----
# AUC: 81.13 Precision: 73.91 Recall: 96.23
#
# wheezy-copper-turtle-magic 495
#
# Fold 1
#
# -----Train----------
# AUC: 99.51 Precision: 100.00 Recall: 99.02
#
# -----Validation-----
# AUC: 85.35 Precision: 97.37 Recall: 72.55
#
# Fold 2
#
# -----Train----------
# AUC: 99.51 Precision: 100.00 Recall: 99.02
#
# -----Validation-----
# AUC: 79.47 Precision: 96.88 Recall: 60.78
#
# Fold 3
#
# -----Train----------
# AUC: 99.75 Precision: 100.00 Recall: 99.51
#
# -----Validation-----
# AUC: 78.76 Precision: 85.37 Recall: 68.63
#
# Fold 4
#
# -----Train----------
# AUC: 99.75 Precision: 100.00 Recall: 99.51
#
# -----Validation-----
# AUC: 77.67 Precision: 88.89 Recall: 62.75
#
# Fold 5
#
# -----Train----------
# AUC: 99.51 Precision: 100.00 Recall: 99.02
#
# -----Validation-----
# AUC: 87.31 Precision: 97.50 Recall: 76.47
#
# wheezy-copper-turtle-magic 496
#
# Fold 1
#
# -----Train----------
# AUC: 99.76 Precision: 99.50 Recall: 100.00
#
# -----Validation-----
# AUC: 81.67 Precision: 75.00 Recall: 94.12
#
# Fold 2
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 88.38 Precision: 82.76 Recall: 96.00
#
# Fold 3
#
# -----Train----------
# AUC: 99.75 Precision: 100.00 Recall: 99.50
#
# -----Validation-----
# AUC: 91.08 Precision: 91.84 Recall: 90.00
#
# Fold 4
#
# -----Train----------
# AUC: 99.75 Precision: 100.00 Recall: 99.50
#
# -----Validation-----
# AUC: 77.04 Precision: 93.55 Recall: 58.00
#
# Fold 5
#
# -----Train----------
# AUC: 99.50 Precision: 100.00 Recall: 99.00
#
# -----Validation-----
# AUC: 83.04 Precision: 94.59 Recall: 70.00
#
# wheezy-copper-turtle-magic 497
#
# Fold 1
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 90.57 Precision: 89.09 Recall: 92.45
#
# Fold 2
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 76.42 Precision: 88.89 Recall: 60.38
#
# Fold 3
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 87.72 Precision: 97.62 Recall: 77.36
#
# Fold 4
#
# -----Train----------
# AUC: 99.76 Precision: 99.53 Recall: 100.00
#
# -----Validation-----
# AUC: 83.67 Precision: 76.47 Recall: 98.11
#
# Fold 5
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 77.88 Precision: 89.19 Recall: 63.46
#
# wheezy-copper-turtle-magic 498
#
# Fold 1
#
# -----Train----------
# AUC: 99.52 Precision: 99.04 Recall: 100.00
#
# -----Validation-----
# AUC: 89.59 Precision: 84.75 Recall: 96.15
#
# Fold 2
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 84.65 Precision: 95.00 Recall: 73.08
#
# Fold 3
#
# -----Train----------
# AUC: 99.29 Precision: 98.56 Recall: 100.00
#
# -----Validation-----
# AUC: 79.81 Precision: 72.46 Recall: 96.15
#
# Fold 4
#
# -----Train----------
# AUC: 99.76 Precision: 99.52 Recall: 100.00
#
# -----Validation-----
# AUC: 92.29 Precision: 87.72 Recall: 98.04
#
# Fold 5
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 88.37 Precision: 86.79 Recall: 90.20
#
# wheezy-copper-turtle-magic 499
#
# Fold 1
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 81.75 Precision: 91.89 Recall: 69.39
#
# Fold 2
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 85.83 Precision: 92.68 Recall: 77.55
#
# Fold 3
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 83.75 Precision: 94.59 Recall: 71.43
#
# Fold 4
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 81.99 Precision: 81.63 Recall: 81.63
#
# Fold 5
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 82.93 Precision: 84.78 Recall: 79.59
#
# wheezy-copper-turtle-magic 500
#
# Fold 1
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 82.24 Precision: 86.67 Recall: 76.47
#
# Fold 2
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 89.12 Precision: 90.00 Recall: 88.24
#
# Fold 3
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 84.27 Precision: 94.87 Recall: 72.55
#
# Fold 4
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 87.92 Precision: 91.30 Recall: 84.00
#
# Fold 5
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 82.92 Precision: 90.24 Recall: 74.00
#
# wheezy-copper-turtle-magic 501
#
# Fold 1
#
# -----Train----------
# AUC: 98.27 Precision: 97.20 Recall: 100.00
#
# -----Validation-----
# AUC: 74.04 Precision: 69.86 Recall: 98.08
#
# Fold 2
#
# -----Train----------
# AUC: 98.55 Precision: 97.65 Recall: 100.00
#
# -----Validation-----
# AUC: 77.62 Precision: 73.53 Recall: 96.15
#
# Fold 3
#
# -----Train----------
# AUC: 98.28 Precision: 97.20 Recall: 100.00
#
# -----Validation-----
# AUC: 79.07 Precision: 74.29 Recall: 100.00
#
# Fold 4
#
# -----Train----------
# AUC: 98.28 Precision: 97.20 Recall: 100.00
#
# -----Validation-----
# AUC: 66.48 Precision: 64.56 Recall: 98.08
#
# Fold 5
#
# -----Train----------
# AUC: 97.99 Precision: 96.74 Recall: 100.00
#
# -----Validation-----
# AUC: 72.70 Precision: 70.00 Recall: 94.23
#
# wheezy-copper-turtle-magic 502
#
# Fold 1
#
# -----Train----------
# AUC: 99.76 Precision: 100.00 Recall: 99.51
#
# -----Validation-----
# AUC: 90.49 Precision: 93.75 Recall: 86.54
#
# Fold 2
#
# -----Train----------
# AUC: 98.79 Precision: 100.00 Recall: 97.57
#
# -----Validation-----
# AUC: 84.65 Precision: 95.00 Recall: 73.08
#
# Fold 3
#
# -----Train----------
# AUC: 98.54 Precision: 100.00 Recall: 97.09
#
# -----Validation-----
# AUC: 79.81 Precision: 100.00 Recall: 59.62
#
# Fold 4
#
# -----Train----------
# AUC: 99.52 Precision: 100.00 Recall: 99.03
#
# -----Validation-----
# AUC: 86.53 Precision: 86.27 Recall: 86.27
#
# Fold 5
#
# -----Train----------
# AUC: 99.52 Precision: 100.00 Recall: 99.03
#
# -----Validation-----
# AUC: 87.37 Precision: 93.18 Recall: 80.39
#
# wheezy-copper-turtle-magic 503
#
# Fold 1
#
# -----Train----------
# AUC: 98.94 Precision: 100.00 Recall: 97.87
#
# -----Validation-----
# AUC: 71.96 Precision: 92.00 Recall: 47.92
#
# Fold 2
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 85.23 Precision: 94.59 Recall: 74.47
#
# Fold 3
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 83.23 Precision: 89.74 Recall: 74.47
#
# Fold 4
#
# -----Train----------
# AUC: 98.94 Precision: 100.00 Recall: 97.88
#
# -----Validation-----
# AUC: 80.94 Precision: 93.94 Recall: 65.96
#
# Fold 5
#
# -----Train----------
# AUC: 99.74 Precision: 100.00 Recall: 99.47
#
# -----Validation-----
# AUC: 78.85 Precision: 90.91 Recall: 63.83
#
# wheezy-copper-turtle-magic 504
#
# Fold 1
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 87.09 Precision: 86.79 Recall: 88.46
#
# Fold 2
#
# -----Train----------
# AUC: 99.76 Precision: 100.00 Recall: 99.52
#
# -----Validation-----
# AUC: 90.15 Precision: 92.00 Recall: 88.46
#
# Fold 3
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 90.03 Precision: 88.89 Recall: 92.31
#
# Fold 4
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 78.55 Precision: 87.50 Recall: 67.31
#
# Fold 5
#
# -----Train----------
# AUC: 99.76 Precision: 100.00 Recall: 99.52
#
# -----Validation-----
# AUC: 85.46 Precision: 95.12 Recall: 75.00
#
# wheezy-copper-turtle-magic 505
#
# Fold 1
#
# -----Train----------
# AUC: 99.75 Precision: 100.00 Recall: 99.51
#
# -----Validation-----
# AUC: 87.25 Precision: 100.00 Recall: 74.51
#
# Fold 2
#
# -----Train----------
# AUC: 99.01 Precision: 100.00 Recall: 98.03
#
# -----Validation-----
# AUC: 70.64 Precision: 88.89 Recall: 47.06
#
# Fold 3
#
# -----Train----------
# AUC: 99.75 Precision: 100.00 Recall: 99.51
#
# -----Validation-----
# AUC: 81.43 Precision: 92.11 Recall: 68.63
#
# Fold 4
#
# -----Train----------
# AUC: 98.77 Precision: 100.00 Recall: 97.54
#
# -----Validation-----
# AUC: 75.55 Precision: 90.62 Recall: 56.86
#
# Fold 5
#
# -----Train----------
# AUC: 99.75 Precision: 100.00 Recall: 99.51
#
# -----Validation-----
# AUC: 89.15 Precision: 91.49 Recall: 86.00
#
# wheezy-copper-turtle-magic 506
#
# Fold 1
#
# -----Train----------
# AUC: 99.53 Precision: 100.00 Recall: 99.06
#
# -----Validation-----
# AUC: 82.41 Precision: 100.00 Recall: 64.81
#
# Fold 2
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 85.97 Precision: 86.54 Recall: 84.91
#
# Fold 3
#
# -----Train----------
# AUC: 99.77 Precision: 100.00 Recall: 99.53
#
# -----Validation-----
# AUC: 83.96 Precision: 92.86 Recall: 73.58
#
# Fold 4
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 95.28 Precision: 98.00 Recall: 92.45
#
# Fold 5
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 90.57 Precision: 93.88 Recall: 86.79
#
# wheezy-copper-turtle-magic 507
#
# Fold 1
#
# -----Train----------
# AUC: 99.49 Precision: 100.00 Recall: 98.99
#
# -----Validation-----
# AUC: 75.09 Precision: 96.30 Recall: 52.00
#
# Fold 2
#
# -----Train----------
# AUC: 99.75 Precision: 100.00 Recall: 99.49
#
# -----Validation-----
# AUC: 69.07 Precision: 95.24 Recall: 40.00
#
# Fold 3
#
# -----Train----------
# AUC: 99.49 Precision: 100.00 Recall: 98.99
#
# -----Validation-----
# AUC: 72.00 Precision: 100.00 Recall: 44.00
#
# Fold 4
#
# -----Train----------
# AUC: 99.75 Precision: 100.00 Recall: 99.50
#
# -----Validation-----
# AUC: 73.47 Precision: 100.00 Recall: 46.94
#
# Fold 5
#
# -----Train----------
# AUC: 99.50 Precision: 100.00 Recall: 98.99
#
# -----Validation-----
# AUC: 77.74 Precision: 93.55 Recall: 59.18
#
# wheezy-copper-turtle-magic 508
#
# Fold 1
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 83.02 Precision: 94.87 Recall: 69.81
#
# Fold 2
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 81.73 Precision: 90.24 Recall: 71.15
#
# Fold 3
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 76.92 Precision: 96.67 Recall: 55.77
#
# Fold 4
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 83.65 Precision: 88.89 Recall: 76.92
#
# Fold 5
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 78.85 Precision: 82.61 Recall: 73.08
#
# wheezy-copper-turtle-magic 509
#
# Fold 1
#
# -----Train----------
# AUC: 99.75 Precision: 99.49 Recall: 100.00
#
# -----Validation-----
# AUC: 79.33 Precision: 73.02 Recall: 92.00
#
# Fold 2
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 80.93 Precision: 82.61 Recall: 77.55
#
# Fold 3
#
# -----Train----------
# AUC: 99.75 Precision: 99.49 Recall: 100.00
#
# -----Validation-----
# AUC: 85.21 Precision: 78.33 Recall: 95.92
#
# Fold 4
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 82.89 Precision: 86.36 Recall: 77.55
#
# Fold 5
#
# -----Train----------
# AUC: 99.75 Precision: 100.00 Recall: 99.49
#
# -----Validation-----
# AUC: 81.87 Precision: 86.05 Recall: 75.51
#
# wheezy-copper-turtle-magic 510
#
# Fold 1
#
# -----Train----------
# AUC: 97.51 Precision: 100.00 Recall: 95.02
#
# -----Validation-----
# AUC: 70.59 Precision: 100.00 Recall: 41.18
#
# Fold 2
#
# -----Train----------
# AUC: 99.00 Precision: 100.00 Recall: 98.01
#
# -----Validation-----
# AUC: 80.50 Precision: 91.89 Recall: 66.67
#
# Fold 3
#
# -----Train----------
# AUC: 98.51 Precision: 100.00 Recall: 97.03
#
# -----Validation-----
# AUC: 72.17 Precision: 89.29 Recall: 50.00
#
# Fold 4
#
# -----Train----------
# AUC: 98.02 Precision: 100.00 Recall: 96.04
#
# -----Validation-----
# AUC: 69.08 Precision: 91.30 Recall: 42.00
#
# Fold 5
#
# -----Train----------
# AUC: 98.76 Precision: 100.00 Recall: 97.52
#
# -----Validation-----
# AUC: 66.08 Precision: 90.00 Recall: 36.00
#
# wheezy-copper-turtle-magic 511
#
# Fold 1
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 87.87 Precision: 83.33 Recall: 96.15
#
# Fold 2
#
# -----Train----------
# AUC: 99.76 Precision: 100.00 Recall: 99.51
#
# -----Validation-----
# AUC: 86.24 Precision: 89.58 Recall: 82.69
#
# Fold 3
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 81.69 Precision: 75.00 Recall: 98.08
#
# Fold 4
#
# -----Train----------
# AUC: 100.00 Precision: 100.00 Recall: 100.00
#
# -----Validation-----
# AUC: 88.04 Precision: 89.80 Recall: 86.27
#
# Fold 5
#
# -----Train----------
# AUC: 99.76 Precision: 100.00 Recall: 99.52
#
# -----Validation-----
# AUC: 82.05 Precision: 88.37 Recall: 74.51

# %% [markdown]
# # Ensemble models

# %%
train['preds_top2'] = (train['preds_qda'] * 0.5) + (train['preds_nusvc'] * 0.5)
test['target_top2'] = (test['target_qda'] * 0.5) + (test['target_nusvc'] * 0.5)

train['preds_top3'] = (train['preds_qda'] * 0.35) + (train['preds_mlp'] * 0.3) + (train['preds_nusvc'] * 0.35)
test['target_top3'] = (test['target_qda'] * 0.35) + (test['target_mlp'] * 0.3) + (test['target_nusvc'] * 0.35)

train['preds_top4'] = (train['preds_qda'] * 0.25) + (train['preds_mlp'] * 0.25) + (train['preds_svc'] * 0.25) + (train['preds_nusvc'] * 0.25)
test['target_top4'] = (test['target_qda'] * 0.25) + (test['target_mlp'] * 0.25) + (test['target_svc'] * 0.25) + (test['target_nusvc'] * 0.25)

train['preds_avg'] = (train['preds_qda'] * 0.2) + (train['preds_knn'] * 0.2) + (train['preds_mlp'] * 0.2) + (train['preds_svc'] * 0.2) + (train['preds_nusvc'] * 0.2)
test['target_avg'] = (test['target_qda'] * 0.2) + (test['target_knn'] * 0.2) + (test['target_mlp'] * 0.2) + (test['target_svc'] * 0.2) + (test['target_nusvc'] * 0.2)

# %% [markdown]
# # Model evaluation
# ## Confusion matrix

# %%
f = plt.subplots(1, 1, figsize=(16, 5), sharex=True)
train_cnf_matrix = confusion_matrix(train['target'], [np.round(x) for x in train['preds_avg']])
train_cnf_matrix_norm = train_cnf_matrix / train_cnf_matrix.sum(axis=1)[:, np.newaxis]
train_df_cm = pd.DataFrame(train_cnf_matrix_norm, index=[0, 1], columns=[0, 1])
sns.heatmap(train_df_cm, annot=True, fmt='.2f', cmap="Blues")
plt.show()

# %% [markdown]
# ## Metrics ROC AUC

# %%
print('QDA AUC %.2f' % roc_auc_score(train['target'], train['preds_qda']))
print('KNN AUC %.2f' % roc_auc_score(train['target'], train['preds_knn']))
print('MLP AUC %.2f' % roc_auc_score(train['target'], train['preds_mlp']))
print('SVC AUC %.2f' % roc_auc_score(train['target'], train['preds_svc']))
print('NuSVC AUC %.2f' % roc_auc_score(train['target'], train['preds_nusvc']))
print('Top 2 AUC %.2f' % roc_auc_score(train['target'], train['preds_top2']))
print('Top 3 AUC %.2f' % roc_auc_score(train['target'], train['preds_top3']))
print('Top 4 AUC %.2f' % roc_auc_score(train['target'], train['preds_top4']))
print('Averaged AUC %.2f' % roc_auc_score(train['target'], train['preds_avg']))
# Out:
# QDA AUC 0.99
# KNN AUC 0.97
# MLP AUC 1.00
# SVC AUC 1.00
# NuSVC AUC 1.00
# Top 2 AUC 1.00
# Top 3 AUC 1.00
# Top 4 AUC 1.00
# Averaged AUC 1.00

# %%
test[['id', 'target_avg', 'target_qda', 'target_knn', 'target_mlp', 'target_svc', 'target_nusvc']].head(10)
# Out:
#                                  id      ...       target_nusvc
# 0  1c13f2701648e0b0d46d8a2a5a131a53      ...           0.714108
# 1  ba88c155ba898fc8b5099893036ef205      ...           0.510971
# 2  7cbab5cea99169139e7e6d8ff74ebb77      ...           0.425507
# 3  ca820ad57809f62eb7b4d13f5d4371a0      ...           0.609120
# 4  7baaf361537fbd8a1aaa2c97a6d4ccc7      ...           0.177280
# 5  8b3116e5e3e92e971dac305d1a093bf6      ...           0.007024
# 6  35cfd7cab9bfa29bc963d1b8c94dd280      ...           0.019388
# 7  83cf532df8ff4642a3e33a70fffdac37      ...           0.862568
# 8  2e1350fe94ec9f2220bec5245e5e9265      ...           0.680472
# 9  e62020afa72eb54a15725473e3a8475b      ...           0.373069
#
# [10 rows x 7 columns]

# %% [markdown]
# # Test predictions

# %%
submission = test[['id', 'target_avg']]
submission.columns = ['id', 'target']
submission.to_csv('submission_avg.csv', index=False)
submission.head(10)
# Out:
#                                  id    target
# 0  1c13f2701648e0b0d46d8a2a5a131a53  0.653531
# 1  ba88c155ba898fc8b5099893036ef205  0.675312
# 2  7cbab5cea99169139e7e6d8ff74ebb77  0.418763
# 3  ca820ad57809f62eb7b4d13f5d4371a0  0.375399
# 4  7baaf361537fbd8a1aaa2c97a6d4ccc7  0.314452
# 5  8b3116e5e3e92e971dac305d1a093bf6  0.129863
# 6  35cfd7cab9bfa29bc963d1b8c94dd280  0.025273
# 7  83cf532df8ff4642a3e33a70fffdac37  0.932103
# 8  2e1350fe94ec9f2220bec5245e5e9265  0.751831
# 9  e62020afa72eb54a15725473e3a8475b  0.185403

# %%
submission = test[['id', 'target_top2']]
submission.columns = ['id', 'target']
submission.to_csv('submission_top2.csv', index=False)
submission.head(10)
# Out:
#                                  id    target
# 0  1c13f2701648e0b0d46d8a2a5a131a53  0.857044
# 1  ba88c155ba898fc8b5099893036ef205  0.740037
# 2  7cbab5cea99169139e7e6d8ff74ebb77  0.212756
# 3  ca820ad57809f62eb7b4d13f5d4371a0  0.374019
# 4  7baaf361537fbd8a1aaa2c97a6d4ccc7  0.290379
# 5  8b3116e5e3e92e971dac305d1a093bf6  0.003512
# 6  35cfd7cab9bfa29bc963d1b8c94dd280  0.009694
# 7  83cf532df8ff4642a3e33a70fffdac37  0.931284
# 8  2e1350fe94ec9f2220bec5245e5e9265  0.840016
# 9  e62020afa72eb54a15725473e3a8475b  0.194293

# %%
submission = test[['id', 'target_top3']]
submission.columns = ['id', 'target']
submission.to_csv('submission_top3.csv', index=False)
submission.head(10)
# Out:
#                                  id    target
# 0  1c13f2701648e0b0d46d8a2a5a131a53  0.732646
# 1  ba88c155ba898fc8b5099893036ef205  0.746097
# 2  7cbab5cea99169139e7e6d8ff74ebb77  0.312874
# 3  ca820ad57809f62eb7b4d13f5d4371a0  0.301316
# 4  7baaf361537fbd8a1aaa2c97a6d4ccc7  0.269418
# 5  8b3116e5e3e92e971dac305d1a093bf6  0.061744
# 6  35cfd7cab9bfa29bc963d1b8c94dd280  0.010505
# 7  83cf532df8ff4642a3e33a70fffdac37  0.946488
# 8  2e1350fe94ec9f2220bec5245e5e9265  0.795845
# 9  e62020afa72eb54a15725473e3a8475b  0.150597

# %%
submission = test[['id', 'target_top4']]
submission.columns = ['id', 'target']
submission.to_csv('submission_top4.csv', index=False)
submission.head(10)
# Out:
#                                  id    target
# 0  1c13f2701648e0b0d46d8a2a5a131a53  0.726913
# 1  ba88c155ba898fc8b5099893036ef205  0.704140
# 2  7cbab5cea99169139e7e6d8ff74ebb77  0.333454
# 3  ca820ad57809f62eb7b4d13f5d4371a0  0.369249
# 4  7baaf361537fbd8a1aaa2c97a6d4ccc7  0.283065
# 5  8b3116e5e3e92e971dac305d1a093bf6  0.052329
# 6  35cfd7cab9bfa29bc963d1b8c94dd280  0.031591
# 7  83cf532df8ff4642a3e33a70fffdac37  0.935128
# 8  2e1350fe94ec9f2220bec5245e5e9265  0.749789
# 9  e62020afa72eb54a15725473e3a8475b  0.161754

# %%
submission = test[['id', 'target_qda']]
submission.columns = ['id', 'target']
submission.to_csv('submission_qda.csv', index=False)
submission.head(10)
# Out:
#                                  id        target
# 0  1c13f2701648e0b0d46d8a2a5a131a53  9.999792e-01
# 1  ba88c155ba898fc8b5099893036ef205  9.691031e-01
# 2  7cbab5cea99169139e7e6d8ff74ebb77  4.450004e-06
# 3  ca820ad57809f62eb7b4d13f5d4371a0  1.389180e-01
# 4  7baaf361537fbd8a1aaa2c97a6d4ccc7  4.034775e-01
# 5  8b3116e5e3e92e971dac305d1a093bf6  1.182619e-07
# 6  35cfd7cab9bfa29bc963d1b8c94dd280  1.157834e-09
# 7  83cf532df8ff4642a3e33a70fffdac37  9.999995e-01
# 8  2e1350fe94ec9f2220bec5245e5e9265  9.995598e-01
# 9  e62020afa72eb54a15725473e3a8475b  1.551651e-02

# %%
submission = test[['id', 'target_knn']]
submission.columns = ['id', 'target']
submission.to_csv('submission_knn.csv', index=False)
submission.head(10)
# Out:
#                                  id  target
# 0  1c13f2701648e0b0d46d8a2a5a131a53    0.36
# 1  ba88c155ba898fc8b5099893036ef205    0.56
# 2  7cbab5cea99169139e7e6d8ff74ebb77    0.76
# 3  ca820ad57809f62eb7b4d13f5d4371a0    0.40
# 4  7baaf361537fbd8a1aaa2c97a6d4ccc7    0.44
# 5  8b3116e5e3e92e971dac305d1a093bf6    0.44
# 6  35cfd7cab9bfa29bc963d1b8c94dd280    0.00
# 7  83cf532df8ff4642a3e33a70fffdac37    0.92
# 8  2e1350fe94ec9f2220bec5245e5e9265    0.76
# 9  e62020afa72eb54a15725473e3a8475b    0.28

# %%
submission = test[['id', 'target_mlp']]
submission.columns = ['id', 'target']
submission.to_csv('submission_mlp.csv', index=False)
submission.head(10)
# Out:
#                                  id    target
# 0  1c13f2701648e0b0d46d8a2a5a131a53  0.442387
# 1  ba88c155ba898fc8b5099893036ef205  0.760237
# 2  7cbab5cea99169139e7e6d8ff74ebb77  0.546485
# 3  ca820ad57809f62eb7b4d13f5d4371a0  0.131675
# 4  7baaf361537fbd8a1aaa2c97a6d4ccc7  0.220511
# 5  8b3116e5e3e92e971dac305d1a093bf6  0.197618
# 6  35cfd7cab9bfa29bc963d1b8c94dd280  0.012397
# 7  83cf532df8ff4642a3e33a70fffdac37  0.981967
# 8  2e1350fe94ec9f2220bec5245e5e9265  0.692778
# 9  e62020afa72eb54a15725473e3a8475b  0.048642

# %%
submission = test[['id', 'target_svc']]
submission.columns = ['id', 'target']
submission.to_csv('submission_svc.csv', index=False)
submission.head(10)
# Out:
#                                  id    target
# 0  1c13f2701648e0b0d46d8a2a5a131a53  0.751179
# 1  ba88c155ba898fc8b5099893036ef205  0.576248
# 2  7cbab5cea99169139e7e6d8ff74ebb77  0.361820
# 3  ca820ad57809f62eb7b4d13f5d4371a0  0.597283
# 4  7baaf361537fbd8a1aaa2c97a6d4ccc7  0.330992
# 5  8b3116e5e3e92e971dac305d1a093bf6  0.004675
# 6  35cfd7cab9bfa29bc963d1b8c94dd280  0.094578
# 7  83cf532df8ff4642a3e33a70fffdac37  0.895979
# 8  2e1350fe94ec9f2220bec5245e5e9265  0.626346
# 9  e62020afa72eb54a15725473e3a8475b  0.209789

# %%
submission = test[['id', 'target_nusvc']]
submission.columns = ['id', 'target']
submission.to_csv('submission_nusvc.csv', index=False)
submission.head(10)
# Out:
#                                  id    target
# 0  1c13f2701648e0b0d46d8a2a5a131a53  0.714108
# 1  ba88c155ba898fc8b5099893036ef205  0.510971
# 2  7cbab5cea99169139e7e6d8ff74ebb77  0.425507
# 3  ca820ad57809f62eb7b4d13f5d4371a0  0.609120
# 4  7baaf361537fbd8a1aaa2c97a6d4ccc7  0.177280
# 5  8b3116e5e3e92e971dac305d1a093bf6  0.007024
# 6  35cfd7cab9bfa29bc963d1b8c94dd280  0.019388
# 7  83cf532df8ff4642a3e33a70fffdac37  0.862568
# 8  2e1350fe94ec9f2220bec5245e5e9265  0.680472
# 9  e62020afa72eb54a15725473e3a8475b  0.373069
